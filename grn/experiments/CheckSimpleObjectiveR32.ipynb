# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(7, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late)**2 + abs(neuron_infra_late - ref_neuron_infra_late)**2
                  + abs(neuron_supra_late - ref_neuron_supra_late)**2)
    delta_early = (abs(prog_early - ref_prog_early)**2 + abs(neuron_infra_early - ref_neuron_infra_early)**2
                  + abs(neuron_supra_early - ref_neuron_supra_early)**2)

    return 1 / max(1, 10000 - 1 * delta_late - 0.5 * delta_early)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=50, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r32"
res = main(prun)

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r32

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
res.fit
# Out:
# 7444.972013845614

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} {res.fit} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 3554.622306976957 =======
# >> G_0: init: 1.00; noise: 1.00; b: 3.67; m: 6.34; expr: 1.00; deg: 0.10; theta: 6.01; asym: 5.00; tree : -6
# >> G_1: init: 0.46; noise: 1.00; b: 0.94; m: 3.38; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : ((4 AND -1) OR (-7 AND 3))
# >> G_2: init: 1.21; noise: 1.00; b: 1.84; m: 5.71; expr: 1.00; deg: 0.10; theta: 0.24; asym: 5.24; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.13; noise: 1.00; b: 0.22; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.00; tree : -5
# >> G_4: init: 1.84; noise: 1.00; b: 0.25; m: 5.19; expr: 1.00; deg: 0.10; theta: 1.09; asym: 5.00; tree : ((6 OR -1) AND -5)
# >> G_5: init: 0.29; noise: 1.00; b: 1.43; m: 4.80; expr: 1.00; deg: 0.10; theta: 7.14; asym: 5.00; tree : ((-2 OR 0) OR 1)
# >> G_6: init: 0.32; noise: 1.00; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.88; asym: 5.00; tree : ((3 OR 5) OR -1)
#
# ======= GENERATION generation_g1 6451.4703376398575 =======
# >> G_0: init: 1.00; noise: 1.00; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.01; asym: 5.00; tree : -6
# >> G_1: init: 0.46; noise: 1.00; b: 0.94; m: 3.38; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : ((4 AND -1) OR (-7 AND 2))
# >> G_2: init: 1.21; noise: 1.00; b: 1.87; m: 5.71; expr: 1.00; deg: 0.12; theta: 0.24; asym: 5.24; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.13; noise: 1.00; b: 0.22; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.00; tree : -5
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 5.19; expr: 1.00; deg: 0.10; theta: 1.09; asym: 5.00; tree : ((6 OR -1) AND 2)
# >> G_5: init: 0.29; noise: 1.00; b: 1.43; m: 4.80; expr: 1.00; deg: 0.10; theta: 7.14; asym: 4.05; tree : ((-2 OR 0) OR 1)
# >> G_6: init: 0.30; noise: 1.00; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.88; asym: 5.00; tree : ((3 OR 5) OR -1)
#
# ======= GENERATION generation_g2 6618.632365234829 =======
# >> G_0: init: 1.00; noise: 1.00; b: 4.11; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.01; asym: 4.41; tree : -6
# >> G_1: init: 0.46; noise: 1.00; b: 0.94; m: 3.38; expr: 1.00; deg: 0.09; theta: 7.31; asym: 5.00; tree : ((4 AND -1) OR (-7 AND 2))
# >> G_2: init: 1.21; noise: 1.02; b: 1.87; m: 5.71; expr: 1.00; deg: 0.11; theta: 0.24; asym: 5.24; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.13; noise: 1.00; b: 0.24; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.94; asym: 5.00; tree : -5
# >> G_4: init: 1.84; noise: 1.00; b: 0.25; m: 5.19; expr: 1.00; deg: 0.10; theta: 1.09; asym: 5.00; tree : ((6 OR -1) AND 4)
# >> G_5: init: 0.29; noise: 1.00; b: 1.43; m: 4.80; expr: 1.00; deg: 0.12; theta: 7.14; asym: 5.00; tree : (-2 OR -5)
# >> G_6: init: 0.32; noise: 1.00; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.88; asym: 5.00; tree : ((3 OR 5) OR -1)
#
# ======= GENERATION generation_g3 6350.131668862413 =======
# >> G_0: init: 1.00; noise: 1.00; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 5.06; tree : -6
# >> G_1: init: 0.46; noise: 1.00; b: 0.94; m: 3.38; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : ((4 AND -1) OR (-3 AND 2))
# >> G_2: init: 1.42; noise: 1.00; b: 1.87; m: 5.71; expr: 1.00; deg: 0.10; theta: 0.24; asym: 5.24; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.13; noise: 1.00; b: 0.22; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.00; tree : -5
# >> G_4: init: 1.84; noise: 1.00; b: 0.25; m: 5.42; expr: 1.11; deg: 0.10; theta: 1.09; asym: 5.76; tree : ((6 OR -1) AND -5)
# >> G_5: init: 0.53; noise: 4.78; b: 4.07; m: 8.00; expr: 4.26; deg: 0.49; theta: 6.19; asym: 4.64; tree : ((7 OR -6) OR -3)
# >> G_6: init: 0.32; noise: 1.00; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.88; asym: 5.00; tree : ((0 OR 5) OR -1)
#
# ======= GENERATION generation_g4 6549.964460686459 =======
# >> G_0: init: 1.00; noise: 1.00; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 5.06; tree : -6
# >> G_1: init: 0.46; noise: 1.00; b: 0.94; m: 3.38; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-3 AND 2)
# >> G_2: init: 1.42; noise: 1.01; b: 1.87; m: 5.71; expr: 1.00; deg: 0.10; theta: 0.24; asym: 4.63; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.13; noise: 1.00; b: 0.22; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.00; tree : -5
# >> G_4: init: 1.84; noise: 1.00; b: 0.25; m: 5.42; expr: 1.00; deg: 0.10; theta: 1.09; asym: 5.76; tree : (-1 AND -5)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.14; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.88; asym: 5.00; tree : ((0 OR 5) OR -1)
#
# ======= GENERATION generation_g5 6854.436180086748 =======
# >> G_0: init: 1.00; noise: 1.00; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 5.06; tree : -6
# >> G_1: init: 0.46; noise: 1.00; b: 0.94; m: 3.11; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (-3 AND 2))
# >> G_2: init: 1.42; noise: 1.01; b: 1.50; m: 5.71; expr: 1.00; deg: 0.10; theta: 0.24; asym: 4.63; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.13; noise: 1.00; b: 0.22; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.00; tree : (-5 OR -6)
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 5.42; expr: 1.00; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -5)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.14; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.88; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g6 7270.825566368262 =======
# >> G_0: init: 1.00; noise: 1.00; b: 3.67; m: 5.34; expr: 0.87; deg: 0.10; theta: 6.68; asym: 5.06; tree : -6
# >> G_1: init: 0.46; noise: 1.00; b: 0.94; m: 3.38; expr: 1.00; deg: 0.11; theta: 7.31; asym: 5.00; tree : (-1 OR (-3 AND 2))
# >> G_2: init: 1.42; noise: 1.01; b: 1.87; m: 5.71; expr: 0.92; deg: 0.10; theta: 0.24; asym: 4.63; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.13; noise: 1.00; b: 0.22; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.00; tree : -1
# >> G_4: init: 1.84; noise: 1.00; b: 0.25; m: 5.42; expr: 1.00; deg: 0.10; theta: 1.09; asym: 5.76; tree : (-1 AND -5)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.14; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.39; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.64; asym: 5.00; tree : ((0 OR 5) OR -1)
#
# ======= GENERATION generation_g7 6953.778376264223 =======
# >> G_0: init: 1.00; noise: 0.91; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 5.06; tree : -6
# >> G_1: init: 0.43; noise: 1.11; b: 0.94; m: 3.11; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (-3 AND 2))
# >> G_2: init: 1.42; noise: 1.01; b: 1.50; m: 5.71; expr: 1.00; deg: 0.11; theta: 0.24; asym: 4.33; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.34; noise: 1.00; b: 0.22; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.47; tree : (-5 OR -6)
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 5.42; expr: 1.00; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.13; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g8 7533.631615649532 =======
# >> G_0: init: 1.00; noise: 0.91; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 5.06; tree : -6
# >> G_1: init: 0.43; noise: 1.11; b: 0.94; m: 3.11; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (-3 AND 2))
# >> G_2: init: 1.42; noise: 1.01; b: 1.50; m: 5.71; expr: 1.00; deg: 0.11; theta: 0.24; asym: 4.37; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.34; noise: 1.00; b: 0.22; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.82; asym: 6.45; tree : ((-5 OR -6) OR -0)
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 4.39; expr: 1.00; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.13; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g9 6911.000107688577 =======
# >> G_0: init: 1.00; noise: 0.91; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 4.69; tree : -6
# >> G_1: init: 0.46; noise: 1.11; b: 0.94; m: 3.11; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (6 OR (-3 AND 2))
# >> G_2: init: 1.42; noise: 0.83; b: 1.50; m: 5.71; expr: 1.00; deg: 0.11; theta: 0.24; asym: 3.89; tree : (2 OR (-6 AND 4))
# >> G_3: init: 1.34; noise: 1.00; b: 0.22; m: 2.42; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.47; tree : -1
# >> G_4: init: 1.84; noise: 1.00; b: 0.23; m: 6.09; expr: 1.00; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -5)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.14; theta: 3.66; asym: 9.17; tree : (7 AND 6)
# >> G_6: init: 0.32; noise: 1.11; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.88; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g10 7404.410755586106 =======
# >> G_0: init: 1.00; noise: 0.91; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 5.06; tree : -6
# >> G_1: init: 0.43; noise: 1.11; b: 0.94; m: 3.34; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.42; noise: 1.01; b: 1.50; m: 5.71; expr: 1.00; deg: 0.11; theta: 0.24; asym: 4.37; tree : ((2 OR 7) OR (-6 AND 4))
# >> G_3: init: 1.34; noise: 1.00; b: 0.22; m: 1.99; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.11; tree : (-5 OR -6)
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 4.39; expr: 1.00; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.13; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g11 7165.796996679343 =======
# >> G_0: init: 1.00; noise: 0.91; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 5.06; tree : -6
# >> G_1: init: 0.43; noise: 1.11; b: 0.94; m: 3.34; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR 2)
# >> G_2: init: 1.42; noise: 1.01; b: 1.50; m: 4.90; expr: 1.00; deg: 0.11; theta: 0.24; asym: 4.37; tree : ((2 OR 7) OR (5 AND 4))
# >> G_3: init: 1.34; noise: 1.00; b: 0.19; m: 1.99; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.11; tree : (-5 OR -6)
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 4.39; expr: 1.00; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 5.22; b: 0.97; m: 8.12; expr: 0.34; deg: 0.13; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.99; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g12 7042.370665820067 =======
# >> G_0: init: 1.00; noise: 0.97; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 1.11; b: 0.94; m: 3.09; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.42; noise: 1.01; b: 1.50; m: 4.90; expr: 1.00; deg: 0.11; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 1.34; noise: 1.00; b: 0.22; m: 1.99; expr: 1.00; deg: 0.10; theta: 0.83; asym: 5.11; tree : (-5 OR -6)
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 4.39; expr: 1.00; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.13; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.84; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g13 7303.522534871354 =======
# >> G_0: init: 1.00; noise: 0.97; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 0.93; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.42; noise: 1.01; b: 1.50; m: 4.90; expr: 1.00; deg: 0.13; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 0.76; noise: 4.69; b: 4.40; m: 6.47; expr: 2.45; deg: 0.56; theta: 9.08; asym: 5.96; tree : 5
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.13; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g14 7231.078820284783 =======
# >> G_0: init: 1.00; noise: 0.97; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 0.93; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.42; noise: 1.01; b: 1.50; m: 4.90; expr: 1.00; deg: 0.13; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 0.89; noise: 4.69; b: 4.40; m: 6.47; expr: 2.45; deg: 0.56; theta: 9.08; asym: 5.96; tree : -3
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g15 7779.32024661513 =======
# >> G_0: init: 1.00; noise: 0.97; b: 3.67; m: 6.34; expr: 0.89; deg: 0.10; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 0.98; b: 0.94; m: 3.09; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.42; noise: 1.01; b: 1.50; m: 4.90; expr: 1.00; deg: 0.13; theta: 0.24; asym: 4.37; tree : (2 OR 4)
# >> G_3: init: 0.76; noise: 4.69; b: 4.40; m: 6.47; expr: 2.45; deg: 0.56; theta: 9.08; asym: 5.96; tree : -6
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.18; noise: 5.22; b: 1.18; m: 8.12; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g16 7549.466873174292 =======
# >> G_0: init: 1.00; noise: 0.97; b: 3.72; m: 6.34; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 0.93; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.31; noise: 1.01; b: 1.50; m: 4.90; expr: 1.00; deg: 0.13; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 0.89; noise: 4.69; b: 4.40; m: 6.22; expr: 2.45; deg: 0.56; theta: 9.08; asym: 5.96; tree : -3
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 5.22; b: 1.18; m: 6.78; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.17; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g17 7691.965435914839 =======
# >> G_0: init: 1.00; noise: 0.97; b: 3.72; m: 6.34; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 0.92; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR 2)
# >> G_2: init: 1.31; noise: 1.01; b: 1.50; m: 4.90; expr: 1.00; deg: 0.13; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 0.85; noise: 4.69; b: 4.40; m: 6.47; expr: 2.45; deg: 0.56; theta: 9.08; asym: 5.96; tree : -3
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : ((-1 OR -3) AND -7)
# >> G_5: init: 0.16; noise: 5.52; b: 1.18; m: 6.78; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.46; tree : 2
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : ((-2 OR 5) OR -1)
#
# ======= GENERATION generation_g18 7923.402314692826 =======
# >> G_0: init: 1.00; noise: 0.97; b: 4.09; m: 6.34; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 0.92; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.31; noise: 1.01; b: 1.50; m: 4.90; expr: 1.00; deg: 0.13; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 0.91; noise: 4.69; b: 4.40; m: 6.47; expr: 2.45; deg: 0.56; theta: 8.34; asym: 5.96; tree : -3
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 4.99; b: 1.18; m: 6.78; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.46; tree : (2 OR 4)
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.60; asym: 5.00; tree : (-2 OR -1)
#
# ======= GENERATION generation_g19 7838.266619799114 =======
# >> G_0: init: 1.00; noise: 0.97; b: 4.09; m: 6.34; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 0.97; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 0))
# >> G_2: init: 1.31; noise: 1.01; b: 1.50; m: 4.90; expr: 1.00; deg: 0.13; theta: 0.22; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 1.66; noise: 5.21; b: 9.23; m: 9.21; expr: 1.92; deg: 2.01; theta: 5.58; asym: 3.54; tree : (3 OR -7)
# >> G_4: init: 1.84; noise: 0.94; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 4.99; b: 1.18; m: 6.78; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.46; tree : (2 OR 4)
# >> G_6: init: 0.32; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.60; asym: 5.00; tree : -2
#
# ======= GENERATION generation_g20 7370.787382032703 =======
# >> G_0: init: 1.00; noise: 0.97; b: 4.09; m: 6.43; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 0.92; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.31; noise: 1.01; b: 1.53; m: 4.90; expr: 0.93; deg: 0.12; theta: 0.24; asym: 4.37; tree : (-6 AND 4)
# >> G_3: init: 0.91; noise: 4.69; b: 4.40; m: 6.47; expr: 3.25; deg: 0.56; theta: 8.34; asym: 5.96; tree : -3
# >> G_4: init: 1.84; noise: 1.00; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 4.99; b: 1.18; m: 6.78; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.46; tree : (2 OR 4)
# >> G_6: init: 0.37; noise: 1.02; b: 1.64; m: 9.42; expr: 1.00; deg: 0.10; theta: 1.60; asym: 5.00; tree : (-2 OR -1)
#
# ======= GENERATION generation_g21 7151.248107344742 =======
# >> G_0: init: 1.00; noise: 0.97; b: 4.09; m: 6.43; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : -6
# >> G_1: init: 0.43; noise: 0.76; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.31; noise: 1.01; b: 1.61; m: 4.90; expr: 1.08; deg: 0.14; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 0.91; noise: 4.69; b: 4.40; m: 6.75; expr: 2.45; deg: 0.56; theta: 8.34; asym: 5.96; tree : -3
# >> G_4: init: 1.84; noise: 1.09; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 4.99; b: 1.18; m: 8.01; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.46; tree : (2 OR 4)
# >> G_6: init: 0.32; noise: 1.16; b: 1.64; m: 9.42; expr: 0.88; deg: 0.10; theta: 1.60; asym: 5.00; tree : (-2 OR -1)
#
# ======= GENERATION generation_g22 7654.623745259735 =======
# >> G_0: init: 1.00; noise: 0.97; b: 4.09; m: 6.43; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : (-6 AND 5)
# >> G_1: init: 0.43; noise: 0.76; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (-1 OR (7 AND 2))
# >> G_2: init: 1.31; noise: 1.01; b: 1.61; m: 4.90; expr: 1.08; deg: 0.16; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 0.91; noise: 3.85; b: 4.40; m: 6.75; expr: 2.45; deg: 0.57; theta: 8.34; asym: 5.96; tree : -3
# >> G_4: init: 1.84; noise: 1.09; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 4.99; b: 1.18; m: 8.01; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.46; tree : (2 OR 4)
# >> G_6: init: 0.32; noise: 1.16; b: 1.64; m: 9.42; expr: 0.88; deg: 0.10; theta: 1.60; asym: 5.00; tree : (-2 OR -1)
#
# ======= GENERATION generation_g23 7420.988791764725 =======
# >> G_0: init: 1.00; noise: 0.97; b: 4.09; m: 6.43; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : (-6 AND (5 OR 1))
# >> G_1: init: 0.41; noise: 0.76; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (7 AND 2)
# >> G_2: init: 1.31; noise: 1.01; b: 1.61; m: 4.90; expr: 1.08; deg: 0.14; theta: 0.25; asym: 4.37; tree : (-6 AND 4)
# >> G_3: init: 0.91; noise: 3.85; b: 4.40; m: 6.75; expr: 2.45; deg: 0.56; theta: 8.34; asym: 4.80; tree : -3
# >> G_4: init: 1.84; noise: 1.09; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 4.99; b: 1.18; m: 8.01; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.46; tree : 4
# >> G_6: init: 0.32; noise: 1.16; b: 1.64; m: 9.42; expr: 0.88; deg: 0.10; theta: 1.60; asym: 5.00; tree : (-2 OR -1)
#
# ======= GENERATION generation_g24 7392.884833238026 =======
# >> G_0: init: 1.00; noise: 0.97; b: 4.09; m: 6.43; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : (-6 AND (5 OR 1))
# >> G_1: init: 0.41; noise: 0.76; b: 0.94; m: 3.14; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : (7 AND (2 OR -3))
# >> G_2: init: 1.31; noise: 1.01; b: 1.61; m: 4.65; expr: 1.17; deg: 0.14; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 0.91; noise: 3.85; b: 4.40; m: 6.75; expr: 2.84; deg: 0.56; theta: 8.34; asym: 5.96; tree : -3
# >> G_4: init: 1.84; noise: 1.09; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 4.99; b: 1.07; m: 8.01; expr: 0.34; deg: 0.11; theta: 3.99; asym: 9.46; tree : 4
# >> G_6: init: 0.32; noise: 1.16; b: 1.64; m: 9.42; expr: 0.88; deg: 0.10; theta: 1.60; asym: 5.00; tree : (-2 OR -1)
#
# ======= GENERATION generation_g25 7444.972013845614 =======
# >> G_0: init: 1.00; noise: 0.97; b: 4.09; m: 6.43; expr: 0.89; deg: 0.11; theta: 6.68; asym: 6.04; tree : (-6 AND (5 OR 1))
# >> G_1: init: 0.41; noise: 0.76; b: 0.94; m: 3.47; expr: 1.00; deg: 0.10; theta: 7.53; asym: 5.00; tree : (7 AND (2 OR -3))
# >> G_2: init: 1.31; noise: 1.01; b: 1.61; m: 4.65; expr: 1.08; deg: 0.14; theta: 0.24; asym: 4.37; tree : (2 OR (-6 AND 4))
# >> G_3: init: 0.85; noise: 3.85; b: 4.40; m: 6.75; expr: 2.45; deg: 0.56; theta: 9.17; asym: 5.96; tree : -3
# >> G_4: init: 2.03; noise: 1.09; b: 0.24; m: 3.59; expr: 1.11; deg: 0.10; theta: 1.09; asym: 6.89; tree : (-1 AND -7)
# >> G_5: init: 0.16; noise: 4.99; b: 1.07; m: 8.01; expr: 0.34; deg: 0.12; theta: 4.30; asym: 9.46; tree : 4
# >> G_6: init: 0.32; noise: 1.16; b: 1.64; m: 9.42; expr: 0.88; deg: 0.09; theta: 1.60; asym: 5.00; tree : (-2 OR -1)
