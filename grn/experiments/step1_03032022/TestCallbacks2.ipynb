# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + s_all + s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=59, silent=True, opti=True,
              run_tissue=False, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = [p**prun.exponent for p in pop_fit]
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="3", start_time=56, end_time=59, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="4", start_time=59, end_time=62, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="5", start_time=62, end_time=65, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="6", start_time=65, end_time=68, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="7", start_time=68, end_time=71, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="8", start_time=71, end_time=74, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="9", start_time=74, end_time=77, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="10", start_time=77, end_time=80, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="11", start_time=80, end_time=83, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="12", start_time=83, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 10
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 20
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, name=None):
    args = get_prun()
    args.cb_init = cb_init
    args.name = name
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    return np.mean(scores), np.std(scores), max(p1)

# %%
model = sm.StringModel("expcb_n{name}_i{i}")
gen = dict(
    ctrl=dict(),
    init1=dict(init=lambda: 0.1),
    init2=dict(init=lambda: 1),
    noise=dict(init=lambda: 1),
    b=dict(init=lambda: 1),
    m=dict(init=lambda: 2),
    expr=dict(init=lambda: 1),
    deg=dict(init=lambda: 0.1),
    theta=dict(init=lambda: 5),
    asym=dict(init=lambda: 10),
)

# %%
# main loop
exporter = Exporter(name="exp_callbacks2_190222")
for (subname, cb_init), i in product(gen.items(), range(5)):
    name = model.fill(name=subname, i=i)
    print(name, subname)
    if name in exporter.list():
        continue
    res = get_score_parametrized(cb_init)
    exporter(res, name)
# Out:
# Exporting at output/exp_callbacks2_190222
# expcb_nctrl_i0 ctrl
# Step 0
# ++ Best 0.07254369787810518 for generation 0
# ++ Best 0.11319817021762149 for generation 1
# Step 4 passed !
# ++ Best 0.37576652325048815 for generation 3
# ++ Best 0.41916787025502833 for generation 47
# Step 5 passed !
# Step 6 passed !
# ++ Best 0.9129830898315306 for generation 56
# Step 7 passed !
# Step 8 passed !
# ++ Best 1.3711628764769799 for generation 86
# OVER
# expcb_nctrl_i1 ctrl
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.3784078435578333 for generation 1
# ++ Best 0.3826691001630216 for generation 20
# ++ Best 0.39832241096200993 for generation 36
# ++ Best 0.442024951789781 for generation 43
# OVER
# expcb_nctrl_i2 ctrl
# Step 0
# ++ Best 0.001681074319610437 for generation 0
# ++ Best 0.06952056900518318 for generation 1
# ++ Best 0.16742780497665538 for generation 3
# ++ Best 0.17517167866934416 for generation 15
# ++ Best 0.17848241200375312 for generation 21
# ++ Best 0.17964174255780374 for generation 49
# Step 9 passed !
# ++ Best 2.2575916084518086 for generation 71
# ++ Best 2.3980692280353333 for generation 72
# Step 10 passed !
# Step 11 passed !
# Step 12 passed !
# ++ Best 3.439535583876922 for generation 93
# OVER
# expcb_nctrl_i3 ctrl
# Step 0
# ++ Best 0.0029526444719818125 for generation 0
# ++ Best 0.06019604299075317 for generation 1
# ++ Best 0.13870659919998746 for generation 2
# ++ Best 0.1568374785467424 for generation 4
# ++ Best 0.41203950832585834 for generation 34
# ++ Best 0.4205773468971583 for generation 46
# ++ Best 0.4329966499426172 for generation 50
# ++ Best 0.4451131485188773 for generation 57
# ++ Best 0.4514209733777211 for generation 67
# ++ Best 0.4630436559060247 for generation 69
# ++ Best 0.4643322021406867 for generation 86
# ++ Best 0.4667091476609252 for generation 97
# OVER
# expcb_nctrl_i4 ctrl
# Step 0
# ++ Best 0.06927265983171088 for generation 0
# ++ Best 0.19021417001562319 for generation 4
# ++ Best 0.38043088949547227 for generation 28
# ++ Best 0.4228370010150978 for generation 46
# ++ Best 0.4344255021285424 for generation 54
# OVER
# expcb_ninit1_i0 init1
# Step 0
# ++ Best 0.13354480167215868 for generation 0
# ++ Best 0.15746142097861485 for generation 3
# ++ Best 0.15807652344987647 for generation 50
# OVER
# expcb_ninit1_i1 init1
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.0677586008357199 for generation 1
# ++ Best 0.07941061427096066 for generation 7
# ++ Best 0.14293364796199784 for generation 9
# OVER
# expcb_ninit1_i2 init1
# Step 0
# ++ Best 0.13354480167215868 for generation 0
# ++ Best 0.13881377228276967 for generation 8
# ++ Best 0.14400588489085983 for generation 23
# ++ Best 0.16137271859063154 for generation 75
# OVER
# expcb_ninit1_i3 init1
# Step 0
# ++ Best 0.13354480167215868 for generation 0
# ++ Best 0.14657485365809222 for generation 1
# OVER
# expcb_ninit1_i4 init1
# Step 0
# ++ Best 0.05984478294083211 for generation 0
# ++ Best 0.13354480167215868 for generation 1
# ++ Best 0.13881377228276967 for generation 4
# ++ Best 0.14400588489085983 for generation 56
# ++ Best 0.2580301768030029 for generation 81
# OVER
# expcb_ninit2_i0 init2
# Step 0
# ++ Best 0.06528991710475524 for generation 0
# ++ Best 0.15281279496020547 for generation 1
# ++ Best 0.17253462843630085 for generation 4
# ++ Best 0.1795847601489087 for generation 14
# ++ Best 0.19974256923823902 for generation 64
# ++ Best 0.4788438115497359 for generation 75
# ++ Best 0.6328066724263547 for generation 96
# OVER
# expcb_ninit2_i1 init2
# Step 0
# ++ Best 0.14905534864615944 for generation 0
# ++ Best 0.15302558658183293 for generation 2
# ++ Best 0.1538895757726292 for generation 17
# ++ Best 0.19168730466054118 for generation 25
# OVER
# expcb_ninit2_i2 init2
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.1795748657865899 for generation 1
# ++ Best 0.3694800057902764 for generation 6
# ++ Best 0.38748638141335273 for generation 23
# ++ Best 0.3915519832700897 for generation 24
# ++ Best 0.40849888552662417 for generation 37
# ++ Best 0.42374187527163065 for generation 43
# ++ Best 0.4355353866754581 for generation 78
# OVER
# expcb_ninit2_i3 init2
# Step 0
# ++ Best 0.031052364527607738 for generation 0
# ++ Best 0.05917437956257355 for generation 1
# ++ Best 0.10103708431280778 for generation 3
# ++ Best 0.1678102244493162 for generation 7
# ++ Best 0.4033293441573521 for generation 21
# ++ Best 0.4991560150158557 for generation 41
# ++ Best 0.5610325570007351 for generation 61
# ++ Best 1.7658080272077274 for generation 76
# OVER
# expcb_ninit2_i4 init2
# Step 0
# ++ Best 0.1380529177204781 for generation 0
# ++ Best 0.7677509768428398 for generation 7
# ++ Best 0.9060840440206379 for generation 20
# ++ Best 0.9363495549923341 for generation 39
# ++ Best 0.9439304418084538 for generation 43
# ++ Best 2.540780186154644 for generation 45
# OVER
# expcb_nnoise_i0 noise
# Step 0
# ++ Best 0.017023522396612683 for generation 0
# ++ Best 0.14879582043215706 for generation 1
# ++ Best 0.15792295964044753 for generation 2
# ++ Best 0.16695654870626836 for generation 7
# ++ Best 0.3192889499496171 for generation 26
# ++ Best 0.33938764439401253 for generation 41
# ++ Best 0.34200937719330476 for generation 44
# ++ Best 0.3541249650588473 for generation 52
# ++ Best 0.3924535497898311 for generation 63
# OVER
# expcb_nnoise_i1 noise
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.08315586401533542 for generation 1
# ++ Best 0.1729151364714722 for generation 2
# ++ Best 0.3954318155926255 for generation 11
# ++ Best 0.39694046226248975 for generation 52
# ++ Best 0.40871763122060256 for generation 73
# ++ Best 0.6720221774976751 for generation 93
# OVER
# expcb_nnoise_i2 noise
# Step 0
# ++ Best 0.0036155363843119476 for generation 0
# ++ Best 0.05964004400683451 for generation 1
# ++ Best 0.09173436111731384 for generation 2
# ++ Best 0.13354480167215868 for generation 4
# ++ Best 0.15752733798013085 for generation 6
# ++ Best 0.16552705371322768 for generation 10
# ++ Best 0.16998798257633396 for generation 16
# ++ Best 0.17081633233966356 for generation 39
# ++ Best 0.1748998630521925 for generation 56
# OVER
# expcb_nnoise_i3 noise
# Step 0
# ++ Best 0.14077554528345101 for generation 0
# ++ Best 0.17722121584793105 for generation 3
# ++ Best 0.1951043659649497 for generation 35
# ++ Best 0.34436645778455577 for generation 73
# ++ Best 0.3568439614268838 for generation 82
# OVER
# expcb_nnoise_i4 noise
# Step 0
# ++ Best 0.0029526444719818125 for generation 0
# ++ Best 0.06034185656960547 for generation 2
# ++ Best 0.07173277409529626 for generation 3
# ++ Best 0.1422997531824579 for generation 8
# ++ Best 0.1509479741892013 for generation 22
# ++ Best 0.16472505756464517 for generation 35
# ++ Best 0.1756902916892739 for generation 53
# ++ Best 0.1946516335938328 for generation 89
# OVER
# expcb_nb_i0 b
# Step 0
# ++ Best 0.3667902123406023 for generation 0
# ++ Best 0.3735354909820692 for generation 35
# ++ Best 0.38232200968053054 for generation 41
# ++ Best 0.3857485520539837 for generation 49
# ++ Best 0.39982558308743543 for generation 52
# ++ Best 0.41561643779263174 for generation 54
# ++ Best 0.6248293564047667 for generation 88
# OVER
# expcb_nb_i1 b
# Step 0
# ++ Best 0.060719870409037764 for generation 0
# ++ Best 0.0649482268933159 for generation 2
# ++ Best 0.1538895757726292 for generation 3
# ++ Best 1.3208237113632881 for generation 13
# ++ Best 1.724719897859354 for generation 27
# OVER
# expcb_nb_i2 b
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.0724858495114816 for generation 1
# ++ Best 0.15113740859028668 for generation 10
# OVER
# expcb_nb_i3 b
# Step 0
# ++ Best 0.1435685956592311 for generation 0
# ++ Best 0.1910466285035355 for generation 2
# ++ Best 0.38064633165615297 for generation 3
# ++ Best 0.4190647495041247 for generation 48
# ++ Best 0.4284406301574212 for generation 77
# ++ Best 0.6348952748802013 for generation 86
# OVER
# expcb_nb_i4 b
# Step 0
# ++ Best 0.06729550352822007 for generation 0
# ++ Best 0.14213488408941274 for generation 4
# ++ Best 0.15001538680400153 for generation 5
# ++ Best 0.1861116979833184 for generation 17
# ++ Best 0.19391944099408806 for generation 25
# ++ Best 0.2949967942664907 for generation 38
# ++ Best 0.336413561125451 for generation 41
# ++ Best 0.3508345975406866 for generation 68
# ++ Best 1.079111400871524 for generation 75
# OVER
# expcb_nm_i0 m
# Step 0
# ++ Best 0.0670249407067825 for generation 0
# ++ Best 0.0701535664226255 for generation 3
# ++ Best 0.0707628696018622 for generation 10
# ++ Best 0.34576512244384117 for generation 14
# ++ Best 0.43131069498293517 for generation 29
# ++ Best 0.4418952002210004 for generation 72
# OVER
# expcb_nm_i1 m
# Step 0
# ++ Best 0.1713320907651461 for generation 0
# ++ Best 0.3099416164464649 for generation 1
# ++ Best 0.33824197690441293 for generation 43
# ++ Best 0.3717647895128559 for generation 86
# ++ Best 0.8576830734241393 for generation 87
# ++ Best 1.6031147698467998 for generation 96
# OVER
# expcb_nm_i2 m
# Step 0
# ++ Best 0.01899494270359262 for generation 0
# ++ Best 0.06003023993628228 for generation 2
# ++ Best 0.06998241029131849 for generation 4
# ++ Best 0.14400588489085983 for generation 6
# ++ Best 0.6873922263042065 for generation 8
# ++ Best 1.3398784920258928 for generation 24
# ++ Best 2.7706729092797597 for generation 37
# ++ Best 3.0431268637540594 for generation 40
# ++ Best 3.491370730328435 for generation 41
# ++ Best 3.974172767427629 for generation 43
# OVER
# expcb_nm_i3 m
# Step 0
# ++ Best 0.13043263396757954 for generation 0
# ++ Best 0.15698311618881475 for generation 7
# ++ Best 0.3315397678057086 for generation 8
# ++ Best 0.3643691414565158 for generation 27
# ++ Best 0.37933177062893436 for generation 41
# ++ Best 0.7195054286131655 for generation 72
# ++ Best 0.7930871985395218 for generation 99
# OVER
# expcb_nm_i4 m
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.06065658598001987 for generation 1
# ++ Best 0.07248978218937474 for generation 5
# ++ Best 0.09766963811975447 for generation 13
# ++ Best 0.13598971533295062 for generation 18
# ++ Best 0.13881377228276967 for generation 42
# ++ Best 0.14400588489085983 for generation 66
# ++ Best 0.14742745683713557 for generation 72
# ++ Best 0.42236905211223297 for generation 77
# ++ Best 0.6266207074452845 for generation 81
# OVER
# expcb_nexpr_i0 expr
# Step 0
# ++ Best 0.06042986613673491 for generation 0
# ++ Best 0.17735433989458305 for generation 1
# ++ Best 0.18649710504630848 for generation 31
# ++ Best 0.1933854001555807 for generation 35
# ++ Best 0.43299348778348334 for generation 57
# ++ Best 0.5798061047828643 for generation 99
# OVER
# expcb_nexpr_i1 expr
# Step 0
# ++ Best 0.1380529177204781 for generation 0
# ++ Best 0.14914653033721573 for generation 5
# ++ Best 0.1605631807804227 for generation 8
# ++ Best 0.19343831422540114 for generation 9
# ++ Best 0.32771471003269503 for generation 89
# OVER
# expcb_nexpr_i2 expr
# Step 0
# ++ Best 0.14861677178619148 for generation 0
# ++ Best 1.5964979675418296 for generation 1
# ++ Best 2.8037380434546986 for generation 25
# ++ Best 2.971256398233599 for generation 32
# ++ Best 3.4192342404380276 for generation 48
# ++ Best 3.553453257139217 for generation 91
# OVER
# expcb_nexpr_i3 expr
# Step 0
# ++ Best 0.16841696973245612 for generation 0
# ++ Best 0.1739737971520973 for generation 55
# ++ Best 0.17429309893415693 for generation 56
# OVER
# expcb_nexpr_i4 expr
# Step 0
# ++ Best 0.0029526444719818125 for generation 0
# ++ Best 0.060936929459973435 for generation 1
# ++ Best 0.15079249389782587 for generation 3
# ++ Best 0.17539820862514063 for generation 14
# ++ Best 0.42056884830897856 for generation 20
# ++ Best 0.5715549727848432 for generation 43
# OVER
# expcb_ndeg_i0 deg
# Step 0
# ++ Best 0.06964085603003849 for generation 0
# ++ Best 0.1375119733396235 for generation 1
# ++ Best 0.14202261895532303 for generation 9
# ++ Best 0.14585372459373924 for generation 33
# ++ Best 0.14952154013003674 for generation 47
# ++ Best 0.14953107423659173 for generation 91
# OVER
# expcb_ndeg_i1 deg
# Step 0
# ++ Best 0.00344759724350436 for generation 0
# ++ Best 0.021991244875029174 for generation 1
# ++ Best 0.05917437956257355 for generation 2
# ++ Best 0.09834833454654203 for generation 3
# ++ Best 0.1483083632777069 for generation 8
# ++ Best 0.1514592244660782 for generation 10
# ++ Best 0.1522183783983136 for generation 26
# ++ Best 0.15305768407078257 for generation 38
# ++ Best 0.1594253097306562 for generation 46
# ++ Best 0.1619684209261487 for generation 67
# OVER
# expcb_ndeg_i2 deg
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.14975220663251543 for generation 2
# ++ Best 0.15641853233299288 for generation 23
# OVER
# expcb_ndeg_i3 deg
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.13354480167215868 for generation 1
# ++ Best 0.1643295893403089 for generation 8
# OVER
# expcb_ndeg_i4 deg
# Step 0
# ++ Best 0.0866477924516346 for generation 0
# ++ Best 0.13354480167215868 for generation 3
# ++ Best 0.14172333400594106 for generation 8
# ++ Best 0.14182616087898553 for generation 11
# ++ Best 0.15771339010367744 for generation 29
# OVER
# expcb_ntheta_i0 theta
# Step 0
# ++ Best 0.15315830790365312 for generation 0
# ++ Best 0.16364101677374823 for generation 19
# ++ Best 0.16948918043668737 for generation 42
# ++ Best 0.9463710948193448 for generation 73
# OVER
# expcb_ntheta_i1 theta
# Step 0
# ++ Best 0.024824047064186838 for generation 0
# ++ Best 0.06609951955933384 for generation 1
# ++ Best 0.348640698174168 for generation 13
# ++ Best 0.4236917981094871 for generation 22
# ++ Best 0.42926956675898664 for generation 27
# ++ Best 0.4364015649537748 for generation 72
# OVER
# expcb_ntheta_i2 theta
# Step 0
# ++ Best 0.060544927236959034 for generation 0
# ++ Best 0.16948918043668737 for generation 7
# ++ Best 0.16961419389226934 for generation 13
# ++ Best 0.17855849556112977 for generation 20
# ++ Best 0.3802175323210817 for generation 30
# ++ Best 0.44541194050884914 for generation 49
# ++ Best 0.446824546278088 for generation 71
# ++ Best 0.4495377464851372 for generation 73
# ++ Best 0.4551551734048274 for generation 87
# OVER
# expcb_ntheta_i3 theta
# Step 0
# ++ Best 0.0028685357989670477 for generation 0
# ++ Best 0.07273155322579283 for generation 1
# ++ Best 0.10148238457856239 for generation 9
# ++ Best 0.15129366437014455 for generation 31
# ++ Best 0.16320614791042817 for generation 36
# ++ Best 0.16929205679720102 for generation 63
# ++ Best 0.23246898627485357 for generation 81
# ++ Best 0.26937898727987286 for generation 85
# OVER
# expcb_ntheta_i4 theta
# Step 0
# ++ Best 0.0601424324335304 for generation 0
# ++ Best 0.13354480167215868 for generation 1
# ++ Best 0.17632329675319405 for generation 57
# ++ Best 0.3087170935411569 for generation 99
# OVER
# expcb_nasym_i0 asym
# Step 0
# ++ Best 0.011641518497555249 for generation 0
# ++ Best 0.05917437956257355 for generation 1
# ++ Best 0.0866477924516346 for generation 4
# ++ Best 0.5817164353255992 for generation 10
# ++ Best 0.6184734390116011 for generation 52
# ++ Best 0.6206914345276537 for generation 75
# ++ Best 0.7078660435827797 for generation 78
# OVER
# expcb_nasym_i1 asym
# Step 0
# ++ Best 0.13354480167215868 for generation 0
# ++ Best 0.14969360943965895 for generation 6
# ++ Best 0.3992037302141902 for generation 8
# ++ Best 0.41879864574431414 for generation 20
# ++ Best 0.44805541696260176 for generation 22
# ++ Best 0.4495442136531653 for generation 24
# ++ Best 0.4551551734048274 for generation 44
# ++ Best 0.4596794480297759 for generation 65
# OVER
# expcb_nasym_i2 asym
# Step 0
# ++ Best 0.05941642977648206 for generation 0
# ++ Best 0.0866477924516346 for generation 5
# ++ Best 0.09225371145495082 for generation 17
# ++ Best 0.4179994229213236 for generation 21
# ++ Best 0.4383218147948942 for generation 29
# ++ Best 0.44600057367492935 for generation 30
# ++ Best 0.5814860832688415 for generation 41
# OVER
# expcb_nasym_i3 asym
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.06521261687006928 for generation 1
# ++ Best 0.07412874570410712 for generation 2
# ++ Best 0.12904211080090114 for generation 5
# ++ Best 0.13396425141728185 for generation 23
# ++ Best 0.1815438013474223 for generation 33
# OVER
# expcb_nasym_i4 asym
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.13354480167215868 for generation 1
# ++ Best 0.4355116019550499 for generation 10
# ++ Best 0.44805541696260176 for generation 41
# ++ Best 0.4551551734048274 for generation 58
# ++ Best 0.4596794480297759 for generation 94
# OVER

# %%
show_curve(sol.stats, REF.stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-30abeee9d69e> in <module>
# ----> 1 show_curve(sol.stats, REF.stats)
#
# NameError: name 'sol' is not defined

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.groupby("name").mean()
# Out:
#            mean        sd       max
# name
# asym   0.383501  0.069597  0.478051
# b      0.698360  0.436650  0.842939
# ctrl   0.600419  0.397447  1.230772
# deg    0.137063  0.018645  0.157992
# expr   0.521177  0.233074  1.041364
# init1  0.156509  0.027497  0.173398
# init2  0.537489  0.256147  1.113324
# m      0.577244  0.424020  1.487778
# noise  0.210384  0.047073  0.358174
# theta  0.270858  0.093605  0.483205

# %%
df.head()
# Out:
#     name  i      mean        sd       max
# 0      m  3  0.223446  0.217769  0.793087
# 1   expr  4  0.219895  0.090702  0.571555
# 2   ctrl  3  0.423949  0.014848  0.466709
# 3  theta  3  0.097096  0.065733  0.269379
# 4  init1  0  0.142843  0.020413  0.158077
