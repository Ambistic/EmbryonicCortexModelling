# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-b39985b10f04> in <module>
#      19
#      20 from lib.ga.utils import weighted_selection_one, normalize_fitness_values
# ---> 21 from lib.utils import pick_best, pick_last
#      22 from jf.utils.export import Exporter
#      23 from jf.autocompute.jf import O, L
#
# ImportError: cannot import name 'pick_best' from 'lib.utils' (/home/nathan/other/EmbryonicCortexModelling/grn/lib/utils.py)

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + s_all + s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=False, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = [p**prun.exponent for p in pop_fit]
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "checkperf_2102_v3"
res = main(prun)
# Out:
# Exporting at output/checkperf_2102_v3
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 0.006972536347630633 for generation 0
# [out] ++ Best 0.0070337870791821674 for generation 6
# [out] ++ Best 0.007154561682657078 for generation 7
# [out] ++ Best 0.008972322205174922 for generation 10
# [out] ++ Best 0.010693953777098085 for generation 18
# [out] ++ Best 0.01721258812475845 for generation 25
# Saving ...
# [out] ++ Best 0.017751292734635247 for generation 57
# Saving ...
# [out] Step 100
# Saving ...
# Saving ...
# [out] Step 200
# Saving ...
# Saving ...
# [out] Step 300
# Saving ...
# Saving ...
# [out] Step 400
# [out] ++ Best 0.022301287537438663 for generation 421
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# Saving ...
# [out] ++ Best 0.030605896091536435 for generation 775
# Saving ...
# [out] Step 800
# Saving ...
# [out] ++ Best 0.031498600695823116 for generation 859
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# [out] ++ Best 0.03901170579913203 for generation 1263
# [out] ++ Best 0.039116963222068445 for generation 1266
# [out] ++ Best 0.040834362616171085 for generation 1285
# Saving ...
# [out] Step 1300
# Saving ...
# [out] ++ Best 0.04794367051729755 for generation 1350
# Saving ...
# [out] Step 1400
# [out] ++ Best 0.05766131450691711 for generation 1427
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# [out] ++ Best 0.05858268101111778 for generation 1599
# Saving ...
# [out] Step 1600
# Saving ...
# [out] ++ Best 0.063914727349944 for generation 1682
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# Saving ...
# [out] Step 2100
# [out] ++ Best 0.06786759620780163 for generation 2143
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# [out] ++ Best 0.07240864548087755 for generation 2264
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
show_curve(res.stats, REF.stats)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-72094eb1a538> in <module>
# ----> 1 show_curve(res.stats, REF.stats)
#
# AttributeError: 'numpy.float64' object has no attribute 'stats'

# %%
print(1)

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/checkperf_2102_v3

# %%
sm = read_model("generation")

# %%
def pick_last(exp, sm=None):
    if sm is None:
        sm = read_model("generation")
    return sm.pick_last(sorted(exp.list()), slot="generation")

def pick_best(res):
    return res[res.index(max(res, key=lambda x: x.fit))]

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.03; noise: 4.01; b: 2.40; m: 6.00; expr: 1.00; deg: 0.00; theta: 4.64; asym: 7.25; tree : NOT (5 OR 3)
# >> G_1: init: 0.24; noise: 7.30; b: 2.61; m: 5.71; expr: 1.00; deg: 0.00; theta: 8.25; asym: 3.23; tree : 0
# >> G_2: init: 1.03; noise: 8.97; b: 1.41; m: 6.40; expr: 1.00; deg: 0.00; theta: 2.09; asym: 0.99; tree : (2 AND (3 AND 5))
# >> G_3: init: 2.29; noise: 2.99; b: 1.86; m: 7.94; expr: 1.00; deg: 0.00; theta: 6.38; asym: 7.29; tree : NOT 2
# >> G_4: init: 1.23; noise: 3.30; b: 1.42; m: 3.92; expr: 1.00; deg: 0.00; theta: 2.84; asym: 8.93; tree : 4
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.78; noise: 9.37; b: 1.34; m: 7.00; expr: 1.00; deg: 0.00; theta: 3.57; asym: 2.68; tree : (5 AND 2)
# >> G_1: init: 0.91; noise: 1.81; b: 1.25; m: 6.63; expr: 1.00; deg: 0.00; theta: 1.67; asym: 5.35; tree : 5
# >> G_2: init: 2.22; noise: 3.89; b: 1.47; m: 6.22; expr: 1.00; deg: 0.00; theta: 5.30; asym: 2.86; tree : (4 AND (3 AND 0))
# >> G_3: init: 0.62; noise: 1.89; b: 1.38; m: 9.69; expr: 1.00; deg: 0.00; theta: 7.81; asym: 1.18; tree : 0
# >> G_4: init: 0.36; noise: 2.75; b: 1.12; m: 8.09; expr: 1.00; deg: 0.00; theta: 4.69; asym: 5.75; tree : NOT NOT 0
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.78; noise: 9.37; b: 1.34; m: 7.00; expr: 1.00; deg: 0.00; theta: 3.61; asym: 2.68; tree : 4
# >> G_1: init: 0.91; noise: 1.81; b: 1.25; m: 6.63; expr: 1.00; deg: 0.00; theta: 1.67; asym: 4.66; tree : 5
# >> G_2: init: 2.22; noise: 3.89; b: 1.47; m: 6.22; expr: 1.00; deg: 0.00; theta: 4.69; asym: 2.86; tree : (4 AND (3 AND 0))
# >> G_3: init: 0.62; noise: 1.89; b: 1.38; m: 9.69; expr: 1.00; deg: 0.00; theta: 7.81; asym: 1.18; tree : 0
# >> G_4: init: 0.36; noise: 2.75; b: 1.12; m: 8.09; expr: 1.00; deg: 0.00; theta: 4.69; asym: 4.63; tree : NOT NOT 0
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.78; noise: 9.37; b: 1.34; m: 7.00; expr: 1.00; deg: 0.00; theta: 3.61; asym: 2.68; tree : 4
# >> G_1: init: 0.91; noise: 1.81; b: 1.25; m: 6.63; expr: 1.00; deg: 0.00; theta: 1.99; asym: 5.35; tree : 5
# >> G_2: init: 2.22; noise: 3.89; b: 1.47; m: 6.22; expr: 1.00; deg: 0.00; theta: 4.67; asym: 2.86; tree : (4 AND (3 AND 0))
# >> G_3: init: 0.62; noise: 1.89; b: 1.38; m: 9.69; expr: 1.00; deg: 0.00; theta: 8.43; asym: 1.18; tree : (0 AND 2)
# >> G_4: init: 0.36; noise: 2.75; b: 1.12; m: 8.09; expr: 1.00; deg: 0.00; theta: 4.36; asym: 4.63; tree : NOT NOT 0
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 0.74; noise: 6.38; b: 2.53; m: 2.98; expr: 1.00; deg: 0.00; theta: 8.46; asym: 7.31; tree : (1 OR (3 AND 0))
# >> G_1: init: 1.99; noise: 7.77; b: 3.92; m: 6.40; expr: 1.00; deg: 0.00; theta: 2.82; asym: 4.53; tree : 2
# >> G_2: init: 1.06; noise: 2.70; b: 0.42; m: 6.80; expr: 1.00; deg: 0.00; theta: 5.68; asym: 5.86; tree : 1
# >> G_3: init: 0.60; noise: 9.95; b: 0.71; m: 6.97; expr: 1.00; deg: 0.00; theta: 3.43; asym: 3.35; tree : (0 AND 1)
# >> G_4: init: 1.56; noise: 7.71; b: 1.20; m: 2.74; expr: 1.00; deg: 0.00; theta: 3.40; asym: 5.06; tree : 3
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.78; noise: 9.37; b: 1.34; m: 7.00; expr: 1.00; deg: 0.00; theta: 4.75; asym: 2.68; tree : (5 AND 2)
# >> G_1: init: 0.91; noise: 1.81; b: 1.25; m: 6.63; expr: 1.00; deg: 0.00; theta: 1.67; asym: 5.35; tree : 3
# >> G_2: init: 2.22; noise: 3.89; b: 1.47; m: 6.22; expr: 1.00; deg: 0.00; theta: 3.16; asym: 2.86; tree : (4 AND (3 AND 5))
# >> G_3: init: 0.62; noise: 1.89; b: 1.38; m: 9.69; expr: 1.00; deg: 0.00; theta: 7.60; asym: 0.96; tree : 0
# >> G_4: init: 0.36; noise: 2.75; b: 1.12; m: 8.09; expr: 1.00; deg: 0.00; theta: 4.49; asym: 4.70; tree : NOT NOT 0
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.99; noise: 7.34; b: 2.82; m: 5.11; expr: 1.00; deg: 0.00; theta: 4.81; asym: 2.79; tree : ((4 OR 1) AND 0)
# >> G_1: init: 0.58; noise: 1.97; b: 1.33; m: 9.90; expr: 1.00; deg: 0.00; theta: 2.54; asym: 5.71; tree : ((1 AND 0) AND 5)
# >> G_2: init: 0.60; noise: 6.49; b: 3.55; m: 4.88; expr: 1.00; deg: 0.00; theta: 9.00; asym: 1.75; tree : (1 OR (5 OR 2))
# >> G_3: init: 0.52; noise: 6.33; b: 0.78; m: 6.02; expr: 1.00; deg: 0.00; theta: 6.36; asym: 2.39; tree : (NOT 0 OR (1 OR 4))
# >> G_4: init: 0.54; noise: 1.22; b: 1.49; m: 5.07; expr: 1.00; deg: 0.00; theta: 3.89; asym: 6.41; tree : (4 OR 0)
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.99; noise: 7.34; b: 2.82; m: 5.11; expr: 1.00; deg: 0.00; theta: 4.81; asym: 2.79; tree : ((5 OR 1) AND 0)
# >> G_1: init: 0.58; noise: 1.97; b: 1.33; m: 9.90; expr: 1.00; deg: 0.00; theta: 2.87; asym: 5.71; tree : ((1 AND 0) AND 5)
# >> G_2: init: 0.60; noise: 6.49; b: 3.55; m: 4.88; expr: 1.00; deg: 0.00; theta: 9.00; asym: 1.75; tree : (1 OR (5 OR 2))
# >> G_3: init: 0.52; noise: 6.33; b: 0.78; m: 6.02; expr: 1.00; deg: 0.00; theta: 5.92; asym: 2.39; tree : (NOT 0 OR (2 OR 3))
# >> G_4: init: 0.54; noise: 1.22; b: 1.49; m: 5.07; expr: 1.00; deg: 0.00; theta: 3.89; asym: 6.41; tree : (4 OR 0)
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 0.88; noise: 9.65; b: 1.35; m: 5.30; expr: 1.00; deg: 0.00; theta: 8.21; asym: 5.44; tree : (NOT 5 OR (0 OR 1))
# >> G_1: init: 0.53; noise: 8.29; b: 1.06; m: 3.95; expr: 1.00; deg: 0.00; theta: 8.66; asym: 9.87; tree : 3
# >> G_2: init: 1.67; noise: 1.39; b: 0.76; m: 9.67; expr: 1.00; deg: 0.00; theta: 2.43; asym: 8.20; tree : 1
# >> G_3: init: 0.20; noise: 1.65; b: 0.42; m: 1.50; expr: 1.00; deg: 0.00; theta: 0.99; asym: 1.35; tree : 2
# >> G_4: init: 0.54; noise: 0.81; b: 1.44; m: 9.00; expr: 1.00; deg: 0.00; theta: 3.36; asym: 4.30; tree : 5
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.99; noise: 7.34; b: 2.82; m: 5.11; expr: 1.00; deg: 0.00; theta: 5.64; asym: 2.79; tree : ((5 OR 1) AND 0)
# >> G_1: init: 0.58; noise: 1.97; b: 1.33; m: 9.90; expr: 1.00; deg: 0.00; theta: 2.99; asym: 5.71; tree : ((1 AND 0) AND 5)
# >> G_2: init: 0.60; noise: 6.49; b: 3.55; m: 4.88; expr: 1.00; deg: 0.00; theta: 8.19; asym: 1.75; tree : (1 OR (5 OR 0))
# >> G_3: init: 0.52; noise: 6.33; b: 0.78; m: 6.02; expr: 1.00; deg: 0.00; theta: 5.92; asym: 1.96; tree : (NOT 0 OR (2 OR 3))
# >> G_4: init: 0.54; noise: 1.22; b: 1.49; m: 5.07; expr: 1.00; deg: 0.00; theta: 4.66; asym: 6.41; tree : NOT 0
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.99; noise: 7.34; b: 2.82; m: 5.11; expr: 1.00; deg: 0.00; theta: 5.04; asym: 2.79; tree : ((5 OR 1) AND 0)
# >> G_1: init: 0.58; noise: 1.97; b: 1.33; m: 9.90; expr: 1.00; deg: 0.00; theta: 3.11; asym: 4.90; tree : ((1 AND 0) AND 5)
# >> G_2: init: 0.60; noise: 6.49; b: 3.55; m: 4.88; expr: 1.00; deg: 0.00; theta: 10.04; asym: 1.75; tree : (1 OR (5 OR 2))
# >> G_3: init: 0.52; noise: 6.33; b: 0.78; m: 6.02; expr: 1.00; deg: 0.00; theta: 5.92; asym: 1.96; tree : (2 OR 3)
# >> G_4: init: 0.54; noise: 1.22; b: 1.49; m: 5.07; expr: 3.39; deg: 0.00; theta: 3.62; asym: 6.41; tree : (4 OR 0)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.99; noise: 7.34; b: 2.82; m: 5.11; expr: 1.00; deg: 0.00; theta: 5.64; asym: 2.79; tree : ((5 OR 1) AND 0)
# >> G_1: init: 0.58; noise: 1.97; b: 1.33; m: 9.90; expr: 1.00; deg: 0.00; theta: 2.71; asym: 5.71; tree : ((1 AND 0) AND 5)
# >> G_2: init: 0.60; noise: 6.49; b: 3.55; m: 4.88; expr: 1.00; deg: 0.00; theta: 8.76; asym: 1.75; tree : (1 OR (5 OR 0))
# >> G_3: init: 0.52; noise: 6.33; b: 0.78; m: 6.02; expr: 1.00; deg: 0.00; theta: 5.24; asym: 1.96; tree : (NOT 0 OR (2 OR 3))
# >> G_4: init: 0.54; noise: 1.22; b: 1.49; m: 5.07; expr: 1.00; deg: 0.00; theta: 0.89; asym: 5.57; tree : 0
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.73; asym: 2.38; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 8.75; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.00; theta: 0.90; asym: 7.39; tree : (1 AND (2 AND 4))
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 4.24; expr: 1.00; deg: 0.00; theta: 8.78; asym: 4.45; tree : (NOT 3 AND 0)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.61; asym: 4.11; tree : NOT (5 AND 2)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.73; asym: 2.07; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 8.75; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.00; theta: 0.90; asym: 7.39; tree : (1 AND (2 AND 4))
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 4.24; expr: 1.00; deg: 0.00; theta: 9.14; asym: 4.45; tree : (NOT 3 AND 0)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.61; asym: 4.11; tree : NOT (5 AND 2)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.73; asym: 1.71; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 9.93; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.00; theta: 0.90; asym: 6.37; tree : (1 AND 4)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 4.24; expr: 1.00; deg: 0.00; theta: 8.78; asym: 4.45; tree : (NOT 3 AND 0)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.61; asym: 4.11; tree : NOT (NOT 5 AND 2)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.72; asym: 1.45; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 9.21; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.00; theta: 0.89; asym: 7.39; tree : (1 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 4.24; expr: 1.00; deg: 0.00; theta: 11.65; asym: 4.45; tree : (NOT 3 AND 2)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.61; asym: 4.11; tree : NOT (5 AND 2)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.72; asym: 1.74; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 9.47; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.00; theta: 0.89; asym: 7.39; tree : (1 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 4.24; expr: 1.00; deg: 0.00; theta: 11.65; asym: 4.45; tree : (NOT 3 AND 2)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.64; asym: 4.11; tree : NOT (5 AND 2)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.72; asym: 1.42; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 9.21; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.00; theta: 1.06; asym: 7.39; tree : (1 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 4.24; expr: 1.00; deg: 0.00; theta: 13.19; asym: 4.45; tree : (NOT 3 AND 0)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.64; asym: 4.11; tree : NOT (5 AND 2)
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.73; asym: 1.74; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 10.44; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.00; theta: 1.02; asym: 7.39; tree : (1 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 4.24; expr: 1.00; deg: 0.00; theta: 12.73; asym: 3.87; tree : (NOT 3 AND 1)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.88; asym: 4.11; tree : NOT ((5 OR 4) AND 2)
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.73; asym: 1.74; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 11.81; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.00; theta: 0.89; asym: 7.39; tree : (1 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 2.94; expr: 1.00; deg: 0.00; theta: 14.96; asym: 3.87; tree : (NOT 3 AND 2)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.57; asym: 3.29; tree : NOT ((5 OR 4) AND 2)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.72; asym: 1.74; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 10.11; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.50; theta: 0.85; asym: 6.00; tree : (1 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 2.94; expr: 1.00; deg: 0.00; theta: 13.52; asym: 3.87; tree : (NOT NOT 3 AND 2)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.91; asym: 2.71; tree : NOT ((5 OR 4) AND 2)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.72; asym: 1.74; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 10.11; asym: 7.50; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.50; theta: 0.93; asym: 6.00; tree : (1 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 2.94; expr: 1.00; deg: 0.00; theta: 12.38; asym: 3.87; tree : (NOT NOT 3 AND 2)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.91; asym: 2.71; tree : NOT ((5 OR 4) AND 0)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.72; asym: 1.74; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 10.11; asym: 7.50; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.50; theta: 0.93; asym: 6.00; tree : (NOT 1 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 2.94; expr: 1.00; deg: 0.00; theta: 13.32; asym: 3.87; tree : (NOT NOT 3 AND 2)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.91; asym: 2.71; tree : NOT ((5 OR 4) AND 0)
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.72; asym: 1.44; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 8.71; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.50; theta: 0.96; asym: 4.08; tree : (1 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 2.94; expr: 1.00; deg: 2.45; theta: 14.96; asym: 3.87; tree : (NOT NOT 0 AND 2)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.60; asym: 2.71; tree : NOT (5 OR 4)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.72; asym: 1.17; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 9.82; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.50; theta: 0.87; asym: 5.03; tree : (3 AND 2)
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 2.94; expr: 1.00; deg: 2.45; theta: 14.94; asym: 3.16; tree : (NOT NOT 3 AND 2)
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.63; asym: 2.71; tree : NOT (5 OR 4)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.54; noise: 7.53; b: 0.68; m: 3.25; expr: 1.00; deg: 0.00; theta: 0.72; asym: 1.44; tree : 4
# >> G_1: init: 0.90; noise: 6.97; b: 1.45; m: 3.57; expr: 1.00; deg: 0.00; theta: 10.63; asym: 9.03; tree : ((2 OR 4) AND NOT 0)
# >> G_2: init: 0.33; noise: 4.59; b: 1.45; m: 1.36; expr: 1.00; deg: 0.50; theta: 1.01; asym: 4.21; tree : 1
# >> G_3: init: 0.27; noise: 7.79; b: 2.97; m: 2.94; expr: 1.00; deg: 2.45; theta: 13.72; asym: 3.87; tree : NOT NOT 3
# >> G_4: init: 0.20; noise: 9.54; b: 2.07; m: 2.81; expr: 1.00; deg: 0.00; theta: 1.78; asym: 2.21; tree : NOT (5 OR 4)
