# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**1.8))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_test"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_test
# [definition]
#
#
# [reload] Found generation 1
# [out] Step 100
# [out] ++ Best 1077.440375449408 for generation 100
# [out] ++ Best 1092.1680276135203 for generation 102
# [out] ++ Best 1102.3806657781477 for generation 104
# [out] ++ Best 1149.9666105603794 for generation 105
# [out] ++ Best 1183.0135144409132 for generation 106
# [out] ++ Best 1214.2432664377156 for generation 109
# [out] ++ Best 1272.3955347673784 for generation 110
# [out] ++ Best 1346.440375449408 for generation 114
# [out] ++ Best 1537.2432664377156 for generation 115
# [out] ++ Best 1603.440375449408 for generation 135
# [out] ++ Best 1737.2878913387765 for generation 137
# [out] ++ Best 1745.0135144409132 for generation 146
# Saving ...
# [out] ++ Best 1850.0135144409132 for generation 173
# [out] ++ Best 2010.092579190645 for generation 196
# Saving ...
# [out] Step 200
# Saving ...
# Saving ...
# [out] Step 300
# [out] ++ Best 2042.665160828964 for generation 323
# Saving ...
# Saving ...
# [out] Step 400
# [out] ++ Best 2247.2878913387767 for generation 410
# Step 3 passed !
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# [out] ++ Best 2293.966610560379 for generation 617
# Saving ...
# Saving ...
# [out] Step 700
# [out] ++ Best 2344.1196186860043 for generation 744
# [out] ++ Best 2353.1680276135203 for generation 746
# Saving ...
# [out] ++ Best 2434.2432664377156 for generation 776
# Saving ...
# [out] Step 800
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# [out] ++ Best 2471.1196186860043 for generation 1077
# Saving ...
# [out] Step 1100
# Saving ...
# [out] ++ Best 2509.1680276135203 for generation 1197
# Saving ...
# [out] Step 1200
# [out] ++ Best 2586.1196186860043 for generation 1206
# Saving ...
# [out] ++ Best 2644.0135144409132 for generation 1257
# Saving ...
# [out] Step 1300
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# [out] ++ Best 2688.2432664377156 for generation 2099
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# [out] ++ Best 2732.2432664377156 for generation 2415
# [out] ++ Best 2742.2432664377156 for generation 2419
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_test

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.90; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.71; asym: 5.00; tree : ((5 AND 3) OR (0 OR 1))
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.42; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 0.23; asym: 5.00; tree : ((4 OR 5) OR 1)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.26; asym: 5.00; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 5.36; asym: 5.00; tree : ((4 OR 0) OR NOT 1)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.70; asym: 5.00; tree : ((5 AND 3) OR (0 OR 1))
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.42; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 0.28; asym: 5.00; tree : (4 OR 5)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.26; asym: 5.00; tree : 1
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.72; asym: 5.00; tree : ((4 OR 0) OR NOT 5)
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.77; asym: 5.00; tree : ((5 AND 3) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.40; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 0.25; asym: 5.00; tree : (4 OR 5)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.26; asym: 5.00; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 5.00; tree : ((4 OR 0) OR NOT 5)
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.66; asym: 5.00; tree : ((5 AND 1) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.42; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 0.29; asym: 5.00; tree : (0 OR 5)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.00; asym: 5.00; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 7.44; asym: 5.00; tree : ((4 OR 0) OR NOT 5)
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.65; asym: 5.00; tree : ((5 AND 1) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.44; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 0.29; asym: 5.00; tree : (4 OR 1)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.26; asym: 5.00; tree : 4
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 5.00; tree : NOT 5
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.65; asym: 4.31; tree : ((5 AND 1) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.44; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 0.25; asym: 5.00; tree : (4 OR 1)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : 4
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 5.00; tree : NOT 5
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.66; asym: 4.29; tree : ((5 AND 1) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.35; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 0.25; asym: 4.06; tree : (5 OR 3)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.26; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 5.00; tree : NOT 5
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.78; asym: 4.31; tree : ((5 AND 1) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 9.37; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 0.24; deg: 0.10; theta: 0.27; asym: 4.17; tree : NOT (4 OR 1)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : 4
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 4.00; tree : NOT 5
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.68; asym: 4.29; tree : ((5 AND 2) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.35; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.33; asym: 3.49; tree : (5 OR 0)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.76; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 4.20; tree : NOT 5
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.63; asym: 4.29; tree : (1 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.56; asym: 5.00; tree : 5
# >> G_2: init: 1.58; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 0.22; asym: 4.06; tree : 2
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.17; asym: 4.24; tree : 4
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 7.05; asym: 5.00; tree : NOT 5
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.60; asym: 4.29; tree : ((5 AND 2) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.28; asym: 5.00; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.84; asym: 3.49; tree : (5 OR 1)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.54; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 3.61; tree : NOT 5
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.60; asym: 3.68; tree : ((5 AND 2) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.13; asym: 5.00; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 4.75; asym: 3.49; tree : 1
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 5.34; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 4.20; tree : NOT 5
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.55; asym: 3.19; tree : ((5 AND 2) OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.42; asym: 5.00; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.33; asym: 3.49; tree : 1
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 5.34; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 4.20; tree : NOT 5
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.70; asym: 3.68; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.13; asym: 5.00; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 4.75; asym: 3.49; tree : 1
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 6.24; asym: 4.24; tree : 0
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 3.56; tree : NOT 5
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.81; asym: 3.68; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.28; asym: 5.00; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 4.75; asym: 2.84; tree : 4
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 6.24; asym: 4.24; tree : 4
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 3.56; tree : NOT 5
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.91; asym: 3.68; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.25; asym: 5.00; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.04; asym: 2.86; tree : 5
# >> G_3: init: 0.85; noise: 7.31; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 5.71; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.85; asym: 3.56; tree : NOT 5
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.81; asym: 3.21; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.06; asym: 5.00; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.04; asym: 2.86; tree : 1
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 6.77; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.81; asym: 2.90; tree : NOT 5
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.81; asym: 3.21; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.06; asym: 5.00; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.50; asym: 2.86; tree : 5
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 6.77; asym: 3.58; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.81; asym: 2.90; tree : NOT 5
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.80; asym: 3.21; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.14; asym: 4.15; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.04; asym: 2.37; tree : (1 OR 5)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 6.56; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.92; asym: 2.90; tree : NOT 5
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.80; asym: 2.74; tree : ((5 OR 0) OR 2)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.35; asym: 4.15; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.04; asym: 2.37; tree : (1 OR 5)
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 6.56; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.92; asym: 2.90; tree : NOT 5
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.78; asym: 3.21; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.24; asym: 4.15; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.46; asym: 2.86; tree : NOT 1
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 5.26; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 7.17; asym: 2.40; tree : NOT 5
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.83; asym: 3.21; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.24; asym: 4.15; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.46; asym: 2.86; tree : NOT 1
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.63; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 7.38; asym: 2.40; tree : NOT 5
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.82; asym: 3.21; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.42; asym: 4.15; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 5.46; asym: 2.86; tree : NOT 1
# >> G_3: init: 2.88; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.63; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 7.17; asym: 2.40; tree : NOT 5
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.70; asym: 3.21; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.40; asym: 3.56; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 4.63; asym: 2.86; tree : NOT 0
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 5.46; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.90; asym: 2.40; tree : NOT 5
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 2.25; noise: 0.53; b: 8.61; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.94; asym: 3.21; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.55; asym: 4.15; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 4.63; asym: 2.48; tree : NOT 1
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.22; asym: 4.24; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.97; asym: 2.40; tree : NOT 5
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 2.25; noise: 0.53; b: 2.32; m: 7.39; expr: 1.00; deg: 0.10; theta: 0.66; asym: 3.21; tree : (5 OR 0)
# >> G_1: init: 1.62; noise: 0.16; b: 0.90; m: 7.28; expr: 1.00; deg: 0.10; theta: 1.55; asym: 4.15; tree : 5
# >> G_2: init: 1.24; noise: 0.21; b: 1.66; m: 1.07; expr: 1.00; deg: 0.10; theta: 4.63; asym: 2.86; tree : NOT 1
# >> G_3: init: 0.85; noise: 0.19; b: 3.49; m: 9.57; expr: 1.00; deg: 0.10; theta: 4.49; asym: 3.62; tree : 2
# >> G_4: init: 1.43; noise: 0.41; b: 0.59; m: 6.49; expr: 1.00; deg: 0.10; theta: 6.90; asym: 2.40; tree : NOT 5
