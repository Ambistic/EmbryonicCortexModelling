# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
import random
from lib.sde.mutate import mutate_gene4, mutate_tree

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None, nb_genes=4):
    return Solution(GRNMain(nb_genes, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
_MUTATE_FUNC = mutate_grn

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        global _MUTATE_FUNC
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + 0.1 * s_all + 0.1 * s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=False, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init),
                                  new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    ObjectiveStep(name="The ONE", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 30
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 25
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, name=None):
    args = get_prun()
    args.cb_init = cb_init
    args.name = name
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    print("Final score", np.mean(scores), "+-", np.std(scores))
    return np.mean(scores), np.std(scores), max(p1)

# %%
def mutate_grn_ctrl(grn):
    grn.set_mutable()
    one_gene = random.choice(grn.genes)
    mutate_gene4(one_gene)
    grn.compile()
    
def mutate_grn_sparse(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.8)
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()
    
def mutate_grn_verysparse(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.9)
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()
    
def mutate_grn_full(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        grn._params *= np.random.normal(1, temperature, shape)
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()

# %%
model = sm.StringModel("expfit_func{mutfunc}_i{i}")
mut_func = dict(
    ctrl=mutate_grn_ctrl,
    sparse=mutate_grn_sparse,
    very_sparse=mutate_grn_verysparse,
    full=mutate_grn_full,
)

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
)

# %%
# main loop
exporter = Exporter(name="exp_mutfunc_220222")
for (funcname, func), i in product(mut_func.items(), range(10)):
    name = model.fill(mutfunc=funcname, i=i)
    print(name)
    if name in exporter.list():
        continue
    _MUTATE_FUNC = func
    res = get_score_parametrized(callback_init)
    exporter(res, name)
# Out:
# Exporting at output/exp_mutfunc_220222
# expfit_funcctrl_i0
# expfit_funcctrl_i1
# expfit_funcctrl_i2
# expfit_funcctrl_i3
# expfit_funcctrl_i4
# expfit_funcctrl_i5
# expfit_funcctrl_i6
# expfit_funcctrl_i7
# expfit_funcctrl_i8
# expfit_funcctrl_i9
# expfit_funcsparse_i0
# Step 0
# ++ Best 0.014668764359330852 for generation 0
# ++ Best 0.0182329502764473 for generation 18
# ++ Best 0.04258679705974726 for generation 23
# ++ Best 0.05577456293887768 for generation 32
# ++ Best 0.057752781487551925 for generation 33
# ++ Best 0.05783617550677683 for generation 34
# ++ Best 0.06074727143721592 for generation 42
# Step 100
# ++ Best 0.06844339278180377 for generation 121
# Step 200
# OVER
# Final score 0.051099427700726244 +- 0.00867363684878789
# expfit_funcsparse_i1
# Step 0
# ++ Best 0.014234248340704933 for generation 0
# ++ Best 0.014652419608914759 for generation 1
# ++ Best 0.018683085938819906 for generation 6
# ++ Best 0.05055058081392947 for generation 12
# ++ Best 0.08556820355981119 for generation 54
# Step 100
# Step 200
# OVER
# Final score 0.0190298791301367 +- 0.010308874359012867
# expfit_funcsparse_i2
# Step 0
# ++ Best 0.014027047135251398 for generation 0
# ++ Best 0.018927672848938867 for generation 1
# ++ Best 0.023537288490538502 for generation 6
# ++ Best 0.03157750086734247 for generation 11
# ++ Best 0.03200414948410105 for generation 15
# ++ Best 0.1372190377179609 for generation 19
# Step The ONE passed !
# ++ Best 0.20122166786335732 for generation 55
# ++ Best 0.2234097684291179 for generation 60
# ++ Best 0.2775138992778584 for generation 84
# ++ Best 0.4103755590827378 for generation 86
# Step 100
# ++ Best 0.4518307287114141 for generation 141
# Step 200
# OVER
# Final score 0.05705119428583386 +- 0.058875540113557875
# expfit_funcsparse_i3
# Step 0
# ++ Best 0.016626661874528104 for generation 0
# ++ Best 0.03561074426735022 for generation 2
# ++ Best 0.04291509192302008 for generation 4
# ++ Best 0.046662021162593464 for generation 99
# Step 100
# ++ Best 0.05299664236638042 for generation 131
# ++ Best 0.05529443165111813 for generation 171
# ++ Best 0.061076728509102333 for generation 196
# Step 200
# ++ Best 0.06139979226922765 for generation 242
# ++ Best 0.08428977346247171 for generation 254
# OVER
# Final score 0.06507684372815559 +- 0.01112543538847417
# expfit_funcsparse_i4
# Step 0
# ++ Best 0.014037082773342289 for generation 0
# ++ Best 0.04418845852781525 for generation 1
# ++ Best 0.04966406553949943 for generation 26
# ++ Best 0.05732380962278831 for generation 35
# ++ Best 0.06479510412685319 for generation 46
# Step 100
# ++ Best 0.08087018270312146 for generation 118
# Step 200
# OVER
# Final score 0.04428096832468316 +- 0.022134903388401576
# expfit_funcsparse_i5
# Step 0
# ++ Best 0.01425454774183215 for generation 0
# ++ Best 0.015031625905976852 for generation 1
# ++ Best 0.02364642125780835 for generation 4
# ++ Best 0.05356033582354628 for generation 5
# ++ Best 0.053792467366876685 for generation 45
# ++ Best 0.06168476102031109 for generation 56
# ++ Best 0.07208068010777947 for generation 81
# Step 100
# Step 200
# ++ Best 0.07498223731026657 for generation 257
# OVER
# Final score 0.03778300508313745 +- 0.036392380759538864
# expfit_funcsparse_i6
# Step 0
# ++ Best 0.01422933130083879 for generation 0
# ++ Best 0.014498768021024674 for generation 2
# ++ Best 0.015538716336500504 for generation 3
# ++ Best 0.06539998446227756 for generation 10
# ++ Best 0.06623929004544327 for generation 49
# ++ Best 0.06806687678410549 for generation 58
# ++ Best 0.06945765838011869 for generation 68
# Step 100
# ++ Best 0.08609721768811118 for generation 127
# Step 200
# OVER
# Final score 0.05132869685283906 +- 0.03216950492282441
# expfit_funcsparse_i7
# Step 0
# ++ Best 0.014130750013484739 for generation 0
# ++ Best 0.014231617705537344 for generation 1
# ++ Best 0.018783837618343537 for generation 2
# ++ Best 0.025764927544675985 for generation 4
# ++ Best 0.03867252705383135 for generation 5
# ++ Best 0.03989470638754921 for generation 28
# ++ Best 0.043033093157956726 for generation 31
# ++ Best 0.04837836210751931 for generation 35
# ++ Best 0.04882880544414609 for generation 49
# ++ Best 0.05811785035052318 for generation 50
# ++ Best 0.059095575278530155 for generation 72
# ++ Best 0.059116691435900974 for generation 77
# ++ Best 0.07052800998191316 for generation 78
# Step 100
# ++ Best 0.07298882352873973 for generation 146
# ++ Best 0.2488484833756008 for generation 156
# Step 200
# OVER
# Final score 0.12360356759497444 +- 0.0695234900668917
# expfit_funcsparse_i8
# Step 0
# ++ Best 0.0249517958725358 for generation 0
# ++ Best 0.03705945458345695 for generation 10
# ++ Best 0.05971361162011844 for generation 41
# ++ Best 0.0654721020790842 for generation 43
# ++ Best 0.07107402241192218 for generation 62
# Step 100
# ++ Best 0.08217793510720009 for generation 128
# ++ Best 0.08872832552556283 for generation 152
# Step 200
# ++ Best 0.08885310298819626 for generation 227
# ++ Best 0.09802609875244359 for generation 275
# OVER
# Final score 0.0858016523063013 +- 0.008578092390321675
# expfit_funcsparse_i9
# Step 0
# ++ Best 0.014063925261672133 for generation 0
# ++ Best 0.015315121171696033 for generation 3
# ++ Best 0.028203624960033122 for generation 5
# ++ Best 0.03717375679501924 for generation 6
# ++ Best 0.048167981854960004 for generation 9
# ++ Best 0.1366797068967536 for generation 23
# ++ Best 0.17214697759608497 for generation 54
# ++ Best 0.20145268774669345 for generation 75
# Step 100
# ++ Best 0.2081832063780424 for generation 114
# ++ Best 0.22040466314868537 for generation 119
# ++ Best 0.26044873876319463 for generation 121
# ++ Best 0.2674958833646424 for generation 143
# ++ Best 0.30712457183767056 for generation 163
# Step 200
# OVER
# Final score 0.12948624624726696 +- 0.08136058777915485
# expfit_funcvery_sparse_i0
# Step 0
# ++ Best 0.01769055455691576 for generation 0
# ++ Best 0.0282288983415387 for generation 6
# ++ Best 0.052024375133668886 for generation 12
# ++ Best 0.12989333218921484 for generation 35
# Step 100
# Step 200
# OVER
# Final score 0.03504222461692988 +- 0.018762567896620053
# expfit_funcvery_sparse_i1
# Step 0
# ++ Best 0.014549476728886996 for generation 0
# ++ Best 0.0162072245455622 for generation 2
# ++ Best 0.0169677239925346 for generation 5
# ++ Best 0.03266137231765489 for generation 11
# ++ Best 0.034251498750963526 for generation 14
# ++ Best 0.034319381254205646 for generation 20
# ++ Best 0.03460933291574942 for generation 25
# ++ Best 0.07745540758608473 for generation 29
# ++ Best 0.07839708324294153 for generation 49
# Step 100
# ++ Best 0.08040401572897782 for generation 140
# Step 200
# OVER
# Final score 0.0634569067402571 +- 0.0059656502212634835
# expfit_funcvery_sparse_i2
# Step 0
# ++ Best 0.0604649817621284 for generation 0
# ++ Best 0.09258011399404291 for generation 47
# Step 100
# ++ Best 0.09432379193920375 for generation 182
# Step 200
# ++ Best 0.1072022649467728 for generation 209
# ++ Best 0.12440246459186606 for generation 231
# OVER
# Final score 0.09370902615462393 +- 0.009358086860289633
# expfit_funcvery_sparse_i3
# Step 0
# ++ Best 0.01551176094418366 for generation 0
# ++ Best 0.02319233222012818 for generation 2
# ++ Best 0.03812487163008615 for generation 3
# ++ Best 0.03940973887222609 for generation 19
# ++ Best 0.04178674332106996 for generation 28
# ++ Best 0.04320818158886793 for generation 55
# ++ Best 0.04336296114244442 for generation 59
# ++ Best 0.046246915623510985 for generation 67
# ++ Best 0.05085686334343202 for generation 71
# Step 100
# ++ Best 0.05472089136498934 for generation 125
# ++ Best 0.05766706998095696 for generation 194
# Step 200
# ++ Best 0.061368792423970635 for generation 224
# ++ Best 0.06856919087557983 for generation 243
# ++ Best 0.0708501935644599 for generation 257
# OVER
# Final score 0.06202410118981585 +- 0.0030077314783835112
# expfit_funcvery_sparse_i4
# Step 0
# ++ Best 0.03557009866467434 for generation 0
# ++ Best 0.043247680980489325 for generation 4
# ++ Best 0.043739051528805736 for generation 24
# ++ Best 0.0516812205289626 for generation 28
# ++ Best 0.09619400083407412 for generation 71
# Step 100
# ++ Best 0.10365572994642368 for generation 133
# ++ Best 0.11916817109456736 for generation 186
# Step 200
# OVER
# Final score 0.03235010173933657 +- 0.013922421302087195
# expfit_funcvery_sparse_i5
# Step 0
# ++ Best 0.014253564448189213 for generation 0
# ++ Best 0.01426637156442171 for generation 3
# ++ Best 0.014708119210452252 for generation 4
# ++ Best 0.01952051481084359 for generation 8
# ++ Best 0.034438779903002315 for generation 16
# ++ Best 0.05508585129358591 for generation 24
# ++ Best 0.05806506171622034 for generation 72
# ++ Best 0.0685811103571663 for generation 91
# Step 100
# ++ Best 0.07825515199580863 for generation 111
# Step 200
# OVER
# Final score 0.05373424588921596 +- 0.01144143980661149
# expfit_funcvery_sparse_i6
# Step 0
# ++ Best 0.014343158447741377 for generation 0
# ++ Best 0.014438440357545051 for generation 1
# ++ Best 0.015615078028234003 for generation 5
# ++ Best 0.01743042152451561 for generation 8
# ++ Best 0.02951784284905116 for generation 15
# ++ Best 0.030223019372582798 for generation 25
# ++ Best 0.04997432662287505 for generation 27
# ++ Best 0.05303148709435671 for generation 80
# ++ Best 0.07879088866259677 for generation 89
# Step 100
# ++ Best 0.08126313837864976 for generation 100
# ++ Best 0.08407183854981257 for generation 127
# ++ Best 0.09620684837765943 for generation 182
# Step 200
# OVER
# Final score 0.08684311887908067 +- 0.0018692903437154424
# expfit_funcvery_sparse_i7
# Step 0
# ++ Best 0.014016397637583701 for generation 0
# ++ Best 0.014063864764715939 for generation 1
# ++ Best 0.038213137586068896 for generation 4
# ++ Best 0.04210484889035866 for generation 48
# ++ Best 0.04284661090496983 for generation 59
# ++ Best 0.04823169291579435 for generation 85
# ++ Best 0.05080699824961422 for generation 97
# Step 100
# ++ Best 0.05101945691741517 for generation 100
# ++ Best 0.05435401637783597 for generation 108
# Step 200
# ++ Best 0.054430360697359084 for generation 289
# OVER
# Final score 0.044258439672226375 +- 0.004105740101670101
# expfit_funcvery_sparse_i8
# Step 0
# ++ Best 0.014199882959461969 for generation 0
# ++ Best 0.02702728872579303 for generation 2
# ++ Best 0.028783191047620973 for generation 6
# ++ Best 0.058693254403917476 for generation 7
# ++ Best 0.06623692224867862 for generation 57
# ++ Best 0.07720977391464223 for generation 60
# Step 100
# ++ Best 0.079496029725927 for generation 173
# ++ Best 0.08593131841561073 for generation 177
# Step 200
# OVER
# Final score 0.05886611851509662 +- 0.006242168610878621
# expfit_funcvery_sparse_i9
# Step 0
# ++ Best 0.006139754906246755 for generation 0
# ++ Best 0.03475627863851671 for generation 2
# ++ Best 0.041519214833644486 for generation 92
# Step 100
# ++ Best 0.05159791347440689 for generation 100
# ++ Best 0.056077686159688694 for generation 160
# ++ Best 0.06194830959302847 for generation 178
# ++ Best 0.08865264346949521 for generation 187
# Step 200
# OVER
# Final score 0.04629352059684133 +- 0.020776288515220852
# expfit_funcfull_i0
# Step 0
# ++ Best 0.01428056385030209 for generation 0
# ++ Best 0.038204289583893304 for generation 2
# ++ Best 0.039594290574526445 for generation 4
# ++ Best 0.0513081899489266 for generation 27
# ++ Best 0.06925648742993355 for generation 52
# Step 100
# ++ Best 0.06970097809831198 for generation 113
# ++ Best 0.07127125108463517 for generation 163
# ++ Best 0.11252490883824354 for generation 197
# Step 200
# ++ Best 0.139093204952413 for generation 268
# OVER
# Final score 0.13313988753791425 +- 0.06408351473369309
# expfit_funcfull_i1
# Step 0
# ++ Best 0.01468494697963472 for generation 0
# ++ Best 0.018666019710241857 for generation 2
# ++ Best 0.019739194812349446 for generation 3
# ++ Best 0.0275663981521006 for generation 5
# ++ Best 0.09299067314860858 for generation 18
# ++ Best 0.11608024480145634 for generation 66
# ++ Best 0.11765907473982704 for generation 81
# Step 100
# ++ Best 0.12622225622704214 for generation 156
# Step 200
# OVER
# Final score 0.05819219993389656 +- 0.021316172661996383
# expfit_funcfull_i2
# Step 0
# ++ Best 0.027858132007885616 for generation 0
# ++ Best 0.06005407212170903 for generation 8
# ++ Best 0.06794769526085222 for generation 86
# Step 100
# ++ Best 0.0694779669466663 for generation 115
# ++ Best 0.0732070538681491 for generation 129
# Step 200
# ++ Best 0.07436407711296782 for generation 217
# ++ Best 0.0749370837260466 for generation 229
# ++ Best 0.07684655132974096 for generation 262
# ++ Best 0.08376578615629535 for generation 298
# OVER
# Final score 0.07597060742764312 +- 0.00587996650932773
# expfit_funcfull_i3
# Step 0
# ++ Best 0.013993494859735273 for generation 0
# ++ Best 0.014210890378780186 for generation 1
# ++ Best 0.014232904204197788 for generation 4
# ++ Best 0.021345817196749037 for generation 5
# ++ Best 0.04651725638095806 for generation 8
# ++ Best 0.09807870869015914 for generation 35
# ++ Best 0.15008491432236776 for generation 53
# Step 100
# Step 200
# OVER
# Final score 0.0629856555418505 +- 0.03675161440262647
# expfit_funcfull_i4
# Step 0
# ++ Best 0.01405543595895012 for generation 0
# ++ Best 0.014253265308055318 for generation 1
# ++ Best 0.016886844329079484 for generation 3
# ++ Best 0.03962291776277527 for generation 5
# ++ Best 0.048749612162357896 for generation 35
# ++ Best 0.051109480361824285 for generation 59
# ++ Best 0.054350021895296884 for generation 93
# Step 100
# ++ Best 0.05674491073806005 for generation 118
# ++ Best 0.05963410300886732 for generation 127
# ++ Best 0.0633432646614092 for generation 140
# ++ Best 0.06690892656399042 for generation 145
# ++ Best 0.07666935775368822 for generation 176
# Step 200
# ++ Best 0.08205399736889811 for generation 220
# ++ Best 0.08300632037920631 for generation 237
# ++ Best 0.08377127400729904 for generation 248
# OVER
# Final score 0.0749507664487586 +- 0.004064524650501524
# expfit_funcfull_i5
# Step 0
# ++ Best 0.014237852473191603 for generation 0
# ++ Best 0.016562808077974733 for generation 1
# ++ Best 0.025736196578337756 for generation 4
# ++ Best 0.041319628215404615 for generation 8
# ++ Best 0.04788265026995747 for generation 13
# ++ Best 0.07226308713816404 for generation 35
# ++ Best 0.08139813257770069 for generation 41
# ++ Best 0.11477235008248188 for generation 78
# Step 100
# ++ Best 0.14036564154136696 for generation 185
# ++ Best 0.16516938605478784 for generation 194
# Step 200
# ++ Best 0.16964094506730384 for generation 210
# OVER
# Final score 0.07761891262335893 +- 0.03854860543529146
# expfit_funcfull_i6
# Step 0
# ++ Best 0.014727288846137374 for generation 0
# ++ Best 0.029092371199581524 for generation 4
# ++ Best 0.02932205185659498 for generation 18
# ++ Best 0.061712598879642894 for generation 26
# ++ Best 0.06392091925289985 for generation 96
# Step 100
# ++ Best 0.0640550461488844 for generation 100
# ++ Best 0.06864148496917159 for generation 134
# ++ Best 0.07969056016061182 for generation 144
# ++ Best 0.08149245529561584 for generation 154
# ++ Best 0.0825300036074182 for generation 155
# ++ Best 0.0856106236332137 for generation 182
# Step 200
# ++ Best 0.09348411495587354 for generation 209
# ++ Best 0.10017963474797015 for generation 231
# OVER
# Final score 0.0735884341120566 +- 0.02114117485372906
# expfit_funcfull_i7
# Step 0
# ++ Best 0.047573057453804156 for generation 0
# ++ Best 0.06653415720629746 for generation 27
# ++ Best 0.08455445250931841 for generation 48
# Step 100
# ++ Best 0.09410914580525202 for generation 114
# ++ Best 0.094325253678729 for generation 147
# ++ Best 0.10278213079991612 for generation 178
# ++ Best 0.14978241621843286 for generation 184
# Step 200
# OVER
# Final score 0.10896623770722573 +- 0.04065314554508046
# expfit_funcfull_i8
# Step 0
# ++ Best 0.014234867452631977 for generation 0
# ++ Best 0.04595465424479957 for generation 1
# ++ Best 0.05446042161632797 for generation 36
# ++ Best 0.058960283588786785 for generation 49
# ++ Best 0.06335342812811871 for generation 51
# ++ Best 0.0667108520024487 for generation 57
# ++ Best 0.07620124897318313 for generation 81
# ++ Best 0.08282842312712059 for generation 82
# Step 100
# ++ Best 0.08673340382245837 for generation 168
# Step 200
# ++ Best 0.08922111213248168 for generation 248
# OVER
# Final score 0.06994012716178727 +- 0.013166228212513263
# expfit_funcfull_i9
# Step 0
# ++ Best 0.013993334945004363 for generation 0
# ++ Best 0.05489979148318807 for generation 1
# ++ Best 0.06057048919691674 for generation 24
# ++ Best 0.07119619528365495 for generation 57
# ++ Best 0.07190608413599858 for generation 59
# ++ Best 0.07547765067625371 for generation 76
# Step 100
# ++ Best 0.07971292799010384 for generation 140
# ++ Best 0.0835884626724156 for generation 196
# Step 200
# ++ Best 0.08607342991261391 for generation 270
# OVER
# Final score 0.09032944732347818 +- 0.05679709591029489

# %%
show_curve(sol.stats, REF.stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-30abeee9d69e> in <module>
# ----> 1 show_curve(sol.stats, REF.stats)
#
# NameError: name 'sol' is not defined

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#   mutfunc  i      mean        sd       max
# 0    ctrl  5  0.069021  0.003811  0.075604
# 1    ctrl  4  0.060421  0.008895  0.093639
# 2  sparse  4  0.044281  0.022135  0.080870
# 3  sparse  2  0.057051  0.058876  0.451831
# 4  sparse  7  0.123604  0.069523  0.248848

# %%
new_df = df.groupby(["mutfunc"]).mean()
new_df
# Out:
#              mean        sd       max
# mutfunc
# ctrl     0.060984  0.011732  0.088428
# full     0.082568  0.030240  0.117783
# sparse   0.066454  0.033914  0.158608

# %%
for i, row in new_df.iterrows():
    print(row.name, row["mean"], row["mean"] - row.sd / np.sqrt(10), row["mean"] + row.sd / np.sqrt(10))
# Out:
# ctrl 0.06098377091961069 0.05727381822815393 0.06469372361106746
# full 0.08256822758179697 0.0730054353348014 0.09213101982879253
# sparse 0.06645414812540548 0.05572952231886237 0.0771787739319486

# %%
row.name
# Out:
# 'sparse'
