# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None, nb_genes=5):
    return Solution(GRNMain(nb_genes, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + s_all + s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=59, silent=True, opti=True,
              run_tissue=False, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init, prun.nb_genes)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    pop_fit = [p**prun.exponent for p in pop_fit]
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init, prun.nb_genes),
                                  new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="3", start_time=56, end_time=59, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="4", start_time=59, end_time=62, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="5", start_time=62, end_time=65, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="6", start_time=65, end_time=68, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="7", start_time=68, end_time=71, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="8", start_time=71, end_time=74, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="9", start_time=74, end_time=77, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="10", start_time=77, end_time=80, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="11", start_time=80, end_time=83, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="12", start_time=83, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 20
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 20
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, nb_genes, name=None):
    args = get_prun()
    args.cb_init = cb_init
    args.name = name
    args.nb_genes = nb_genes
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    print("Final score", np.mean(scores), "+-", np.std(scores))
    return np.mean(scores), np.std(scores), max(p1)

# %%
model = sm.StringModel("expfit_nb{genes}_i{i}")
gen = [3, 4, 5, 7]

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
)

# %%
# main loop
exporter = Exporter(name="exp_nbgenes_220222")
for genes, i in product(gen, range(10)):
    name = model.fill(genes=genes,
                      i=i)
    print(name)
    if name in exporter.list():
        continue
    res = get_score_parametrized(callback_init, genes)
    exporter(res, name)
# Out:
# Exporting at output/exp_nbgenes_220222
# expfit_nb3_i0
# Step 4 passed !
# Step 0
# ++ Best 0.39660685620165126 for generation 0
# ++ Best 0.41390713475458635 for generation 13
# ++ Best 0.4833642271440456 for generation 20
# Step 5 passed !
# ++ Best 0.5871152302973722 for generation 57
# ++ Best 0.6265963450298626 for generation 58
# Step 100
# Step 6 passed !
# Step 7 passed !
# Step 8 passed !
# Step 9 passed !
# Step 10 passed !
# ++ Best 1.7929292569131179 for generation 146
# Step 11 passed !
# Step 12 passed !
# ++ Best 3.1162774857596998 for generation 148
# ++ Best 3.6874429326894456 for generation 157
# OVER
# Final score 2.915706817149344 +- 0.9954320988312717
# expfit_nb3_i1
# Step 0
# ++ Best 0.06121153166703668 for generation 0
# ++ Best 0.35430828163558026 for generation 2
# ++ Best 0.41229862113518656 for generation 7
# ++ Best 2.4145278406739252 for generation 8
# ++ Best 3.191318177613512 for generation 25
# ++ Best 3.2787182076591783 for generation 46
# Step 100
# ++ Best 3.413301533844366 for generation 137
# ++ Best 3.420446406886131 for generation 188
# OVER
# Final score 1.871598077586058 +- 0.9610810045918846
# expfit_nb3_i2
# Step 0
# ++ Best 0.18788103578864812 for generation 0
# ++ Best 0.3530394338279518 for generation 2
# ++ Best 0.3646675537979076 for generation 4
# ++ Best 0.4067964611661562 for generation 23
# ++ Best 0.408678435651356 for generation 48
# ++ Best 0.46808069783834794 for generation 51
# Step 100
# ++ Best 0.6470095738925221 for generation 103
# ++ Best 0.6485868354327617 for generation 112
# ++ Best 0.6534862764374136 for generation 138
# ++ Best 0.7005256195913265 for generation 146
# OVER
# Final score 0.7778171928794249 +- 0.16662095396556637
# expfit_nb3_i3
# Step 0
# ++ Best 1.1586357991943215 for generation 0
# ++ Best 1.2317351213128307 for generation 42
# ++ Best 1.256294913733674 for generation 47
# ++ Best 1.2663406200775293 for generation 67
# ++ Best 1.3380967658431988 for generation 69
# ++ Best 1.488582665727125 for generation 89
# Step 100
# ++ Best 1.5392254826009113 for generation 116
# ++ Best 1.6129726889916678 for generation 123
# ++ Best 1.8747736704144675 for generation 126
# ++ Best 3.4655457661870375 for generation 130
# ++ Best 3.8905116453730635 for generation 136
# ++ Best 4.043665371851072 for generation 165
# OVER
# Final score 1.5934549433566099 +- 1.0797746433451403
# expfit_nb3_i4
# Step 0
# ++ Best 0.060273100672394636 for generation 0
# ++ Best 0.07233889520263265 for generation 1
# ++ Best 0.16333922840288492 for generation 3
# ++ Best 0.25934886556544456 for generation 5
# ++ Best 0.29408517725864036 for generation 7
# ++ Best 0.3109704534735274 for generation 8
# ++ Best 0.5783726139197967 for generation 10
# ++ Best 0.756181490394069 for generation 35
# ++ Best 0.9471157436234734 for generation 63
# Step 100
# ++ Best 0.9481138612885125 for generation 163
# OVER
# Final score 0.573405160691165 +- 0.24589276559177992
# expfit_nb3_i5
# Step 0
# ++ Best 0.08794968411513163 for generation 0
# ++ Best 0.47180485420281404 for generation 1
# ++ Best 0.6537748246906601 for generation 48
# ++ Best 1.3676657131251522 for generation 81
# Step 100
# OVER
# Final score 0.41230632093999703 +- 0.2846976219223332
# expfit_nb3_i6
# Step 0
# ++ Best 0.1429655758000925 for generation 0
# ++ Best 0.38546078413154805 for generation 5
# ++ Best 0.4343173751760296 for generation 17
# ++ Best 0.5233589361048097 for generation 22
# ++ Best 0.5522838119203655 for generation 37
# ++ Best 2.72165388871179 for generation 41
# ++ Best 2.9455588446219805 for generation 50
# ++ Best 3.625340036440286 for generation 51
# Step 100
# ++ Best 3.8022932379706056 for generation 159
# OVER
# Final score 0.688271664008594 +- 0.808967653185143
# expfit_nb3_i7
# Step 0
# ++ Best 0.40232596024758593 for generation 0
# ++ Best 0.6396753901247965 for generation 9
# ++ Best 0.8220968679776415 for generation 19
# ++ Best 0.8367620870618104 for generation 36
# ++ Best 0.8599668940627081 for generation 93
# Step 100
# ++ Best 1.2073413338062187 for generation 139
# ++ Best 1.4600072576984515 for generation 154
# ++ Best 1.4862133488503546 for generation 160
# ++ Best 1.565852062547968 for generation 165
# ++ Best 2.256708798163331 for generation 167
# OVER
# Final score 0.5439660333482539 +- 0.840559038151274
# expfit_nb3_i8
# Step 0
# ++ Best 0.17624355314195303 for generation 0
# ++ Best 0.381518682029066 for generation 4
# ++ Best 0.3839444938054777 for generation 8
# ++ Best 0.9634090149940119 for generation 16
# ++ Best 1.3742789774371402 for generation 17
# Step 100
# OVER
# Final score 0.5121952568233824 +- 0.2555043725894536
# expfit_nb3_i9
# Step 0
# ++ Best 0.0722344464064251 for generation 0
# ++ Best 0.08350920797149616 for generation 1
# ++ Best 0.3721658398638028 for generation 2
# ++ Best 0.3954069893273683 for generation 10
# ++ Best 0.42133789537870714 for generation 15
# ++ Best 0.5145005416488886 for generation 24
# ++ Best 0.6384302695343067 for generation 32
# ++ Best 1.114500972186982 for generation 47
# ++ Best 1.4143242232475532 for generation 55
# ++ Best 1.501944669751003 for generation 59
# ++ Best 3.778615588594542 for generation 67
# Step 100
# OVER
# Final score 0.6472873797299625 +- 0.5373615193135151
# expfit_nb4_i0
# Step 0
# ++ Best 0.1785673117285109 for generation 0
# ++ Best 0.3163714542296332 for generation 5
# ++ Best 0.34934088821738285 for generation 8
# ++ Best 0.6660745284678524 for generation 9
# ++ Best 0.9049840892124494 for generation 19
# ++ Best 0.966726600938197 for generation 48
# Step 100
# ++ Best 2.9427446384439135 for generation 102
# OVER
# Final score 0.835255930771053 +- 0.8301398555139254
# expfit_nb4_i1
# Step 0
# ++ Best 0.3869099367248655 for generation 0
# ++ Best 0.40934860776465365 for generation 1
# ++ Best 0.6046943632182347 for generation 13
# ++ Best 0.6795030380349801 for generation 40
# ++ Best 0.9576222941450181 for generation 51
# Step 100
# OVER
# Final score 0.49850851756940334 +- 0.22062603928462435
# expfit_nb4_i2
# Step 0
# ++ Best 0.07174138696531554 for generation 0
# ++ Best 0.08917443188168124 for generation 1
# ++ Best 0.42732147677328836 for generation 2
# ++ Best 0.6134176659995811 for generation 21
# ++ Best 0.657859517852621 for generation 33
# ++ Best 3.00283344638211 for generation 57
# Step 100
# ++ Best 3.0411922091789134 for generation 142
# OVER
# Final score 1.0748382367161002 +- 0.8474270226247235
# expfit_nb4_i3
# Step 0
# ++ Best 0.17229944737282152 for generation 0
# ++ Best 0.3896369773805243 for generation 3
# ++ Best 0.4423741865224311 for generation 8
# ++ Best 0.5089601300383048 for generation 23
# ++ Best 0.6429728050475112 for generation 24
# ++ Best 1.0998565261451105 for generation 33
# ++ Best 1.3992430678593506 for generation 51
# ++ Best 1.724796798320492 for generation 57
# ++ Best 2.555511973196831 for generation 65
# Step 100
# OVER
# Final score 0.6945359511528018 +- 0.17980526474718087
# expfit_nb4_i4
# Step 0
# ++ Best 0.08193366910952327 for generation 0
# ++ Best 1.0988684067957004 for generation 1
# ++ Best 1.1728324750663437 for generation 20
# ++ Best 1.8676781111531924 for generation 45
# ++ Best 2.2538968250824567 for generation 46
# ++ Best 2.85792275259599 for generation 65
# ++ Best 3.119982719228003 for generation 73
# Step 100
# ++ Best 3.5988698876699066 for generation 129
# ++ Best 3.9236442918437193 for generation 133
# ++ Best 4.243010259488717 for generation 138
# ++ Best 4.249199612488801 for generation 175
# OVER
# Final score 1.6808375377821796 +- 1.0366971540866226
# expfit_nb4_i5
# Step 0
# ++ Best 0.17858448677736624 for generation 0
# ++ Best 0.18055312291074196 for generation 3
# ++ Best 0.34801057713533834 for generation 8
# ++ Best 0.40162574954937735 for generation 22
# ++ Best 0.4024510598048594 for generation 33
# ++ Best 0.4281261618462161 for generation 42
# ++ Best 0.6118751333543514 for generation 56
# ++ Best 0.8965627822434568 for generation 62
# ++ Best 1.137494364972753 for generation 66
# Step 100
# ++ Best 1.2281653165628759 for generation 104
# ++ Best 1.336058439752441 for generation 190
# ++ Best 2.077046859146086 for generation 199
# OVER
# Final score 1.5858000364523979 +- 0.661891943318654
# expfit_nb4_i6
# Step 0
# ++ Best 0.06112996468404928 for generation 0
# ++ Best 0.08309914038560852 for generation 3
# ++ Best 0.41388823416713694 for generation 6
# ++ Best 0.4162778681893019 for generation 32
# ++ Best 0.510164626523518 for generation 35
# ++ Best 0.534010463127623 for generation 38
# ++ Best 0.5345394159034043 for generation 48
# ++ Best 0.5577251720445938 for generation 60
# ++ Best 0.6626444932499294 for generation 87
# ++ Best 0.7427892864742108 for generation 92
# ++ Best 0.7441342043301084 for generation 93
# Step 100
# ++ Best 1.5290343428705724 for generation 103
# ++ Best 1.5985432951368819 for generation 107
# ++ Best 1.943767486369153 for generation 118
# ++ Best 2.0587835073109857 for generation 175
# ++ Best 3.9480696648567286 for generation 181
# OVER
# Final score 1.9140060591493853 +- 0.8241471644880853
# expfit_nb4_i7
# Step 0
# ++ Best 0.05964004400683451 for generation 0
# ++ Best 0.28582040728261293 for generation 1
# ++ Best 0.33986792674223065 for generation 14
# ++ Best 0.6204150066558819 for generation 30
# ++ Best 0.6280022546243239 for generation 49
# Step 100
# ++ Best 0.6292595790901072 for generation 135
# ++ Best 0.8003633307033218 for generation 136
# ++ Best 0.8860900461725323 for generation 166
# ++ Best 0.927033812692198 for generation 171
# ++ Best 1.1938109630951024 for generation 175
# OVER
# Final score 0.6772513102755995 +- 0.10008780337148365
# expfit_nb4_i8
# Step 0
# ++ Best 0.13165228050239203 for generation 0
# ++ Best 0.36843591153957844 for generation 4
# ++ Best 0.5904075694009551 for generation 16
# ++ Best 0.7015490511016089 for generation 20
# ++ Best 1.1736732377917025 for generation 22
# ++ Best 2.286335583717359 for generation 43
# ++ Best 2.4122903169509917 for generation 78
# ++ Best 2.9700501333155156 for generation 84
# ++ Best 3.201421448345353 for generation 94
# Step 100
# ++ Best 3.3914965144800835 for generation 102
# ++ Best 3.499993903456934 for generation 117
# ++ Best 3.6837004830923616 for generation 135
# ++ Best 3.758139106640097 for generation 149
# ++ Best 3.7782489398086336 for generation 163
# ++ Best 3.784099340772401 for generation 191
# OVER
# Final score 3.0614375031856134 +- 0.8535731552665298
# expfit_nb4_i9
# Step 0
# ++ Best 0.06042986613673491 for generation 0
# ++ Best 0.06084127074979341 for generation 1
# ++ Best 0.06121153166703668 for generation 2
# ++ Best 0.41570628468466453 for generation 3
# ++ Best 0.41853730500494113 for generation 20
# ++ Best 0.43011243918417563 for generation 22
# ++ Best 0.6380347535473544 for generation 34
# ++ Best 0.8166982159372129 for generation 58
# Step 100
# ++ Best 0.8471641619314141 for generation 160
# ++ Best 0.9151822038472888 for generation 185
# ++ Best 0.9397587637533612 for generation 199
# OVER
# Final score 0.6881908537212587 +- 0.3330745272705113
# expfit_nb5_i0
# Step 0
# ++ Best 0.061183799615814445 for generation 0
# ++ Best 0.11439933974844706 for generation 3
# ++ Best 0.3251350864162194 for generation 6
# ++ Best 0.7735101900207307 for generation 11
# ++ Best 1.1848267675543143 for generation 14
# Step 100
# ++ Best 1.3149505899158491 for generation 184
# OVER
# Final score 0.6694583047437153 +- 0.3730072359673678
# expfit_nb5_i1
# Step 0
# ++ Best 0.31394012652227177 for generation 0
# ++ Best 0.3480618929004191 for generation 7
# ++ Best 0.7546327137557531 for generation 10
# ++ Best 0.9154118044243605 for generation 57
# ++ Best 1.4837263907025329 for generation 73
# ++ Best 2.787329757030394 for generation 92
# ++ Best 4.023122344104043 for generation 94
# Step 100
# OVER
# Final score 0.9424976643393089 +- 1.3285567074293152
# expfit_nb5_i2
# Step 0
# ++ Best 0.06968694488773187 for generation 0
# ++ Best 0.07043701011943655 for generation 1
# ++ Best 0.12179577561078293 for generation 2
# ++ Best 0.18129437470827314 for generation 6
# ++ Best 0.188183971435566 for generation 7
# ++ Best 0.19489757067086205 for generation 12
# ++ Best 0.33879213450524104 for generation 14
# ++ Best 0.37378498009985783 for generation 23
# ++ Best 0.6858775557750002 for generation 29
# ++ Best 1.076054970988045 for generation 37
# ++ Best 2.747406482416039 for generation 64
# Step 100
# ++ Best 3.171640134036304 for generation 143
# OVER
# Final score 0.44627244855854425 +- 0.42454582258289725
# expfit_nb5_i3
# Step 0
# ++ Best 0.14088499241702246 for generation 0
# ++ Best 0.16190329163150158 for generation 11
# ++ Best 0.29766378248590397 for generation 15
# ++ Best 0.42423041885904833 for generation 16
# ++ Best 0.6096436169191783 for generation 30
# ++ Best 0.6192867430024273 for generation 32
# ++ Best 0.6302857058884822 for generation 53
# ++ Best 0.6586445625869646 for generation 67
# Step 100
# OVER
# Final score 0.3906161861781893 +- 0.21850132525499508
# expfit_nb5_i4
# Step 0
# ++ Best 0.15411528562302546 for generation 0
# ++ Best 0.3456961668592442 for generation 2
# ++ Best 0.41517269135805396 for generation 12
# ++ Best 0.5906259762751518 for generation 27
# ++ Best 0.7163124868234931 for generation 30
# ++ Best 0.86852186176249 for generation 73
# ++ Best 1.7367467032245605 for generation 74
# ++ Best 2.1385978095672247 for generation 76
# ++ Best 2.8950886534478233 for generation 88
# Step 100
# ++ Best 3.1136406384222375 for generation 143
# ++ Best 3.3345372587763866 for generation 146
# ++ Best 3.704817407339651 for generation 154
# OVER
# Final score 2.2359727783131147 +- 1.058293449813765
# expfit_nb5_i5
# Step 0
# ++ Best 0.3352095076769407 for generation 0
# ++ Best 0.4072268797370521 for generation 11
# ++ Best 0.6774207513771597 for generation 23
# ++ Best 0.804958158111337 for generation 71
# Step 100
# ++ Best 0.836589490125887 for generation 104
# ++ Best 0.8495627431955155 for generation 122
# ++ Best 0.8507286669592011 for generation 125
# ++ Best 0.8604278737897357 for generation 189
# OVER
# Final score 0.590015430908423 +- 0.35092588203364433
# expfit_nb5_i6
# Step 0
# ++ Best 0.16364101677374823 for generation 0
# ++ Best 0.16834308644101062 for generation 6
# ++ Best 0.3805513534222848 for generation 19
# ++ Best 0.4046762276172688 for generation 33
# ++ Best 0.4307432480160313 for generation 45
# ++ Best 0.6208259229778912 for generation 93
# Step 100
# ++ Best 0.670739669457079 for generation 116
# ++ Best 0.6777456564420893 for generation 145
# ++ Best 0.8986298429173128 for generation 156
# ++ Best 0.9743422494653223 for generation 160
# ++ Best 1.0197561178486343 for generation 181
# OVER
# Final score 0.7175915264110149 +- 0.23451685247685355
# expfit_nb5_i7
# Step 0
# ++ Best 0.19144135564662412 for generation 0
# ++ Best 0.27758620942239065 for generation 4
# ++ Best 0.2994791629032684 for generation 10
# ++ Best 0.3859972347696269 for generation 21
# ++ Best 0.39241448514953486 for generation 36
# ++ Best 0.40462316347976757 for generation 57
# ++ Best 0.4221774453000692 for generation 67
# ++ Best 0.6508909479224498 for generation 72
# ++ Best 0.8053650596243115 for generation 84
# Step 100
# ++ Best 0.8556176446215558 for generation 107
# ++ Best 0.9480337757825219 for generation 117
# ++ Best 0.9565919370199525 for generation 126
# ++ Best 0.9946215073747862 for generation 139
# ++ Best 1.0816193245792358 for generation 149
# ++ Best 1.1407872156684384 for generation 152
# OVER
# Final score 0.7379609266455107 +- 0.2797923197084683
# expfit_nb5_i8
# Step 0
# ++ Best 0.40406144716679737 for generation 0
# ++ Best 0.4417320892257844 for generation 21
# ++ Best 0.44892810367094355 for generation 24
# ++ Best 0.5882399671261044 for generation 31
# ++ Best 0.6086368580006474 for generation 47
# ++ Best 0.6308146251222265 for generation 75
# ++ Best 0.6613538604902558 for generation 81
# Step 100
# OVER
# Final score 0.3908157672914512 +- 0.11551326245915466
# expfit_nb5_i9
# Step 0
# ++ Best 0.07099810240694106 for generation 0
# ++ Best 0.07122137797185304 for generation 2
# ++ Best 0.7769029337012456 for generation 3
# ++ Best 0.7783279932140581 for generation 40
# ++ Best 0.965142277974262 for generation 44
# ++ Best 2.4521636340157396 for generation 62
# Step 100
# ++ Best 2.646144278912369 for generation 134
# ++ Best 3.7382562021286914 for generation 161
# ++ Best 4.122717586705957 for generation 165
# ++ Best 4.146138956548048 for generation 186
# OVER
# Final score 1.5959270769376255 +- 1.6719989778733042
# expfit_nb7_i0
# Step 0
# ++ Best 0.1692071848192197 for generation 0
# ++ Best 0.3173054702625521 for generation 5
# ++ Best 0.48169423552456836 for generation 13
# ++ Best 0.7727649541739835 for generation 14
# ++ Best 1.1910341043857935 for generation 44
# Step 100
# ++ Best 1.3372363975002861 for generation 108
# ++ Best 1.4618011322549789 for generation 114
# OVER
# Final score 0.42737203591646233 +- 0.31296882302345275
# expfit_nb7_i1
# Step 0
# ++ Best 0.10927090204460893 for generation 0
# ++ Best 1.1906116524708348 for generation 2
# ++ Best 1.381454819902585 for generation 20
# ++ Best 2.580547448476576 for generation 56
# ++ Best 2.8905139679536256 for generation 62
# Step 100
# ++ Best 3.006255356107468 for generation 180
# OVER
# Final score 1.235606460948015 +- 1.0570286466205008
# expfit_nb7_i2
# Step 0
# ++ Best 0.060703311319629596 for generation 0
# ++ Best 0.0607620868452736 for generation 2
# ++ Best 0.379147041739778 for generation 4
# ++ Best 0.6248118655384352 for generation 14
# ++ Best 0.8299988079982203 for generation 20
# ++ Best 0.8638689851742669 for generation 26
# ++ Best 0.954496753021342 for generation 55
# ++ Best 1.04107683630457 for generation 89
# ++ Best 1.1980269508058077 for generation 93
# Step 100
# ++ Best 2.6678056901634672 for generation 116
# ++ Best 3.4878936012364417 for generation 128
# ++ Best 3.627209322257939 for generation 140
# ++ Best 3.7992004562236734 for generation 150
# ++ Best 4.303030665662317 for generation 152
# OVER
# Final score 2.4477972779071324 +- 1.2593714997691772
# expfit_nb7_i3
# Step 0
# ++ Best 0.060096408325351666 for generation 0
# ++ Best 0.06105481942392089 for generation 1
# ++ Best 0.15713467208883172 for generation 4
# ++ Best 0.32775623030780116 for generation 9
# ++ Best 0.6778191468473913 for generation 13
# ++ Best 2.05966891965584 for generation 29
# Step 100
# ++ Best 3.478457555638406 for generation 106
# ++ Best 3.7358855956641834 for generation 121
# ++ Best 3.8834241844644106 for generation 139
# ++ Best 4.077918572086419 for generation 187
# OVER
# Final score 1.5478438644418684 +- 0.9731500101020158
# expfit_nb7_i4
# Step 0
# ++ Best 0.06057236535107255 for generation 0
# ++ Best 0.06065658598001987 for generation 1
# ++ Best 0.17033977304085654 for generation 2
# ++ Best 0.19427893019460962 for generation 3
# ++ Best 0.372399617464168 for generation 4
# ++ Best 0.9750181109238862 for generation 14
# ++ Best 2.4515676290910813 for generation 34
# Step 100
# OVER
# Final score 0.48848918854102175 +- 0.19559930774310358
# expfit_nb7_i5
# Step 0
# ++ Best 0.0601424324335304 for generation 0
# ++ Best 0.1384702526795531 for generation 1
# ++ Best 0.14252836616602518 for generation 2
# ++ Best 0.18882685695684895 for generation 3
# ++ Best 0.3789308491651364 for generation 5
# ++ Best 0.5639058267360507 for generation 6
# ++ Best 0.7115711886411473 for generation 35
# ++ Best 0.9166405291826036 for generation 73
# Step 100
# ++ Best 2.0581044034421097 for generation 105
# ++ Best 2.3284186835669374 for generation 123
# ++ Best 2.375758738183832 for generation 164
# ++ Best 3.036127852057807 for generation 183
# OVER
# Final score 0.5948036934856008 +- 0.4370316462638102
# expfit_nb7_i6
# Step 0
# ++ Best 0.060851868720882094 for generation 0
# ++ Best 0.49720005492215746 for generation 1
# ++ Best 0.5853086794904798 for generation 5
# ++ Best 0.6539869858777142 for generation 30
# ++ Best 1.6831841786255413 for generation 41
# Step 100
# OVER
# Final score 0.3707348752837836 +- 0.25502319656850236
# expfit_nb7_i7
# Step 0
# ++ Best 0.3537418607715502 for generation 0
# ++ Best 0.5146799985593872 for generation 7
# ++ Best 0.6309766710299907 for generation 13
# ++ Best 0.6523294241506533 for generation 19
# ++ Best 0.6646191016865768 for generation 22
# ++ Best 0.7571011860538175 for generation 26
# ++ Best 0.8547417183310215 for generation 45
# ++ Best 0.9394040338827445 for generation 59
# ++ Best 0.9639693695820678 for generation 75
# ++ Best 1.1601401376575873 for generation 79
# Step 100
# ++ Best 2.218624671131703 for generation 117
# OVER
# Final score 0.4664320076723113 +- 0.8665256519868549
# expfit_nb7_i8
# Step 0
# ++ Best 0.060273100672394636 for generation 0
# ++ Best 0.060566385379354964 for generation 1
# ++ Best 0.27674251268778993 for generation 2
# ++ Best 0.4296075925486922 for generation 9
# ++ Best 0.6747026715555894 for generation 20
# ++ Best 0.7439998934613018 for generation 23
# ++ Best 0.9612494470303184 for generation 25
# ++ Best 0.9633561002792862 for generation 45
# ++ Best 2.9139937412376797 for generation 79
# Step 100
# ++ Best 3.2242334497542746 for generation 117
# ++ Best 3.26511808634854 for generation 119
# ++ Best 3.2847371469645217 for generation 135
# OVER
# Final score 1.2720055587344012 +- 1.1190483867158112
# expfit_nb7_i9
# Step 0
# ++ Best 0.07019242751421345 for generation 0
# ++ Best 0.08643188402787742 for generation 1
# ++ Best 0.19833278693823764 for generation 2
# ++ Best 0.4341961082420287 for generation 9
# ++ Best 0.7846918084090136 for generation 16
# ++ Best 0.8869525556210012 for generation 41
# ++ Best 1.4088167985097686 for generation 54
# ++ Best 2.7310430275548763 for generation 84
# ++ Best 2.806269533174753 for generation 98
# Step 100
# ++ Best 3.384293005464329 for generation 107
# OVER
# Final score 1.7604486211936652 +- 0.7263548716838361

# %%
show_curve(sol.stats, REF.stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-30abeee9d69e> in <module>
# ----> 1 show_curve(sol.stats, REF.stats)
#
# NameError: name 'sol' is not defined

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#   genes  i      mean        sd       max
# 0     7  5  0.594804  0.437032  3.036128
# 1     4  4  1.680838  1.036697  4.249200
# 2     7  1  1.235606  1.057029  3.006255
# 3     5  9  1.595927  1.671999  4.146139
# 4     3  4  0.573405  0.245893  0.948114

# %%
df.groupby(["genes"]).mean()
# Out:
#            mean        sd       max
# genes
# 3      1.053601  0.617589  2.537976
# 4      1.271066  0.588747  2.568906
# 5      0.871713  0.605565  2.070164
# 7      1.061153  0.720210  2.890754
