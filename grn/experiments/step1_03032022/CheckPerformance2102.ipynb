# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + s_all + s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=False, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = [p**prun.exponent for p in pop_fit]
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=59, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="4", start_time=59, end_time=62, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="5", start_time=62, end_time=65, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="6", start_time=65, end_time=68, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="7", start_time=68, end_time=71, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="8", start_time=71, end_time=74, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="9", start_time=74, end_time=77, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="10", start_time=77, end_time=80, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="11", start_time=80, end_time=83, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="12", start_time=83, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 20
    max_pop = 50

def get_prun(size=7, exponent=2):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 10,  # maybe 10 is too much
    expr=lambda: np.random.beta(1.5, 3) * 3,
    deg=lambda: np.random.beta(1.5, 3) * 1,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "checkperf_2102_v1"
res = main(prun)
# Out:
# Exporting at output/checkperf_2102_v1
# [definition]
#
#
# [reload] Found generation 5
# Step 3 passed !
# Step 4 passed !
# Step 5 passed !
# Step 6 passed !
# Step 7 passed !
# Step 8 passed !
# [out] Step 300
# [out] ++ Best 2.6128885785945917 for generation 300
# Step 9 passed !
# [out] ++ Best 3.513259079018485 for generation 301
# Step 10 passed !
# Step 11 passed !
# [out] ++ Best 4.587274144268434 for generation 305
# Step 12 passed !
# [out] ++ Best 5.232951933868733 for generation 330
# Saving ...
# [out] ++ Best 5.4108663059576365 for generation 351
# Saving ...
# [out] Step 400
# Saving ...
# [out] ++ Best 5.8204520054969455 for generation 469
# Saving ...
# [out] Step 500
# Saving ...
# [out] ++ Best 5.837725444925925 for generation 580
# Saving ...
# [out] Step 600
# Saving ...
# [out] ++ Best 5.968963754235882 for generation 671
# Saving ...
# [out] Step 700
# Saving ...
# Saving ...
# [out] Step 800
# [out] ++ Best 6.066187733737007 for generation 814
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# [out] ++ Best 6.109761677014345 for generation 1068
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# Saving ...
# [out] Step 1300
# [out] ++ Best 6.3798848835373105 for generation 1311
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/checkperf_2102_v1

# %%
def pick_last(exp, sm=None):
    if sm is None:
        sm = read_model("generation")
    return sm.pick_last(sorted(exp.list()), slot="generation")

def pick_best(res):
    return res[res.index(max(res, key=lambda x: x.fit))]

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
res

# %%
show_curve(res.stats, REF.stats)

# %%
res.grn
# Out:
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.33; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.90; asym: 3.44; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 6.27; expr: 0.49; deg: 0.41; theta: 10.07; asym: 2.89; tree : NOT (0 AND (2 AND 4))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 12.58; asym: 5.34; tree : NOT NOT (NOT 3 OR 2)
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.65; asym: 3.01; tree : NOT NOT 1

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 9.61; asym: 4.75; tree : (4 OR NOT 2)
# >> G_1: init: 1.59; noise: 5.55; b: 3.93; m: 9.50; expr: 0.35; deg: 0.17; theta: 2.47; asym: 6.05; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 4.90; asym: 5.70; tree : (5 OR (0 AND 3))
# >> G_3: init: 0.86; noise: 0.74; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 9.74; asym: 7.63; tree : 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 0.57; theta: 5.35; asym: 6.04; tree : ((2 OR 5) AND 1)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 8.50; asym: 4.75; tree : (4 OR NOT 2)
# >> G_1: init: 1.59; noise: 5.55; b: 3.93; m: 9.50; expr: 0.35; deg: 0.17; theta: 2.47; asym: 6.05; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 4.68; asym: 5.70; tree : (5 OR (0 AND 3))
# >> G_3: init: 0.86; noise: 0.74; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 9.74; asym: 7.63; tree : 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 0.57; theta: 5.47; asym: 6.04; tree : (0 AND 1)
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 7.86; asym: 3.35; tree : (4 OR NOT 2)
# >> G_1: init: 1.59; noise: 5.55; b: 3.93; m: 9.50; expr: 0.35; deg: 0.17; theta: 2.47; asym: 6.05; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 5.27; asym: 5.70; tree : (5 OR (0 AND 3))
# >> G_3: init: 0.86; noise: 0.74; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 9.74; asym: 7.63; tree : 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 2.00; deg: 0.57; theta: 5.96; asym: 6.04; tree : (2 AND 1)
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.27; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.59; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.08; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 5.76; asym: 5.70; tree : (4 OR (0 AND 3))
# >> G_3: init: 0.86; noise: 0.74; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 10.21; asym: 7.63; tree : NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 5.17; asym: 4.99; tree : ((5 OR 4) AND 1)
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.27; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.59; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.08; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 3.51; expr: 0.49; deg: 0.26; theta: 5.76; asym: 5.70; tree : (4 OR (1 AND 3))
# >> G_3: init: 0.86; noise: 0.74; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 12.43; asym: 7.63; tree : NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 5.12; asym: 4.99; tree : ((5 OR 4) AND 1)
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.27; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.59; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.04; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 6.68; asym: 4.63; tree : (4 OR (1 AND 2))
# >> G_3: init: 0.86; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 10.68; asym: 7.63; tree : NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.66; asym: 4.99; tree : (5 AND 1)
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 12.44; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.59; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.04; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 6.68; asym: 4.63; tree : (4 OR (1 AND 2))
# >> G_3: init: 0.86; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 10.68; asym: 7.63; tree : NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.66; asym: 4.99; tree : (5 AND NOT 1)
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.27; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.59; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.32; asym: 4.28; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 6.68; asym: 4.63; tree : (4 OR (1 AND 2))
# >> G_3: init: 1.73; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 10.68; asym: 7.63; tree : NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.66; asym: 4.99; tree : 5
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 12.44; asym: 4.75; tree : NOT 5
# >> G_1: init: 1.59; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 2.58; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 7.14; asym: 4.63; tree : (4 OR (0 AND 2))
# >> G_3: init: 0.86; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 10.68; asym: 7.63; tree : NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.66; asym: 4.99; tree : (5 AND NOT 1)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.40; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.63; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 8.15; asym: 4.63; tree : NOT (1 AND 2)
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 13.68; asym: 7.63; tree : NOT NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.66; asym: 4.20; tree : (5 AND NOT 1)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 12.12; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 2.89; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 8.15; asym: 4.63; tree : NOT (1 AND 2)
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 15.66; asym: 7.63; tree : NOT NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.66; asym: 4.20; tree : (5 AND NOT 1)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.33; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.51; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 7.97; asym: 4.63; tree : NOT (1 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 11.97; asym: 6.29; tree : NOT NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.57; asym: 3.56; tree : (5 AND NOT 1)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 12.64; asym: 4.08; tree : ((4 AND 1) OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.51; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 7.94; asym: 4.63; tree : NOT (1 AND 2)
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 11.97; asym: 5.11; tree : NOT NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.57; asym: 4.20; tree : (5 AND NOT 1)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 15.81; asym: 4.75; tree : NOT 5
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.51; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 7.97; asym: 4.63; tree : NOT (1 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 11.33; asym: 5.13; tree : NOT NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.59; asym: 3.56; tree : (5 AND NOT NOT 1)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.33; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 4.20; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 8.51; asym: 3.96; tree : NOT (0 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 11.33; asym: 6.29; tree : NOT NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.43; asym: 3.56; tree : NOT 1
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 15.31; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 4.86; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.26; theta: 8.51; asym: 3.96; tree : NOT (0 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 11.33; asym: 6.29; tree : NOT NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.43; asym: 3.04; tree : NOT 1
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.33; asym: 4.02; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.70; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.41; theta: 9.91; asym: 3.96; tree : NOT (0 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 8.69; asym: 5.22; tree : NOT NOT 3
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.41; asym: 3.56; tree : NOT 1
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.28; asym: 4.75; tree : ((4 OR NOT 5) OR 0)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.70; asym: 4.20; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.41; theta: 8.70; asym: 3.96; tree : NOT (0 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 12.12; asym: 6.29; tree : NOT NOT 3
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.43; asym: 3.01; tree : NOT NOT 1
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 14.29; asym: 4.02; tree : (NOT 5 OR 2)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.63; asym: 5.23; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 1.56; m: 4.32; expr: 0.49; deg: 0.26; theta: 9.19; asym: 4.63; tree : (NOT 2 OR 3)
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 12.70; asym: 6.29; tree : NOT NOT 4
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.08; expr: 0.60; deg: 2.92; theta: 5.16; asym: 3.56; tree : ((5 OR 2) AND NOT 1)
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 12.82; asym: 4.11; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.70; asym: 4.20; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 4.32; expr: 0.49; deg: 0.41; theta: 8.48; asym: 3.37; tree : NOT (0 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 12.12; asym: 6.29; tree : NOT NOT 3
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.65; asym: 3.01; tree : NOT NOT 1
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 12.73; asym: 4.75; tree : ((4 OR NOT 5) OR 3)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.70; asym: 4.20; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 6.27; expr: 0.49; deg: 0.41; theta: 7.68; asym: 3.37; tree : NOT (0 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 10.82; asym: 6.29; tree : NOT NOT 2
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.65; asym: 3.01; tree : NOT NOT 1
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 12.73; asym: 3.98; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 4.28; asym: 4.20; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 6.27; expr: 0.49; deg: 0.41; theta: 9.13; asym: 3.37; tree : NOT (0 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 11.81; asym: 6.29; tree : NOT NOT 5
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.65; asym: 3.01; tree : NOT NOT 1
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.45; asym: 3.98; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 4.28; asym: 4.20; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 6.27; expr: 0.49; deg: 0.41; theta: 11.48; asym: 2.73; tree : NOT (0 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 11.81; asym: 6.29; tree : NOT NOT 5
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.39; asym: 3.01; tree : NOT NOT 1
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 14.09; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.48; asym: 4.20; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 6.27; expr: 0.49; deg: 0.41; theta: 10.89; asym: 2.89; tree : NOT (0 AND (2 AND 5))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 10.82; asym: 4.33; tree : NOT NOT (NOT 3 OR 2)
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.65; asym: 3.01; tree : NOT NOT 1
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 14.11; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.46; asym: 4.20; tree : NOT 0
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 6.27; expr: 0.49; deg: 0.41; theta: 10.49; asym: 2.89; tree : NOT (0 AND (2 AND 4))
# >> G_3: init: 1.52; noise: 9.81; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 10.61; asym: 6.29; tree : NOT NOT (NOT 3 OR 2)
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.65; asym: 3.01; tree : NOT (NOT 1 AND 2)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.34; noise: 7.69; b: 3.07; m: 5.04; expr: 1.17; deg: 0.16; theta: 13.33; asym: 4.75; tree : (4 OR NOT 5)
# >> G_1: init: 1.51; noise: 5.55; b: 3.93; m: 3.38; expr: 0.35; deg: 0.17; theta: 3.90; asym: 3.44; tree : NOT 3
# >> G_2: init: 0.46; noise: 2.10; b: 0.67; m: 6.27; expr: 0.49; deg: 0.41; theta: 10.07; asym: 2.89; tree : NOT (0 AND (2 AND 4))
# >> G_3: init: 1.52; noise: 0.09; b: 1.24; m: 7.22; expr: 2.07; deg: 0.54; theta: 12.58; asym: 5.34; tree : NOT NOT (NOT 3 OR 2)
# >> G_4: init: 0.47; noise: 0.77; b: 3.45; m: 5.95; expr: 0.60; deg: 2.92; theta: 4.65; asym: 3.01; tree : NOT NOT 1
