# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
import random
from lib.sde.mutate import mutate_gene4, mutate_tree

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None, nb_genes=4):
    return Solution(GRNMain(nb_genes, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
_MUTATE_FUNC = mutate_grn

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        global _MUTATE_FUNC
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + s_all + s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=False, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init),
                                  new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    ObjectiveStep(name="The ONE", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 30
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 25
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, name=None):
    args = get_prun()
    args.cb_init = cb_init
    args.name = name
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    print("Final score", np.mean(scores), "+-", np.std(scores))
    return np.mean(scores), np.std(scores), max(p1)

# %%
def mutate_grn_ctrl(grn):
    grn.set_mutable()
    one_gene = random.choice(grn.genes)
    mutate_gene4(one_gene)
    grn.compile()
    
def mutate_grn_sparse(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.8)
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()
    
def mutate_grn_verysparse(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.9)
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()
    
def mutate_grn_full(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        grn._params *= np.random.normal(1, temperature, shape)
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()

# %%
model = sm.StringModel("expfit_func{mutfunc}_i{i}")
mut_func = dict(
    ctrl=mutate_grn_ctrl,
    sparse=mutate_grn_sparse,
    verysparse=mutate_grn_verysparse,
    full=mutate_grn_full,
)

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
)

# %%
# main loop
exporter = Exporter(name="exp_mutfunc3_230222")
for (funcname, func), i in product(mut_func.items(), range(10)):
    name = model.fill(mutfunc=funcname, i=i)
    print(name)
    if name in exporter.list():
        continue
    _MUTATE_FUNC = func
    res = get_score_parametrized(callback_init)
    exporter(res, name)
# Out:
# Exporting at output/exp_mutfunc3_230222
# expfit_funcctrl_i0
# Step 0
# ++ Best 0.005715428951530896 for generation 0
# ++ Best 0.005717727757418606 for generation 2
# ++ Best 0.00903301778664776 for generation 3
# ++ Best 0.010018540040037816 for generation 6
# ++ Best 0.010216879072348984 for generation 53
# ++ Best 0.01125002015449634 for generation 91
# Step 100
# ++ Best 0.011376569547146295 for generation 112
# ++ Best 0.011850887053174056 for generation 115
# Step 200
# ++ Best 0.021084118259025078 for generation 210
# ++ Best 0.02184160031628033 for generation 219
# ++ Best 0.026443004200953198 for generation 230
# OVER
# Final score 0.02455257532108739 +- 0.002109797062907628
# expfit_funcctrl_i1
# Step 0
# ++ Best 0.005847987235910127 for generation 0
# ++ Best 0.007623905097063736 for generation 1
# ++ Best 0.010371654890096537 for generation 13
# ++ Best 0.010953215856505725 for generation 44
# ++ Best 0.011755230494852484 for generation 63
# ++ Best 0.011989349445361517 for generation 74
# ++ Best 0.01379693747247644 for generation 76
# Step 100
# Step 200
# ++ Best 0.01481906430702123 for generation 298
# OVER
# Final score 0.012878650735950703 +- 0.0009043692981268995
# expfit_funcctrl_i2
# Step 0
# ++ Best 0.005628698924941984 for generation 0
# ++ Best 0.0057123324407055915 for generation 1
# ++ Best 0.005791125435635069 for generation 5
# ++ Best 0.006522382305287185 for generation 10
# ++ Best 0.010193297769106125 for generation 14
# ++ Best 0.010206319041623585 for generation 23
# ++ Best 0.0128985834909822 for generation 25
# ++ Best 0.01440092573687661 for generation 37
# ++ Best 0.01627417643920199 for generation 99
# Step 100
# ++ Best 0.020955416485829683 for generation 127
# Step 200
# OVER
# Final score 0.02967216166224118 +- 0.010928941846477773
# expfit_funcctrl_i3
# Step 0
# ++ Best 0.0031917565565026053 for generation 0
# ++ Best 0.005959052908973959 for generation 1
# ++ Best 0.008830531793772354 for generation 5
# ++ Best 0.009409448453743436 for generation 14
# ++ Best 0.00947112777688594 for generation 18
# ++ Best 0.009973749467433577 for generation 19
# ++ Best 0.015381271509284406 for generation 24
# ++ Best 0.017492312267480863 for generation 30
# ++ Best 0.02383178336455931 for generation 36
# Step 100
# Step 200
# OVER
# Final score 0.01074003475561911 +- 0.00805247738105622
# expfit_funcctrl_i4
# Step 0
# ++ Best 0.005618976491540063 for generation 0
# ++ Best 0.005893570473329155 for generation 1
# ++ Best 0.00755583854947451 for generation 3
# ++ Best 0.0296707755378315 for generation 4
# ++ Best 0.03905120520561823 for generation 68
# ++ Best 0.046014246658687995 for generation 98
# Step 100
# ++ Best 0.04654953475273422 for generation 118
# Step 200
# OVER
# Final score 0.017406749059233385 +- 0.013490419933511423
# expfit_funcctrl_i5
# Step 0
# ++ Best 0.005639027076397544 for generation 0
# ++ Best 0.005701974885452601 for generation 1
# ++ Best 0.00642525260221359 for generation 2
# ++ Best 0.006660581038244579 for generation 11
# ++ Best 0.00856206913357358 for generation 16
# ++ Best 0.01118978312351559 for generation 22
# Step 100
# ++ Best 0.011403852453877577 for generation 113
# ++ Best 0.012217359137953868 for generation 115
# Step 200
# ++ Best 0.014351806114643652 for generation 227
# ++ Best 0.014786736277631623 for generation 286
# OVER
# Final score 0.013903254464090678 +- 0.0009341653761662536
# expfit_funcctrl_i6
# Step 0
# ++ Best 0.003440595297483264 for generation 0
# ++ Best 0.0036801875596214877 for generation 1
# ++ Best 0.009545126986606292 for generation 2
# ++ Best 0.010156582693890049 for generation 3
# ++ Best 0.0103075492474531 for generation 47
# Step 100
# ++ Best 0.010404521152943186 for generation 115
# ++ Best 0.010666898121564832 for generation 122
# ++ Best 0.011611074831037063 for generation 145
# ++ Best 0.01203201517305802 for generation 176
# Step 200
# OVER
# Final score 0.013057670882598727 +- 0.0006679240582894644
# expfit_funcctrl_i7
# Step 0
# ++ Best 0.0040754784438835805 for generation 0
# ++ Best 0.005878051425992243 for generation 1
# ++ Best 0.00899512249586236 for generation 7
# ++ Best 0.01030127336833279 for generation 13
# Step 100
# ++ Best 0.01273607229799121 for generation 148
# ++ Best 0.012843338782926128 for generation 194
# Step 200
# ++ Best 0.02044717036680453 for generation 203
# OVER
# Final score 0.01646890437395751 +- 0.004158355975612002
# expfit_funcctrl_i8
# Step 0
# ++ Best 0.005618976491540063 for generation 0
# ++ Best 0.00580235836429748 for generation 1
# ++ Best 0.010002448835376295 for generation 3
# ++ Best 0.013497872711859857 for generation 9
# ++ Best 0.016122069677849963 for generation 92
# Step 100
# ++ Best 0.061547808772546606 for generation 199
# Step 200
# ++ Best 0.06313259182548937 for generation 245
# OVER
# Final score 0.03584953825744114 +- 0.016708536399521603
# expfit_funcctrl_i9
# Step 0
# ++ Best 0.0033888950236137267 for generation 0
# ++ Best 0.005631080902219972 for generation 1
# ++ Best 0.005717065679027624 for generation 3
# ++ Best 0.009776710305473104 for generation 4
# ++ Best 0.011806593264674243 for generation 8
# ++ Best 0.032753665965353486 for generation 13
# Step 100
# Step 200
# OVER
# Final score 0.013457279657201327 +- 0.007389782334786535
# expfit_funcsparse_i0
# Step 0
# ++ Best 0.005640475015687841 for generation 0
# ++ Best 0.005791671070362545 for generation 2
# ++ Best 0.01033342159944087 for generation 6
# ++ Best 0.021459879879410854 for generation 42
# ++ Best 0.02692327563487373 for generation 87
# Step 100
# Step 200
# OVER
# Final score 0.010379521963851194 +- 0.004148775694260143
# expfit_funcsparse_i1
# Step 0
# ++ Best 0.005803915069171869 for generation 0
# ++ Best 0.005901237072178215 for generation 2
# ++ Best 0.0065868202259849115 for generation 7
# ++ Best 0.00899688263259016 for generation 8
# ++ Best 0.009376170060812424 for generation 11
# ++ Best 0.010226116303525925 for generation 15
# ++ Best 0.010744224893775493 for generation 48
# ++ Best 0.013477428338985017 for generation 64
# Step 100
# Step 200
# OVER
# Final score 0.01924802824762631 +- 0.00324741656629835
# expfit_funcsparse_i2
# Step 0
# ++ Best 0.0062229201764033215 for generation 0
# ++ Best 0.009147723834001567 for generation 3
# ++ Best 0.011702776364263888 for generation 7
# ++ Best 0.012748019186918043 for generation 13
# ++ Best 0.016572214727412164 for generation 47
# ++ Best 0.05121258767053708 for generation 81
# Step 100
# Step 200
# OVER
# Final score 0.042761592597310924 +- 0.01117411279732605
# expfit_funcsparse_i3
# Step 0
# ++ Best 0.004727882143503933 for generation 0
# ++ Best 0.0057494326239801215 for generation 1
# ++ Best 0.006379458991479752 for generation 4
# ++ Best 0.006477313331050703 for generation 8
# ++ Best 0.007335410679140981 for generation 14
# ++ Best 0.009568031575829132 for generation 15
# ++ Best 0.010246110796391877 for generation 21
# ++ Best 0.010660908302146792 for generation 64
# ++ Best 0.011256796853846795 for generation 96
# Step 100
# ++ Best 0.012673566322666776 for generation 148
# ++ Best 0.018033502692154636 for generation 153
# ++ Best 0.027698556481280466 for generation 154
# Step 200
# OVER
# Final score 0.017380482610829542 +- 0.006565877829471669
# expfit_funcsparse_i4
# Step 0
# ++ Best 0.0036578773603505783 for generation 0
# ++ Best 0.005638492992581882 for generation 1
# ++ Best 0.006417885899373093 for generation 3
# ++ Best 0.009087204816768953 for generation 10
# ++ Best 0.009820747422078752 for generation 13
# ++ Best 0.010426015993418672 for generation 38
# ++ Best 0.045494007873715714 for generation 50
# ++ Best 0.0464799021629939 for generation 76
# Step 100
# ++ Best 0.056150631195771045 for generation 107
# Step 200
# ++ Best 0.0661686304364939 for generation 243
# OVER
# Final score 0.02788678760320753 +- 0.012867945763238044
# expfit_funcsparse_i5
# Step 0
# ++ Best 0.006171750992106744 for generation 0
# ++ Best 0.011438385809013695 for generation 5
# ++ Best 0.04274482526331317 for generation 46
# Step 100
# ++ Best 0.06383520330791292 for generation 106
# Step 200
# OVER
# Final score 0.01965348155356674 +- 0.01832810679207193
# expfit_funcsparse_i6
# Step 0
# ++ Best 0.005626799342454625 for generation 0
# ++ Best 0.005804725877054076 for generation 1
# ++ Best 0.005982073568042002 for generation 2
# ++ Best 0.010715141896753606 for generation 13
# Step 100
# ++ Best 0.013750683154531491 for generation 119
# ++ Best 0.05411160854281474 for generation 172
# Step 200
# OVER
# Final score 0.006029904290375132 +- 0.0011246143979371686
# expfit_funcsparse_i7
# Step 0
# ++ Best 0.005711927419592091 for generation 0
# ++ Best 0.00764269484907617 for generation 1
# ++ Best 0.009478131557446723 for generation 12
# ++ Best 0.012077726315202281 for generation 28
# ++ Best 0.01421144390591733 for generation 92
# Step 100
# Step 200
# ++ Best 0.016266237709501682 for generation 242
# OVER
# Final score 0.012494848828523128 +- 0.0045685199818611966
# expfit_funcsparse_i8
# Step 0
# ++ Best 0.005720331719419822 for generation 0
# ++ Best 0.006155928452438346 for generation 1
# ++ Best 0.008529759571630782 for generation 5
# ++ Best 0.009103066118785126 for generation 8
# ++ Best 0.009902929334553952 for generation 39
# ++ Best 0.011263230206404986 for generation 42
# Step 100
# ++ Best 0.013015793629332605 for generation 144
# Step 200
# ++ Best 0.02409528988505409 for generation 210
# OVER
# Final score 0.006483965772128286 +- 0.0014355294855473745
# expfit_funcsparse_i9
# Step 0
# ++ Best 0.005634747959912927 for generation 0
# ++ Best 0.00563657164871351 for generation 1
# ++ Best 0.007532196482296633 for generation 3
# ++ Best 0.008305823706256195 for generation 12
# ++ Best 0.009224216765007173 for generation 30
# ++ Best 0.010821670004289593 for generation 35
# ++ Best 0.011266709677869297 for generation 45
# ++ Best 0.011899126755387618 for generation 51
# ++ Best 0.017734174963433984 for generation 62
# ++ Best 0.026661351984271223 for generation 65
# ++ Best 0.02743023079326625 for generation 80
# Step 100
# ++ Best 0.04610366651606686 for generation 113
# Step 200
# OVER
# Final score 0.0324964424939094 +- 0.009701625974705218
# expfit_funcverysparse_i0
# Step 0
# ++ Best 0.005634839948365909 for generation 0
# ++ Best 0.005712750983743262 for generation 1
# ++ Best 0.010210864002623837 for generation 2
# ++ Best 0.012285054438743677 for generation 30
# Step 100
# ++ Best 0.014467073659527463 for generation 166
# Step 200
# ++ Best 0.014497243570595435 for generation 208
# OVER
# Final score 0.015107769213083664 +- 0.0010583969410920629
# expfit_funcverysparse_i1
# Step 0
# ++ Best 0.009757358052485624 for generation 0
# ++ Best 0.025622011286525016 for generation 4
# Step 100
# Step 200
# OVER
# Final score 0.00804690352514657 +- 0.0037814901510584437
# expfit_funcverysparse_i2
# Step 0
# ++ Best 0.005254219146748621 for generation 0
# ++ Best 0.005634885461360977 for generation 1
# ++ Best 0.00824542500948138 for generation 2
# ++ Best 0.009958704626583685 for generation 3
# ++ Best 0.010217756295485016 for generation 6
# ++ Best 0.014115310904134091 for generation 29
# Step 100
# Step 200
# OVER
# Final score 0.014382925993018112 +- 0.00039269855643058995
# expfit_funcverysparse_i3
# Step 0
# ++ Best 0.0056262621343962154 for generation 0
# ++ Best 0.0058074919708448035 for generation 1
# ++ Best 0.00587019215543682 for generation 5
# ++ Best 0.00595619384337639 for generation 6
# ++ Best 0.005986179360585877 for generation 7
# ++ Best 0.008880082452548621 for generation 11
# ++ Best 0.009435251142066899 for generation 12
# ++ Best 0.009616500885415229 for generation 33
# ++ Best 0.009708472385864066 for generation 38
# Step 100
# ++ Best 0.009822335052424924 for generation 116
# ++ Best 0.011276820478919869 for generation 147
# Step 200
# ++ Best 0.016200822335046643 for generation 231
# OVER
# Final score 0.012110645174647373 +- 0.0017411244932413758
# expfit_funcverysparse_i4
# Step 0
# ++ Best 0.004112907203018694 for generation 0
# ++ Best 0.005779272259663098 for generation 1
# ++ Best 0.005956828184657029 for generation 2
# ++ Best 0.007708774106061685 for generation 4
# ++ Best 0.008739365597316107 for generation 12
# ++ Best 0.008850333472505266 for generation 24
# ++ Best 0.010460985243296504 for generation 46
# ++ Best 0.010809973543171338 for generation 61
# ++ Best 0.010855846057733395 for generation 82
# ++ Best 0.011086484808237465 for generation 95
# Step 100
# ++ Best 0.02099225251956734 for generation 116
# ++ Best 0.02258995984744023 for generation 120
# ++ Best 0.03209603800718534 for generation 148
# ++ Best 0.04743902474691674 for generation 152
# Step 200
# ++ Best 0.05498873258039946 for generation 202
# ++ Best 0.05913925742336884 for generation 214
# ++ Best 0.06116990203346353 for generation 235
# OVER
# Final score 0.03557748023458061 +- 0.015661495101752937
# expfit_funcverysparse_i5
# Step 0
# ++ Best 0.005634839948365909 for generation 0
# ++ Best 0.005638069243862199 for generation 1
# ++ Best 0.0058959172466565915 for generation 2
# ++ Best 0.009007133551836397 for generation 6
# ++ Best 0.010571246823871247 for generation 12
# ++ Best 0.018372383191071404 for generation 24
# Step 100
# ++ Best 0.044193716833487 for generation 186
# ++ Best 0.04603042229808341 for generation 187
# ++ Best 0.05617076001700176 for generation 193
# Step 200
# ++ Best 0.05645649121927764 for generation 219
# ++ Best 0.061404058093079576 for generation 229
# OVER
# Final score 0.04924077904001766 +- 0.015370251208885728
# expfit_funcverysparse_i6
# Step 0
# ++ Best 0.005618976491540063 for generation 0
# ++ Best 0.005720941753385237 for generation 1
# ++ Best 0.006865443080869856 for generation 4
# ++ Best 0.009818911858737208 for generation 7
# ++ Best 0.013506559517851319 for generation 34
# Step 100
# Step 200
# OVER
# Final score 0.010986308083483777 +- 0.002083118333800708
# expfit_funcverysparse_i7
# Step 0
# ++ Best 0.0058892653580885305 for generation 0
# ++ Best 0.008471736256284645 for generation 1
# ++ Best 0.010183548835848624 for generation 4
# ++ Best 0.01039537050756443 for generation 34
# ++ Best 0.036435883502105346 for generation 36
# ++ Best 0.05881738578195716 for generation 46
# ++ Best 0.06587447053979315 for generation 70
# Step 100
# ++ Best 0.06871674190348633 for generation 121
# Step 200
# ++ Best 0.071551669222298 for generation 206
# OVER
# Final score 0.03530996237372273 +- 0.013836927617331662
# expfit_funcverysparse_i8
# Step 0
# ++ Best 0.005770219293293484 for generation 0
# ++ Best 0.010531965667023021 for generation 2
# ++ Best 0.010940899431466047 for generation 39
# Step 100
# Step 200
# ++ Best 0.011561028595264226 for generation 284
# ++ Best 0.011563683905928818 for generation 290
# OVER
# Final score 0.011106863216045967 +- 0.0003683235731021268
# expfit_funcverysparse_i9
# Step 0
# ++ Best 0.007321450513775336 for generation 0
# ++ Best 0.01021444138970751 for generation 12
# ++ Best 0.032924692032399484 for generation 56
# Step 100
# Step 200
# OVER
# Final score 0.019763394005261642 +- 0.008035062394972769
# expfit_funcfull_i0
# Step 0
# ++ Best 0.005701608907352313 for generation 0
# ++ Best 0.011121098764737257 for generation 1
# ++ Best 0.011995903703153272 for generation 12
# ++ Best 0.01791268605610813 for generation 97
# Step 100
# Step 200
# OVER
# Final score 0.012276232988917626 +- 0.005564753993301881
# expfit_funcfull_i1
# Step 0
# ++ Best 0.005865317272813408 for generation 0
# ++ Best 0.007447192409832289 for generation 1
# ++ Best 0.009367567417680717 for generation 7
# ++ Best 0.010493784084880673 for generation 9
# ++ Best 0.028579121764378688 for generation 68
# Step 100
# Step 200
# OVER
# Final score 0.008688573553636492 +- 0.0022569331774869718
# expfit_funcfull_i2
# Step 0
# ++ Best 0.005638135026477158 for generation 0
# ++ Best 0.005720488075578031 for generation 2
# ++ Best 0.005872792909968649 for generation 3
# ++ Best 0.006108040902645406 for generation 5
# ++ Best 0.007563188471718777 for generation 9
# ++ Best 0.008501270214560831 for generation 12
# ++ Best 0.01030729363037776 for generation 15
# ++ Best 0.013725497085768515 for generation 36
# ++ Best 0.028139881512820573 for generation 41
# Step 100
# Step 200
# ++ Best 0.031052545302818667 for generation 272
# OVER
# Final score 0.007727231712682002 +- 0.0021358844852503445
# expfit_funcfull_i3
# Step 0
# ++ Best 0.005634839948365909 for generation 0
# ++ Best 0.006594577404027561 for generation 1
# ++ Best 0.009859748030592223 for generation 2
# ++ Best 0.010822657300490037 for generation 60
# ++ Best 0.011347626206910676 for generation 67
# ++ Best 0.012628740592936272 for generation 76
# Step 100
# ++ Best 0.013005663631076119 for generation 102
# ++ Best 0.020976722949999534 for generation 149
# Step 200
# OVER
# Final score 0.010194072013494218 +- 0.012263204814164584
# expfit_funcfull_i4
# Step 0
# ++ Best 0.005794492063946396 for generation 0
# ++ Best 0.008375652125471015 for generation 2
# ++ Best 0.009235042264173864 for generation 8
# ++ Best 0.01000812097122276 for generation 40
# ++ Best 0.01033611756244248 for generation 60
# ++ Best 0.010887555684662483 for generation 69
# Step 100
# ++ Best 0.010933203511005764 for generation 123
# ++ Best 0.01334322101482423 for generation 133
# Step 200
# OVER
# Final score 0.00591808609252857 +- 0.0001349184742733966
# expfit_funcfull_i5
# Step 0
# ++ Best 0.005712240911041066 for generation 0
# ++ Best 0.009965724527316302 for generation 1
# ++ Best 0.01589109160137164 for generation 69
# Step 100
# Step 200
# ++ Best 0.02294992453146809 for generation 275
# OVER
# Final score 0.021508306699137225 +- 0.00524595374163695
# expfit_funcfull_i6
# Step 0
# ++ Best 0.005715759034982413 for generation 0
# ++ Best 0.005715939115153076 for generation 2
# ++ Best 0.009198764273373333 for generation 3
# ++ Best 0.009897574629532079 for generation 24
# ++ Best 0.010875435713264528 for generation 63
# ++ Best 0.012456491242452718 for generation 76
# Step 100
# Step 200
# OVER
# Final score 0.011975819762551108 +- 0.006601784755102339
# expfit_funcfull_i7
# Step 0
# ++ Best 0.0060424633955927926 for generation 0
# ++ Best 0.006195738655146959 for generation 1
# ++ Best 0.009615666331998835 for generation 2
# ++ Best 0.009821370764653536 for generation 8
# ++ Best 0.010226706284071147 for generation 52
# ++ Best 0.010226863664163416 for generation 54
# ++ Best 0.01053598674504069 for generation 76
# ++ Best 0.01057691839199543 for generation 80
# Step 100
# ++ Best 0.026522823915207043 for generation 110
# ++ Best 0.03886184288816392 for generation 135
# Step 200
# OVER
# Final score 0.022827275065603635 +- 0.01594216724947596
# expfit_funcfull_i8
# Step 0
# ++ Best 0.005739922404391641 for generation 0
# ++ Best 0.008892137423633675 for generation 2
# ++ Best 0.009382106555233992 for generation 17
# ++ Best 0.009405970752293037 for generation 25
# ++ Best 0.009864687952057721 for generation 28
# ++ Best 0.016900938159584142 for generation 36
# Step 100
# ++ Best 0.01831588066200805 for generation 117
# Step 200
# OVER
# Final score 0.015798458778882817 +- 0.013910838077266093
# expfit_funcfull_i9
# Step 0
# ++ Best 0.006493956498662261 for generation 0
# ++ Best 0.00798312719164266 for generation 8
# ++ Best 0.009145692532537558 for generation 20
# ++ Best 0.009814660627714338 for generation 66
# ++ Best 0.023790424955069746 for generation 79
# Step 100
# Step 200
# ++ Best 0.04406570611268344 for generation 200
# ++ Best 0.07432349411045498 for generation 219
# OVER
# Final score 0.05291538003263676 +- 0.018587944582940528

# %%
show_curve(sol.stats, REF.stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-30abeee9d69e> in <module>
# ----> 1 show_curve(sol.stats, REF.stats)
#
# NameError: name 'sol' is not defined

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#       mutfunc  i      mean        sd       max
# 0  verysparse  3  0.012111  0.001741  0.016201
# 1        ctrl  5  0.013903  0.000934  0.014787
# 2        ctrl  4  0.017407  0.013490  0.046550
# 3      sparse  4  0.027887  0.012868  0.066169
# 4      sparse  2  0.042762  0.011174  0.051213

# %%
new_df = df.groupby(["mutfunc"]).mean()
new_df
# Out:
#                 mean        sd       max
# mutfunc
# ctrl        0.018799  0.006534  0.027575
# full        0.016983  0.008264  0.027877
# sparse      0.019482  0.007316  0.038989
# verysparse  0.021163  0.006233  0.032256

# %%
for i, row in new_df.iterrows():
    print(row.name, row["mean"], row["mean"] - row.sd / np.sqrt(10), row["mean"] + row.sd / np.sqrt(10))
# Out:
# ctrl 0.018798681916942117 0.016732298863691302 0.020865064970192932
# full 0.016982943670007043 0.014369498797917647 0.01959638854209644
# sparse 0.01948150559613282 0.017167903403502414 0.021795107788763226
# verysparse 0.02116330308590081 0.01919229057309225 0.023134315598709366

# %%
row.name
