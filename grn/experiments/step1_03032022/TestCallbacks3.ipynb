# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + s_all + s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=59, silent=True, opti=True,
              run_tissue=False, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    if prun.normalize:
        pop_fit = normalize_fitness_values(pop_fit)
    
    pop_fit = [p**prun.exponent for p in pop_fit]
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="3", start_time=56, end_time=59, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="4", start_time=59, end_time=62, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="5", start_time=62, end_time=65, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="6", start_time=65, end_time=68, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="7", start_time=68, end_time=71, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="8", start_time=71, end_time=74, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="9", start_time=74, end_time=77, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="10", start_time=77, end_time=80, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="11", start_time=80, end_time=83, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="12", start_time=83, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 20
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 20
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, exponent, normalize, name=None):
    args = get_prun(exponent=exponent)
    args.cb_init = cb_init
    args.name = name
    args.normalize = normalize
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    print("Final score", np.mean(scores), "+-", np.std(scores))
    return np.mean(scores), np.std(scores), max(p1)

# %%
model = sm.StringModel("expfit_exp{exponent}_n{normalize}_i{i}")
gen = product(
    [1, 2, 3],
    [True, False]
)

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 10,
    expr=lambda: np.random.beta(1.5, 3) * 3,
    deg=lambda: np.random.beta(1.5, 3) * 1,
)

# %%
# main loop
exporter = Exporter(name="exp_callbacks3_210222")
for (exponent, normalize), i in product(gen, range(10)):
    name = model.fill(exponent=exponent,
                      normalize=normalize,
                      i=i)
    print(name)
    if name in exporter.list():
        continue
    res = get_score_parametrized(callback_init, exponent, normalize)
    exporter(res, name)
# Out:
# Exporting at output/exp_callbacks3_210222
# expfit_exp1_nTrue_i0
# Step 4 passed !
# Step 5 passed !
# Step 6 passed !
# Step 7 passed !
# Step 8 passed !
# Step 9 passed !
# Step 10 passed !
# Step 11 passed !
# Step 0
# ++ Best 2.4105419919027464 for generation 0
# Step 12 passed !
# ++ Best 2.4519315444155003 for generation 36
# ++ Best 2.7095173014284137 for generation 38
# ++ Best 2.7785726718266397 for generation 53
# ++ Best 3.82936759056421 for generation 54
# ++ Best 3.9996528113658356 for generation 64
# Step 100
# ++ Best 4.086460485812541 for generation 114
# OVER
# Final score 2.426988967976802 +- 0.41660445049011013
# expfit_exp1_nTrue_i1
# Step 0
# ++ Best 0.1657393384116567 for generation 0
# ++ Best 0.16618320854305166 for generation 3
# ++ Best 0.36332177283239575 for generation 4
# ++ Best 0.39773281498281254 for generation 9
# ++ Best 0.731845530336097 for generation 13
# ++ Best 1.0697755212366555 for generation 28
# ++ Best 1.3083191213541374 for generation 41
# ++ Best 1.4798167928113517 for generation 51
# ++ Best 1.5311716005592242 for generation 78
# Step 100
# ++ Best 1.6386244066743356 for generation 120
# OVER
# Final score 0.6441579117124239 +- 0.6949616175904648
# expfit_exp1_nTrue_i2
# Step 0
# ++ Best 0.009027161248356029 for generation 0
# ++ Best 0.1949952865833996 for generation 1
# ++ Best 0.2904855250140297 for generation 5
# ++ Best 0.3759909348145741 for generation 9
# ++ Best 0.3958823420984773 for generation 10
# ++ Best 0.43755137075172157 for generation 25
# ++ Best 0.4664292996490994 for generation 64
# ++ Best 0.47516788251092845 for generation 97
# Step 100
# ++ Best 0.8865189667371383 for generation 129
# ++ Best 1.0648964332486393 for generation 133
# ++ Best 1.1170465984916484 for generation 152
# ++ Best 1.2793432839110714 for generation 183
# OVER
# Final score 0.6633726916336773 +- 0.24624020076054373
# expfit_exp1_nTrue_i3
# Step 0
# ++ Best 0.08655832328934843 for generation 0
# ++ Best 0.8298744804048994 for generation 1
# ++ Best 1.0271312718967762 for generation 3
# ++ Best 1.2985360140755102 for generation 32
# ++ Best 1.3150185476110425 for generation 35
# ++ Best 1.3560813921335548 for generation 38
# ++ Best 2.0642133567886196 for generation 45
# Step 100
# ++ Best 2.157938054054689 for generation 190
# OVER
# Final score 0.926961930895278 +- 0.5476142553619145
# expfit_exp1_nTrue_i4
# Step 0
# ++ Best 0.18065395468920778 for generation 0
# ++ Best 0.19476481509180174 for generation 1
# ++ Best 0.196283045161391 for generation 4
# ++ Best 0.2736858337037178 for generation 7
# ++ Best 0.36298565988895515 for generation 13
# ++ Best 0.39732549349808705 for generation 22
# ++ Best 0.4037954243734193 for generation 98
# Step 100
# ++ Best 0.4287249092070552 for generation 106
# ++ Best 0.675754579543122 for generation 149
# ++ Best 0.7016671677530322 for generation 179
# OVER
# Final score 0.5296894707377503 +- 0.3627741879919464
# expfit_exp1_nTrue_i5
# Step 0
# ++ Best 0.020567746100076157 for generation 0
# ++ Best 0.06084127074979341 for generation 1
# ++ Best 0.12577159363238533 for generation 2
# ++ Best 0.1646275403288089 for generation 3
# ++ Best 0.31565424711421763 for generation 7
# ++ Best 0.37580573161082087 for generation 14
# ++ Best 0.6662256678086057 for generation 18
# ++ Best 0.835171920564818 for generation 28
# Step 100
# ++ Best 3.534314170962938 for generation 141
# ++ Best 3.5577969165501413 for generation 167
# OVER
# Final score 2.1221269352979792 +- 1.397705806252707
# expfit_exp1_nTrue_i6
# Step 0
# ++ Best 0.13967041523963405 for generation 0
# ++ Best 0.3452970167713554 for generation 1
# ++ Best 0.36390956350871856 for generation 23
# ++ Best 0.376980671014741 for generation 25
# ++ Best 0.46189842681181775 for generation 38
# ++ Best 0.9844816692511967 for generation 87
# ++ Best 1.2306771772697818 for generation 91
# ++ Best 1.3242973365799702 for generation 92
# ++ Best 2.289058558688769 for generation 98
# Step 100
# ++ Best 2.6242566688365954 for generation 108
# ++ Best 3.246729713686917 for generation 111
# ++ Best 3.249470322257847 for generation 160
# ++ Best 3.45944429244525 for generation 187
# OVER
# Final score 1.9109619520541514 +- 0.9961505645688356
# expfit_exp1_nTrue_i7
# Step 0
# ++ Best 0.07070466917299742 for generation 0
# ++ Best 0.08619509268705652 for generation 1
# ++ Best 0.14058823641819934 for generation 5
# ++ Best 0.2872495135866208 for generation 6
# ++ Best 1.1414593234512695 for generation 7
# ++ Best 1.2382232791224481 for generation 20
# ++ Best 1.3294465521119518 for generation 25
# ++ Best 1.4638769851578108 for generation 27
# ++ Best 1.541242702192665 for generation 31
# ++ Best 1.5514477374663171 for generation 74
# ++ Best 1.6095435636012336 for generation 76
# ++ Best 1.7230640593587498 for generation 88
# Step 100
# ++ Best 1.9010052407008418 for generation 120
# ++ Best 2.000597058379139 for generation 177
# OVER
# Final score 1.2360963948286205 +- 0.44481805651029677
# expfit_exp1_nTrue_i8
# Step 0
# ++ Best 0.10761255602119309 for generation 0
# ++ Best 0.17840049278333722 for generation 1
# ++ Best 0.27685869202837643 for generation 6
# ++ Best 0.43738482878408846 for generation 8
# ++ Best 0.4432595017084819 for generation 9
# ++ Best 0.5441123832709401 for generation 34
# ++ Best 0.615542054182729 for generation 52
# ++ Best 0.83963907185665 for generation 90
# Step 100
# ++ Best 1.0650659844425479 for generation 105
# ++ Best 2.595351335232374 for generation 131
# ++ Best 2.850964740629846 for generation 140
# ++ Best 2.9515361608508375 for generation 150
# ++ Best 3.5649472774734154 for generation 170
# OVER
# Final score 1.3460060980290758 +- 1.0664253071838712
# expfit_exp1_nTrue_i9
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.06719326431301592 for generation 1
# ++ Best 0.08568132986306135 for generation 3
# ++ Best 0.40575351121415015 for generation 4
# ++ Best 0.4164140035332222 for generation 19
# ++ Best 0.7712635025759437 for generation 26
# ++ Best 0.8473895028914831 for generation 34
# ++ Best 1.3173214531201038 for generation 41
# ++ Best 1.395719455053221 for generation 69
# ++ Best 1.5839778328877456 for generation 71
# ++ Best 1.7362039230948538 for generation 87
# Step 100
# ++ Best 3.25512971766038 for generation 133
# ++ Best 3.8049831287311418 for generation 173
# ++ Best 4.044351377460977 for generation 180
# OVER
# Final score 2.7395368055937523 +- 1.3531997808489171
# expfit_exp1_nFalse_i0
# Step 0
# ++ Best 0.10029245512520962 for generation 0
# ++ Best 0.11520762966976902 for generation 3
# ++ Best 0.1701151224832101 for generation 4
# ++ Best 0.38237918597873777 for generation 6
# ++ Best 0.40307132107819255 for generation 18
# ++ Best 0.4034778598479286 for generation 22
# ++ Best 0.716494950343058 for generation 23
# ++ Best 0.7871285698045384 for generation 67
# ++ Best 0.909528255369301 for generation 95
# Step 100
# ++ Best 1.9243259842553107 for generation 177
# ++ Best 3.5701248198051316 for generation 192
# OVER
# Final score 2.038618189735191 +- 0.9305061881647503
# expfit_exp1_nFalse_i1
# Step 0
# ++ Best 0.7018337754454008 for generation 0
# ++ Best 0.8719368041968107 for generation 30
# Step 100
# OVER
# Final score 0.6477741265454118 +- 0.10349354341572674
# expfit_exp1_nFalse_i2
# Step 0
# ++ Best 0.1888451784344073 for generation 0
# ++ Best 0.26884695466937736 for generation 9
# ++ Best 0.39572658153727125 for generation 10
# ++ Best 0.415944148494823 for generation 12
# ++ Best 0.5888844416271338 for generation 14
# ++ Best 0.9512414624188978 for generation 33
# Step 100
# ++ Best 1.3400810809115955 for generation 187
# OVER
# Final score 0.49412096766608943 +- 0.2264067031994436
# expfit_exp1_nFalse_i3
# Step 0
# ++ Best 0.19949228082502257 for generation 0
# ++ Best 0.34936280118603236 for generation 13
# Step 100
# ++ Best 0.6492555085338019 for generation 105
# ++ Best 0.828321522582377 for generation 177
# OVER
# Final score 0.5626500267945491 +- 0.21940587962646324
# expfit_exp1_nFalse_i4
# Step 0
# ++ Best 0.1358586705660185 for generation 0
# ++ Best 1.0403933373324328 for generation 4
# ++ Best 1.12300354306231 for generation 23
# ++ Best 1.1277974844416994 for generation 36
# ++ Best 1.3153546765270088 for generation 37
# ++ Best 1.3444113349490165 for generation 49
# ++ Best 1.4037176924635173 for generation 54
# ++ Best 1.4289835687092256 for generation 82
# Step 100
# ++ Best 1.5699462310325325 for generation 107
# ++ Best 1.731508618609284 for generation 109
# ++ Best 1.97848233682304 for generation 153
# OVER
# Final score 0.7225787786685212 +- 0.500107449667755
# expfit_exp1_nFalse_i5
# Step 0
# ++ Best 0.0403879687319378 for generation 0
# ++ Best 0.10747140364141598 for generation 1
# ++ Best 0.38474107261365453 for generation 2
# ++ Best 0.4075248290596115 for generation 3
# ++ Best 0.45005220877949326 for generation 5
# ++ Best 0.6316734352572827 for generation 19
# ++ Best 0.7044759502069493 for generation 20
# ++ Best 0.7181962125064958 for generation 26
# ++ Best 0.9798205897867485 for generation 60
# Step 100
# OVER
# Final score 0.6541161465503343 +- 0.08829784348444036
# expfit_exp1_nFalse_i6
# Step 0
# ++ Best 0.060273100672394636 for generation 0
# ++ Best 0.07508513759023829 for generation 1
# ++ Best 0.39684023367852717 for generation 2
# ++ Best 0.43089813094800034 for generation 28
# ++ Best 0.4318486413868513 for generation 51
# Step 100
# ++ Best 0.6353072617339404 for generation 100
# ++ Best 0.6392867943807468 for generation 115
# OVER
# Final score 0.27957448678422214 +- 0.11781965012111925
# expfit_exp1_nFalse_i7
# Step 0
# ++ Best 0.072993402566039 for generation 0
# ++ Best 0.3118958255373452 for generation 4
# ++ Best 0.3871866671763649 for generation 6
# ++ Best 0.4286511369357706 for generation 19
# ++ Best 0.45815094675837087 for generation 20
# ++ Best 0.4624187223164802 for generation 52
# ++ Best 0.475522886831176 for generation 53
# ++ Best 0.5598266382241123 for generation 77
# ++ Best 0.5627492364294988 for generation 90
# ++ Best 0.5925093911090937 for generation 95
# Step 100
# ++ Best 0.6210015346212776 for generation 109
# OVER
# Final score 0.42641517984282346 +- 0.020669074197694627
# expfit_exp1_nFalse_i8
# Step 0
# ++ Best 0.06112996468404928 for generation 0
# ++ Best 0.3124313572833589 for generation 1
# ++ Best 3.0112852853078165 for generation 8
# ++ Best 3.302610379092754 for generation 23
# ++ Best 3.3426594209710383 for generation 27
# ++ Best 3.772877461656565 for generation 36
# ++ Best 4.077674812652977 for generation 47
# ++ Best 4.088675569950815 for generation 79
# Step 100
# ++ Best 4.143716656175314 for generation 156
# ++ Best 4.220952262409832 for generation 170
# OVER
# Final score 2.5008781738993116 +- 0.9172207988120975
# expfit_exp1_nFalse_i9
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.10940273918442968 for generation 1
# ++ Best 0.16032909853889968 for generation 4
# ++ Best 0.38889210179114275 for generation 15
# ++ Best 0.504584282096409 for generation 21
# ++ Best 1.0857043418964125 for generation 24
# ++ Best 1.1324557817744423 for generation 54
# ++ Best 1.3462383981953963 for generation 59
# ++ Best 1.4957870564278686 for generation 79
# Step 100
# ++ Best 1.6551832944972216 for generation 135
# ++ Best 1.761678801099674 for generation 138
# ++ Best 2.150751778435454 for generation 148
# ++ Best 2.618119342903095 for generation 158
# ++ Best 2.7008940597992055 for generation 176
# OVER
# Final score 1.991146429784277 +- 1.0591747630172346
# expfit_exp2_nTrue_i0
# Step 0
# ++ Best 0.06121153166703668 for generation 0
# ++ Best 0.10334221383753364 for generation 1
# ++ Best 0.17734841369276624 for generation 2
# ++ Best 0.46715354394588793 for generation 3
# ++ Best 0.7011305211720362 for generation 16
# ++ Best 1.705140899569658 for generation 50
# ++ Best 1.9234574910022608 for generation 86
# Step 100
# ++ Best 2.607616607724917 for generation 111
# ++ Best 2.8889133995468317 for generation 128
# ++ Best 3.0979882159003456 for generation 140
# ++ Best 3.4512799033884902 for generation 186
# OVER
# Final score 1.0762577947865277 +- 0.8070758811797241
# expfit_exp2_nTrue_i1
# Step 0
# ++ Best 0.17535405229101447 for generation 0
# ++ Best 0.9212484947660349 for generation 2
# Step 100
# ++ Best 1.0438657171938832 for generation 144
# ++ Best 1.058585168813889 for generation 153
# ++ Best 1.1574028281045161 for generation 192
# OVER
# Final score 0.6251531862725336 +- 0.28663740680386646
# expfit_exp2_nTrue_i2
# Step 0
# ++ Best 0.06032993884451865 for generation 0
# ++ Best 0.1723342885446692 for generation 1
# ++ Best 0.19984246639800637 for generation 2
# ++ Best 0.8561287553740872 for generation 10
# ++ Best 0.878023009187558 for generation 28
# ++ Best 0.9139984594580259 for generation 31
# ++ Best 0.9145730667643179 for generation 44
# ++ Best 0.926061731392935 for generation 56
# Step 100
# ++ Best 0.938344563936776 for generation 129
# ++ Best 1.0861365979341921 for generation 133
# ++ Best 1.19894646296626 for generation 146
# ++ Best 1.2589992128382363 for generation 175
# ++ Best 1.3833070240486598 for generation 192
# OVER
# Final score 0.8211094237621792 +- 0.365724936204932
# expfit_exp2_nTrue_i3
# Step 0
# ++ Best 0.060682378261181266 for generation 0
# ++ Best 0.060719870409037764 for generation 1
# ++ Best 0.40893166345330806 for generation 3
# ++ Best 0.5940370853817187 for generation 10
# ++ Best 0.6063663478339636 for generation 21
# ++ Best 0.8860054471618539 for generation 23
# ++ Best 1.0307052206665808 for generation 37
# ++ Best 1.1007417757613291 for generation 61
# ++ Best 1.3393713010239248 for generation 91
# ++ Best 1.377471846277382 for generation 93
# Step 100
# ++ Best 1.3899789507638582 for generation 148
# ++ Best 1.5137346194030858 for generation 149
# ++ Best 3.294075021963994 for generation 157
# ++ Best 3.610633809972366 for generation 164
# ++ Best 3.6803850985653823 for generation 174
# ++ Best 4.348352597161241 for generation 196
# OVER
# Final score 0.6942585892509059 +- 1.1314900396525314
# expfit_exp2_nTrue_i4
# Step 0
# ++ Best 0.060682378261181266 for generation 0
# ++ Best 0.0847725022788532 for generation 1
# ++ Best 0.1067681833732429 for generation 2
# ++ Best 0.363764345725327 for generation 5
# ++ Best 0.4170309897973426 for generation 11
# ++ Best 0.4643322021406867 for generation 25
# ++ Best 0.4691100356624747 for generation 34
# ++ Best 0.8145917280258753 for generation 56
# ++ Best 2.9056750345120643 for generation 64
# Step 100
# OVER
# Final score 0.3371486877412047 +- 0.18694725389082745
# expfit_exp2_nTrue_i5
# Step 0
# ++ Best 0.06019604299075317 for generation 0
# ++ Best 0.1841177511504372 for generation 1
# ++ Best 0.3427607018398744 for generation 2
# ++ Best 0.41853047132617643 for generation 3
# ++ Best 0.5158289212681461 for generation 13
# ++ Best 0.5389351005602828 for generation 22
# ++ Best 0.5791103458444906 for generation 29
# ++ Best 0.6079542826850827 for generation 37
# ++ Best 0.684206212517507 for generation 75
# Step 100
# ++ Best 0.8478525526787041 for generation 101
# ++ Best 0.9253145479242517 for generation 102
# ++ Best 1.058671484499534 for generation 167
# OVER
# Final score 0.7212313288068118 +- 0.22740801631184207
# expfit_exp2_nTrue_i6
# Step 0
# ++ Best 0.6148684936098895 for generation 0
# ++ Best 3.609342954715851 for generation 11
# ++ Best 3.9712017651287703 for generation 51
# Step 100
# OVER
# Final score 2.4601410318443073 +- 0.8111356710324102
# expfit_exp2_nTrue_i7
# Step 0
# ++ Best 0.32203403373887235 for generation 0
# ++ Best 0.6132349012327448 for generation 3
# ++ Best 0.6690890172655606 for generation 24
# ++ Best 1.5791324362865264 for generation 44
# ++ Best 3.01663055201219 for generation 60
# ++ Best 3.226830388596752 for generation 79
# ++ Best 3.883568044665331 for generation 81
# ++ Best 4.227014398286809 for generation 91
# Step 100
# ++ Best 4.247602320734156 for generation 142
# ++ Best 4.398292432466414 for generation 199
# OVER
# Final score 1.086565118880176 +- 1.3616878983193732
# expfit_exp2_nTrue_i8
# Step 0
# ++ Best 0.16949875517839594 for generation 0
# ++ Best 0.36421190094623257 for generation 11
# ++ Best 0.3712963750194617 for generation 21
# ++ Best 0.3814500348805948 for generation 29
# ++ Best 0.4084301164863125 for generation 31
# ++ Best 0.4523308988797615 for generation 58
# Step 100
# ++ Best 0.45383595455123527 for generation 189
# OVER
# Final score 0.31299480453150463 +- 0.2132094942691917
# expfit_exp2_nTrue_i9
# Step 0
# ++ Best 0.05984478294083211 for generation 0
# ++ Best 0.12153755560532994 for generation 1
# ++ Best 0.14718947268903923 for generation 5
# ++ Best 0.15409181010701575 for generation 6
# ++ Best 0.6383619644040247 for generation 8
# ++ Best 3.170018583461646 for generation 13
# Step 100
# ++ Best 3.174998931196834 for generation 165
# OVER
# Final score 1.1532228364576884 +- 0.7002838452970094
# expfit_exp2_nFalse_i0
# Step 0
# ++ Best 0.15072498430977085 for generation 0
# ++ Best 0.3359298950044175 for generation 4
# ++ Best 0.3729335285537352 for generation 18
# ++ Best 0.38714957890616647 for generation 21
# ++ Best 0.3997879236262249 for generation 41
# ++ Best 0.4130578155672172 for generation 47
# ++ Best 0.47531426115566744 for generation 51
# ++ Best 0.5297548438923734 for generation 62
# ++ Best 0.5583490950807182 for generation 90
# Step 100
# ++ Best 0.5627934015154263 for generation 152
# ++ Best 0.5761263259882654 for generation 190
# ++ Best 0.7068602331747936 for generation 193
# OVER
# Final score 0.3760915026173703 +- 0.100335381422936
# expfit_exp2_nFalse_i1
# Step 0
# ++ Best 0.08629398894240224 for generation 0
# ++ Best 0.36308065680305085 for generation 1
# ++ Best 0.49664507072881403 for generation 2
# ++ Best 0.518993675879496 for generation 64
# Step 100
# ++ Best 0.6449829390452316 for generation 104
# ++ Best 0.8683470250481817 for generation 120
# ++ Best 1.1973183510023997 for generation 136
# ++ Best 1.5483656968083999 for generation 138
# ++ Best 2.1535304852514763 for generation 139
# ++ Best 2.3826970912094363 for generation 165
# OVER
# Final score 0.28396363043874406 +- 0.1863153191629132
# expfit_exp2_nFalse_i2
# Step 0
# ++ Best 0.1795748657865899 for generation 0
# ++ Best 0.3528015823360288 for generation 1
# ++ Best 0.4340492876777775 for generation 2
# ++ Best 0.4361821598376818 for generation 25
# ++ Best 0.6334177548077601 for generation 31
# ++ Best 0.9057406643775785 for generation 32
# ++ Best 1.247249165165446 for generation 36
# Step 100
# ++ Best 1.331386506556178 for generation 114
# ++ Best 3.1723259257009446 for generation 143
# OVER
# Final score 0.7703330569519025 +- 0.22301005773002577
# expfit_exp2_nFalse_i3
# Step 0
# ++ Best 0.05990014603125603 for generation 0
# ++ Best 0.08825859999779313 for generation 3
# ++ Best 0.15568419330945935 for generation 4
# ++ Best 0.1909090693067495 for generation 6
# ++ Best 0.19287236603439617 for generation 8
# ++ Best 0.36102957775012096 for generation 9
# ++ Best 0.3932577434541662 for generation 23
# ++ Best 0.41021548292301935 for generation 28
# ++ Best 0.4155874214121039 for generation 35
# ++ Best 0.5476677984922679 for generation 47
# ++ Best 0.6469281209661397 for generation 67
# Step 100
# OVER
# Final score 0.45503996235488103 +- 0.07394404491076931
# expfit_exp2_nFalse_i4
# Step 0
# ++ Best 0.45546041320810593 for generation 0
# ++ Best 1.1769961928743407 for generation 19
# ++ Best 2.324243122424935 for generation 24
# ++ Best 2.504938404915546 for generation 25
# ++ Best 4.334795475942169 for generation 28
# Step 100
# OVER
# Final score 2.0485196169736564 +- 0.7411961635572022
# expfit_exp2_nFalse_i5
# Step 0
# ++ Best 0.10422189252201765 for generation 0
# ++ Best 0.1288323286156128 for generation 1
# ++ Best 0.1503377994026882 for generation 2
# ++ Best 0.2937052923547201 for generation 3
# ++ Best 0.30001740744324534 for generation 17
# ++ Best 0.35646535825420544 for generation 22
# ++ Best 0.5879723926292242 for generation 27
# ++ Best 0.8878998793009447 for generation 44
# ++ Best 2.092066255946882 for generation 55
# ++ Best 2.647623433736535 for generation 57
# Step 100
# OVER
# Final score 1.7650909124453833 +- 0.6676411166735629
# expfit_exp2_nFalse_i6
# Step 0
# ++ Best 0.10228120315710396 for generation 0
# ++ Best 0.14857778544498984 for generation 1
# ++ Best 0.1933393806508947 for generation 6
# ++ Best 0.2410893563488078 for generation 12
# ++ Best 0.28152108109585 for generation 16
# ++ Best 0.4137454355859561 for generation 22
# ++ Best 0.42659995553013397 for generation 27
# ++ Best 0.5381254371271653 for generation 29
# ++ Best 0.5684500635572312 for generation 39
# ++ Best 0.5706822288856341 for generation 44
# ++ Best 0.649760327677622 for generation 55
# ++ Best 0.682825178674876 for generation 68
# Step 100
# OVER
# Final score 0.4420604018316968 +- 0.14391621035996013
# expfit_exp2_nFalse_i7
# Step 0
# ++ Best 0.3672649552375876 for generation 0
# ++ Best 0.39559869892730903 for generation 2
# ++ Best 0.4306758462829773 for generation 3
# ++ Best 0.6551916932261841 for generation 12
# ++ Best 0.6948940089145674 for generation 31
# ++ Best 1.3498282779608426 for generation 42
# ++ Best 2.1417098616669765 for generation 60
# ++ Best 2.456800082629302 for generation 69
# Step 100
# ++ Best 2.857672235743564 for generation 113
# ++ Best 3.3173223418933944 for generation 137
# ++ Best 3.4508684658382225 for generation 181
# OVER
# Final score 1.6567342834937473 +- 1.2280089928228817
# expfit_exp2_nFalse_i8
# Step 0
# ++ Best 0.36004558750168364 for generation 0
# ++ Best 0.41283399714633884 for generation 5
# ++ Best 0.6354509580623495 for generation 8
# ++ Best 0.9431529305650075 for generation 27
# ++ Best 1.0549765156304787 for generation 52
# ++ Best 1.6512325570807942 for generation 62
# Step 100
# ++ Best 1.8374904260846494 for generation 105
# ++ Best 1.974094784602376 for generation 108
# ++ Best 2.0449675198513333 for generation 146
# ++ Best 2.241213057733543 for generation 151
# ++ Best 2.8304155275847256 for generation 188
# OVER
# Final score 1.8241337616093027 +- 1.05516127443958
# expfit_exp2_nFalse_i9
# Step 0
# ++ Best 0.15045372881243466 for generation 0
# ++ Best 0.4178349700122298 for generation 4
# ++ Best 1.1890187485491879 for generation 20
# ++ Best 1.2002268861614271 for generation 40
# ++ Best 1.2496250047089414 for generation 48
# Step 100
# ++ Best 1.2798194669268665 for generation 188
# OVER
# Final score 0.4987695711768457 +- 0.5434767868555922
# expfit_exp3_nTrue_i0
# Step 0
# ++ Best 0.06121153166703668 for generation 0
# ++ Best 0.18255508862061653 for generation 1
# ++ Best 1.5001359310217357 for generation 2
# ++ Best 1.5005878342420758 for generation 46
# ++ Best 1.5164246921663918 for generation 52
# ++ Best 1.5738325490310097 for generation 79
# Step 100
# ++ Best 1.7008445782192647 for generation 155
# ++ Best 1.7533523889778913 for generation 179
# OVER
# Final score 0.9644173989262178 +- 0.46333810402217723
# expfit_exp3_nTrue_i1
# Step 0
# ++ Best 0.0019519358760914458 for generation 0
# ++ Best 0.41826852963463645 for generation 1
# ++ Best 0.6530510167325924 for generation 15
# ++ Best 0.6662522941436897 for generation 27
# ++ Best 2.7152206179664113 for generation 39
# ++ Best 2.8687779740463144 for generation 45
# Step 100
# OVER
# Final score 0.8617481808223314 +- 0.47870484196032165
# expfit_exp3_nTrue_i2
# Step 0
# ++ Best 0.07156110967436534 for generation 0
# ++ Best 0.43077808727319566 for generation 1
# ++ Best 0.5592801531175582 for generation 7
# ++ Best 0.7688480575662346 for generation 12
# ++ Best 1.277260887061761 for generation 20
# ++ Best 2.8824746725106216 for generation 21
# ++ Best 3.235357007375013 for generation 75
# Step 100
# ++ Best 3.5749905473453203 for generation 110
# ++ Best 3.6655828622427307 for generation 121
# ++ Best 3.8057287491794383 for generation 131
# ++ Best 4.011800961398829 for generation 156
# ++ Best 4.285141252542992 for generation 173
# OVER
# Final score 1.8044552827486897 +- 1.5850408876422903
# expfit_exp3_nTrue_i3
# Step 0
# ++ Best 0.06046738327649333 for generation 0
# ++ Best 0.0608898273665552 for generation 1
# ++ Best 0.07137840537084389 for generation 2
# ++ Best 0.17561819075587698 for generation 4
# ++ Best 0.4100030104418295 for generation 10
# ++ Best 0.5880397973479754 for generation 11
# ++ Best 0.6753390293013533 for generation 24
# ++ Best 0.6951454868000598 for generation 28
# ++ Best 0.8024126968894529 for generation 49
# ++ Best 0.8224104417294412 for generation 69
# ++ Best 0.8453518027617734 for generation 73
# ++ Best 0.9902853859861251 for generation 88
# Step 100
# ++ Best 1.0457747478952253 for generation 108
# ++ Best 1.4313258970859244 for generation 112
# ++ Best 1.547819716004272 for generation 114
# ++ Best 1.5937984998537624 for generation 123
# ++ Best 2.1015447742758075 for generation 124
# ++ Best 2.5534099389138905 for generation 131
# ++ Best 2.613350878483797 for generation 137
# ++ Best 2.6926099174560565 for generation 138
# ++ Best 3.0948811455199126 for generation 151
# OVER
# Final score 2.3966169691089565 +- 0.3168430852240144
# expfit_exp3_nTrue_i4
# Step 0
# ++ Best 0.03499147008450794 for generation 0
# ++ Best 0.07253772196852183 for generation 1
# ++ Best 0.10008904116216892 for generation 2
# ++ Best 0.6269443897735502 for generation 8
# ++ Best 0.6631273168283777 for generation 22
# ++ Best 0.9348695136891959 for generation 27
# ++ Best 1.1035417474414975 for generation 30
# ++ Best 1.189556089514733 for generation 33
# ++ Best 1.4688744713530664 for generation 34
# ++ Best 1.6846745510023518 for generation 88
# Step 100
# ++ Best 1.7430779602090196 for generation 120
# OVER
# Final score 1.0522307557726702 +- 0.31539991870249906
# expfit_exp3_nTrue_i5
# Step 0
# ++ Best 0.08773330097471824 for generation 0
# ++ Best 0.15526669222928888 for generation 1
# ++ Best 0.19946040673336604 for generation 5
# ++ Best 0.6492000115936283 for generation 12
# ++ Best 1.4504705544062468 for generation 27
# ++ Best 1.6276183090011387 for generation 30
# ++ Best 1.819537308160575 for generation 45
# ++ Best 1.9157065341835602 for generation 84
# ++ Best 1.963825177850227 for generation 85
# ++ Best 2.130013634226218 for generation 86
# ++ Best 2.182992074804014 for generation 88
# ++ Best 2.279247151940688 for generation 89
# Step 100
# ++ Best 2.482810720586922 for generation 118
# OVER
# Final score 1.34034073533411 +- 0.6805905704475177
# expfit_exp3_nTrue_i6
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.18885500435165964 for generation 2
# ++ Best 0.1981363495921126 for generation 14
# ++ Best 0.4054056152030506 for generation 16
# ++ Best 0.6229090427330539 for generation 25
# ++ Best 0.9324747991846848 for generation 27
# ++ Best 1.9000083736021278 for generation 51
# ++ Best 2.4113336322391627 for generation 56
# ++ Best 2.8466916738106174 for generation 62
# ++ Best 3.3672285062347886 for generation 80
# Step 100
# ++ Best 3.576034612511739 for generation 138
# OVER
# Final score 1.554201430058527 +- 1.2266986029070046
# expfit_exp3_nTrue_i7
# Step 0
# ++ Best 0.1966747927278706 for generation 0
# ++ Best 0.40166092906373674 for generation 4
# ++ Best 0.4456264772281584 for generation 22
# ++ Best 0.481669269138145 for generation 25
# ++ Best 0.7981342053465941 for generation 26
# ++ Best 0.829425846563985 for generation 35
# ++ Best 1.4219261494948299 for generation 38
# ++ Best 3.2699242205931394 for generation 43
# ++ Best 3.3066745534315727 for generation 60
# ++ Best 3.5863570993358977 for generation 76
# Step 100
# OVER
# Final score 0.653929485395717 +- 0.5866412032972492
# expfit_exp3_nTrue_i8
# Step 0
# ++ Best 0.060096408325351666 for generation 0
# ++ Best 0.127781505183923 for generation 1
# ++ Best 0.3976192388393193 for generation 3
# ++ Best 1.363279724745432 for generation 20
# Step 100
# ++ Best 1.4054759954727318 for generation 159
# OVER
# Final score 0.4311597740240501 +- 0.5022353678125508
# expfit_exp3_nTrue_i9
# Step 0
# ++ Best 0.32915053694887647 for generation 0
# ++ Best 0.3596667265526003 for generation 9
# ++ Best 0.36214126850017875 for generation 10
# ++ Best 0.7375504409187303 for generation 16
# ++ Best 0.8858200676640823 for generation 23
# ++ Best 1.0639225307542652 for generation 24
# ++ Best 1.0740232480263783 for generation 55
# ++ Best 1.1842525126499692 for generation 56
# ++ Best 1.2071941124985903 for generation 87
# ++ Best 1.7655124911001352 for generation 91
# Step 100
# ++ Best 2.0766465481413015 for generation 140
# OVER
# Final score 1.0691151561398962 +- 0.3403820864531925
# expfit_exp3_nFalse_i0
# Step 0
# ++ Best 0.06087831845242644 for generation 0
# ++ Best 0.19145139819520404 for generation 2
# ++ Best 0.4220317564105568 for generation 3
# ++ Best 0.5770602222481631 for generation 6
# ++ Best 0.590706655101426 for generation 23
# ++ Best 0.856503187537665 for generation 34
# ++ Best 0.8605845889899416 for generation 49
# ++ Best 0.9038711413641902 for generation 52
# ++ Best 1.1733865111541313 for generation 58
# ++ Best 1.2676102389344277 for generation 82
# Step 100
# ++ Best 1.3294858381893848 for generation 136
# ++ Best 1.5379820853195427 for generation 137
# ++ Best 1.5575804304156822 for generation 150
# ++ Best 1.679691622732611 for generation 175
# ++ Best 1.9650121324049934 for generation 181
# ++ Best 2.287832309262865 for generation 183
# ++ Best 2.56167567815548 for generation 196
# OVER
# Final score 1.9544996422845777 +- 0.8485905292169009
# expfit_exp3_nFalse_i1
# Step 0
# ++ Best 0.07166454157359399 for generation 0
# ++ Best 0.09742174004716447 for generation 2
# ++ Best 0.3674340417685557 for generation 4
# ++ Best 0.6096646523045638 for generation 25
# ++ Best 0.6777215546653156 for generation 43
# ++ Best 0.94279892129165 for generation 49
# ++ Best 1.4579879243132705 for generation 96
# Step 100
# ++ Best 2.111085124385753 for generation 103
# ++ Best 4.079934356508022 for generation 104
# ++ Best 4.218103529385688 for generation 176
# OVER
# Final score 2.404735403895882 +- 1.3402344018727028
# expfit_exp3_nFalse_i2
# Step 0
# ++ Best 0.17915974955911781 for generation 0
# ++ Best 0.19276483351130133 for generation 2
# ++ Best 0.19393965536015542 for generation 4
# ++ Best 0.19554375349288142 for generation 16
# ++ Best 0.34329827207967445 for generation 22
# ++ Best 0.6278627589836452 for generation 26
# ++ Best 0.8878744351643166 for generation 31
# ++ Best 0.9474968896307299 for generation 34
# ++ Best 0.9990216492752342 for generation 40
# ++ Best 1.835102097939563 for generation 70
# Step 100
# ++ Best 2.345059027586602 for generation 146
# ++ Best 2.5896422046401155 for generation 148
# ++ Best 2.592669580924849 for generation 187
# ++ Best 2.6196636658359145 for generation 192
# OVER
# Final score 0.28373252371027713 +- 0.3013903813392667
# expfit_exp3_nFalse_i3
# Step 0
# ++ Best 0.087695822327437 for generation 0
# ++ Best 0.15718354698211498 for generation 1
# ++ Best 0.1680370317737773 for generation 5
# ++ Best 0.5994913990724766 for generation 11
# ++ Best 0.7250611132399039 for generation 13
# ++ Best 3.4346613613796526 for generation 22
# ++ Best 3.6950978583823746 for generation 69
# Step 100
# ++ Best 3.8497478950518893 for generation 143
# OVER
# Final score 0.6972212820577777 +- 1.1171542319743821
# expfit_exp3_nFalse_i4
# Step 0
# ++ Best 0.16646724917358396 for generation 0
# ++ Best 0.1762332915755957 for generation 1
# ++ Best 0.3585931367651657 for generation 6
# ++ Best 0.38782283538175333 for generation 7
# ++ Best 0.4297089606711853 for generation 8
# ++ Best 0.6701059798537334 for generation 18
# ++ Best 0.8508423225160926 for generation 81
# ++ Best 0.936451831692804 for generation 94
# Step 100
# ++ Best 0.9385070810144591 for generation 132
# ++ Best 0.9880999912197233 for generation 147
# OVER
# Final score 0.5234815213695513 +- 0.23367366920246518
# expfit_exp3_nFalse_i5
# Step 0
# ++ Best 0.060936929459973435 for generation 0
# ++ Best 0.17486177635986147 for generation 1
# ++ Best 0.3720127806686584 for generation 5
# ++ Best 0.4061356309137014 for generation 23
# ++ Best 0.42590815789737924 for generation 33
# ++ Best 0.4336123059583164 for generation 41
# ++ Best 0.43464422315157125 for generation 45
# ++ Best 0.44903652622044044 for generation 46
# ++ Best 0.6167558705729591 for generation 47
# ++ Best 0.6559912755922978 for generation 55
# ++ Best 0.6667208946345908 for generation 83
# Step 100
# ++ Best 1.2890154074257103 for generation 143
# ++ Best 2.9257524467366074 for generation 148
# ++ Best 3.155425684569992 for generation 163
# ++ Best 3.2048167925968647 for generation 170
# OVER
# Final score 2.174723391821765 +- 0.7513835917538536
# expfit_exp3_nFalse_i6
# Step 0
# ++ Best 0.1544783897058027 for generation 0
# ++ Best 0.34508980627395003 for generation 3
# ++ Best 1.0307415852550852 for generation 9
# ++ Best 1.9839367389927172 for generation 24
# ++ Best 2.000516600051866 for generation 49
# ++ Best 2.056066855404303 for generation 78
# ++ Best 2.08560122581043 for generation 79
# Step 100
# ++ Best 2.088447095725334 for generation 105
# ++ Best 2.1786532469615167 for generation 142
# OVER
# Final score 1.5120111961982636 +- 0.33505894705352857
# expfit_exp3_nFalse_i7
# Step 0
# ++ Best 0.060566385379354964 for generation 0
# ++ Best 0.17822081079006324 for generation 1
# ++ Best 0.37522907673971795 for generation 3
# ++ Best 0.39437659582958606 for generation 17
# ++ Best 0.4118517419612011 for generation 19
# ++ Best 0.4370465261655747 for generation 46
# ++ Best 0.620094873045697 for generation 48
# ++ Best 0.896535251944173 for generation 53
# ++ Best 1.0884883243005383 for generation 60
# Step 100
# ++ Best 1.2780927825100323 for generation 193
# ++ Best 1.3169170280258595 for generation 198
# OVER
# Final score 0.9755205855697874 +- 0.30992703003440925
# expfit_exp3_nFalse_i8
# Step 0
# ++ Best 0.05917437956257355 for generation 0
# ++ Best 0.18735760894666992 for generation 1
# ++ Best 0.1952486970614945 for generation 4
# ++ Best 0.36827033371145096 for generation 5
# ++ Best 0.3894007565679415 for generation 9
# ++ Best 0.53805512572634 for generation 36
# ++ Best 0.5844995352430791 for generation 66
# Step 100
# ++ Best 0.8529580321356537 for generation 119
# ++ Best 1.7972512886165055 for generation 124
# ++ Best 2.113879614403625 for generation 129
# ++ Best 2.1218693236033968 for generation 135
# ++ Best 2.244661767303636 for generation 144
# ++ Best 2.4867780968681545 for generation 150
# ++ Best 2.595954599832182 for generation 154
# OVER
# Final score 1.5615293719593046 +- 0.8207378539339164
# expfit_exp3_nFalse_i9
# Step 0
# ++ Best 0.07177651792388419 for generation 0
# ++ Best 0.07190565247877598 for generation 1
# ++ Best 0.8025446633649467 for generation 2
# ++ Best 0.8199839253389342 for generation 29
# ++ Best 0.8773381600373973 for generation 30
# ++ Best 0.9813980451323986 for generation 46
# Step 100
# ++ Best 1.1437442364617718 for generation 106
# ++ Best 1.533996842302651 for generation 113
# ++ Best 2.483631650605595 for generation 149
# ++ Best 2.883017618385339 for generation 196
# OVER
# Final score 0.9669513117271826 +- 0.858581362212931

# %%
show_curve(sol.stats, REF.stats)

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#   exponent normalize  i      mean        sd       max
# 0        3     False  6  1.512011  0.335059  2.178653
# 1        1      True  4  0.529689  0.362774  0.701667
# 2        1      True  2  0.663373  0.246240  1.279343
# 3        2     False  6  0.442060  0.143916  0.682825
# 4        3     False  1  2.404735  1.340234  4.218104

# %%
df.groupby(["exponent", "normalize"]).mean()
# Out:
#                         mean        sd       max
# exponent normalize
# 1        False      1.031787  0.418310  1.775090
#          True       1.454590  0.752649  2.649117
# 2        False      1.012074  0.496301  2.213516
#          True       0.928808  0.609160  2.630302
# 3        False      1.305441  0.691673  2.641665
#          True       1.212822  0.649587  2.687256
