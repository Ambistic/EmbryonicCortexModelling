# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn, SparseMutator

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")
_MUTATE_FUNC = SparseMutator()

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(7, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late)**2 + abs(neuron_infra_late - ref_neuron_infra_late)**2
                  + abs(neuron_supra_late - ref_neuron_supra_late)**2)
    delta_early = (abs(prog_early - ref_prog_early)**2 + abs(neuron_infra_early - ref_neuron_infra_early)**2
                  + abs(neuron_supra_early - ref_neuron_supra_early)**2)

    return 1 / max(1, 10000 - 1 * delta_late - 0.5 * delta_early)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=50, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if batch_gen == prun.n_gen:
        print("Already finished")
        return
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // prun.batch_size
            exporter(pop[-prun.batch_size:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r33"
res = main(prun)

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r33

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load("generation_g10"))

# %%
res.fit
# Out:
# 7687.023071605126

# %%
# for i in range(5):
#     print(fitness_multistep(prun, res.grn, prun.steps))

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} {res.fit} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 3884.134621153994 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.59; m: 8.47; expr: 1.00; deg: 0.10; theta: 5.56; asym: 5.00; tree : (3 OR (-1 AND 6))
# >> G_1: init: 0.52; noise: 1.00; b: 4.23; m: 8.62; expr: 1.00; deg: 0.10; theta: 0.19; asym: 5.00; tree : ((2 AND -3) AND -0)
# >> G_2: init: 0.18; noise: 1.00; b: 2.13; m: 4.42; expr: 1.00; deg: 0.10; theta: 4.30; asym: 5.00; tree : 5
# >> G_3: init: 1.06; noise: 1.00; b: 0.75; m: 1.96; expr: 1.00; deg: 0.10; theta: 1.48; asym: 5.00; tree : -3
# >> G_4: init: 1.90; noise: 1.00; b: 0.73; m: 7.16; expr: 1.00; deg: 0.10; theta: 6.37; asym: 5.00; tree : -6
# >> G_5: init: 2.37; noise: 1.00; b: 2.99; m: 5.72; expr: 1.00; deg: 0.10; theta: 7.00; asym: 5.00; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.38; noise: 1.00; b: 0.82; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.77; asym: 5.00; tree : -7
#
# ======= GENERATION generation_g1 4586.762073679408 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.88; m: 8.47; expr: 1.00; deg: 0.10; theta: 5.56; asym: 5.00; tree : (-1 AND 6)
# >> G_1: init: 0.49; noise: 1.00; b: 4.23; m: 8.62; expr: 1.00; deg: 0.10; theta: 0.19; asym: 5.00; tree : ((2 AND -3) AND -0)
# >> G_2: init: 0.18; noise: 1.00; b: 2.13; m: 4.42; expr: 0.91; deg: 0.10; theta: 4.20; asym: 5.00; tree : (5 AND 6)
# >> G_3: init: 1.06; noise: 1.00; b: 0.75; m: 1.96; expr: 1.00; deg: 0.11; theta: 1.48; asym: 5.00; tree : -3
# >> G_4: init: 1.90; noise: 1.00; b: 0.59; m: 7.16; expr: 1.00; deg: 0.09; theta: 6.33; asym: 5.00; tree : -6
# >> G_5: init: 2.37; noise: 1.00; b: 2.99; m: 5.72; expr: 1.00; deg: 0.10; theta: 7.00; asym: 5.00; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.38; noise: 1.00; b: 0.82; m: 2.52; expr: 1.00; deg: 0.09; theta: 4.77; asym: 5.00; tree : -7
#
# ======= GENERATION generation_g2 4776.4322658700075 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.79; m: 8.77; expr: 0.95; deg: 0.10; theta: 5.58; asym: 5.00; tree : (-1 AND 6)
# >> G_1: init: 0.49; noise: 1.00; b: 3.99; m: 8.57; expr: 0.91; deg: 0.11; theta: 0.13; asym: 5.12; tree : ((2 AND -3) AND -0)
# >> G_2: init: 0.18; noise: 0.98; b: 2.06; m: 4.79; expr: 1.08; deg: 0.10; theta: 5.32; asym: 5.08; tree : (5 AND 6)
# >> G_3: init: 0.94; noise: 1.00; b: 0.58; m: 1.81; expr: 0.95; deg: 0.11; theta: 1.30; asym: 5.00; tree : -3
# >> G_4: init: 1.30; noise: 1.00; b: 0.63; m: 7.16; expr: 1.00; deg: 0.09; theta: 6.87; asym: 4.05; tree : -6
# >> G_5: init: 3.08; noise: 1.00; b: 2.99; m: 5.72; expr: 0.98; deg: 0.10; theta: 6.40; asym: 5.00; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.38; noise: 1.00; b: 0.93; m: 2.31; expr: 0.96; deg: 0.09; theta: 4.51; asym: 4.93; tree : -7
#
# ======= GENERATION generation_g3 5598.176350286103 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.79; m: 8.76; expr: 0.92; deg: 0.09; theta: 5.95; asym: 4.96; tree : 6
# >> G_1: init: 0.54; noise: 1.00; b: 3.70; m: 8.87; expr: 0.91; deg: 0.09; theta: 0.13; asym: 3.36; tree : (-3 AND -0)
# >> G_2: init: 0.18; noise: 1.05; b: 1.82; m: 4.89; expr: 1.14; deg: 0.12; theta: 5.38; asym: 5.08; tree : (5 AND 6)
# >> G_3: init: 0.94; noise: 1.05; b: 0.52; m: 2.09; expr: 1.06; deg: 0.13; theta: 1.04; asym: 4.23; tree : (-3 OR -1)
# >> G_4: init: 1.22; noise: 1.00; b: 0.73; m: 5.70; expr: 0.88; deg: 0.12; theta: 7.33; asym: 3.83; tree : -6
# >> G_5: init: 3.53; noise: 1.00; b: 2.99; m: 5.36; expr: 0.96; deg: 0.10; theta: 6.40; asym: 5.57; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.43; noise: 0.87; b: 0.81; m: 2.57; expr: 1.00; deg: 0.09; theta: 4.51; asym: 5.39; tree : -7
#
# ======= GENERATION generation_g4 5621.875495912362 =======
# >> G_0: init: 0.91; noise: 1.12; b: 1.63; m: 8.47; expr: 1.00; deg: 0.11; theta: 5.97; asym: 4.86; tree : (-1 AND 6)
# >> G_1: init: 0.42; noise: 1.00; b: 2.81; m: 9.20; expr: 0.96; deg: 0.10; theta: 0.22; asym: 4.57; tree : ((2 AND -3) AND -0)
# >> G_2: init: 0.22; noise: 0.92; b: 1.99; m: 5.14; expr: 1.04; deg: 0.10; theta: 5.01; asym: 3.96; tree : (5 AND 6)
# >> G_3: init: 0.94; noise: 1.18; b: 0.65; m: 1.81; expr: 0.79; deg: 0.11; theta: 1.67; asym: 5.66; tree : (-3 OR -0)
# >> G_4: init: 1.16; noise: 0.97; b: 0.65; m: 9.18; expr: 0.99; deg: 0.09; theta: 6.38; asym: 5.00; tree : -6
# >> G_5: init: 3.04; noise: 0.93; b: 2.78; m: 6.36; expr: 1.04; deg: 0.12; theta: 6.40; asym: 4.57; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.49; noise: 1.00; b: 1.08; m: 2.55; expr: 0.78; deg: 0.11; theta: 5.04; asym: 4.59; tree : -7
#
# ======= GENERATION generation_g5 5416.170876522611 =======
# >> G_0: init: 0.91; noise: 1.12; b: 1.59; m: 8.47; expr: 1.00; deg: 0.11; theta: 6.08; asym: 5.83; tree : 6
# >> G_1: init: 0.42; noise: 1.07; b: 2.81; m: 9.96; expr: 0.96; deg: 0.11; theta: 0.22; asym: 4.57; tree : ((2 AND -1) AND -0)
# >> G_2: init: 0.22; noise: 0.92; b: 1.99; m: 4.50; expr: 1.04; deg: 0.11; theta: 5.01; asym: 3.96; tree : (5 AND 6)
# >> G_3: init: 0.94; noise: 1.18; b: 0.70; m: 1.81; expr: 0.69; deg: 0.12; theta: 1.67; asym: 6.51; tree : (-3 OR -0)
# >> G_4: init: 1.10; noise: 0.97; b: 0.61; m: 10.14; expr: 1.13; deg: 0.09; theta: 5.60; asym: 5.00; tree : -6
# >> G_5: init: 3.04; noise: 0.93; b: 2.78; m: 6.36; expr: 0.95; deg: 0.12; theta: 6.34; asym: 4.57; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.49; noise: 1.00; b: 1.08; m: 2.55; expr: 0.78; deg: 0.11; theta: 5.04; asym: 4.59; tree : -7
#
# ======= GENERATION generation_g6 6063.44309213302 =======
# >> G_0: init: 1.01; noise: 0.75; b: 1.63; m: 8.95; expr: 1.00; deg: 0.08; theta: 5.96; asym: 5.03; tree : (-1 AND 6)
# >> G_1: init: 0.47; noise: 0.93; b: 2.91; m: 9.19; expr: 1.00; deg: 0.11; theta: 0.20; asym: 5.12; tree : ((2 AND -3) AND -0)
# >> G_2: init: 0.16; noise: 1.25; b: 1.90; m: 5.59; expr: 0.91; deg: 0.09; theta: 4.10; asym: 4.81; tree : (5 AND 6)
# >> G_3: init: 0.60; noise: 0.91; b: 0.59; m: 2.13; expr: 0.77; deg: 0.14; theta: 1.38; asym: 5.62; tree : (5 OR -0)
# >> G_4: init: 1.26; noise: 1.11; b: 0.76; m: 8.73; expr: 0.88; deg: 0.10; theta: 6.09; asym: 5.08; tree : -6
# >> G_5: init: 2.66; noise: 1.03; b: 2.88; m: 4.72; expr: 0.89; deg: 0.11; theta: 6.40; asym: 5.00; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.44; noise: 0.90; b: 0.89; m: 2.45; expr: 0.90; deg: 0.11; theta: 5.93; asym: 5.05; tree : -0
#
# ======= GENERATION generation_g7 5879.209744950693 =======
# >> G_0: init: 0.89; noise: 1.22; b: 1.83; m: 9.00; expr: 1.10; deg: 0.10; theta: 5.92; asym: 4.93; tree : (-1 AND 6)
# >> G_1: init: 0.41; noise: 1.10; b: 2.81; m: 9.20; expr: 0.82; deg: 0.11; theta: 0.22; asym: 5.30; tree : ((2 AND -1) AND -0)
# >> G_2: init: 0.24; noise: 0.96; b: 2.23; m: 4.27; expr: 1.28; deg: 0.11; theta: 4.39; asym: 3.32; tree : (5 AND 6)
# >> G_3: init: 0.67; noise: 1.22; b: 0.60; m: 1.88; expr: 0.77; deg: 0.12; theta: 1.44; asym: 4.14; tree : (-3 OR -0)
# >> G_4: init: 1.18; noise: 0.95; b: 0.51; m: 8.77; expr: 0.98; deg: 0.09; theta: 5.84; asym: 4.48; tree : 5
# >> G_5: init: 3.43; noise: 0.85; b: 2.78; m: 8.70; expr: 1.09; deg: 0.11; theta: 6.34; asym: 5.56; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.52; noise: 1.06; b: 1.06; m: 2.26; expr: 0.61; deg: 0.11; theta: 3.96; asym: 4.15; tree : (-7 AND -5)
#
# ======= GENERATION generation_g8 6614.03084836072 =======
# >> G_0: init: 0.95; noise: 1.22; b: 1.83; m: 9.00; expr: 1.07; deg: 0.11; theta: 6.16; asym: 4.93; tree : (-1 AND 6)
# >> G_1: init: 0.38; noise: 0.95; b: 2.77; m: 9.18; expr: 0.64; deg: 0.10; theta: 0.24; asym: 5.30; tree : ((2 AND -6) AND -0)
# >> G_2: init: 0.26; noise: 0.96; b: 1.87; m: 5.63; expr: 1.26; deg: 0.11; theta: 4.58; asym: 3.97; tree : (5 AND 6)
# >> G_3: init: 0.67; noise: 1.28; b: 0.65; m: 1.88; expr: 0.77; deg: 0.12; theta: 1.81; asym: 3.58; tree : (-3 OR -0)
# >> G_4: init: 1.18; noise: 0.89; b: 0.45; m: 8.77; expr: 0.93; deg: 0.07; theta: 5.52; asym: 5.84; tree : 5
# >> G_5: init: 3.41; noise: 0.66; b: 2.78; m: 5.91; expr: 1.09; deg: 0.11; theta: 5.87; asym: 6.68; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.52; noise: 0.99; b: 1.30; m: 2.26; expr: 0.61; deg: 0.11; theta: 4.28; asym: 4.35; tree : (-7 AND -5)
#
# ======= GENERATION generation_g9 7012.100582306544 =======
# >> G_0: init: 1.06; noise: 1.22; b: 1.10; m: 10.03; expr: 1.10; deg: 0.11; theta: 5.92; asym: 5.05; tree : (-1 AND 6)
# >> G_1: init: 0.38; noise: 1.08; b: 2.77; m: 9.11; expr: 0.57; deg: 0.10; theta: 0.24; asym: 4.98; tree : ((2 AND -1) AND -0)
# >> G_2: init: 0.25; noise: 0.96; b: 2.46; m: 4.51; expr: 1.33; deg: 0.11; theta: 4.45; asym: 4.00; tree : (5 AND 6)
# >> G_3: init: 0.67; noise: 1.32; b: 0.58; m: 1.64; expr: 0.89; deg: 0.12; theta: 1.58; asym: 3.46; tree : -3
# >> G_4: init: 1.14; noise: 0.98; b: 0.45; m: 8.24; expr: 1.04; deg: 0.07; theta: 5.84; asym: 5.00; tree : 5
# >> G_5: init: 3.41; noise: 0.82; b: 3.32; m: 5.91; expr: 1.09; deg: 0.11; theta: 6.34; asym: 6.38; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.52; noise: 1.07; b: 0.96; m: 2.26; expr: 0.58; deg: 0.11; theta: 3.96; asym: 4.02; tree : ((-7 AND -4) AND -5)
#
# ======= GENERATION generation_g10 7687.023071605126 =======
# >> G_0: init: 0.94; noise: 0.97; b: 1.81; m: 7.87; expr: 1.14; deg: 0.10; theta: 5.58; asym: 4.27; tree : (-1 AND 6)
# >> G_1: init: 0.31; noise: 1.01; b: 2.80; m: 8.67; expr: 0.56; deg: 0.08; theta: 0.19; asym: 4.49; tree : ((2 AND -1) AND -0)
# >> G_2: init: 0.22; noise: 0.96; b: 1.89; m: 4.44; expr: 1.52; deg: 0.11; theta: 5.24; asym: 2.95; tree : (5 AND 6)
# >> G_3: init: 0.74; noise: 1.26; b: 0.68; m: 2.34; expr: 0.79; deg: 0.12; theta: 1.34; asym: 4.42; tree : (-0 OR -1)
# >> G_4: init: 1.13; noise: 1.03; b: 0.59; m: 10.23; expr: 1.01; deg: 0.07; theta: 7.55; asym: 5.50; tree : 5
# >> G_5: init: 3.58; noise: 0.80; b: 2.62; m: 8.58; expr: 1.27; deg: 0.13; theta: 5.90; asym: 6.87; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.60; noise: 0.81; b: 1.00; m: 2.30; expr: 0.61; deg: 0.14; theta: 4.42; asym: 4.10; tree : -7
#
# ======= GENERATION generation_g11 7779.397333660147 =======
# >> G_0: init: 1.14; noise: 0.97; b: 1.81; m: 8.24; expr: 1.14; deg: 0.10; theta: 6.19; asym: 4.90; tree : ((-1 OR -0) AND 6)
# >> G_1: init: 0.31; noise: 1.01; b: 2.80; m: 8.67; expr: 0.57; deg: 0.07; theta: 0.19; asym: 4.59; tree : ((2 AND -1) AND -0)
# >> G_2: init: 0.22; noise: 0.92; b: 1.89; m: 5.43; expr: 1.54; deg: 0.11; theta: 5.24; asym: 2.95; tree : (5 AND 6)
# >> G_3: init: 0.82; noise: 1.45; b: 0.68; m: 2.34; expr: 0.76; deg: 0.12; theta: 1.34; asym: 4.63; tree : (-0 OR -1)
# >> G_4: init: 1.13; noise: 1.03; b: 0.54; m: 10.23; expr: 1.01; deg: 0.06; theta: 7.55; asym: 5.50; tree : 5
# >> G_5: init: 3.60; noise: 0.96; b: 2.62; m: 7.96; expr: 1.27; deg: 0.13; theta: 5.79; asym: 7.25; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.66; noise: 0.81; b: 0.87; m: 2.82; expr: 0.61; deg: 0.14; theta: 4.07; asym: 4.33; tree : -7
#
# ======= GENERATION generation_g12 8940.83534577017 =======
# >> G_0: init: 0.97; noise: 0.97; b: 2.07; m: 7.83; expr: 1.25; deg: 0.10; theta: 5.58; asym: 5.25; tree : (-1 AND 6)
# >> G_1: init: 0.31; noise: 0.97; b: 2.80; m: 9.10; expr: 0.65; deg: 0.07; theta: 0.20; asym: 4.34; tree : ((2 AND -1) AND -0)
# >> G_2: init: 0.21; noise: 0.96; b: 1.79; m: 4.26; expr: 1.52; deg: 0.10; theta: 5.73; asym: 2.72; tree : 5
# >> G_3: init: 0.82; noise: 1.34; b: 0.68; m: 1.95; expr: 0.79; deg: 0.12; theta: 1.35; asym: 4.63; tree : (-0 OR -1)
# >> G_4: init: 1.23; noise: 0.92; b: 0.60; m: 10.66; expr: 1.01; deg: 0.08; theta: 6.72; asym: 6.09; tree : 5
# >> G_5: init: 4.21; noise: 0.67; b: 2.62; m: 8.24; expr: 1.17; deg: 0.13; theta: 5.81; asym: 9.28; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.58; noise: 0.93; b: 1.00; m: 2.66; expr: 0.67; deg: 0.14; theta: 4.07; asym: 3.80; tree : -7
#
# ======= GENERATION generation_g13 8957.576564365616 =======
# >> G_0: init: 0.88; noise: 0.97; b: 2.07; m: 8.04; expr: 1.25; deg: 0.10; theta: 5.31; asym: 4.71; tree : 6
# >> G_1: init: 0.26; noise: 1.20; b: 2.80; m: 9.10; expr: 0.57; deg: 0.06; theta: 0.20; asym: 3.84; tree : ((2 AND -1) AND -0)
# >> G_2: init: 0.24; noise: 1.16; b: 1.72; m: 6.14; expr: 1.47; deg: 0.09; theta: 5.15; asym: 2.92; tree : 5
# >> G_3: init: 0.93; noise: 1.34; b: 0.64; m: 2.34; expr: 0.79; deg: 0.12; theta: 1.23; asym: 3.33; tree : (-0 OR -1)
# >> G_4: init: 1.10; noise: 0.98; b: 0.55; m: 9.86; expr: 0.83; deg: 0.07; theta: 7.46; asym: 6.02; tree : 5
# >> G_5: init: 4.21; noise: 0.80; b: 2.79; m: 8.67; expr: 1.01; deg: 0.13; theta: 5.55; asym: 10.27; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.50; noise: 0.73; b: 1.04; m: 2.85; expr: 0.56; deg: 0.13; theta: 3.96; asym: 3.95; tree : -7
#
# ======= GENERATION generation_g14 9491.328139006402 =======
# >> G_0: init: 0.92; noise: 1.03; b: 1.67; m: 7.00; expr: 1.25; deg: 0.10; theta: 5.10; asym: 4.61; tree : 6
# >> G_1: init: 0.26; noise: 1.10; b: 2.80; m: 9.10; expr: 0.57; deg: 0.06; theta: 0.20; asym: 4.29; tree : ((2 AND -1) AND -0)
# >> G_2: init: 0.23; noise: 1.22; b: 1.43; m: 6.46; expr: 1.52; deg: 0.08; theta: 5.15; asym: 3.15; tree : 5
# >> G_3: init: 0.93; noise: 1.47; b: 0.64; m: 2.34; expr: 0.79; deg: 0.13; theta: 1.43; asym: 3.33; tree : (-0 OR -1)
# >> G_4: init: 1.10; noise: 0.98; b: 0.48; m: 8.35; expr: 0.83; deg: 0.06; theta: 6.85; asym: 6.58; tree : 5
# >> G_5: init: 4.81; noise: 0.80; b: 2.60; m: 8.67; expr: 1.01; deg: 0.12; theta: 5.43; asym: 12.31; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.54; noise: 0.83; b: 1.04; m: 2.99; expr: 0.55; deg: 0.11; theta: 4.10; asym: 3.95; tree : -7
#
# ======= GENERATION generation_g15 9424.136789578903 =======
# >> G_0: init: 0.87; noise: 0.64; b: 2.07; m: 8.45; expr: 1.26; deg: 0.10; theta: 5.31; asym: 4.73; tree : 6
# >> G_1: init: 0.21; noise: 1.12; b: 2.39; m: 9.10; expr: 0.66; deg: 0.06; theta: 0.20; asym: 3.84; tree : ((5 AND -1) AND -0)
# >> G_2: init: 0.22; noise: 1.02; b: 1.52; m: 5.25; expr: 1.47; deg: 0.10; theta: 5.15; asym: 3.12; tree : 5
# >> G_3: init: 1.02; noise: 1.23; b: 0.64; m: 2.32; expr: 0.79; deg: 0.13; theta: 1.39; asym: 3.33; tree : (-0 OR -1)
# >> G_4: init: 1.44; noise: 1.21; b: 0.56; m: 9.86; expr: 0.83; deg: 0.07; theta: 7.46; asym: 6.02; tree : 5
# >> G_5: init: 4.21; noise: 0.67; b: 3.03; m: 7.91; expr: 1.01; deg: 0.13; theta: 5.55; asym: 10.27; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.54; noise: 0.63; b: 1.12; m: 2.40; expr: 0.56; deg: 0.12; theta: 3.96; asym: 3.80; tree : -7
#
# ======= GENERATION generation_g16 9374.303994684882 =======
# >> G_0: init: 0.75; noise: 0.73; b: 2.39; m: 7.91; expr: 1.26; deg: 0.11; theta: 5.18; asym: 4.83; tree : 0
# >> G_1: init: 0.22; noise: 1.12; b: 2.36; m: 10.03; expr: 0.69; deg: 0.06; theta: 0.22; asym: 3.40; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.22; noise: 0.86; b: 1.68; m: 5.25; expr: 1.47; deg: 0.09; theta: 4.92; asym: 2.40; tree : 5
# >> G_3: init: 1.02; noise: 1.23; b: 0.61; m: 2.32; expr: 0.68; deg: 0.13; theta: 1.74; asym: 3.33; tree : (-3 OR -1)
# >> G_4: init: 1.23; noise: 1.45; b: 0.47; m: 9.86; expr: 0.79; deg: 0.07; theta: 7.18; asym: 6.02; tree : 5
# >> G_5: init: 4.58; noise: 0.66; b: 2.89; m: 7.91; expr: 1.11; deg: 0.13; theta: 5.74; asym: 9.83; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.44; noise: 0.67; b: 1.20; m: 2.81; expr: 0.49; deg: 0.12; theta: 3.96; asym: 4.20; tree : -7
#
# ======= GENERATION generation_g17 9389.677169969136 =======
# >> G_0: init: 0.81; noise: 0.67; b: 2.52; m: 7.91; expr: 1.26; deg: 0.11; theta: 5.18; asym: 4.83; tree : 6
# >> G_1: init: 0.22; noise: 1.11; b: 2.35; m: 10.03; expr: 0.69; deg: 0.06; theta: 0.22; asym: 3.13; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.23; noise: 0.86; b: 1.68; m: 5.25; expr: 1.38; deg: 0.09; theta: 4.92; asym: 2.40; tree : 5
# >> G_3: init: 1.02; noise: 1.23; b: 0.61; m: 2.25; expr: 0.68; deg: 0.13; theta: 1.74; asym: 3.33; tree : (-3 OR -1)
# >> G_4: init: 1.23; noise: 1.45; b: 0.47; m: 9.86; expr: 0.77; deg: 0.07; theta: 7.18; asym: 6.02; tree : 5
# >> G_5: init: 4.58; noise: 0.66; b: 2.89; m: 6.85; expr: 1.05; deg: 0.13; theta: 5.74; asym: 9.83; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.44; noise: 0.61; b: 1.14; m: 2.81; expr: 0.47; deg: 0.12; theta: 3.96; asym: 4.47; tree : -7
#
# ======= GENERATION generation_g18 9176.51850143729 =======
# >> G_0: init: 0.78; noise: 0.91; b: 2.23; m: 7.91; expr: 1.28; deg: 0.10; theta: 5.18; asym: 5.34; tree : 0
# >> G_1: init: 0.19; noise: 1.18; b: 2.35; m: 9.87; expr: 0.71; deg: 0.08; theta: 0.18; asym: 3.40; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.25; noise: 0.93; b: 1.68; m: 5.25; expr: 1.47; deg: 0.09; theta: 4.92; asym: 2.40; tree : 5
# >> G_3: init: 1.02; noise: 1.16; b: 0.61; m: 2.05; expr: 0.64; deg: 0.12; theta: 1.74; asym: 3.64; tree : (-3 OR -1)
# >> G_4: init: 1.23; noise: 1.47; b: 0.45; m: 10.27; expr: 0.76; deg: 0.08; theta: 7.04; asym: 6.92; tree : 5
# >> G_5: init: 5.09; noise: 0.43; b: 2.39; m: 7.97; expr: 1.08; deg: 0.13; theta: 5.74; asym: 9.83; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.43; noise: 0.61; b: 0.94; m: 2.81; expr: 0.49; deg: 0.12; theta: 3.96; asym: 4.83; tree : (-7 OR -2)
#
# ======= GENERATION generation_g19 8990.927608719576 =======
# >> G_0: init: 0.71; noise: 0.91; b: 2.21; m: 7.73; expr: 1.37; deg: 0.07; theta: 5.18; asym: 5.48; tree : 0
# >> G_1: init: 0.19; noise: 1.30; b: 2.52; m: 10.03; expr: 0.71; deg: 0.08; theta: 0.17; asym: 3.40; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.25; noise: 0.98; b: 1.74; m: 5.57; expr: 1.47; deg: 0.09; theta: 4.08; asym: 2.90; tree : 5
# >> G_3: init: 1.02; noise: 1.07; b: 0.64; m: 2.05; expr: 0.64; deg: 0.12; theta: 1.85; asym: 3.95; tree : (7 OR -1)
# >> G_4: init: 1.23; noise: 1.52; b: 0.45; m: 8.92; expr: 0.76; deg: 0.09; theta: 7.04; asym: 7.30; tree : 5
# >> G_5: init: 5.09; noise: 0.50; b: 2.39; m: 7.97; expr: 0.88; deg: 0.13; theta: 5.74; asym: 10.89; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.43; noise: 0.69; b: 0.86; m: 2.81; expr: 0.50; deg: 0.12; theta: 3.96; asym: 4.83; tree : (-7 OR -2)
#
# ======= GENERATION generation_g20 9443.77202244154 =======
# >> G_0: init: 0.72; noise: 0.91; b: 2.21; m: 7.81; expr: 1.37; deg: 0.07; theta: 5.18; asym: 4.39; tree : 0
# >> G_1: init: 0.17; noise: 1.30; b: 2.52; m: 8.44; expr: 0.75; deg: 0.08; theta: 0.17; asym: 3.40; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.26; noise: 1.13; b: 1.74; m: 5.57; expr: 1.56; deg: 0.09; theta: 4.08; asym: 2.90; tree : 5
# >> G_3: init: 1.02; noise: 1.07; b: 0.66; m: 2.01; expr: 0.62; deg: 0.12; theta: 1.65; asym: 3.95; tree : (7 OR -1)
# >> G_4: init: 1.23; noise: 1.37; b: 0.45; m: 8.92; expr: 0.76; deg: 0.09; theta: 7.04; asym: 6.14; tree : (5 OR 0)
# >> G_5: init: 4.52; noise: 0.42; b: 2.39; m: 9.35; expr: 0.88; deg: 0.13; theta: 5.74; asym: 10.89; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.43; noise: 0.70; b: 0.85; m: 2.81; expr: 0.50; deg: 0.12; theta: 3.96; asym: 4.83; tree : (-7 OR -2)
#
# ======= GENERATION generation_g21 9525.492027005566 =======
# >> G_0: init: 0.72; noise: 0.91; b: 2.21; m: 7.75; expr: 1.37; deg: 0.07; theta: 5.78; asym: 5.48; tree : 0
# >> G_1: init: 0.17; noise: 1.18; b: 2.52; m: 8.40; expr: 0.75; deg: 0.08; theta: 0.17; asym: 3.56; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.23; noise: 1.13; b: 1.74; m: 5.57; expr: 1.47; deg: 0.09; theta: 4.08; asym: 2.90; tree : 5
# >> G_3: init: 1.02; noise: 1.09; b: 0.66; m: 2.05; expr: 0.66; deg: 0.12; theta: 1.85; asym: 3.95; tree : (7 OR -1)
# >> G_4: init: 1.23; noise: 1.25; b: 0.45; m: 7.66; expr: 0.75; deg: 0.09; theta: 7.13; asym: 6.62; tree : (5 OR 0)
# >> G_5: init: 4.52; noise: 0.42; b: 2.39; m: 9.35; expr: 0.88; deg: 0.13; theta: 5.74; asym: 10.89; tree : ((0 OR -6) AND (1 OR 5))
# >> G_6: init: 0.43; noise: 0.69; b: 0.87; m: 2.81; expr: 0.50; deg: 0.12; theta: 4.41; asym: 4.83; tree : (-7 OR -2)
#
# ======= GENERATION generation_g22 9491.937346676834 =======
# >> G_0: init: 0.65; noise: 0.96; b: 2.25; m: 7.75; expr: 1.37; deg: 0.06; theta: 5.98; asym: 6.02; tree : 0
# >> G_1: init: 0.18; noise: 1.18; b: 1.87; m: 9.94; expr: 0.75; deg: 0.08; theta: 0.17; asym: 3.43; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.25; noise: 1.13; b: 1.46; m: 5.06; expr: 1.47; deg: 0.08; theta: 3.83; asym: 3.33; tree : 5
# >> G_3: init: 1.07; noise: 1.17; b: 0.50; m: 2.26; expr: 0.66; deg: 0.11; theta: 2.52; asym: 3.93; tree : (7 OR -1)
# >> G_4: init: 1.26; noise: 1.44; b: 0.51; m: 7.65; expr: 0.69; deg: 0.10; theta: 7.13; asym: 6.80; tree : (5 OR 0)
# >> G_5: init: 5.00; noise: 0.42; b: 2.37; m: 9.35; expr: 0.63; deg: 0.13; theta: 5.53; asym: 10.87; tree : ((-3 OR -6) AND (1 OR 5))
# >> G_6: init: 0.46; noise: 0.66; b: 0.76; m: 2.81; expr: 0.54; deg: 0.11; theta: 4.76; asym: 4.83; tree : (-7 OR (-2 AND 6))
#
# ======= GENERATION generation_g23 9407.48727315096 =======
# >> G_0: init: 0.65; noise: 0.96; b: 2.25; m: 7.75; expr: 1.37; deg: 0.06; theta: 5.98; asym: 6.02; tree : 0
# >> G_1: init: 0.18; noise: 1.18; b: 1.88; m: 9.94; expr: 0.75; deg: 0.08; theta: 0.17; asym: 3.43; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.23; noise: 1.13; b: 1.46; m: 5.06; expr: 1.48; deg: 0.08; theta: 3.83; asym: 3.33; tree : 5
# >> G_3: init: 1.07; noise: 1.17; b: 0.50; m: 2.26; expr: 0.66; deg: 0.11; theta: 2.52; asym: 3.93; tree : ((7 OR -1) OR -2)
# >> G_4: init: 1.26; noise: 1.44; b: 0.51; m: 7.89; expr: 0.69; deg: 0.10; theta: 7.13; asym: 6.80; tree : (5 OR 0)
# >> G_5: init: 5.63; noise: 0.42; b: 2.37; m: 9.35; expr: 0.63; deg: 0.13; theta: 5.53; asym: 10.87; tree : ((-3 OR -6) AND (1 OR 5))
# >> G_6: init: 0.46; noise: 0.66; b: 0.76; m: 2.81; expr: 0.54; deg: 0.11; theta: 4.76; asym: 4.83; tree : (-7 OR -2)
#
# ======= GENERATION generation_g24 9491.636803905447 =======
# >> G_0: init: 0.72; noise: 0.99; b: 2.25; m: 7.61; expr: 1.37; deg: 0.06; theta: 5.98; asym: 6.02; tree : 0
# >> G_1: init: 0.19; noise: 1.34; b: 1.43; m: 9.76; expr: 0.75; deg: 0.08; theta: 0.17; asym: 3.43; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.27; noise: 1.13; b: 1.64; m: 4.76; expr: 1.53; deg: 0.08; theta: 4.01; asym: 3.33; tree : 5
# >> G_3: init: 0.92; noise: 1.31; b: 0.50; m: 2.26; expr: 0.76; deg: 0.11; theta: 2.52; asym: 4.14; tree : ((7 OR -1) OR -2)
# >> G_4: init: 1.40; noise: 1.03; b: 0.49; m: 8.08; expr: 0.69; deg: 0.10; theta: 7.13; asym: 6.80; tree : (5 OR 0)
# >> G_5: init: 6.16; noise: 0.54; b: 1.97; m: 9.35; expr: 0.63; deg: 0.13; theta: 5.58; asym: 9.32; tree : ((-3 OR -6) AND (1 OR -2))
# >> G_6: init: 0.46; noise: 0.74; b: 0.68; m: 2.93; expr: 0.57; deg: 0.11; theta: 4.12; asym: 5.00; tree : (-7 OR -2)
#
# ======= GENERATION generation_g25 9488.875254407745 =======
# >> G_0: init: 0.65; noise: 0.84; b: 2.06; m: 7.75; expr: 1.37; deg: 0.05; theta: 5.98; asym: 6.02; tree : 0
# >> G_1: init: 0.18; noise: 1.18; b: 1.88; m: 9.94; expr: 0.75; deg: 0.08; theta: 0.17; asym: 3.43; tree : ((5 AND 6) AND -0)
# >> G_2: init: 0.29; noise: 1.13; b: 1.15; m: 4.15; expr: 1.48; deg: 0.08; theta: 4.05; asym: 3.69; tree : 5
# >> G_3: init: 0.92; noise: 0.90; b: 0.57; m: 2.26; expr: 0.76; deg: 0.10; theta: 2.52; asym: 3.48; tree : ((7 OR -1) OR -2)
# >> G_4: init: 1.26; noise: 1.44; b: 0.48; m: 7.89; expr: 0.73; deg: 0.09; theta: 8.22; asym: 8.05; tree : (5 OR (0 OR -7))
# >> G_5: init: 6.16; noise: 0.45; b: 1.78; m: 9.35; expr: 0.75; deg: 0.13; theta: 5.58; asym: 9.32; tree : ((-3 OR -6) AND (1 OR -2))
# >> G_6: init: 0.47; noise: 0.75; b: 0.76; m: 2.43; expr: 0.53; deg: 0.11; theta: 4.12; asym: 4.83; tree : (-7 OR -2)
