# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
import random
from lib.sde.mutate import mutate_gene4, mutate_tree

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None, nb_genes=4):
    return Solution(GRNMain(nb_genes, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
_MUTATE_FUNC = mutate_grn

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        global _MUTATE_FUNC
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**1.5))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init),
                                  new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e6
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    ObjectiveStep(name="The ONE", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 30
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 25
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, name=None):
    args = get_prun()
    args.cb_init = cb_init
    args.name = name
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    print("Final score", np.mean(scores), "+-", np.std(scores))
    return np.mean(scores), np.std(scores), max(p1)

# %%
def mutate_grn_verysparse(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.9)
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()

# %%
model = sm.StringModel("expfit_func{mutfunc}_i{i}")
mut_func = dict(
    fullctrl=lambda x: mutate_grn_verysparse(x),
    full005=lambda x: mutate_grn_verysparse(x, temperature=0.05),
    full02=lambda x: mutate_grn_verysparse(x, temperature=0.2),
)

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
)

# %%
# main loop
exporter = Exporter(name="exp_mutfunc7_280222")
for (funcname, func), i in product(mut_func.items(), range(10)):
    name = model.fill(mutfunc=funcname, i=i)
    print(name)
    if name in exporter.list():
        continue
    _MUTATE_FUNC = func
    res = get_score_parametrized(callback_init)
    exporter(res, name)
# Out:
# Exporting at output/exp_mutfunc7_280222
# expfit_funcfullctrl_i0
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 971.4307806183468 for generation 1
# ++ Best 1012.3725830020304 for generation 2
# ++ Best 1024.479740822548 for generation 6
# Step The ONE passed !
# ++ Best 1034.3772233983161 for generation 17
# ++ Best 1036.479740822548 for generation 46
# ++ Best 1038.3725830020305 for generation 77
# ++ Best 1048.3772233983161 for generation 82
# Step 100
# ++ Best 1064.0 for generation 107
# ++ Best 1071.0 for generation 130
# ++ Best 1072.3772233983161 for generation 132
# ++ Best 1082.430780618347 for generation 140
# ++ Best 1123.3772233983161 for generation 145
# ++ Best 1128.5171273060905 for generation 154
# ++ Best 1162.430780618347 for generation 155
# ++ Best 1164.8302205930993 for generation 196
# Step 200
# ++ Best 1201.8108532838846 for generation 202
# ++ Best 1246.9072043644996 for generation 203
# ++ Best 1475.180920072727 for generation 211
# ++ Best 1873.6324676318527 for generation 248
# OVER
# Final score 1432.9211747707886 +- 99.18227059225266
# expfit_funcfullctrl_i1
# Step 0
# ++ Best 1004.0 for generation 0
# ++ Best 1012.479740822548 for generation 1
# ++ Best 1020.4307806183471 for generation 3
# ++ Best 1020.5171273060907 for generation 43
# ++ Best 1021.4307806183471 for generation 48
# ++ Best 1036.0 for generation 52
# ++ Best 1046.632467631853 for generation 69
# ++ Best 1080.430780618347 for generation 78
# ++ Best 1093.430780618347 for generation 97
# Step 100
# ++ Best 1095.430780618347 for generation 144
# Step 200
# ++ Best 1150.3772233983161 for generation 229
# ++ Best 1167.5171273060905 for generation 279
# OVER
# Final score 1116.7459731806637 +- 28.242742419036713
# expfit_funcfullctrl_i2
# Step 0
# ++ Best 993.0 for generation 0
# ++ Best 1030.0 for generation 1
# ++ Best 1032.479740822548 for generation 28
# ++ Best 1039.819660112501 for generation 54
# ++ Best 1044.0 for generation 79
# ++ Best 1046.0 for generation 95
# Step 100
# Step 200
# ++ Best 1155.5171273060905 for generation 269
# ++ Best 1215.180920072727 for generation 277
# ++ Best 1222.9052498068888 for generation 297
# OVER
# Final score 1151.3036300419344 +- 60.09788909330706
# expfit_funcfullctrl_i3
# Step 0
# ++ Best 782.4719062652532 for generation 0
# ++ Best 994.9999999999999 for generation 1
# ++ Best 1016.0 for generation 5
# ++ Best 1031.0 for generation 34
# ++ Best 1172.5171273060905 for generation 59
# ++ Best 1225.3772233983161 for generation 68
# ++ Best 1310.430780618347 for generation 80
# ++ Best 1350.430780618347 for generation 83
# ++ Best 1352.0 for generation 90
# Step 100
# ++ Best 1480.3772233983163 for generation 107
# ++ Best 1523.5171273060905 for generation 113
# ++ Best 1570.430780618347 for generation 116
# ++ Best 1627.3772233983163 for generation 132
# ++ Best 1679.3772233983161 for generation 134
# ++ Best 1684.6324676318527 for generation 172
# ++ Best 1720.9052498068886 for generation 193
# Step 200
# ++ Best 1767.0 for generation 218
# ++ Best 1800.5572809000084 for generation 286
# ++ Best 1862.0 for generation 293
# OVER
# Final score 1519.1502131781635 +- 511.4500300934186
# expfit_funcfullctrl_i4
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 931.6324676318527 for generation 1
# ++ Best 983.4307806183471 for generation 2
# ++ Best 1009.3030615433008 for generation 4
# ++ Best 1121.3772233983161 for generation 5
# ++ Best 1262.127833418968 for generation 43
# Step 100
# Step 200
# ++ Best 1264.9806640162437 for generation 237
# ++ Best 1318.0 for generation 245
# OVER
# Final score 992.339691162397 +- 156.7982707035906
# expfit_funcfullctrl_i5
# Step 0
# ++ Best 979.5171273060906 for generation 0
# ++ Best 1009.8196601125011 for generation 3
# ++ Best 1017.4797408225479 for generation 28
# ++ Best 1020.8196601125011 for generation 80
# ++ Best 1021.4797408225479 for generation 81
# ++ Best 1023.3725830020305 for generation 89
# Step 100
# ++ Best 1040.8038475772933 for generation 106
# ++ Best 1270.6167965851648 for generation 145
# ++ Best 1313.0 for generation 151
# Step 200
# ++ Best 1340.430780618347 for generation 281
# OVER
# Final score 1165.0197964999222 +- 45.96847089514007
# expfit_funcfullctrl_i6
# Step 0
# ++ Best 798.9372075915135 for generation 0
# ++ Best 979.5171273060906 for generation 1
# ++ Best 996.5171273060906 for generation 2
# ++ Best 1014.3030615433009 for generation 19
# ++ Best 1019.0000000000001 for generation 40
# ++ Best 1045.430780618347 for generation 72
# Step 100
# ++ Best 1065.1809200727273 for generation 109
# ++ Best 1093.430780618347 for generation 130
# ++ Best 1094.9072043644999 for generation 134
# ++ Best 1138.430780618347 for generation 150
# Step 200
# ++ Best 1143.430780618347 for generation 275
# OVER
# Final score 1056.1678794616662 +- 39.622351562812256
# expfit_funcfullctrl_i7
# Step 0
# ++ Best 932.1809200727271 for generation 0
# ++ Best 983.4307806183471 for generation 2
# ++ Best 991.3772233983163 for generation 6
# ++ Best 1030.0 for generation 25
# ++ Best 1033.0 for generation 56
# Step 100
# Step 200
# ++ Best 1042.3772233983161 for generation 281
# ++ Best 1072.3030615433008 for generation 288
# OVER
# Final score 1043.7678336609029 +- 15.7070921574589
# expfit_funcfullctrl_i8
# Step 0
# ++ Best 983.3772233983162 for generation 0
# ++ Best 998.3772233983162 for generation 1
# ++ Best 1038.479740822548 for generation 5
# ++ Best 1041.3725830020305 for generation 38
# ++ Best 1051.0 for generation 48
# ++ Best 1051.3772233983161 for generation 66
# ++ Best 1081.430780618347 for generation 73
# ++ Best 1085.0 for generation 78
# ++ Best 1114.0 for generation 82
# ++ Best 1133.430780618347 for generation 84
# Step 100
# ++ Best 1187.3772233983161 for generation 104
# ++ Best 1277.430780618347 for generation 109
# ++ Best 1350.3772233983163 for generation 111
# ++ Best 1363.632467631853 for generation 127
# ++ Best 1370.3725830020305 for generation 135
# ++ Best 1392.0177871865296 for generation 143
# ++ Best 1409.430780618347 for generation 186
# Step 200
# ++ Best 1428.632467631853 for generation 242
# ++ Best 1453.0 for generation 243
# ++ Best 1474.6958749638075 for generation 265
# OVER
# Final score 1312.0852930654098 +- 53.62953327389864
# expfit_funcfullctrl_i9
# Step 0
# ++ Best 1013.4307806183471 for generation 0
# ++ Best 1021.5171273060905 for generation 4
# ++ Best 1043.479740822548 for generation 48
# ++ Best 1052.5171273060905 for generation 51
# ++ Best 1060.430780618347 for generation 54
# ++ Best 1067.5171273060905 for generation 60
# ++ Best 1071.430780618347 for generation 63
# ++ Best 1115.127833418968 for generation 82
# Step 100
# ++ Best 1122.430780618347 for generation 152
# Step 200
# ++ Best 1132.6167965851648 for generation 231
# ++ Best 1133.6167965851648 for generation 232
# ++ Best 1144.430780618347 for generation 244
# ++ Best 1153.9072043644996 for generation 252
# ++ Best 1166.430780618347 for generation 257
# ++ Best 1197.5572809000084 for generation 258
# ++ Best 1199.430780618347 for generation 269
# ++ Best 1204.9052498068888 for generation 272
# ++ Best 1223.430780618347 for generation 284
# OVER
# Final score 1180.413334085441 +- 12.740944052491908
# expfit_funcfull005_i0
# Step 0
# ++ Best 836.6832327484502 for generation 0
# ++ Best 1035.0 for generation 1
# ++ Best 1036.1715728752538 for generation 40
# ++ Best 1037.1715728752538 for generation 43
# ++ Best 1038.0 for generation 52
# ++ Best 1040.0 for generation 92
# Step 100
# ++ Best 1042.0 for generation 109
# Step 200
# OVER
# Final score 1025.3322064172776 +- 16.17685930002381
# expfit_funcfull005_i1
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 525.8115118112678 for generation 1
# ++ Best 1274.5171273060905 for generation 2
# ++ Best 1405.8108532838846 for generation 25
# ++ Best 1438.8379265803828 for generation 35
# ++ Best 1486.632467631853 for generation 43
# ++ Best 1575.6167965851648 for generation 48
# Step 100
# Step 200
# OVER
# Final score 1216.0423955468837 +- 255.35774198384618
# expfit_funcfull005_i2
# Step 0
# ++ Best 982.5171273060907 for generation 0
# ++ Best 1021.8038475772934 for generation 1
# ++ Best 1037.3772233983161 for generation 2
# ++ Best 1037.430780618347 for generation 28
# ++ Best 1077.5171273060905 for generation 37
# ++ Best 1090.3772233983161 for generation 43
# ++ Best 1104.5171273060905 for generation 77
# ++ Best 1138.9072043644996 for generation 94
# ++ Best 1154.8108532838846 for generation 95
# Step 100
# Step 200
# OVER
# Final score 961.5531800625365 +- 222.8285440013531
# expfit_funcfull005_i3
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 972.4307806183471 for generation 4
# ++ Best 1007.3725830020305 for generation 5
# ++ Best 1022.1715728752538 for generation 13
# ++ Best 1026.1715728752538 for generation 14
# ++ Best 1029.479740822548 for generation 59
# ++ Best 1049.3725830020305 for generation 61
# ++ Best 1059.430780618347 for generation 66
# ++ Best 1090.3725830020305 for generation 67
# ++ Best 1096.5171273060905 for generation 77
# ++ Best 1138.3772233983161 for generation 80
# ++ Best 1227.5171273060905 for generation 85
# Step 100
# ++ Best 1233.9072043644996 for generation 121
# ++ Best 1289.632467631853 for generation 138
# Step 200
# ++ Best 1292.5171273060905 for generation 213
# ++ Best 1312.127833418968 for generation 232
# ++ Best 1348.5171273060905 for generation 277
# OVER
# Final score 1201.4757316656269 +- 60.173296331948606
# expfit_funcfull005_i4
# Step 0
# ++ Best 585.7433661044786 for generation 0
# ++ Best 976.4307806183471 for generation 1
# ++ Best 1002.0000000000001 for generation 2
# ++ Best 1020.8038475772934 for generation 10
# ++ Best 1024.1715728752538 for generation 12
# ++ Best 1024.8038475772933 for generation 41
# ++ Best 1026.0 for generation 49
# ++ Best 1031.0 for generation 50
# ++ Best 1037.1715728752538 for generation 61
# Step 100
# Step 200
# OVER
# Final score 1015.0103777249233 +- 11.169751300646148
# expfit_funcfull005_i5
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 822.9806640162438 for generation 1
# ++ Best 986.430780618347 for generation 2
# ++ Best 1004.3030615433009 for generation 3
# ++ Best 1070.7659104059273 for generation 9
# ++ Best 1086.6167965851648 for generation 38
# ++ Best 1094.8108532838846 for generation 42
# ++ Best 1095.430780618347 for generation 64
# ++ Best 1107.6167965851648 for generation 81
# ++ Best 1115.430780618347 for generation 83
# Step 100
# ++ Best 1144.3772233983161 for generation 155
# ++ Best 1292.68323274845 for generation 175
# Step 200
# ++ Best 1302.9806640162437 for generation 204
# ++ Best 1491.6958749638075 for generation 249
# ++ Best 1511.4254926465876 for generation 261
# OVER
# Final score 1029.5375964982106 +- 266.37461065693174
# expfit_funcfull005_i6
# Step 0
# ++ Best 979.5171273060906 for generation 0
# ++ Best 1067.0 for generation 6
# ++ Best 1084.430780618347 for generation 28
# ++ Best 1092.9052498068888 for generation 73
# ++ Best 1093.9052498068888 for generation 74
# ++ Best 1095.3772233983161 for generation 77
# Step 100
# ++ Best 1098.3772233983161 for generation 182
# Step 200
# ++ Best 1113.430780618347 for generation 222
# ++ Best 1118.9072043644999 for generation 283
# ++ Best 1132.3725830020305 for generation 287
# OVER
# Final score 1068.5782848018903 +- 14.177379691860517
# expfit_funcfull005_i7
# Step 0
# ++ Best 990.5171273060906 for generation 0
# ++ Best 1009.0 for generation 4
# ++ Best 1022.8196601125011 for generation 7
# ++ Best 1058.3772233983161 for generation 17
# ++ Best 1060.430780618347 for generation 32
# ++ Best 1068.430780618347 for generation 40
# ++ Best 1090.5171273060905 for generation 46
# ++ Best 1097.5171273060905 for generation 65
# ++ Best 1097.6167965851648 for generation 75
# Step 100
# ++ Best 1113.5171273060905 for generation 102
# ++ Best 1192.430780618347 for generation 112
# Step 200
# ++ Best 1217.0 for generation 244
# OVER
# Final score 1111.4198454701072 +- 37.94724164203023
# expfit_funcfull005_i8
# Step 0
# ++ Best 994.5171273060906 for generation 0
# ++ Best 1020.8196601125011 for generation 6
# ++ Best 1078.430780618347 for generation 12
# ++ Best 1108.5171273060905 for generation 26
# ++ Best 1112.0 for generation 38
# ++ Best 1154.7659104059273 for generation 39
# ++ Best 1162.9072043644996 for generation 58
# ++ Best 1184.430780618347 for generation 69
# ++ Best 1212.7659104059273 for generation 94
# Step 100
# ++ Best 1231.0 for generation 112
# Step 200
# OVER
# Final score 1085.8426942338924 +- 37.90574176811195
# expfit_funcfull005_i9
# Step 0
# ++ Best 955.4254926465876 for generation 0
# ++ Best 971.4307806183468 for generation 3
# ++ Best 985.430780618347 for generation 4
# ++ Best 987.5171273060906 for generation 7
# ++ Best 1019.0000000000001 for generation 8
# ++ Best 1159.5171273060905 for generation 15
# ++ Best 1278.6167965851648 for generation 25
# ++ Best 1291.3772233983163 for generation 70
# Step 100
# ++ Best 1348.6958749638075 for generation 124
# ++ Best 1470.0 for generation 126
# Step 200
# OVER
# Final score 1186.5731243681298 +- 94.35417781852566
# expfit_funcfull02_i0
# Step 0
# ++ Best 592.1090832097385 for generation 0
# ++ Best 996.3772233983162 for generation 1
# ++ Best 1005.3030615433008 for generation 5
# ++ Best 1054.0 for generation 9
# ++ Best 1088.0 for generation 47
# ++ Best 1106.8038475772933 for generation 52
# ++ Best 1435.430780618347 for generation 68
# ++ Best 1468.819660112501 for generation 75
# ++ Best 1657.4307806183472 for generation 78
# ++ Best 1710.3725830020305 for generation 82
# Step 100
# ++ Best 1724.430780618347 for generation 180
# ++ Best 1760.479740822548 for generation 189
# ++ Best 1828.6324676318527 for generation 193
# Step 200
# ++ Best 1957.9052498068886 for generation 243
# OVER
# Final score 363.4910521440895 +- 727.5673117777944
# expfit_funcfull02_i1
# Step 0
# ++ Best 1089.3772233983161 for generation 0
# ++ Best 1266.3772233983163 for generation 33
# ++ Best 1307.5171273060905 for generation 37
# ++ Best 1328.0 for generation 42
# ++ Best 1521.3772233983163 for generation 46
# ++ Best 1667.0000000000002 for generation 52
# ++ Best 1775.9343726813183 for generation 74
# ++ Best 1980.0 for generation 89
# Step 100
# ++ Best 2371.842953458653 for generation 105
# Step 200
# OVER
# Final score 1840.9559138756345 +- 177.55451982038758
# expfit_funcfull02_i2
# Step 0
# ++ Best 766.4462449467756 for generation 0
# ++ Best 983.5171273060906 for generation 1
# ++ Best 1019.4797408225479 for generation 5
# ++ Best 1153.430780618347 for generation 17
# ++ Best 1179.430780618347 for generation 31
# ++ Best 1206.5171273060905 for generation 32
# ++ Best 1290.5171273060905 for generation 34
# ++ Best 1322.430780618347 for generation 41
# ++ Best 1382.430780618347 for generation 55
# ++ Best 1430.430780618347 for generation 77
# ++ Best 1536.5572809000084 for generation 79
# Step 100
# ++ Best 1563.4254926465876 for generation 116
# ++ Best 1584.3772233983163 for generation 153
# ++ Best 1636.3772233983163 for generation 167
# Step 200
# ++ Best 1639.9052498068886 for generation 249
# OVER
# Final score 1470.7059399479215 +- 64.5722448130221
# expfit_funcfull02_i3
# Step 0
# ++ Best 977.5171273060906 for generation 0
# ++ Best 1008.5171273060907 for generation 1
# ++ Best 1010.3772233983163 for generation 10
# ++ Best 1026.0 for generation 13
# ++ Best 1033.8038475772933 for generation 31
# ++ Best 1037.8038475772933 for generation 60
# ++ Best 1043.8038475772933 for generation 81
# Step 100
# ++ Best 1045.3725830020305 for generation 165
# ++ Best 1090.430780618347 for generation 192
# ++ Best 1117.5171273060905 for generation 198
# Step 200
# ++ Best 1133.430780618347 for generation 231
# ++ Best 1152.430780618347 for generation 237
# ++ Best 1178.430780618347 for generation 257
# ++ Best 1209.5171273060905 for generation 262
# ++ Best 1301.3772233983163 for generation 263
# ++ Best 1307.6958749638075 for generation 272
# ++ Best 1311.632467631853 for generation 276
# ++ Best 1332.5171273060905 for generation 290
# OVER
# Final score 1249.164554745927 +- 40.941411257144985
# expfit_funcfull02_i4
# Step 0
# ++ Best 1004.3725830020306 for generation 0
# ++ Best 1220.127833418968 for generation 5
# ++ Best 1226.180920072727 for generation 40
# ++ Best 1233.180920072727 for generation 52
# ++ Best 1266.430780618347 for generation 56
# Step 100
# ++ Best 1278.430780618347 for generation 136
# ++ Best 1305.5171273060905 for generation 138
# ++ Best 1382.0 for generation 142
# ++ Best 1387.0177871865296 for generation 170
# Step 200
# ++ Best 1517.3725830020305 for generation 226
# OVER
# Final score 1309.8685982402155 +- 55.66457628355254
# expfit_funcfull02_i5
# Step 0
# ++ Best 941.9072043644998 for generation 0
# ++ Best 988.3772233983162 for generation 1
# ++ Best 1016.3725830020304 for generation 4
# ++ Best 1020.3030615433009 for generation 7
# ++ Best 1025.819660112501 for generation 28
# ++ Best 1036.0 for generation 35
# ++ Best 1037.1715728752538 for generation 62
# ++ Best 1038.0 for generation 79
# Step 100
# ++ Best 1039.0 for generation 101
# ++ Best 1047.0 for generation 106
# Step 200
# ++ Best 1084.430780618347 for generation 295
# ++ Best 1096.3772233983161 for generation 297
# OVER
# Final score 1097.9734942606356 +- 20.651649449624053
# expfit_funcfull02_i6
# Step 0
# ++ Best 997.5171273060907 for generation 0
# ++ Best 1009.479740822548 for generation 2
# ++ Best 1012.0000000000001 for generation 45
# ++ Best 1019.3725830020306 for generation 48
# ++ Best 1037.3030615433008 for generation 60
# ++ Best 1339.5171273060905 for generation 78
# ++ Best 1398.430780618347 for generation 92
# Step 100
# ++ Best 1400.9072043644996 for generation 136
# ++ Best 1464.4254926465876 for generation 154
# Step 200
# ++ Best 1519.429432664245 for generation 243
# ++ Best 1526.4244923464075 for generation 281
# ++ Best 1617.4450780624625 for generation 285
# ++ Best 1648.1541758681326 for generation 294
# OVER
# Final score 1342.5753121233736 +- 108.5486901030076
# expfit_funcfull02_i7
# Step 0
# ++ Best 941.9072043644998 for generation 0
# ++ Best 998.3772233983162 for generation 1
# ++ Best 1013.5171273060906 for generation 7
# ++ Best 1036.0 for generation 26
# ++ Best 1125.5171273060905 for generation 29
# ++ Best 1171.430780618347 for generation 46
# ++ Best 1313.430780618347 for generation 57
# ++ Best 1568.9052498068886 for generation 73
# ++ Best 1652.7522678871787 for generation 97
# Step 100
# ++ Best 1671.9372075915132 for generation 159
# Step 200
# OVER
# Final score 1371.2041227936093 +- 134.6589264973993
# expfit_funcfull02_i8
# Step 0
# ++ Best 981.5171273060907 for generation 0
# ++ Best 986.3772233983161 for generation 2
# ++ Best 1038.0 for generation 6
# ++ Best 1195.446609406726 for generation 18
# ++ Best 1250.784233781151 for generation 29
# ++ Best 1319.4254926465876 for generation 31
# ++ Best 1359.703884586921 for generation 42
# ++ Best 1410.5572809000084 for generation 67
# Step 100
# ++ Best 1413.9052498068886 for generation 197
# Step 200
# ++ Best 1445.6167965851648 for generation 229
# ++ Best 1499.6958749638075 for generation 254
# OVER
# Final score 1326.0000990577742 +- 60.695743404400424
# expfit_funcfull02_i9
# Step 0
# ++ Best 595.5747697696941 for generation 0
# ++ Best 992.0 for generation 2
# ++ Best 1155.430780618347 for generation 9
# ++ Best 1357.6167965851648 for generation 27
# ++ Best 1376.430780618347 for generation 40
# ++ Best 1403.5171273060905 for generation 58
# ++ Best 1410.9052498068886 for generation 68
# ++ Best 1447.127833418968 for generation 74
# ++ Best 1488.9072043644996 for generation 94
# Step 100
# ++ Best 1534.0 for generation 103
# ++ Best 1587.1809200727268 for generation 111
# ++ Best 1650.703884586921 for generation 113
# ++ Best 1673.7871501443146 for generation 160
# ++ Best 1695.0 for generation 178
# ++ Best 1769.0000000000002 for generation 184
# Step 200
# OVER
# Final score 1457.643614601655 +- 487.786894918989

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#     mutfunc  i         mean          sd          max
# 0    full02  0   363.491052  727.567312  1957.905250
# 1   full005  7  1111.419845   37.947242  1217.000000
# 2    full02  9  1457.643615  487.786895  1769.000000
# 3   full005  3  1201.475732   60.173296  1348.517127
# 4  fullctrl  7  1043.767834   15.707092  1072.303062

# %%
new_df = df.groupby(["mutfunc"]).mean()
new_df
# Out:
#                  mean          sd          max
# mutfunc
# full005   1090.136544  101.646534  1271.991443
# full02    1282.958270  187.864197  1650.470765
# fullctrl  1196.991482  102.343959  1369.834612

# %%
for i, row in new_df.iterrows():
    print(row.name, row["mean"], row["mean"] - row.sd / np.sqrt(10), row["mean"] + row.sd / np.sqrt(10))
# Out:
# full005 1090.1365436789476 1057.99308716662 1122.2800001912753
# full02 1282.9582701790837 1223.5503949001845 1342.3661454579828
# fullctrl 1196.991481910729 1164.6274802376781 1229.3554835837797

# %%
row.name
# Out:
# 'fullctrl'
