# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 100 - 1 * delta_late - 0.5 * delta_early)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r21"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r21
# [definition]
#
#
# Step 3 passed !
# [out] Step 0
# [out] ++ Best 71.71616186536465 for generation 0
# [out] ++ Best 71.7467741102626 for generation 11
# [out] ++ Best 71.76718227352791 for generation 15
# [out] ++ Best 71.89983533475241 for generation 16
# [out] ++ Best 71.91003941638505 for generation 17
# [out] ++ Best 72.0937128857728 for generation 19
# [out] ++ Best 72.5733047225075 for generation 36
# Saving ...
# [out] ++ Best 72.97126390618098 for generation 54
# [out] ++ Best 73.0528965592422 for generation 89
# Saving ...
# [out] Step 100
# [out] ++ Best 73.1141210490381 for generation 126
# [out] ++ Best 73.32502739639573 for generation 140
# [out] ++ Best 74.39983533475241 for generation 149
# Saving ...
# [out] ++ Best 85.11011629841703 for generation 199
# Saving ...
# [out] Step 200
# [out] ++ Best 85.77338160453948 for generation 210
# [out] ++ Best 86.14072854331499 for generation 215
# Saving ...
# Saving ...
# [out] Step 300
# [out] ++ Best 91.60939624655035 for generation 302
# Saving ...
# Saving ...
# [out] Step 400
# Saving ...
# Saving ...
# [out] Step 500
# [out] ++ Best 91.95633502206056 for generation 513
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# Saving ...
# Saving ...
# [out] Step 800
# [out] ++ Best 92.04889180862112 for generation 845
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# [out] ++ Best 92.0991921649177 for generation 1272
# Saving ...
# [out] Step 1300
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# [out] ++ Best 92.38490645063199 for generation 2407
# [out] ++ Best 92.43664691066192 for generation 2410
# [out] ++ Best 92.65093262494766 for generation 2417
# Saving ...
# [out] ++ Best 92.71143706287688 for generation 2451
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r21

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))
# Out:
# (88.02776359348911,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             2.0              9.0                 46.0             7.0
# 56.50             2.0             10.0                 46.0             8.0
# 56.75             2.0             10.0                 47.0             8.0
# 57.00             2.0             10.0                 49.0             8.0
# ...               ...              ...                  ...             ...
# 85.00            23.0           1293.0                 59.0          1270.0
# 85.25            23.0           1296.0                 59.0          1273.0
# 85.50            23.0           1300.0                 58.0          1277.0
# 85.75            23.0           1303.0                 55.0          1280.0
# 86.00            23.0           1306.0                 56.0          1283.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            55.0
# 56.50  56.50            56.0
# 56.75  56.75            57.0
# 57.00  57.00            59.0
# ...      ...             ...
# 85.00  85.00          1352.0
# 85.25  85.25          1355.0
# 85.50  85.50          1358.0
# 85.75  85.75          1358.0
# 86.00  86.00          1362.0
#
# [121 rows x 6 columns])
# (64.9307946962873,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             3.0              7.0                 47.0             4.0
# 56.50             3.0              7.0                 49.0             4.0
# 56.75             3.0              7.0                 50.0             4.0
# 57.00             3.0              8.0                 52.0             5.0
# 57.25             3.0              8.0                 54.0             5.0
# 57.50             3.0              8.0                 56.0             5.0
# 57.75             3.0              8.0                 63.0             5.0
# 58.00             4.0              9.0                 69.0             5.0
# 58.25             4.0              9.0                 76.0             5.0
# 58.50             4.0              9.0                 82.0             5.0
# 58.75             4.0             10.0                 89.0             6.0
# 59.00             4.0             11.0                 92.0             7.0
# 59.25             4.0             11.0                 95.0             7.0
# 59.50             4.0             11.0                 98.0             7.0
# 59.75             4.0             11.0                104.0             7.0
# 60.00             4.0             11.0                107.0             7.0
        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             0.0             14.0                 41.0            14.0
# 56.50             0.0             14.0                 41.0            14.0
# 56.75             0.0             14.0                 41.0            14.0
# 57.00             0.0             14.0                 43.0            14.0
# ...               ...              ...                  ...             ...
# 85.00            20.0           1127.0                 48.0          1107.0
# 85.25            20.0           1128.0                 47.0          1108.0
# 85.50            20.0           1128.0                 49.0          1108.0
# 85.75            20.0           1130.0                 50.0          1110.0
# 86.00            20.0           1133.0                 47.0          1113.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            55.0
# 56.50  56.50            55.0
# 56.75  56.75            55.0
# 57.00  57.00            57.0
# ...      ...             ...
# 85.00  85.00          1175.0
# 85.25  85.25          1175.0
# 85.50  85.50          1177.0
# 85.75  85.75          1180.0
# 86.00  86.00          1180.0
#
# [121 rows x 6 columns])
# (91.22164114450953,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             0.0             13.0                 41.0            13.0
# 56.50             0.0             14.0                 41.0            14.0
# 56.75             0.0             14.0                 42.0            14.0
# 57.00             0.0             14.0                 44.0            14.0
# ...               ...              ...                  ...             ...
# 85.00            20.0           1134.0                 50.0          1114.0
# 85.25            20.0           1136.0                 50.0          1116.0
# 85.50            20.0           1138.0                 50.0          1118.0
# 85.75            20.0           1142.0                 46.0          1122.0
# 86.00            20.0           1145.0                 45.0          1125.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            54.0
# 56.50  56.50            55.0
# 56.75  56.75            56.0
# 57.00  57.00            58.0
# ...      ...             ...
# 85.00  85.00          1184.0
# 85.25  85.25          1186.0
# 85.50  85.50          1188.0
# 85.75  85.75          1188.0
# 86.00  86.00          1190.0
#
# [121 rows x 6 columns])

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.07; m: 1.17; expr: 1.00; deg: 0.10; theta: 2.18; asym: 5.00; tree : (-0 AND (-5 AND 1))
# >> G_1: init: 2.21; noise: 1.00; b: 0.11; m: 3.73; expr: 1.00; deg: 0.10; theta: 4.49; asym: 5.00; tree : (-4 AND (-2 AND -1))
# >> G_2: init: 0.71; noise: 1.00; b: 0.31; m: 9.22; expr: 1.00; deg: 0.10; theta: 7.78; asym: 5.00; tree : 5
# >> G_3: init: 0.43; noise: 1.00; b: 2.16; m: 2.72; expr: 1.00; deg: 0.10; theta: 8.19; asym: 5.00; tree : -2
# >> G_4: init: 0.96; noise: 1.00; b: 0.58; m: 1.02; expr: 0.89; deg: 0.10; theta: 0.40; asym: 5.00; tree : ((1 AND 5) AND (-4 OR -3))
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.00; noise: 1.00; b: 2.56; m: 8.89; expr: 1.00; deg: 0.10; theta: 3.50; asym: 4.73; tree : (5 AND 4)
# >> G_1: init: 0.20; noise: 1.04; b: 1.15; m: 3.34; expr: 1.00; deg: 0.10; theta: 2.36; asym: 5.00; tree : 1
# >> G_2: init: 0.22; noise: 0.94; b: 2.44; m: 3.83; expr: 1.00; deg: 0.10; theta: 5.81; asym: 5.00; tree : 0
# >> G_3: init: 1.15; noise: 1.15; b: 1.72; m: 9.09; expr: 1.00; deg: 0.10; theta: 9.36; asym: 5.00; tree : ((0 OR 3) AND -1)
# >> G_4: init: 1.88; noise: 1.00; b: 0.29; m: 6.51; expr: 1.00; deg: 0.10; theta: 9.93; asym: 5.00; tree : (0 OR 4)
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.42; m: 7.35; expr: 1.00; deg: 0.10; theta: 3.06; asym: 5.00; tree : (1 AND 4)
# >> G_1: init: 0.35; noise: 1.00; b: 2.73; m: 3.86; expr: 1.00; deg: 0.10; theta: 7.79; asym: 5.00; tree : -1
# >> G_2: init: 1.37; noise: 1.00; b: 3.22; m: 2.82; expr: 1.00; deg: 0.10; theta: 1.13; asym: 5.00; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.00; b: 1.61; m: 8.29; expr: 1.00; deg: 0.10; theta: 0.89; asym: 5.00; tree : -5
# >> G_4: init: 0.21; noise: 1.00; b: 0.35; m: 2.76; expr: 1.00; deg: 0.10; theta: 7.97; asym: 5.00; tree : ((-5 OR 4) OR -2)
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.42; m: 7.35; expr: 1.00; deg: 0.10; theta: 3.06; asym: 5.00; tree : (1 AND 4)
# >> G_1: init: 0.35; noise: 1.00; b: 2.74; m: 4.42; expr: 1.00; deg: 0.10; theta: 7.79; asym: 5.00; tree : -1
# >> G_2: init: 1.37; noise: 1.00; b: 3.22; m: 2.82; expr: 1.00; deg: 0.10; theta: 1.13; asym: 5.00; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 1.41; m: 8.29; expr: 1.00; deg: 0.10; theta: 0.89; asym: 5.00; tree : -5
# >> G_4: init: 0.21; noise: 1.17; b: 0.35; m: 2.76; expr: 1.00; deg: 0.10; theta: 7.97; asym: 5.80; tree : (-5 OR 4)
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.42; m: 7.35; expr: 1.00; deg: 0.10; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 1.00; b: 2.74; m: 4.42; expr: 1.00; deg: 0.10; theta: 7.79; asym: 5.00; tree : -1
# >> G_2: init: 1.37; noise: 1.13; b: 3.22; m: 2.82; expr: 1.00; deg: 0.10; theta: 1.13; asym: 4.88; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 1.72; m: 8.29; expr: 1.00; deg: 0.10; theta: 0.89; asym: 5.00; tree : (-1 OR 3)
# >> G_4: init: 0.21; noise: 1.17; b: 0.35; m: 2.76; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.80; tree : ((-5 OR 4) OR -2)
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.42; m: 6.75; expr: 1.00; deg: 0.10; theta: 2.28; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 1.00; b: 2.74; m: 4.42; expr: 1.00; deg: 0.10; theta: 7.79; asym: 5.00; tree : -1
# >> G_2: init: 1.37; noise: 1.13; b: 3.22; m: 2.82; expr: 1.00; deg: 0.10; theta: 1.13; asym: 4.83; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 1.72; m: 8.29; expr: 1.00; deg: 0.10; theta: 0.89; asym: 5.00; tree : (-1 OR -0)
# >> G_4: init: 0.21; noise: 1.17; b: 0.35; m: 2.76; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.80; tree : ((-5 OR 4) OR -2)
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 0.99; noise: 1.00; b: 0.42; m: 7.35; expr: 1.00; deg: 0.10; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 1.00; b: 2.74; m: 4.42; expr: 1.00; deg: 0.10; theta: 7.79; asym: 5.00; tree : -1
# >> G_2: init: 1.37; noise: 1.13; b: 3.22; m: 2.82; expr: 1.00; deg: 0.10; theta: 1.13; asym: 3.99; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 1.72; m: 8.29; expr: 1.00; deg: 0.10; theta: 0.89; asym: 5.00; tree : ((-1 OR 3) OR 5)
# >> G_4: init: 0.21; noise: 1.17; b: 0.35; m: 2.76; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.80; tree : ((-0 OR 5) OR -2)
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.42; m: 5.95; expr: 1.00; deg: 0.10; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.85; noise: 3.37; b: 6.57; m: 3.27; expr: 3.95; deg: 1.93; theta: 1.06; asym: 8.16; tree : ((-5 AND 0) OR (2 AND -3))
# >> G_2: init: 1.37; noise: 1.13; b: 3.22; m: 2.98; expr: 1.00; deg: 0.10; theta: 1.13; asym: 4.83; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 1.72; m: 8.29; expr: 1.00; deg: 0.09; theta: 0.89; asym: 5.00; tree : (-5 OR 3)
# >> G_4: init: 0.21; noise: 1.17; b: 0.35; m: 2.76; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.80; tree : (-5 OR -2)
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.42; m: 7.35; expr: 1.00; deg: 0.09; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 1.00; b: 3.09; m: 3.93; expr: 0.92; deg: 0.10; theta: 7.79; asym: 5.00; tree : -0
# >> G_2: init: 1.37; noise: 1.01; b: 2.97; m: 2.82; expr: 1.00; deg: 0.10; theta: 1.13; asym: 4.77; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 1.72; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 5.00; tree : (-1 OR 3)
# >> G_4: init: 0.20; noise: 1.21; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 4.94; tree : ((-5 OR 4) OR -2)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.42; m: 7.35; expr: 1.00; deg: 0.10; theta: 2.46; asym: 5.00; tree : 4
# >> G_1: init: 0.30; noise: 1.00; b: 2.80; m: 3.93; expr: 0.88; deg: 0.10; theta: 8.49; asym: 5.00; tree : 3
# >> G_2: init: 1.37; noise: 1.01; b: 3.22; m: 2.82; expr: 1.00; deg: 0.10; theta: 1.13; asym: 4.74; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 1.72; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.89; asym: 4.78; tree : (-1 OR 3)
# >> G_4: init: 0.21; noise: 1.21; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.21; tree : ((-0 OR 4) OR -2)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.42; m: 7.35; expr: 0.99; deg: 0.10; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 0.89; b: 3.09; m: 3.93; expr: 0.93; deg: 0.10; theta: 7.79; asym: 5.00; tree : -0
# >> G_2: init: 1.37; noise: 1.01; b: 2.97; m: 2.82; expr: 0.92; deg: 0.10; theta: 1.13; asym: 4.77; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 1.72; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 5.00; tree : (-1 OR 3)
# >> G_4: init: 0.20; noise: 1.21; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.21; tree : ((-5 OR 4) OR -2)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.00; noise: 1.16; b: 0.42; m: 7.35; expr: 1.00; deg: 0.08; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 1.00; b: 2.64; m: 3.93; expr: 0.93; deg: 0.13; theta: 7.79; asym: 5.00; tree : -0
# >> G_2: init: 1.32; noise: 1.12; b: 2.97; m: 2.82; expr: 1.00; deg: 0.08; theta: 1.11; asym: 4.77; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 2.00; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 5.00; tree : (-1 OR 3)
# >> G_4: init: 0.20; noise: 1.21; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.21; tree : (-5 OR -2)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.00; noise: 1.16; b: 0.42; m: 7.35; expr: 1.00; deg: 0.08; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 1.00; b: 2.64; m: 3.93; expr: 0.93; deg: 0.13; theta: 7.79; asym: 5.00; tree : -0
# >> G_2: init: 1.32; noise: 1.12; b: 2.97; m: 2.82; expr: 1.00; deg: 0.08; theta: 1.11; asym: 4.77; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 1.19; b: 1.86; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 4.66; tree : -1
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.21; tree : (4 OR -2)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.42; m: 7.35; expr: 1.00; deg: 0.10; theta: 2.31; asym: 5.00; tree : 4
# >> G_1: init: 0.30; noise: 1.00; b: 2.86; m: 3.93; expr: 1.02; deg: 0.10; theta: 8.49; asym: 5.00; tree : (-4 AND 2)
# >> G_2: init: 1.37; noise: 1.01; b: 3.71; m: 2.82; expr: 1.00; deg: 0.10; theta: 1.13; asym: 4.74; tree : (0 AND (-5 AND -2))
# >> G_3: init: 2.85; noise: 1.02; b: 8.16; m: 5.60; expr: 4.88; deg: 0.12; theta: 6.81; asym: 7.39; tree : ((2 OR 0) AND -3)
# >> G_4: init: 0.21; noise: 1.21; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.21; tree : ((-5 OR 4) OR -2)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.00; noise: 1.16; b: 0.42; m: 6.32; expr: 1.00; deg: 0.08; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 0.82; b: 2.64; m: 3.93; expr: 0.93; deg: 0.13; theta: 7.79; asym: 5.00; tree : -1
# >> G_2: init: 1.32; noise: 1.12; b: 2.97; m: 2.82; expr: 1.00; deg: 0.08; theta: 1.11; asym: 4.77; tree : ((0 AND -2) AND (-5 AND 1))
# >> G_3: init: 0.30; noise: 1.19; b: 1.86; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 4.40; tree : (-2 AND 5)
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.21; tree : (4 OR -2)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 0.89; noise: 1.22; b: 0.49; m: 7.35; expr: 1.00; deg: 0.08; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.36; noise: 0.74; b: 2.64; m: 3.33; expr: 0.93; deg: 0.13; theta: 7.79; asym: 5.00; tree : -1
# >> G_2: init: 1.32; noise: 1.12; b: 2.97; m: 2.82; expr: 1.00; deg: 0.08; theta: 1.11; asym: 4.77; tree : ((0 AND -2) AND (-5 AND 1))
# >> G_3: init: 0.30; noise: 0.86; b: 1.97; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 4.40; tree : (-1 AND 5)
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.21; tree : (0 OR -2)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.00; noise: 1.16; b: 0.42; m: 7.35; expr: 1.00; deg: 0.08; theta: 2.51; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 0.74; b: 2.64; m: 3.93; expr: 0.93; deg: 0.13; theta: 7.79; asym: 5.00; tree : (-0 AND 3)
# >> G_2: init: 1.32; noise: 1.12; b: 2.97; m: 2.82; expr: 1.00; deg: 0.08; theta: 1.11; asym: 4.77; tree : ((0 AND -2) AND (-5 AND 1))
# >> G_3: init: 0.30; noise: 1.32; b: 1.86; m: 10.47; expr: 1.07; deg: 0.10; theta: 0.86; asym: 4.40; tree : (-1 AND 5)
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 6.23; tree : (4 OR -2)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.00; noise: 1.16; b: 0.42; m: 7.35; expr: 1.00; deg: 0.08; theta: 2.51; asym: 5.00; tree : 5
# >> G_1: init: 0.35; noise: 0.74; b: 2.47; m: 3.93; expr: 0.93; deg: 0.13; theta: 9.09; asym: 5.00; tree : (-1 AND -3)
# >> G_2: init: 1.32; noise: 1.12; b: 2.97; m: 2.82; expr: 0.90; deg: 0.08; theta: 1.19; asym: 4.77; tree : ((0 AND -2) AND (-5 AND -3))
# >> G_3: init: 0.30; noise: 0.86; b: 1.97; m: 10.47; expr: 0.88; deg: 0.10; theta: 0.93; asym: 4.40; tree : (-0 AND (5 OR -1))
# >> G_4: init: 0.25; noise: 1.26; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.21; tree : (4 OR -2)
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.00; noise: 1.16; b: 0.42; m: 7.35; expr: 1.00; deg: 0.08; theta: 2.51; asym: 4.89; tree : 4
# >> G_1: init: 0.35; noise: 0.74; b: 2.64; m: 4.29; expr: 0.93; deg: 0.13; theta: 7.79; asym: 5.70; tree : -0
# >> G_2: init: 1.32; noise: 1.29; b: 3.29; m: 2.63; expr: 0.95; deg: 0.08; theta: 1.37; asym: 4.77; tree : ((0 AND -2) AND (-5 AND 1))
# >> G_3: init: 0.27; noise: 1.17; b: 1.86; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 4.40; tree : ((-1 AND -2) AND 5)
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.04; tree : (4 OR -2)
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 0.97; noise: 1.16; b: 0.42; m: 7.35; expr: 1.00; deg: 0.08; theta: 2.51; asym: 4.89; tree : 4
# >> G_1: init: 0.35; noise: 0.74; b: 2.86; m: 4.29; expr: 0.93; deg: 0.13; theta: 8.92; asym: 5.00; tree : -0
# >> G_2: init: 1.32; noise: 1.29; b: 2.85; m: 2.62; expr: 1.00; deg: 0.08; theta: 1.37; asym: 4.77; tree : ((0 AND -2) AND (-5 AND 1))
# >> G_3: init: 0.27; noise: 1.17; b: 1.86; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.98; asym: 4.40; tree : ((-1 AND -2) AND 5)
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.88; expr: 1.00; deg: 0.11; theta: 7.97; asym: 5.04; tree : (4 OR -2)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.00; noise: 1.16; b: 0.42; m: 7.35; expr: 1.00; deg: 0.08; theta: 2.30; asym: 4.57; tree : 4
# >> G_1: init: 0.29; noise: 0.74; b: 2.64; m: 4.29; expr: 0.93; deg: 0.13; theta: 7.79; asym: 4.50; tree : -0
# >> G_2: init: 1.43; noise: 1.29; b: 2.97; m: 2.63; expr: 1.00; deg: 0.08; theta: 1.19; asym: 4.77; tree : ((0 AND -2) AND (-5 AND 1))
# >> G_3: init: 0.28; noise: 1.17; b: 1.86; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 4.40; tree : ((-1 AND -2) AND 5)
# >> G_4: init: 0.20; noise: 1.50; b: 0.35; m: 2.88; expr: 1.00; deg: 0.10; theta: 7.97; asym: 5.87; tree : -2
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 0.97; noise: 1.14; b: 0.42; m: 7.35; expr: 1.00; deg: 0.08; theta: 2.41; asym: 4.89; tree : 4
# >> G_1: init: 0.35; noise: 0.74; b: 2.68; m: 4.29; expr: 0.93; deg: 0.13; theta: 8.92; asym: 5.00; tree : (-0 OR (-1 OR 3))
# >> G_2: init: 1.32; noise: 1.29; b: 2.85; m: 2.62; expr: 1.00; deg: 0.08; theta: 1.37; asym: 4.41; tree : ((0 AND -2) AND (-5 AND 1))
# >> G_3: init: 0.27; noise: 1.17; b: 1.86; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 3.99; tree : (-1 AND 5)
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.80; expr: 1.00; deg: 0.11; theta: 7.97; asym: 4.09; tree : (4 OR -2)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 0.88; noise: 1.16; b: 0.42; m: 7.35; expr: 1.05; deg: 0.07; theta: 2.85; asym: 4.57; tree : 4
# >> G_1: init: 0.29; noise: 0.74; b: 2.64; m: 4.29; expr: 0.99; deg: 0.13; theta: 7.79; asym: 4.50; tree : (-0 AND -2)
# >> G_2: init: 1.32; noise: 1.29; b: 3.38; m: 2.63; expr: 1.00; deg: 0.08; theta: 1.19; asym: 4.77; tree : ((0 AND -2) AND (-5 AND 1))
# >> G_3: init: 0.28; noise: 1.17; b: 1.57; m: 10.47; expr: 1.00; deg: 0.10; theta: 0.93; asym: 4.40; tree : ((-0 AND -2) AND 5)
# >> G_4: init: 0.19; noise: 1.50; b: 0.35; m: 2.88; expr: 1.00; deg: 0.10; theta: 7.97; asym: 5.04; tree : -2
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 0.97; noise: 1.14; b: 0.42; m: 7.35; expr: 0.92; deg: 0.08; theta: 2.41; asym: 4.89; tree : 4
# >> G_1: init: 0.35; noise: 0.74; b: 2.68; m: 4.29; expr: 0.93; deg: 0.13; theta: 8.92; asym: 5.00; tree : (-0 OR (-1 OR 3))
# >> G_2: init: 1.32; noise: 1.29; b: 2.85; m: 2.62; expr: 1.00; deg: 0.08; theta: 1.53; asym: 4.41; tree : ((0 AND -2) AND (-5 AND 1))
# >> G_3: init: 0.24; noise: 1.17; b: 1.68; m: 10.76; expr: 1.00; deg: 0.10; theta: 0.93; asym: 3.99; tree : (-1 AND 5)
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.80; expr: 1.00; deg: 0.12; theta: 7.97; asym: 4.09; tree : (4 OR -2)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 0.97; noise: 1.14; b: 0.42; m: 7.93; expr: 0.92; deg: 0.08; theta: 2.41; asym: 4.89; tree : 4
# >> G_1: init: 0.35; noise: 0.74; b: 2.95; m: 4.29; expr: 0.93; deg: 0.13; theta: 8.92; asym: 5.00; tree : (-0 OR (-1 OR 3))
# >> G_2: init: 1.32; noise: 1.29; b: 2.85; m: 2.62; expr: 1.00; deg: 0.08; theta: 1.37; asym: 4.41; tree : ((0 AND -2) AND -5)
# >> G_3: init: 0.27; noise: 1.17; b: 1.68; m: 9.16; expr: 1.00; deg: 0.10; theta: 0.93; asym: 3.99; tree : (-1 AND 5)
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.80; expr: 1.00; deg: 0.12; theta: 7.97; asym: 4.09; tree : (4 OR -2)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 0.97; noise: 1.14; b: 0.42; m: 7.93; expr: 0.92; deg: 0.08; theta: 2.41; asym: 4.89; tree : 4
# >> G_1: init: 0.35; noise: 0.74; b: 2.95; m: 4.29; expr: 0.93; deg: 0.13; theta: 8.92; asym: 5.00; tree : (-0 OR (-1 OR 3))
# >> G_2: init: 1.32; noise: 1.29; b: 2.85; m: 2.62; expr: 1.00; deg: 0.08; theta: 1.37; asym: 4.41; tree : ((0 AND -2) AND -5)
# >> G_3: init: 0.27; noise: 1.17; b: 1.68; m: 10.60; expr: 1.00; deg: 0.10; theta: 0.93; asym: 3.99; tree : (-1 AND 5)
# >> G_4: init: 0.20; noise: 1.26; b: 0.35; m: 2.80; expr: 1.00; deg: 0.12; theta: 8.17; asym: 4.09; tree : (4 OR -2)
