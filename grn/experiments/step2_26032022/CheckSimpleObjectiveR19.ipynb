# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_n, ref_n = normalize_time(stats, ref_stats, "neuron_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_n = stats_n.set_index("time")
    
    prog = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron = stats_n.loc[last_time_stats]["neuron_pop_size"]
    
    ref_prog = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron = ref_n.loc[last_time_ref]["neuron_pop_size"]

    return (prog - ref_prog)**2 + (neuron - ref_neuron)**2

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=1e3,
            cell_cls=ccls, end_time=prun.end_time, start_time=50, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=1e-4, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r19"
res = main(prun)

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r19

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps)[0])

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.08; noise: 0.09; b: 2.38; m: 8.20; expr: 1.00; deg: 0.10; theta: 5.34; asym: 5.00; tree : -2
# >> G_1: init: 0.33; noise: 0.24; b: 1.44; m: 6.35; expr: 1.00; deg: 0.10; theta: 4.12; asym: 5.00; tree : (2 OR 3)
# >> G_2: init: 0.51; noise: 0.13; b: 1.23; m: 5.31; expr: 1.00; deg: 0.10; theta: 1.27; asym: 5.00; tree : ((-5 OR 4) OR (-2 OR -0))
# >> G_3: init: 1.91; noise: 0.09; b: 1.48; m: 8.33; expr: 1.00; deg: 0.10; theta: 2.31; asym: 5.00; tree : -0
# >> G_4: init: 0.87; noise: 0.06; b: 2.01; m: 1.08; expr: 0.94; deg: 0.10; theta: 4.22; asym: 5.00; tree : -5
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.12; noise: 0.27; b: 0.10; m: 2.56; expr: 1.00; deg: 0.10; theta: 3.68; asym: 5.00; tree : 5
# >> G_1: init: 0.80; noise: 0.28; b: 2.67; m: 3.93; expr: 1.00; deg: 0.10; theta: 4.63; asym: 5.00; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.43; noise: 0.41; b: 1.74; m: 8.52; expr: 1.00; deg: 0.10; theta: 5.78; asym: 5.00; tree : 2
# >> G_3: init: 0.77; noise: 0.13; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.00; tree : (-3 AND (-2 AND -5))
# >> G_4: init: 0.23; noise: 0.08; b: 1.14; m: 8.05; expr: 1.00; deg: 0.10; theta: 8.55; asym: 5.00; tree : -2
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.12; noise: 0.27; b: 0.10; m: 2.56; expr: 1.00; deg: 0.10; theta: 3.68; asym: 5.00; tree : 5
# >> G_1: init: 0.98; noise: 0.28; b: 2.67; m: 3.93; expr: 0.93; deg: 0.10; theta: 4.63; asym: 5.00; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.43; noise: 0.41; b: 1.74; m: 8.53; expr: 1.00; deg: 0.10; theta: 5.78; asym: 5.00; tree : 2
# >> G_3: init: 0.77; noise: 0.13; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.00; tree : (-2 AND -5)
# >> G_4: init: 0.23; noise: 0.08; b: 1.14; m: 9.10; expr: 1.00; deg: 0.10; theta: 7.66; asym: 5.00; tree : -2
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.12; noise: 0.31; b: 0.10; m: 2.56; expr: 1.00; deg: 0.09; theta: 3.68; asym: 5.31; tree : 5
# >> G_1: init: 0.98; noise: 0.28; b: 2.67; m: 3.93; expr: 0.93; deg: 0.10; theta: 4.63; asym: 5.00; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.43; noise: 0.41; b: 1.74; m: 8.52; expr: 0.92; deg: 0.10; theta: 5.78; asym: 5.78; tree : 2
# >> G_3: init: 0.77; noise: 0.13; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.39; asym: 4.96; tree : (-2 AND -5)
# >> G_4: init: 0.23; noise: 0.08; b: 1.14; m: 9.10; expr: 1.00; deg: 0.10; theta: 7.66; asym: 4.59; tree : -2
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.12; noise: 0.31; b: 0.10; m: 2.56; expr: 1.00; deg: 0.09; theta: 3.68; asym: 5.31; tree : 5
# >> G_1: init: 0.98; noise: 0.28; b: 2.67; m: 3.93; expr: 0.93; deg: 0.10; theta: 5.30; asym: 5.00; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.21; noise: 0.49; b: 1.74; m: 8.38; expr: 0.92; deg: 0.10; theta: 5.78; asym: 5.78; tree : 2
# >> G_3: init: 0.77; noise: 0.13; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.49; tree : (-2 AND -5)
# >> G_4: init: 0.23; noise: 0.08; b: 1.14; m: 9.10; expr: 1.00; deg: 0.10; theta: 7.66; asym: 4.59; tree : -2
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.21; noise: 0.31; b: 0.10; m: 2.56; expr: 1.00; deg: 0.09; theta: 3.68; asym: 5.31; tree : 5
# >> G_1: init: 0.98; noise: 0.28; b: 2.67; m: 3.93; expr: 0.93; deg: 0.10; theta: 5.30; asym: 5.00; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.21; noise: 0.49; b: 1.82; m: 8.38; expr: 0.92; deg: 0.10; theta: 5.78; asym: 5.78; tree : 2
# >> G_3: init: 0.77; noise: 0.13; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.49; tree : (-2 AND -5)
# >> G_4: init: 0.23; noise: 0.08; b: 1.14; m: 8.49; expr: 1.00; deg: 0.10; theta: 7.66; asym: 4.59; tree : -2
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.15; noise: 0.28; b: 0.09; m: 2.90; expr: 1.00; deg: 0.10; theta: 3.68; asym: 5.00; tree : 5
# >> G_1: init: 0.97; noise: 0.26; b: 2.67; m: 3.93; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.43; noise: 0.41; b: 1.74; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.05; asym: 5.01; tree : 2
# >> G_3: init: 0.77; noise: 0.13; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.00; tree : (-2 AND -5)
# >> G_4: init: 0.27; noise: 0.08; b: 0.97; m: 9.10; expr: 1.00; deg: 0.10; theta: 7.66; asym: 5.00; tree : -2
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.15; noise: 0.28; b: 0.09; m: 2.90; expr: 1.00; deg: 0.10; theta: 3.68; asym: 5.17; tree : 5
# >> G_1: init: 0.97; noise: 0.26; b: 2.67; m: 3.93; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.43; noise: 0.41; b: 1.74; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.05; asym: 5.01; tree : 2
# >> G_3: init: 0.77; noise: 0.13; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.00; tree : ((-2 AND -5) AND 1)
# >> G_4: init: 0.27; noise: 0.08; b: 0.97; m: 9.10; expr: 1.00; deg: 0.10; theta: 7.66; asym: 5.00; tree : -2
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.15; noise: 0.28; b: 0.08; m: 2.90; expr: 1.00; deg: 0.10; theta: 3.68; asym: 5.17; tree : 5
# >> G_1: init: 0.86; noise: 0.26; b: 2.67; m: 3.93; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.43; noise: 0.41; b: 1.74; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.05; asym: 5.01; tree : 2
# >> G_3: init: 0.77; noise: 0.13; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.00; tree : ((-2 AND -5) AND 1)
# >> G_4: init: 0.27; noise: 0.08; b: 0.97; m: 9.10; expr: 1.00; deg: 0.10; theta: 7.66; asym: 5.00; tree : -2
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.15; noise: 0.28; b: 0.08; m: 2.90; expr: 1.00; deg: 0.10; theta: 3.68; asym: 5.17; tree : 5
# >> G_1: init: 0.86; noise: 0.27; b: 2.67; m: 3.93; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.43; noise: 0.41; b: 1.74; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.05; asym: 5.01; tree : 2
# >> G_3: init: 0.77; noise: 0.13; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.00; tree : ((-2 AND -5) AND 1)
# >> G_4: init: 0.30; noise: 0.08; b: 0.97; m: 10.74; expr: 1.00; deg: 0.10; theta: 7.66; asym: 5.00; tree : -2
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.13; noise: 4.82; b: 9.08; m: 6.72; expr: 4.24; deg: 2.44; theta: 0.82; asym: 7.38; tree : (-0 OR (2 AND -4))
# >> G_1: init: 0.86; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((3 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.47; noise: 0.41; b: 1.74; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.05; asym: 5.01; tree : 2
# >> G_3: init: 0.77; noise: 0.14; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND -5)
# >> G_4: init: 0.30; noise: 0.08; b: 0.97; m: 9.10; expr: 1.00; deg: 0.10; theta: 7.66; asym: 5.02; tree : -2
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.13; noise: 4.82; b: 9.08; m: 6.72; expr: 4.24; deg: 2.44; theta: 0.82; asym: 7.38; tree : (-0 OR (2 AND 5))
# >> G_1: init: 0.86; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((1 OR -0) OR (-5 AND -2))
# >> G_2: init: 1.47; noise: 0.35; b: 1.88; m: 8.52; expr: 0.95; deg: 0.10; theta: 4.19; asym: 5.01; tree : (2 AND -3)
# >> G_3: init: 0.91; noise: 0.14; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND -5)
# >> G_4: init: 0.30; noise: 0.08; b: 0.97; m: 9.10; expr: 1.00; deg: 0.10; theta: 7.66; asym: 4.61; tree : -2
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.13; noise: 4.82; b: 9.08; m: 6.72; expr: 4.24; deg: 2.93; theta: 0.82; asym: 7.38; tree : (-0 OR (2 AND 5))
# >> G_1: init: 0.86; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((1 OR -0) OR (-5 AND -3))
# >> G_2: init: 1.47; noise: 0.41; b: 1.88; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.05; asym: 5.01; tree : 2
# >> G_3: init: 0.91; noise: 0.14; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND -5)
# >> G_4: init: 0.30; noise: 0.08; b: 0.97; m: 9.78; expr: 1.00; deg: 0.10; theta: 7.87; asym: 5.02; tree : -2
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.11; noise: 4.82; b: 9.08; m: 6.72; expr: 4.24; deg: 2.93; theta: 0.82; asym: 7.38; tree : (-0 OR (2 AND 5))
# >> G_1: init: 0.86; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((1 OR -0) OR (-5 AND -3))
# >> G_2: init: 1.47; noise: 0.41; b: 1.88; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.05; asym: 5.01; tree : 2
# >> G_3: init: 0.91; noise: 0.14; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND -5)
# >> G_4: init: 0.30; noise: 0.08; b: 0.97; m: 9.78; expr: 1.00; deg: 0.10; theta: 7.87; asym: 5.02; tree : 0
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.13; noise: 4.82; b: 9.08; m: 6.72; expr: 4.24; deg: 2.93; theta: 0.82; asym: 7.38; tree : (-0 OR (2 AND 5))
# >> G_1: init: 0.84; noise: 0.27; b: 2.67; m: 2.81; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((1 OR -0) OR -5)
# >> G_2: init: 1.36; noise: 0.41; b: 1.88; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.05; asym: 5.01; tree : 2
# >> G_3: init: 0.91; noise: 0.16; b: 5.30; m: 4.57; expr: 1.00; deg: 0.11; theta: 4.48; asym: 5.00; tree : -5
# >> G_4: init: 2.69; noise: 0.70; b: 4.06; m: 4.54; expr: 1.54; deg: 2.24; theta: 5.19; asym: 9.04; tree : ((-2 OR 5) AND (4 OR 1))
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.11; noise: 4.82; b: 9.08; m: 6.72; expr: 4.24; deg: 2.93; theta: 0.82; asym: 7.38; tree : (-0 OR (3 AND 4))
# >> G_1: init: 0.86; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.53; asym: 5.58; tree : (-0 OR (-4 AND -3))
# >> G_2: init: 1.47; noise: 0.41; b: 1.88; m: 8.52; expr: 0.95; deg: 0.09; theta: 5.05; asym: 4.06; tree : 0
# >> G_3: init: 0.91; noise: 0.11; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND -5)
# >> G_4: init: 0.30; noise: 0.08; b: 0.97; m: 9.78; expr: 1.00; deg: 0.10; theta: 7.87; asym: 5.02; tree : 0
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.13; noise: 4.82; b: 9.08; m: 6.72; expr: 4.24; deg: 2.93; theta: 0.82; asym: 7.38; tree : (-0 OR 2)
# >> G_1: init: 0.84; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((1 OR -0) OR -5)
# >> G_2: init: 1.36; noise: 0.41; b: 1.88; m: 8.52; expr: 0.95; deg: 0.12; theta: 5.05; asym: 5.01; tree : 2
# >> G_3: init: 0.91; noise: 0.16; b: 5.30; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.48; asym: 5.00; tree : -5
# >> G_4: init: 2.24; noise: 8.39; b: 9.40; m: 2.59; expr: 1.47; deg: 1.63; theta: 8.05; asym: 6.94; tree : -0
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.13; noise: 5.68; b: 9.08; m: 6.72; expr: 4.24; deg: 2.93; theta: 0.82; asym: 7.38; tree : (-0 OR (2 AND 4))
# >> G_1: init: 0.84; noise: 0.32; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((1 OR -0) OR -5)
# >> G_2: init: 1.35; noise: 0.41; b: 1.88; m: 8.52; expr: 0.95; deg: 0.12; theta: 5.05; asym: 5.01; tree : (2 AND 4)
# >> G_3: init: 0.91; noise: 0.16; b: 5.30; m: 4.57; expr: 0.81; deg: 0.10; theta: 3.89; asym: 5.00; tree : -5
# >> G_4: init: 2.24; noise: 8.39; b: 9.40; m: 2.59; expr: 1.47; deg: 1.45; theta: 8.46; asym: 6.94; tree : -0
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.11; noise: 5.12; b: 7.29; m: 6.72; expr: 4.24; deg: 2.93; theta: 0.82; asym: 7.38; tree : (-0 OR 4)
# >> G_1: init: 0.86; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.53; asym: 5.58; tree : (-0 OR (-4 AND -3))
# >> G_2: init: 1.47; noise: 0.34; b: 1.88; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.97; asym: 4.06; tree : 0
# >> G_3: init: 1.05; noise: 0.14; b: 6.14; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND (-5 AND -1))
# >> G_4: init: 0.30; noise: 0.08; b: 0.97; m: 9.78; expr: 1.00; deg: 0.10; theta: 7.87; asym: 5.29; tree : 1
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.21; noise: 5.68; b: 10.55; m: 6.72; expr: 4.24; deg: 2.93; theta: 0.82; asym: 7.38; tree : (-0 OR (2 AND 4))
# >> G_1: init: 0.84; noise: 0.32; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.96; asym: 5.58; tree : ((1 OR -0) OR -5)
# >> G_2: init: 1.35; noise: 0.41; b: 1.88; m: 8.52; expr: 0.95; deg: 0.12; theta: 5.05; asym: 5.01; tree : (2 AND 4)
# >> G_3: init: 0.91; noise: 0.16; b: 5.30; m: 4.57; expr: 0.81; deg: 0.10; theta: 3.85; asym: 5.00; tree : -5
# >> G_4: init: 2.24; noise: 7.45; b: 9.40; m: 2.59; expr: 1.47; deg: 1.45; theta: 9.53; asym: 6.94; tree : (-0 OR -3)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.11; noise: 5.12; b: 7.29; m: 6.72; expr: 4.24; deg: 2.98; theta: 0.82; asym: 7.38; tree : (-0 OR 4)
# >> G_1: init: 0.96; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.53; asym: 5.58; tree : (-0 OR -3)
# >> G_2: init: 1.49; noise: 0.34; b: 1.88; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.08; asym: 4.06; tree : (0 OR -1)
# >> G_3: init: 1.05; noise: 0.14; b: 6.14; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND -1)
# >> G_4: init: 0.30; noise: 0.08; b: 0.97; m: 9.78; expr: 0.91; deg: 0.10; theta: 8.01; asym: 5.29; tree : 1
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.11; noise: 5.12; b: 7.29; m: 6.72; expr: 4.24; deg: 2.98; theta: 0.82; asym: 7.38; tree : 4
# >> G_1: init: 0.96; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.53; asym: 5.58; tree : (-0 OR -3)
# >> G_2: init: 1.49; noise: 0.34; b: 1.88; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.08; asym: 4.06; tree : (0 OR -1)
# >> G_3: init: 1.05; noise: 0.14; b: 6.14; m: 4.57; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND -1)
# >> G_4: init: 0.30; noise: 0.08; b: 0.72; m: 9.78; expr: 0.91; deg: 0.10; theta: 8.01; asym: 5.29; tree : -2
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.11; noise: 5.12; b: 9.87; m: 6.72; expr: 4.24; deg: 2.98; theta: 0.82; asym: 7.38; tree : 4
# >> G_1: init: 0.96; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.53; asym: 5.58; tree : (-0 OR -3)
# >> G_2: init: 1.49; noise: 0.34; b: 1.88; m: 8.52; expr: 0.95; deg: 0.11; theta: 5.08; asym: 4.08; tree : (0 OR -1)
# >> G_3: init: 1.05; noise: 0.14; b: 6.14; m: 3.70; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND (-1 AND -5))
# >> G_4: init: 0.30; noise: 0.07; b: 0.72; m: 9.94; expr: 0.91; deg: 0.10; theta: 8.01; asym: 5.29; tree : -2
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.11; noise: 4.99; b: 8.72; m: 6.72; expr: 4.24; deg: 2.98; theta: 0.82; asym: 7.38; tree : 4
# >> G_1: init: 0.96; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.53; asym: 5.58; tree : (-0 OR -3)
# >> G_2: init: 1.49; noise: 0.34; b: 1.88; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.08; asym: 4.06; tree : (0 OR (-1 AND 2))
# >> G_3: init: 1.05; noise: 0.13; b: 5.36; m: 3.70; expr: 1.00; deg: 0.10; theta: 4.52; asym: 5.00; tree : (-2 AND (-1 AND -5))
# >> G_4: init: 0.30; noise: 0.06; b: 0.72; m: 9.94; expr: 0.91; deg: 0.10; theta: 8.01; asym: 5.29; tree : (3 OR 4)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.11; noise: 4.27; b: 9.87; m: 6.72; expr: 4.24; deg: 2.98; theta: 0.82; asym: 7.38; tree : 4
# >> G_1: init: 1.07; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.53; asym: 5.58; tree : (-0 OR -3)
# >> G_2: init: 1.49; noise: 0.34; b: 1.88; m: 8.52; expr: 0.95; deg: 0.11; theta: 5.08; asym: 4.06; tree : (0 OR -1)
# >> G_3: init: 1.05; noise: 0.14; b: 6.14; m: 3.37; expr: 1.00; deg: 0.10; theta: 5.35; asym: 4.56; tree : (-2 AND (-1 AND -0))
# >> G_4: init: 0.30; noise: 0.07; b: 0.72; m: 9.94; expr: 0.91; deg: 0.10; theta: 8.01; asym: 5.29; tree : -2
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.11; noise: 5.12; b: 9.87; m: 6.72; expr: 4.24; deg: 2.98; theta: 0.82; asym: 7.38; tree : 4
# >> G_1: init: 0.96; noise: 0.27; b: 2.67; m: 3.17; expr: 0.93; deg: 0.11; theta: 4.53; asym: 5.58; tree : (-0 OR -3)
# >> G_2: init: 1.49; noise: 0.34; b: 1.88; m: 8.52; expr: 0.95; deg: 0.10; theta: 5.08; asym: 4.06; tree : (0 OR -1)
# >> G_3: init: 1.05; noise: 0.14; b: 6.14; m: 3.37; expr: 1.00; deg: 0.10; theta: 5.35; asym: 4.56; tree : (-2 AND (-1 AND -3))
# >> G_4: init: 0.30; noise: 0.07; b: 0.72; m: 9.94; expr: 0.91; deg: 0.10; theta: 8.01; asym: 5.29; tree : -2
