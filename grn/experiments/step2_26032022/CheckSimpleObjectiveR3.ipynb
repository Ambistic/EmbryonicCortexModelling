# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**1.8))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r3"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r3
# [definition]
#
#
# [reload] Found generation 25
# [out] Step 1300
# [out] ++ Best 2878.1680276135203 for generation 1300
# Step 3 passed !
# [out] ++ Best 3055.943533777942 for generation 1302
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-28e7a9a4688d> in <module>
#       2 prun.cb_init = callback_init
#       3 prun.name = "check_simple_obj_r3"
# ----> 4 res = main(prun)
#
# <ipython-input-15-b9e59561fcb1> in main(prun)
#      20     for i in range(batch_gen * prun.batch_size,
#      21                    prun.n_gen * prun.batch_size):
# ---> 22         fit, stats = do_fitness(prun, sol)
#      23         sol.fit, sol.stats = fit, stats
#      24
#
# <ipython-input-12-803c9e3dddd9> in do_fitness(prun, sol)
#       3
#       4 def do_fitness(prun, sol):
# ----> 5     fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
#       6     return fitness, stats
#       7
#
# <ipython-input-11-424afec1b8a4> in fitness_multistep(prun, grn, steps)
#       6     # first step
#       7     for step in steps:
# ----> 8         if not bb.run_until(step.end_time):
#       9             stop = True
#      10
#
# ~/other/EmbryonicCortexModelling/grn/brain.py in run_until(self, time_point)
#     145                 and (self.range[self.current_step] < time_point):
#     146             T = self.range[self.current_step]
# --> 147             if not self._tick(T, self.time_step):
#     148                 self.info("Population exploded or extinguished")
#     149                 return False
#
# ~/other/EmbryonicCortexModelling/grn/brain.py in _tick(self, absolute_time, relative_time)
#     175
#     176         if self.run_tissue:
# --> 177             self.tissue.tick(absolute_time, relative_time)
#     178
#     179         self.monitor(absolute_time + relative_time)  # because after computation
#
# ~/other/EmbryonicCortexModelling/grn/cbmos/cbmodel/CBModelv3.py in tick(self, current_time, time_step)
#      71         y0 = _np.array([cell.position for cell in self.cells]).reshape(-1)
#      72
# ---> 73         sol = self._calculate_next_positions(current_time, current_time + time_step,
#      74                                              y0)
#      75
#
# ~/other/EmbryonicCortexModelling/grn/cbmos/cbmodel/CBModelv3.py in _calculate_next_positions(self, time_start, time_end, y0, raw_t)
#      83         _logging.debug("Calling solver with: t0={}, tf={}".format(
#      84             time_start, time_end))
# ---> 85         return self.solver(self._ode_system(self.force_args),
#      86                            (time_start, time_end),
#      87                            y0,
#
# ~/other/EmbryonicCortexModelling/grn/cbmos/solvers/euler_forward.py in solve_ivp(fun, t_span, y0, t_eval, dt)
#      31
#      32     while t < tf :
# ---> 33         y = y + dt*fun(t,y)
#      34         t = t + dt
#      35
#
# ~/other/EmbryonicCortexModelling/grn/cbmos/cbmodel/CBModelv3.py in f(t, y)
#     236             norm = _np.sqrt((cross_diff**2).sum(axis=1)) # shape (n, n)
#     237             forces = _np.expand_dims(
# --> 238                 self.force(norm, **force_args)\
#     239                     / (norm + _np.diag(self.hpc_backend.ones(y_r.shape[0]))),
#     240                 axis=1,
#
# ~/other/EmbryonicCortexModelling/grn/cbmos/force_functions.py in __call__(self, r, mu, s, a, rA)
#     297             return 0.
#     298         r[r==0] = 0.0001  # get away from zero - this is an awful hack! Plus it does not allow for single value evaluation
# --> 299         return _np.where(r < s, mu*_np.log(1+(r-s)), _np.where(r < rA, mu*(r-s)*_np.exp(-a*(r-s)), 0))
#     300
#     301     def derive(self):
#
# KeyboardInterrupt:

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r3

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.13; asym: 5.00; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.76; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.00; asym: 5.00; tree : (1 OR NOT 0)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 5.39; asym: 5.00; tree : (5 OR (4 AND 1))
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 0.10; theta: 7.43; asym: 5.00; tree : (NOT 1 OR (3 OR 4))
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.13; asym: 4.16; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.96; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 5.00; tree : (1 OR NOT 0)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 5.39; asym: 4.14; tree : (5 OR (2 AND 1))
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 0.10; theta: 7.28; asym: 5.00; tree : (NOT 1 OR (3 OR 4))
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.13; asym: 4.04; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.96; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 4.20; tree : (1 OR NOT 0)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 5.39; asym: 5.00; tree : (5 OR (2 AND 1))
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 0.10; theta: 7.28; asym: 5.00; tree : (NOT 1 OR (3 OR 5))
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.13; asym: 4.04; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.96; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 3.49; tree : (1 OR NOT 0)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 5.72; asym: 5.00; tree : (5 OR (2 AND 1))
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 0.10; theta: 7.25; asym: 5.00; tree : (3 OR 5)
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.13; asym: 4.04; tree : (1 OR 4)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.96; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : (1 OR NOT 0)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 5.72; asym: 5.00; tree : (5 OR 1)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 0.10; theta: 7.25; asym: 5.00; tree : (3 OR 4)
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.13; asym: 4.04; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.96; asym: 3.61; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 3.49; tree : (1 OR NOT 4)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 5.72; asym: 5.00; tree : (2 AND 1)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 0.10; theta: 7.61; asym: 5.00; tree : 3
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.75; asym: 3.52; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 1.25; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : (1 OR NOT 0)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 6.22; asym: 5.00; tree : (5 OR 1)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 0.10; theta: 8.44; asym: 5.00; tree : (3 OR 1)
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 5.92; asym: 4.04; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.96; asym: 3.61; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 3.49; tree : (1 OR NOT 4)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 5.71; asym: 4.31; tree : (2 AND 1)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 0.10; theta: 8.27; asym: 5.00; tree : (3 OR 0)
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.48; asym: 2.91; tree : (1 OR 5)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 1.24; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : (1 OR NOT (0 AND 4))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 7.48; asym: 5.00; tree : (5 OR 1)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 9.37; asym: 5.00; tree : (1 OR 4)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.48; asym: 2.91; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 1.03; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (0 AND (4 AND 3))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.66; asym: 5.00; tree : ((5 AND 2) OR 1)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 8.52; asym: 5.00; tree : (3 OR 4)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.48; asym: 2.91; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 1.03; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (1 AND (4 AND 3))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.66; asym: 5.00; tree : ((5 AND 2) OR 1)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 8.60; asym: 4.09; tree : (3 OR 4)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.65; asym: 2.91; tree : 1
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : (3 OR NOT (0 AND 4))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 7.55; asym: 5.00; tree : 1
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 10.88; asym: 4.33; tree : 4
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.89; asym: 2.91; tree : (1 OR 3)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.92; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (0 AND (4 AND 3))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.66; asym: 5.00; tree : (2 OR 0)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 10.17; asym: 3.42; tree : (3 OR 4)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.60; asym: 2.91; tree : (1 OR 3)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (0 AND (4 AND 3))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.99; asym: 5.00; tree : ((5 AND 2) OR 0)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 10.17; asym: 2.87; tree : (3 OR 4)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.96; asym: 2.36; tree : (1 OR (5 AND 3))
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.91; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (0 AND 2)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 9.29; asym: 5.00; tree : ((5 AND 2) OR 0)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 9.44; asym: 4.09; tree : (3 OR 0)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 5.77; asym: 1.99; tree : (1 OR 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.92; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.61; asym: 2.90; tree : NOT (0 AND (4 AND 5))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.98; asym: 5.00; tree : ((5 AND 2) OR 4)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 10.93; asym: 2.87; tree : (3 OR 4)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 4.98; asym: 2.47; tree : (1 OR 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.85; asym: 5.00; tree : (2 OR 0)
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (0 AND (4 AND 5))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 10.61; asym: 4.18; tree : ((5 AND 2) OR 0)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 10.93; asym: 2.87; tree : (5 OR 4)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 5.83; asym: 2.47; tree : (1 OR NOT (0 OR 2))
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.79; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.90; asym: 2.90; tree : NOT (4 AND 5)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 10.61; asym: 4.18; tree : 0
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 10.93; asym: 2.87; tree : 5
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 7.35; asym: 2.47; tree : (1 OR 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.93; asym: 5.00; tree : 2
# >> G_2: init: 0.27; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.70; asym: 2.90; tree : NOT (0 AND 5)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 13.59; asym: 4.18; tree : (2 OR 0)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 10.66; asym: 2.87; tree : 5
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 7.35; asym: 2.47; tree : (1 OR 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.95; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.70; asym: 2.90; tree : NOT (0 AND (1 AND 5))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 14.85; asym: 4.18; tree : ((5 AND 4) OR 0)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 10.93; asym: 2.02; tree : 5
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 5.83; asym: 2.47; tree : (1 OR NOT 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.79; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.90; asym: 2.90; tree : NOT 4
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 1.76; theta: 11.90; asym: 4.18; tree : (2 OR 1)
# >> G_4: init: 0.83; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 12.70; asym: 2.87; tree : (5 OR 0)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 9.83; asym: 2.47; tree : (4 OR NOT 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.83; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (0 AND (4 AND 5))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 10.40; asym: 3.41; tree : (5 OR 0)
# >> G_4: init: 2.56; noise: 3.47; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 12.14; asym: 2.87; tree : NOT 5
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 8.28; asym: 2.47; tree : (4 OR NOT 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.83; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (0 AND 5)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 9.35; asym: 3.41; tree : 0
# >> G_4: init: 2.56; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 14.42; asym: 2.87; tree : NOT 1
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 6.30; asym: 2.47; tree : (4 OR NOT 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.75; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (1 AND (4 AND 5))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 10.66; asym: 3.41; tree : 0
# >> G_4: init: 2.56; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 13.20; asym: 2.87; tree : NOT 2
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 6.30; asym: 2.47; tree : (4 OR NOT 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.75; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (1 AND (4 AND 5))
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 11.76; asym: 3.41; tree : 0
# >> G_4: init: 2.56; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 12.06; asym: 2.87; tree : NOT 2
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.00; noise: 0.21; b: 0.94; m: 6.31; expr: 1.00; deg: 0.10; theta: 6.30; asym: 2.47; tree : (4 OR NOT 0)
# >> G_1: init: 0.47; noise: 0.17; b: 2.57; m: 8.16; expr: 1.00; deg: 0.10; theta: 0.75; asym: 5.00; tree : 2
# >> G_2: init: 0.65; noise: 0.05; b: 1.94; m: 1.78; expr: 1.00; deg: 0.10; theta: 10.82; asym: 2.90; tree : NOT (4 AND 5)
# >> G_3: init: 0.37; noise: 0.34; b: 1.19; m: 1.24; expr: 1.00; deg: 0.10; theta: 10.21; asym: 2.90; tree : NOT (0 OR 1)
# >> G_4: init: 2.56; noise: 0.60; b: 1.79; m: 5.77; expr: 1.00; deg: 1.80; theta: 12.72; asym: 2.87; tree : NOT 2
