# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve_2, show_curve_progenitor
from jf.models.stringmodel import read_model

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**1.5))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.2, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r4"
# res = main(prun)

# %%
exp = Exporter(name="check_simple_obj_r4")
# Out:
# Exporting at output/check_simple_obj_r4

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
show_curve_2(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 0.98; noise: 0.11; b: 1.67; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.74; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 9.24; asym: 5.00; tree : 5
# >> G_2: init: 0.18; noise: 0.16; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 6.87; asym: 5.00; tree : 4
# >> G_3: init: 0.43; noise: 0.16; b: 0.97; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.74; asym: 5.00; tree : (3 AND NOT 4)
# >> G_4: init: 0.62; noise: 0.62; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 6.86; asym: 5.00; tree : ((5 AND 0) OR NOT 2)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 0.98; noise: 0.11; b: 1.67; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.74; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 9.89; asym: 5.00; tree : 5
# >> G_2: init: 0.18; noise: 0.16; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 6.87; asym: 4.02; tree : 4
# >> G_3: init: 0.43; noise: 0.16; b: 0.97; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.82; asym: 5.00; tree : (3 AND NOT 1)
# >> G_4: init: 0.62; noise: 0.62; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.22; asym: 4.04; tree : ((5 AND 0) OR NOT 2)
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.74; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 10.10; asym: 4.15; tree : 5
# >> G_2: init: 0.18; noise: 0.16; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 7.78; asym: 4.02; tree : 4
# >> G_3: init: 0.43; noise: 0.16; b: 0.97; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.82; asym: 4.05; tree : (3 AND NOT 1)
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.22; asym: 4.04; tree : ((5 AND 0) OR NOT 2)
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 8.16; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 8.89; asym: 4.15; tree : 5
# >> G_2: init: 0.18; noise: 0.16; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.60; asym: 4.02; tree : 4
# >> G_3: init: 0.43; noise: 0.16; b: 0.97; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.82; asym: 4.05; tree : NOT 1
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 3.52; tree : ((5 AND 0) OR NOT 2)
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 8.16; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 3.83; m: 7.61; expr: 1.00; deg: 0.10; theta: 8.75; asym: 4.15; tree : 5
# >> G_2: init: 0.18; noise: 0.16; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.60; asym: 4.02; tree : 4
# >> G_3: init: 0.43; noise: 0.16; b: 0.97; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.88; asym: 4.05; tree : NOT 1
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 3.52; tree : (0 OR NOT 2)
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 8.16; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 8.28; asym: 4.15; tree : 5
# >> G_2: init: 0.18; noise: 0.16; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 7.89; asym: 4.02; tree : 4
# >> G_3: init: 0.43; noise: 0.16; b: 0.97; m: 2.14; expr: 0.82; deg: 0.10; theta: 0.88; asym: 4.05; tree : NOT 2
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 3.52; tree : (0 OR NOT 2)
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 8.39; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 9.96; asym: 3.59; tree : 5
# >> G_2: init: 0.18; noise: 0.16; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.76; asym: 4.02; tree : 4
# >> G_3: init: 0.43; noise: 0.16; b: 0.97; m: 2.14; expr: 0.82; deg: 0.10; theta: 1.02; asym: 4.05; tree : NOT 1
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 8.01; asym: 3.52; tree : (0 OR NOT 2)
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.27; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 8.89; asym: 3.10; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.82; asym: 4.02; tree : 1
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.83; asym: 4.05; tree : NOT 1
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : (5 OR NOT 2)
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.27; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 8.89; asym: 3.10; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.82; asym: 4.02; tree : (1 AND 0)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.83; asym: 4.05; tree : NOT 1
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : ((5 AND 4) OR NOT 2)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.27; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 11.03; asym: 2.59; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.82; asym: 4.02; tree : (1 AND 0)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.78; asym: 3.25; tree : NOT 1
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : ((5 AND 4) OR NOT 2)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 6.95; asym: 5.00; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 8.89; asym: 3.10; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.82; asym: 4.02; tree : (1 AND 0)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.78; asym: 4.05; tree : NOT (1 OR 2)
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.92; asym: 2.87; tree : (4 OR NOT 2)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.36; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 11.03; asym: 2.25; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.82; asym: 4.02; tree : (1 AND 0)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.86; asym: 3.25; tree : NOT 1
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 8.13; asym: 2.87; tree : ((5 AND 4) OR NOT 2)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.02; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 11.03; asym: 2.25; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.00; asym: 4.02; tree : (1 AND NOT 0)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.86; asym: 3.25; tree : NOT 1
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : ((5 AND 4) OR NOT 2)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.02; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 11.03; asym: 2.25; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.05; asym: 4.02; tree : 1
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.86; asym: 3.25; tree : NOT 5
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.51; tree : (5 OR NOT 2)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 6.11; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 12.06; asym: 1.80; tree : (5 OR 1)
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 8.82; asym: 4.02; tree : 1
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.67; asym: 1.91; tree : (NOT 0 OR 2)
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : ((5 AND 4) OR NOT 2)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.96; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 11.03; asym: 1.45; tree : (5 OR 1)
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 11.58; asym: 4.02; tree : (1 OR 2)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.79; asym: 1.91; tree : NOT 0
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : ((5 AND 4) OR NOT 2)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.73; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 11.24; asym: 1.45; tree : (5 OR 1)
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 7.06; expr: 1.00; deg: 0.10; theta: 11.58; asym: 4.02; tree : (1 OR 2)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 6.50; expr: 1.00; deg: 0.10; theta: 0.79; asym: 1.91; tree : NOT 5
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : ((5 AND 4) OR NOT 2)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.96; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 9.68; asym: 1.26; tree : (5 OR 1)
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 2.95; expr: 1.00; deg: 0.10; theta: 13.44; asym: 4.02; tree : (1 OR 2)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 2.14; expr: 1.00; deg: 0.10; theta: 0.94; asym: 1.91; tree : NOT 5
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : ((5 AND 4) OR NOT 2)
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.77; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 13.11; asym: 1.45; tree : (5 OR 1)
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 7.06; expr: 1.00; deg: 0.10; theta: 12.24; asym: 3.32; tree : (1 OR 2)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 6.50; expr: 1.00; deg: 0.10; theta: 0.73; asym: 1.91; tree : NOT 5
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : (4 OR NOT 2)
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 7.13; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 13.11; asym: 1.18; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 7.06; expr: 1.00; deg: 0.10; theta: 13.70; asym: 4.02; tree : (1 OR 2)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 6.50; expr: 1.00; deg: 0.10; theta: 0.84; asym: 1.58; tree : NOT 2
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.69; asym: 2.87; tree : (4 OR NOT 2)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 6.48; asym: 4.10; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 13.11; asym: 1.18; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 7.06; expr: 1.00; deg: 0.10; theta: 13.70; asym: 4.02; tree : (1 OR 2)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 6.50; expr: 1.00; deg: 0.10; theta: 0.84; asym: 1.58; tree : NOT 2
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.96; asym: 2.87; tree : (4 OR NOT 2)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 6.43; asym: 3.45; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 10.07; asym: 1.18; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 7.06; expr: 1.00; deg: 0.10; theta: 12.89; asym: 4.02; tree : (1 OR 2)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 6.50; expr: 1.00; deg: 0.10; theta: 0.75; asym: 1.58; tree : NOT 2
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.96; asym: 2.87; tree : (4 OR NOT 2)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 6.70; asym: 3.45; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 12.02; asym: 1.18; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 7.06; expr: 1.00; deg: 0.10; theta: 13.70; asym: 4.02; tree : (1 OR 2)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 6.50; expr: 1.00; deg: 0.10; theta: 1.01; asym: 1.58; tree : NOT 3
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.96; asym: 2.87; tree : (4 OR NOT 2)
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 6.70; asym: 3.45; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 12.02; asym: 0.95; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 7.06; expr: 1.00; deg: 0.10; theta: 14.80; asym: 4.02; tree : (1 OR 2)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 6.50; expr: 1.00; deg: 0.10; theta: 0.89; asym: 1.58; tree : NOT 2
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.96; asym: 2.37; tree : (4 OR NOT 2)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 6.43; asym: 3.45; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 14.75; asym: 1.18; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 7.06; expr: 1.00; deg: 0.10; theta: 15.74; asym: 3.31; tree : 1
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 6.50; expr: 1.00; deg: 0.10; theta: 0.76; asym: 1.58; tree : NOT 5
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.96; asym: 2.87; tree : (4 OR NOT 2)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 0.98; noise: 0.11; b: 3.69; m: 9.17; expr: 1.00; deg: 0.10; theta: 5.12; asym: 3.45; tree : 3
# >> G_1: init: 0.54; noise: 0.49; b: 0.61; m: 7.61; expr: 1.00; deg: 0.10; theta: 13.81; asym: 1.18; tree : 5
# >> G_2: init: 0.18; noise: 4.99; b: 2.04; m: 8.86; expr: 1.00; deg: 0.10; theta: 14.43; asym: 4.02; tree : ((1 OR 2) OR 4)
# >> G_3: init: 0.43; noise: 0.16; b: 2.01; m: 6.50; expr: 1.00; deg: 0.10; theta: 0.74; asym: 1.58; tree : NOT 2
# >> G_4: init: 0.62; noise: 8.73; b: 1.27; m: 2.97; expr: 1.00; deg: 0.10; theta: 7.96; asym: 2.87; tree : (4 OR NOT 2)
