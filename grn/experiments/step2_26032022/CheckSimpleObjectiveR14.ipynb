# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_n, ref_n = normalize_time(stats, ref_stats, "neuron_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_n = stats_n.set_index("time")
    
    prog = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron = stats_n.loc[last_time_stats]["neuron_pop_size"]
    
    ref_prog = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron = ref_n.loc[last_time_ref]["neuron_pop_size"]

    return (prog - ref_prog)**2 + (neuron - ref_neuron)**2

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=1e3,
            cell_cls=ccls, end_time=prun.end_time, start_time=50, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r14"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r14
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 8.341041270638543e-05 for generation 0
# [out] ++ Best 8.708348538074222e-05 for generation 1
# [out] ++ Best 0.00010805982494671985 for generation 4
# [out] ++ Best 0.00016614651740301954 for generation 16
# Saving ...
# [out] ++ Best 0.0003214723383682657 for generation 62
# Saving ...
# [out] Step 100
# Saving ...
# Saving ...
# [out] Step 200
# Saving ...
# Saving ...
# [out] Step 300
# Saving ...
# Saving ...
# [out] Step 400
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# Saving ...
# Saving ...
# [out] Step 800
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# [out] ++ Best 0.00033939715178214205 for generation 1210
# Saving ...
# Saving ...
# [out] Step 1300
# Saving ...
# [out] ++ Best 0.00035216131927388986 for generation 1386
# [out] ++ Best 0.0004306189807010956 for generation 1395
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# Saving ...
# [out] Step 2100
# [out] ++ Best 0.0005362502987281104 for generation 2121
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r14

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps)[0])
# Out:
# 9.295885690974515e-05
# 9.378977743863766e-05
# 9.304535133582256e-05
# 9.320880879911203e-05
# 9.274608232626483e-05

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 0.90; noise: 0.70; b: 2.42; m: 1.59; expr: 1.00; deg: 0.10; theta: 7.02; asym: 5.00; tree : 5
# >> G_1: init: 1.99; noise: 0.36; b: 0.88; m: 1.30; expr: 1.00; deg: 0.10; theta: 2.43; asym: 5.00; tree : 3
# >> G_2: init: 1.61; noise: 0.19; b: 1.63; m: 4.76; expr: 1.00; deg: 0.10; theta: 2.43; asym: 5.00; tree : NOT 4
# >> G_3: init: 1.09; noise: 0.09; b: 3.35; m: 7.79; expr: 1.00; deg: 0.10; theta: 9.55; asym: 5.00; tree : 4
# >> G_4: init: 0.06; noise: 0.25; b: 0.34; m: 5.95; expr: 1.00; deg: 0.10; theta: 1.82; asym: 5.00; tree : ((2 OR 5) AND 1)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 0.46; noise: 0.28; b: 2.85; m: 6.69; expr: 1.00; deg: 0.10; theta: 4.60; asym: 5.00; tree : 1
# >> G_1: init: 1.92; noise: 0.09; b: 1.50; m: 3.84; expr: 1.00; deg: 0.10; theta: 0.53; asym: 5.00; tree : ((1 OR 5) AND 0)
# >> G_2: init: 2.20; noise: 0.51; b: 0.34; m: 2.07; expr: 1.00; deg: 0.10; theta: 7.26; asym: 5.00; tree : 1
# >> G_3: init: 1.08; noise: 0.30; b: 1.69; m: 8.10; expr: 1.18; deg: 0.10; theta: 5.95; asym: 5.00; tree : NOT 3
# >> G_4: init: 1.60; noise: 0.23; b: 0.80; m: 1.70; expr: 1.00; deg: 0.10; theta: 4.77; asym: 5.00; tree : 2
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.75; noise: 0.34; b: 1.60; m: 6.82; expr: 1.00; deg: 0.10; theta: 1.67; asym: 5.00; tree : ((5 AND 4) OR (2 OR 0))
# >> G_1: init: 2.00; noise: 0.39; b: 2.24; m: 1.83; expr: 1.00; deg: 0.10; theta: 6.02; asym: 5.00; tree : 1
# >> G_2: init: 2.21; noise: 0.38; b: 2.28; m: 3.54; expr: 1.00; deg: 0.10; theta: 6.72; asym: 5.00; tree : (1 AND 0)
# >> G_3: init: 0.24; noise: 0.74; b: 0.93; m: 7.80; expr: 1.00; deg: 0.10; theta: 8.36; asym: 5.00; tree : (1 AND 5)
# >> G_4: init: 0.46; noise: 0.08; b: 1.69; m: 1.48; expr: 1.00; deg: 0.10; theta: 2.07; asym: 5.00; tree : 1
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 2.75; noise: 0.29; b: 1.51; m: 6.43; expr: 1.00; deg: 0.10; theta: 8.93; asym: 5.00; tree : (NOT 2 OR 1)
# >> G_1: init: 0.55; noise: 0.50; b: 0.69; m: 8.28; expr: 1.00; deg: 0.10; theta: 4.20; asym: 5.00; tree : 2
# >> G_2: init: 0.23; noise: 0.30; b: 2.61; m: 6.19; expr: 1.00; deg: 0.10; theta: 8.43; asym: 5.00; tree : (4 OR NOT 2)
# >> G_3: init: 0.86; noise: 0.02; b: 2.82; m: 8.86; expr: 1.00; deg: 0.10; theta: 2.37; asym: 5.00; tree : 5
# >> G_4: init: 0.39; noise: 0.53; b: 0.68; m: 5.73; expr: 1.00; deg: 0.10; theta: 9.85; asym: 5.00; tree : (4 AND (5 OR 1))
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.31; noise: 0.40; b: 3.94; m: 8.34; expr: 1.00; deg: 0.10; theta: 6.20; asym: 5.00; tree : ((3 OR 0) OR 1)
# >> G_1: init: 0.29; noise: 0.22; b: 2.32; m: 5.63; expr: 1.00; deg: 0.10; theta: 1.81; asym: 5.00; tree : 2
# >> G_2: init: 0.67; noise: 0.33; b: 2.48; m: 4.96; expr: 1.00; deg: 0.10; theta: 7.68; asym: 5.00; tree : 4
# >> G_3: init: 0.14; noise: 0.42; b: 0.57; m: 5.80; expr: 1.00; deg: 0.10; theta: 6.31; asym: 5.00; tree : (4 AND (3 AND 5))
# >> G_4: init: 0.98; noise: 0.34; b: 0.40; m: 4.14; expr: 1.00; deg: 0.10; theta: 1.45; asym: 5.00; tree : 1
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 0.75; noise: 0.15; b: 1.87; m: 4.19; expr: 1.00; deg: 0.10; theta: 0.86; asym: 5.00; tree : (0 OR 1)
# >> G_1: init: 0.46; noise: 0.64; b: 3.13; m: 8.90; expr: 1.00; deg: 0.10; theta: 9.28; asym: 5.00; tree : 3
# >> G_2: init: 0.32; noise: 0.66; b: 3.79; m: 8.95; expr: 1.00; deg: 0.10; theta: 5.79; asym: 5.00; tree : 0
# >> G_3: init: 1.29; noise: 0.59; b: 2.28; m: 3.63; expr: 1.00; deg: 0.10; theta: 8.23; asym: 5.00; tree : 4
# >> G_4: init: 0.49; noise: 0.31; b: 2.60; m: 6.76; expr: 1.00; deg: 0.10; theta: 2.96; asym: 5.58; tree : 2
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.56; noise: 0.49; b: 2.59; m: 3.58; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : NOT (2 AND 0)
# >> G_1: init: 1.07; noise: 0.03; b: 1.69; m: 5.56; expr: 1.00; deg: 0.10; theta: 3.37; asym: 5.00; tree : 0
# >> G_2: init: 0.48; noise: 0.69; b: 2.15; m: 6.99; expr: 1.00; deg: 0.10; theta: 5.07; asym: 5.00; tree : 0
# >> G_3: init: 2.00; noise: 0.23; b: 2.35; m: 2.27; expr: 1.00; deg: 0.10; theta: 6.04; asym: 5.00; tree : 0
# >> G_4: init: 0.23; noise: 0.66; b: 1.90; m: 2.62; expr: 1.00; deg: 0.10; theta: 2.08; asym: 5.00; tree : NOT 3
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 0.68; noise: 0.60; b: 0.72; m: 7.97; expr: 1.00; deg: 0.10; theta: 7.20; asym: 5.00; tree : NOT 5
# >> G_1: init: 0.34; noise: 0.71; b: 1.20; m: 6.35; expr: 1.00; deg: 0.10; theta: 4.26; asym: 5.00; tree : 2
# >> G_2: init: 1.27; noise: 0.25; b: 0.30; m: 7.95; expr: 1.00; deg: 0.10; theta: 1.70; asym: 5.00; tree : (NOT 1 AND 4)
# >> G_3: init: 0.96; noise: 0.43; b: 1.32; m: 5.22; expr: 1.00; deg: 0.10; theta: 0.71; asym: 5.00; tree : 4
# >> G_4: init: 1.41; noise: 0.30; b: 1.75; m: 5.33; expr: 1.00; deg: 0.10; theta: 7.77; asym: 5.00; tree : 3
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 0.80; noise: 0.31; b: 1.60; m: 2.30; expr: 1.00; deg: 0.10; theta: 2.13; asym: 5.00; tree : ((2 OR 5) OR 0)
# >> G_1: init: 0.52; noise: 0.06; b: 1.92; m: 8.06; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : (2 OR 4)
# >> G_2: init: 1.87; noise: 0.07; b: 1.55; m: 3.86; expr: 1.00; deg: 0.10; theta: 7.28; asym: 5.00; tree : NOT NOT 5
# >> G_3: init: 1.03; noise: 0.13; b: 1.47; m: 8.98; expr: 1.00; deg: 0.10; theta: 7.32; asym: 5.00; tree : 1
# >> G_4: init: 1.28; noise: 0.14; b: 3.19; m: 2.12; expr: 1.00; deg: 0.10; theta: 6.14; asym: 5.00; tree : 2
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 2.00; noise: 0.71; b: 1.29; m: 9.08; expr: 1.00; deg: 0.10; theta: 8.55; asym: 5.00; tree : 2
# >> G_1: init: 1.16; noise: 0.49; b: 1.58; m: 3.83; expr: 1.00; deg: 0.10; theta: 8.19; asym: 5.00; tree : ((5 OR 2) AND (3 AND 4))
# >> G_2: init: 1.65; noise: 0.69; b: 1.91; m: 3.18; expr: 1.00; deg: 0.10; theta: 1.41; asym: 5.00; tree : 2
# >> G_3: init: 0.29; noise: 0.63; b: 3.30; m: 7.42; expr: 1.00; deg: 0.10; theta: 3.62; asym: 5.00; tree : 5
# >> G_4: init: 0.27; noise: 0.35; b: 0.84; m: 1.92; expr: 1.00; deg: 0.10; theta: 8.86; asym: 5.00; tree : (3 OR NOT 4)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.20; noise: 0.32; b: 2.35; m: 2.39; expr: 1.00; deg: 0.10; theta: 0.01; asym: 5.00; tree : 5
# >> G_1: init: 1.90; noise: 0.34; b: 1.92; m: 8.90; expr: 1.00; deg: 0.10; theta: 9.73; asym: 5.00; tree : 3
# >> G_2: init: 0.34; noise: 0.38; b: 3.13; m: 4.02; expr: 1.00; deg: 0.10; theta: 9.53; asym: 5.00; tree : 0
# >> G_3: init: 0.18; noise: 0.37; b: 1.45; m: 6.14; expr: 1.00; deg: 0.10; theta: 7.18; asym: 5.00; tree : 5
# >> G_4: init: 1.00; noise: 0.45; b: 0.65; m: 5.17; expr: 1.00; deg: 0.10; theta: 0.96; asym: 5.00; tree : 0
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 0.58; noise: 0.57; b: 0.49; m: 8.73; expr: 1.00; deg: 0.10; theta: 1.30; asym: 5.00; tree : NOT 3
# >> G_1: init: 1.29; noise: 0.03; b: 2.22; m: 5.44; expr: 1.00; deg: 0.10; theta: 2.95; asym: 5.00; tree : 4
# >> G_2: init: 1.51; noise: 0.48; b: 1.95; m: 3.18; expr: 1.00; deg: 0.10; theta: 6.14; asym: 5.43; tree : 1
# >> G_3: init: 1.04; noise: 0.18; b: 0.95; m: 7.14; expr: 1.00; deg: 0.10; theta: 6.41; asym: 5.00; tree : NOT NOT 0
# >> G_4: init: 1.37; noise: 0.81; b: 3.75; m: 4.16; expr: 1.00; deg: 0.10; theta: 8.96; asym: 5.00; tree : 0
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 0.55; noise: 0.20; b: 1.43; m: 2.09; expr: 1.00; deg: 0.10; theta: 3.67; asym: 5.00; tree : ((1 OR 5) OR (2 OR 3))
# >> G_1: init: 0.78; noise: 0.17; b: 3.13; m: 1.89; expr: 1.00; deg: 0.10; theta: 1.89; asym: 5.00; tree : (3 AND (5 OR 4))
# >> G_2: init: 1.42; noise: 0.09; b: 1.88; m: 2.65; expr: 1.00; deg: 0.10; theta: 8.87; asym: 5.00; tree : NOT 0
# >> G_3: init: 0.34; noise: 0.22; b: 3.31; m: 3.87; expr: 1.00; deg: 0.10; theta: 9.78; asym: 5.00; tree : (2 OR 1)
# >> G_4: init: 0.68; noise: 0.17; b: 2.01; m: 6.14; expr: 1.00; deg: 0.10; theta: 3.21; asym: 5.00; tree : 5
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 0.45; noise: 0.27; b: 1.76; m: 4.00; expr: 1.00; deg: 0.10; theta: 9.86; asym: 5.00; tree : NOT 1
# >> G_1: init: 1.05; noise: 0.49; b: 1.68; m: 6.55; expr: 1.00; deg: 0.10; theta: 6.87; asym: 5.00; tree : 4
# >> G_2: init: 0.82; noise: 0.26; b: 1.24; m: 6.66; expr: 1.00; deg: 0.10; theta: 4.78; asym: 5.00; tree : (3 OR 4)
# >> G_3: init: 0.93; noise: 0.50; b: 1.78; m: 2.61; expr: 1.00; deg: 0.10; theta: 3.26; asym: 5.00; tree : 0
# >> G_4: init: 0.06; noise: 0.57; b: 0.86; m: 9.76; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : NOT 3
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 2.20; noise: 0.24; b: 0.23; m: 5.70; expr: 1.00; deg: 0.10; theta: 5.20; asym: 5.00; tree : NOT (5 AND 1)
# >> G_1: init: 0.44; noise: 0.20; b: 0.89; m: 7.39; expr: 1.01; deg: 0.10; theta: 6.66; asym: 5.00; tree : ((3 AND 0) OR 2)
# >> G_2: init: 1.73; noise: 0.47; b: 0.77; m: 1.03; expr: 0.94; deg: 0.10; theta: 8.38; asym: 5.00; tree : (NOT 0 AND NOT 5)
# >> G_3: init: 1.28; noise: 0.59; b: 1.37; m: 7.75; expr: 1.00; deg: 0.10; theta: 2.02; asym: 5.00; tree : 5
# >> G_4: init: 1.04; noise: 0.12; b: 1.69; m: 2.28; expr: 1.00; deg: 0.10; theta: 4.42; asym: 5.00; tree : NOT 4
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.44; noise: 0.15; b: 1.28; m: 1.65; expr: 1.00; deg: 0.10; theta: 4.69; asym: 5.00; tree : NOT 5
# >> G_1: init: 0.22; noise: 0.32; b: 1.11; m: 2.78; expr: 1.00; deg: 0.11; theta: 1.61; asym: 5.00; tree : (NOT 3 AND 1)
# >> G_2: init: 0.72; noise: 0.54; b: 1.20; m: 6.81; expr: 1.00; deg: 0.10; theta: 3.46; asym: 5.00; tree : 2
# >> G_3: init: 1.82; noise: 0.72; b: 0.48; m: 4.16; expr: 1.00; deg: 0.10; theta: 3.43; asym: 5.00; tree : 4
# >> G_4: init: 0.54; noise: 0.25; b: 0.13; m: 5.24; expr: 1.00; deg: 0.10; theta: 9.36; asym: 5.00; tree : NOT (0 OR 1)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 0.15; noise: 0.36; b: 1.04; m: 2.18; expr: 1.00; deg: 0.10; theta: 9.06; asym: 5.00; tree : 2
# >> G_1: init: 0.21; noise: 0.11; b: 1.69; m: 1.34; expr: 1.00; deg: 0.10; theta: 4.80; asym: 5.00; tree : 1
# >> G_2: init: 0.67; noise: 0.43; b: 1.52; m: 7.97; expr: 1.00; deg: 0.10; theta: 1.69; asym: 5.00; tree : NOT 5
# >> G_3: init: 0.48; noise: 0.33; b: 3.59; m: 5.71; expr: 1.00; deg: 0.10; theta: 3.18; asym: 5.00; tree : 2
# >> G_4: init: 0.95; noise: 0.43; b: 1.92; m: 5.80; expr: 1.00; deg: 0.10; theta: 0.91; asym: 5.00; tree : 2
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.03; noise: 0.45; b: 0.14; m: 3.07; expr: 1.00; deg: 0.10; theta: 7.20; asym: 5.00; tree : ((3 OR 0) OR 1)
# >> G_1: init: 1.17; noise: 0.32; b: 3.91; m: 3.02; expr: 1.00; deg: 0.10; theta: 3.52; asym: 5.00; tree : NOT 1
# >> G_2: init: 1.19; noise: 0.20; b: 0.64; m: 4.06; expr: 1.00; deg: 0.10; theta: 8.19; asym: 5.00; tree : ((3 OR 2) OR (1 OR 4))
# >> G_3: init: 0.81; noise: 0.25; b: 0.25; m: 6.35; expr: 1.00; deg: 0.10; theta: 9.17; asym: 5.00; tree : (2 AND 4)
# >> G_4: init: 1.25; noise: 0.35; b: 1.82; m: 2.73; expr: 1.00; deg: 0.10; theta: 8.76; asym: 5.00; tree : 5
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.09; noise: 0.47; b: 1.08; m: 6.74; expr: 1.00; deg: 0.10; theta: 0.01; asym: 5.00; tree : 3
# >> G_1: init: 0.94; noise: 0.20; b: 3.91; m: 9.17; expr: 1.00; deg: 0.10; theta: 2.09; asym: 5.00; tree : 5
# >> G_2: init: 1.63; noise: 0.68; b: 1.30; m: 6.83; expr: 1.00; deg: 0.08; theta: 7.09; asym: 5.00; tree : NOT NOT 0
# >> G_3: init: 1.26; noise: 0.73; b: 3.11; m: 3.82; expr: 1.00; deg: 0.10; theta: 9.07; asym: 5.00; tree : (5 OR (2 AND 1))
# >> G_4: init: 1.38; noise: 0.42; b: 0.02; m: 3.24; expr: 1.00; deg: 0.10; theta: 9.68; asym: 5.00; tree : 2
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 0.38; noise: 0.61; b: 1.73; m: 6.37; expr: 1.00; deg: 0.10; theta: 3.01; asym: 5.00; tree : NOT 4
# >> G_1: init: 1.02; noise: 0.14; b: 2.65; m: 8.39; expr: 1.00; deg: 0.10; theta: 3.85; asym: 5.00; tree : NOT 1
# >> G_2: init: 0.59; noise: 0.64; b: 1.87; m: 3.02; expr: 1.00; deg: 0.10; theta: 6.32; asym: 5.00; tree : 2
# >> G_3: init: 0.84; noise: 0.08; b: 2.38; m: 6.73; expr: 1.00; deg: 0.10; theta: 6.35; asym: 5.00; tree : 4
# >> G_4: init: 0.06; noise: 0.12; b: 0.34; m: 9.00; expr: 1.00; deg: 0.10; theta: 9.41; asym: 5.00; tree : (4 AND 0)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 0.50; noise: 0.24; b: 0.98; m: 5.04; expr: 1.00; deg: 0.10; theta: 0.52; asym: 5.00; tree : 3
# >> G_1: init: 0.46; noise: 0.17; b: 1.35; m: 3.88; expr: 1.00; deg: 0.09; theta: 2.65; asym: 5.00; tree : (2 AND (0 AND 5))
# >> G_2: init: 0.40; noise: 0.73; b: 1.20; m: 9.84; expr: 1.00; deg: 0.10; theta: 4.18; asym: 5.00; tree : NOT NOT 4
# >> G_3: init: 0.65; noise: 0.40; b: 0.73; m: 9.59; expr: 1.00; deg: 0.10; theta: 3.26; asym: 5.00; tree : NOT 1
# >> G_4: init: 1.30; noise: 0.24; b: 2.36; m: 3.62; expr: 1.00; deg: 0.10; theta: 6.87; asym: 5.00; tree : 0
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 0.02; noise: 0.33; b: 1.08; m: 1.16; expr: 1.00; deg: 0.10; theta: 4.35; asym: 5.00; tree : 1
# >> G_1: init: 1.18; noise: 0.47; b: 3.67; m: 6.53; expr: 1.00; deg: 0.10; theta: 3.57; asym: 5.00; tree : 3
# >> G_2: init: 0.52; noise: 0.27; b: 1.03; m: 1.23; expr: 1.00; deg: 0.10; theta: 6.32; asym: 5.00; tree : 4
# >> G_3: init: 0.76; noise: 0.40; b: 2.33; m: 8.04; expr: 1.00; deg: 0.10; theta: 6.56; asym: 5.00; tree : 2
# >> G_4: init: 0.66; noise: 0.07; b: 2.50; m: 8.05; expr: 1.00; deg: 0.10; theta: 2.24; asym: 5.00; tree : ((4 AND 5) OR 3)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 0.52; noise: 0.02; b: 2.93; m: 9.39; expr: 1.00; deg: 0.10; theta: 0.94; asym: 5.00; tree : ((3 OR 4) OR 2)
# >> G_1: init: 0.73; noise: 0.13; b: 2.02; m: 3.17; expr: 1.00; deg: 0.10; theta: 1.57; asym: 5.00; tree : NOT 2
# >> G_2: init: 1.23; noise: 0.81; b: 3.68; m: 4.84; expr: 1.00; deg: 0.10; theta: 3.55; asym: 5.00; tree : ((0 AND 3) AND NOT 4)
# >> G_3: init: 0.92; noise: 0.17; b: 2.64; m: 8.35; expr: 1.00; deg: 0.09; theta: 7.83; asym: 5.00; tree : 3
# >> G_4: init: 0.28; noise: 0.06; b: 2.40; m: 7.92; expr: 1.00; deg: 0.10; theta: 1.05; asym: 5.00; tree : 1
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.33; noise: 0.40; b: 3.37; m: 8.64; expr: 1.00; deg: 0.10; theta: 0.32; asym: 5.00; tree : 0
# >> G_1: init: 0.63; noise: 0.24; b: 2.70; m: 1.35; expr: 1.00; deg: 0.10; theta: 8.31; asym: 5.00; tree : 1
# >> G_2: init: 1.29; noise: 0.35; b: 0.50; m: 3.63; expr: 1.00; deg: 0.10; theta: 7.86; asym: 5.00; tree : NOT 2
# >> G_3: init: 0.89; noise: 0.43; b: 1.72; m: 2.18; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 0
# >> G_4: init: 0.16; noise: 0.39; b: 1.65; m: 7.52; expr: 1.00; deg: 0.10; theta: 4.50; asym: 5.00; tree : (1 AND (0 AND 3))
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 0.46; noise: 0.07; b: 3.79; m: 3.59; expr: 1.00; deg: 0.10; theta: 7.67; asym: 4.36; tree : NOT 0
# >> G_1: init: 1.24; noise: 0.39; b: 1.25; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.42; asym: 5.00; tree : (3 AND (0 OR 2))
# >> G_2: init: 1.20; noise: 0.47; b: 2.03; m: 2.15; expr: 1.00; deg: 0.10; theta: 6.72; asym: 5.00; tree : 3
# >> G_3: init: 0.69; noise: 0.33; b: 3.43; m: 2.10; expr: 1.00; deg: 0.10; theta: 4.47; asym: 5.00; tree : 0
# >> G_4: init: 0.60; noise: 0.32; b: 0.27; m: 8.50; expr: 1.00; deg: 0.10; theta: 7.94; asym: 5.00; tree : 1
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 0.86; noise: 0.44; b: 0.94; m: 1.26; expr: 1.00; deg: 0.10; theta: 6.22; asym: 5.00; tree : (4 AND (3 OR 2))
# >> G_1: init: 0.04; noise: 0.39; b: 1.16; m: 10.00; expr: 1.00; deg: 0.10; theta: 7.25; asym: 5.00; tree : 0
# >> G_2: init: 1.98; noise: 0.53; b: 0.84; m: 2.66; expr: 1.00; deg: 0.10; theta: 6.27; asym: 5.00; tree : NOT 1
# >> G_3: init: 1.05; noise: 0.22; b: 2.29; m: 6.54; expr: 1.00; deg: 0.10; theta: 5.93; asym: 5.00; tree : 4
# >> G_4: init: 1.34; noise: 0.42; b: 0.35; m: 6.75; expr: 1.00; deg: 0.10; theta: 6.52; asym: 5.00; tree : NOT 1
