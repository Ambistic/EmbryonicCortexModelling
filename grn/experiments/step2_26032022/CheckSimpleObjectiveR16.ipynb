# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve_2, show_curve_progenitor
from jf.models.stringmodel import read_model

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**2))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=66, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r16"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r16
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 990.0 for generation 0
# [out] ++ Best 991.0 for generation 1
# Step 3 passed !
# [out] ++ Best 999.0 for generation 15
# [out] ++ Best 1039.0 for generation 45
# Saving ...
# [out] ++ Best 1052.0 for generation 50
# [out] ++ Best 1077.0 for generation 59
# [out] ++ Best 1085.0 for generation 62
# [out] ++ Best 1192.0 for generation 67
# Saving ...
# [out] Step 100
# [out] ++ Best 1204.0 for generation 112
# [out] ++ Best 1242.0 for generation 122
# [out] ++ Best 1252.0 for generation 127
# [out] ++ Best 1274.0 for generation 142
# Saving ...
# [out] ++ Best 1276.0 for generation 162
# [out] ++ Best 1312.0 for generation 163
# [out] ++ Best 1353.0 for generation 180
# [out] ++ Best 1358.0 for generation 181
# Saving ...
# [out] Step 200
# [out] ++ Best 1392.0 for generation 200
# [out] ++ Best 1415.0 for generation 201
# [out] ++ Best 1605.0 for generation 205
# Saving ...
# [out] ++ Best 1652.9999999999998 for generation 252
# Saving ...
# [out] Step 300
# Saving ...
# Saving ...
# [out] Step 400
# [out] ++ Best 1709.0 for generation 439
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# [out] ++ Best 1794.0 for generation 718
# Saving ...
# Saving ...
# [out] Step 800
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# Saving ...
# [out] Step 1300
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# [out] ++ Best 1809.0 for generation 1956
# Saving ...
# [out] Step 2000
# Saving ...
# [out] ++ Best 1824.0 for generation 2073
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r16

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
show_curve_2(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.84; noise: 0.14; b: 3.66; m: 8.47; expr: 1.00; deg: 0.10; theta: 6.05; asym: 5.00; tree : (-5 OR (-2 OR -4))
# >> G_1: init: 0.65; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : -5
# >> G_2: init: 0.93; noise: 0.38; b: 1.69; m: 4.05; expr: 1.00; deg: 0.11; theta: 2.99; asym: 5.00; tree : ((-0 OR -5) OR (1 AND -2))
# >> G_3: init: 2.28; noise: 0.11; b: 2.66; m: 2.55; expr: 1.00; deg: 0.10; theta: 8.37; asym: 5.00; tree : -3
# >> G_4: init: 0.78; noise: 0.20; b: 3.56; m: 3.92; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.84; noise: 0.14; b: 3.66; m: 8.47; expr: 1.19; deg: 0.10; theta: 6.05; asym: 5.00; tree : (1 OR (-2 OR -4))
# >> G_1: init: 0.65; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : (-5 AND 0)
# >> G_2: init: 0.93; noise: 0.38; b: 1.69; m: 4.05; expr: 0.81; deg: 0.11; theta: 2.99; asym: 5.00; tree : ((-0 OR -5) OR (1 AND -2))
# >> G_3: init: 2.28; noise: 0.11; b: 2.66; m: 2.77; expr: 1.00; deg: 0.10; theta: 8.37; asym: 4.97; tree : -3
# >> G_4: init: 0.78; noise: 0.20; b: 3.56; m: 3.92; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.84; noise: 0.14; b: 4.21; m: 8.47; expr: 1.19; deg: 0.10; theta: 6.05; asym: 5.00; tree : (-5 OR (-2 OR -4))
# >> G_1: init: 0.65; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : -4
# >> G_2: init: 2.97; noise: 0.08; b: 8.51; m: 2.71; expr: 4.65; deg: 0.46; theta: 1.62; asym: 6.56; tree : (0 AND 3)
# >> G_3: init: 2.32; noise: 0.10; b: 2.66; m: 2.77; expr: 1.00; deg: 0.10; theta: 9.40; asym: 4.97; tree : -3
# >> G_4: init: 0.63; noise: 0.20; b: 3.56; m: 3.92; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.84; noise: 0.14; b: 4.21; m: 8.47; expr: 1.19; deg: 0.10; theta: 6.05; asym: 5.00; tree : (-5 OR (-2 OR -4))
# >> G_1: init: 0.65; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : (-4 OR 2)
# >> G_2: init: 2.97; noise: 0.09; b: 8.51; m: 2.71; expr: 4.65; deg: 0.46; theta: 1.62; asym: 7.64; tree : (0 AND 3)
# >> G_3: init: 1.93; noise: 0.10; b: 2.66; m: 2.77; expr: 1.00; deg: 0.10; theta: 9.40; asym: 4.97; tree : (-3 AND 5)
# >> G_4: init: 0.63; noise: 0.20; b: 3.56; m: 3.92; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.84; noise: 0.14; b: 4.55; m: 8.47; expr: 1.19; deg: 0.10; theta: 6.05; asym: 5.00; tree : (-2 OR -4)
# >> G_1: init: 0.65; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : -4
# >> G_2: init: 2.97; noise: 0.08; b: 8.51; m: 2.71; expr: 4.65; deg: 0.46; theta: 1.62; asym: 6.56; tree : (0 AND -2)
# >> G_3: init: 2.32; noise: 0.10; b: 2.66; m: 2.77; expr: 0.82; deg: 0.10; theta: 10.51; asym: 4.97; tree : -4
# >> G_4: init: 0.55; noise: 0.20; b: 3.56; m: 3.92; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.84; noise: 0.14; b: 4.55; m: 8.47; expr: 1.19; deg: 0.10; theta: 6.05; asym: 5.00; tree : (-2 OR -4)
# >> G_1: init: 0.65; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : -4
# >> G_2: init: 2.97; noise: 0.08; b: 8.51; m: 2.71; expr: 4.65; deg: 0.46; theta: 1.62; asym: 6.56; tree : (0 AND -2)
# >> G_3: init: 2.32; noise: 0.10; b: 2.66; m: 2.77; expr: 0.82; deg: 0.10; theta: 10.51; asym: 4.05; tree : -4
# >> G_4: init: 0.55; noise: 0.20; b: 3.56; m: 3.92; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.84; noise: 0.14; b: 4.55; m: 8.47; expr: 1.19; deg: 0.10; theta: 6.05; asym: 5.00; tree : (-2 OR -4)
# >> G_1: init: 0.65; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.10; theta: 3.82; asym: 5.00; tree : -4
# >> G_2: init: 2.86; noise: 0.06; b: 8.51; m: 2.71; expr: 5.14; deg: 0.46; theta: 1.62; asym: 6.56; tree : (0 AND -2)
# >> G_3: init: 2.32; noise: 0.10; b: 2.66; m: 2.77; expr: 0.82; deg: 0.10; theta: 10.51; asym: 4.05; tree : -4
# >> G_4: init: 0.55; noise: 0.21; b: 3.56; m: 3.92; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 2.13; noise: 0.14; b: 3.94; m: 8.47; expr: 1.19; deg: 0.10; theta: 6.05; asym: 5.00; tree : (1 OR (-2 OR -4))
# >> G_1: init: 0.65; noise: 0.56; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 5.00; tree : -4
# >> G_2: init: 2.97; noise: 0.09; b: 8.51; m: 2.71; expr: 4.04; deg: 0.46; theta: 1.62; asym: 7.64; tree : (0 AND 3)
# >> G_3: init: 0.25; noise: 6.22; b: 4.54; m: 6.74; expr: 4.28; deg: 1.08; theta: 8.79; asym: 4.53; tree : (5 OR -4)
# >> G_4: init: 0.63; noise: 0.20; b: 3.56; m: 3.93; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 2.13; noise: 0.15; b: 3.88; m: 8.47; expr: 1.19; deg: 0.10; theta: 6.05; asym: 4.32; tree : (-2 OR -4)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 5.00; tree : (-4 OR 2)
# >> G_2: init: 2.97; noise: 0.09; b: 8.51; m: 2.71; expr: 4.04; deg: 0.46; theta: 1.62; asym: 7.64; tree : (0 AND 3)
# >> G_3: init: 1.93; noise: 0.10; b: 2.66; m: 2.77; expr: 1.16; deg: 0.10; theta: 10.59; asym: 5.34; tree : 0
# >> G_4: init: 0.63; noise: 0.20; b: 3.56; m: 3.93; expr: 1.00; deg: 0.12; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 2.13; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.10; theta: 5.03; asym: 4.32; tree : (-2 OR -4)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 5.00; tree : (-4 OR 2)
# >> G_2: init: 2.97; noise: 0.09; b: 8.51; m: 2.71; expr: 4.04; deg: 0.48; theta: 1.62; asym: 7.64; tree : (0 AND 3)
# >> G_3: init: 1.93; noise: 0.10; b: 2.48; m: 2.33; expr: 1.13; deg: 0.10; theta: 10.59; asym: 5.34; tree : 0
# >> G_4: init: 0.63; noise: 0.20; b: 3.56; m: 3.93; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 2.11; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.10; theta: 6.05; asym: 4.32; tree : ((-2 OR -4) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 5.00; tree : (-4 OR 2)
# >> G_2: init: 2.97; noise: 0.09; b: 7.52; m: 2.71; expr: 4.04; deg: 0.52; theta: 1.62; asym: 7.64; tree : 0
# >> G_3: init: 1.93; noise: 0.10; b: 2.66; m: 2.77; expr: 1.31; deg: 0.10; theta: 10.59; asym: 5.34; tree : 5
# >> G_4: init: 0.56; noise: 0.20; b: 3.56; m: 3.93; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 2.13; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.09; theta: 6.05; asym: 4.32; tree : ((-2 OR -4) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 5.00; tree : (-4 OR 2)
# >> G_2: init: 2.67; noise: 0.09; b: 7.52; m: 2.71; expr: 4.04; deg: 0.52; theta: 1.62; asym: 7.64; tree : 0
# >> G_3: init: 1.93; noise: 0.10; b: 2.66; m: 2.77; expr: 1.21; deg: 0.10; theta: 11.95; asym: 5.34; tree : 5
# >> G_4: init: 0.56; noise: 0.16; b: 3.56; m: 4.12; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 2.41; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.08; theta: 6.05; asym: 4.32; tree : ((-2 OR -4) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.91; asym: 5.00; tree : (-4 OR 2)
# >> G_2: init: 2.67; noise: 0.09; b: 7.52; m: 2.71; expr: 4.01; deg: 0.52; theta: 1.62; asym: 7.64; tree : (0 AND 2)
# >> G_3: init: 1.93; noise: 0.10; b: 2.66; m: 2.77; expr: 1.26; deg: 0.10; theta: 11.95; asym: 5.34; tree : -1
# >> G_4: init: 0.59; noise: 0.20; b: 3.56; m: 4.12; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 2.41; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.07; theta: 6.05; asym: 4.23; tree : ((-2 OR -4) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 4.89; tree : (-4 OR 2)
# >> G_2: init: 2.61; noise: 0.09; b: 7.52; m: 2.59; expr: 4.04; deg: 0.52; theta: 1.62; asym: 7.64; tree : (0 AND 2)
# >> G_3: init: 0.02; noise: 4.65; b: 6.72; m: 1.24; expr: 0.47; deg: 1.72; theta: 9.21; asym: 6.91; tree : (-2 OR 1)
# >> G_4: init: 0.56; noise: 0.20; b: 3.56; m: 4.12; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 2.41; noise: 0.17; b: 4.21; m: 8.47; expr: 1.19; deg: 0.07; theta: 5.92; asym: 4.23; tree : ((-2 OR -4) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 4.89; tree : (-4 OR 2)
# >> G_2: init: 3.10; noise: 0.09; b: 7.52; m: 2.59; expr: 4.04; deg: 0.52; theta: 1.62; asym: 7.64; tree : (0 AND 2)
# >> G_3: init: 0.02; noise: 4.65; b: 6.72; m: 1.24; expr: 0.47; deg: 1.72; theta: 9.21; asym: 6.91; tree : (-2 OR 1)
# >> G_4: init: 0.56; noise: 0.17; b: 3.56; m: 4.12; expr: 1.00; deg: 0.11; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.07; theta: 6.05; asym: 4.37; tree : ((-2 OR -4) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 4.89; tree : (-4 OR 2)
# >> G_2: init: 2.61; noise: 0.10; b: 7.52; m: 2.59; expr: 4.04; deg: 0.52; theta: 1.62; asym: 7.64; tree : (0 AND 2)
# >> G_3: init: 0.02; noise: 4.65; b: 6.72; m: 1.24; expr: 0.47; deg: 1.72; theta: 9.92; asym: 6.91; tree : 1
# >> G_4: init: 0.56; noise: 0.20; b: 3.56; m: 4.12; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.07; theta: 6.05; asym: 4.23; tree : (-2 OR -4)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 4.89; tree : (-4 OR 2)
# >> G_2: init: 2.61; noise: 0.10; b: 7.04; m: 2.59; expr: 4.04; deg: 0.52; theta: 1.62; asym: 7.64; tree : (0 AND 2)
# >> G_3: init: 0.02; noise: 4.65; b: 6.72; m: 1.24; expr: 0.47; deg: 1.72; theta: 11.04; asym: 6.91; tree : (1 OR -3)
# >> G_4: init: 0.56; noise: 0.20; b: 3.56; m: 4.12; expr: 1.00; deg: 0.10; theta: 5.29; asym: 4.30; tree : -1
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.07; theta: 6.05; asym: 4.23; tree : ((-2 OR -4) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 4.89; tree : (-4 OR 2)
# >> G_2: init: 2.61; noise: 0.10; b: 7.04; m: 2.93; expr: 4.42; deg: 0.52; theta: 1.46; asym: 7.64; tree : (0 AND 2)
# >> G_3: init: 0.02; noise: 3.92; b: 6.72; m: 1.24; expr: 0.47; deg: 1.72; theta: 12.50; asym: 6.91; tree : -3
# >> G_4: init: 0.56; noise: 0.20; b: 3.56; m: 4.12; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.07; theta: 6.05; asym: 4.23; tree : ((-2 OR -4) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 4.89; tree : (-4 OR 2)
# >> G_2: init: 2.61; noise: 0.11; b: 7.04; m: 2.93; expr: 4.42; deg: 0.52; theta: 1.46; asym: 7.64; tree : (0 AND 2)
# >> G_3: init: 0.02; noise: 3.92; b: 6.72; m: 1.24; expr: 0.47; deg: 1.72; theta: 12.50; asym: 6.91; tree : (-3 OR -2)
# >> G_4: init: 0.56; noise: 0.20; b: 3.56; m: 4.12; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 8.27; expr: 1.19; deg: 0.07; theta: 6.03; asym: 3.73; tree : ((-2 OR 5) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 5.03; tree : (-4 OR 2)
# >> G_2: init: 2.32; noise: 0.10; b: 7.52; m: 2.59; expr: 4.04; deg: 0.52; theta: 1.62; asym: 7.64; tree : (0 AND 2)
# >> G_3: init: 0.02; noise: 5.06; b: 6.93; m: 1.24; expr: 0.47; deg: 1.72; theta: 9.92; asym: 6.91; tree : (4 OR -3)
# >> G_4: init: 0.56; noise: 0.21; b: 3.56; m: 4.12; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 8.47; expr: 1.19; deg: 0.05; theta: 6.05; asym: 4.23; tree : ((-2 OR -4) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 5.22; tree : (-4 OR (2 AND 0))
# >> G_2: init: 2.32; noise: 0.10; b: 7.52; m: 2.59; expr: 4.04; deg: 0.52; theta: 1.62; asym: 7.64; tree : 2
# >> G_3: init: 0.02; noise: 4.65; b: 5.81; m: 1.24; expr: 0.47; deg: 1.82; theta: 9.92; asym: 6.91; tree : -3
# >> G_4: init: 0.56; noise: 0.21; b: 3.56; m: 4.12; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 7.71; expr: 1.19; deg: 0.07; theta: 6.03; asym: 4.23; tree : ((-2 OR 5) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.82; asym: 5.03; tree : (-4 OR 2)
# >> G_2: init: 2.32; noise: 0.09; b: 7.52; m: 2.59; expr: 3.45; deg: 0.52; theta: 1.62; asym: 8.04; tree : ((0 AND 1) AND 2)
# >> G_3: init: 0.02; noise: 4.88; b: 6.93; m: 1.24; expr: 0.47; deg: 1.72; theta: 11.79; asym: 6.91; tree : (1 OR -3)
# >> G_4: init: 0.56; noise: 0.18; b: 3.56; m: 4.41; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 7.78; expr: 1.19; deg: 0.06; theta: 6.03; asym: 4.23; tree : ((-2 OR 5) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.79; asym: 5.03; tree : (-4 OR 2)
# >> G_2: init: 2.32; noise: 0.09; b: 7.52; m: 2.59; expr: 3.45; deg: 0.52; theta: 1.62; asym: 8.04; tree : ((0 AND 1) AND 2)
# >> G_3: init: 0.02; noise: 4.88; b: 6.93; m: 1.24; expr: 0.47; deg: 1.72; theta: 11.79; asym: 6.91; tree : (4 OR -3)
# >> G_4: init: 0.56; noise: 0.18; b: 3.56; m: 4.41; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 7.78; expr: 1.19; deg: 0.06; theta: 6.03; asym: 4.23; tree : (-2 OR 0)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.79; asym: 5.03; tree : (-4 OR 2)
# >> G_2: init: 2.32; noise: 0.09; b: 7.52; m: 2.59; expr: 3.45; deg: 0.52; theta: 1.62; asym: 8.04; tree : ((0 AND 1) AND 2)
# >> G_3: init: 0.02; noise: 4.88; b: 6.93; m: 1.24; expr: 0.47; deg: 1.72; theta: 11.79; asym: 6.91; tree : (4 OR -3)
# >> G_4: init: 0.56; noise: 0.18; b: 3.56; m: 4.41; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 7.78; expr: 1.19; deg: 0.07; theta: 6.03; asym: 4.23; tree : ((-2 OR 5) OR -1)
# >> G_1: init: 0.50; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.09; theta: 3.79; asym: 5.03; tree : (-4 OR 2)
# >> G_2: init: 2.32; noise: 0.09; b: 7.52; m: 2.59; expr: 3.45; deg: 0.52; theta: 1.59; asym: 8.96; tree : ((0 AND 1) AND 2)
# >> G_3: init: 0.02; noise: 4.88; b: 6.93; m: 1.19; expr: 0.47; deg: 1.72; theta: 11.79; asym: 6.91; tree : ((1 AND 4) OR -3)
# >> G_4: init: 0.56; noise: 0.18; b: 3.56; m: 4.41; expr: 1.00; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 2.71; noise: 0.15; b: 4.21; m: 7.78; expr: 1.19; deg: 0.07; theta: 6.03; asym: 4.81; tree : ((-2 OR 5) OR -1)
# >> G_1: init: 0.55; noise: 0.57; b: 2.22; m: 6.48; expr: 1.00; deg: 0.08; theta: 3.77; asym: 5.03; tree : (-4 OR 2)
# >> G_2: init: 2.32; noise: 0.09; b: 7.52; m: 2.59; expr: 3.45; deg: 0.52; theta: 1.59; asym: 8.04; tree : 1
# >> G_3: init: 0.02; noise: 4.88; b: 6.93; m: 1.19; expr: 0.47; deg: 1.71; theta: 10.43; asym: 6.91; tree : (1 OR -3)
# >> G_4: init: 0.56; noise: 0.18; b: 3.56; m: 4.41; expr: 1.02; deg: 0.10; theta: 5.29; asym: 5.00; tree : -1
