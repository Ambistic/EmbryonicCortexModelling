# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + s_all + s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = [p**prun.exponent for p in pop_fit]
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "checkperf_2102_v6"
res = main(prun)
# Out:
# Exporting at output/checkperf_2102_v6
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 0.00831845693454963 for generation 0
# [out] ++ Best 0.008806328229831937 for generation 2
# [out] ++ Best 0.010945442693322583 for generation 6
# Saving ...
# Saving ...
# [out] Step 100
# Saving ...
# Saving ...
# [out] Step 200
# Saving ...
# Saving ...
# [out] Step 300
# Saving ...
# Saving ...
# [out] Step 400
# [out] ++ Best 0.013310592778475707 for generation 429
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# [out] ++ Best 0.013339415600767398 for generation 554
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# [out] ++ Best 0.013375540198937545 for generation 725
# Saving ...
# Saving ...
# [out] Step 800
# [out] ++ Best 0.016031346288003883 for generation 803
# Saving ...
# [out] ++ Best 0.030148942995075784 for generation 883
# Saving ...
# [out] Step 900
# [out] ++ Best 0.030912175698255898 for generation 920
# [out] ++ Best 0.0329442022277419 for generation 941
# [out] ++ Best 0.03465317459519848 for generation 943
# Saving ...
# [out] ++ Best 0.05856399349612894 for generation 959
# [out] ++ Best 0.06373945067841091 for generation 963
# Saving ...
# [out] Step 1000
# [out] ++ Best 0.06776141119256436 for generation 1025
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...

# %%
print(1)

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/checkperf_2102_v6

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 0.49; noise: 0.29; b: 0.29; m: 4.71; expr: 1.00; deg: 0.10; theta: 7.47; asym: 5.00; tree : 3
# >> G_1: init: 1.19; noise: 0.49; b: 1.07; m: 4.98; expr: 1.00; deg: 0.10; theta: 7.74; asym: 5.00; tree : 0
# >> G_2: init: 1.77; noise: 0.44; b: 3.28; m: 9.01; expr: 1.00; deg: 0.10; theta: 7.23; asym: 5.00; tree : 5
# >> G_3: init: 1.32; noise: 0.57; b: 2.39; m: 5.62; expr: 1.00; deg: 0.10; theta: 3.83; asym: 5.00; tree : ((4 OR 0) AND 3)
# >> G_4: init: 0.03; noise: 0.10; b: 1.95; m: 6.51; expr: 1.00; deg: 0.10; theta: 8.22; asym: 5.00; tree : 1
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 0.49; noise: 0.29; b: 0.29; m: 4.71; expr: 1.00; deg: 0.10; theta: 7.47; asym: 5.00; tree : 3
# >> G_1: init: 1.19; noise: 0.49; b: 1.07; m: 4.98; expr: 1.00; deg: 0.10; theta: 7.74; asym: 5.00; tree : 0
# >> G_2: init: 1.77; noise: 0.44; b: 3.28; m: 9.01; expr: 1.00; deg: 0.10; theta: 7.29; asym: 4.36; tree : 5
# >> G_3: init: 1.32; noise: 0.57; b: 2.39; m: 5.62; expr: 1.00; deg: 0.10; theta: 3.83; asym: 5.00; tree : ((4 OR 0) AND 3)
# >> G_4: init: 0.03; noise: 0.10; b: 1.95; m: 6.51; expr: 1.00; deg: 0.10; theta: 8.32; asym: 5.00; tree : 1
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 0.47; noise: 0.57; b: 0.75; m: 7.96; expr: 1.00; deg: 0.10; theta: 6.58; asym: 5.00; tree : (0 OR (4 OR 1))
# >> G_1: init: 1.49; noise: 0.14; b: 2.14; m: 1.19; expr: 1.00; deg: 0.10; theta: 8.29; asym: 5.00; tree : ((1 AND 2) OR 5)
# >> G_2: init: 0.28; noise: 0.49; b: 2.27; m: 6.37; expr: 1.00; deg: 0.10; theta: 6.37; asym: 5.00; tree : 5
# >> G_3: init: 0.87; noise: 0.05; b: 1.61; m: 8.99; expr: 1.00; deg: 0.10; theta: 6.53; asym: 5.00; tree : 0
# >> G_4: init: 0.53; noise: 0.46; b: 0.65; m: 8.30; expr: 1.00; deg: 0.10; theta: 3.87; asym: 5.00; tree : 1
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 2.20; noise: 0.10; b: 1.91; m: 7.30; expr: 1.00; deg: 0.10; theta: 0.49; asym: 5.00; tree : (4 AND 1)
# >> G_1: init: 1.18; noise: 0.41; b: 0.82; m: 2.34; expr: 1.00; deg: 0.10; theta: 0.91; asym: 5.00; tree : ((5 OR 3) AND (1 OR 0))
# >> G_2: init: 0.35; noise: 0.50; b: 3.04; m: 2.63; expr: 1.00; deg: 0.10; theta: 7.82; asym: 4.09; tree : (NOT 2 OR (0 OR 4))
# >> G_3: init: 0.64; noise: 0.18; b: 1.32; m: 2.46; expr: 1.00; deg: 0.10; theta: 8.25; asym: 5.00; tree : (1 AND 4)
# >> G_4: init: 0.87; noise: 0.29; b: 1.52; m: 3.97; expr: 1.00; deg: 0.10; theta: 13.42; asym: 5.00; tree : (4 OR 1)
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 2.32; noise: 0.28; b: 2.43; m: 6.85; expr: 1.00; deg: 0.10; theta: 3.59; asym: 5.00; tree : (4 AND 1)
# >> G_1: init: 0.43; noise: 0.74; b: 0.38; m: 7.87; expr: 1.00; deg: 0.10; theta: 0.02; asym: 5.00; tree : (3 AND 2)
# >> G_2: init: 1.08; noise: 0.28; b: 1.59; m: 3.62; expr: 1.00; deg: 0.10; theta: 1.91; asym: 5.00; tree : 4
# >> G_3: init: 0.17; noise: 0.39; b: 1.90; m: 6.60; expr: 1.00; deg: 0.10; theta: 8.39; asym: 5.00; tree : (2 OR (1 OR 5))
# >> G_4: init: 0.21; noise: 0.40; b: 3.23; m: 9.52; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : 2
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 2.55; noise: 0.34; b: 0.33; m: 6.08; expr: 1.00; deg: 0.10; theta: 1.79; asym: 5.00; tree : 0
# >> G_1: init: 0.94; noise: 0.36; b: 0.95; m: 8.51; expr: 1.00; deg: 0.10; theta: 4.87; asym: 5.00; tree : ((3 OR 0) OR (4 AND 1))
# >> G_2: init: 0.59; noise: 0.04; b: 0.45; m: 2.45; expr: 1.00; deg: 0.10; theta: 6.10; asym: 5.00; tree : (0 OR 4)
# >> G_3: init: 1.21; noise: 0.27; b: 0.69; m: 5.52; expr: 1.00; deg: 0.10; theta: 1.66; asym: 5.00; tree : 5
# >> G_4: init: 0.93; noise: 0.39; b: 0.42; m: 3.81; expr: 1.00; deg: 0.10; theta: 6.70; asym: 5.00; tree : 4
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 0.97; noise: 0.31; b: 2.67; m: 3.04; expr: 1.00; deg: 0.10; theta: 3.22; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 0.13; b: 0.75; m: 8.19; expr: 1.00; deg: 0.10; theta: 7.77; asym: 4.20; tree : ((2 OR 1) AND NOT 3)
# >> G_2: init: 1.95; noise: 0.12; b: 1.29; m: 1.78; expr: 1.00; deg: 0.10; theta: 3.55; asym: 5.00; tree : 5
# >> G_3: init: 0.79; noise: 0.06; b: 1.56; m: 5.84; expr: 1.00; deg: 0.10; theta: 8.44; asym: 5.00; tree : (4 OR NOT 1)
# >> G_4: init: 0.89; noise: 0.66; b: 1.44; m: 8.94; expr: 1.00; deg: 0.10; theta: 6.20; asym: 5.00; tree : NOT (3 AND 4)
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 0.97; noise: 0.31; b: 2.67; m: 3.04; expr: 1.00; deg: 0.10; theta: 3.22; asym: 5.00; tree : 4
# >> G_1: init: 0.35; noise: 0.13; b: 0.75; m: 8.19; expr: 1.00; deg: 0.10; theta: 8.87; asym: 4.20; tree : ((2 OR 1) AND NOT 3)
# >> G_2: init: 1.95; noise: 0.12; b: 1.29; m: 1.78; expr: 1.00; deg: 0.10; theta: 3.87; asym: 5.00; tree : 4
# >> G_3: init: 0.79; noise: 0.06; b: 1.56; m: 5.84; expr: 1.00; deg: 0.10; theta: 8.45; asym: 5.00; tree : (4 OR NOT (1 AND 2))
# >> G_4: init: 0.89; noise: 0.66; b: 1.44; m: 8.94; expr: 1.00; deg: 0.10; theta: 5.33; asym: 5.00; tree : NOT (3 AND (4 OR 2))
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 0.56; noise: 0.29; b: 1.28; m: 3.28; expr: 1.00; deg: 0.10; theta: 8.43; asym: 5.00; tree : 2
# >> G_1: init: 1.18; noise: 0.29; b: 2.28; m: 6.81; expr: 1.00; deg: 0.10; theta: 9.00; asym: 5.00; tree : 5
# >> G_2: init: 0.91; noise: 0.29; b: 1.66; m: 2.65; expr: 1.00; deg: 0.10; theta: 7.04; asym: 5.00; tree : NOT 4
# >> G_3: init: 0.68; noise: 0.42; b: 1.89; m: 5.08; expr: 1.00; deg: 0.10; theta: 5.43; asym: 5.00; tree : (NOT 1 AND 0)
# >> G_4: init: 1.55; noise: 0.37; b: 1.73; m: 4.38; expr: 1.00; deg: 0.10; theta: 7.45; asym: 5.00; tree : 2
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 0.66; noise: 0.45; b: 0.49; m: 1.07; expr: 1.00; deg: 0.10; theta: 2.45; asym: 5.00; tree : ((5 AND 2) OR 4)
# >> G_1: init: 0.77; noise: 0.64; b: 0.34; m: 3.53; expr: 1.00; deg: 0.10; theta: 9.55; asym: 5.00; tree : 3
# >> G_2: init: 0.25; noise: 0.51; b: 2.76; m: 1.23; expr: 1.00; deg: 0.10; theta: 6.94; asym: 5.00; tree : 4
# >> G_3: init: 1.23; noise: 0.68; b: 1.27; m: 1.31; expr: 1.00; deg: 0.10; theta: 9.47; asym: 5.00; tree : 5
# >> G_4: init: 1.21; noise: 0.42; b: 2.11; m: 2.05; expr: 1.00; deg: 0.10; theta: 4.27; asym: 5.00; tree : NOT 1
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 7.96; asym: 5.00; tree : (NOT 1 OR 3)
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 4.78; asym: 5.00; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 8.45; asym: 4.28; tree : (4 OR (3 AND 2))
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.42; asym: 5.00; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 8.07; asym: 5.00; tree : 2
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 8.30; asym: 5.00; tree : NOT 5
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 4.29; asym: 5.00; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 7.48; asym: 4.28; tree : (4 OR 3)
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.42; asym: 4.26; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 8.07; asym: 5.00; tree : 2
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 7.43; asym: 4.08; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 4.78; asym: 5.00; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 9.85; asym: 5.00; tree : (5 OR 3)
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.42; asym: 4.15; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 8.07; asym: 4.19; tree : 2
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 9.07; asym: 5.00; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 4.78; asym: 4.21; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 9.10; asym: 5.00; tree : NOT (4 OR 3)
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 5.84; asym: 5.00; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 8.07; asym: 4.36; tree : 2
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 8.18; asym: 4.08; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 4.92; asym: 5.00; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 8.45; asym: 5.00; tree : (5 OR (3 AND 2))
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.11; asym: 5.00; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 6.60; asym: 4.18; tree : NOT 2
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 8.35; asym: 4.08; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 4.92; asym: 5.00; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 9.55; asym: 5.00; tree : (5 OR 3)
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.11; asym: 4.16; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 5.91; asym: 2.85; tree : NOT NOT 2
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 8.35; asym: 4.08; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 5.96; asym: 5.00; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 8.94; asym: 5.00; tree : 5
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.11; asym: 4.16; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 5.91; asym: 3.03; tree : NOT NOT 2
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 8.77; asym: 4.08; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 5.96; asym: 5.00; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 8.45; asym: 4.17; tree : 3
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.11; asym: 4.16; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 7.08; asym: 4.18; tree : NOT (NOT 2 OR (1 OR 3))
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 8.62; asym: 3.32; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 6.43; asym: 4.07; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 8.45; asym: 5.00; tree : 5
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.11; asym: 4.16; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 8.42; asym: 4.18; tree : NOT NOT 2
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 8.62; asym: 3.32; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 6.43; asym: 3.55; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 8.45; asym: 5.00; tree : 5
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.11; asym: 3.43; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 7.89; asym: 4.18; tree : NOT NOT 2
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 9.21; asym: 3.32; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 6.43; asym: 3.55; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 7.66; asym: 5.00; tree : 5
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 5.87; asym: 4.16; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 8.42; asym: 4.18; tree : NOT NOT 2
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 8.62; asym: 3.32; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 7.47; asym: 2.91; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 8.45; asym: 4.17; tree : 5
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.11; asym: 4.16; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 9.53; asym: 4.18; tree : NOT NOT 2
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 9.15; asym: 3.32; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 5.76; asym: 2.01; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 8.45; asym: 4.07; tree : 5
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.18; asym: 3.60; tree : (NOT 2 OR 0)
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 11.37; asym: 3.42; tree : NOT NOT 2
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 9.67; asym: 3.32; tree : NOT (1 AND NOT 3)
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 5.91; asym: 2.94; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 10.40; asym: 5.00; tree : 5
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.21; asym: 3.43; tree : NOT 2
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 8.40; asym: 4.18; tree : NOT NOT 2
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 9.29; asym: 3.32; tree : NOT 1
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 5.38; asym: 2.01; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 9.17; asym: 2.87; tree : 5
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.18; asym: 3.00; tree : (NOT 2 OR 0)
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 11.37; asym: 3.42; tree : NOT NOT 2
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.19; noise: 0.03; b: 1.48; m: 6.22; expr: 1.00; deg: 0.10; theta: 9.82; asym: 2.67; tree : (NOT 1 OR 5)
# >> G_1: init: 1.41; noise: 0.38; b: 0.58; m: 1.52; expr: 1.00; deg: 0.10; theta: 6.67; asym: 1.83; tree : 3
# >> G_2: init: 1.66; noise: 0.23; b: 3.53; m: 1.13; expr: 1.00; deg: 0.10; theta: 9.95; asym: 3.49; tree : 5
# >> G_3: init: 1.73; noise: 0.27; b: 1.85; m: 4.50; expr: 1.00; deg: 0.10; theta: 6.11; asym: 3.60; tree : (NOT 2 OR 0)
# >> G_4: init: 0.21; noise: 0.07; b: 1.62; m: 1.70; expr: 1.00; deg: 0.10; theta: 8.84; asym: 4.18; tree : NOT NOT 2
