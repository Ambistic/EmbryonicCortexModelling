# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_n, ref_n = normalize_time(stats, ref_stats, "neuron_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_n = stats_n.set_index("time")
    
    prog = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron = stats_n.loc[last_time_stats]["neuron_pop_size"]
    
    ref_prog = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron = ref_n.loc[last_time_ref]["neuron_pop_size"]

    return 1 / max(1, 1000 - abs(prog - ref_prog) - abs(neuron - ref_neuron))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r10"
res = main(prun)

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r10

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))
# Out:
# Step 3 passed !
# (993.3102132615767,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              2.0                 67.0  56.25            69.0
# 56.50              3.0                 72.0  56.50            75.0
# 56.75              4.0                 73.0  56.75            77.0
# 57.00              4.0                 75.0  57.00            79.0
# ...                ...                  ...    ...             ...
# 85.00           1242.0                338.0  85.00          1580.0
# 85.25           1257.0                323.0  85.25          1580.0
# 85.50           1270.0                356.0  85.50          1626.0
# 85.75           1300.0                339.0  85.75          1639.0
# 86.00           1319.0                326.0  86.00          1645.0
#
# [121 rows x 4 columns])
# (991.2757712587426,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              3.0                 71.0  56.25            74.0
# 56.50              3.0                 71.0  56.50            74.0
# 56.75              4.0                 71.0  56.75            75.0
# 57.00              4.0                 74.0  57.00            78.0
# ...                ...                  ...    ...             ...
# 85.00            880.0                266.0  85.00          1146.0
# 85.25            897.0                250.0  85.25          1147.0
# 85.50            907.0                247.0  85.50          1154.0
# 85.75            919.0                235.0  85.75          1154.0
# 86.00            926.0                230.0  86.00          1156.0
#
# [121 rows x 4 columns])
# (992.0512814628241,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              0.0                 74.0  56.25            74.0
# 56.50              1.0                 73.0  56.50            74.0
# 56.75              1.0                 76.0  56.75            77.0
# 57.00              3.0                 76.0  57.00            79.0
# ...                ...                  ...    ...             ...
# 85.00            887.0                248.0  85.00          1135.0
# 85.25            911.0                226.0  85.25          1137.0
# 85.50            919.0                224.0  85.50          1143.0
# 85.75            927.0                222.0  85.75          1149.0
# 86.00            942.0                208.0  86.00          1150.0
#
# [121 rows x 4 columns])
# (989.6367438738216,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              2.0                 68.0  56.25            70.0
# 56.50              3.0                 69.0  56.50            72.0
# 56.75              3.0                 70.0  56.75            73.0
# 57.00              3.0                 70.0  57.00            73.0
# ...                ...                  ...    ...             ...
# 85.00           1359.0                449.0  85.00          1808.0
# 85.25           1414.0                397.0  85.25          1811.0
# 85.50           1432.0                390.0  85.50          1822.0
# 85.75           1452.0                373.0  85.75          1825.0
# 86.00           1476.0                349.0  86.00          1825.0
#
# [121 rows x 4 columns])
# (989.5410773811916,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              1.0                 73.0  56.25            74.0
# 56.50              1.0                 74.0  56.50            75.0
# 56.75              1.0                 75.0  56.75            76.0
# 57.00              2.0                 74.0  57.00            76.0
# ...                ...                  ...    ...             ...
# 81.25           1032.0                426.0  81.25          1458.0
# 81.50           1066.0                454.0  81.50          1520.0
# 81.75           1103.0                452.0  81.75          1555.0
# 82.00           1124.0                433.0  82.00          1557.0
# 82.25           1143.0                532.0  82.25          1675.0
#
# [106 rows x 4 columns])

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.23; noise: 0.85; b: 1.21; m: 1.82; expr: 1.00; deg: 0.10; theta: 2.68; asym: 5.00; tree : (-2 OR -0)
# >> G_1: init: 0.85; noise: 0.36; b: 1.20; m: 1.68; expr: 1.00; deg: 0.10; theta: 7.13; asym: 5.00; tree : 2
# >> G_2: init: 0.52; noise: 0.37; b: 2.16; m: 7.90; expr: 1.00; deg: 0.10; theta: 4.86; asym: 5.00; tree : -0
# >> G_3: init: 0.09; noise: 0.32; b: 1.92; m: 5.60; expr: 1.00; deg: 0.10; theta: 8.91; asym: 5.00; tree : 3
# >> G_4: init: 0.51; noise: 0.08; b: 1.81; m: 4.33; expr: 1.00; deg: 0.10; theta: 9.84; asym: 5.00; tree : ((0 OR -5) AND 3)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 5.36; asym: 5.00; tree : 4
# >> G_1: init: 1.17; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 9.14; asym: 5.00; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 4.30; asym: 4.35; tree : -0
# >> G_3: init: 2.21; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.36; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.81; asym: 5.00; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 5.75; asym: 5.00; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 9.14; asym: 5.00; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.86; asym: 4.35; tree : (-0 AND 2)
# >> G_3: init: 2.21; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.54; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 7.31; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.81; asym: 5.00; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 5.57; asym: 4.24; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 9.52; asym: 4.23; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.64; asym: 4.35; tree : NOT (3 AND 2)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.59; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.81; asym: 5.00; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 6.21; asym: 4.24; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 9.52; asym: 3.46; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.58; asym: 4.35; tree : NOT (0 AND 2)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.59; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.56; asym: 5.00; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 7.51; asym: 4.24; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 9.52; asym: 4.23; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.02; asym: 4.35; tree : NOT (3 AND 2)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.52; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.56; asym: 4.22; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.91; asym: 3.49; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 11.41; asym: 4.23; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.22; asym: 4.35; tree : NOT (3 AND 2)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.50; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.56; asym: 4.22; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.91; asym: 3.49; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 11.18; asym: 4.23; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.22; asym: 4.35; tree : NOT ((3 AND 5) AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.43; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.56; asym: 4.22; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.91; asym: 3.49; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 10.46; asym: 3.52; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.22; asym: 4.35; tree : NOT ((3 AND 5) AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.53; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.76; asym: 4.22; tree : (5 AND (2 AND 3))
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.91; asym: 3.49; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 10.03; asym: 3.52; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.22; asym: 4.35; tree : NOT ((3 AND 5) AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 2.75; deg: 0.10; theta: 1.53; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.76; asym: 4.22; tree : (5 AND (2 AND 3))
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.03; asym: 2.90; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 11.18; asym: 3.01; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.94; asym: 4.35; tree : NOT (5 AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.54; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.51; asym: 4.22; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.03; asym: 2.90; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 11.18; asym: 3.01; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.67; asym: 4.35; tree : NOT (5 AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.64; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.68; asym: 4.22; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.01; asym: 2.35; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 11.18; asym: 3.01; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 6.23; asym: 4.35; tree : NOT (5 AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.62; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.68; asym: 4.22; tree : (-1 AND (2 AND 3))
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 10.19; asym: 2.90; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 11.18; asym: 2.59; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.67; asym: 4.35; tree : NOT (5 AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.64; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.68; asym: 4.22; tree : (-1 AND (2 AND 5))
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.86; asym: 2.90; tree : (4 OR 0)
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 12.18; asym: 2.59; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 5.67; asym: 3.67; tree : NOT (5 AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.56; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.68; asym: 4.22; tree : (-1 AND (2 AND 5))
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.62; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.26; asym: 2.46; tree : (4 OR 1)
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 16.85; asym: 3.01; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 6.33; asym: 3.53; tree : NOT 4
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.45; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 0.56; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.78; asym: 4.22; tree : (-1 AND 5)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.86; asym: 2.90; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 16.91; asym: 2.08; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 6.49; asym: 4.35; tree : NOT NOT (5 AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.70; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.68; asym: 4.22; tree : (-1 AND (2 AND 5))
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.86; asym: 2.53; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 16.91; asym: 2.08; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 6.49; asym: 3.74; tree : NOT NOT (5 AND 4)
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.70; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.68; asym: 4.22; tree : (-1 AND (2 AND 5))
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 9.27; asym: 2.90; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 18.42; asym: 2.08; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 6.49; asym: 3.74; tree : NOT NOT 4
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.28; deg: 0.10; theta: 1.70; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.68; asym: 4.22; tree : (-1 AND (2 AND 5))
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.32; asym: 2.90; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 20.18; asym: 1.70; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 6.49; asym: 3.74; tree : NOT NOT 4
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.00; deg: 0.10; theta: 1.70; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.90; asym: 4.22; tree : (-1 AND (2 AND 0))
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 8.61; asym: 2.53; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 20.45; asym: 2.08; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 7.32; asym: 3.74; tree : NOT NOT 4
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.28; deg: 0.10; theta: 1.70; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.62; asym: 4.22; tree : (-1 AND 4)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 9.90; asym: 2.53; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 20.45; asym: 2.08; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 7.32; asym: 3.74; tree : NOT NOT 4
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.28; deg: 0.10; theta: 1.70; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.86; asym: 3.54; tree : (-1 AND 3)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 9.90; asym: 2.53; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 18.44; asym: 2.08; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 6.44; asym: 3.74; tree : NOT NOT 4
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.28; deg: 0.10; theta: 1.70; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.86; asym: 3.54; tree : (-1 AND 3)
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 10.43; asym: 2.53; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 23.59; asym: 2.08; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 6.30; expr: 1.00; deg: 0.10; theta: 8.24; asym: 3.18; tree : NOT NOT 4
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.28; deg: 0.10; theta: 1.58; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.86; asym: 3.54; tree : (-1 AND 3)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 10.09; asym: 1.68; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 21.91; asym: 1.78; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 7.11; asym: 3.13; tree : (NOT NOT 1 AND (3 OR 5))
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.28; deg: 0.10; theta: 1.56; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.61; asym: 4.22; tree : (-1 AND 0)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 2.18; noise: 0.23; b: 0.92; m: 1.32; expr: 1.00; deg: 0.10; theta: 10.09; asym: 1.68; tree : 4
# >> G_1: init: 0.40; noise: 0.19; b: 0.93; m: 9.13; expr: 1.00; deg: 0.10; theta: 20.08; asym: 1.78; tree : 3
# >> G_2: init: 1.84; noise: 0.08; b: 0.69; m: 2.10; expr: 1.00; deg: 0.10; theta: 7.11; asym: 3.13; tree : (NOT NOT 1 AND (3 OR 5))
# >> G_3: init: 2.52; noise: 0.44; b: 0.18; m: 2.53; expr: 1.28; deg: 0.10; theta: 1.56; asym: 5.00; tree : -1
# >> G_4: init: 0.52; noise: 2.92; b: 1.90; m: 8.78; expr: 1.00; deg: 0.10; theta: 2.61; asym: 4.22; tree : (-1 AND 0)
