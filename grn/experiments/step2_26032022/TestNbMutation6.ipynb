# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
import random
from lib.sde.mutate import mutate_gene4, mutate_tree

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None, nb_genes=4):
    return Solution(GRNMain(nb_genes, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
_MUTATE_FUNC = mutate_grn

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        global _MUTATE_FUNC
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + s_all + s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init),
                                  new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    ObjectiveStep(name="The ONE", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 30
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 25
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, name=None):
    args = get_prun()
    args.cb_init = cb_init
    args.name = name
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    print("Final score", np.mean(scores), "+-", np.std(scores))
    return np.mean(scores), np.std(scores), max(p1)

# %%
def mutate_grn_verysparse(grn, temperature=0.1, expr_deg_coeff=1.0):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    expr_deg_mask = np.array([1, 1, 1, 1, expr_deg_coeff,
                              expr_deg_coeff, 1, 1]).reshape((8, 1))
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.9) * expr_deg_mask
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()

# %%
model = sm.StringModel("expfit_func{mutfunc}_i{i}")
mut_func = dict(
    vsctrl=lambda x: mutate_grn_verysparse(x),
    vs05=lambda x: mutate_grn_verysparse(x, expr_deg_coeff=0.5),
    vs02=lambda x: mutate_grn_verysparse(x, expr_deg_coeff=0.2),
)

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
)

# %%
# main loop
exporter = Exporter(name="exp_mutfunc6_280222")
for (funcname, func), i in product(mut_func.items(), range(10)):
    name = model.fill(mutfunc=funcname, i=i)
    print(name)
    if name in exporter.list():
        continue
    _MUTATE_FUNC = func
    res = get_score_parametrized(callback_init)
    exporter(res, name)
# Out:
# Exporting at output/exp_mutfunc6_280222
# expfit_funcvsctrl_i0
# Step 0
# ++ Best 0.005759635770507761 for generation 0
# ++ Best 0.007217568421303967 for generation 3
# ++ Best 0.008723840500449536 for generation 10
# ++ Best 0.009765862158298872 for generation 11
# ++ Best 0.009935884588540236 for generation 23
# ++ Best 0.010838267460941345 for generation 40
# ++ Best 0.0109100259410291 for generation 59
# ++ Best 0.01969472679603656 for generation 67
# Step 100
# ++ Best 0.02217612606197367 for generation 181
# ++ Best 0.025736626220680164 for generation 197
# Step 200
# ++ Best 0.036356180423450964 for generation 205
# ++ Best 0.04518322910305877 for generation 268
# OVER
# Final score 0.028476931086938932 +- 0.01148030063990862
# expfit_funcvsctrl_i1
# Step 0
# ++ Best 0.003066533846666993 for generation 0
# ++ Best 0.00563657164871351 for generation 1
# ++ Best 0.005701150487313098 for generation 2
# ++ Best 0.006216534768863303 for generation 3
# ++ Best 0.008843430587221715 for generation 7
# ++ Best 0.009085699931181286 for generation 17
# ++ Best 0.009142147958945718 for generation 23
# ++ Best 0.010836068539083707 for generation 26
# Step 100
# ++ Best 0.012055940734245279 for generation 122
# Step 200
# ++ Best 0.012264932875603077 for generation 251
# OVER
# Final score 0.010792120212561856 +- 0.0005391281602351796
# expfit_funcvsctrl_i2
# Step 0
# ++ Best 0.005640497489478068 for generation 0
# ++ Best 0.010858207354594125 for generation 1
# ++ Best 0.012210348566807645 for generation 31
# ++ Best 0.01252357475822056 for generation 75
# Step 100
# ++ Best 0.015774381945072132 for generation 114
# ++ Best 0.03395174850201293 for generation 166
# Step 200
# OVER
# Final score 0.01956303886855523 +- 0.01591531185007958
# expfit_funcvsctrl_i3
# Step 0
# ++ Best 0.005638069243862199 for generation 0
# ++ Best 0.005717203196994829 for generation 1
# ++ Best 0.005799245009830078 for generation 4
# ++ Best 0.014580987881051584 for generation 5
# ++ Best 0.014848107226871349 for generation 65
# ++ Best 0.016732179767949877 for generation 76
# Step 100
# Step 200
# ++ Best 0.04322682849326607 for generation 219
# ++ Best 0.04517148950342877 for generation 265
# ++ Best 0.047274756660319564 for generation 281
# OVER
# Final score 0.035744399603378135 +- 0.005879709405217969
# expfit_funcvsctrl_i4
# Step 0
# ++ Best 0.0035626280616566286 for generation 0
# ++ Best 0.005639377945332419 for generation 1
# ++ Best 0.006047293503274026 for generation 2
# ++ Best 0.008737304607981063 for generation 4
# ++ Best 0.010462636645335237 for generation 16
# ++ Best 0.011164878032698363 for generation 24
# Step 100
# ++ Best 0.012600984838326121 for generation 116
# Step 200
# ++ Best 0.012978637836101018 for generation 229
# OVER
# Final score 0.01170535538568867 +- 0.0004721333982029311
# expfit_funcvsctrl_i5
# Step 0
# ++ Best 0.005624377975614203 for generation 0
# ++ Best 0.01058575289311527 for generation 1
# ++ Best 0.011693265504040554 for generation 15
# ++ Best 0.012093258139846264 for generation 54
# Step 100
# Step 200
# OVER
# Final score 0.011833386275076766 +- 0.0008155395977610057
# expfit_funcvsctrl_i6
# Step 0
# ++ Best 0.00571377541505093 for generation 0
# ++ Best 0.019983175836403893 for generation 1
# Step 100
# Step 200
# OVER
# Final score 0.009820023982804313 +- 0.004024984801942379
# expfit_funcvsctrl_i7
# Step 0
# ++ Best 0.006219304195509894 for generation 0
# ++ Best 0.00810421909513008 for generation 1
# ++ Best 0.009413780874406774 for generation 11
# ++ Best 0.010676646762857041 for generation 21
# Step 100
# ++ Best 0.02000237588255657 for generation 122
# Step 200
# OVER
# Final score 0.009597257671495028 +- 0.004739752506315991
# expfit_funcvsctrl_i8
# Step 0
# ++ Best 0.00571527594849947 for generation 0
# ++ Best 0.005901207047331341 for generation 1
# ++ Best 0.009230912533885775 for generation 2
# ++ Best 0.009248436715527 for generation 17
# ++ Best 0.010918988035986217 for generation 18
# ++ Best 0.01832831073534991 for generation 29
# ++ Best 0.018543088020687902 for generation 68
# ++ Best 0.0270772672592294 for generation 95
# Step 100
# ++ Best 0.04927738729558159 for generation 180
# Step 200
# OVER
# Final score 0.015333497584939857 +- 0.012869927570223302
# expfit_funcvsctrl_i9
# Step 0
# ++ Best 0.008369626784387865 for generation 0
# ++ Best 0.008382351550475434 for generation 6
# ++ Best 0.00872293896076496 for generation 11
# ++ Best 0.01052658891883537 for generation 13
# ++ Best 0.010576091911398421 for generation 47
# ++ Best 0.012585248115895883 for generation 73
# Step 100
# ++ Best 0.014630899941030404 for generation 115
# Step 200
# ++ Best 0.025580198371310342 for generation 262
# OVER
# Final score 0.006367198078188892 +- 0.0004253158052987167
# expfit_funcvs05_i0
# Step 0
# ++ Best 0.009044418595197912 for generation 0
# ++ Best 0.010261137021494145 for generation 29
# ++ Best 0.010327742406444856 for generation 56
# ++ Best 0.011158460534450363 for generation 58
# ++ Best 0.01306079626724211 for generation 60
# ++ Best 0.013764133039745463 for generation 64
# Step 100
# ++ Best 0.019977417097304346 for generation 102
# Step 200
# OVER
# Final score 0.00850942375261857 +- 0.0048894550752934685
# expfit_funcvs05_i1
# Step 0
# ++ Best 0.005621770184851567 for generation 0
# ++ Best 0.009153324895992973 for generation 1
# ++ Best 0.0104059647150641 for generation 13
# ++ Best 0.012749954758214294 for generation 78
# Step 100
# Step 200
# ++ Best 0.014568479123813677 for generation 294
# OVER
# Final score 0.031456816117572145 +- 0.01941476025385234
# expfit_funcvs05_i2
# Step 0
# ++ Best 0.003751233971329617 for generation 0
# ++ Best 0.005884585169535637 for generation 1
# ++ Best 0.006073699527606516 for generation 2
# ++ Best 0.009886564458234886 for generation 7
# ++ Best 0.010165129462171418 for generation 25
# ++ Best 0.010615747550330122 for generation 77
# ++ Best 0.03699140333409523 for generation 89
# Step 100
# Step 200
# OVER
# Final score 0.01477123583561834 +- 0.004907595057397123
# expfit_funcvs05_i3
# Step 0
# ++ Best 0.005853753388496079 for generation 0
# ++ Best 0.005896927058412348 for generation 8
# ++ Best 0.006174259296960518 for generation 9
# ++ Best 0.008511166908716703 for generation 10
# ++ Best 0.010132739024470953 for generation 11
# ++ Best 0.010310382928416007 for generation 26
# ++ Best 0.010555931188960262 for generation 35
# ++ Best 0.010716378409063022 for generation 91
# Step 100
# ++ Best 0.011818226015129383 for generation 124
# Step 200
# OVER
# Final score 0.011433391672542403 +- 0.0009021521102865794
# expfit_funcvs05_i4
# Step 0
# ++ Best 0.00576112134570884 for generation 0
# ++ Best 0.008500034682970803 for generation 1
# ++ Best 0.010093710038141671 for generation 10
# ++ Best 0.010346134010421877 for generation 21
# ++ Best 0.010665974223378685 for generation 30
# ++ Best 0.011209143505498644 for generation 84
# Step 100
# ++ Best 0.012353969090878306 for generation 152
# Step 200
# ++ Best 0.017489755264102676 for generation 202
# OVER
# Final score 0.014539391982440785 +- 0.003116318290618053
# expfit_funcvs05_i5
# Step 0
# ++ Best 0.0033849762611647778 for generation 0
# ++ Best 0.005638492992581882 for generation 1
# ++ Best 0.005870730369595929 for generation 2
# ++ Best 0.008737334295051627 for generation 3
# ++ Best 0.009945734690271657 for generation 12
# ++ Best 0.01380279303524041 for generation 27
# ++ Best 0.01594297191782001 for generation 35
# Step 100
# Step 200
# ++ Best 0.02036686909543987 for generation 263
# ++ Best 0.03101053427776089 for generation 278
# OVER
# Final score 0.017789684618131456 +- 0.01201450424111731
# expfit_funcvs05_i6
# Step 0
# ++ Best 0.005788211163639072 for generation 0
# ++ Best 0.00628207310357211 for generation 2
# ++ Best 0.00904489130983265 for generation 4
# ++ Best 0.009605856377591452 for generation 8
# ++ Best 0.013036350273519536 for generation 9
# Step 100
# ++ Best 0.015563908461323314 for generation 101
# Step 200
# OVER
# Final score 0.007168437822765413 +- 0.001606012345050872
# expfit_funcvs05_i7
# Step 0
# ++ Best 0.004555117711374182 for generation 0
# ++ Best 0.006803910588754945 for generation 1
# ++ Best 0.00830184909817666 for generation 6
# ++ Best 0.00832082242709986 for generation 10
# ++ Best 0.008649642679803808 for generation 20
# ++ Best 0.009463763836426395 for generation 24
# ++ Best 0.011071945819843691 for generation 30
# ++ Best 0.01124025514460159 for generation 69
# Step 100
# Step 200
# ++ Best 0.011722888233221979 for generation 200
# ++ Best 0.017752508912355736 for generation 216
# OVER
# Final score 0.005763068604190277 +- 0.0013844351822350886
# expfit_funcvs05_i8
# Step 0
# ++ Best 0.010269219152610821 for generation 0
# ++ Best 0.026966491550875528 for generation 75
# Step 100
# Step 200
# OVER
# Final score 0.0056333087258832884 +- 4.300919598480969e-06
# expfit_funcvs05_i9
# Step 0
# ++ Best 0.005640044687052625 for generation 0
# ++ Best 0.00571235655772317 for generation 1
# ++ Best 0.00587175630734183 for generation 2
# ++ Best 0.005944620150286822 for generation 3
# ++ Best 0.007407657721085141 for generation 7
# ++ Best 0.008452567426370532 for generation 9
# ++ Best 0.01074216018303306 for generation 46
# Step 100
# ++ Best 0.028098867775382973 for generation 109
# ++ Best 0.03780324405681469 for generation 132
# ++ Best 0.03801470658044721 for generation 146
# ++ Best 0.03909239249007155 for generation 155
# ++ Best 0.041451903306847275 for generation 169
# ++ Best 0.05737011777151065 for generation 177
# Step 200
# ++ Best 0.06008915191750114 for generation 296
# OVER
# Final score 0.04548755647269756 +- 0.009868770667791349
# expfit_funcvs02_i0
# Step 0
# ++ Best 0.006772051711723814 for generation 0
# ++ Best 0.008716900648654182 for generation 2
# ++ Best 0.008833760902483945 for generation 9
# ++ Best 0.009423160420486583 for generation 23
# ++ Best 0.011617960523277585 for generation 31
# ++ Best 0.0119013867292027 for generation 34
# Step 100
# ++ Best 0.012212713247577167 for generation 152
# Step 200
# ++ Best 0.012885979801717951 for generation 201
# ++ Best 0.02930760288483484 for generation 266
# OVER
# Final score 0.013073736884041723 +- 0.00472328321426563
# expfit_funcvs02_i1
# Step 0
# ++ Best 0.005639529800625755 for generation 0
# ++ Best 0.005873736501585934 for generation 2
# ++ Best 0.012250812969500213 for generation 4
# Step 100
# ++ Best 0.02135626752408014 for generation 143
# Step 200
# OVER
# Final score 0.021708405819583033 +- 0.0035672161554160054
# expfit_funcvs02_i2
# Step 0
# ++ Best 0.006904961576966273 for generation 0
# ++ Best 0.010056322386718749 for generation 1
# ++ Best 0.011450847480426327 for generation 40
# ++ Best 0.02991734521585348 for generation 43
# ++ Best 0.04104766260004405 for generation 91
# Step 100
# Step 200
# OVER
# Final score 0.007208043868425945 +- 0.005128493455022831
# expfit_funcvs02_i3
# Step 0
# ++ Best 0.0058706086639127774 for generation 0
# ++ Best 0.006279333208133295 for generation 1
# ++ Best 0.009192321719732673 for generation 8
# ++ Best 0.009339715189786917 for generation 12
# ++ Best 0.009889266909654783 for generation 14
# ++ Best 0.010261710890785035 for generation 47
# ++ Best 0.012030567592344384 for generation 66
# Step 100
# ++ Best 0.03425146663265246 for generation 146
# Step 200
# OVER
# Final score 0.021111830156705508 +- 0.013898165260799207
# expfit_funcvs02_i4
# Step 0
# ++ Best 0.005634747959912927 for generation 0
# ++ Best 0.005795174539300898 for generation 1
# ++ Best 0.008125415389865713 for generation 2
# ++ Best 0.011153011181116113 for generation 5
# Step 100
# ++ Best 0.011745845384166509 for generation 183
# Step 200
# ++ Best 0.014200494996833922 for generation 239
# OVER
# Final score 0.010656449869842785 +- 0.0066614596977086086
# expfit_funcvs02_i5
# Step 0
# ++ Best 0.006073457198381523 for generation 0
# ++ Best 0.009507419238959746 for generation 1
# ++ Best 0.01308461880000962 for generation 5
# Step 100
# ++ Best 0.01312866322835941 for generation 157
# Step 200
# OVER
# Final score 0.011606214246902908 +- 0.004904827168281969
# expfit_funcvs02_i6
# Step 0
# ++ Best 0.005639408639256785 for generation 0
# ++ Best 0.008947422792982444 for generation 1
# ++ Best 0.009914193553155204 for generation 2
# ++ Best 0.01041991286628657 for generation 15
# ++ Best 0.010614303754527273 for generation 34
# Step 100
# Step 200
# ++ Best 0.01168984976354576 for generation 252
# ++ Best 0.016681540839872645 for generation 255
# OVER
# Final score 0.016610308082547844 +- 0.0014047887098049157
# expfit_funcvs02_i7
# Step 0
# ++ Best 0.005716474575489543 for generation 0
# ++ Best 0.005798605704053982 for generation 2
# ++ Best 0.007023515899981657 for generation 8
# ++ Best 0.013182839129324634 for generation 16
# ++ Best 0.01703373166216553 for generation 17
# Step 100
# Step 200
# OVER
# Final score 0.012371127727970848 +- 0.01109533474485357
# expfit_funcvs02_i8
# Step 0
# ++ Best 0.0041943882231451225 for generation 0
# ++ Best 0.004629578367210319 for generation 1
# ++ Best 0.005624377975614203 for generation 2
# ++ Best 0.005634747959912927 for generation 4
# ++ Best 0.005707710822835933 for generation 5
# ++ Best 0.006625908120870299 for generation 7
# ++ Best 0.01037547286896754 for generation 9
# ++ Best 0.022428822125522913 for generation 17
# Step 100
# Step 200
# OVER
# Final score 0.025622777617575386 +- 0.011800676616411179
# expfit_funcvs02_i9
# Step 0
# ++ Best 0.005639027076397544 for generation 0
# ++ Best 0.008575482292483222 for generation 1
# ++ Best 0.009263278812608215 for generation 3
# ++ Best 0.010343063830364176 for generation 5
# ++ Best 0.010704157888077033 for generation 29
# ++ Best 0.013295192876917175 for generation 69
# Step 100
# Step 200
# OVER
# Final score 0.012159144896490986 +- 0.0009003397129916499

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#   mutfunc  i      mean        sd       max
# 0  vsctrl  4  0.011705  0.000472  0.012979
# 1    vs05  9  0.045488  0.009869  0.060089
# 2  vsctrl  6  0.009820  0.004025  0.019983
# 3  vsctrl  1  0.010792  0.000539  0.012265
# 4    vs05  4  0.014539  0.003116  0.017490

# %%
new_df = df.groupby(["mutfunc"]).mean()
new_df
# Out:
#              mean        sd       max
# mutfunc
# vs02     0.015213  0.006408  0.022273
# vs05     0.016255  0.005811  0.025223
# vsctrl   0.015923  0.005716  0.027859

# %%
for i, row in new_df.iterrows():
    print(row.name, row["mean"], row["mean"] - row.sd / np.sqrt(10), row["mean"] + row.sd / np.sqrt(10))
# Out:
# vs02 0.015212803917008697 0.013186271410304548 0.017239336423712847
# vs05 0.016255231560446025 0.01441768563982163 0.01809277748107042
# vsctrl 0.01592332087496277 0.014115696438462718 0.017730945311462822

# %%
row.name
# Out:
# 'vsctrl'

# %%
print(1)
# Out:
# 1
