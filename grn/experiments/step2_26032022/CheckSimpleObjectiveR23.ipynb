# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 70.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 100 - 1 * delta_late - 0.5 * delta_early)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r23"
res = main(prun)

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r23

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
res.fit
# Out:
# 95.6519166002077

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))
# Out:
# Step 3 passed !
# (93.52032497002175,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             2.0              9.0                 51.0             7.0
# 56.50             5.0             12.0                 48.0             7.0
# 56.75             6.0             13.0                 51.0             7.0
# 57.00             6.0             13.0                 53.0             7.0
# ...               ...              ...                  ...             ...
# 85.00           299.0           1055.0                151.0           756.0
# 85.25           300.0           1070.0                158.0           770.0
# 85.50           300.0           1086.0                158.0           786.0
# 85.75           302.0           1103.0                157.0           801.0
# 86.00           304.0           1121.0                143.0           817.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            60.0
# 56.50  56.50            60.0
# 56.75  56.75            64.0
# 57.00  57.00            66.0
# ...      ...             ...
# 85.00  85.00          1206.0
# 85.25  85.25          1228.0
# 85.50  85.50          1244.0
# 85.75  85.75          1260.0
# 86.00  86.00          1264.0
#
# [121 rows x 6 columns])
# (84.00709150683045,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             1.0              4.0                 59.0             3.0
# 56.50             1.0              5.0                 58.0             4.0
# 56.75             1.0              5.0                 65.0             4.0
# 57.00             4.0              8.0                 65.0             4.0
# ...               ...              ...                  ...             ...
# 85.00           499.0           1597.0                207.0          1098.0
# 85.25           501.0           1610.0                224.0          1109.0
# 85.50           502.0           1630.0                247.0          1128.0
# 85.75           506.0           1665.0                226.0          1159.0
# 86.00           507.0           1680.0                234.0          1173.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            63.0
# 56.50  56.50            63.0
# 56.75  56.75            70.0
# 57.00  57.00            73.0
# ...      ...             ...
# 85.00  85.00          1804.0
# 85.25  85.25          1834.0
# 85.50  85.50          1877.0
# 85.75  85.75          1891.0
# 86.00  86.00          1914.0
#
# [121 rows x 6 columns])
# (94.07028394714646,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             1.0              9.0                 43.0             8.0
# 56.50             1.0              9.0                 45.0             8.0
# 56.75             1.0              9.0                 50.0             8.0
# 57.00             1.0              9.0                 56.0             8.0
# ...               ...              ...                  ...             ...
# 85.00           368.0           1198.0                174.0           830.0
# 85.25           373.0           1212.0                179.0           839.0
# 85.50           376.0           1232.0                172.0           856.0
# 85.75           376.0           1240.0                171.0           864.0
# 86.00           378.0           1256.0                164.0           878.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            52.0
# 56.50  56.50            54.0
# 56.75  56.75            59.0
# 57.00  57.00            65.0
# ...      ...             ...
# 85.00  85.00          1372.0
# 85.25  85.25          1391.0
# 85.50  85.50          1404.0
# 85.75  85.75          1411.0
# 86.00  86.00          1420.0
#
# [121 rows x 6 columns])
# (84.62821800072292,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             4.0             11.0                 49.0             7.0
# 56.50             4.0             11.0                 51.0             7.0
# 56.75             5.0             12.0                 51.0             7.0
# 57.00             5.0             13.0                 50.0             8.0
# ...               ...              ...                  ...             ...
# 85.00           245.0            638.0                 78.0           393.0
# 85.25           247.0            647.0                 75.0           400.0
# 85.50           248.0            651.0                 78.0           403.0
# 85.75           250.0            659.0                 79.0           409.0
# 86.00           252.0            669.0                 75.0           417.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            60.0
# 56.50  56.50            62.0
# 56.75  56.75            63.0
# 57.00  57.00            63.0
# ...      ...             ...
# 85.00  85.00           716.0
# 85.25  85.25           722.0
# 85.50  85.50           729.0
# 85.75  85.75           738.0
# 86.00  86.00           744.0
#
# [121 rows x 6 columns])
# (92.95910048022583,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             4.0              8.0                 50.0             4.0
# 56.50             4.0              8.0                 52.0             4.0
# 56.75             4.0              8.0                 52.0             4.0
# 57.00             4.0              8.0                 58.0             4.0
# ...               ...              ...                  ...             ...
# 85.00           311.0           1035.0                136.0           724.0
# 85.25           312.0           1046.0                138.0           734.0
# 85.50           316.0           1062.0                135.0           746.0
# 85.75           316.0           1072.0                139.0           756.0
# 86.00           320.0           1089.0                136.0           769.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            58.0
# 56.50  56.50            60.0
# 56.75  56.75            60.0
# 57.00  57.00            66.0
# ...      ...             ...
# 85.00  85.00          1171.0
# 85.25  85.25          1184.0
# 85.50  85.50          1197.0
# 85.75  85.75          1211.0
# 86.00  86.00          1225.0
#
# [121 rows x 6 columns])

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.35; m: 8.32; expr: 1.00; deg: 0.10; theta: 8.68; asym: 5.00; tree : -2
# >> G_1: init: 0.21; noise: 1.00; b: 3.94; m: 2.83; expr: 1.00; deg: 0.09; theta: 2.98; asym: 5.00; tree : -0
# >> G_2: init: 0.67; noise: 1.00; b: 1.74; m: 7.43; expr: 1.00; deg: 0.10; theta: 3.51; asym: 5.00; tree : -3
# >> G_3: init: 0.51; noise: 1.00; b: 1.62; m: 2.49; expr: 1.00; deg: 0.10; theta: 2.93; asym: 5.00; tree : (-0 AND (2 AND 5))
# >> G_4: init: 0.09; noise: 1.00; b: 0.72; m: 7.50; expr: 1.00; deg: 0.10; theta: 1.81; asym: 5.00; tree : (0 AND -4)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.00; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : ((2 OR -4) OR 0)
# >> G_1: init: 0.45; noise: 1.00; b: 2.57; m: 5.29; expr: 1.00; deg: 0.10; theta: 9.80; asym: 5.00; tree : -2
# >> G_2: init: 0.91; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.10; theta: 1.82; asym: 5.00; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.40; noise: 1.00; b: 2.35; m: 5.41; expr: 1.10; deg: 0.10; theta: 0.08; asym: 5.00; tree : 4
# >> G_4: init: 2.20; noise: 1.00; b: 3.24; m: 3.18; expr: 0.86; deg: 0.10; theta: 7.21; asym: 5.32; tree : 0
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.19; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : ((2 OR -4) OR 0)
# >> G_1: init: 0.45; noise: 1.00; b: 2.57; m: 5.29; expr: 0.83; deg: 0.10; theta: 9.80; asym: 5.00; tree : (-2 OR -1)
# >> G_2: init: 0.91; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.10; theta: 1.82; asym: 4.05; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.40; noise: 1.00; b: 2.35; m: 5.41; expr: 1.10; deg: 0.10; theta: 0.08; asym: 5.00; tree : ((4 OR -1) OR -0)
# >> G_4: init: 2.20; noise: 1.00; b: 3.24; m: 3.18; expr: 0.86; deg: 0.10; theta: 7.21; asym: 5.32; tree : (0 OR 2)
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.00; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : ((3 OR -4) OR 0)
# >> G_1: init: 0.45; noise: 1.00; b: 2.57; m: 5.29; expr: 0.83; deg: 0.10; theta: 9.80; asym: 5.00; tree : (-2 OR -1)
# >> G_2: init: 0.91; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.10; theta: 1.82; asym: 5.00; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.40; noise: 1.00; b: 2.35; m: 5.41; expr: 0.88; deg: 0.10; theta: 0.08; asym: 5.29; tree : (4 OR -0)
# >> G_4: init: 2.20; noise: 1.00; b: 3.24; m: 3.18; expr: 0.86; deg: 0.10; theta: 7.21; asym: 5.32; tree : (0 OR 3)
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.13; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : ((2 OR -4) OR 0)
# >> G_1: init: 0.45; noise: 1.00; b: 2.30; m: 5.19; expr: 0.83; deg: 0.11; theta: 10.29; asym: 5.00; tree : (-2 OR -1)
# >> G_2: init: 0.91; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.10; theta: 1.82; asym: 5.00; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.40; noise: 1.00; b: 2.57; m: 5.41; expr: 1.10; deg: 0.10; theta: 0.08; asym: 5.00; tree : (-2 OR -0)
# >> G_4: init: 2.20; noise: 1.00; b: 3.24; m: 3.18; expr: 0.86; deg: 0.10; theta: 7.21; asym: 5.32; tree : (0 OR 2)
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.19; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : ((2 OR -4) OR 0)
# >> G_1: init: 0.45; noise: 0.86; b: 2.57; m: 5.29; expr: 0.83; deg: 0.10; theta: 9.80; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.08; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.00; b: 2.35; m: 5.41; expr: 1.10; deg: 0.10; theta: 0.08; asym: 5.00; tree : (4 OR -0)
# >> G_4: init: 2.09; noise: 1.00; b: 3.24; m: 3.18; expr: 0.86; deg: 0.10; theta: 7.21; asym: 6.91; tree : 0
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.19; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : ((2 OR -4) OR 0)
# >> G_1: init: 0.45; noise: 0.86; b: 2.57; m: 5.29; expr: 0.83; deg: 0.10; theta: 9.80; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.08; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.00; b: 2.37; m: 5.41; expr: 1.10; deg: 0.10; theta: 0.08; asym: 5.00; tree : ((4 OR -0) OR -5)
# >> G_4: init: 2.09; noise: 1.00; b: 3.24; m: 3.18; expr: 0.86; deg: 0.10; theta: 7.21; asym: 8.14; tree : 1
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.19; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : ((2 OR 1) OR 0)
# >> G_1: init: 0.45; noise: 0.86; b: 2.57; m: 5.29; expr: 0.83; deg: 0.10; theta: 9.80; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.08; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.00; b: 2.37; m: 5.41; expr: 1.10; deg: 0.10; theta: 0.08; asym: 5.00; tree : ((4 OR -0) OR -5)
# >> G_4: init: 2.09; noise: 1.00; b: 3.24; m: 4.05; expr: 0.86; deg: 0.10; theta: 7.21; asym: 9.48; tree : 1
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.19; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : ((2 OR 1) OR 0)
# >> G_1: init: 0.45; noise: 1.03; b: 2.57; m: 5.29; expr: 0.83; deg: 0.10; theta: 10.93; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.08; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.00; b: 2.37; m: 4.93; expr: 1.10; deg: 0.10; theta: 0.06; asym: 5.00; tree : ((4 OR -3) OR -5)
# >> G_4: init: 2.09; noise: 0.83; b: 3.24; m: 4.05; expr: 0.86; deg: 0.09; theta: 7.21; asym: 9.48; tree : (1 OR 5)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.21; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.08; theta: 8.85; asym: 5.00; tree : ((2 OR 1) OR 0)
# >> G_1: init: 0.45; noise: 0.86; b: 2.57; m: 5.29; expr: 0.83; deg: 0.10; theta: 10.93; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.02; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.09; theta: 1.95; asym: 5.09; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.00; b: 2.37; m: 4.25; expr: 1.10; deg: 0.12; theta: 0.08; asym: 5.00; tree : ((4 OR -0) OR -5)
# >> G_4: init: 2.09; noise: 1.00; b: 3.24; m: 4.05; expr: 0.87; deg: 0.09; theta: 7.21; asym: 9.48; tree : 1
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.19; noise: 1.00; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : ((2 OR 3) OR 0)
# >> G_1: init: 0.45; noise: 0.86; b: 2.04; m: 5.31; expr: 0.83; deg: 0.11; theta: 9.80; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.08; noise: 1.00; b: 0.97; m: 1.20; expr: 1.03; deg: 0.09; theta: 1.89; asym: 5.00; tree : ((-4 AND 0) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.00; b: 2.37; m: 5.41; expr: 0.89; deg: 0.10; theta: 0.08; asym: 5.00; tree : ((4 OR -0) OR -5)
# >> G_4: init: 2.09; noise: 1.00; b: 3.24; m: 4.05; expr: 0.86; deg: 0.09; theta: 7.21; asym: 9.48; tree : 1
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.19; noise: 1.05; b: 2.77; m: 4.71; expr: 1.00; deg: 0.10; theta: 7.36; asym: 5.99; tree : ((2 OR 1) OR 5)
# >> G_1: init: 0.45; noise: 1.03; b: 2.57; m: 5.29; expr: 0.83; deg: 0.10; theta: 10.93; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.08; noise: 1.00; b: 0.97; m: 1.42; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.00; b: 2.37; m: 4.93; expr: 1.10; deg: 0.10; theta: 0.08; asym: 5.00; tree : ((4 OR -3) OR -5)
# >> G_4: init: 2.09; noise: 0.83; b: 3.17; m: 4.05; expr: 0.86; deg: 0.07; theta: 7.21; asym: 9.48; tree : (1 OR 5)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.19; noise: 1.05; b: 2.77; m: 4.71; expr: 1.00; deg: 0.10; theta: 7.36; asym: 5.99; tree : (2 OR 1)
# >> G_1: init: 0.45; noise: 1.03; b: 2.57; m: 5.29; expr: 0.83; deg: 0.10; theta: 10.93; asym: 5.00; tree : 5
# >> G_2: init: 1.09; noise: 1.00; b: 0.97; m: 1.42; expr: 1.03; deg: 0.07; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.00; b: 2.37; m: 4.93; expr: 1.10; deg: 0.10; theta: 0.08; asym: 5.00; tree : ((4 OR -3) OR 1)
# >> G_4: init: 2.09; noise: 0.83; b: 3.17; m: 4.05; expr: 0.86; deg: 0.07; theta: 7.21; asym: 9.48; tree : (1 OR 5)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.31; noise: 1.05; b: 2.90; m: 4.71; expr: 1.00; deg: 0.10; theta: 6.08; asym: 5.00; tree : (1 OR (5 AND -3))
# >> G_1: init: 0.43; noise: 1.09; b: 2.82; m: 5.29; expr: 0.84; deg: 0.10; theta: 10.93; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.08; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.00; b: 2.37; m: 4.93; expr: 1.10; deg: 0.10; theta: 0.08; asym: 4.85; tree : (4 OR (-3 AND -1))
# >> G_4: init: 2.09; noise: 0.83; b: 3.17; m: 4.05; expr: 0.86; deg: 0.07; theta: 7.21; asym: 9.48; tree : ((1 OR -3) OR -2)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.19; noise: 1.05; b: 2.90; m: 5.48; expr: 1.00; deg: 0.10; theta: 7.36; asym: 5.00; tree : (1 OR 5)
# >> G_1: init: 0.45; noise: 1.09; b: 2.82; m: 5.29; expr: 0.84; deg: 0.10; theta: 12.37; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.08; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.08; b: 2.37; m: 4.93; expr: 1.10; deg: 0.10; theta: 0.08; asym: 4.85; tree : (4 OR (-3 AND -1))
# >> G_4: init: 2.21; noise: 0.83; b: 3.17; m: 4.05; expr: 0.86; deg: 0.07; theta: 7.21; asym: 11.37; tree : ((1 OR -3) OR -2)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.19; noise: 1.05; b: 2.90; m: 5.48; expr: 1.00; deg: 0.10; theta: 7.36; asym: 5.00; tree : (1 OR 5)
# >> G_1: init: 0.39; noise: 1.09; b: 2.82; m: 6.24; expr: 0.84; deg: 0.10; theta: 12.37; asym: 5.00; tree : (5 OR -1)
# >> G_2: init: 1.08; noise: 1.00; b: 0.97; m: 1.39; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 1.08; b: 2.37; m: 4.93; expr: 1.10; deg: 0.10; theta: 0.08; asym: 4.85; tree : (4 OR (-3 AND -1))
# >> G_4: init: 2.63; noise: 0.83; b: 3.17; m: 4.05; expr: 0.86; deg: 0.07; theta: 7.21; asym: 11.37; tree : ((1 OR -3) OR 5)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.19; noise: 1.05; b: 2.77; m: 3.81; expr: 1.00; deg: 0.11; theta: 7.36; asym: 5.71; tree : (2 OR (1 OR 0))
# >> G_1: init: 0.45; noise: 1.10; b: 2.71; m: 5.29; expr: 0.83; deg: 0.11; theta: 12.58; asym: 5.00; tree : 5
# >> G_2: init: 1.09; noise: 1.16; b: 0.86; m: 1.42; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 0.82; b: 2.62; m: 4.93; expr: 1.10; deg: 0.10; theta: 0.09; asym: 4.84; tree : ((4 OR -3) OR 1)
# >> G_4: init: 2.09; noise: 0.69; b: 3.17; m: 4.26; expr: 0.86; deg: 0.07; theta: 7.21; asym: 9.48; tree : (1 OR 5)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 0.96; noise: 1.05; b: 2.77; m: 3.81; expr: 1.00; deg: 0.11; theta: 7.36; asym: 5.71; tree : (2 OR (1 OR 0))
# >> G_1: init: 0.45; noise: 1.10; b: 2.71; m: 5.29; expr: 0.83; deg: 0.11; theta: 12.58; asym: 5.00; tree : 5
# >> G_2: init: 1.09; noise: 1.16; b: 0.86; m: 1.42; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.48; noise: 0.82; b: 2.62; m: 4.93; expr: 1.10; deg: 0.10; theta: 0.09; asym: 5.38; tree : ((4 OR -3) OR 1)
# >> G_4: init: 2.09; noise: 0.69; b: 3.17; m: 4.26; expr: 0.86; deg: 0.07; theta: 7.21; asym: 9.48; tree : (1 OR 5)
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.41; noise: 1.05; b: 2.77; m: 4.43; expr: 1.00; deg: 0.10; theta: 7.36; asym: 5.71; tree : (2 OR (1 OR 0))
# >> G_1: init: 0.45; noise: 1.10; b: 2.71; m: 5.29; expr: 0.83; deg: 0.10; theta: 12.58; asym: 5.19; tree : (5 OR 3)
# >> G_2: init: 1.09; noise: 1.00; b: 0.86; m: 1.42; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.29; noise: 1.00; b: 2.99; m: 4.93; expr: 1.10; deg: 0.12; theta: 0.09; asym: 5.00; tree : 4
# >> G_4: init: 2.09; noise: 0.83; b: 3.34; m: 3.50; expr: 0.86; deg: 0.07; theta: 7.21; asym: 9.48; tree : 1
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.22; noise: 1.05; b: 2.96; m: 3.81; expr: 1.02; deg: 0.10; theta: 7.36; asym: 5.71; tree : (2 OR (1 OR -5))
# >> G_1: init: 0.45; noise: 1.10; b: 2.71; m: 5.29; expr: 0.83; deg: 0.10; theta: 12.58; asym: 5.19; tree : (5 OR 3)
# >> G_2: init: 0.99; noise: 1.00; b: 0.87; m: 1.42; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.29; noise: 1.00; b: 2.62; m: 4.93; expr: 1.10; deg: 0.13; theta: 0.09; asym: 5.00; tree : 5
# >> G_4: init: 2.09; noise: 0.83; b: 3.17; m: 3.29; expr: 0.86; deg: 0.07; theta: 7.21; asym: 9.48; tree : 1
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.06; noise: 1.05; b: 2.96; m: 3.81; expr: 1.02; deg: 0.10; theta: 7.36; asym: 5.71; tree : (2 OR (1 OR 0))
# >> G_1: init: 0.45; noise: 1.10; b: 2.71; m: 5.29; expr: 0.83; deg: 0.10; theta: 12.58; asym: 5.19; tree : (5 OR 3)
# >> G_2: init: 0.99; noise: 1.04; b: 0.87; m: 1.42; expr: 1.03; deg: 0.09; theta: 1.94; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.29; noise: 1.00; b: 2.73; m: 4.93; expr: 1.10; deg: 0.13; theta: 0.09; asym: 5.00; tree : 4
# >> G_4: init: 2.09; noise: 0.83; b: 3.17; m: 3.29; expr: 0.86; deg: 0.07; theta: 7.21; asym: 9.48; tree : 1
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.22; noise: 0.95; b: 2.96; m: 3.81; expr: 1.02; deg: 0.10; theta: 7.36; asym: 5.71; tree : (2 OR (1 OR 0))
# >> G_1: init: 0.45; noise: 1.10; b: 2.71; m: 5.29; expr: 0.83; deg: 0.10; theta: 12.58; asym: 5.19; tree : (5 OR 3)
# >> G_2: init: 0.99; noise: 1.19; b: 0.87; m: 1.21; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : ((-4 AND 1) AND (-5 AND 2))
# >> G_3: init: 1.29; noise: 1.00; b: 2.62; m: 4.93; expr: 1.19; deg: 0.13; theta: 0.09; asym: 5.00; tree : 5
# >> G_4: init: 2.09; noise: 0.83; b: 3.17; m: 3.29; expr: 0.98; deg: 0.07; theta: 7.21; asym: 10.41; tree : 1
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.22; noise: 1.05; b: 2.96; m: 3.81; expr: 1.02; deg: 0.10; theta: 6.54; asym: 5.71; tree : (3 OR 1)
# >> G_1: init: 0.45; noise: 1.12; b: 2.71; m: 5.29; expr: 0.83; deg: 0.10; theta: 12.77; asym: 5.19; tree : (5 OR 3)
# >> G_2: init: 0.99; noise: 1.00; b: 0.87; m: 1.21; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : (-4 AND (-5 AND 2))
# >> G_3: init: 1.29; noise: 1.00; b: 2.62; m: 4.41; expr: 1.12; deg: 0.13; theta: 0.09; asym: 5.00; tree : 5
# >> G_4: init: 2.02; noise: 0.83; b: 3.17; m: 3.29; expr: 0.98; deg: 0.07; theta: 7.21; asym: 9.48; tree : 1
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.22; noise: 1.05; b: 3.04; m: 3.81; expr: 1.03; deg: 0.10; theta: 6.54; asym: 5.71; tree : (3 OR 1)
# >> G_1: init: 0.45; noise: 1.12; b: 2.71; m: 5.29; expr: 0.83; deg: 0.10; theta: 12.77; asym: 5.19; tree : (5 OR 3)
# >> G_2: init: 0.99; noise: 1.00; b: 0.87; m: 1.21; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : (-4 AND (-5 AND 2))
# >> G_3: init: 1.29; noise: 1.00; b: 2.62; m: 4.41; expr: 1.12; deg: 0.13; theta: 0.09; asym: 5.00; tree : 5
# >> G_4: init: 2.02; noise: 0.83; b: 3.17; m: 3.29; expr: 0.98; deg: 0.07; theta: 7.21; asym: 9.48; tree : 1
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.22; noise: 1.05; b: 3.04; m: 3.81; expr: 1.03; deg: 0.10; theta: 6.54; asym: 5.71; tree : (3 OR 1)
# >> G_1: init: 0.45; noise: 1.12; b: 2.71; m: 5.29; expr: 0.83; deg: 0.10; theta: 13.93; asym: 5.19; tree : (5 OR 3)
# >> G_2: init: 0.99; noise: 1.00; b: 0.87; m: 1.21; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : (-4 AND (-5 AND 2))
# >> G_3: init: 1.29; noise: 1.00; b: 2.62; m: 4.10; expr: 1.12; deg: 0.12; theta: 0.06; asym: 5.00; tree : 5
# >> G_4: init: 2.02; noise: 0.83; b: 3.17; m: 3.29; expr: 0.98; deg: 0.07; theta: 7.21; asym: 9.48; tree : 1
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.22; noise: 1.05; b: 3.04; m: 3.07; expr: 1.03; deg: 0.10; theta: 6.54; asym: 6.66; tree : (3 OR 1)
# >> G_1: init: 0.45; noise: 1.12; b: 2.71; m: 5.29; expr: 0.83; deg: 0.10; theta: 13.93; asym: 5.19; tree : (5 OR 3)
# >> G_2: init: 0.99; noise: 1.00; b: 0.87; m: 1.21; expr: 1.03; deg: 0.09; theta: 1.86; asym: 5.00; tree : (-4 AND (-5 AND 2))
# >> G_3: init: 1.29; noise: 1.00; b: 2.62; m: 4.10; expr: 1.12; deg: 0.12; theta: 0.06; asym: 5.00; tree : 5
# >> G_4: init: 2.02; noise: 0.83; b: 3.17; m: 3.29; expr: 0.98; deg: 0.07; theta: 7.21; asym: 9.48; tree : 1
