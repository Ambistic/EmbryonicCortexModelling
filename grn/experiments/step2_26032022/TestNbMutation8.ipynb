# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
import random
from lib.sde.mutate import mutate_gene4, mutate_tree_2

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None, nb_genes=4):
    return Solution(GRNMain(nb_genes, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
_MUTATE_FUNC = mutate_grn

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        global _MUTATE_FUNC
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**1.5))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init),
                                  new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e6
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    ObjectiveStep(name="The ONE", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 20
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 25
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, name=None):
    args = get_prun()
    args.cb_init = cb_init
    args.name = name
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    print("Final score", np.mean(scores), "+-", np.std(scores))
    return np.mean(scores), np.std(scores), max(p1)

# %%
def mutate_grn_verysparse(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.9)
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree_2(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()

# %%
model = sm.StringModel("expfit_func{mutfunc}_i{i}")
mut_func = dict(
    fullctrl=lambda x: mutate_grn_verysparse(x),
    full005=lambda x: mutate_grn_verysparse(x, temperature=0.05),
    full02=lambda x: mutate_grn_verysparse(x, temperature=0.2),
)

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
)

# %%
# main loop
exporter = Exporter(name="exp_mutfunc8_280222")
for (funcname, func), i in product(mut_func.items(), range(10)):
    name = model.fill(mutfunc=funcname, i=i)
    print(name)
    if name in exporter.list():
        continue
    _MUTATE_FUNC = func
    res = get_score_parametrized(callback_init)
    exporter(res, name)
# Out:
# Exporting at output/exp_mutfunc8_280222
# expfit_funcfullctrl_i0
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 1029.0 for generation 1
# Step The ONE passed !
# ++ Best 1041.0 for generation 33
# ++ Best 1226.180920072727 for generation 34
# ++ Best 1299.430780618347 for generation 60
# ++ Best 1679.9377863789657 for generation 79
# Step 100
# ++ Best 1688.0177871865296 for generation 121
# ++ Best 1716.8302205930995 for generation 126
# ++ Best 1756.68323274845 for generation 133
# ++ Best 1769.9072043644996 for generation 180
# OVER
# Final score 1610.632097525448 +- 71.66948936602877
# expfit_funcfullctrl_i1
# Step 0
# ++ Best 844.8302205930993 for generation 0
# ++ Best 971.4307806183468 for generation 4
# ++ Best 1024.1715728752538 for generation 5
# ++ Best 1038.0 for generation 22
# Step 100
# OVER
# Final score 1011.1073632772119 +- 12.764143149619951
# expfit_funcfullctrl_i2
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 795.752267887179 for generation 2
# ++ Best 995.3772233983163 for generation 3
# ++ Best 1028.3030615433008 for generation 4
# ++ Best 1029.0 for generation 30
# ++ Best 1030.0 for generation 39
# ++ Best 1037.1715728752538 for generation 65
# ++ Best 1039.3772233983161 for generation 69
# ++ Best 1055.3725830020305 for generation 85
# Step 100
# ++ Best 1058.5171273060905 for generation 106
# ++ Best 1073.5171273060905 for generation 130
# ++ Best 1076.430780618347 for generation 149
# ++ Best 1087.0 for generation 155
# ++ Best 1093.5171273060905 for generation 160
# ++ Best 1210.430780618347 for generation 179
# ++ Best 1229.430780618347 for generation 184
# ++ Best 1246.5171273060905 for generation 195
# ++ Best 1259.7659104059273 for generation 198
# OVER
# Final score 1175.3803074858024 +- 29.447444060106793
# expfit_funcfullctrl_i3
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 975.430780618347 for generation 1
# ++ Best 984.3772233983163 for generation 5
# ++ Best 985.430780618347 for generation 10
# ++ Best 1006.5171273060905 for generation 15
# ++ Best 1007.3030615433008 for generation 17
# ++ Best 1025.0 for generation 24
# ++ Best 1029.0 for generation 25
# ++ Best 1030.0 for generation 27
# ++ Best 1030.3725830020305 for generation 35
# ++ Best 1031.3725830020305 for generation 76
# Step 100
# ++ Best 1067.5171273060905 for generation 106
# ++ Best 1104.5171273060905 for generation 118
# ++ Best 1126.0 for generation 126
# ++ Best 1235.5171273060905 for generation 130
# ++ Best 1316.8302205930995 for generation 135
# ++ Best 1382.430780618347 for generation 137
# ++ Best 1604.7038845869213 for generation 140
# ++ Best 1678.8302205930995 for generation 157
# ++ Best 1774.632467631853 for generation 168
# OVER
# Final score 1464.725597192684 +- 87.43962624093672
# expfit_funcfullctrl_i4
# Step 0
# ++ Best 998.430780618347 for generation 0
# ++ Best 1006.3030615433009 for generation 5
# ++ Best 1007.0 for generation 16
# ++ Best 1031.0 for generation 35
# ++ Best 1034.819660112501 for generation 55
# Step 100
# ++ Best 1039.3725830020305 for generation 114
# ++ Best 1045.3725830020305 for generation 140
# ++ Best 1047.3030615433008 for generation 166
# ++ Best 1051.479740822548 for generation 180
# ++ Best 1056.3030615433008 for generation 192
# OVER
# Final score 1028.150596547264 +- 9.54879673105668
# expfit_funcfullctrl_i5
# Step 0
# ++ Best 977.5171273060906 for generation 0
# ++ Best 998.3725830020306 for generation 2
# ++ Best 1012.5171273060906 for generation 15
# ++ Best 1012.8196601125012 for generation 16
# ++ Best 1045.3772233983161 for generation 25
# ++ Best 1056.3772233983161 for generation 63
# ++ Best 1096.430780618347 for generation 81
# ++ Best 1114.5171273060905 for generation 83
# Step 100
# ++ Best 1129.0 for generation 117
# ++ Best 1158.632467631853 for generation 120
# OVER
# Final score 1069.9071033887053 +- 42.62314308058423
# expfit_funcfullctrl_i6
# Step 0
# ++ Best 973.430780618347 for generation 0
# ++ Best 1009.3030615433008 for generation 1
# ++ Best 1016.9999999999999 for generation 3
# ++ Best 1019.0000000000001 for generation 74
# Step 100
# ++ Best 1019.8196601125011 for generation 157
# ++ Best 1023.8038475772934 for generation 170
# OVER
# Final score 993.3982327292636 +- 11.492891677439248
# expfit_funcfullctrl_i7
# Step 0
# ++ Best 727.8088906668698 for generation 0
# ++ Best 851.8379265803829 for generation 1
# ++ Best 993.9999999999999 for generation 2
# ++ Best 1000.3725830020305 for generation 6
# ++ Best 1002.430780618347 for generation 8
# ++ Best 1020.4797408225479 for generation 12
# ++ Best 1027.1715728752538 for generation 34
# ++ Best 1030.3030615433008 for generation 74
# ++ Best 1031.3030615433008 for generation 95
# Step 100
# ++ Best 1042.8038475772933 for generation 115
# ++ Best 1048.479740822548 for generation 154
# OVER
# Final score 1020.1138806551178 +- 5.143317788464391
# expfit_funcfullctrl_i8
# Step 0
# ++ Best 987.3772233983162 for generation 0
# ++ Best 1002.3772233983162 for generation 3
# ++ Best 1005.3030615433008 for generation 15
# ++ Best 1008.3030615433009 for generation 17
# ++ Best 1235.180920072727 for generation 19
# ++ Best 1304.6958749638075 for generation 32
# ++ Best 1312.4254926465876 for generation 68
# Step 100
# ++ Best 1314.4254926465876 for generation 194
# OVER
# Final score 1216.372589820196 +- 87.69089448797749
# expfit_funcfullctrl_i9
# Step 0
# ++ Best 983.3772233983162 for generation 0
# ++ Best 984.4307806183468 for generation 3
# ++ Best 992.5171273060906 for generation 6
# ++ Best 1002.5171273060906 for generation 12
# ++ Best 1025.0 for generation 17
# ++ Best 1037.430780618347 for generation 56
# ++ Best 1048.5171273060905 for generation 64
# ++ Best 1471.4244923464075 for generation 176
# ++ Best 1493.430780618347 for generation 192
# OVER
# Final score 1367.528492521054 +- 39.2118677577806
# expfit_funcfull02_i1
# Step 0
# ++ Best 1016.9999999999999 for generation 0
# ++ Best 1019.3030615433008 for generation 73
# ++ Best 1028.819660112501 for generation 99
# Step 100
# ++ Best 1042.0 for generation 125
# ++ Best 1043.0 for generation 158
# ++ Best 1046.0 for generation 197
# OVER
# Final score 1019.1879766487946 +- 13.158514092805115
# expfit_funcfull02_i2
# Step 0
# ++ Best 989.5171273060907 for generation 0
# ++ Best 998.3772233983162 for generation 13
# ++ Best 1000.3725830020305 for generation 14
# ++ Best 1007.3030615433008 for generation 17
# ++ Best 1013.303061543301 for generation 27
# ++ Best 1022.5171273060906 for generation 31
# ++ Best 1036.0 for generation 37
# ++ Best 1037.1370184487248 for generation 57
# ++ Best 1041.0 for generation 62
# ++ Best 1041.3772233983161 for generation 70
# ++ Best 1070.430780618347 for generation 72
# ++ Best 1092.937786378966 for generation 80
# ++ Best 1117.430780618347 for generation 87
# Step 100
# ++ Best 1136.430780618347 for generation 117
# ++ Best 1189.5171273060905 for generation 119
# ++ Best 1203.430780618347 for generation 140
# ++ Best 1216.0 for generation 148
# ++ Best 1255.0 for generation 175
# ++ Best 1292.4244923464075 for generation 186
# OVER
# Final score 1097.2086619557092 +- 88.70311561161546
# expfit_funcfull02_i3
# Step 0
# ++ Best 939.9072043644998 for generation 0
# ++ Best 971.4307806183468 for generation 1
# ++ Best 1013.303061543301 for generation 3
# ++ Best 1020.0 for generation 10
# ++ Best 1029.1715728752538 for generation 16
# ++ Best 1031.0 for generation 60
# ++ Best 1035.0 for generation 61
# Step 100
# ++ Best 1036.0 for generation 100
# ++ Best 1037.0 for generation 113
# ++ Best 1038.0 for generation 169
# ++ Best 1041.0 for generation 174
# OVER
# Final score 1035.6171572875253 +- 1.875930937549229
# expfit_funcfull02_i4
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 972.4307806183471 for generation 1
# ++ Best 993.0 for generation 2
# ++ Best 1265.5171273060905 for generation 6
# ++ Best 1334.5171273060905 for generation 32
# ++ Best 1574.430780618347 for generation 36
# Step 100
# ++ Best 1602.0 for generation 120
# ++ Best 1635.9052498068886 for generation 142
# OVER
# Final score 1488.416067420931 +- 76.58722087050336
# expfit_funcfull02_i5
# Step 0
# ++ Best 847.8302205930994 for generation 0
# ++ Best 1021.303061543301 for generation 4
# ++ Best 1021.8038475772934 for generation 10
# ++ Best 1189.430780618347 for generation 16
# ++ Best 1201.3772233983161 for generation 40
# ++ Best 1223.430780618347 for generation 43
# ++ Best 1258.6167965851648 for generation 48
# ++ Best 1310.632467631853 for generation 49
# ++ Best 1325.6167965851648 for generation 78
# Step 100
# ++ Best 1357.9052498068886 for generation 153
# OVER
# Final score 1161.6966388862324 +- 95.50617435467612
# expfit_funcfull02_i6
# Step 0
# ++ Best 969.1278334189681 for generation 0
# ++ Best 983.5171273060906 for generation 2
# ++ Best 1020.8196601125011 for generation 6
# ++ Best 1023.4797408225478 for generation 15
# ++ Best 1056.5171273060905 for generation 38
# ++ Best 1087.479740822548 for generation 40
# ++ Best 1094.0 for generation 44
# ++ Best 1142.0 for generation 45
# ++ Best 1173.5171273060905 for generation 48
# ++ Best 1386.9530022087924 for generation 61
# ++ Best 1458.430780618347 for generation 67
# ++ Best 1460.430780618347 for generation 77
# ++ Best 1467.0 for generation 84
# ++ Best 1499.4719062652532 for generation 86
# ++ Best 1545.430780618347 for generation 96
# Step 100
# ++ Best 1574.5572809000084 for generation 105
# ++ Best 1575.4254926465874 for generation 158
# ++ Best 1608.6958749638075 for generation 160
# ++ Best 1610.9372075915137 for generation 184
# OVER
# Final score 1504.1633812108507 +- 117.7232492430947
# expfit_funcfull02_i7
# Step 0
# ++ Best 234.33872113010455 for generation 0
# ++ Best 1097.0 for generation 1
# ++ Best 1113.5171273060905 for generation 27
# ++ Best 1133.5171273060905 for generation 32
# ++ Best 1163.0 for generation 34
# ++ Best 1246.5171273060905 for generation 41
# ++ Best 1367.9072043644996 for generation 54
# ++ Best 1388.430780618347 for generation 64
# ++ Best 1601.1541758681326 for generation 86
# ++ Best 1631.0128207762377 for generation 94
# ++ Best 1720.7842337811508 for generation 95
# Step 100
# ++ Best 1796.3772233983161 for generation 163
# ++ Best 2039.0128207762375 for generation 194
# OVER
# Final score 943.2982345205825 +- 945.4098355374807
# expfit_funcfull02_i8
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 1006.3772233983162 for generation 1
# ++ Best 1078.5171273060905 for generation 9
# ++ Best 1127.9372075915135 for generation 23
# ++ Best 1196.5171273060905 for generation 30
# ++ Best 1290.430780618347 for generation 36
# ++ Best 1302.5171273060905 for generation 39
# ++ Best 1304.430780618347 for generation 42
# ++ Best 1463.5171273060905 for generation 53
# ++ Best 1681.8108532838849 for generation 96
# Step 100
# ++ Best 1766.9072043644999 for generation 153
# ++ Best 1780.1370184487246 for generation 155
# OVER
# Final score 458.0917805367627 +- 701.8059484461603
# expfit_funcfull02_i9
# Step 0
# ++ Best 985.3772233983162 for generation 0
# ++ Best 988.3772233983162 for generation 1
# ++ Best 1004.3030615433009 for generation 6
# ++ Best 1013.0000000000001 for generation 13
# ++ Best 1035.1715728752538 for generation 15
# ++ Best 1040.0 for generation 46
# Step 100
# ++ Best 1043.0 for generation 145
# ++ Best 1044.0 for generation 168
# OVER
# Final score 1031.6075663365773 +- 13.936723475652695

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#     mutfunc  i         mean          sd          max
# 0    full02  0  1367.528493   39.211868  1493.430781
# 1   full005  7  1264.568294   43.307899  1335.430781
# 2    full02  9  1031.607566   13.936723  1044.000000
# 3   full005  3  1199.115282  108.355397  1319.424492
# 4  fullctrl  7  1020.113881    5.143318  1048.479741

# %%
new_df = df.groupby(["mutfunc"]).mean()
new_df
# Out:
#                  mean          sd          max
# mutfunc
# full005   1186.883243   98.268458  1323.538007
# full02    1110.681596  209.391858  1434.075282
# fullctrl  1182.617017   44.817931  1274.237468

# %%
for i, row in new_df.iterrows():
    print(row.name, row["mean"], row["mean"] - row.sd / np.sqrt(10), row["mean"] + row.sd / np.sqrt(10))
# Out:
# full005 1186.8832432004149 1155.8080284115326 1217.9584579892971
# full02 1110.681595732502 1044.4660762446963 1176.8971152203078
# fullctrl 1182.617016673857 1168.444342628164 1196.7896907195502

# %%
row.name
# Out:
# 'fullctrl'
