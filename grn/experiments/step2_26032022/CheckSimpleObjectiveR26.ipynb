# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(7, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 70.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 100 - 1 * delta_late - 0.5 * delta_early)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=50, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r26"
res = main(prun)

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r26

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
res.fit
# Out:
# 32.52626234769093

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.00; noise: 1.00; b: 3.98; m: 9.21; expr: 1.00; deg: 0.10; theta: 0.06; asym: 5.00; tree : (-0 AND -7)
# >> G_1: init: 1.47; noise: 1.00; b: 1.95; m: 5.83; expr: 1.00; deg: 0.10; theta: 0.90; asym: 5.00; tree : ((7 AND 2) OR (-4 AND -1))
# >> G_2: init: 0.49; noise: 1.00; b: 2.42; m: 6.49; expr: 1.00; deg: 0.10; theta: 2.09; asym: 5.00; tree : ((4 AND -1) OR -2)
# >> G_3: init: 0.22; noise: 1.00; b: 1.19; m: 4.59; expr: 1.00; deg: 0.10; theta: 8.26; asym: 5.00; tree : ((-4 AND 5) OR 0)
# >> G_4: init: 2.08; noise: 1.00; b: 0.17; m: 5.48; expr: 1.00; deg: 0.10; theta: 5.39; asym: 5.00; tree : (-5 OR 0)
# >> G_5: init: 0.72; noise: 1.00; b: 0.23; m: 6.72; expr: 1.00; deg: 0.10; theta: 5.84; asym: 5.00; tree : -5
# >> G_6: init: 1.57; noise: 1.00; b: 1.79; m: 3.32; expr: 1.20; deg: 0.10; theta: 6.38; asym: 5.00; tree : (1 AND 2)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.55; m: 6.89; expr: 1.00; deg: 0.10; theta: 2.50; asym: 5.00; tree : ((5 OR -1) OR (7 OR -4))
# >> G_1: init: 2.58; noise: 1.00; b: 2.42; m: 3.10; expr: 1.00; deg: 0.10; theta: 1.65; asym: 5.00; tree : ((2 AND -5) OR -4)
# >> G_2: init: 0.33; noise: 1.00; b: 0.75; m: 2.29; expr: 1.00; deg: 0.10; theta: 7.66; asym: 5.00; tree : (-1 OR 6)
# >> G_3: init: 0.77; noise: 1.00; b: 0.45; m: 3.64; expr: 1.00; deg: 0.10; theta: 0.89; asym: 5.00; tree : ((-2 OR -0) AND -3)
# >> G_4: init: 0.14; noise: 1.00; b: 0.32; m: 7.27; expr: 1.00; deg: 0.10; theta: 4.16; asym: 5.00; tree : 0
# >> G_5: init: 1.01; noise: 1.00; b: 1.25; m: 8.94; expr: 1.00; deg: 0.10; theta: 2.47; asym: 5.00; tree : -0
# >> G_6: init: 0.43; noise: 1.00; b: 2.86; m: 3.48; expr: 1.00; deg: 0.10; theta: 0.71; asym: 5.00; tree : (-3 AND (4 AND -1))
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.00; noise: 1.00; b: 2.96; m: 9.39; expr: 1.00; deg: 0.10; theta: 3.39; asym: 5.00; tree : ((-5 OR -1) AND (-6 AND -4))
# >> G_1: init: 0.94; noise: 1.00; b: 1.68; m: 3.07; expr: 1.00; deg: 0.10; theta: 8.62; asym: 5.00; tree : (2 AND 5)
# >> G_2: init: 1.43; noise: 1.00; b: 0.54; m: 2.41; expr: 1.00; deg: 0.10; theta: 7.36; asym: 5.00; tree : -0
# >> G_3: init: 0.58; noise: 1.00; b: 2.52; m: 7.60; expr: 1.00; deg: 0.10; theta: 4.58; asym: 5.51; tree : 4
# >> G_4: init: 0.79; noise: 1.00; b: 0.89; m: 8.16; expr: 1.00; deg: 0.10; theta: 6.01; asym: 5.00; tree : (-2 OR -1)
# >> G_5: init: 1.92; noise: 1.00; b: 3.96; m: 5.98; expr: 1.00; deg: 0.10; theta: 9.10; asym: 5.00; tree : ((-3 AND 1) OR (-4 AND 2))
# >> G_6: init: 0.57; noise: 1.00; b: 2.20; m: 1.99; expr: 1.00; deg: 0.10; theta: 2.36; asym: 5.00; tree : (-5 AND (2 AND -3))
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.00; noise: 1.00; b: 2.26; m: 8.99; expr: 1.00; deg: 0.10; theta: 2.74; asym: 5.00; tree : ((-6 AND -3) AND 1)
# >> G_1: init: 0.43; noise: 1.00; b: 0.38; m: 1.32; expr: 1.00; deg: 0.10; theta: 6.98; asym: 5.00; tree : (-5 OR -1)
# >> G_2: init: 0.68; noise: 1.00; b: 0.62; m: 7.58; expr: 1.00; deg: 0.10; theta: 3.85; asym: 5.00; tree : -0
# >> G_3: init: 1.57; noise: 1.00; b: 1.62; m: 6.81; expr: 1.00; deg: 0.10; theta: 9.03; asym: 5.00; tree : (7 OR -3)
# >> G_4: init: 0.06; noise: 1.00; b: 1.82; m: 9.11; expr: 1.00; deg: 0.10; theta: 0.88; asym: 5.00; tree : ((-0 AND 4) AND 3)
# >> G_5: init: 0.87; noise: 1.00; b: 1.36; m: 5.87; expr: 1.00; deg: 0.10; theta: 4.35; asym: 5.00; tree : 7
# >> G_6: init: 0.88; noise: 1.08; b: 4.04; m: 6.49; expr: 1.00; deg: 0.10; theta: 2.43; asym: 5.00; tree : (-7 AND (6 OR -0))
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.00; noise: 0.95; b: 0.22; m: 8.65; expr: 1.00; deg: 0.10; theta: 5.25; asym: 5.00; tree : (0 OR -4)
# >> G_1: init: 0.16; noise: 1.00; b: 2.74; m: 9.05; expr: 1.00; deg: 0.10; theta: 0.14; asym: 5.00; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.62; expr: 1.00; deg: 0.08; theta: 1.03; asym: 5.00; tree : (-4 OR (6 AND 1))
# >> G_3: init: 0.88; noise: 1.00; b: 2.24; m: 7.79; expr: 1.00; deg: 0.10; theta: 0.86; asym: 5.00; tree : (6 AND (-7 AND -5))
# >> G_4: init: 0.39; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.00; tree : (-3 OR 7)
# >> G_5: init: 2.27; noise: 0.86; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.78; asym: 5.00; tree : ((7 AND -3) OR (4 OR -5))
# >> G_6: init: 2.65; noise: 1.00; b: 1.26; m: 7.84; expr: 1.00; deg: 0.10; theta: 6.62; asym: 5.00; tree : ((3 AND -6) OR -5)
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.00; noise: 0.95; b: 0.22; m: 8.65; expr: 1.00; deg: 0.10; theta: 5.25; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 1.00; b: 2.74; m: 9.05; expr: 1.00; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.62; expr: 1.00; deg: 0.08; theta: 1.03; asym: 5.00; tree : (-4 OR (6 AND 1))
# >> G_3: init: 0.88; noise: 1.00; b: 2.24; m: 7.79; expr: 1.00; deg: 0.10; theta: 0.86; asym: 4.74; tree : (6 AND (-7 AND -5))
# >> G_4: init: 0.39; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.00; tree : (-3 OR 7)
# >> G_5: init: 2.27; noise: 0.86; b: 1.97; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.78; asym: 5.00; tree : ((7 AND -3) OR (4 OR -5))
# >> G_6: init: 2.65; noise: 1.00; b: 1.26; m: 7.84; expr: 0.87; deg: 0.10; theta: 6.62; asym: 5.00; tree : (3 AND -6)
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.00; noise: 0.95; b: 0.23; m: 9.60; expr: 1.00; deg: 0.10; theta: 5.25; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 1.00; b: 2.74; m: 9.05; expr: 1.00; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.62; expr: 1.00; deg: 0.08; theta: 1.03; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.88; noise: 1.00; b: 2.24; m: 7.79; expr: 1.01; deg: 0.10; theta: 0.86; asym: 4.74; tree : (6 AND (-7 AND -5))
# >> G_4: init: 0.39; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.00; tree : (-3 OR 7)
# >> G_5: init: 2.27; noise: 0.86; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.78; asym: 5.00; tree : ((7 AND -3) OR (4 OR -5))
# >> G_6: init: 2.65; noise: 1.00; b: 1.26; m: 7.84; expr: 0.87; deg: 0.10; theta: 6.62; asym: 5.00; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.00; noise: 0.95; b: 0.23; m: 9.60; expr: 1.00; deg: 0.10; theta: 5.25; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 1.00; b: 2.74; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.62; expr: 1.00; deg: 0.08; theta: 1.03; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.88; noise: 0.89; b: 2.24; m: 7.79; expr: 1.01; deg: 0.10; theta: 0.86; asym: 4.74; tree : (6 AND (-7 AND -5))
# >> G_4: init: 0.39; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.00; tree : (-3 OR 7)
# >> G_5: init: 2.27; noise: 0.86; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.78; asym: 5.00; tree : ((7 AND -3) OR (4 OR -5))
# >> G_6: init: 2.65; noise: 1.00; b: 1.26; m: 7.84; expr: 0.87; deg: 0.10; theta: 6.62; asym: 4.20; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.00; noise: 0.95; b: 0.23; m: 9.60; expr: 1.00; deg: 0.10; theta: 5.25; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 1.00; b: 2.74; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.62; expr: 1.00; deg: 0.08; theta: 1.03; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.89; b: 2.24; m: 7.79; expr: 1.01; deg: 0.10; theta: 0.86; asym: 4.74; tree : (3 AND (-7 AND -5))
# >> G_4: init: 0.39; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.00; tree : (-3 OR 7)
# >> G_5: init: 2.27; noise: 0.86; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.78; asym: 5.00; tree : ((7 AND -3) OR -5)
# >> G_6: init: 2.65; noise: 1.00; b: 1.26; m: 7.37; expr: 0.87; deg: 0.10; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.00; noise: 0.95; b: 0.23; m: 9.60; expr: 1.00; deg: 0.10; theta: 5.25; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 1.00; b: 2.74; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 1.03; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.89; b: 2.24; m: 7.79; expr: 1.01; deg: 0.10; theta: 0.86; asym: 4.74; tree : (3 AND (4 AND -5))
# >> G_4: init: 0.39; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.00; tree : (-3 OR 7)
# >> G_5: init: 2.27; noise: 0.86; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.78; asym: 5.00; tree : ((7 AND -3) OR -5)
# >> G_6: init: 2.65; noise: 1.00; b: 1.26; m: 7.37; expr: 0.87; deg: 0.10; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.00; noise: 0.95; b: 0.23; m: 9.60; expr: 1.00; deg: 0.10; theta: 5.25; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 1.00; b: 2.74; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 1.03; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.89; b: 2.24; m: 8.24; expr: 1.01; deg: 0.10; theta: 0.86; asym: 4.74; tree : (3 AND (4 AND 0))
# >> G_4: init: 0.39; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR 7)
# >> G_5: init: 2.27; noise: 0.86; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND -3) OR -5)
# >> G_6: init: 2.65; noise: 1.00; b: 1.26; m: 7.37; expr: 0.87; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.00; noise: 0.95; b: 0.23; m: 9.68; expr: 1.00; deg: 0.10; theta: 5.25; asym: 5.89; tree : -3
# >> G_1: init: 0.16; noise: 1.04; b: 2.74; m: 10.45; expr: 0.97; deg: 0.10; theta: 0.14; asym: 4.59; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.62; expr: 1.00; deg: 0.08; theta: 1.03; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 1.11; noise: 0.89; b: 2.24; m: 7.50; expr: 1.01; deg: 0.10; theta: 0.86; asym: 4.74; tree : (3 AND (-7 AND -6))
# >> G_4: init: 0.31; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.00; tree : (-0 OR 7)
# >> G_5: init: 2.27; noise: 0.86; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.78; asym: 5.00; tree : ((7 AND -3) OR -5)
# >> G_6: init: 2.65; noise: 0.85; b: 1.26; m: 7.37; expr: 0.87; deg: 0.10; theta: 6.62; asym: 4.45; tree : (3 AND -6)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.00; noise: 0.80; b: 0.23; m: 9.60; expr: 1.00; deg: 0.10; theta: 4.68; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 1.00; b: 2.74; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 0.98; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.89; b: 2.60; m: 8.24; expr: 1.01; deg: 0.10; theta: 0.86; asym: 3.93; tree : (3 AND 4)
# >> G_4: init: 0.39; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR (7 AND -1))
# >> G_5: init: 2.27; noise: 0.76; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND -3) OR -5)
# >> G_6: init: 2.65; noise: 1.00; b: 1.26; m: 7.37; expr: 0.92; deg: 0.12; theta: 6.86; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.00; noise: 0.94; b: 0.23; m: 11.45; expr: 1.00; deg: 0.10; theta: 4.68; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 1.00; b: 2.74; m: 9.17; expr: 0.97; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 0.98; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.89; b: 2.24; m: 8.24; expr: 1.01; deg: 0.10; theta: 0.86; asym: 4.74; tree : (-6 AND 4)
# >> G_4: init: 0.38; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR (7 AND -1))
# >> G_5: init: 2.27; noise: 0.86; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND -3) OR -5)
# >> G_6: init: 3.01; noise: 1.00; b: 1.41; m: 7.37; expr: 0.92; deg: 0.12; theta: 7.35; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.23; m: 8.02; expr: 1.00; deg: 0.10; theta: 4.68; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 0.80; b: 2.74; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 0.98; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.89; b: 2.27; m: 8.24; expr: 1.01; deg: 0.10; theta: 0.86; asym: 4.74; tree : (3 AND 4)
# >> G_4: init: 0.40; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR (7 AND -1))
# >> G_5: init: 2.27; noise: 0.86; b: 1.82; m: 2.72; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND -3) OR -2)
# >> G_6: init: 2.71; noise: 1.00; b: 1.26; m: 7.37; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.00; noise: 0.80; b: 0.23; m: 9.60; expr: 1.00; deg: 0.10; theta: 4.68; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.16; noise: 1.00; b: 2.65; m: 10.55; expr: 0.97; deg: 0.10; theta: 0.14; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 7.67; expr: 1.00; deg: 0.08; theta: 1.11; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.89; b: 2.24; m: 8.24; expr: 1.01; deg: 0.10; theta: 0.86; asym: 4.74; tree : (3 AND 4)
# >> G_4: init: 0.38; noise: 1.00; b: 1.56; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR (7 AND -1))
# >> G_5: init: 2.27; noise: 0.86; b: 1.67; m: 2.74; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND -3) OR 4)
# >> G_6: init: 3.01; noise: 1.00; b: 1.26; m: 6.88; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : (4 AND -6)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.23; m: 8.02; expr: 1.00; deg: 0.10; theta: 4.68; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.15; noise: 0.80; b: 2.74; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.15; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 0.98; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.89; b: 2.27; m: 8.24; expr: 0.98; deg: 0.10; theta: 0.86; asym: 4.74; tree : (2 AND 4)
# >> G_4: init: 0.40; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR (7 AND -1))
# >> G_5: init: 2.27; noise: 0.86; b: 1.82; m: 2.72; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND 0) OR -2)
# >> G_6: init: 2.71; noise: 1.00; b: 1.26; m: 7.37; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.23; m: 8.02; expr: 1.00; deg: 0.10; theta: 5.36; asym: 5.00; tree : (0 OR -3)
# >> G_1: init: 0.15; noise: 0.80; b: 2.60; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.15; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 0.98; asym: 4.48; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.89; b: 2.27; m: 8.24; expr: 0.98; deg: 0.10; theta: 0.86; asym: 5.39; tree : (2 AND 4)
# >> G_4: init: 0.40; noise: 1.00; b: 1.46; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR (7 AND -1))
# >> G_5: init: 2.27; noise: 0.87; b: 1.82; m: 2.72; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND 0) OR -2)
# >> G_6: init: 2.71; noise: 1.00; b: 1.33; m: 7.37; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.23; m: 8.02; expr: 1.00; deg: 0.10; theta: 5.18; asym: 4.08; tree : (0 OR -3)
# >> G_1: init: 0.15; noise: 0.80; b: 2.74; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.15; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 0.98; asym: 5.00; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 1.01; b: 2.27; m: 8.24; expr: 0.98; deg: 0.10; theta: 0.86; asym: 4.74; tree : (2 AND 4)
# >> G_4: init: 0.40; noise: 1.00; b: 1.39; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR (7 AND -1))
# >> G_5: init: 2.27; noise: 0.85; b: 1.82; m: 2.72; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND 0) OR -2)
# >> G_6: init: 2.71; noise: 1.00; b: 1.26; m: 7.37; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.23; m: 8.02; expr: 1.00; deg: 0.10; theta: 5.36; asym: 5.00; tree : -3
# >> G_1: init: 0.15; noise: 0.80; b: 2.60; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.17; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 0.98; asym: 4.48; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.79; b: 2.27; m: 8.24; expr: 0.98; deg: 0.08; theta: 0.86; asym: 5.39; tree : -7
# >> G_4: init: 0.40; noise: 0.99; b: 1.46; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR 7)
# >> G_5: init: 2.27; noise: 0.87; b: 1.82; m: 2.72; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND 0) OR -2)
# >> G_6: init: 2.71; noise: 1.00; b: 1.33; m: 6.02; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.23; m: 8.02; expr: 1.00; deg: 0.10; theta: 5.36; asym: 5.00; tree : -3
# >> G_1: init: 0.15; noise: 0.80; b: 2.60; m: 9.05; expr: 0.97; deg: 0.10; theta: 0.15; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 0.98; asym: 4.48; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.87; b: 2.06; m: 8.24; expr: 0.98; deg: 0.08; theta: 0.86; asym: 5.39; tree : (-7 AND 4)
# >> G_4: init: 0.40; noise: 0.99; b: 1.46; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR 7)
# >> G_5: init: 2.27; noise: 0.87; b: 1.82; m: 2.72; expr: 1.00; deg: 0.10; theta: 3.71; asym: 5.00; tree : ((7 AND 0) OR -2)
# >> G_6: init: 2.71; noise: 1.00; b: 1.33; m: 6.02; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND -0) AND -6)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.25; m: 8.02; expr: 1.00; deg: 0.10; theta: 5.36; asym: 6.69; tree : -3
# >> G_1: init: 0.15; noise: 0.80; b: 2.60; m: 10.56; expr: 0.97; deg: 0.10; theta: 0.15; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.00; deg: 0.08; theta: 0.98; asym: 4.48; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.87; b: 2.06; m: 8.24; expr: 0.98; deg: 0.08; theta: 0.86; asym: 5.39; tree : (-7 AND (4 AND -0))
# >> G_4: init: 0.40; noise: 0.99; b: 1.46; m: 4.42; expr: 1.00; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-3 OR (7 AND -1))
# >> G_5: init: 2.27; noise: 0.87; b: 1.82; m: 2.72; expr: 1.00; deg: 0.10; theta: 3.71; asym: 4.53; tree : ((4 AND 0) OR -2)
# >> G_6: init: 2.81; noise: 1.00; b: 1.33; m: 6.02; expr: 0.92; deg: 0.12; theta: 7.30; asym: 4.40; tree : ((3 AND -0) AND -6)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.23; m: 8.02; expr: 1.00; deg: 0.10; theta: 5.36; asym: 4.17; tree : -3
# >> G_1: init: 0.15; noise: 0.92; b: 2.97; m: 9.05; expr: 0.97; deg: 0.09; theta: 0.15; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 3.49; m: 9.19; expr: 1.07; deg: 0.08; theta: 0.98; asym: 4.48; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.67; b: 2.27; m: 8.24; expr: 0.80; deg: 0.10; theta: 0.86; asym: 4.43; tree : (2 AND 4)
# >> G_4: init: 0.40; noise: 1.00; b: 1.46; m: 4.42; expr: 1.01; deg: 0.10; theta: 9.54; asym: 5.51; tree : (-5 OR (7 AND 0))
# >> G_5: init: 2.27; noise: 0.87; b: 1.89; m: 2.72; expr: 1.00; deg: 0.08; theta: 3.71; asym: 5.00; tree : ((7 AND 0) OR -2)
# >> G_6: init: 2.67; noise: 1.00; b: 1.33; m: 7.37; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.23; m: 8.02; expr: 1.00; deg: 0.10; theta: 5.36; asym: 4.17; tree : -3
# >> G_1: init: 0.15; noise: 0.92; b: 3.09; m: 9.05; expr: 0.97; deg: 0.09; theta: 0.15; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 2.96; m: 9.19; expr: 1.07; deg: 0.08; theta: 0.98; asym: 4.48; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.82; noise: 0.67; b: 2.27; m: 8.24; expr: 0.80; deg: 0.10; theta: 0.86; asym: 4.43; tree : (2 AND 4)
# >> G_4: init: 0.40; noise: 1.00; b: 1.46; m: 4.36; expr: 1.01; deg: 0.10; theta: 9.54; asym: 5.51; tree : (1 OR (7 AND 0))
# >> G_5: init: 2.27; noise: 0.87; b: 1.89; m: 2.72; expr: 1.00; deg: 0.08; theta: 3.71; asym: 5.00; tree : ((7 AND 0) OR -2)
# >> G_6: init: 2.67; noise: 1.00; b: 1.33; m: 7.37; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.23; m: 8.02; expr: 1.00; deg: 0.10; theta: 5.36; asym: 4.17; tree : -3
# >> G_1: init: 0.15; noise: 0.92; b: 2.97; m: 9.05; expr: 0.97; deg: 0.09; theta: 0.15; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 2.96; m: 8.22; expr: 1.07; deg: 0.08; theta: 0.98; asym: 4.48; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 0.98; noise: 0.67; b: 2.27; m: 8.24; expr: 0.80; deg: 0.10; theta: 0.86; asym: 4.43; tree : (2 AND 4)
# >> G_4: init: 0.40; noise: 1.00; b: 1.46; m: 4.53; expr: 1.01; deg: 0.10; theta: 9.54; asym: 5.29; tree : (1 OR 7)
# >> G_5: init: 2.27; noise: 0.87; b: 1.89; m: 2.72; expr: 1.00; deg: 0.08; theta: 3.71; asym: 5.00; tree : ((7 AND 0) OR -2)
# >> G_6: init: 2.67; noise: 1.00; b: 1.33; m: 7.37; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND 0)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.00; noise: 0.64; b: 0.27; m: 8.02; expr: 1.00; deg: 0.10; theta: 5.36; asym: 4.17; tree : -3
# >> G_1: init: 0.15; noise: 0.92; b: 2.97; m: 7.50; expr: 0.97; deg: 0.09; theta: 0.15; asym: 4.66; tree : (5 OR -4)
# >> G_2: init: 1.91; noise: 1.00; b: 2.96; m: 9.19; expr: 1.07; deg: 0.08; theta: 0.98; asym: 4.48; tree : (-4 OR (-3 AND 1))
# >> G_3: init: 1.05; noise: 0.67; b: 2.27; m: 8.24; expr: 0.80; deg: 0.10; theta: 0.86; asym: 4.43; tree : (2 AND 4)
# >> G_4: init: 0.40; noise: 1.00; b: 1.46; m: 4.42; expr: 1.01; deg: 0.10; theta: 9.54; asym: 5.51; tree : (1 OR (7 AND 0))
# >> G_5: init: 2.25; noise: 0.87; b: 1.89; m: 2.72; expr: 1.00; deg: 0.08; theta: 3.71; asym: 5.00; tree : ((7 AND 0) OR -2)
# >> G_6: init: 2.67; noise: 1.00; b: 1.33; m: 7.37; expr: 0.92; deg: 0.12; theta: 6.62; asym: 4.45; tree : ((3 AND 4) AND -6)
