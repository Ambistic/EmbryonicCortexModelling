# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 100 - 1 * delta_late - 0.5 * delta_early)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r20"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r20
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 71.47126390618098 for generation 0
# Step 3 passed !
# [out] ++ Best 71.58350880414017 for generation 1
# [out] ++ Best 72.7467741102626 for generation 3
# [out] ++ Best 78.36885015462468 for generation 22
# Saving ...
# [out] ++ Best 80.05252362401242 for generation 51
# [out] ++ Best 80.84844199135938 for generation 55
# [out] ++ Best 86.37357495711245 for generation 58
# [out] ++ Best 89.1694933244594 for generation 75
# [out] ++ Best 90.07765658976551 for generation 86
# Saving ...
# [out] Step 100
# [out] ++ Best 90.57765658976551 for generation 105
# [out] ++ Best 90.64908516119408 for generation 124
# [out] ++ Best 91.48581985507163 for generation 147
# Saving ...
# Saving ...
# [out] Step 200
# Saving ...
# Saving ...
# [out] Step 300
# Saving ...
# [out] ++ Best 92.0080754820905 for generation 393
# Saving ...
# [out] Step 400
# [out] ++ Best 92.0284836453558 for generation 423
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# Saving ...
# [out] ++ Best 92.08898808328503 for generation 790
# Saving ...
# [out] Step 800
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# [out] ++ Best 92.13052446168234 for generation 1086
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# Saving ...
# [out] Step 1300
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# [out] ++ Best 92.14072854331499 for generation 1666
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# [out] ++ Best 92.21143706287687 for generation 1840
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# Saving ...
# [out] Step 2100
# Saving ...
# [out] ++ Best 92.23256527800888 for generation 2158
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r20

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))
# Out:
# (88.2361970934002,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             0.0              1.0                 57.0             1.0
# 56.50             0.0              1.0                 58.0             1.0
# 56.75             0.0              1.0                 60.0             1.0
# 57.00             0.0              1.0                 64.0             1.0
# ...               ...              ...                  ...             ...
# 85.00             0.0           1201.0                106.0          1201.0
# 85.25             0.0           1212.0                107.0          1212.0
# 85.50             0.0           1222.0                105.0          1222.0
# 85.75             0.0           1229.0                104.0          1229.0
# 86.00             0.0           1236.0                102.0          1236.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            58.0
# 56.50  56.50            59.0
# 56.75  56.75            61.0
# 57.00  57.00            65.0
# ...      ...             ...
# 85.00  85.00          1307.0
# 85.25  85.25          1319.0
# 85.50  85.50          1327.0
# 85.75  85.75          1333.0
# 86.00  86.00          1338.0
#
# [121 rows x 6 columns])
# (88.71143706287688,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             0.0              0.0                 57.0             0.0
# 56.50             0.0              0.0                 60.0             0.0
# 56.75             0.0              1.0                 59.0             1.0
# 57.00             0.0              2.0                 58.0             2.0
# ...               ...              ...                  ...             ...
# 85.00             0.0           1182.0                100.0          1182.0
# 85.25             0.0           1194.0                 93.0          1194.0
# 85.50             0.0           1204.0                 93.0          1204.0
# 85.75             0.0           1210.0                 96.0          1210.0
# 86.00             0.0           1222.0                 92.0          1222.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            57.0
# 56.50  56.50            60.0
# 56.75  56.75            60.0
# 57.00  57.00            60.0
# ...      ...             ...
# 85.00  85.00          1282.0
# 85.25  85.25          1287.0
# 85.50  85.50          1297.0
# 85.75  85.75          1306.0
# 86.00  86.00          1314.0
#
# [121 rows x 6 columns])
# (92.11011629841703,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             0.0              0.0                 54.0             0.0
# 56.50             0.0              0.0                 56.0             0.0
# 56.75             0.0              0.0                 56.0             0.0
# 57.00             0.0              0.0                 59.0             0.0
# ...               ...              ...                  ...             ...
# 85.00             0.0            993.0                 99.0           993.0
# 85.25             0.0           1001.0                100.0          1001.0
# 85.50             0.0           1013.0                 93.0          1013.0
# 85.75             0.0           1023.0                 88.0          1023.0
# 86.00             0.0           1029.0                 86.0          1029.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            54.0
# 56.50  56.50            56.0
# 56.75  56.75            56.0
# 57.00  57.00            59.0
# ...      ...             ...
# 85.00  85.00          1092.0
# 85.25  85.25          1101.0
# 85.50  85.50          1106.0
# 85.75  85.75          1111.0
# 86.00  86.00          1115.0
#
# [121 rows x 6 columns])
# (91.68082481797893,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             0.0              2.0                 54.0             2.0
# 56.50             0.0              2.0                 55.0             2.0
# 56.75             0.0              2.0                 56.0             2.0
# 57.00             0.0              3.0                 59.0             3.0
# ...               ...              ...                  ...             ...
# 85.00             0.0           1064.0                 86.0          1064.0
# 85.25             0.0           1069.0                 83.0          1069.0
# 85.50             0.0           1074.0                 81.0          1074.0
# 85.75             0.0           1076.0                 85.0          1076.0
# 86.00             0.0           1084.0                 89.0          1084.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            56.0
# 56.50  56.50            57.0
# 56.75  56.75            58.0
# 57.00  57.00            62.0
# ...      ...             ...
# 85.00  85.00          1150.0
# 85.25  85.25          1152.0
# 85.50  85.50          1155.0
# 85.75  85.75          1161.0
# 86.00  86.00          1173.0
#
# [121 rows x 6 columns])
# (89.69174895147826,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             0.0              2.0                 55.0             2.0
# 56.50             0.0              3.0                 57.0             3.0
# 56.75             0.0              3.0                 59.0             3.0
# 57.00             0.0              3.0                 60.0             3.0
# ...               ...              ...                  ...             ...
# 85.00             0.0            934.0                 60.0           934.0
# 85.25             0.0            941.0                 54.0           941.0
# 85.50             0.0            946.0                 53.0           946.0
# 85.75             0.0            951.0                 48.0           951.0
# 86.00             0.0            954.0                 54.0           954.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            57.0
# 56.50  56.50            60.0
# 56.75  56.75            62.0
# 57.00  57.00            63.0
# ...      ...             ...
# 85.00  85.00           994.0
# 85.25  85.25           995.0
# 85.50  85.50           999.0
# 85.75  85.75           999.0
# 86.00  86.00          1008.0
#
# [121 rows x 6 columns])

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.97; m: 9.02; expr: 1.00; deg: 0.10; theta: 1.56; asym: 5.00; tree : ((-0 OR 5) OR 3)
# >> G_1: init: 0.68; noise: 1.00; b: 2.11; m: 7.09; expr: 1.00; deg: 0.10; theta: 2.48; asym: 5.00; tree : ((-2 OR -4) AND 0)
# >> G_2: init: 0.34; noise: 1.00; b: 0.73; m: 2.22; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.49; noise: 1.00; b: 2.14; m: 7.82; expr: 1.00; deg: 0.10; theta: 3.35; asym: 5.00; tree : -1
# >> G_4: init: 0.77; noise: 1.00; b: 1.77; m: 5.64; expr: 1.00; deg: 0.10; theta: 6.11; asym: 5.00; tree : -4
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.18; noise: 1.00; b: 1.97; m: 9.02; expr: 1.00; deg: 0.10; theta: 1.56; asym: 5.00; tree : ((-0 OR 5) OR 3)
# >> G_1: init: 0.68; noise: 1.00; b: 2.15; m: 7.09; expr: 1.00; deg: 0.10; theta: 2.48; asym: 5.28; tree : ((-2 OR -4) AND 0)
# >> G_2: init: 0.39; noise: 1.00; b: 0.73; m: 2.22; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.49; noise: 1.00; b: 2.14; m: 7.82; expr: 1.00; deg: 0.12; theta: 3.35; asym: 5.00; tree : -1
# >> G_4: init: 0.77; noise: 1.00; b: 1.77; m: 5.64; expr: 1.00; deg: 0.10; theta: 6.11; asym: 5.00; tree : -4
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.97; m: 9.02; expr: 1.00; deg: 0.10; theta: 1.56; asym: 5.00; tree : ((-0 OR 5) OR 3)
# >> G_1: init: 0.68; noise: 1.00; b: 2.15; m: 7.09; expr: 1.00; deg: 0.12; theta: 2.48; asym: 5.28; tree : ((-2 OR -4) AND 0)
# >> G_2: init: 0.34; noise: 1.00; b: 0.73; m: 2.22; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 1.55; noise: 4.40; b: 9.18; m: 1.23; expr: 4.10; deg: 0.19; theta: 1.58; asym: 8.82; tree : -1
# >> G_4: init: 0.77; noise: 1.00; b: 1.77; m: 5.64; expr: 1.00; deg: 0.12; theta: 6.11; asym: 5.00; tree : -4
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.04; noise: 1.00; b: 1.97; m: 10.29; expr: 1.00; deg: 0.10; theta: 1.41; asym: 5.00; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.20; deg: 2.70; theta: 5.75; asym: 0.87; tree : ((-4 AND 1) OR 2)
# >> G_2: init: 0.34; noise: 1.00; b: 0.73; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.58; noise: 0.86; b: 2.14; m: 7.82; expr: 1.06; deg: 0.10; theta: 3.10; asym: 5.00; tree : -1
# >> G_4: init: 0.77; noise: 1.00; b: 1.77; m: 5.64; expr: 1.00; deg: 0.10; theta: 6.11; asym: 5.00; tree : -4
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.04; noise: 1.00; b: 1.97; m: 10.29; expr: 1.00; deg: 0.10; theta: 1.41; asym: 5.82; tree : 5
# >> G_1: init: 0.74; noise: 2.44; b: 5.07; m: 7.76; expr: 0.20; deg: 3.07; theta: 5.75; asym: 0.87; tree : ((-4 AND 1) OR 2)
# >> G_2: init: 0.34; noise: 1.00; b: 0.73; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.51; noise: 0.86; b: 2.14; m: 7.82; expr: 1.06; deg: 0.10; theta: 3.10; asym: 5.00; tree : -1
# >> G_4: init: 0.77; noise: 1.00; b: 1.77; m: 5.64; expr: 1.00; deg: 0.10; theta: 5.19; asym: 5.00; tree : -4
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 0.99; noise: 0.98; b: 1.68; m: 10.29; expr: 1.00; deg: 0.10; theta: 1.41; asym: 5.00; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.20; deg: 2.70; theta: 5.75; asym: 0.87; tree : ((-4 AND 1) OR 2)
# >> G_2: init: 0.34; noise: 1.00; b: 0.73; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.58; noise: 0.86; b: 2.14; m: 8.32; expr: 1.06; deg: 0.10; theta: 3.10; asym: 5.00; tree : -1
# >> G_4: init: 0.73; noise: 1.00; b: 1.77; m: 5.64; expr: 1.00; deg: 0.11; theta: 6.11; asym: 5.64; tree : -4
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 0.99; noise: 1.00; b: 1.68; m: 10.38; expr: 1.00; deg: 0.10; theta: 1.41; asym: 5.00; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.20; deg: 2.70; theta: 5.74; asym: 0.87; tree : ((-4 AND 1) OR 2)
# >> G_2: init: 0.34; noise: 0.83; b: 0.73; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.58; noise: 0.86; b: 2.14; m: 8.32; expr: 1.06; deg: 0.10; theta: 3.10; asym: 5.00; tree : -0
# >> G_4: init: 0.77; noise: 1.00; b: 1.77; m: 5.64; expr: 0.85; deg: 0.10; theta: 6.11; asym: 5.00; tree : -4
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 0.99; noise: 1.00; b: 1.68; m: 10.38; expr: 1.00; deg: 0.10; theta: 1.41; asym: 5.00; tree : 5
# >> G_1: init: 0.79; noise: 2.15; b: 5.07; m: 7.76; expr: 0.20; deg: 2.70; theta: 5.74; asym: 0.87; tree : ((-4 AND 1) OR 2)
# >> G_2: init: 0.34; noise: 0.83; b: 0.73; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 1.61; noise: 9.11; b: 7.66; m: 7.59; expr: 1.85; deg: 1.12; theta: 5.62; asym: 6.55; tree : 3
# >> G_4: init: 0.77; noise: 1.00; b: 1.77; m: 5.64; expr: 0.85; deg: 0.10; theta: 6.11; asym: 5.00; tree : (-4 AND -5)
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.04; noise: 1.00; b: 1.97; m: 10.29; expr: 1.00; deg: 0.10; theta: 1.41; asym: 5.00; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.20; deg: 2.70; theta: 5.75; asym: 0.87; tree : (1 OR 4)
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.56; noise: 0.78; b: 2.14; m: 7.01; expr: 1.11; deg: 0.10; theta: 3.10; asym: 5.00; tree : -5
# >> G_4: init: 0.77; noise: 1.10; b: 1.77; m: 4.66; expr: 1.00; deg: 0.11; theta: 6.11; asym: 5.00; tree : (0 AND 5)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.16; noise: 1.00; b: 1.97; m: 10.29; expr: 1.00; deg: 0.10; theta: 1.41; asym: 5.00; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.20; deg: 2.70; theta: 5.75; asym: 0.87; tree : (1 OR 4)
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.56; noise: 0.78; b: 2.14; m: 7.01; expr: 1.11; deg: 0.10; theta: 3.10; asym: 5.00; tree : -5
# >> G_4: init: 0.72; noise: 1.10; b: 1.77; m: 4.66; expr: 1.00; deg: 0.11; theta: 6.11; asym: 5.00; tree : (0 AND 5)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 0.99; noise: 1.00; b: 1.99; m: 11.77; expr: 1.00; deg: 0.11; theta: 1.41; asym: 5.00; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.20; deg: 2.70; theta: 5.74; asym: 0.83; tree : ((1 OR 4) OR 0)
# >> G_2: init: 0.34; noise: 1.00; b: 0.80; m: 2.09; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.58; noise: 1.02; b: 2.14; m: 6.89; expr: 1.06; deg: 0.10; theta: 2.99; asym: 5.00; tree : (-3 AND 2)
# >> G_4: init: 0.77; noise: 1.00; b: 1.77; m: 6.58; expr: 0.85; deg: 0.12; theta: 6.11; asym: 5.00; tree : -4
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 0.86; noise: 1.08; b: 1.97; m: 10.29; expr: 1.00; deg: 0.10; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : (1 OR 4)
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.56; noise: 0.78; b: 2.14; m: 7.01; expr: 1.11; deg: 0.10; theta: 3.10; asym: 5.00; tree : -5
# >> G_4: init: 0.73; noise: 1.26; b: 1.77; m: 4.66; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.00; tree : (0 AND 5)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 0.86; noise: 1.08; b: 2.06; m: 10.29; expr: 1.00; deg: 0.10; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : 1
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.56; noise: 0.69; b: 2.14; m: 5.87; expr: 1.11; deg: 0.10; theta: 3.10; asym: 5.00; tree : -5
# >> G_4: init: 0.73; noise: 1.26; b: 1.77; m: 4.66; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.00; tree : (0 AND 5)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 0.86; noise: 1.08; b: 2.06; m: 10.29; expr: 1.00; deg: 0.10; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : 1
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.56; noise: 0.69; b: 2.14; m: 5.87; expr: 1.11; deg: 0.10; theta: 3.10; asym: 5.62; tree : -5
# >> G_4: init: 0.73; noise: 1.29; b: 1.78; m: 4.66; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.00; tree : (0 AND (5 OR -3))
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 0.99; noise: 1.00; b: 1.99; m: 11.77; expr: 1.00; deg: 0.11; theta: 1.41; asym: 5.00; tree : (5 OR 2)
# >> G_1: init: 0.74; noise: 2.35; b: 5.07; m: 7.76; expr: 0.20; deg: 2.70; theta: 5.74; asym: 0.83; tree : ((1 AND 3) OR 4)
# >> G_2: init: 0.34; noise: 0.85; b: 0.80; m: 2.09; expr: 1.00; deg: 0.10; theta: 7.06; asym: 4.93; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 1.14; noise: 2.44; b: 8.59; m: 8.47; expr: 1.55; deg: 1.48; theta: 1.42; asym: 3.51; tree : (-4 AND (-1 AND -0))
# >> G_4: init: 0.92; noise: 1.00; b: 1.77; m: 6.58; expr: 0.95; deg: 0.12; theta: 6.11; asym: 5.00; tree : (-5 AND -1)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 0.86; noise: 1.08; b: 2.06; m: 10.29; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : 1
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.56; noise: 4.98; b: 7.66; m: 2.85; expr: 1.95; deg: 1.30; theta: 7.29; asym: 6.94; tree : ((2 AND 4) AND -1)
# >> G_4: init: 0.73; noise: 1.26; b: 1.77; m: 4.66; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.76; tree : (0 AND 5)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 0.86; noise: 1.08; b: 2.06; m: 10.29; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.74; noise: 2.15; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.72; tree : 1
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.53; noise: 4.98; b: 7.66; m: 2.85; expr: 1.97; deg: 1.23; theta: 7.29; asym: 6.94; tree : ((2 AND 4) AND -1)
# >> G_4: init: 0.73; noise: 1.26; b: 1.77; m: 4.66; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.94; tree : (0 AND 2)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 0.86; noise: 1.08; b: 2.06; m: 8.43; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.74; noise: 2.22; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : (1 AND 2)
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.55; noise: 5.45; b: 8.65; m: 2.85; expr: 1.97; deg: 1.23; theta: 7.29; asym: 6.94; tree : ((2 AND 4) AND -1)
# >> G_4: init: 0.73; noise: 1.26; b: 1.77; m: 4.66; expr: 1.05; deg: 0.09; theta: 6.11; asym: 5.76; tree : (0 AND (5 OR 4))
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 0.83; noise: 1.08; b: 2.06; m: 10.94; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.74; noise: 2.05; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : 1
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.55; noise: 5.45; b: 8.65; m: 2.85; expr: 1.97; deg: 1.23; theta: 7.29; asym: 6.94; tree : ((2 AND -3) AND -1)
# >> G_4: init: 0.73; noise: 1.30; b: 1.77; m: 4.66; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.76; tree : (0 AND (5 OR 4))
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 0.83; noise: 0.92; b: 2.06; m: 10.94; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.74; noise: 2.05; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : 1
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.55; noise: 5.45; b: 8.65; m: 2.85; expr: 1.97; deg: 1.23; theta: 7.27; asym: 6.58; tree : ((2 AND -3) AND -0)
# >> G_4: init: 0.73; noise: 1.30; b: 1.77; m: 4.66; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.76; tree : (0 AND (5 OR 4))
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 0.83; noise: 0.92; b: 2.06; m: 10.94; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.86; noise: 2.05; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : 1
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.55; noise: 5.45; b: 8.34; m: 2.85; expr: 1.97; deg: 1.23; theta: 7.27; asym: 6.58; tree : ((2 AND -3) AND -0)
# >> G_4: init: 0.73; noise: 1.30; b: 1.77; m: 4.66; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.76; tree : (0 AND (5 OR 4))
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 0.83; noise: 1.08; b: 2.06; m: 10.94; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.88; noise: 2.39; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : (1 AND 2)
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.55; noise: 5.45; b: 8.65; m: 2.69; expr: 1.97; deg: 1.23; theta: 7.29; asym: 6.94; tree : ((2 AND -3) AND -1)
# >> G_4: init: 0.73; noise: 1.30; b: 1.77; m: 4.64; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.76; tree : (0 AND 5)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 0.83; noise: 1.08; b: 2.22; m: 10.94; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.88; noise: 2.39; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : (1 AND 2)
# >> G_2: init: 0.34; noise: 1.00; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR -2)
# >> G_3: init: 0.55; noise: 5.45; b: 8.65; m: 2.69; expr: 1.97; deg: 1.23; theta: 7.29; asym: 6.94; tree : ((2 AND -3) AND -1)
# >> G_4: init: 0.62; noise: 1.30; b: 1.77; m: 4.64; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.76; tree : (0 AND (5 OR 4))
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 0.83; noise: 0.92; b: 2.06; m: 10.94; expr: 1.00; deg: 0.11; theta: 1.16; asym: 5.26; tree : 5
# >> G_1: init: 0.86; noise: 2.05; b: 5.07; m: 7.76; expr: 0.21; deg: 2.70; theta: 5.75; asym: 0.87; tree : 1
# >> G_2: init: 0.34; noise: 1.08; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.06; asym: 5.00; tree : (-1 OR -2)
# >> G_3: init: 0.55; noise: 5.45; b: 8.34; m: 2.87; expr: 1.97; deg: 1.23; theta: 7.27; asym: 6.58; tree : (2 AND -3)
# >> G_4: init: 0.73; noise: 1.30; b: 1.77; m: 4.66; expr: 1.05; deg: 0.11; theta: 6.11; asym: 5.40; tree : (0 AND (5 OR 4))
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 0.90; noise: 0.92; b: 2.06; m: 10.94; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.86; noise: 2.05; b: 5.07; m: 7.76; expr: 0.21; deg: 2.78; theta: 5.75; asym: 0.87; tree : 1
# >> G_2: init: 0.34; noise: 1.15; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.14; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.55; noise: 5.45; b: 8.34; m: 3.04; expr: 1.97; deg: 1.47; theta: 7.27; asym: 6.58; tree : 2
# >> G_4: init: 0.82; noise: 1.43; b: 1.77; m: 4.66; expr: 1.15; deg: 0.11; theta: 5.84; asym: 5.40; tree : (0 AND (-2 OR -3))
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 0.90; noise: 0.92; b: 2.06; m: 10.94; expr: 1.00; deg: 0.11; theta: 1.16; asym: 4.72; tree : 5
# >> G_1: init: 0.86; noise: 2.05; b: 5.07; m: 7.76; expr: 0.21; deg: 2.78; theta: 5.75; asym: 0.87; tree : 1
# >> G_2: init: 0.34; noise: 1.15; b: 0.74; m: 2.02; expr: 1.00; deg: 0.10; theta: 7.14; asym: 5.00; tree : (-1 OR (-4 OR -2))
# >> G_3: init: 0.55; noise: 5.45; b: 8.34; m: 3.04; expr: 1.97; deg: 1.47; theta: 7.27; asym: 6.58; tree : 2
# >> G_4: init: 0.82; noise: 1.43; b: 1.77; m: 4.66; expr: 1.05; deg: 0.11; theta: 5.84; asym: 5.40; tree : (0 AND (-2 OR -3))
