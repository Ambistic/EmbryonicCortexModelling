# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve_2, show_curve_progenitor
from jf.models.stringmodel import read_model

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**1.2))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=66, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 100
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r12"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r12
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 1009.8742674679168 for generation 0
# [out] ++ Best 1028.2628071811534 for generation 1
# Step 3 passed !
# [out] ++ Best 1054.1423819745241 for generation 20
# [out] ++ Best 1080.2749780457932 for generation 33
# Saving ...
# [out] ++ Best 1102.2749780457932 for generation 51
# [out] ++ Best 1120.230663071776 for generation 67
# [out] ++ Best 1166.2749780457932 for generation 68
# [out] ++ Best 1187.1423819745241 for generation 70
# [out] ++ Best 1231.2863905196475 for generation 77
# Saving ...
# [out] Step 100
# Saving ...
# Saving ...
# [out] Step 200
# Saving ...
# Saving ...
# [out] Step 300
# [out] ++ Best 1266.3049978713964 for generation 304
# Saving ...
# Saving ...
# [out] Step 400
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# [out] ++ Best 1280.7623205809743 for generation 696
# Saving ...
# [out] Step 700
# Saving ...
# Saving ...
# [out] Step 800
# Saving ...
# Saving ...
# [out] Step 900
# [out] ++ Best 1296.7623205809743 for generation 937
# Saving ...
# Saving ...
# [out] Step 1000
# [out] ++ Best 1305.176783802322 for generation 1009
# Saving ...
# [out] ++ Best 1321.3487430509251 for generation 1095
# Saving ...
# [out] Step 1100
# [out] ++ Best 1323.7282830884526 for generation 1107
# [out] ++ Best 1358.8181252684262 for generation 1111
# Saving ...
# Saving ...
# [out] Step 1200
# [out] ++ Best 1362.0402140868505 for generation 1226
# Saving ...
# [out] ++ Best 1366.6576884804706 for generation 1273
# Saving ...
# [out] Step 1300
# [out] ++ Best 1380.9400616972382 for generation 1332
# Saving ...
# [out] ++ Best 1412.4757578855506 for generation 1397
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# [out] ++ Best 1420.2825852003439 for generation 1501
# [out] ++ Best 1465.2054447128608 for generation 1525
# Saving ...
# Saving ...
# [out] Step 1600
# [out] ++ Best 1512.0 for generation 1613
# Saving ...
# [out] ++ Best 1534.1307373338182 for generation 1662
# [out] ++ Best 1554.283789601148 for generation 1672
# [out] ++ Best 1593.212877416078 for generation 1677
# Saving ...
# [out] Step 1700
# [out] ++ Best 1657.8907099650207 for generation 1708
# [out] ++ Best 1697.4629865464992 for generation 1709
# [out] ++ Best 1702.7361855513436 for generation 1724
# Saving ...
# [out] ++ Best 1869.4879894470703 for generation 1759
# Saving ...
# [out] Step 1800
# [out] ++ Best 1971.292444640357 for generation 1823
# [out] ++ Best 1976.0345032311977 for generation 1845
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# [out] ++ Best 2014.621413090467 for generation 2298
# Saving ...
# [out] Step 2300
# [out] ++ Best 2029.348743050925 for generation 2309
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...
# [out] Step 2500
# [out] ++ Best 2049.8267996219874 for generation 2547
# Saving ...
# [out] ++ Best 2065.396687653013 for generation 2569
# Saving ...
# [out] Step 2600
# Saving ...
# Saving ...
# [out] Step 2700
# Saving ...
# [out] ++ Best 2081.4444617558643 for generation 2765
# Saving ...
# [out] Step 2800
# [out] ++ Best 2115.7708360905026 for generation 2824
# Saving ...
# Saving ...
# [out] Step 2900
# Saving ...
# Saving ...
# [out] Step 3000
# Saving ...
# Saving ...
# [out] Step 3100
# Saving ...
# Saving ...
# [out] Step 3200
# [out] ++ Best 2119.820090562971 for generation 3220
# Saving ...
# Saving ...
# [out] Step 3300
# Saving ...
# Saving ...
# [out] Step 3400
# Saving ...
# Saving ...
# [out] Step 3500
# Saving ...
# Saving ...
# [out] Step 3600
# Saving ...
# Saving ...
# [out] Step 3700
# Saving ...
# Saving ...
# [out] Step 3800
# Saving ...
# Saving ...
# [out] Step 3900
# Saving ...
# Saving ...
# [out] Step 4000
# Saving ...
# Saving ...
# [out] Step 4100
# Saving ...
# Saving ...
# [out] Step 4200
# Saving ...
# Saving ...
# [out] Step 4300
# Saving ...
# Saving ...
# [out] Step 4400
# Saving ...
# Saving ...
# [out] Step 4500
# Saving ...
# Saving ...
# [out] Step 4600
# Saving ...
# Saving ...
# [out] Step 4700
# Saving ...
# Saving ...
# [out] Step 4800
# Saving ...
# Saving ...
# [out] Step 4900
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r12

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
show_curve_2(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 4.57; asym: 5.00; tree : ((1 OR 4) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 6.14; asym: 5.00; tree : -3
# >> G_2: init: 2.24; noise: 0.34; b: 0.40; m: 9.22; expr: 1.00; deg: 0.10; theta: 0.92; asym: 5.00; tree : ((3 OR -4) OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.05; asym: 5.00; tree : 2
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 5.32; asym: 4.21; tree : (2 AND (3 OR -0))
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 5.02; asym: 5.00; tree : ((1 OR 4) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 6.14; asym: 5.00; tree : -3
# >> G_2: init: 2.24; noise: 0.34; b: 0.40; m: 9.22; expr: 1.00; deg: 0.10; theta: 0.99; asym: 5.00; tree : ((3 OR -4) OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.05; asym: 4.03; tree : (2 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 5.32; asym: 4.21; tree : (2 AND (3 OR -0))
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 5.18; asym: 5.00; tree : (1 OR 4)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 6.14; asym: 5.00; tree : -3
# >> G_2: init: 2.24; noise: 0.34; b: 0.40; m: 9.22; expr: 1.00; deg: 0.10; theta: 0.99; asym: 5.00; tree : ((3 OR -4) OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.07; asym: 4.03; tree : (2 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 5.32; asym: 4.21; tree : (2 AND 3)
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 4.81; asym: 5.00; tree : (1 OR 4)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 6.14; asym: 5.00; tree : -3
# >> G_2: init: 2.24; noise: 0.34; b: 0.40; m: 9.22; expr: 1.00; deg: 0.10; theta: 0.94; asym: 5.00; tree : ((3 OR -4) OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.07; asym: 4.03; tree : (2 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 5.32; asym: 4.21; tree : (2 AND 3)
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 6.03; asym: 5.00; tree : (1 OR 4)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : -3
# >> G_2: init: 2.24; noise: 0.34; b: 0.40; m: 9.22; expr: 1.00; deg: 0.10; theta: 0.80; asym: 4.25; tree : ((3 OR -4) OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.07; asym: 4.03; tree : (2 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 5.32; asym: 4.21; tree : (2 OR 0)
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 5.80; asym: 5.00; tree : (1 OR 4)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 6.51; asym: 5.00; tree : -3
# >> G_2: init: 2.24; noise: 0.34; b: 0.40; m: 9.22; expr: 1.00; deg: 0.10; theta: 0.91; asym: 4.09; tree : ((3 OR 1) OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.07; asym: 4.03; tree : (2 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 5.99; asym: 4.21; tree : 3
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 4.81; asym: 4.07; tree : (1 OR (4 OR -5))
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.93; asym: 5.00; tree : -3
# >> G_2: init: 0.90; noise: 8.79; b: 5.62; m: 8.33; expr: 4.49; deg: 2.21; theta: 6.69; asym: 3.41; tree : (5 AND 0)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.07; asym: 3.34; tree : (2 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 5.45; asym: 3.57; tree : (2 AND 3)
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 5.24; asym: 5.00; tree : (1 OR 0)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 6.51; asym: 5.00; tree : -3
# >> G_2: init: 2.24; noise: 0.34; b: 0.40; m: 9.22; expr: 1.00; deg: 0.10; theta: 1.18; asym: 3.40; tree : ((3 OR 1) OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.07; asym: 4.03; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 5.99; asym: 4.21; tree : (3 OR -1)
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 5.24; asym: 5.00; tree : (1 OR 0)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 6.51; asym: 5.00; tree : -3
# >> G_2: init: 1.45; noise: 2.20; b: 1.46; m: 5.93; expr: 2.23; deg: 2.67; theta: 3.65; asym: 8.99; tree : ((-4 AND -2) OR 1)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.07; asym: 2.88; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 7.90; asym: 3.50; tree : (3 OR -1)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 5.24; asym: 5.00; tree : ((1 OR 0) OR -4)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 6.51; asym: 5.00; tree : -3
# >> G_2: init: 1.45; noise: 2.20; b: 1.46; m: 5.93; expr: 2.23; deg: 2.67; theta: 3.65; asym: 8.99; tree : ((-4 AND -2) OR 1)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.07; asym: 2.88; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 7.90; asym: 2.94; tree : (3 OR -1)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 5.41; asym: 5.00; tree : (1 OR 2)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.97; asym: 5.00; tree : -3
# >> G_2: init: 1.45; noise: 2.20; b: 1.46; m: 5.93; expr: 2.23; deg: 2.67; theta: 3.81; asym: 8.99; tree : (-4 OR 1)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.07; asym: 2.88; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.31; asym: 3.50; tree : (3 OR -1)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 5.98; asym: 5.00; tree : (5 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.97; asym: 5.00; tree : -3
# >> G_2: init: 1.45; noise: 2.20; b: 1.46; m: 5.93; expr: 2.23; deg: 2.67; theta: 3.83; asym: 8.99; tree : 5
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.12; asym: 2.88; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 7.90; asym: 3.50; tree : (3 OR -1)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 5.93; asym: 5.00; tree : (5 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.97; asym: 5.00; tree : -3
# >> G_2: init: 1.45; noise: 2.20; b: 1.46; m: 5.93; expr: 2.23; deg: 2.67; theta: 3.92; asym: 8.99; tree : (-4 OR 1)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.12; asym: 2.88; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.31; asym: 3.50; tree : (3 OR 5)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 6.65; asym: 5.00; tree : (5 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.97; asym: 5.00; tree : -3
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.40; asym: 9.18; tree : 2
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.14; asym: 2.88; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.64; asym: 2.84; tree : ((3 OR 4) OR 5)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 6.01; asym: 5.00; tree : (5 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.97; asym: 4.25; tree : -3
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.46; asym: 9.18; tree : -3
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.14; asym: 2.40; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 7.98; asym: 2.84; tree : (3 OR 5)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 6.01; asym: 5.00; tree : (-2 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.97; asym: 4.25; tree : -3
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.42; asym: 9.18; tree : -3
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.14; asym: 2.88; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 7.98; asym: 2.84; tree : (3 OR 5)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 7.05; asym: 5.00; tree : (5 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.26; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.37; asym: 8.00; tree : -3
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.14; asym: 2.88; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 7.40; asym: 2.84; tree : (3 OR 5)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 7.18; asym: 5.00; tree : (5 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.71; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.37; asym: 8.00; tree : -3
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.14; asym: 2.88; tree : (-1 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.62; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 6.96; asym: 5.00; tree : (5 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.37; asym: 8.00; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.13; asym: 2.88; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.80; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 6.78; asym: 5.00; tree : (5 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.36; asym: 8.00; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.13; asym: 2.88; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.80; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 7.64; asym: 4.37; tree : (5 OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.71; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.41; asym: 8.00; tree : (3 OR -2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.17; asym: 2.48; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.53; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 6.38; asym: 5.00; tree : ((5 OR 3) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.38; asym: 8.00; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.13; asym: 1.99; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.80; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 6.56; asym: 5.00; tree : ((5 OR 3) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.33; asym: 6.69; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.13; asym: 1.99; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.17; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 6.38; asym: 5.00; tree : ((5 OR 3) OR -2)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.71; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.38; asym: 8.00; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.13; asym: 1.99; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.52; asym: 2.35; tree : 0
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 8.26; asym: 5.00; tree : ((5 OR 3) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.33; asym: 4.68; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.16; asym: 1.99; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.80; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 8.26; asym: 5.00; tree : ((5 OR 3) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.33; asym: 4.68; tree : -2
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.16; asym: 1.99; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.80; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g26 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 8.26; asym: 5.00; tree : ((5 OR 3) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.84; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.33; asym: 4.01; tree : -2
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.16; asym: 1.99; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.80; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g27 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 8.30; asym: 4.25; tree : ((0 OR 3) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.34; asym: 6.69; tree : ((-4 OR 2) OR -1)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.16; asym: 1.73; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.13; asym: 2.35; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g28 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 9.31; asym: 4.04; tree : (-2 OR -5)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.30; asym: 4.07; tree : -2
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.16; asym: 1.62; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.95; asym: 2.35; tree : (3 OR 0)
#
# ======= GENERATION generation_g29 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 9.69; asym: 4.25; tree : ((-2 OR 3) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.34; asym: 6.69; tree : (-4 OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.16; asym: 1.73; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.05; asym: 2.35; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g30 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 10.28; asym: 4.25; tree : ((0 OR 3) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.67; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.40; asym: 6.69; tree : (3 OR 5)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.14; asym: 1.42; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.05; asym: 2.03; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g31 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 8.88; asym: 2.93; tree : ((0 OR 3) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.44; asym: 6.69; tree : (-4 OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.18; asym: 1.73; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.14; asym: 2.03; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g32 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 10.42; asym: 2.93; tree : (0 OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.44; asym: 6.69; tree : (-4 OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.18; asym: 1.73; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.14; asym: 2.03; tree : (2 OR 0)
#
# ======= GENERATION generation_g33 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 10.12; asym: 2.93; tree : ((0 OR -4) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.66; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.54; asym: 5.46; tree : -0
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.16; asym: 1.73; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.14; asym: 2.03; tree : ((-4 OR -5) OR 0)
#
# ======= GENERATION generation_g34 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 10.67; asym: 2.40; tree : ((0 OR -4) OR 1)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.66; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.54; asym: 5.46; tree : (-0 OR -4)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.16; asym: 1.73; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.14; asym: 2.03; tree : ((-4 OR -5) OR 0)
#
# ======= GENERATION generation_g35 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 10.91; asym: 2.93; tree : (0 OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.94; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.43; asym: 6.69; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.22; asym: 1.73; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.45; asym: 2.03; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g36 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 8.30; asym: 2.93; tree : (0 OR (3 AND -2))
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.94; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.48; asym: 6.69; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.22; asym: 1.73; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.01; asym: 2.03; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g37 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 11.87; asym: 2.55; tree : (0 OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.98; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.43; asym: 6.69; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.27; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.45; asym: 2.03; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g38 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 11.18; asym: 2.55; tree : (0 OR (3 OR 4))
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 4.97; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.45; asym: 6.69; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.45; asym: 2.03; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g39 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 11.18; asym: 2.55; tree : (0 OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.03; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.45; asym: 6.69; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.89; asym: 2.03; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g40 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 11.35; asym: 2.55; tree : (-2 OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.03; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.45; asym: 5.45; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.89; asym: 2.03; tree : ((2 OR -5) OR 0)
#
# ======= GENERATION generation_g41 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 11.64; asym: 2.55; tree : (0 OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.01; asym: 3.65; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.53; asym: 6.69; tree : -4
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.45; asym: 2.03; tree : (-5 OR 0)
#
# ======= GENERATION generation_g42 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 17.88; asym: 2.12; tree : ((0 OR -5) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.15; asym: 3.70; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.45; asym: 5.64; tree : (-4 OR (-0 OR 3))
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.21; asym: 2.03; tree : (-5 OR 0)
#
# ======= GENERATION generation_g43 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 19.27; asym: 2.12; tree : ((0 OR -5) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.15; asym: 3.03; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.45; asym: 5.64; tree : (-4 OR -0)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.21; asym: 2.03; tree : (-5 OR 0)
#
# ======= GENERATION generation_g44 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 17.88; asym: 2.12; tree : ((0 OR -5) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.09; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.80; asym: 4.92; tree : (-4 OR (-0 OR 3))
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.21; asym: 2.03; tree : ((-5 OR 0) OR -2)
#
# ======= GENERATION generation_g45 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 17.65; asym: 1.50; tree : ((0 OR -5) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.09; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.84; asym: 4.92; tree : 3
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.21; asym: 2.03; tree : ((-5 OR 0) OR -2)
#
# ======= GENERATION generation_g46 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 18.71; asym: 1.81; tree : ((0 OR -5) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.09; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.80; asym: 4.11; tree : (5 OR (-0 OR 2))
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.21; asym: 1.48; tree : ((-5 OR 0) OR -2)
#
# ======= GENERATION generation_g47 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 25.08; asym: 2.12; tree : (-2 OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.09; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.90; asym: 4.92; tree : (-0 OR 2)
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.21; asym: 1.74; tree : (-5 OR -2)
#
# ======= GENERATION generation_g48 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 16.20; asym: 1.53; tree : ((0 OR -5) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.09; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.73; asym: 4.11; tree : (5 OR (-0 OR 1))
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.44; tree : ((-3 AND -5) AND -2)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.80; asym: 1.48; tree : ((-5 OR 0) OR -3)
#
# ======= GENERATION generation_g49 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 26.96; asym: 1.77; tree : ((0 OR -2) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.09; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.90; asym: 4.92; tree : (-0 OR (2 OR 4))
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.20; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 9.21; asym: 1.74; tree : ((-5 AND -3) OR -2)
#
# ======= GENERATION generation_g50 =======
# >> G_0: init: 1.17; noise: 0.16; b: 0.92; m: 2.01; expr: 1.00; deg: 0.10; theta: 29.07; asym: 1.77; tree : ((0 OR -2) OR 3)
# >> G_1: init: 0.97; noise: 0.41; b: 2.92; m: 7.77; expr: 1.00; deg: 0.10; theta: 5.09; asym: 4.25; tree : (-3 AND 1)
# >> G_2: init: 2.02; noise: 2.05; b: 8.78; m: 6.40; expr: 0.51; deg: 0.70; theta: 0.87; asym: 4.92; tree : (-0 OR (2 OR 4))
# >> G_3: init: 0.26; noise: 0.01; b: 1.93; m: 8.79; expr: 1.00; deg: 0.10; theta: 2.23; asym: 1.20; tree : (-3 AND -5)
# >> G_4: init: 0.28; noise: 0.33; b: 0.27; m: 6.47; expr: 1.00; deg: 0.10; theta: 8.62; asym: 1.74; tree : ((-5 AND -3) OR -2)
