# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(7, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 70.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 100 - 1 * delta_late - 0.5 * delta_early)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r24"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r24
# [definition]
#
#
# [reload] Found generation 25
# [out] Step 1300
# [out] ++ Best 86.9785017183708 for generation 1300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e92e49b59e5c> in <module>
#       2 prun.cb_init = callback_init
#       3 prun.name = "check_simple_obj_r24"
# ----> 4 res = main(prun)
#
# <ipython-input-15-b9e59561fcb1> in main(prun)
#      20     for i in range(batch_gen * prun.batch_size,
#      21                    prun.n_gen * prun.batch_size):
# ---> 22         fit, stats = do_fitness(prun, sol)
#      23         sol.fit, sol.stats = fit, stats
#      24
#
# <ipython-input-12-d758d86a391a> in do_fitness(prun, sol)
#       3
#       4 def do_fitness(prun, sol):
# ----> 5     fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
#       6     return fitness, stats
#       7
#
# <ipython-input-11-424afec1b8a4> in fitness_multistep(prun, grn, steps)
#       6     # first step
#       7     for step in steps:
# ----> 8         if not bb.run_until(step.end_time):
#       9             stop = True
#      10
#
# ~/other/EmbryonicCortexModelling/grn/brain.py in run_until(self, time_point)
#     145                 and (self.range[self.current_step] < time_point):
#     146             T = self.range[self.current_step]
# --> 147             if not self._tick(T, self.time_step):
#     148                 self.info("Population exploded or extinguished")
#     149                 return False
#
# ~/other/EmbryonicCortexModelling/grn/brain.py in _tick(self, absolute_time, relative_time)
#     170         # take care of cells
#     171         if self.opti:
# --> 172             self.population.tick_cell_programs_batch(absolute_time, relative_time)
#     173         else:
#     174             self.population.tick_cell_programs(absolute_time, relative_time)
#
# ~/other/EmbryonicCortexModelling/grn/lib/population.py in tick_cell_programs_batch(self, absolute_time, relative_time)
#      70
#      71         # this batch function must be provided by the cell class
# ---> 72         self.cell_cls.batch_tick(cells, absolute_time, relative_time)
#      73
#      74         for C in cells:
#
# ~/other/EmbryonicCortexModelling/grn/submodels/grn_bi_v1.py in batch_tick(cells, absolute_time, relative_time)
#     134         cell_programs = [c.cell_program for c in cells]
#     135         batch = CellBatch(cell_programs)
# --> 136         batch.run_step(relative_time)
#
# ~/other/EmbryonicCortexModelling/grn/lib/sde/cell/cell5.py in run_step(self, ts, base_size, mul)
#     183         for cell_batch in finebatch(self.cells, base_size, mul):
#     184             batch_size = max(base_size, len(cell_batch))
# --> 185             self.run_step_batch(cell_batch, batch_size, ts)
#     186
#     187     def run_step_batch(self, cell_batch, size, ts):
#
# ~/other/EmbryonicCortexModelling/grn/lib/sde/cell/cell5.py in run_step_batch(self, cell_batch, size, ts)
#     205         activations = batch_compute_activation(quantities, self.grn.b, self.grn.theta, self.grn.m)
#     206         full_activations = batch_concatenate(activations, environments)
# --> 207         expressions = batch_compute_expression(self.grn.genes, full_activations)
#     208         derivatives = batch_compute_derivatives(expressions, quantities, self.grn.expr, self.grn.deg)
#     209         quantities = batch_compute_quantities(quantities, derivatives, self.grn.noise, ts, self.get_random_key())
#
# ~/other/EmbryonicCortexModelling/grn/lib/sde/cell/cell5.py in batch_compute_expression(genes, activations)
#     119 def batch_compute_expression(genes, activations):
#     120     gene_funcs = [gene.tree.get_compiled() for gene in genes]
# --> 121     return j_batch_compute_expressions(gene_funcs, activations)
#     122
#     123
#
# ~/other/EmbryonicCortexModelling/grn/lib/sde/cell/cell5.py in j_batch_compute_expressions(gene_funcs, expressions)
#     130 # @jit
#     131 def j_batch_compute_expressions(gene_funcs, expressions):
# --> 132     return [
#     133         jnp.array([gene_func(expression) for gene_func in gene_funcs])
#     134         for expression in expressions
#
# ~/other/EmbryonicCortexModelling/grn/lib/sde/cell/cell5.py in <listcomp>(.0)
#     131 def j_batch_compute_expressions(gene_funcs, expressions):
#     132     return [
# --> 133         jnp.array([gene_func(expression) for gene_func in gene_funcs])
#     134         for expression in expressions
#     135     ]
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in array(object, dtype, copy, order, ndmin)
#    3658   elif isinstance(object, (list, tuple)):
#    3659     if object:
# -> 3660       out = stack([asarray(elt, dtype=dtype) for elt in object])
#    3661     else:
#    3662       out = np.array([], dtype=dtype)
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in stack(arrays, axis, out)
#    3404       if shape(a) != shape0:
#    3405         raise ValueError("All input arrays must have the same shape.")
# -> 3406       new_arrays.append(expand_dims(a, axis))
#    3407     return concatenate(new_arrays, axis=axis)
#    3408
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in expand_dims(a, axis)
#    1870   if hasattr(a, "expand_dims"):
#    1871     return a.expand_dims(axis)
# -> 1872   return lax.expand_dims(a, axis)
#    1873
#    1874
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/lax/lax.py in expand_dims(array, dimensions)
#    1200     result_shape.insert(i, 1)
#    1201   broadcast_dims = [i for i in range(ndim_out) if i not in dims_set]
# -> 1202   return broadcast_in_dim(array, result_shape, broadcast_dims)
#    1203
#    1204
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/lax/lax.py in broadcast_in_dim(operand, shape, broadcast_dimensions)
#     734     dyn_shape = []
#     735     shape_ = shape  # type: ignore
# --> 736   return broadcast_in_dim_p.bind(
#     737       operand, *dyn_shape, shape=tuple(shape_),
#     738       broadcast_dimensions=tuple(broadcast_dimensions))
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/core.py in bind(self, *args, **params)
#     277     assert (not config.jax_enable_checks or
#     278             all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 279     return self.bind_with_trace(find_top_trace(args), args, params)
#     280
#     281   def bind_with_trace(self, trace, args, params):
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/core.py in bind_with_trace(self, trace, args, params)
#     280
#     281   def bind_with_trace(self, trace, args, params):
# --> 282     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     283     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     284
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/core.py in process_primitive(self, primitive, tracers, params)
#     596
#     597   def process_primitive(self, primitive, tracers, params):
# --> 598     return primitive.impl(*tracers, **params)
#     599
#     600   def process_call(self, primitive, f, tracers, params):
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/dispatch.py in apply_primitive(prim, *args, **params)
#      92   compiled_fun = xla_primitive_callable(prim, *unsafe_map(arg_spec, args),
#      93                                         **params)
# ---> 94   return compiled_fun(*args)
#      95
#      96 # TODO(phawkins): update code referring to xla.apply_primitive to point here.
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/dispatch.py in <lambda>(*args, **kw)
#     112                                     prim.name, donated_invars, *arg_specs)
#     113   if not prim.multiple_results:
# --> 114     return lambda *args, **kw: compiled(*args, **kw)[0]
#     115   else:
#     116     return compiled
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/dispatch.py in _execute_compiled(name, compiled, output_buffer_counts, result_handlers, kept_var_idx, *args)
#     442   input_bufs = util.flatten(
#     443       device_put(x, device) for i, x in enumerate(args) if i in kept_var_idx)
# --> 444   out_bufs = compiled.execute(input_bufs)
#     445   check_special(name, out_bufs)
#     446   if output_buffer_counts is None:
#
# KeyboardInterrupt:

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r24

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
res.fit
# Out:
# 89.25295049141387

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.99; m: 1.71; expr: 1.00; deg: 0.10; theta: 9.97; asym: 5.00; tree : ((0 AND -7) AND (4 OR -5))
# >> G_1: init: 0.10; noise: 1.00; b: 0.23; m: 1.70; expr: 1.00; deg: 0.10; theta: 0.13; asym: 5.00; tree : 2
# >> G_2: init: 0.72; noise: 1.00; b: 1.22; m: 1.13; expr: 1.00; deg: 0.10; theta: 3.43; asym: 5.00; tree : -4
# >> G_3: init: 1.45; noise: 1.00; b: 2.28; m: 9.96; expr: 1.00; deg: 0.10; theta: 6.05; asym: 5.00; tree : 2
# >> G_4: init: 0.18; noise: 1.00; b: 2.19; m: 2.06; expr: 1.00; deg: 0.10; theta: 9.88; asym: 5.00; tree : -5
# >> G_5: init: 0.08; noise: 1.00; b: 0.90; m: 2.77; expr: 1.00; deg: 0.10; theta: 7.78; asym: 5.00; tree : (0 AND -6)
# >> G_6: init: 2.28; noise: 1.00; b: 2.20; m: 3.25; expr: 1.00; deg: 0.10; theta: 1.40; asym: 5.00; tree : ((4 AND -0) OR 3)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.99; m: 1.71; expr: 1.18; deg: 0.10; theta: 9.97; asym: 5.00; tree : ((0 AND -7) AND (4 OR -5))
# >> G_1: init: 0.10; noise: 1.00; b: 0.23; m: 1.70; expr: 0.81; deg: 0.12; theta: 0.13; asym: 5.00; tree : 2
# >> G_2: init: 0.72; noise: 1.00; b: 1.22; m: 1.13; expr: 1.00; deg: 0.10; theta: 3.43; asym: 5.00; tree : -0
# >> G_3: init: 1.45; noise: 1.00; b: 2.28; m: 9.96; expr: 1.00; deg: 0.10; theta: 6.05; asym: 5.00; tree : 2
# >> G_4: init: 0.18; noise: 1.00; b: 2.00; m: 2.06; expr: 1.00; deg: 0.10; theta: 9.88; asym: 5.38; tree : -5
# >> G_5: init: 0.08; noise: 1.00; b: 0.90; m: 2.77; expr: 1.00; deg: 0.10; theta: 7.78; asym: 5.00; tree : (0 AND -6)
# >> G_6: init: 2.28; noise: 1.00; b: 2.20; m: 3.25; expr: 1.00; deg: 0.09; theta: 1.40; asym: 5.00; tree : ((4 AND -0) OR 3)
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.84; noise: 1.00; b: 3.48; m: 4.36; expr: 1.00; deg: 0.10; theta: 4.83; asym: 5.00; tree : -3
# >> G_2: init: 0.79; noise: 1.00; b: 2.66; m: 2.29; expr: 1.00; deg: 0.10; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.00; b: 1.06; m: 6.37; expr: 1.00; deg: 0.10; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.63; m: 7.93; expr: 1.00; deg: 0.10; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR (-0 OR 4))
# >> G_5: init: 2.15; noise: 1.00; b: 2.75; m: 9.02; expr: 1.00; deg: 0.10; theta: 0.30; asym: 5.00; tree : 1
# >> G_6: init: 1.79; noise: 1.00; b: 1.18; m: 4.29; expr: 1.00; deg: 0.10; theta: 7.60; asym: 5.00; tree : 6
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 3.48; m: 4.36; expr: 1.00; deg: 0.10; theta: 4.83; asym: 5.94; tree : -3
# >> G_2: init: 0.79; noise: 1.00; b: 2.66; m: 2.23; expr: 1.00; deg: 0.10; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.00; b: 1.06; m: 6.37; expr: 1.00; deg: 0.10; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.63; m: 7.93; expr: 1.00; deg: 0.10; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 2.56; noise: 1.00; b: 2.75; m: 9.02; expr: 1.00; deg: 0.10; theta: 0.31; asym: 5.00; tree : 1
# >> G_6: init: 1.79; noise: 1.00; b: 1.18; m: 4.29; expr: 1.00; deg: 0.10; theta: 7.60; asym: 5.00; tree : 6
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.00; noise: 1.11; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 3.48; m: 4.36; expr: 1.00; deg: 0.10; theta: 3.90; asym: 5.94; tree : -3
# >> G_2: init: 0.79; noise: 1.00; b: 2.66; m: 2.23; expr: 1.00; deg: 0.10; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.00; b: 1.06; m: 6.37; expr: 1.00; deg: 0.10; theta: 3.94; asym: 4.68; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.63; m: 7.93; expr: 1.00; deg: 0.10; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 2.56; noise: 1.00; b: 2.75; m: 9.02; expr: 1.00; deg: 0.10; theta: 0.31; asym: 5.00; tree : 1
# >> G_6: init: 1.79; noise: 1.00; b: 1.25; m: 4.29; expr: 1.00; deg: 0.10; theta: 7.60; asym: 5.00; tree : 6
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.97; noise: 1.00; b: 3.48; m: 4.36; expr: 1.00; deg: 0.10; theta: 4.83; asym: 5.00; tree : -3
# >> G_2: init: 0.79; noise: 1.00; b: 2.98; m: 2.23; expr: 1.00; deg: 0.10; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.00; b: 1.06; m: 6.37; expr: 1.00; deg: 0.10; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.91; noise: 0.87; b: 2.63; m: 7.93; expr: 1.00; deg: 0.10; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 2.15; noise: 1.00; b: 2.75; m: 9.02; expr: 1.00; deg: 0.10; theta: 0.31; asym: 5.00; tree : 1
# >> G_6: init: 1.79; noise: 1.00; b: 1.20; m: 4.29; expr: 1.00; deg: 0.10; theta: 7.60; asym: 4.97; tree : 6
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.00; noise: 1.11; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 3.48; m: 4.36; expr: 1.00; deg: 0.10; theta: 3.90; asym: 5.94; tree : -3
# >> G_2: init: 0.79; noise: 1.00; b: 2.74; m: 2.23; expr: 1.00; deg: 0.10; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.13; b: 1.06; m: 6.37; expr: 1.00; deg: 0.10; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.63; m: 7.93; expr: 1.00; deg: 0.10; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 2.56; noise: 0.86; b: 2.27; m: 9.02; expr: 1.00; deg: 0.10; theta: 0.31; asym: 5.00; tree : 1
# >> G_6: init: 1.97; noise: 1.00; b: 1.18; m: 4.29; expr: 1.00; deg: 0.10; theta: 7.60; asym: 5.00; tree : 6
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.32; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.97; noise: 0.90; b: 3.48; m: 4.41; expr: 1.00; deg: 0.10; theta: 4.83; asym: 5.00; tree : -3
# >> G_2: init: 0.79; noise: 1.00; b: 2.98; m: 2.74; expr: 0.97; deg: 0.10; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.00; b: 1.06; m: 6.37; expr: 1.00; deg: 0.09; theta: 3.94; asym: 5.00; tree : -2
# >> G_4: init: 1.91; noise: 0.87; b: 2.63; m: 7.93; expr: 1.00; deg: 0.10; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 2.15; noise: 1.00; b: 2.75; m: 10.48; expr: 1.00; deg: 0.10; theta: 0.31; asym: 5.97; tree : 1
# >> G_6: init: 2.00; noise: 1.00; b: 0.95; m: 4.29; expr: 1.00; deg: 0.10; theta: 7.60; asym: 4.97; tree : 6
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.00; noise: 1.11; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.46; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 3.48; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.94; tree : (-3 OR 5)
# >> G_2: init: 0.79; noise: 1.00; b: 2.66; m: 2.23; expr: 1.00; deg: 0.10; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.14; b: 1.06; m: 6.37; expr: 1.00; deg: 0.09; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.63; m: 7.93; expr: 0.97; deg: 0.11; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 2.56; noise: 0.86; b: 2.33; m: 8.55; expr: 1.00; deg: 0.10; theta: 0.31; asym: 5.00; tree : 1
# >> G_6: init: 1.79; noise: 0.99; b: 1.04; m: 4.29; expr: 1.00; deg: 0.10; theta: 7.60; asym: 5.00; tree : 6
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.00; noise: 1.11; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 2.84; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.77; asym: 5.94; tree : -3
# >> G_2: init: 2.30; noise: 0.27; b: 6.97; m: 8.40; expr: 0.33; deg: 2.02; theta: 8.79; asym: 5.93; tree : 0
# >> G_3: init: 0.95; noise: 1.13; b: 1.06; m: 6.37; expr: 1.00; deg: 0.09; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 7.93; expr: 1.07; deg: 0.10; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 2.56; noise: 0.91; b: 2.33; m: 9.45; expr: 1.12; deg: 0.10; theta: 0.31; asym: 5.00; tree : 1
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.29; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.00; noise: 0.95; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 3.48; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.94; tree : -3
# >> G_2: init: 0.79; noise: 1.00; b: 2.97; m: 2.23; expr: 1.00; deg: 0.10; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 6.37; expr: 1.00; deg: 0.09; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.58; noise: 1.00; b: 2.93; m: 7.93; expr: 1.10; deg: 0.13; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 2.56; noise: 0.79; b: 2.33; m: 9.45; expr: 1.12; deg: 0.10; theta: 0.31; asym: 5.00; tree : 1
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.29; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.00; noise: 1.11; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 3.01; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.94; tree : -3
# >> G_2: init: 0.79; noise: 1.00; b: 2.97; m: 2.23; expr: 1.00; deg: 0.12; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 6.37; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 7.93; expr: 1.10; deg: 0.12; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.79; b: 2.33; m: 9.89; expr: 1.12; deg: 0.11; theta: 0.31; asym: 5.00; tree : -4
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.29; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.00; noise: 1.11; b: 1.36; m: 8.70; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.00; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 3.48; m: 3.97; expr: 1.00; deg: 0.11; theta: 4.39; asym: 5.94; tree : -3
# >> G_2: init: 0.79; noise: 1.00; b: 2.97; m: 2.32; expr: 1.00; deg: 0.10; theta: 4.05; asym: 5.00; tree : 5
# >> G_3: init: 0.95; noise: 1.35; b: 1.06; m: 7.38; expr: 1.00; deg: 0.09; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 6.87; expr: 1.10; deg: 0.12; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 1.67; noise: 3.85; b: 7.06; m: 4.18; expr: 0.73; deg: 0.77; theta: 0.82; asym: 4.21; tree : 3
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.39; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.00; noise: 1.11; b: 1.36; m: 8.80; expr: 1.00; deg: 0.10; theta: 2.66; asym: 4.27; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 3.35; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.39; asym: 5.07; tree : -3
# >> G_2: init: 2.56; noise: 8.00; b: 5.48; m: 9.06; expr: 2.71; deg: 2.37; theta: 8.15; asym: 2.34; tree : (4 OR (2 AND -1))
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 8.59; expr: 1.10; deg: 0.12; theta: 4.56; asym: 5.00; tree : ((-2 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.79; b: 2.33; m: 9.89; expr: 1.12; deg: 0.11; theta: 0.31; asym: 5.00; tree : -4
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 0.98; deg: 0.10; theta: 7.60; asym: 4.69; tree : (6 OR -2)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.80; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.82; noise: 1.00; b: 3.35; m: 3.97; expr: 1.00; deg: 0.10; theta: 3.61; asym: 5.07; tree : -3
# >> G_2: init: 2.56; noise: 6.55; b: 5.48; m: 9.06; expr: 2.71; deg: 2.37; theta: 8.15; asym: 2.34; tree : (4 OR (2 AND -1))
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 7.30; expr: 1.10; deg: 0.12; theta: 4.56; asym: 5.00; tree : ((5 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.33; m: 9.89; expr: 1.12; deg: 0.11; theta: 0.31; asym: 4.25; tree : -4
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.80; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.76; noise: 1.00; b: 3.35; m: 3.97; expr: 1.00; deg: 0.11; theta: 3.61; asym: 5.07; tree : -3
# >> G_2: init: 2.56; noise: 6.55; b: 5.48; m: 9.06; expr: 2.71; deg: 2.37; theta: 8.15; asym: 2.34; tree : (4 OR (2 AND -1))
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 0.88; b: 2.93; m: 7.30; expr: 1.10; deg: 0.12; theta: 4.56; asym: 5.00; tree : ((5 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.33; m: 9.89; expr: 1.12; deg: 0.10; theta: 0.31; asym: 4.25; tree : -4
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.80; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.79; noise: 1.00; b: 3.35; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.01; asym: 5.07; tree : -3
# >> G_2: init: 2.43; noise: 6.55; b: 5.48; m: 8.31; expr: 2.71; deg: 2.37; theta: 8.15; asym: 2.34; tree : (4 OR (2 AND -1))
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 7.30; expr: 1.10; deg: 0.12; theta: 4.56; asym: 4.05; tree : ((5 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.33; m: 9.89; expr: 1.12; deg: 0.10; theta: 0.31; asym: 4.25; tree : -4
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.05; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.79; noise: 1.00; b: 3.35; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.01; asym: 5.92; tree : -3
# >> G_2: init: 2.43; noise: 6.55; b: 5.48; m: 8.31; expr: 2.71; deg: 2.63; theta: 8.15; asym: 2.34; tree : (4 OR -1)
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 7.30; expr: 1.10; deg: 0.12; theta: 4.56; asym: 4.05; tree : ((5 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.33; m: 9.89; expr: 1.12; deg: 0.10; theta: 0.31; asym: 4.23; tree : -4
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.05; expr: 1.00; deg: 0.08; theta: 2.66; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.79; noise: 1.00; b: 3.35; m: 3.97; expr: 1.00; deg: 0.10; theta: 3.43; asym: 5.92; tree : -3
# >> G_2: init: 2.43; noise: 6.55; b: 5.48; m: 8.31; expr: 2.71; deg: 2.63; theta: 8.95; asym: 2.34; tree : (4 OR -1)
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 7.30; expr: 1.10; deg: 0.12; theta: 4.56; asym: 4.05; tree : ((5 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.33; m: 9.89; expr: 1.12; deg: 0.10; theta: 0.31; asym: 4.23; tree : 5
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.05; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.79; noise: 1.00; b: 3.35; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.01; asym: 5.92; tree : -3
# >> G_2: init: 2.43; noise: 6.55; b: 5.48; m: 7.28; expr: 2.71; deg: 2.63; theta: 8.15; asym: 2.34; tree : (4 OR (-7 AND -3))
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 6.42; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 7.30; expr: 1.10; deg: 0.12; theta: 4.56; asym: 3.55; tree : ((5 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.33; m: 9.89; expr: 1.12; deg: 0.11; theta: 0.31; asym: 4.23; tree : -4
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 0.98; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR 5)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.05; expr: 1.00; deg: 0.10; theta: 2.66; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.79; noise: 1.00; b: 3.35; m: 3.97; expr: 0.93; deg: 0.10; theta: 3.59; asym: 5.91; tree : -3
# >> G_2: init: 2.43; noise: 6.55; b: 5.48; m: 8.31; expr: 2.71; deg: 2.63; theta: 9.78; asym: 2.34; tree : (4 OR (-1 AND 5))
# >> G_3: init: 0.95; noise: 1.15; b: 1.06; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 2.01; noise: 1.00; b: 2.93; m: 7.30; expr: 1.10; deg: 0.12; theta: 4.56; asym: 4.05; tree : ((5 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.33; m: 9.89; expr: 1.12; deg: 0.10; theta: 0.31; asym: 4.23; tree : 5
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 1.05; deg: 0.10; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.46; expr: 1.00; deg: 0.11; theta: 2.66; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.79; noise: 1.11; b: 3.40; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.01; asym: 5.07; tree : -3
# >> G_2: init: 2.29; noise: 5.93; b: 5.48; m: 8.31; expr: 2.30; deg: 2.63; theta: 8.15; asym: 2.34; tree : (-3 OR 2)
# >> G_3: init: 0.95; noise: 1.15; b: 0.93; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 4.64; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 5.86; expr: 1.10; deg: 0.12; theta: 4.56; asym: 4.05; tree : ((5 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.33; m: 9.89; expr: 1.09; deg: 0.10; theta: 0.30; asym: 4.23; tree : (-4 OR 1)
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 0.98; deg: 0.11; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.46; expr: 1.00; deg: 0.10; theta: 2.64; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.79; noise: 1.24; b: 3.35; m: 3.30; expr: 1.00; deg: 0.10; theta: 4.01; asym: 5.07; tree : -3
# >> G_2: init: 2.29; noise: 5.93; b: 5.48; m: 8.31; expr: 2.30; deg: 2.63; theta: 8.15; asym: 2.34; tree : (-3 OR 2)
# >> G_3: init: 0.95; noise: 1.15; b: 0.93; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 5.00; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 5.86; expr: 1.10; deg: 0.12; theta: 4.56; asym: 4.05; tree : ((5 AND 3) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.33; m: 11.85; expr: 1.09; deg: 0.10; theta: 0.30; asym: 5.04; tree : -4
# >> G_6: init: 1.79; noise: 1.00; b: 1.04; m: 4.36; expr: 0.98; deg: 0.11; theta: 7.60; asym: 5.54; tree : (6 OR -2)
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.00; noise: 1.05; b: 1.36; m: 8.46; expr: 1.00; deg: 0.11; theta: 2.66; asym: 5.65; tree : (6 AND -4)
# >> G_1: init: 0.79; noise: 1.11; b: 3.40; m: 3.97; expr: 1.00; deg: 0.10; theta: 4.01; asym: 5.07; tree : -3
# >> G_2: init: 2.29; noise: 5.69; b: 5.48; m: 8.31; expr: 2.30; deg: 2.63; theta: 8.15; asym: 2.34; tree : 2
# >> G_3: init: 0.95; noise: 1.15; b: 0.93; m: 5.99; expr: 1.00; deg: 0.11; theta: 3.94; asym: 4.64; tree : -0
# >> G_4: init: 1.79; noise: 1.00; b: 2.93; m: 5.86; expr: 1.10; deg: 0.12; theta: 4.56; asym: 4.05; tree : ((5 AND -1) OR -0)
# >> G_5: init: 3.00; noise: 0.69; b: 2.25; m: 9.89; expr: 1.09; deg: 0.10; theta: 0.30; asym: 4.23; tree : (-4 OR 1)
# >> G_6: init: 1.79; noise: 1.02; b: 1.04; m: 4.36; expr: 0.98; deg: 0.11; theta: 7.84; asym: 5.26; tree : (6 OR -1)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.61; m: 4.96; expr: 1.00; deg: 0.10; theta: 4.00; asym: 5.00; tree : 7
# >> G_1: init: 1.38; noise: 1.00; b: 1.21; m: 6.67; expr: 1.00; deg: 0.10; theta: 6.53; asym: 5.00; tree : -7
# >> G_2: init: 1.45; noise: 1.00; b: 1.18; m: 2.73; expr: 1.00; deg: 0.10; theta: 6.98; asym: 5.00; tree : ((3 AND 2) OR (-5 AND 7))
# >> G_3: init: 0.61; noise: 6.06; b: 9.90; m: 8.77; expr: 0.68; deg: 1.10; theta: 2.18; asym: 1.42; tree : ((-7 OR -4) AND 6)
# >> G_4: init: 2.07; noise: 1.00; b: 2.76; m: 1.39; expr: 1.00; deg: 0.10; theta: 7.17; asym: 5.00; tree : (6 AND -2)
# >> G_5: init: 0.22; noise: 1.00; b: 2.25; m: 4.22; expr: 1.00; deg: 0.10; theta: 8.75; asym: 5.00; tree : (5 OR 4)
# >> G_6: init: 0.69; noise: 1.00; b: 3.57; m: 9.22; expr: 1.00; deg: 0.10; theta: 6.40; asym: 5.00; tree : -5
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.61; m: 4.96; expr: 1.00; deg: 0.10; theta: 4.00; asym: 5.00; tree : 7
# >> G_1: init: 1.38; noise: 1.00; b: 1.21; m: 6.67; expr: 1.00; deg: 0.10; theta: 6.53; asym: 5.00; tree : -7
# >> G_2: init: 1.45; noise: 1.00; b: 1.18; m: 2.73; expr: 1.00; deg: 0.10; theta: 6.98; asym: 4.75; tree : ((3 AND 2) OR (-5 AND 7))
# >> G_3: init: 0.61; noise: 6.06; b: 9.90; m: 8.77; expr: 0.68; deg: 1.10; theta: 2.18; asym: 1.42; tree : ((-7 OR -4) AND 6)
# >> G_4: init: 2.07; noise: 1.00; b: 2.76; m: 1.39; expr: 1.00; deg: 0.10; theta: 7.17; asym: 5.00; tree : (6 AND -2)
# >> G_5: init: 0.22; noise: 1.00; b: 2.25; m: 4.22; expr: 1.00; deg: 0.10; theta: 8.75; asym: 5.94; tree : (5 OR 4)
# >> G_6: init: 0.69; noise: 1.00; b: 3.57; m: 9.22; expr: 0.93; deg: 0.10; theta: 6.40; asym: 5.00; tree : -5
