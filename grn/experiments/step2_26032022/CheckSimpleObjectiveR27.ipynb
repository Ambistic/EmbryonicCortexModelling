# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(7, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 100 - 1 * delta_late - 0.5 * delta_early)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=50, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r27"
res = main(prun)

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r27

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
res.fit
# Out:
# 46.89091410519984

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.00; noise: 1.00; b: 4.53; m: 6.71; expr: 1.00; deg: 0.11; theta: 9.76; asym: 5.00; tree : 0
# >> G_1: init: 1.58; noise: 1.00; b: 0.67; m: 5.61; expr: 1.00; deg: 0.10; theta: 9.96; asym: 5.00; tree : (7 OR 2)
# >> G_2: init: 1.35; noise: 1.00; b: 0.57; m: 2.65; expr: 1.00; deg: 0.10; theta: 2.29; asym: 5.00; tree : ((5 AND 4) OR 0)
# >> G_3: init: 1.76; noise: 1.00; b: 0.40; m: 3.81; expr: 1.00; deg: 0.10; theta: 1.31; asym: 5.00; tree : (1 OR (-0 AND -2))
# >> G_4: init: 0.85; noise: 1.00; b: 1.15; m: 1.42; expr: 1.00; deg: 0.10; theta: 1.19; asym: 5.00; tree : -4
# >> G_5: init: 1.53; noise: 1.00; b: 2.28; m: 7.88; expr: 1.00; deg: 0.10; theta: 1.68; asym: 5.00; tree : 4
# >> G_6: init: 0.14; noise: 1.00; b: 2.69; m: 7.59; expr: 1.00; deg: 0.10; theta: 5.81; asym: 5.00; tree : -2
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.08; m: 8.27; expr: 1.00; deg: 0.10; theta: 5.92; asym: 5.00; tree : -2
# >> G_1: init: 0.20; noise: 1.00; b: 2.48; m: 1.68; expr: 1.00; deg: 0.10; theta: 8.85; asym: 5.00; tree : -6
# >> G_2: init: 1.30; noise: 1.00; b: 0.87; m: 1.63; expr: 1.00; deg: 0.10; theta: 0.58; asym: 5.00; tree : (4 OR 5)
# >> G_3: init: 1.27; noise: 1.00; b: 2.72; m: 9.61; expr: 1.00; deg: 0.10; theta: 1.93; asym: 5.00; tree : (-3 OR (2 OR -7))
# >> G_4: init: 0.99; noise: 1.00; b: 2.76; m: 5.17; expr: 1.00; deg: 0.10; theta: 1.89; asym: 5.00; tree : 3
# >> G_5: init: 0.86; noise: 1.00; b: 1.78; m: 4.98; expr: 1.00; deg: 0.10; theta: 4.97; asym: 5.00; tree : 3
# >> G_6: init: 0.45; noise: 1.00; b: 2.29; m: 4.41; expr: 1.00; deg: 0.10; theta: 1.95; asym: 5.00; tree : 3
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.00; noise: 1.00; b: 2.11; m: 8.82; expr: 1.00; deg: 0.10; theta: 5.89; asym: 5.00; tree : 1
# >> G_1: init: 1.77; noise: 1.00; b: 0.99; m: 7.46; expr: 1.00; deg: 0.10; theta: 6.05; asym: 5.00; tree : ((-6 OR -0) OR -2)
# >> G_2: init: 2.51; noise: 1.00; b: 3.66; m: 9.82; expr: 1.00; deg: 0.10; theta: 3.07; asym: 5.00; tree : 7
# >> G_3: init: 0.86; noise: 1.00; b: 0.60; m: 7.12; expr: 1.00; deg: 0.10; theta: 7.15; asym: 5.00; tree : 4
# >> G_4: init: 0.55; noise: 1.00; b: 2.99; m: 6.46; expr: 1.00; deg: 0.10; theta: 9.33; asym: 5.00; tree : 4
# >> G_5: init: 0.65; noise: 1.00; b: 1.95; m: 4.10; expr: 1.00; deg: 0.10; theta: 5.24; asym: 5.00; tree : ((6 AND -4) AND (-3 OR -7))
# >> G_6: init: 0.71; noise: 1.19; b: 1.67; m: 8.28; expr: 1.00; deg: 0.10; theta: 3.42; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.81; m: 6.34; expr: 1.00; deg: 0.10; theta: 6.36; asym: 5.00; tree : ((-1 AND 3) AND -0)
# >> G_1: init: 1.06; noise: 1.00; b: 1.54; m: 7.06; expr: 1.00; deg: 0.10; theta: 9.73; asym: 5.00; tree : ((5 OR 4) OR (3 OR 6))
# >> G_2: init: 0.89; noise: 1.00; b: 2.17; m: 2.91; expr: 1.00; deg: 0.10; theta: 5.33; asym: 5.00; tree : (-0 AND 1)
# >> G_3: init: 0.52; noise: 1.00; b: 1.19; m: 1.05; expr: 1.00; deg: 0.10; theta: 9.51; asym: 5.00; tree : 3
# >> G_4: init: 0.13; noise: 1.00; b: 2.64; m: 6.10; expr: 1.00; deg: 0.10; theta: 0.89; asym: 5.00; tree : 0
# >> G_5: init: 2.43; noise: 1.00; b: 1.93; m: 7.93; expr: 1.00; deg: 0.10; theta: 9.48; asym: 5.00; tree : 1
# >> G_6: init: 1.59; noise: 1.00; b: 1.52; m: 9.48; expr: 1.00; deg: 0.10; theta: 5.06; asym: 5.00; tree : 3
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.63; m: 7.40; expr: 1.00; deg: 0.10; theta: 2.78; asym: 5.00; tree : -3
# >> G_1: init: 0.23; noise: 1.00; b: 3.21; m: 5.18; expr: 1.00; deg: 0.10; theta: 8.91; asym: 5.00; tree : -0
# >> G_2: init: 1.62; noise: 1.00; b: 1.34; m: 2.40; expr: 1.00; deg: 0.10; theta: 1.51; asym: 5.00; tree : -6
# >> G_3: init: 1.16; noise: 1.00; b: 1.08; m: 6.41; expr: 1.00; deg: 0.10; theta: 9.16; asym: 5.00; tree : ((-0 AND 6) AND -5)
# >> G_4: init: 0.21; noise: 1.00; b: 1.24; m: 7.51; expr: 1.00; deg: 0.10; theta: 6.95; asym: 5.00; tree : (-5 OR -4)
# >> G_5: init: 1.41; noise: 1.00; b: 0.21; m: 3.93; expr: 1.00; deg: 0.10; theta: 9.32; asym: 5.00; tree : ((6 AND -7) AND (3 AND -2))
# >> G_6: init: 0.83; noise: 1.00; b: 0.23; m: 2.41; expr: 1.00; deg: 0.10; theta: 9.69; asym: 5.00; tree : 4
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.92; m: 1.88; expr: 1.00; deg: 0.10; theta: 3.59; asym: 5.00; tree : 5
# >> G_1: init: 0.39; noise: 1.00; b: 2.17; m: 9.70; expr: 1.00; deg: 0.10; theta: 9.31; asym: 5.00; tree : 1
# >> G_2: init: 0.98; noise: 1.00; b: 1.92; m: 5.01; expr: 1.00; deg: 0.10; theta: 6.07; asym: 5.00; tree : 2
# >> G_3: init: 0.42; noise: 1.00; b: 0.49; m: 7.95; expr: 1.00; deg: 0.10; theta: 4.99; asym: 5.00; tree : -0
# >> G_4: init: 1.01; noise: 1.00; b: 1.58; m: 9.95; expr: 1.00; deg: 0.10; theta: 1.25; asym: 5.00; tree : -0
# >> G_5: init: 2.05; noise: 1.00; b: 0.51; m: 6.34; expr: 1.00; deg: 0.10; theta: 7.64; asym: 5.00; tree : ((2 AND -1) OR -0)
# >> G_6: init: 0.21; noise: 1.00; b: 1.01; m: 1.72; expr: 1.00; deg: 0.10; theta: 1.82; asym: 5.00; tree : -1
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.20; m: 6.59; expr: 1.00; deg: 0.10; theta: 5.50; asym: 5.00; tree : 6
# >> G_1: init: 1.36; noise: 1.00; b: 3.58; m: 4.76; expr: 1.00; deg: 0.10; theta: 6.73; asym: 5.00; tree : (-2 AND -1)
# >> G_2: init: 0.93; noise: 1.00; b: 3.26; m: 7.28; expr: 1.00; deg: 0.10; theta: 2.28; asym: 5.00; tree : 7
# >> G_3: init: 1.18; noise: 1.00; b: 0.86; m: 2.53; expr: 1.00; deg: 0.10; theta: 4.34; asym: 5.00; tree : (-3 OR -0)
# >> G_4: init: 0.95; noise: 1.00; b: 2.28; m: 4.72; expr: 1.00; deg: 0.10; theta: 5.67; asym: 5.00; tree : (-4 OR (2 OR -3))
# >> G_5: init: 1.71; noise: 1.00; b: 1.09; m: 2.89; expr: 1.00; deg: 0.10; theta: 9.92; asym: 5.00; tree : ((6 AND 0) OR 7)
# >> G_6: init: 0.75; noise: 1.00; b: 0.73; m: 3.45; expr: 1.00; deg: 0.10; theta: 9.27; asym: 5.00; tree : (-1 AND (5 AND 3))
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.00; noise: 1.00; b: 3.68; m: 8.36; expr: 1.00; deg: 0.10; theta: 4.31; asym: 5.07; tree : -2
# >> G_1: init: 0.83; noise: 1.00; b: 1.42; m: 3.43; expr: 1.00; deg: 0.10; theta: 3.08; asym: 5.00; tree : -3
# >> G_2: init: 2.12; noise: 1.00; b: 0.26; m: 9.96; expr: 1.00; deg: 0.10; theta: 5.13; asym: 5.00; tree : (-6 AND (-5 AND -1))
# >> G_3: init: 1.76; noise: 1.00; b: 0.95; m: 7.55; expr: 1.00; deg: 0.10; theta: 2.24; asym: 5.00; tree : (3 AND -4)
# >> G_4: init: 1.37; noise: 1.00; b: 2.23; m: 9.27; expr: 1.00; deg: 0.10; theta: 1.85; asym: 5.00; tree : 4
# >> G_5: init: 1.68; noise: 1.00; b: 3.56; m: 4.83; expr: 1.00; deg: 0.10; theta: 5.36; asym: 5.00; tree : 3
# >> G_6: init: 1.52; noise: 1.00; b: 4.28; m: 4.98; expr: 1.00; deg: 0.10; theta: 7.62; asym: 5.00; tree : -5
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.26; m: 7.15; expr: 1.00; deg: 0.10; theta: 7.40; asym: 5.00; tree : -3
# >> G_1: init: 1.74; noise: 1.00; b: 1.23; m: 7.62; expr: 1.12; deg: 0.10; theta: 3.10; asym: 5.00; tree : (7 AND (1 OR 2))
# >> G_2: init: 0.54; noise: 1.00; b: 2.26; m: 6.69; expr: 1.00; deg: 0.10; theta: 2.46; asym: 5.00; tree : ((-1 OR 3) AND (4 OR -2))
# >> G_3: init: 1.27; noise: 1.00; b: 1.26; m: 4.19; expr: 1.00; deg: 0.10; theta: 6.97; asym: 5.00; tree : 3
# >> G_4: init: 2.22; noise: 1.00; b: 0.72; m: 5.06; expr: 1.00; deg: 0.10; theta: 5.16; asym: 5.00; tree : (-4 AND (7 AND 1))
# >> G_5: init: 1.50; noise: 1.00; b: 1.71; m: 1.62; expr: 1.00; deg: 0.10; theta: 8.51; asym: 5.00; tree : (7 AND 2)
# >> G_6: init: 0.46; noise: 1.00; b: 2.46; m: 5.63; expr: 1.00; deg: 0.10; theta: 4.70; asym: 5.00; tree : (-1 AND -6)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.00; noise: 1.00; b: 3.32; m: 2.45; expr: 1.00; deg: 0.10; theta: 9.14; asym: 5.00; tree : 1
# >> G_1: init: 0.67; noise: 1.00; b: 1.90; m: 6.66; expr: 1.00; deg: 0.10; theta: 5.95; asym: 5.00; tree : 7
# >> G_2: init: 1.63; noise: 1.00; b: 3.02; m: 3.21; expr: 1.00; deg: 0.10; theta: 5.95; asym: 5.00; tree : ((-4 AND 0) OR 2)
# >> G_3: init: 0.62; noise: 1.00; b: 1.99; m: 1.27; expr: 1.00; deg: 0.10; theta: 4.36; asym: 5.00; tree : 3
# >> G_4: init: 0.71; noise: 1.00; b: 1.14; m: 1.67; expr: 1.00; deg: 0.10; theta: 2.05; asym: 5.00; tree : ((-2 OR 6) OR (1 OR 3))
# >> G_5: init: 1.06; noise: 1.00; b: 0.67; m: 8.75; expr: 1.00; deg: 0.10; theta: 0.65; asym: 5.00; tree : ((1 OR -7) OR 6)
# >> G_6: init: 0.97; noise: 1.00; b: 1.87; m: 1.62; expr: 1.00; deg: 0.10; theta: 6.51; asym: 5.00; tree : 0
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.00; noise: 1.00; b: 1.83; m: 1.76; expr: 1.00; deg: 0.10; theta: 4.13; asym: 5.00; tree : 1
# >> G_1: init: 1.87; noise: 1.00; b: 2.97; m: 4.94; expr: 1.00; deg: 0.10; theta: 3.13; asym: 5.00; tree : -6
# >> G_2: init: 0.43; noise: 1.00; b: 2.35; m: 7.54; expr: 1.00; deg: 0.10; theta: 0.03; asym: 5.00; tree : 3
# >> G_3: init: 0.55; noise: 1.00; b: 1.12; m: 8.04; expr: 1.00; deg: 0.10; theta: 5.21; asym: 5.00; tree : (-0 OR 5)
# >> G_4: init: 1.03; noise: 1.00; b: 2.75; m: 5.86; expr: 1.00; deg: 0.10; theta: 9.78; asym: 5.00; tree : ((-1 OR 2) AND 6)
# >> G_5: init: 0.46; noise: 1.00; b: 2.63; m: 9.08; expr: 1.00; deg: 0.10; theta: 4.91; asym: 5.00; tree : -7
# >> G_6: init: 0.47; noise: 1.00; b: 0.44; m: 2.39; expr: 1.00; deg: 0.10; theta: 3.08; asym: 5.00; tree : -6
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 0.80; noise: 1.00; b: 1.60; m: 5.53; expr: 1.00; deg: 0.10; theta: 8.96; asym: 5.00; tree : ((-5 AND 4) AND (7 AND -1))
# >> G_2: init: 0.15; noise: 1.06; b: 0.16; m: 3.08; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 5))
# >> G_3: init: 0.37; noise: 1.00; b: 1.90; m: 2.17; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.09; noise: 1.00; b: 1.79; m: 9.93; expr: 1.13; deg: 0.10; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.51; noise: 1.00; b: 1.56; m: 3.29; expr: 1.00; deg: 0.10; theta: 7.90; asym: 5.00; tree : 6
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.00; deg: 0.10; theta: 0.32; asym: 5.00; tree : (7 AND 4)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 0.80; noise: 1.00; b: 1.60; m: 5.53; expr: 1.00; deg: 0.10; theta: 8.26; asym: 4.07; tree : ((-5 AND 4) AND (7 AND -1))
# >> G_2: init: 0.15; noise: 1.06; b: 0.16; m: 3.08; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 5))
# >> G_3: init: 0.37; noise: 1.08; b: 1.90; m: 2.17; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.09; noise: 1.00; b: 1.79; m: 9.93; expr: 1.13; deg: 0.10; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.51; noise: 1.00; b: 1.56; m: 3.29; expr: 1.17; deg: 0.10; theta: 7.90; asym: 5.00; tree : 6
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.00; deg: 0.10; theta: 0.32; asym: 5.00; tree : (7 AND (4 AND -2))
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 0.80; noise: 1.00; b: 1.60; m: 5.53; expr: 1.00; deg: 0.10; theta: 8.96; asym: 5.00; tree : ((-5 AND 4) AND (7 AND 0))
# >> G_2: init: 0.15; noise: 1.06; b: 0.16; m: 3.08; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 5))
# >> G_3: init: 0.37; noise: 1.00; b: 1.90; m: 1.84; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.09; noise: 1.00; b: 1.79; m: 9.93; expr: 1.13; deg: 0.12; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.74; noise: 1.15; b: 1.56; m: 3.29; expr: 1.00; deg: 0.10; theta: 7.90; asym: 5.00; tree : 6
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.00; deg: 0.09; theta: 0.32; asym: 5.00; tree : (7 AND 4)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.09; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 0.80; noise: 1.00; b: 1.60; m: 5.53; expr: 1.00; deg: 0.10; theta: 8.96; asym: 5.00; tree : ((-5 AND 4) AND (7 AND 0))
# >> G_2: init: 0.15; noise: 1.06; b: 0.16; m: 3.26; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 5))
# >> G_3: init: 0.37; noise: 1.00; b: 1.90; m: 1.84; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.09; noise: 1.00; b: 1.79; m: 9.93; expr: 1.13; deg: 0.12; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.74; noise: 1.15; b: 1.56; m: 3.29; expr: 1.00; deg: 0.10; theta: 7.90; asym: 5.00; tree : 6
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.00; deg: 0.09; theta: 0.32; asym: 5.00; tree : (7 AND 4)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 0.80; noise: 1.00; b: 1.46; m: 5.53; expr: 1.00; deg: 0.10; theta: 8.96; asym: 4.00; tree : ((-5 AND 4) AND (7 AND 0))
# >> G_2: init: 0.15; noise: 0.99; b: 0.16; m: 3.08; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 5))
# >> G_3: init: 0.37; noise: 1.00; b: 1.90; m: 1.84; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.09; noise: 1.00; b: 1.79; m: 9.93; expr: 1.13; deg: 0.12; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.74; noise: 1.15; b: 1.56; m: 3.29; expr: 1.12; deg: 0.10; theta: 7.90; asym: 4.86; tree : 6
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.00; deg: 0.09; theta: 0.32; asym: 5.00; tree : (7 AND 4)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 1.67; noise: 6.64; b: 4.38; m: 1.57; expr: 2.79; deg: 2.60; theta: 5.10; asym: 4.95; tree : -3
# >> G_2: init: 0.15; noise: 1.06; b: 0.16; m: 3.59; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 5))
# >> G_3: init: 0.37; noise: 1.00; b: 1.90; m: 1.84; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.09; noise: 1.00; b: 1.79; m: 9.93; expr: 1.13; deg: 0.12; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.74; noise: 1.00; b: 1.56; m: 3.29; expr: 1.00; deg: 0.10; theta: 7.90; asym: 5.00; tree : (6 AND -5)
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.16; deg: 0.10; theta: 0.32; asym: 5.00; tree : 4
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.09; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 1.67; noise: 6.64; b: 4.38; m: 1.57; expr: 2.79; deg: 2.60; theta: 5.10; asym: 4.95; tree : -3
# >> G_2: init: 0.15; noise: 1.06; b: 0.16; m: 3.59; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 5))
# >> G_3: init: 0.37; noise: 1.00; b: 1.90; m: 2.19; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.09; noise: 1.00; b: 1.79; m: 9.93; expr: 1.13; deg: 0.12; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.74; noise: 1.00; b: 1.56; m: 3.29; expr: 1.00; deg: 0.10; theta: 7.90; asym: 5.00; tree : 6
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.16; deg: 0.10; theta: 0.35; asym: 5.00; tree : 4
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.09; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 1.67; noise: 6.64; b: 4.38; m: 1.57; expr: 2.79; deg: 2.60; theta: 5.10; asym: 5.20; tree : -3
# >> G_2: init: 0.15; noise: 1.06; b: 0.16; m: 3.59; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 5))
# >> G_3: init: 0.37; noise: 1.00; b: 1.90; m: 2.19; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.31; noise: 1.00; b: 1.79; m: 9.93; expr: 1.13; deg: 0.12; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 2.08; noise: 1.00; b: 1.56; m: 3.29; expr: 1.00; deg: 0.10; theta: 7.90; asym: 5.00; tree : 6
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.16; deg: 0.10; theta: 0.35; asym: 5.00; tree : 4
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.25; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.09; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 1.43; noise: 6.64; b: 4.38; m: 1.57; expr: 2.79; deg: 2.78; theta: 5.10; asym: 4.95; tree : -3
# >> G_2: init: 0.15; noise: 1.06; b: 0.16; m: 3.59; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 5))
# >> G_3: init: 0.37; noise: 1.00; b: 1.90; m: 2.19; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.09; noise: 1.00; b: 1.79; m: 11.32; expr: 1.13; deg: 0.12; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.74; noise: 1.00; b: 1.56; m: 3.29; expr: 1.00; deg: 0.10; theta: 7.90; asym: 5.00; tree : 6
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.16; deg: 0.10; theta: 0.35; asym: 5.00; tree : 4
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 0.68; noise: 1.19; b: 1.60; m: 5.27; expr: 1.02; deg: 0.10; theta: 8.96; asym: 5.00; tree : (4 AND (7 AND 0))
# >> G_2: init: 0.15; noise: 1.06; b: 0.16; m: 3.18; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 1))
# >> G_3: init: 0.37; noise: 1.08; b: 1.56; m: 1.84; expr: 1.00; deg: 0.09; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.31; noise: 1.05; b: 1.99; m: 9.93; expr: 1.13; deg: 0.13; theta: 3.39; asym: 5.39; tree : 3
# >> G_5: init: 1.74; noise: 1.05; b: 2.10; m: 3.62; expr: 1.12; deg: 0.10; theta: 7.90; asym: 5.00; tree : -1
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.00; deg: 0.09; theta: 0.37; asym: 5.83; tree : (7 AND 4)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 0.65; noise: 0.82; b: 1.60; m: 5.88; expr: 1.00; deg: 0.10; theta: 8.96; asym: 5.00; tree : ((-5 AND 4) AND (7 AND 0))
# >> G_2: init: 0.17; noise: 1.06; b: 0.13; m: 3.18; expr: 1.00; deg: 0.10; theta: 9.96; asym: 5.00; tree : (0 AND 1)
# >> G_3: init: 0.37; noise: 1.08; b: 1.56; m: 1.84; expr: 1.02; deg: 0.10; theta: 5.99; asym: 5.00; tree : 2
# >> G_4: init: 1.31; noise: 1.00; b: 1.99; m: 9.93; expr: 1.25; deg: 0.12; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.74; noise: 1.05; b: 1.56; m: 3.62; expr: 1.12; deg: 0.10; theta: 7.90; asym: 5.00; tree : -1
# >> G_6: init: 0.05; noise: 1.00; b: 4.16; m: 3.59; expr: 1.00; deg: 0.09; theta: 0.37; asym: 4.69; tree : (7 AND 4)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 0.68; noise: 1.19; b: 1.38; m: 5.53; expr: 1.00; deg: 0.10; theta: 8.96; asym: 5.00; tree : (7 AND 0)
# >> G_2: init: 0.11; noise: 1.06; b: 0.16; m: 2.85; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 1))
# >> G_3: init: 0.37; noise: 1.08; b: 1.56; m: 1.84; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.31; noise: 1.05; b: 1.99; m: 10.20; expr: 1.13; deg: 0.13; theta: 3.39; asym: 5.58; tree : 3
# >> G_5: init: 1.74; noise: 1.07; b: 2.10; m: 3.62; expr: 1.12; deg: 0.10; theta: 7.90; asym: 5.00; tree : (-1 AND 4)
# >> G_6: init: 0.04; noise: 1.00; b: 4.09; m: 3.59; expr: 1.00; deg: 0.09; theta: 0.37; asym: 5.00; tree : (6 AND -2)
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 5.00; tree : -4
# >> G_1: init: 0.68; noise: 1.35; b: 1.38; m: 5.53; expr: 1.00; deg: 0.10; theta: 8.96; asym: 5.00; tree : (7 AND 0)
# >> G_2: init: 0.11; noise: 1.06; b: 0.16; m: 2.85; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 1))
# >> G_3: init: 0.37; noise: 1.08; b: 1.56; m: 1.84; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : (2 AND -4)
# >> G_4: init: 1.31; noise: 1.05; b: 1.99; m: 10.20; expr: 1.13; deg: 0.13; theta: 3.39; asym: 5.58; tree : 3
# >> G_5: init: 1.74; noise: 1.05; b: 2.10; m: 3.62; expr: 1.12; deg: 0.10; theta: 7.90; asym: 5.00; tree : (-1 AND 4)
# >> G_6: init: 0.04; noise: 1.00; b: 4.09; m: 3.59; expr: 1.00; deg: 0.09; theta: 0.37; asym: 5.00; tree : (6 AND 0)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 4.21; tree : (-4 OR -5)
# >> G_1: init: 0.68; noise: 1.19; b: 1.17; m: 5.53; expr: 1.00; deg: 0.10; theta: 8.96; asym: 5.00; tree : 7
# >> G_2: init: 0.11; noise: 1.06; b: 0.16; m: 2.85; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 1))
# >> G_3: init: 0.37; noise: 1.08; b: 1.56; m: 2.11; expr: 1.00; deg: 0.10; theta: 6.54; asym: 5.00; tree : 2
# >> G_4: init: 1.27; noise: 1.05; b: 1.99; m: 10.20; expr: 1.13; deg: 0.13; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.74; noise: 1.05; b: 2.10; m: 3.62; expr: 1.12; deg: 0.10; theta: 7.90; asym: 5.00; tree : (3 AND 4)
# >> G_6: init: 0.04; noise: 1.00; b: 4.09; m: 3.59; expr: 1.07; deg: 0.09; theta: 0.37; asym: 5.00; tree : (6 AND 4)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.10; noise: 1.00; b: 2.35; m: 5.59; expr: 1.00; deg: 0.10; theta: 2.77; asym: 4.21; tree : -4
# >> G_1: init: 0.68; noise: 1.39; b: 1.64; m: 5.53; expr: 1.00; deg: 0.10; theta: 8.96; asym: 5.00; tree : (7 AND 0)
# >> G_2: init: 0.11; noise: 1.01; b: 0.16; m: 2.85; expr: 1.00; deg: 0.10; theta: 9.61; asym: 5.00; tree : (-7 AND (0 AND 1))
# >> G_3: init: 0.37; noise: 1.08; b: 1.56; m: 2.11; expr: 1.00; deg: 0.09; theta: 6.54; asym: 5.00; tree : -4
# >> G_4: init: 1.27; noise: 1.05; b: 1.99; m: 10.20; expr: 1.13; deg: 0.13; theta: 3.39; asym: 5.00; tree : 3
# >> G_5: init: 1.74; noise: 1.05; b: 2.10; m: 3.62; expr: 1.12; deg: 0.10; theta: 7.90; asym: 5.00; tree : (-1 AND 4)
# >> G_6: init: 0.04; noise: 1.00; b: 4.09; m: 3.59; expr: 1.07; deg: 0.09; theta: 0.37; asym: 5.00; tree : 4
