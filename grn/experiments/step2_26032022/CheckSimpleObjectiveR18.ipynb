# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_n, ref_n = normalize_time(stats, ref_stats, "neuron_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_n = stats_n.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_n.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_n.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_n.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_n.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 100 - 1 * delta_late - 0.5 * delta_early)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r18"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r18
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 73.72226652820251 for generation 0
# Step 3 passed !
# [out] ++ Best 78.0324883959769 for generation 3
# [out] ++ Best 80.88625188619164 for generation 39
# Saving ...
# [out] ++ Best 82.83523147802838 for generation 54
# [out] ++ Best 82.92479330782074 for generation 68
# [out] ++ Best 83.7263659469973 for generation 75
# [out] ++ Best 84.31820268169116 for generation 86
# Saving ...
# [out] Step 100
# Saving ...
# Saving ...
# [out] Step 200
# Saving ...
# Saving ...
# [out] Step 300
# Saving ...
# [out] ++ Best 85.66514145720139 for generation 384
# [out] ++ Best 86.16514145720139 for generation 396
# Saving ...
# [out] Step 400
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# Saving ...
# Saving ...
# [out] Step 800
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# [out] ++ Best 86.46541169180632 for generation 1029
# [out] ++ Best 86.5157120481029 for generation 1032
# Saving ...
# Saving ...
# [out] Step 1100
# [out] ++ Best 86.78101817055187 for generation 1109
# [out] ++ Best 86.95520761017369 for generation 1136
# [out] ++ Best 87.43479944690836 for generation 1149
# Saving ...
# [out] ++ Best 87.44065166128301 for generation 1164
# Saving ...
# [out] Step 1200
# Saving ...
# Saving ...
# [out] Step 1300
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# [out] ++ Best 87.52663618160226 for generation 1996
# Saving ...
# [out] Step 2000
# Saving ...
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r18

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))
# Out:
# (85.93934925671141,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             3.0             20.0                 37.0            17.0
# 56.50             3.0             21.0                 36.0            18.0
# 56.75             3.0             21.0                 36.0            18.0
# 57.00             3.0             21.0                 36.0            18.0
# ...               ...              ...                  ...             ...
# 85.00             4.0             22.0                102.0            18.0
# 85.25             4.0             22.0                103.0            18.0
# 85.50             4.0             22.0                105.0            18.0
# 85.75             4.0             22.0                105.0            18.0
# 86.00             4.0             22.0                106.0            18.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            57.0
# 56.50  56.50            57.0
# 56.75  56.75            57.0
# 57.00  57.00            57.0
# ...      ...             ...
# 85.00  85.00           124.0
# 85.25  85.25           125.0
# 85.50  85.50           127.0
# 85.75  85.75           127.0
# 86.00  86.00           128.0
#
# [121 rows x 6 columns])
# (83.42459536527572,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             1.0             17.0                 36.0            16.0
# 56.50             1.0             17.0                 36.0            16.0
# 56.75             1.0             17.0                 36.0            16.0
# 57.00             1.0             17.0                 37.0            16.0
# ...               ...              ...                  ...             ...
# 85.00             2.0             18.0                106.0            16.0
# 85.25             2.0             18.0                107.0            16.0
# 85.50             2.0             18.0                108.0            16.0
# 85.75             2.0             18.0                108.0            16.0
# 86.00             2.0             18.0                109.0            16.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            53.0
# 56.50  56.50            53.0
# 56.75  56.75            53.0
# 57.00  57.00            54.0
# ...      ...             ...
# 85.00  85.00           124.0
# 85.25  85.25           125.0
# 85.50  85.50           126.0
# 85.75  85.75           126.0
# 86.00  86.00           127.0
#
# [121 rows x 6 columns])
# (84.31820268169119,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             1.0             19.0                 32.0            18.0
# 56.50             1.0             19.0                 33.0            18.0
# 56.75             2.0             20.0                 32.0            18.0
# 57.00             2.0             20.0                 32.0            18.0
# ...               ...              ...                  ...             ...
# 85.00             2.0             20.0                 82.0            18.0
# 85.25             2.0             20.0                 82.0            18.0
# 85.50             2.0             20.0                 82.0            18.0
# 85.75             2.0             20.0                 83.0            18.0
# 86.00             2.0             20.0                 83.0            18.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            51.0
# 56.50  56.50            52.0
# 56.75  56.75            52.0
# 57.00  57.00            52.0
# ...      ...             ...
# 85.00  85.00           102.0
# 85.25  85.25           102.0
# 85.50  85.50           102.0
# 85.75  85.75           103.0
# 86.00  86.00           103.0
#
# [121 rows x 6 columns])
# (86.46105982454833,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             3.0             22.0                 32.0            19.0
# 56.50             3.0             23.0                 31.0            20.0
# 56.75             3.0             23.0                 31.0            20.0
# 57.00             3.0             23.0                 31.0            20.0
# ...               ...              ...                  ...             ...
# 85.00             3.0             23.0                 66.0            20.0
# 85.25             3.0             23.0                 66.0            20.0
# 85.50             3.0             23.0                 66.0            20.0
# 85.75             3.0             23.0                 68.0            20.0
# 86.00             3.0             23.0                 68.0            20.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            54.0
# 56.50  56.50            54.0
# 56.75  56.75            54.0
# 57.00  57.00            54.0
# ...      ...             ...
# 85.00  85.00            89.0
# 85.25  85.25            89.0
# 85.50  85.50            89.0
# 85.75  85.75            91.0
# 86.00  86.00            91.0
#
# [121 rows x 6 columns])
# (83.44747637598758,        infra_pop_size  neuron_pop_size  progenitor_pop_size  supra_pop_size  \
# 56.00             0.0              0.0                 49.0             0.0
# 56.25             4.0             17.0                 42.0            13.0
# 56.50             4.0             17.0                 42.0            13.0
# 56.75             4.0             17.0                 42.0            13.0
# 57.00             4.0             17.0                 42.0            13.0
# ...               ...              ...                  ...             ...
# 85.00             4.0             17.0                 88.0            13.0
# 85.25             4.0             17.0                 88.0            13.0
# 85.50             4.0             17.0                 88.0            13.0
# 85.75             4.0             17.0                 88.0            13.0
# 86.00             4.0             17.0                 89.0            13.0
#
#         time  whole_pop_size
# 56.00  56.00            49.0
# 56.25  56.25            59.0
# 56.50  56.50            59.0
# 56.75  56.75            59.0
# 57.00  57.00            59.0
# ...      ...             ...
# 85.00  85.00           105.0
# 85.25  85.25           105.0
# 85.50  85.50           105.0
# 85.75  85.75           105.0
# 86.00  86.00           106.0
#
# [121 rows x 6 columns])

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.41; noise: 2.60; b: 2.96; m: 2.67; expr: 0.43; deg: 2.85; theta: 1.16; asym: 7.29; tree : (-3 OR -2)
# >> G_1: init: 1.43; noise: 1.00; b: 0.68; m: 3.78; expr: 1.00; deg: 0.10; theta: 1.34; asym: 5.00; tree : (-3 OR 0)
# >> G_2: init: 0.22; noise: 1.00; b: 0.77; m: 8.42; expr: 1.00; deg: 0.10; theta: 9.01; asym: 5.00; tree : ((-0 OR 5) AND (-4 AND -1))
# >> G_3: init: 1.73; noise: 1.00; b: 0.91; m: 6.42; expr: 1.00; deg: 0.10; theta: 9.15; asym: 5.00; tree : ((3 AND 5) AND (0 AND -1))
# >> G_4: init: 1.08; noise: 1.00; b: 1.96; m: 3.27; expr: 1.00; deg: 0.10; theta: 4.65; asym: 5.00; tree : ((-3 OR 4) AND -0)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.00; noise: 1.00; b: 0.46; m: 6.52; expr: 1.00; deg: 0.10; theta: 5.69; asym: 4.39; tree : -5
# >> G_1: init: 0.71; noise: 1.00; b: 3.33; m: 4.33; expr: 1.00; deg: 0.10; theta: 3.63; asym: 5.00; tree : -0
# >> G_2: init: 1.33; noise: 1.00; b: 1.01; m: 9.22; expr: 1.00; deg: 0.10; theta: 4.11; asym: 5.00; tree : ((-3 AND -2) OR -5)
# >> G_3: init: 0.99; noise: 1.00; b: 1.68; m: 9.20; expr: 1.00; deg: 0.10; theta: 0.39; asym: 5.00; tree : (1 OR 5)
# >> G_4: init: 0.15; noise: 1.00; b: 1.65; m: 9.19; expr: 1.00; deg: 0.10; theta: 7.28; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.00; noise: 1.12; b: 0.46; m: 6.52; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : -5
# >> G_1: init: 0.71; noise: 1.00; b: 3.33; m: 4.33; expr: 1.00; deg: 0.10; theta: 3.63; asym: 5.00; tree : -0
# >> G_2: init: 1.33; noise: 1.00; b: 1.01; m: 9.22; expr: 1.00; deg: 0.10; theta: 4.11; asym: 5.00; tree : (3 OR -5)
# >> G_3: init: 0.99; noise: 1.00; b: 1.68; m: 9.20; expr: 1.00; deg: 0.10; theta: 0.39; asym: 5.00; tree : 1
# >> G_4: init: 0.15; noise: 1.00; b: 2.24; m: 9.19; expr: 1.00; deg: 0.10; theta: 7.28; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.05; noise: 1.00; b: 0.46; m: 6.52; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : -5
# >> G_1: init: 0.71; noise: 1.00; b: 3.33; m: 4.33; expr: 1.00; deg: 0.09; theta: 3.76; asym: 4.82; tree : -0
# >> G_2: init: 2.07; noise: 3.04; b: 1.79; m: 8.53; expr: 2.06; deg: 0.35; theta: 6.05; asym: 6.33; tree : 3
# >> G_3: init: 0.99; noise: 1.00; b: 1.68; m: 9.20; expr: 1.00; deg: 0.10; theta: 0.39; asym: 5.00; tree : (1 OR 5)
# >> G_4: init: 0.15; noise: 1.00; b: 1.94; m: 9.19; expr: 0.97; deg: 0.10; theta: 6.70; asym: 5.78; tree : -0
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.05; noise: 1.00; b: 0.46; m: 6.52; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : -5
# >> G_1: init: 0.71; noise: 1.00; b: 3.33; m: 4.33; expr: 1.00; deg: 0.09; theta: 3.76; asym: 4.82; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 8.53; expr: 2.06; deg: 0.35; theta: 6.05; asym: 6.33; tree : 3
# >> G_3: init: 0.99; noise: 1.00; b: 1.68; m: 9.16; expr: 1.03; deg: 0.10; theta: 0.39; asym: 5.00; tree : (1 OR 5)
# >> G_4: init: 0.15; noise: 1.00; b: 1.94; m: 9.19; expr: 0.97; deg: 0.10; theta: 6.70; asym: 6.19; tree : -0
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.05; noise: 1.00; b: 0.46; m: 6.52; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : -5
# >> G_1: init: 0.71; noise: 1.00; b: 3.33; m: 4.33; expr: 1.00; deg: 0.09; theta: 3.76; asym: 4.82; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.66; m: 8.53; expr: 2.46; deg: 0.35; theta: 6.05; asym: 6.33; tree : 3
# >> G_3: init: 0.99; noise: 1.00; b: 1.68; m: 9.20; expr: 1.03; deg: 0.10; theta: 0.39; asym: 5.00; tree : 1
# >> G_4: init: 0.15; noise: 1.00; b: 1.94; m: 9.19; expr: 0.97; deg: 0.10; theta: 6.70; asym: 5.65; tree : -0
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.05; noise: 1.00; b: 0.46; m: 6.52; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : -5
# >> G_1: init: 0.71; noise: 1.00; b: 3.33; m: 4.33; expr: 1.14; deg: 0.09; theta: 3.76; asym: 4.82; tree : -0
# >> G_2: init: 2.07; noise: 3.10; b: 1.79; m: 8.53; expr: 2.06; deg: 0.28; theta: 6.05; asym: 6.33; tree : 3
# >> G_3: init: 0.99; noise: 1.00; b: 1.68; m: 9.20; expr: 1.03; deg: 0.10; theta: 0.39; asym: 5.00; tree : 5
# >> G_4: init: 0.15; noise: 1.00; b: 1.94; m: 9.19; expr: 0.97; deg: 0.10; theta: 6.70; asym: 6.19; tree : -4
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.05; noise: 1.00; b: 0.46; m: 6.52; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : -5
# >> G_1: init: 0.71; noise: 1.00; b: 3.33; m: 4.33; expr: 1.14; deg: 0.09; theta: 3.76; asym: 4.82; tree : -0
# >> G_2: init: 2.07; noise: 3.10; b: 1.79; m: 8.53; expr: 2.06; deg: 0.28; theta: 6.05; asym: 6.33; tree : 3
# >> G_3: init: 0.99; noise: 1.00; b: 1.68; m: 9.20; expr: 0.89; deg: 0.10; theta: 0.39; asym: 5.00; tree : 5
# >> G_4: init: 0.15; noise: 1.00; b: 1.94; m: 9.19; expr: 0.97; deg: 0.10; theta: 6.70; asym: 6.80; tree : -4
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 0.95; noise: 1.00; b: 0.46; m: 6.52; expr: 1.02; deg: 0.10; theta: 5.69; asym: 5.00; tree : -5
# >> G_1: init: 0.71; noise: 1.00; b: 3.14; m: 4.33; expr: 1.14; deg: 0.09; theta: 3.76; asym: 4.82; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 8.53; expr: 1.70; deg: 0.35; theta: 6.05; asym: 6.33; tree : -5
# >> G_3: init: 0.99; noise: 1.00; b: 1.36; m: 9.20; expr: 1.03; deg: 0.10; theta: 0.39; asym: 4.85; tree : 5
# >> G_4: init: 0.15; noise: 1.00; b: 1.94; m: 9.48; expr: 0.97; deg: 0.10; theta: 6.70; asym: 6.19; tree : -4
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.05; noise: 1.00; b: 0.46; m: 6.52; expr: 1.00; deg: 0.10; theta: 6.33; asym: 5.00; tree : -5
# >> G_1: init: 0.72; noise: 0.89; b: 3.21; m: 4.02; expr: 1.14; deg: 0.09; theta: 3.76; asym: 4.44; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 8.53; expr: 2.38; deg: 0.35; theta: 6.05; asym: 6.33; tree : 3
# >> G_3: init: 1.11; noise: 1.00; b: 1.36; m: 9.20; expr: 1.03; deg: 0.10; theta: 0.39; asym: 5.00; tree : 3
# >> G_4: init: 0.15; noise: 1.00; b: 1.94; m: 9.99; expr: 0.97; deg: 0.10; theta: 6.70; asym: 6.19; tree : -4
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 0.95; noise: 1.05; b: 0.49; m: 6.52; expr: 1.02; deg: 0.12; theta: 5.69; asym: 4.24; tree : -1
# >> G_1: init: 0.62; noise: 1.00; b: 3.14; m: 4.33; expr: 1.35; deg: 0.09; theta: 4.09; asym: 4.82; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 8.53; expr: 2.06; deg: 0.35; theta: 6.05; asym: 7.47; tree : -5
# >> G_3: init: 1.11; noise: 1.00; b: 1.36; m: 9.20; expr: 1.03; deg: 0.10; theta: 0.37; asym: 4.85; tree : (5 OR -2)
# >> G_4: init: 0.32; noise: 8.12; b: 1.37; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.85; asym: 3.23; tree : -2
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 0.95; noise: 1.05; b: 0.49; m: 6.52; expr: 1.02; deg: 0.12; theta: 5.69; asym: 3.86; tree : -1
# >> G_1: init: 0.62; noise: 1.00; b: 3.14; m: 4.33; expr: 1.38; deg: 0.09; theta: 4.09; asym: 4.17; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 7.26; expr: 2.06; deg: 0.35; theta: 6.05; asym: 7.47; tree : -5
# >> G_3: init: 1.11; noise: 1.00; b: 1.36; m: 9.20; expr: 1.00; deg: 0.10; theta: 0.37; asym: 4.85; tree : (5 OR -2)
# >> G_4: init: 0.32; noise: 8.12; b: 1.37; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.85; asym: 3.23; tree : -2
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 0.95; noise: 1.05; b: 0.49; m: 6.52; expr: 1.02; deg: 0.12; theta: 5.69; asym: 3.86; tree : -1
# >> G_1: init: 0.62; noise: 1.00; b: 3.14; m: 4.33; expr: 1.38; deg: 0.09; theta: 4.09; asym: 4.17; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 8.53; expr: 2.06; deg: 0.35; theta: 6.05; asym: 7.47; tree : (-5 AND -0)
# >> G_3: init: 1.11; noise: 1.00; b: 1.36; m: 9.20; expr: 1.20; deg: 0.10; theta: 0.37; asym: 4.85; tree : (5 OR -2)
# >> G_4: init: 0.32; noise: 8.12; b: 1.37; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.85; asym: 3.23; tree : -2
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 0.95; noise: 1.03; b: 0.49; m: 6.52; expr: 1.02; deg: 0.12; theta: 5.69; asym: 3.86; tree : -1
# >> G_1: init: 0.62; noise: 1.00; b: 3.14; m: 4.33; expr: 1.38; deg: 0.09; theta: 4.09; asym: 3.92; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.74; m: 8.53; expr: 2.06; deg: 0.35; theta: 5.41; asym: 7.47; tree : -5
# >> G_3: init: 1.19; noise: 1.00; b: 1.36; m: 9.27; expr: 1.00; deg: 0.10; theta: 0.37; asym: 4.85; tree : (5 OR (-2 OR 0))
# >> G_4: init: 0.32; noise: 8.12; b: 1.37; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.85; asym: 3.23; tree : -2
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 0.95; noise: 1.03; b: 0.49; m: 6.52; expr: 1.02; deg: 0.12; theta: 5.69; asym: 3.86; tree : -1
# >> G_1: init: 0.62; noise: 1.00; b: 3.14; m: 4.33; expr: 1.38; deg: 0.08; theta: 4.09; asym: 3.92; tree : (-0 AND (-3 OR -2))
# >> G_2: init: 2.07; noise: 2.59; b: 1.74; m: 8.53; expr: 2.06; deg: 0.38; theta: 6.53; asym: 7.47; tree : (-5 AND -2)
# >> G_3: init: 1.19; noise: 1.00; b: 1.36; m: 9.20; expr: 1.00; deg: 0.10; theta: 0.37; asym: 4.85; tree : (5 OR (-2 OR 0))
# >> G_4: init: 0.32; noise: 7.23; b: 1.37; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.85; asym: 3.23; tree : -2
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 0.95; noise: 1.05; b: 0.49; m: 6.52; expr: 1.02; deg: 0.12; theta: 5.69; asym: 4.12; tree : -1
# >> G_1: init: 0.62; noise: 1.00; b: 3.14; m: 4.33; expr: 1.24; deg: 0.09; theta: 4.09; asym: 4.17; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 8.53; expr: 2.06; deg: 0.35; theta: 6.05; asym: 8.34; tree : -0
# >> G_3: init: 1.19; noise: 1.00; b: 1.36; m: 9.20; expr: 1.00; deg: 0.09; theta: 0.37; asym: 4.85; tree : (5 OR (-3 OR -0))
# >> G_4: init: 0.32; noise: 8.12; b: 1.46; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.85; asym: 3.23; tree : -2
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 0.95; noise: 1.05; b: 0.49; m: 6.52; expr: 1.02; deg: 0.12; theta: 5.69; asym: 3.86; tree : (-1 AND 4)
# >> G_1: init: 0.62; noise: 1.00; b: 3.14; m: 4.33; expr: 1.38; deg: 0.09; theta: 4.27; asym: 4.17; tree : (3 AND 1)
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 8.53; expr: 2.06; deg: 0.35; theta: 6.05; asym: 6.56; tree : -5
# >> G_3: init: 1.18; noise: 1.00; b: 1.60; m: 9.20; expr: 1.20; deg: 0.10; theta: 0.37; asym: 4.86; tree : (5 OR -2)
# >> G_4: init: 0.32; noise: 8.12; b: 1.25; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.57; asym: 3.23; tree : -2
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 0.98; noise: 1.05; b: 0.40; m: 6.52; expr: 1.02; deg: 0.12; theta: 5.69; asym: 3.86; tree : (-1 AND 5)
# >> G_1: init: 0.62; noise: 1.00; b: 3.14; m: 4.33; expr: 1.38; deg: 0.09; theta: 4.09; asym: 4.17; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 6.33; expr: 2.06; deg: 0.39; theta: 6.05; asym: 7.47; tree : -5
# >> G_3: init: 1.48; noise: 0.31; b: 4.34; m: 2.92; expr: 3.02; deg: 1.08; theta: 7.17; asym: 5.15; tree : (2 AND 5)
# >> G_4: init: 0.36; noise: 8.12; b: 1.28; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.85; asym: 3.23; tree : -4
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 0.89; noise: 1.05; b: 0.40; m: 6.52; expr: 1.02; deg: 0.13; theta: 5.69; asym: 3.86; tree : (-1 AND 5)
# >> G_1: init: 0.62; noise: 1.16; b: 3.14; m: 4.33; expr: 1.38; deg: 0.09; theta: 4.09; asym: 4.17; tree : -0
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 6.95; expr: 2.06; deg: 0.39; theta: 6.05; asym: 7.47; tree : -5
# >> G_3: init: 1.48; noise: 0.31; b: 4.34; m: 2.92; expr: 3.01; deg: 1.21; theta: 7.17; asym: 5.31; tree : (3 AND 5)
# >> G_4: init: 0.39; noise: 8.12; b: 1.28; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.85; asym: 3.23; tree : -4
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.12; noise: 1.05; b: 0.40; m: 6.52; expr: 1.02; deg: 0.13; theta: 5.69; asym: 3.86; tree : (-1 AND 5)
# >> G_1: init: 0.62; noise: 1.00; b: 3.14; m: 4.33; expr: 1.38; deg: 0.09; theta: 4.09; asym: 4.17; tree : (-0 AND 2)
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 6.74; expr: 2.06; deg: 0.39; theta: 6.05; asym: 7.47; tree : -5
# >> G_3: init: 1.48; noise: 0.31; b: 4.34; m: 2.92; expr: 3.02; deg: 1.08; theta: 7.17; asym: 5.15; tree : ((2 AND 5) OR -0)
# >> G_4: init: 0.43; noise: 8.12; b: 1.28; m: 2.54; expr: 1.26; deg: 2.05; theta: 4.90; asym: 3.23; tree : -4
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.12; noise: 1.05; b: 0.40; m: 6.52; expr: 1.02; deg: 0.13; theta: 5.69; asym: 3.86; tree : (-1 AND (5 OR -4))
# >> G_1: init: 0.62; noise: 0.91; b: 3.14; m: 4.33; expr: 1.38; deg: 0.09; theta: 4.09; asym: 4.17; tree : (-0 AND 2)
# >> G_2: init: 2.07; noise: 2.59; b: 1.56; m: 6.33; expr: 2.06; deg: 0.39; theta: 6.05; asym: 7.47; tree : -5
# >> G_3: init: 1.48; noise: 0.31; b: 4.85; m: 2.92; expr: 3.02; deg: 1.08; theta: 6.81; asym: 5.15; tree : 2
# >> G_4: init: 0.36; noise: 8.12; b: 1.28; m: 2.54; expr: 1.26; deg: 2.05; theta: 5.47; asym: 3.23; tree : -4
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.12; noise: 0.92; b: 0.40; m: 6.52; expr: 1.02; deg: 0.13; theta: 5.69; asym: 3.14; tree : (-1 AND 5)
# >> G_1: init: 0.62; noise: 0.92; b: 3.14; m: 4.33; expr: 1.19; deg: 0.09; theta: 4.09; asym: 3.51; tree : (-0 AND -4)
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 6.33; expr: 2.06; deg: 0.39; theta: 6.05; asym: 7.47; tree : -5
# >> G_3: init: 1.48; noise: 0.31; b: 4.34; m: 2.92; expr: 3.02; deg: 1.08; theta: 7.17; asym: 5.15; tree : ((2 AND 5) AND 3)
# >> G_4: init: 0.36; noise: 8.35; b: 1.48; m: 2.54; expr: 1.22; deg: 2.05; theta: 6.20; asym: 3.23; tree : -4
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.12; noise: 0.92; b: 0.40; m: 6.52; expr: 1.02; deg: 0.13; theta: 5.69; asym: 3.23; tree : (-1 AND 5)
# >> G_1: init: 0.66; noise: 0.92; b: 3.14; m: 4.33; expr: 1.19; deg: 0.09; theta: 4.09; asym: 3.51; tree : (-0 AND -4)
# >> G_2: init: 2.07; noise: 2.59; b: 1.79; m: 6.33; expr: 2.06; deg: 0.39; theta: 6.05; asym: 7.47; tree : -5
# >> G_3: init: 1.48; noise: 0.31; b: 4.34; m: 2.92; expr: 3.02; deg: 1.08; theta: 7.17; asym: 5.15; tree : ((2 AND 5) AND 3)
# >> G_4: init: 0.38; noise: 8.35; b: 1.48; m: 2.54; expr: 1.22; deg: 2.05; theta: 6.20; asym: 3.23; tree : (-0 AND 1)
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.00; noise: 1.00; b: 2.43; m: 4.79; expr: 1.00; deg: 0.10; theta: 1.27; asym: 5.00; tree : (-2 AND -4)
# >> G_1: init: 1.26; noise: 1.00; b: 2.19; m: 8.46; expr: 1.00; deg: 0.10; theta: 3.13; asym: 5.00; tree : -4
# >> G_2: init: 1.75; noise: 1.00; b: 2.97; m: 4.86; expr: 1.00; deg: 0.10; theta: 3.35; asym: 5.00; tree : 2
# >> G_3: init: 1.22; noise: 1.00; b: 0.91; m: 8.94; expr: 1.00; deg: 0.10; theta: 1.40; asym: 5.00; tree : 3
# >> G_4: init: 0.12; noise: 1.00; b: 0.16; m: 6.11; expr: 1.00; deg: 0.10; theta: 4.55; asym: 5.00; tree : (0 OR 2)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.09; noise: 0.92; b: 0.40; m: 6.52; expr: 1.02; deg: 0.13; theta: 5.69; asym: 3.14; tree : (-1 AND 5)
# >> G_1: init: 0.62; noise: 0.92; b: 3.14; m: 4.33; expr: 1.19; deg: 0.09; theta: 4.09; asym: 3.51; tree : (-0 AND 1)
# >> G_2: init: 2.07; noise: 2.59; b: 1.98; m: 6.33; expr: 2.06; deg: 0.39; theta: 6.05; asym: 7.47; tree : -5
# >> G_3: init: 2.01; noise: 6.27; b: 3.67; m: 2.21; expr: 2.00; deg: 2.33; theta: 0.42; asym: 8.27; tree : (-0 OR 3)
# >> G_4: init: 0.35; noise: 8.35; b: 1.48; m: 2.54; expr: 1.22; deg: 2.05; theta: 6.20; asym: 3.23; tree : (-0 OR -3)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.09; noise: 0.92; b: 0.40; m: 6.52; expr: 1.02; deg: 0.13; theta: 6.47; asym: 3.14; tree : (-1 AND 5)
# >> G_1: init: 0.62; noise: 0.92; b: 3.14; m: 4.33; expr: 1.19; deg: 0.09; theta: 4.09; asym: 3.51; tree : (-0 AND -4)
# >> G_2: init: 2.07; noise: 2.59; b: 1.98; m: 6.33; expr: 2.06; deg: 0.39; theta: 6.05; asym: 8.62; tree : (-5 AND -2)
# >> G_3: init: 1.48; noise: 0.32; b: 4.34; m: 2.92; expr: 3.02; deg: 1.30; theta: 7.17; asym: 5.52; tree : ((2 AND 5) AND 3)
# >> G_4: init: 0.35; noise: 9.75; b: 1.48; m: 2.54; expr: 1.22; deg: 2.05; theta: 6.20; asym: 3.23; tree : -0
