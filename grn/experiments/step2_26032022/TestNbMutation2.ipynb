# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
import random
from lib.sde.mutate import mutate_gene4, mutate_tree

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None, nb_genes=4):
    return Solution(GRNMain(nb_genes, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
_MUTATE_FUNC = mutate_grn

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        global _MUTATE_FUNC
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    s_prog = score_stats_norm(bb.stats, ref.stats, col_stats=f"progenitor_pop_size",
                     col_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)
    s_all = score_stats_norm(bb.stats, ref.stats, col_stats=f"whole_pop_size",
                     col_ref="whole_pop_size", norm=2.0, *args, **kwargs)
    s_neuron = score_stats_norm(bb.stats, ref.stats, col_stats=f"neuron_pop_size",
                     col_ref="neuron_pop_size", col_norm_data="progenitor_pop_size",
                       col_norm_ref="progenitor_pop_size", norm=2.0, *args, **kwargs)

    return np.mean(s_prog + s_all + s_neuron)

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init),
                                  new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 3
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    ObjectiveStep(name="The ONE", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 30
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 25
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, name=None):
    args = get_prun()
    args.cb_init = cb_init
    args.name = name
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    print("Final score", np.mean(scores), "+-", np.std(scores))
    return np.mean(scores), np.std(scores), max(p1)

# %%
def mutate_grn_full(grn, temperature=0.1, param_prob=0.8):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        grn._params *= np.random.normal(1, temperature, shape)
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()

# %%
model = sm.StringModel("expfit_func{mutfunc}_i{i}")
mut_func = dict(
    fullctrl=lambda x: mutate_grn_full(x),
    full005=lambda x: mutate_grn_full(x, temperature=0.05),
    full02=lambda x: mutate_grn_full(x, temperature=0.2),
    fullprob07=lambda x: mutate_grn_full(x, param_prob=0.7),
    fullprob09=lambda x: mutate_grn_full(x, param_prob=0.9),
)

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
)

# %%
# main loop
exporter = Exporter(name="exp_mutfunc2_230222")
for (funcname, func), i in product(mut_func.items(), range(10)):
    name = model.fill(mutfunc=funcname, i=i)
    print(name)
    if name in exporter.list():
        continue
    _MUTATE_FUNC = func
    res = get_score_parametrized(callback_init)
    exporter(res, name)
# Out:
# Exporting at output/exp_mutfunc2_230222
# expfit_funcfullctrl_i0
# Step 0
# ++ Best 0.005633067077028449 for generation 0
# ++ Best 0.01033464315191776 for generation 4
# ++ Best 0.012428018281833278 for generation 14
# Step 100
# Step 200
# ++ Best 0.054111548839893664 for generation 235
# OVER
# Final score 0.026853114044352495 +- 0.009685849368249094
# expfit_funcfullctrl_i1
# Step 0
# ++ Best 0.005954476391756627 for generation 0
# ++ Best 0.01124819075998008 for generation 2
# ++ Best 0.050023313062306084 for generation 23
# Step 100
# Step 200
# OVER
# Final score 0.024417321477323766 +- 0.0132293633229334
# expfit_funcfullctrl_i2
# Step 0
# ++ Best 0.0059647207775084385 for generation 0
# ++ Best 0.010031893753530698 for generation 2
# ++ Best 0.010097811225158395 for generation 39
# ++ Best 0.010677713351940996 for generation 58
# ++ Best 0.011214021238378126 for generation 68
# ++ Best 0.01375174809880427 for generation 78
# Step 100
# Step 200
# ++ Best 0.01741633427485033 for generation 291
# OVER
# Final score 0.018741615979560654 +- 0.010217623565153192
# expfit_funcfullctrl_i3
# Step 0
# ++ Best 0.011472965967289818 for generation 0
# Step 100
# ++ Best 0.012740537678975029 for generation 132
# Step 200
# OVER
# Final score 0.012453304200043138 +- 0.0004326529939360881
# expfit_funcfullctrl_i4
# Step 0
# ++ Best 0.006211728324167708 for generation 0
# ++ Best 0.0070678810565331955 for generation 1
# ++ Best 0.007777573366246516 for generation 12
# ++ Best 0.009815689854848403 for generation 18
# ++ Best 0.03903201236685397 for generation 45
# Step 100
# Step 200
# OVER
# Final score 0.03553592263585896 +- 0.008194515182887047
# expfit_funcfullctrl_i5
# Step 0
# ++ Best 0.007889607150774254 for generation 0
# ++ Best 0.00889361941353052 for generation 2
# ++ Best 0.01043208083207586 for generation 22
# ++ Best 0.014245618769808593 for generation 61
# Step 100
# Step 200
# OVER
# Final score 0.012500630240658792 +- 0.0009933746378542204
# expfit_funcfullctrl_i6
# Step 0
# ++ Best 0.007123160849514491 for generation 0
# ++ Best 0.007346526059012468 for generation 8
# ++ Best 0.010589507486847742 for generation 9
# ++ Best 0.03951585206637554 for generation 13
# Step 100
# Step 200
# OVER
# Final score 0.025111148572598017 +- 0.010090548495861213
# expfit_funcfullctrl_i7
# Step 0
# ++ Best 0.007011828112697295 for generation 0
# ++ Best 0.009013803833230239 for generation 2
# ++ Best 0.009518937285973202 for generation 17
# ++ Best 0.009653725827959708 for generation 32
# ++ Best 0.010738424541209294 for generation 43
# ++ Best 0.011291381979656005 for generation 47
# Step 100
# Step 200
# ++ Best 0.012233989955544337 for generation 259
# ++ Best 0.015113820571991034 for generation 262
# ++ Best 0.016893897448162453 for generation 272
# OVER
# Final score 0.019260812328776526 +- 0.006249624297115309
# expfit_funcfullctrl_i8
# Step 0
# ++ Best 0.005801706676680042 for generation 0
# ++ Best 0.008807165348931414 for generation 3
# ++ Best 0.010461126676891091 for generation 4
# ++ Best 0.011084198407018584 for generation 14
# ++ Best 0.011660346876933021 for generation 52
# Step 100
# ++ Best 0.013386325812329868 for generation 156
# ++ Best 0.014797570390298815 for generation 165
# Step 200
# OVER
# Final score 0.020918967531858502 +- 0.01583636896205742
# expfit_funcfullctrl_i9
# Step 0
# ++ Best 0.010145195882002757 for generation 0
# ++ Best 0.010762863267166401 for generation 9
# Step 100
# ++ Best 0.011252677970499999 for generation 106
# ++ Best 0.011357181236211652 for generation 112
# ++ Best 0.011619862118604137 for generation 139
# Step 200
# ++ Best 0.03542521619689996 for generation 225
# OVER
# Final score 0.023608257925365646 +- 0.010097127796451371
# expfit_funcfull005_i0
# Step 0
# ++ Best 0.005632772079153126 for generation 0
# ++ Best 0.005859389884197141 for generation 1
# ++ Best 0.011348561761415023 for generation 5
# ++ Best 0.015378139297188509 for generation 19
# Step 100
# ++ Best 0.07071807382637539 for generation 153
# Step 200
# OVER
# Final score 0.008769443028178442 +- 0.009255505293106012
# expfit_funcfull005_i1
# Step 0
# ++ Best 0.005639330757369466 for generation 0
# ++ Best 0.005799471590701413 for generation 1
# ++ Best 0.006775135726113405 for generation 3
# ++ Best 0.009222097022632273 for generation 6
# ++ Best 0.009667597788557598 for generation 46
# ++ Best 0.010374654491764805 for generation 67
# ++ Best 0.010745212218442683 for generation 81
# ++ Best 0.011227703615309897 for generation 86
# Step 100
# ++ Best 0.011784529958573263 for generation 120
# ++ Best 0.012073791288028754 for generation 155
# ++ Best 0.01213772233386612 for generation 164
# ++ Best 0.012188291386399954 for generation 179
# Step 200
# ++ Best 0.014497687073799585 for generation 213
# OVER
# Final score 0.010698963943908148 +- 0.0033124612242964456
# expfit_funcfull005_i2
# Step 0
# ++ Best 0.010604661578480673 for generation 0
# ++ Best 0.011719620382109799 for generation 17
# ++ Best 0.020323246999839492 for generation 31
# ++ Best 0.042716973546513055 for generation 35
# Step 100
# Step 200
# OVER
# Final score 0.028030437695267037 +- 0.006949311300792886
# expfit_funcfull005_i3
# Step 0
# ++ Best 0.005628957672971806 for generation 0
# ++ Best 0.005634611429796669 for generation 1
# ++ Best 0.0057032446559585346 for generation 2
# ++ Best 0.009848807158397931 for generation 4
# ++ Best 0.010314899424329073 for generation 6
# ++ Best 0.03383492783530712 for generation 17
# ++ Best 0.04911437851082887 for generation 31
# Step 100
# Step 200
# OVER
# Final score 0.02335888065102834 +- 0.009275121662972013
# expfit_funcfull005_i4
# Step 0
# ++ Best 0.0056395455309693615 for generation 0
# ++ Best 0.005640766958229856 for generation 1
# ++ Best 0.006037392242128181 for generation 3
# ++ Best 0.009415501721331584 for generation 5
# ++ Best 0.010147191362357026 for generation 40
# ++ Best 0.01157798251514988 for generation 63
# ++ Best 0.016145555727435743 for generation 87
# ++ Best 0.022675934791661516 for generation 99
# Step 100
# Step 200
# OVER
# Final score 0.022363995563955383 +- 0.00998365243372954
# expfit_funcfull005_i5
# Step 0
# ++ Best 0.005869711995527114 for generation 0
# ++ Best 0.010300263739068054 for generation 1
# ++ Best 0.010459579361072968 for generation 27
# ++ Best 0.011116711762720374 for generation 61
# ++ Best 0.012914966619624841 for generation 67
# Step 100
# ++ Best 0.016017670773651564 for generation 168
# Step 200
# OVER
# Final score 0.011053284857367942 +- 0.0030826861886747285
# expfit_funcfull005_i6
# Step 0
# ++ Best 0.005706727485042775 for generation 0
# ++ Best 0.00589854299897907 for generation 1
# ++ Best 0.010080790156977193 for generation 4
# ++ Best 0.010420910777031736 for generation 6
# ++ Best 0.010542918385244104 for generation 92
# Step 100
# ++ Best 0.01903720626506283 for generation 137
# ++ Best 0.01907455340695604 for generation 184
# Step 200
# ++ Best 0.019746503768327282 for generation 214
# OVER
# Final score 0.01957693395462805 +- 0.0005174510168830612
# expfit_funcfull005_i7
# Step 0
# ++ Best 0.005639529800625755 for generation 0
# ++ Best 0.006208844452593721 for generation 1
# ++ Best 0.009773756490349133 for generation 2
# ++ Best 0.06992807032767619 for generation 21
# ++ Best 0.07132633315002813 for generation 54
# ++ Best 0.07985679894955194 for generation 60
# Step 100
# Step 200
# OVER
# Final score 0.04403942745445241 +- 0.015210694311353438
# expfit_funcfull005_i8
# Step 0
# ++ Best 0.005712030339918329 for generation 0
# ++ Best 0.006058801028324836 for generation 1
# ++ Best 0.009847349052567499 for generation 2
# ++ Best 0.024252356270267193 for generation 5
# Step 100
# Step 200
# OVER
# Final score 0.008863187166923256 +- 0.007576885559074126
# expfit_funcfull005_i9
# Step 0
# ++ Best 0.005624377975614203 for generation 0
# ++ Best 0.00852900788087425 for generation 1
# ++ Best 0.011328525828741349 for generation 3
# ++ Best 0.013870949134064567 for generation 7
# ++ Best 0.01516725516647277 for generation 27
# Step 100
# ++ Best 0.019990238105788573 for generation 179
# Step 200
# ++ Best 0.024350245861422107 for generation 279
# OVER
# Final score 0.021110910553841965 +- 0.002584919616819792
# expfit_funcfull02_i0
# Step 0
# ++ Best 0.01041775245236369 for generation 0
# ++ Best 0.010892957129099353 for generation 1
# ++ Best 0.013108064277921194 for generation 12
# ++ Best 0.013934653632414794 for generation 14
# Step 100
# Step 200
# ++ Best 0.019110482529361105 for generation 234
# OVER
# Final score 0.016763632826935788 +- 0.005676176430464575
# expfit_funcfull02_i1
# Step 0
# ++ Best 0.008263444863829414 for generation 0
# ++ Best 0.008408300966883418 for generation 4
# ++ Best 0.012510480116915931 for generation 5
# Step 100
# Step 200
# OVER
# Final score 0.011925532584353943 +- 0.002662804765045977
# expfit_funcfull02_i2
# Step 0
# ++ Best 0.007161506721908749 for generation 0
# ++ Best 0.010364716856657285 for generation 1
# ++ Best 0.011104651588493586 for generation 11
# ++ Best 0.011151043229975972 for generation 87
# ++ Best 0.013267067202875075 for generation 94
# Step 100
# Step 200
# OVER
# Final score 0.01112743462462914 +- 0.0021497129003114333
# expfit_funcfull02_i3
# Step 0
# ++ Best 0.005634839948365909 for generation 0
# ++ Best 0.005636094146226109 for generation 3
# ++ Best 0.007568142103267958 for generation 5
# ++ Best 0.00839020147901967 for generation 18
# ++ Best 0.014234462680631148 for generation 24
# Step 100
# Step 200
# ++ Best 0.027155513492310334 for generation 203
# ++ Best 0.04193512425855985 for generation 224
# OVER
# Final score 0.025442879292713348 +- 0.021491195279617084
# expfit_funcfull02_i4
# Step 0
# ++ Best 0.006632325186880709 for generation 0
# ++ Best 0.0069051112776993 for generation 3
# ++ Best 0.011641886358607847 for generation 14
# ++ Best 0.011660901391754843 for generation 30
# ++ Best 0.015904700333859944 for generation 35
# ++ Best 0.04140308202965496 for generation 71
# Step 100
# Step 200
# OVER
# Final score 0.01761907054547528 +- 0.014381507492749622
# expfit_funcfull02_i5
# Step 0
# ++ Best 0.005632772079153126 for generation 0
# ++ Best 0.0056408530407474535 for generation 1
# ++ Best 0.011949352600430195 for generation 2
# ++ Best 0.020048939189479927 for generation 5
# Step 100
# Step 200
# OVER
# Final score 0.016384790019203836 +- 0.007993883076416068
# expfit_funcfull02_i6
# Step 0
# ++ Best 0.005715560120063912 for generation 0
# ++ Best 0.009841855597147453 for generation 1
# ++ Best 0.010975513188088452 for generation 45
# ++ Best 0.011196653741496821 for generation 71
# ++ Best 0.011789879581032883 for generation 78
# Step 100
# ++ Best 0.011865945438760036 for generation 170
# ++ Best 0.013079545261437953 for generation 176
# ++ Best 0.013463065173104954 for generation 199
# Step 200
# ++ Best 0.0190952005169246 for generation 257
# OVER
# Final score 0.020206678494670897 +- 0.0013643566161312402
# expfit_funcfull02_i7
# Step 0
# ++ Best 0.005987190237930956 for generation 0
# ++ Best 0.008264596472933018 for generation 1
# ++ Best 0.009207277965930983 for generation 3
# ++ Best 0.010325898944357372 for generation 11
# ++ Best 0.01658700068576494 for generation 49
# ++ Best 0.07435072228359739 for generation 70
# Step 100
# Step 200
# OVER
# Final score 0.024724805280309084 +- 0.01761099126864241
# expfit_funcfull02_i8
# Step 0
# ++ Best 0.005632772079153126 for generation 0
# ++ Best 0.0056395455309693615 for generation 1
# ++ Best 0.005712954209860035 for generation 2
# ++ Best 0.00589874972621453 for generation 7
# ++ Best 0.007148556039218467 for generation 9
# ++ Best 0.008826846239559783 for generation 16
# ++ Best 0.008895374715344838 for generation 28
# ++ Best 0.010918316249967041 for generation 34
# ++ Best 0.01576969539744837 for generation 46
# ++ Best 0.016112487782312376 for generation 57
# ++ Best 0.02645724911990158 for generation 90
# Step 100
# Step 200
# ++ Best 0.04049101299311859 for generation 233
# OVER
# Final score 0.02451497755660422 +- 0.007334300252576899
# expfit_funcfull02_i9
# Step 0
# ++ Best 0.00575517214982581 for generation 0
# ++ Best 0.008561703812837676 for generation 4
# ++ Best 0.009042219485165834 for generation 10
# ++ Best 0.009415252298947656 for generation 11
# ++ Best 0.01027327234091384 for generation 12
# ++ Best 0.010898639519345292 for generation 54
# ++ Best 0.015588871010702046 for generation 80
# Step 100
# ++ Best 0.017553898560738215 for generation 174
# Step 200
# OVER
# Final score 0.015287432509239727 +- 0.0016351080714126893
# expfit_funcfullprob07_i0
# Step 0
# ++ Best 0.006900883768624412 for generation 0
# ++ Best 0.010263624204346131 for generation 6
# ++ Best 0.0115951874056934 for generation 8
# ++ Best 0.013123769196802805 for generation 82
# Step 100
# Step 200
# ++ Best 0.016250884671015133 for generation 271
# OVER
# Final score 0.018682480037233617 +- 0.002443048288349469
# expfit_funcfullprob07_i1
# Step 0
# ++ Best 0.008049386404655594 for generation 0
# ++ Best 0.009054579194642875 for generation 2
# ++ Best 0.010306818911333488 for generation 3
# ++ Best 0.011518241999624472 for generation 32
# ++ Best 0.016630528296359377 for generation 42
# Step 100
# Step 200
# OVER
# Final score 0.01216277295681524 +- 0.0034666357674752245
# expfit_funcfullprob07_i2
# Step 0
# ++ Best 0.005700307982446078 for generation 0
# ++ Best 0.006992728084956968 for generation 1
# ++ Best 0.009940462816728992 for generation 2
# ++ Best 0.010101559937695872 for generation 8
# ++ Best 0.011371386683654094 for generation 27
# ++ Best 0.0364475192391051 for generation 70
# Step 100
# Step 200
# OVER
# Final score 0.006249911012741761 +- 0.005091620538631493
# expfit_funcfullprob07_i3
# Step 0
# ++ Best 0.010088221570696613 for generation 0
# ++ Best 0.016242073244924268 for generation 6
# Step 100
# Step 200
# OVER
# Final score 0.02442213970236387 +- 0.016614263043611095
# expfit_funcfullprob07_i4
# Step 0
# ++ Best 0.0036916594675564527 for generation 0
# ++ Best 0.010059315738299289 for generation 1
# ++ Best 0.010979837574347638 for generation 64
# ++ Best 0.011735299172130734 for generation 92
# Step 100
# Step 200
# ++ Best 0.020904891930875455 for generation 223
# OVER
# Final score 0.011399941770442557 +- 0.005925027802015627
# expfit_funcfullprob07_i5
# Step 0
# ++ Best 0.005632772079153126 for generation 0
# ++ Best 0.009666167105378213 for generation 1
# ++ Best 0.01009188906480323 for generation 18
# ++ Best 0.013436473786448438 for generation 22
# ++ Best 0.016576817150285212 for generation 26
# Step 100
# Step 200
# ++ Best 0.021622182319461957 for generation 295
# OVER
# Final score 0.01157223273728778 +- 0.010145014857143857
# expfit_funcfullprob07_i6
# Step 0
# ++ Best 0.005776736362221852 for generation 0
# ++ Best 0.0058006047654558445 for generation 6
# ++ Best 0.007129111553977073 for generation 8
# ++ Best 0.010256794801384455 for generation 10
# ++ Best 0.011046276529233923 for generation 42
# Step 100
# ++ Best 0.012928632100036254 for generation 114
# Step 200
# OVER
# Final score 0.012328382989878432 +- 0.0007145989891112674
# expfit_funcfullprob07_i7
# Step 0
# ++ Best 0.006876000035122615 for generation 0
# ++ Best 0.009170575524677892 for generation 2
# ++ Best 0.009934757176237085 for generation 6
# ++ Best 0.010167160914041639 for generation 17
# ++ Best 0.01029170943434389 for generation 26
# ++ Best 0.012538680932857526 for generation 55
# ++ Best 0.04790145972226138 for generation 88
# Step 100
# Step 200
# OVER
# Final score 0.035813910423558956 +- 0.017246265683389248
# expfit_funcfullprob07_i8
# Step 0
# ++ Best 0.005716540456587368 for generation 0
# ++ Best 0.007894889529307288 for generation 5
# ++ Best 0.02472142910394352 for generation 9
# Step 100
# Step 200
# ++ Best 0.03131670389844425 for generation 224
# ++ Best 0.05031429093761741 for generation 294
# OVER
# Final score 0.032250958371761 +- 0.012216704039751298
# expfit_funcfullprob07_i9
# Step 0
# ++ Best 0.006650696313214613 for generation 0
# ++ Best 0.008628725301686757 for generation 1
# ++ Best 0.017023169444931242 for generation 2
# Step 100
# Step 200
# OVER
# Final score 0.008031584840536603 +- 0.004536601396143406
# expfit_funcfullprob09_i0
# Step 0
# ++ Best 0.0056262621343962154 for generation 0
# ++ Best 0.00571618112491634 for generation 2
# ++ Best 0.01015208079259281 for generation 3
# ++ Best 0.011045754325896278 for generation 61
# ++ Best 0.014241252658530884 for generation 78
# Step 100
# Step 200
# OVER
# Final score 0.014306819300887286 +- 0.005641127937113249
# expfit_funcfullprob09_i1
# Step 0
# ++ Best 0.0037589280324412575 for generation 0
# ++ Best 0.005634611429796669 for generation 1
# ++ Best 0.007189348049680021 for generation 2
# ++ Best 0.010062448859615585 for generation 10
# ++ Best 0.015874405220337246 for generation 19
# Step 100
# Step 200
# OVER
# Final score 0.016847856786876194 +- 0.004378108758499577
# expfit_funcfullprob09_i2
# Step 0
# ++ Best 0.0057176669588600935 for generation 0
# ++ Best 0.02774364846665024 for generation 4
# ++ Best 0.04467602792230887 for generation 84
# Step 100
# ++ Best 0.045386808540358155 for generation 197
# Step 200
# OVER
# Final score 0.013447647903247784 +- 0.006937597698679986
# expfit_funcfullprob09_i3
# Step 0
# ++ Best 0.01071161193283309 for generation 0
# ++ Best 0.01464847832695702 for generation 21
# Step 100
# Step 200
# ++ Best 0.024454034532674945 for generation 216
# OVER
# Final score 0.022671662007561613 +- 0.01777675312217117
# expfit_funcfullprob09_i4
# Step 0
# ++ Best 0.007636293417484521 for generation 0
# ++ Best 0.008868635236568114 for generation 1
# ++ Best 0.009289652381562258 for generation 13
# ++ Best 0.011070296554495934 for generation 26
# Step 100
# ++ Best 0.011683081752317076 for generation 109
# ++ Best 0.024115460626899576 for generation 158
# Step 200
# OVER
# Final score 0.019156685502292728 +- 0.0016421091463183015
# expfit_funcfullprob09_i5
# Step 0
# ++ Best 0.007474600509301567 for generation 0
# ++ Best 0.009303071736428924 for generation 9
# ++ Best 0.01040443279399278 for generation 17
# ++ Best 0.010496272809996017 for generation 18
# ++ Best 0.016800563723880373 for generation 40
# Step 100
# Step 200
# OVER
# Final score 0.01653416672024397 +- 0.001428345582831645
# expfit_funcfullprob09_i6
# Step 0
# ++ Best 0.0038355585326428515 for generation 0
# ++ Best 0.005777676288656661 for generation 1
# ++ Best 0.00579812041122198 for generation 2
# ++ Best 0.006152075103968251 for generation 5
# ++ Best 0.007066792287063537 for generation 7
# ++ Best 0.010285851247928626 for generation 8
# ++ Best 0.010293069933730957 for generation 65
# ++ Best 0.010295258642615749 for generation 96
# Step 100
# ++ Best 0.010755950460021698 for generation 159
# Step 200
# ++ Best 0.011025161989307744 for generation 295
# ++ Best 0.011198441334641016 for generation 296
# OVER
# Final score 0.010982476009536182 +- 0.0002610600422166188
# expfit_funcfullprob09_i7
# Step 0
# ++ Best 0.005618976491540063 for generation 0
# ++ Best 0.005780367016900089 for generation 1
# ++ Best 0.00947106514866955 for generation 2
# ++ Best 0.009719897240946322 for generation 10
# ++ Best 0.01134152978993632 for generation 31
# ++ Best 0.05737916228968095 for generation 43
# Step 100
# Step 200
# OVER
# Final score 0.02143553807401931 +- 0.021227297857338796
# expfit_funcfullprob09_i8
# Step 0
# ++ Best 0.0056262621343962154 for generation 0
# ++ Best 0.005634885461360977 for generation 1
# ++ Best 0.005802969295743021 for generation 2
# ++ Best 0.009846166954050913 for generation 4
# ++ Best 0.0103416369602791 for generation 28
# ++ Best 0.011884303966007186 for generation 33
# Step 100
# ++ Best 0.013439599708738327 for generation 116
# ++ Best 0.013729116624466067 for generation 148
# Step 200
# ++ Best 0.04926996238461364 for generation 224
# OVER
# Final score 0.010311765111563159 +- 0.009303290035277254
# expfit_funcfullprob09_i9
# Step 0
# ++ Best 0.005626799342454625 for generation 0
# ++ Best 0.00616371314895822 for generation 1
# ++ Best 0.008483680668180203 for generation 2
# ++ Best 0.009902541074546465 for generation 7
# ++ Best 0.03895990217282533 for generation 12
# Step 100
# Step 200
# OVER
# Final score 0.008961356533091649 +- 0.006680243376526701

# %%
show_curve(sol.stats, REF.stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-30abeee9d69e> in <module>
# ----> 1 show_curve(sol.stats, REF.stats)
#
# NameError: name 'sol' is not defined

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#       mutfunc  i      mean        sd       max
# 0      full02  0  0.016764  0.005676  0.019110
# 1  fullprob09  0  0.014307  0.005641  0.014241
# 2     full005  7  0.044039  0.015211  0.079857
# 3  fullprob09  2  0.013448  0.006938  0.045387
# 4      full02  9  0.015287  0.001635  0.017554

# %%
new_df = df.groupby(["mutfunc"]).mean()
new_df
# Out:
#                 mean        sd       max
# mutfunc
# full005     0.019787  0.006775  0.036395
# full02      0.018400  0.008230  0.029977
# fullctrl    0.021940  0.008503  0.029420
# fullprob07  0.017291  0.007840  0.025627
# fullprob09  0.015466  0.007528  0.029768

# %%
for i, row in new_df.iterrows():
    print(row.name, row["mean"], row["mean"] - row.sd / np.sqrt(10), row["mean"] + row.sd / np.sqrt(10))
# Out:
# full005 0.019786546486955096 0.017644144842056696 0.021928948131853497
# full02 0.018399723373413526 0.01579716771582507 0.02100227903100198
# fullctrl 0.02194010949363965 0.019251318129949877 0.02462890085732942
# fullprob07 0.01729143148426198 0.01481221274287393 0.01977065022565003
# fullprob09 0.015465597394931987 0.013085163364576628 0.017846031425287345

# %%
row.name
