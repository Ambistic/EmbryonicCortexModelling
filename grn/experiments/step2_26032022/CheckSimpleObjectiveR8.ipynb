# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_n, ref_n = normalize_time(stats, ref_stats, "neuron_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_n = stats_n.set_index("time")
    
    prog = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron = stats_n.loc[last_time_stats]["neuron_pop_size"]
    
    ref_prog = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron = ref_n.loc[last_time_ref]["neuron_pop_size"]

    return 1 / max(1, 1000 - abs(prog - ref_prog) - abs(neuron - ref_neuron))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r8"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r8
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 967.3574039118035 for generation 0
# [out] ++ Best 974.4448887792396 for generation 1
# [out] ++ Best 974.4857051057701 for generation 4
# Step 3 passed !
# [out] ++ Best 974.5469295955661 for generation 17
# [out] ++ Best 974.8530520445457 for generation 19
# [out] ++ Best 975.1999908200559 for generation 29
# [out] ++ Best 975.4857051057701 for generation 31
# [out] ++ Best 977.2816234731171 for generation 32
# [out] ++ Best 983.3632561261784 for generation 38
# Saving ...
# [out] ++ Best 983.7101949016886 for generation 52
# [out] ++ Best 984.1591744935253 for generation 62
# [out] ++ Best 984.7306030649538 for generation 83
# [out] ++ Best 984.8938683710761 for generation 91
# [out] ++ Best 991.5265214323008 for generation 98
# [out] ++ Best 993.4857051057703 for generation 99
# Saving ...
# [out] Step 100
# [out] ++ Best 998.0775418404639 for generation 115
# Saving ...
# [out] ++ Best 998.3020316363824 for generation 181
# Saving ...
# [out] Step 200
# [out] ++ Best 998.4448887792397 for generation 206
# Saving ...
# [out] ++ Best 998.5609634351351 for generation 266
# Saving ...
# [out] Step 300
# [out] ++ Best 998.5673377588314 for generation 339
# Saving ...
# Saving ...
# [out] Step 400
# Saving ...
# [out] ++ Best 998.6425960881965 for generation 462
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# Saving ...
# [out] ++ Best 998.7038205779924 for generation 757
# Saving ...
# [out] Step 800
# Saving ...
# Saving ...
# [out] Step 900
# [out] ++ Best 998.7854532310536 for generation 915
# Saving ...
# [out] ++ Best 998.9755010241377 for generation 998
# Saving ...
# [out] Step 1000
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# Saving ...
# [out] Step 1300
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# [out] ++ Best 999.030351190237 for generation 1947
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# [out] ++ Best 999.0367255139334 for generation 2050
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r8

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))
# Out:
# (997.3020316363824,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5              2.0                 81.0  56.5            83.0
# 57.0              3.0                 84.0  57.0            87.0
# 57.5              3.0                 89.0  57.5            92.0
# 58.0              3.0                 92.0  58.0            95.0
# ...               ...                  ...   ...             ...
# 84.0           1128.0                 48.0  84.0          1176.0
# 84.5           1135.0                 43.0  84.5          1178.0
# 85.0           1143.0                 42.0  85.0          1185.0
# 85.5           1150.0                 35.0  85.5          1185.0
# 86.0           1152.0                 33.0  86.0          1185.0
#
# [61 rows x 4 columns])
# (998.3020316363824,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5              1.0                 73.0  56.5            74.0
# 57.0              1.0                 81.0  57.0            82.0
# 57.5              3.0                 87.0  57.5            90.0
# 58.0              3.0                 93.0  58.0            96.0
# ...               ...                  ...   ...             ...
# 84.0           1168.0                 52.0  84.0          1220.0
# 84.5           1178.0                 48.0  84.5          1226.0
# 85.0           1186.0                 44.0  85.0          1230.0
# 85.5           1192.0                 42.0  85.5          1234.0
# 86.0           1201.0                 33.0  86.0          1234.0
#
# [61 rows x 4 columns])
# (998.1323920065637,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5              1.0                 78.0  56.5            79.0
# 57.0              1.0                 86.0  57.0            87.0
# 57.5              1.0                 92.0  57.5            93.0
# 58.0              1.0                 96.0  58.0            97.0
# ...               ...                  ...   ...             ...
# 84.0           1228.0                 53.0  84.0          1281.0
# 84.5           1242.0                 43.0  84.5          1285.0
# 85.0           1247.0                 40.0  85.0          1287.0
# 85.5           1251.0                 40.0  85.5          1291.0
# 86.0           1253.0                 38.0  86.0          1291.0
#
# [61 rows x 4 columns])
# (998.2344328228902,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5              0.0                 78.0  56.5            78.0
# 57.0              0.0                 90.0  57.0            90.0
# 57.5              0.0                 97.0  57.5            97.0
# 58.0              0.0                 98.0  58.0            98.0
# ...               ...                  ...   ...             ...
# 84.0           1210.0                 70.0  84.0          1280.0
# 84.5           1216.0                 74.0  84.5          1290.0
# 85.0           1230.0                 65.0  85.0          1295.0
# 85.5           1244.0                 52.0  85.5          1296.0
# 86.0           1253.0                 43.0  86.0          1296.0
#
# [61 rows x 4 columns])
# (998.8326438812804,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5              0.0                 77.0  56.5            77.0
# 57.0              0.0                 86.0  57.0            86.0
# 57.5              1.0                 92.0  57.5            93.0
# 58.0              1.0                 97.0  58.0            98.0
# ...               ...                  ...   ...             ...
# 84.0           1181.0                 69.0  84.0          1250.0
# 84.5           1197.0                 57.0  84.5          1254.0
# 85.0           1205.0                 50.0  85.0          1255.0
# 85.5           1212.0                 48.0  85.5          1260.0
# 86.0           1220.0                 40.0  86.0          1260.0
#
# [61 rows x 4 columns])

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 8.28; asym: 5.00; tree : 0
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 9.00; expr: 1.00; deg: 0.10; theta: 10.35; asym: 5.00; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 8.87; asym: 5.00; tree : ((2 OR 3) OR 1)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 5.59; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.57; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.26; asym: 5.00; tree : ((3 AND -4) OR -0)
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : 0
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 9.00; expr: 1.00; deg: 0.10; theta: 9.15; asym: 5.00; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 8.87; asym: 5.00; tree : (2 OR 1)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.40; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.57; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.26; asym: 5.00; tree : ((3 AND -4) OR -0)
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : 0
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 9.00; expr: 1.00; deg: 0.10; theta: 9.15; asym: 5.00; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 7.81; asym: 5.00; tree : (2 OR 1)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.57; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.28; asym: 5.00; tree : (2 OR -0)
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 7.31; asym: 5.00; tree : 0
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 9.00; expr: 1.00; deg: 0.10; theta: 8.51; asym: 5.00; tree : (-3 AND 4)
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 7.81; asym: 5.00; tree : (2 OR 1)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 4.36; tree : 3
# >> G_4: init: 1.99; noise: 0.57; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.15; asym: 4.19; tree : (2 OR -0)
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 6.46; asym: 4.32; tree : 0
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 4.73; expr: 1.00; deg: 0.10; theta: 8.91; asym: 5.00; tree : (-3 OR 1)
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 8.97; asym: 5.00; tree : (2 OR 1)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.57; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.26; asym: 3.38; tree : (3 OR -0)
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 8.75; asym: 5.00; tree : 0
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 9.00; expr: 1.00; deg: 0.10; theta: 8.37; asym: 5.00; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 8.11; asym: 5.00; tree : 2
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 4.25; tree : 3
# >> G_4: init: 1.99; noise: 0.57; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.68; asym: 5.00; tree : ((3 OR 2) AND 0)
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 7.79; asym: 4.15; tree : (0 OR 1)
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 9.00; expr: 1.00; deg: 0.10; theta: 10.05; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 7.48; asym: 5.00; tree : ((2 AND 0) OR 1)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.16; asym: 4.09; tree : (3 OR -0)
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 8.75; asym: 5.00; tree : 0
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 9.00; expr: 1.00; deg: 0.10; theta: 8.37; asym: 5.00; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 11.42; asym: 5.00; tree : 2
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.57; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.86; asym: 5.00; tree : 4
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 7.40; asym: 3.27; tree : (0 OR 1)
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 9.00; expr: 1.00; deg: 0.10; theta: 7.79; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 8.97; asym: 3.67; tree : (2 OR 4)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.05; asym: 4.09; tree : (3 OR -0)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 7.40; asym: 4.09; tree : 4
# >> G_1: init: 0.32; noise: 0.33; b: 0.51; m: 9.00; expr: 1.00; deg: 0.10; theta: 8.11; asym: 4.25; tree : (-3 AND 5)
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 2.03; deg: 0.10; theta: 8.09; asym: 4.18; tree : (4 OR 1)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.25; asym: 3.34; tree : (3 OR -0)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 7.70; asym: 4.09; tree : 4
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 13.11; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 8.97; asym: 4.18; tree : (NOT 2 OR 4)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.59; asym: 4.09; tree : (3 OR -0)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 5.38; asym: 4.09; tree : 4
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 13.59; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 9.91; asym: 4.18; tree : (NOT 2 OR 4)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.59; asym: 4.09; tree : (3 OR -0)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 7.82; asym: 4.09; tree : ((4 OR 1) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 14.37; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.77; asym: 4.18; tree : (NOT 2 OR 5)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.85; asym: 4.09; tree : (3 OR -0)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 7.70; asym: 4.09; tree : 4
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 12.58; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.77; asym: 3.58; tree : (NOT 2 OR 5)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.99; asym: 4.09; tree : ((3 AND 4) OR -0)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 8.02; asym: 3.34; tree : ((4 OR 1) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 14.37; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.81; asym: 4.18; tree : (NOT 2 OR 5)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 2.34; asym: 4.09; tree : (3 OR -0)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 8.95; asym: 3.34; tree : ((4 OR 1) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 14.48; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.81; asym: 4.18; tree : (NOT 2 OR 5)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 1.95; asym: 4.09; tree : (5 OR -0)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 10.42; asym: 3.34; tree : ((4 OR 1) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 13.03; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.83; asym: 4.18; tree : (NOT 3 OR 5)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 0.52; asym: 4.09; tree : (5 OR -0)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 8.28; asym: 2.88; tree : (4 OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 16.52; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.81; asym: 3.35; tree : (NOT 2 OR 5)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 2.30; asym: 3.53; tree : -0
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 8.28; asym: 2.88; tree : (4 OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 17.78; asym: 4.25; tree : -3
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.81; asym: 3.35; tree : (NOT 2 OR 5)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.99; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 2.30; asym: 2.99; tree : (-0 OR 5)
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 11.75; asym: 3.34; tree : ((4 OR 1) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 14.15; asym: 4.25; tree : (-3 AND 5)
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.96; asym: 4.18; tree : 5
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : 3
# >> G_4: init: 1.77; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 0.48; asym: 4.09; tree : ((5 OR 2) OR -0)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 14.26; asym: 3.34; tree : ((4 OR 1) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 13.18; asym: 3.70; tree : (-3 AND 5)
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.96; asym: 4.18; tree : 5
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : (3 OR 1)
# >> G_4: init: 1.77; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 0.52; asym: 4.09; tree : (5 OR NOT -0)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 14.70; asym: 3.34; tree : ((4 OR 1) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 14.05; asym: 3.70; tree : (-3 AND 5)
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.96; asym: 4.18; tree : (5 AND 0)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : (3 OR 1)
# >> G_4: init: 1.77; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 0.52; asym: 4.09; tree : (5 OR -0)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 13.47; asym: 3.34; tree : ((4 OR 1) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 14.43; asym: 3.70; tree : (-3 AND 5)
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 1.08; asym: 4.18; tree : 5
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : (3 OR 1)
# >> G_4: init: 1.77; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 0.55; asym: 4.09; tree : (5 OR NOT (-0 AND 4))
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 13.88; asym: 3.34; tree : ((4 OR 3) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 13.18; asym: 2.52; tree : (-3 AND 5)
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 0.96; asym: 4.18; tree : 3
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : (3 OR 1)
# >> G_4: init: 1.77; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 0.47; asym: 3.50; tree : (5 OR NOT -0)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 13.47; asym: 2.78; tree : ((4 OR 1) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 14.43; asym: 3.70; tree : (-3 AND 5)
# >> G_2: init: 0.54; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 1.00; asym: 3.59; tree : 5
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : (3 OR 1)
# >> G_4: init: 1.77; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 0.50; asym: 3.43; tree : (3 OR NOT (-0 AND 4))
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.98; noise: 0.19; b: 2.93; m: 4.88; expr: 1.00; deg: 0.10; theta: 16.55; asym: 2.81; tree : ((4 OR 3) OR 5)
# >> G_1: init: 0.32; noise: 0.33; b: 8.59; m: 9.00; expr: 1.00; deg: 0.10; theta: 13.03; asym: 4.25; tree : (-3 AND (5 AND 4))
# >> G_2: init: 0.57; noise: 0.56; b: 2.08; m: 5.13; expr: 1.00; deg: 0.10; theta: 1.02; asym: 4.18; tree : ((5 AND 2) AND 3)
# >> G_3: init: 0.11; noise: 0.03; b: 2.51; m: 9.33; expr: 1.00; deg: 0.10; theta: 6.48; asym: 5.00; tree : (3 OR 1)
# >> G_4: init: 1.77; noise: 0.76; b: 2.99; m: 3.74; expr: 1.00; deg: 0.10; theta: 0.69; asym: 4.09; tree : -0
