# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_n, ref_n = normalize_time(stats, ref_stats, "neuron_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_n = stats_n.set_index("time")
    
    prog = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron = stats_n.loc[last_time_stats]["neuron_pop_size"]
    
    ref_prog = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron = ref_n.loc[last_time_ref]["neuron_pop_size"]

    return 1 / max(1, 1000 - abs(prog - ref_prog) - abs(neuron - ref_neuron))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r7"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r7
# [definition]
#
#
# Step 3 passed !
# [out] Step 0
# [out] ++ Best 974.1183581669947 for generation 0
# [out] ++ Best 974.3224397996478 for generation 1
# [out] ++ Best 978.3020316363823 for generation 4
# Saving ...
# [out] ++ Best 983.1533222791505 for generation 52
# [out] ++ Best 984.8676079934363 for generation 74
# [out] ++ Best 985.377812075069 for generation 90
# Saving ...
# [out] Step 100
# [out] ++ Best 986.7451590138445 for generation 101
# [out] ++ Best 990.657152037087 for generation 130
# [out] ++ Best 991.391845914638 for generation 149
# Saving ...
# [out] ++ Best 993.0104651362934 for generation 158
# [out] ++ Best 995.8063835036403 for generation 174
# Saving ...
# [out] Step 200
# [out] ++ Best 998.4798528913956 for generation 215
# Saving ...
# Saving ...
# [out] Step 300
# Saving ...
# Saving ...
# [out] Step 400
# [out] ++ Best 999.2961794220079 for generation 416
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# Saving ...
# Saving ...
# [out] Step 800
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# Saving ...
# [out] Step 1300
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r7

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))
# Out:
# (992.7247508505792,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5             27.0                 32.0  56.5            59.0
# 57.0             29.0                 35.0  57.0            64.0
# 57.5             36.0                 29.0  57.5            65.0
# 58.0             37.0                 31.0  58.0            68.0
# ...               ...                  ...   ...             ...
# 84.0            846.0                178.0  84.0          1024.0
# 84.5            869.0                183.0  84.5          1052.0
# 85.0            895.0                177.0  85.0          1072.0
# 85.5            913.0                184.0  85.5          1097.0
# 86.0            938.0                171.0  86.0          1109.0
#
# [61 rows x 4 columns])
# (989.5061132690356,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5             27.0                 34.0  56.5            61.0
# 57.0             32.0                 31.0  57.0            63.0
# 57.5             33.0                 35.0  57.5            68.0
# 58.0             35.0                 35.0  58.0            70.0
# ...               ...                  ...   ...             ...
# 84.0            657.0                101.0  84.0           758.0
# 84.5            667.0                110.0  84.5           777.0
# 85.0            692.0                 99.0  85.0           791.0
# 85.5            715.0                 80.0  85.5           795.0
# 86.0            720.0                 83.0  86.0           803.0
#
# [61 rows x 4 columns])
# (995.1673561187197,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5             24.0                 41.0  56.5            65.0
# 57.0             28.0                 40.0  57.0            68.0
# 57.5             30.0                 41.0  57.5            71.0
# 58.0             31.0                 43.0  58.0            74.0
# ...               ...                  ...   ...             ...
# 84.0           1135.0                269.0  84.0          1404.0
# 84.5           1176.0                284.0  84.5          1460.0
# 85.0           1217.0                275.0  85.0          1492.0
# 85.5           1251.0                280.0  85.5          1531.0
# 86.0           1289.0                265.0  86.0          1554.0
#
# [61 rows x 4 columns])
# (996.4594447281303,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5             22.0                 39.0  56.5            61.0
# 57.0             24.0                 40.0  57.0            64.0
# 57.5             26.0                 46.0  57.5            72.0
# 58.0             30.0                 44.0  58.0            74.0
# ...               ...                  ...   ...             ...
# 84.0            994.0                208.0  84.0          1202.0
# 84.5           1035.0                195.0  84.5          1230.0
# 85.0           1061.0                196.0  85.0          1257.0
# 85.5           1096.0                176.0  85.5          1272.0
# 86.0           1116.0                166.0  86.0          1282.0
#
# [61 rows x 4 columns])
# (996.9288324832322,       neuron_pop_size  progenitor_pop_size  time  whole_pop_size
# 56.0              0.0                 49.0  56.0            49.0
# 56.5             23.0                 39.0  56.5            62.0
# 57.0             27.0                 38.0  57.0            65.0
# 57.5             29.0                 40.0  57.5            69.0
# 58.0             31.0                 44.0  58.0            75.0
# ...               ...                  ...   ...             ...
# 84.0           1054.0                206.0  84.0          1260.0
# 84.5           1083.0                201.0  84.5          1284.0
# 85.0           1109.0                212.0  85.0          1321.0
# 85.5           1142.0                207.0  85.5          1349.0
# 86.0           1172.0                199.0  86.0          1371.0
#
# [61 rows x 4 columns])

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 8.89; asym: 5.00; tree : (3 OR NOT 4)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 7.61; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 9.15; asym: 5.00; tree : ((0 OR 2) OR (1 AND 3))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 9.24; asym: 5.00; tree : 5
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 7.85; asym: 5.00; tree : NOT 3
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 10.32; asym: 5.00; tree : (3 OR NOT 4)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 9.50; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.97; asym: 4.22; tree : ((0 OR 2) OR (1 AND 3))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 9.95; asym: 5.00; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 7.85; asym: 4.37; tree : NOT NOT 1
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 10.32; asym: 5.00; tree : (3 OR (NOT 4 OR 5))
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 10.11; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 7.96; asym: 5.00; tree : ((0 OR 2) OR (1 AND 3))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 10.75; asym: 5.00; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 9.16; asym: 5.00; tree : NOT NOT 1
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 9.27; asym: 4.37; tree : (3 OR NOT 4)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 10.49; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.00; asym: 4.22; tree : ((0 OR 2) OR (1 AND 5))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 10.63; asym: 5.00; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 7.85; asym: 4.37; tree : NOT NOT 1
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 10.63; asym: 5.00; tree : (3 OR NOT 4)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 9.50; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.00; asym: 3.50; tree : ((0 OR 2) OR (1 AND 3))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 9.68; asym: 5.00; tree : NOT 4
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 10.15; asym: 4.37; tree : NOT NOT 1
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 10.24; asym: 5.00; tree : (3 OR NOT 4)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 10.80; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.00; asym: 3.50; tree : ((0 OR 2) OR (1 AND 3))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 8.56; asym: 5.00; tree : NOT 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 9.81; asym: 4.37; tree : NOT NOT 1
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 10.24; asym: 5.00; tree : (3 OR NOT 1)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 10.80; asym: 4.16; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.00; asym: 3.50; tree : ((0 OR 2) OR (1 AND 3))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 8.77; asym: 5.00; tree : NOT 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 9.19; asym: 4.37; tree : NOT NOT 1
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 10.24; asym: 5.00; tree : (3 OR NOT 1)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 10.80; asym: 4.16; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.00; asym: 3.50; tree : ((0 OR 2) OR (1 AND 3))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 8.77; asym: 5.00; tree : NOT NOT 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 9.19; asym: 4.37; tree : NOT NOT 1
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 10.24; asym: 5.00; tree : (3 OR NOT 1)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 11.38; asym: 4.16; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.00; asym: 3.50; tree : ((0 OR 2) OR (1 AND 3))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 8.77; asym: 5.00; tree : NOT NOT 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 9.49; asym: 4.37; tree : NOT NOT 1
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 10.24; asym: 4.25; tree : (0 OR NOT 1)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 10.80; asym: 4.16; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.00; asym: 2.96; tree : ((0 OR 2) OR (1 AND 3))
# >> G_3: init: 1.74; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 10.37; asym: 4.05; tree : NOT NOT 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 11.05; asym: 4.37; tree : NOT (NOT 1 AND 3)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 13.26; asym: 5.00; tree : ((3 AND 4) OR NOT 5)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 17.59; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.31; asym: 3.50; tree : ((0 OR 2) OR 5)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 8.36; asym: 3.50; tree : (1 OR 5)
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 18.28; asym: 4.37; tree : NOT NOT (1 AND 4)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 13.04; asym: 4.29; tree : (3 OR NOT 0)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 11.96; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.50; tree : ((0 OR 2) OR 5)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 11.05; asym: 4.28; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 20.56; asym: 4.37; tree : NOT NOT (1 AND (4 AND 0))
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 13.04; asym: 4.29; tree : (3 OR NOT 0)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 11.83; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.50; tree : ((0 OR 2) OR 5)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 13.85; asym: 4.28; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 20.65; asym: 4.37; tree : NOT NOT (1 AND (4 AND 0))
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 12.73; asym: 3.51; tree : (3 OR NOT 0)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 11.83; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.06; tree : ((0 OR 2) OR 5)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 13.85; asym: 4.28; tree : 3
# >> G_4: init: 1.18; noise: 6.92; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 20.65; asym: 4.37; tree : NOT NOT (1 AND (4 AND 0))
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 15.46; asym: 5.00; tree : (5 OR NOT (0 OR 4))
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 24.35; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 7.92; asym: 3.50; tree : ((0 OR 2) OR 5)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 9.04; asym: 3.50; tree : (4 OR 5)
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 21.33; asym: 3.05; tree : NOT NOT (1 AND 0)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 3.92; asym: 3.62; tree : (3 OR NOT 5)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 9.48; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.50; tree : (0 OR 2)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 11.37; asym: 3.44; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 22.50; asym: 2.43; tree : NOT NOT (1 AND 0)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 7.18; asym: 3.62; tree : (3 OR NOT 5)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 8.55; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 7.95; asym: 3.50; tree : ((0 OR 2) OR 5)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 13.07; asym: 2.81; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 24.82; asym: 2.94; tree : NOT NOT (1 AND (4 AND 0))
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 6.93; asym: 3.62; tree : (3 OR NOT 5)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 7.97; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 7.95; asym: 3.50; tree : ((0 OR 2) OR 5)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 13.07; asym: 2.81; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 24.82; asym: 2.94; tree : NOT NOT (1 AND (4 AND 0))
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 6.71; asym: 3.62; tree : (3 OR NOT 5)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 7.97; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 7.95; asym: 3.50; tree : (2 OR 5)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 15.68; asym: 2.44; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 25.49; asym: 2.94; tree : NOT NOT (1 AND (4 AND 0))
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 4.63; asym: 2.96; tree : (3 OR NOT 5)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 6.00; expr: 1.00; deg: 0.10; theta: 8.21; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.50; tree : 2
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 9.77; expr: 1.00; deg: 0.10; theta: 13.44; asym: 2.81; tree : 2
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 20.11; asym: 2.94; tree : NOT NOT (4 AND 2)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 5.75; asym: 3.62; tree : (3 OR NOT 5)
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 11.50; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.50; tree : 2
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 4.02; expr: 1.00; deg: 0.10; theta: 18.69; asym: 2.81; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 1.88; m: 6.86; expr: 1.00; deg: 0.10; theta: 19.57; asym: 2.94; tree : NOT NOT (4 AND 0)
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 6.93; asym: 3.62; tree : NOT 5
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 11.50; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.50; tree : 2
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 4.02; expr: 1.00; deg: 0.10; theta: 19.64; asym: 2.37; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 7.30; m: 6.86; expr: 1.00; deg: 0.10; theta: 26.70; asym: 2.94; tree : NOT NOT (3 AND 0)
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 6.93; asym: 3.62; tree : NOT 5
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 11.50; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.50; tree : 2
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 4.02; expr: 1.00; deg: 0.10; theta: 18.32; asym: 2.37; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 7.30; m: 6.86; expr: 1.00; deg: 0.10; theta: 24.19; asym: 2.94; tree : NOT NOT (3 AND 0)
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 7.77; asym: 3.03; tree : NOT 5
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 10.03; asym: 4.33; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.50; tree : 2
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 4.02; expr: 1.00; deg: 0.10; theta: 19.67; asym: 2.37; tree : 0
# >> G_4: init: 1.18; noise: 0.27; b: 7.30; m: 6.86; expr: 1.00; deg: 0.10; theta: 28.21; asym: 2.94; tree : NOT NOT (3 AND 0)
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 7.53; asym: 3.00; tree : NOT 0
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 12.69; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.03; asym: 3.50; tree : (2 OR 1)
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 4.02; expr: 1.00; deg: 0.10; theta: 19.64; asym: 2.37; tree : 3
# >> G_4: init: 1.18; noise: 0.27; b: 7.30; m: 6.86; expr: 1.00; deg: 0.77; theta: 25.76; asym: 2.94; tree : NOT NOT (2 AND 0)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 1.82; noise: 0.18; b: 0.38; m: 6.61; expr: 1.00; deg: 0.10; theta: 7.77; asym: 3.62; tree : NOT 5
# >> G_1: init: 2.36; noise: 0.34; b: 2.37; m: 3.64; expr: 1.00; deg: 0.10; theta: 13.32; asym: 5.00; tree : 2
# >> G_2: init: 0.74; noise: 0.37; b: 2.42; m: 1.24; expr: 1.00; deg: 0.10; theta: 8.23; asym: 3.50; tree : 2
# >> G_3: init: 2.63; noise: 0.22; b: 0.34; m: 4.02; expr: 1.00; deg: 0.10; theta: 19.08; asym: 2.37; tree : 2
# >> G_4: init: 1.18; noise: 0.27; b: 7.30; m: 6.86; expr: 1.00; deg: 0.10; theta: 25.76; asym: 2.44; tree : NOT NOT NOT (3 AND 0)
