# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn4 import GRNMain4 as GRNMain
from lib.sde.mutate import mutate_grn4 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
import random
from lib.sde.mutate import mutate_gene4, mutate_tree

# %%
HISTORY = defaultdict(dict)
HALL_OF_FAME = []

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)

# %%
def individual_generator(id_=-1, cb_init=None, nb_genes=4):
    return Solution(GRNMain(nb_genes, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
_MUTATE_FUNC = mutate_grn

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        global _MUTATE_FUNC
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**1.5))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=3e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        # score_step = score_both_size(bb.stats, prun.ref, max_step=step.end_time, min_step=previous_time)
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def mean_sd_fitness(prun, grn, run=3):
    fitnesses = [fitness_multistep(prun, grn) for i in range(run)]
    return np.mean(fitnesses), np.std(fitnesses)

# %%
def multi_fitness(*args):
    fitnesses = [fitness_multistep(*args) for i in range(3)]
    scores = [x[0] for x in fitnesses]
    return fitnesses[scores.index(min(scores))]

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init),
                                  new_fitness=0.5, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e6
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    ObjectiveStep(name="The ONE", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 10
    n_gen = 30
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 25
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def main(prun):
    prun.history = defaultdict(dict)
    # exporter = Exporter()
    best = 0
    sol = do_init(prun)
    pop = [sol]
    for generation in range(prun.n_gen * prun.pop_size):
        # args.generation = generation
        # objective.new_trial()
        fit, stats = do_fitness(prun, sol)
        sol.fit = fit
        sol.stats = stats
        
        # history
        # print(f"Fitness = {fit}", end="\t\t")
        if generation % 100 == 0:
            print(f"Step {generation}")
        if fit > best:
            print(f"++ Best {fit} for generation {generation}")
            best = fit
            
        monitor = sol
        prun.history[generation] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        # TODO get the stats associated with the best scores
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
    print("OVER")
    return best

# %%
prun = get_prun()
# res = main(prun)

# %%
def get_score_parametrized(cb_init, name=None):
    args = get_prun()
    args.cb_init = cb_init
    args.name = name
    main(args)
    p1 = L(args.history.values()).fit
    idx = p1.index(max(p1))
    sol = args.history[idx]
    scores = [fitness_multistep(args, sol.grn, args.steps)[0] for i in range(10)]
    print("Final score", np.mean(scores), "+-", np.std(scores))
    return np.mean(scores), np.std(scores), max(p1)

# %%
def mutate_grn_half(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.5)
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()
    
def mutate_grn_sparse(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.8)
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()
    
def mutate_grn_verysparse(grn, temperature=0.1):
    grn.set_mutable()
    shape = grn._params.shape
    r = random.random()
    param_prob = 0.8
    if r < param_prob:
        mask = (np.random.uniform(0, 1, shape) > 0.9)
        coeff = np.random.normal(0, temperature, shape)
        true_coeff = mask * coeff + 1
        grn._params *= true_coeff
    else:
        one_gene = random.choice(grn.genes)
        one_gene.tree = mutate_tree(one_gene.tree, one_gene.get_labels_not_in_tree())
    grn.compile()

# %%
model = sm.StringModel("expfit_func{mutfunc}_i{i}")
mut_func = dict(
    verysparse=lambda x: mutate_grn_verysparse(x),
    sparse=lambda x: mutate_grn_sparse(x),
    half=lambda x: mutate_grn_half(x),
)

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
)

# %%
# main loop
exporter = Exporter(name="exp_mutfunc9_sparsity_newobj_030322")
for (funcname, func), i in product(mut_func.items(), range(10)):
    name = model.fill(mutfunc=funcname, i=i)
    print(name)
    if name in exporter.list():
        continue
    _MUTATE_FUNC = func
    res = get_score_parametrized(callback_init)
    exporter(res, name)
# Out:
# Exporting at output/exp_mutfunc9_sparsity_newobj_030322
# expfit_funcverysparse_i0
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 983.5171273060906 for generation 1
# ++ Best 1011.3030615433009 for generation 2
# Step The ONE passed !
# ++ Best 1029.819660112501 for generation 5
# ++ Best 1032.819660112501 for generation 11
# ++ Best 1045.1715728752538 for generation 33
# ++ Best 1049.0 for generation 95
# Step 100
# ++ Best 1055.0 for generation 103
# Step 200
# OVER
# Final score 1028.9693570937939 +- 13.981733265228698
# expfit_funcverysparse_i1
# Step 0
# ++ Best 825.9806640162438 for generation 0
# ++ Best 888.4244923464074 for generation 1
# ++ Best 920.5572809000083 for generation 2
# ++ Best 972.4307806183471 for generation 3
# ++ Best 987.4307806183468 for generation 8
# ++ Best 1000.479740822548 for generation 9
# ++ Best 1017.4307806183471 for generation 11
# ++ Best 1075.5171273060905 for generation 16
# ++ Best 1076.819660112501 for generation 28
# ++ Best 1087.5171273060905 for generation 29
# ++ Best 1109.430780618347 for generation 53
# ++ Best 1114.430780618347 for generation 63
# ++ Best 1145.3772233983161 for generation 65
# ++ Best 1162.430780618347 for generation 66
# ++ Best 1174.3772233983161 for generation 73
# ++ Best 1174.5171273060905 for generation 79
# ++ Best 1252.430780618347 for generation 98
# Step 100
# ++ Best 1258.0 for generation 102
# ++ Best 1262.430780618347 for generation 135
# ++ Best 1301.0 for generation 138
# ++ Best 1356.9052498068886 for generation 192
# Step 200
# ++ Best 1488.3725830020305 for generation 211
# ++ Best 1582.430780618347 for generation 218
# ++ Best 1619.5171273060905 for generation 220
# ++ Best 1699.9072043644996 for generation 225
# ++ Best 1761.5171273060905 for generation 262
# ++ Best 1770.9052498068884 for generation 280
# ++ Best 1849.0177871865296 for generation 285
# OVER
# Final score 1340.213693260085 +- 471.9666079430415
# expfit_funcverysparse_i2
# Step 0
# ++ Best 977.430780618347 for generation 0
# ++ Best 997.0 for generation 2
# ++ Best 1008.4797408225479 for generation 4
# ++ Best 1026.0 for generation 11
# ++ Best 1027.819660112501 for generation 53
# ++ Best 1031.0 for generation 54
# Step 100
# Step 200
# OVER
# Final score 1003.0689413779686 +- 15.960071403405996
# expfit_funcverysparse_i3
# Step 0
# ++ Best 973.430780618347 for generation 0
# ++ Best 1014.8196601125011 for generation 2
# ++ Best 1023.8038475772934 for generation 19
# ++ Best 1028.3030615433008 for generation 42
# ++ Best 1031.0 for generation 87
# Step 100
# ++ Best 1035.3030615433008 for generation 104
# ++ Best 1038.3725830020305 for generation 113
# Step 200
# ++ Best 1038.819660112501 for generation 204
# ++ Best 1044.8038475772933 for generation 215
# OVER
# Final score 1011.1753027200933 +- 12.90569382119349
# expfit_funcverysparse_i4
# Step 0
# ++ Best 994.3725830020306 for generation 0
# ++ Best 999.479740822548 for generation 9
# ++ Best 1013.6958749638075 for generation 14
# ++ Best 1026.3725830020305 for generation 30
# ++ Best 1040.430780618347 for generation 33
# ++ Best 1054.430780618347 for generation 36
# ++ Best 1065.430780618347 for generation 41
# ++ Best 1074.3772233983161 for generation 61
# Step 100
# Step 200
# ++ Best 1075.3725830020305 for generation 205
# OVER
# Final score 1022.3057038648225 +- 22.514456330928883
# expfit_funcverysparse_i5
# Step 0
# ++ Best 975.430780618347 for generation 0
# ++ Best 1001.3725830020305 for generation 1
# ++ Best 1004.3030615433009 for generation 19
# ++ Best 1143.430780618347 for generation 20
# ++ Best 1150.5171273060905 for generation 46
# ++ Best 1257.430780618347 for generation 57
# ++ Best 1259.5171273060905 for generation 70
# ++ Best 1387.5171273060905 for generation 71
# ++ Best 1636.6324676318527 for generation 76
# ++ Best 1926.3772233983161 for generation 85
# Step 100
# ++ Best 1952.8108532838849 for generation 122
# ++ Best 1972.0177871865299 for generation 163
# Step 200
# ++ Best 1974.8108532838844 for generation 270
# OVER
# Final score 397.46391112599696 +- 796.333650600432
# expfit_funcverysparse_i6
# Step 0
# ++ Best 1002.4797408225478 for generation 0
# ++ Best 1009.0 for generation 2
# ++ Best 1009.8196601125011 for generation 16
# ++ Best 1029.1715728752538 for generation 34
# ++ Best 1033.1715728752538 for generation 55
# Step 100
# ++ Best 1034.0 for generation 116
# ++ Best 1037.0 for generation 147
# Step 200
# OVER
# Final score 1022.0935715560934 +- 14.166242172319919
# expfit_funcverysparse_i7
# Step 0
# ++ Best 995.3772233983163 for generation 0
# ++ Best 999.479740822548 for generation 3
# ++ Best 1009.3030615433008 for generation 10
# ++ Best 1080.430780618347 for generation 20
# ++ Best 1096.5171273060905 for generation 33
# ++ Best 1099.0 for generation 51
# ++ Best 1100.5171273060905 for generation 54
# ++ Best 1118.3772233983161 for generation 55
# ++ Best 1136.0 for generation 56
# ++ Best 1137.430780618347 for generation 84
# ++ Best 1203.5171273060905 for generation 86
# Step 100
# ++ Best 1244.5171273060905 for generation 100
# ++ Best 1297.430780618347 for generation 130
# ++ Best 1328.5171273060905 for generation 136
# ++ Best 1357.8302205930995 for generation 138
# ++ Best 1363.3772233983163 for generation 143
# ++ Best 1388.6958749638075 for generation 144
# ++ Best 1440.0 for generation 147
# ++ Best 1468.9072043644996 for generation 160
# ++ Best 1507.9072043644996 for generation 173
# ++ Best 1514.6324676318527 for generation 181
# Step 200
# ++ Best 1563.80889066687 for generation 220
# ++ Best 1566.0 for generation 230
# OVER
# Final score 1366.7146562048147 +- 102.15395574379288
# expfit_funcverysparse_i8
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 848.8302205930994 for generation 1
# ++ Best 1003.5171273060906 for generation 2
# ++ Best 1055.5171273060905 for generation 6
# ++ Best 1092.3772233983161 for generation 28
# ++ Best 1106.3772233983161 for generation 39
# ++ Best 1116.0 for generation 44
# ++ Best 1132.430780618347 for generation 72
# ++ Best 1167.430780618347 for generation 99
# Step 100
# ++ Best 1232.3725830020305 for generation 112
# ++ Best 1300.430780618347 for generation 124
# ++ Best 1337.180920072727 for generation 137
# ++ Best 1436.7659104059273 for generation 175
# Step 200
# ++ Best 1455.9072043644996 for generation 288
# OVER
# Final score 1239.3943669051446 +- 51.362679801964056
# expfit_funcverysparse_i9
# Step 0
# ++ Best 878.0 for generation 0
# ++ Best 1008.4797408225479 for generation 1
# ++ Best 1016.3725830020304 for generation 3
# ++ Best 1091.0 for generation 19
# ++ Best 1252.3772233983161 for generation 34
# ++ Best 1357.430780618347 for generation 65
# ++ Best 1388.5171273060905 for generation 67
# ++ Best 1395.0 for generation 76
# ++ Best 1501.0 for generation 82
# Step 100
# ++ Best 1584.8379265803828 for generation 107
# ++ Best 1604.1370184487248 for generation 140
# ++ Best 1673.3772233983163 for generation 150
# ++ Best 1691.9806640162437 for generation 178
# Step 200
# ++ Best 1842.8108532838846 for generation 244
# OVER
# Final score 1501.7410334527913 +- 106.11740963234784
# expfit_funcsparse_i0
# Step 0
# ++ Best 819.4294326642449 for generation 0
# ++ Best 978.430780618347 for generation 1
# ++ Best 1219.430780618347 for generation 2
# ++ Best 1329.0 for generation 26
# ++ Best 1357.4719062652532 for generation 34
# ++ Best 1427.5171273060905 for generation 45
# ++ Best 1472.479740822548 for generation 75
# ++ Best 1534.9072043644996 for generation 76
# Step 100
# ++ Best 1570.180920072727 for generation 100
# ++ Best 1651.8108532838844 for generation 199
# Step 200
# ++ Best 1665.8108532838846 for generation 212
# ++ Best 1724.8088906668702 for generation 214
# ++ Best 1761.3030615433008 for generation 234
# ++ Best 1788.0 for generation 246
# ++ Best 2129.9072043645 for generation 256
# OVER
# Final score 1327.394341306925 +- 670.2464557489956
# expfit_funcsparse_i1
# Step 0
# ++ Best 1032.0 for generation 0
# ++ Best 1034.0 for generation 29
# ++ Best 1035.0 for generation 34
# ++ Best 1036.0 for generation 39
# ++ Best 1038.0 for generation 59
# ++ Best 1040.0 for generation 86
# ++ Best 1041.0 for generation 97
# Step 100
# Step 200
# ++ Best 1042.0 for generation 298
# OVER
# Final score 1032.519434509773 +- 4.570277536250621
# expfit_funcsparse_i2
# Step 0
# ++ Best 1280.5572809000084 for generation 0
# ++ Best 1480.9372075915135 for generation 31
# Step 100
# ++ Best 1519.703884586921 for generation 102
# ++ Best 1557.0 for generation 125
# ++ Best 1902.3772233983161 for generation 132
# ++ Best 1992.8302205930995 for generation 180
# ++ Best 2021.8302205930997 for generation 183
# ++ Best 2117.8302205930995 for generation 189
# Step 200
# ++ Best 2202.9343726813186 for generation 253
# ++ Best 2232.137018448725 for generation 292
# OVER
# Final score 1321.1065474175916 +- 675.8508230136155
# expfit_funcsparse_i3
# Step 0
# ++ Best 978.5171273060906 for generation 0
# ++ Best 985.5171273060906 for generation 4
# ++ Best 999.479740822548 for generation 8
# ++ Best 1004.0 for generation 9
# ++ Best 1021.3772233983161 for generation 16
# ++ Best 1028.3030615433008 for generation 22
# ++ Best 1034.479740822548 for generation 32
# ++ Best 1038.5171273060905 for generation 42
# ++ Best 1049.3772233983161 for generation 58
# Step 100
# ++ Best 1135.5171273060905 for generation 103
# ++ Best 1175.5171273060905 for generation 159
# ++ Best 1192.5572809000084 for generation 186
# ++ Best 1229.430780618347 for generation 190
# Step 200
# ++ Best 1231.3772233983161 for generation 246
# ++ Best 1318.5171273060905 for generation 284
# ++ Best 1421.430780618347 for generation 285
# OVER
# Final score 444.8750760527772 +- 561.2731484224375
# expfit_funcsparse_i4
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 760.1541758681326 for generation 1
# ++ Best 944.9999999999999 for generation 4
# ++ Best 972.4307806183471 for generation 6
# ++ Best 1002.0000000000001 for generation 7
# ++ Best 1046.3030615433008 for generation 13
# ++ Best 1058.430780618347 for generation 40
# ++ Best 1066.3725830020305 for generation 51
# ++ Best 1091.3725830020305 for generation 52
# ++ Best 1097.5171273060905 for generation 62
# ++ Best 1105.430780618347 for generation 67
# ++ Best 1112.430780618347 for generation 70
# ++ Best 1129.3772233983161 for generation 72
# ++ Best 1129.430780618347 for generation 74
# ++ Best 1144.3772233983161 for generation 77
# ++ Best 1163.3772233983161 for generation 85
# ++ Best 1167.5171273060905 for generation 87
# ++ Best 1197.430780618347 for generation 98
# Step 100
# ++ Best 1599.430780618347 for generation 109
# ++ Best 1617.430780618347 for generation 119
# ++ Best 1808.5171273060905 for generation 120
# ++ Best 1874.6958749638075 for generation 128
# ++ Best 1928.180920072727 for generation 136
# ++ Best 2040.905249806889 for generation 165
# ++ Best 2567.703884586921 for generation 168
# Step 200
# ++ Best 2919.937786378966 for generation 230
# ++ Best 2968.842953458653 for generation 277
# OVER
# Final score 1782.0832320231304 +- 906.9733316940711
# expfit_funcsparse_i5
# Step 0
# ++ Best 876.4254926465876 for generation 0
# ++ Best 902.8108532838845 for generation 1
# ++ Best 984.5171273060907 for generation 4
# ++ Best 1122.5171273060905 for generation 12
# ++ Best 1128.3772233983161 for generation 40
# ++ Best 1161.430780618347 for generation 65
# ++ Best 1191.127833418968 for generation 91
# Step 100
# Step 200
# ++ Best 1229.430780618347 for generation 268
# ++ Best 1256.0 for generation 288
# OVER
# Final score 1169.7298324420778 +- 45.62163266651706
# expfit_funcsparse_i6
# Step 0
# ++ Best 26.962437264446294 for generation 0
# ++ Best 951.0 for generation 1
# ++ Best 984.3772233983163 for generation 2
# ++ Best 1001.4797408225478 for generation 3
# ++ Best 1020.1715728752537 for generation 48
# Step 100
# ++ Best 1022.8196601125011 for generation 120
# ++ Best 1029.0 for generation 168
# Step 200
# OVER
# Final score 999.2116253993132 +- 12.9438915070754
# expfit_funcsparse_i7
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 1003.4797408225479 for generation 1
# ++ Best 1016.0 for generation 11
# ++ Best 1016.5171273060906 for generation 28
# ++ Best 1028.3725830020305 for generation 34
# ++ Best 1029.3725830020305 for generation 37
# ++ Best 1036.0 for generation 74
# ++ Best 1037.0 for generation 85
# ++ Best 1041.479740822548 for generation 86
# ++ Best 1066.3772233983161 for generation 90
# Step 100
# ++ Best 1071.5171273060905 for generation 141
# ++ Best 1090.0 for generation 145
# ++ Best 1197.3725830020305 for generation 154
# ++ Best 1198.8302205930993 for generation 168
# ++ Best 1262.0177871865296 for generation 172
# ++ Best 1269.430780618347 for generation 191
# Step 200
# ++ Best 1334.9806640162437 for generation 212
# ++ Best 1349.9372075915135 for generation 249
# ++ Best 1355.9052498068886 for generation 256
# ++ Best 1443.182661669125 for generation 262
# ++ Best 1452.8108532838846 for generation 276
# ++ Best 1501.7476355752597 for generation 280
# OVER
# Final score 1278.3435708533584 +- 76.4457497571763
# expfit_funcsparse_i8
# Step 0
# ++ Best 981.5171273060907 for generation 0
# ++ Best 1134.3772233983161 for generation 4
# ++ Best 1145.430780618347 for generation 26
# ++ Best 1218.5171273060905 for generation 28
# ++ Best 1248.430780618347 for generation 41
# ++ Best 1276.3772233983163 for generation 46
# ++ Best 1600.3772233983163 for generation 62
# ++ Best 1711.430780618347 for generation 64
# ++ Best 1941.4307806183472 for generation 81
# Step 100
# ++ Best 2086.137018448725 for generation 114
# ++ Best 2144.446609406726 for generation 155
# Step 200
# ++ Best 2398.837926580383 for generation 286
# OVER
# Final score 1038.390163178155 +- 1040.7117022960701
# expfit_funcsparse_i9
# Step 0
# ++ Best 985.5171273060906 for generation 0
# ++ Best 1028.1715728752538 for generation 2
# ++ Best 1031.3772233983161 for generation 43
# ++ Best 1033.0 for generation 74
# ++ Best 1038.0 for generation 89
# ++ Best 1043.3772233983161 for generation 96
# Step 100
# ++ Best 1059.430780618347 for generation 101
# ++ Best 1093.430780618347 for generation 114
# ++ Best 1117.430780618347 for generation 128
# ++ Best 1147.430780618347 for generation 133
# ++ Best 1235.9052498068888 for generation 152
# ++ Best 1323.430780618347 for generation 153
# ++ Best 1389.6958749638075 for generation 158
# Step 200
# ++ Best 1399.4450780624625 for generation 261
# OVER
# Final score 1167.3922589308943 +- 137.8011525870947
# expfit_funchalf_i0
# Step 0
# ++ Best 991.5171273060906 for generation 0
# ++ Best 1003.5171273060906 for generation 4
# ++ Best 1004.3725830020306 for generation 13
# ++ Best 1021.303061543301 for generation 28
# ++ Best 1032.0 for generation 45
# ++ Best 1034.819660112501 for generation 47
# ++ Best 1040.0 for generation 48
# ++ Best 1045.0 for generation 49
# ++ Best 1046.8038475772933 for generation 57
# Step 100
# Step 200
# ++ Best 1187.5171273060905 for generation 201
# ++ Best 1268.5171273060905 for generation 203
# ++ Best 1537.3772233983163 for generation 208
# ++ Best 1953.9052498068886 for generation 217
# ++ Best 1997.6167965851648 for generation 231
# OVER
# Final score 1271.588504790468 +- 833.272237074746
# expfit_funchalf_i1
# Step 0
# ++ Best 974.430780618347 for generation 0
# ++ Best 990.0 for generation 1
# ++ Best 995.3725830020305 for generation 6
# ++ Best 1024.3030615433008 for generation 7
# ++ Best 1065.430780618347 for generation 28
# ++ Best 1068.3772233983161 for generation 36
# ++ Best 1118.3993047522692 for generation 59
# ++ Best 1223.430780618347 for generation 97
# Step 100
# ++ Best 1325.430780618347 for generation 137
# ++ Best 1467.430780618347 for generation 169
# Step 200
# ++ Best 1735.0 for generation 220
# OVER
# Final score 1140.3726227033349 +- 766.6973857719039
# expfit_funchalf_i2
# Step 0
# ++ Best 975.430780618347 for generation 0
# ++ Best 979.4307806183468 for generation 1
# ++ Best 994.9999999999999 for generation 2
# ++ Best 998.0000000000001 for generation 11
# ++ Best 1014.8196601125011 for generation 12
# ++ Best 1212.1370184487248 for generation 13
# ++ Best 1220.937786378966 for generation 64
# ++ Best 1270.430780618347 for generation 73
# ++ Best 1310.8108532838846 for generation 86
# Step 100
# ++ Best 1489.703884586921 for generation 110
# ++ Best 1500.2877265918203 for generation 122
# ++ Best 1822.9532463605942 for generation 128
# ++ Best 1861.4868262710766 for generation 175
# Step 200
# ++ Best 1878.703884586921 for generation 269
# ++ Best 1911.4450780624625 for generation 270
# ++ Best 1980.7433661044786 for generation 288
# OVER
# Final score 489.56800387441456 +- 755.8298001351719
# expfit_funchalf_i3
# Step 0
# ++ Best 999.479740822548 for generation 0
# ++ Best 1036.430780618347 for generation 7
# ++ Best 1038.5171273060905 for generation 28
# ++ Best 1109.0 for generation 29
# ++ Best 1224.5171273060905 for generation 31
# ++ Best 1233.479740822548 for generation 35
# ++ Best 1275.8108532838846 for generation 37
# ++ Best 1370.3772233983163 for generation 49
# ++ Best 1375.3772233983163 for generation 59
# Step 100
# ++ Best 1456.9372075915135 for generation 100
# ++ Best 1576.574769769694 for generation 105
# ++ Best 1817.752267887179 for generation 132
# Step 200
# ++ Best 1955.5171273060905 for generation 239
# ++ Best 1974.574769769694 for generation 248
# ++ Best 2412.1090832097384 for generation 252
# ++ Best 2686.7842337811508 for generation 284
# OVER
# Final score 1947.5966080025144 +- 243.2825872415702
# expfit_funchalf_i4
# Step 0
# ++ Best 942.9072043644998 for generation 0
# ++ Best 987.5171273060906 for generation 1
# ++ Best 990.0 for generation 2
# ++ Best 999.479740822548 for generation 4
# ++ Best 1008.5171273060907 for generation 6
# ++ Best 1018.8038475772934 for generation 10
# ++ Best 1068.430780618347 for generation 15
# ++ Best 1076.430780618347 for generation 27
# ++ Best 1111.5171273060905 for generation 36
# ++ Best 1177.6958749638075 for generation 42
# ++ Best 1186.0 for generation 44
# ++ Best 1256.5171273060905 for generation 58
# ++ Best 1268.430780618347 for generation 62
# Step 100
# ++ Best 1275.0 for generation 181
# Step 200
# ++ Best 1393.9072043644996 for generation 242
# OVER
# Final score 1211.9403729664232 +- 85.70872503614176
# expfit_funchalf_i5
# Step 0
# ++ Best 1000.479740822548 for generation 0
# ++ Best 1018.5171273060906 for generation 10
# ++ Best 1458.6167965851648 for generation 25
# ++ Best 1490.430780618347 for generation 26
# ++ Best 1567.0 for generation 98
# Step 100
# ++ Best 1610.581364284546 for generation 120
# ++ Best 1639.6324676318527 for generation 155
# ++ Best 1885.8379265803826 for generation 174
# ++ Best 1973.9806640162435 for generation 177
# ++ Best 2049.399304752269 for generation 189
# Step 200
# ++ Best 2205.8302205930995 for generation 286
# OVER
# Final score 648.742764986905 +- 989.5178540513834
# expfit_funchalf_i6
# Step 0
# ++ Best 978.5171273060906 for generation 0
# ++ Best 997.4307806183468 for generation 8
# ++ Best 1000.5171273060906 for generation 24
# ++ Best 1022.8038475772934 for generation 30
# ++ Best 1025.1715728752538 for generation 68
# Step 100
# ++ Best 1026.1715728752538 for generation 157
# ++ Best 1027.1715728752538 for generation 198
# Step 200
# ++ Best 1030.0 for generation 203
# ++ Best 1033.3772233983161 for generation 210
# OVER
# Final score 1002.1462787779052 +- 17.681605527891367
# expfit_funchalf_i7
# Step 0
# ++ Best 975.430780618347 for generation 0
# ++ Best 979.5171273060906 for generation 3
# ++ Best 997.3725830020306 for generation 6
# ++ Best 1002.4797408225478 for generation 9
# ++ Best 1009.3030615433008 for generation 27
# ++ Best 1009.5171273060907 for generation 70
# ++ Best 1011.0 for generation 87
# ++ Best 1019.5171273060906 for generation 90
# ++ Best 1038.0 for generation 93
# Step 100
# ++ Best 1039.3772233983161 for generation 114
# ++ Best 1048.0 for generation 119
# ++ Best 1067.0 for generation 124
# ++ Best 1071.5171273060905 for generation 135
# ++ Best 1134.430780618347 for generation 148
# ++ Best 1249.632467631853 for generation 153
# ++ Best 1284.430780618347 for generation 163
# ++ Best 1360.5171273060905 for generation 187
# ++ Best 1420.0 for generation 197
# Step 200
# ++ Best 1457.0 for generation 244
# ++ Best 1490.9052498068886 for generation 253
# ++ Best 1549.3772233983163 for generation 272
# ++ Best 1698.8379265803828 for generation 278
# OVER
# Final score 1496.9278706542173 +- 66.9948604976936
# expfit_funchalf_i8
# Step 0
# ++ Best 1.0 for generation 0
# ++ Best 838.3993047522694 for generation 1
# ++ Best 990.0 for generation 2
# ++ Best 1001.3725830020305 for generation 7
# ++ Best 1011.8196601125012 for generation 12
# ++ Best 1017.3030615433009 for generation 21
# ++ Best 1019.8196601125011 for generation 33
# ++ Best 1023.8196601125012 for generation 44
# ++ Best 1032.8038475772933 for generation 47
# ++ Best 1033.8038475772933 for generation 85
# Step 100
# ++ Best 1041.0 for generation 132
# Step 200
# ++ Best 1053.3772233983161 for generation 210
# ++ Best 1062.0 for generation 226
# ++ Best 1180.3772233983161 for generation 247
# ++ Best 1194.0 for generation 265
# ++ Best 1362.430780618347 for generation 268
# ++ Best 1436.632467631853 for generation 281
# ++ Best 1500.9372075915135 for generation 291
# OVER
# Final score 1522.9083600926242 +- 91.42113639348003
# expfit_funchalf_i9
# Step 0
# ++ Best 1003.3725830020305 for generation 0
# ++ Best 1134.5171273060905 for generation 4
# ++ Best 1179.430780618347 for generation 34
# ++ Best 1234.5171273060905 for generation 35
# ++ Best 1355.430780618347 for generation 47
# ++ Best 1399.5171273060905 for generation 49
# ++ Best 1683.5171273060907 for generation 51
# ++ Best 1777.4244923464073 for generation 57
# Step 100
# ++ Best 1847.4244923464078 for generation 102
# ++ Best 1873.8302205930993 for generation 117
# ++ Best 1935.0128207762375 for generation 123
# ++ Best 2052.937786378966 for generation 140
# ++ Best 2162.9806640162437 for generation 147
# ++ Best 2285.1090832097384 for generation 167
# ++ Best 2860.80889066687 for generation 169
# Step 200
# OVER
# Final score 275.42851598598935 +- 823.285547957968

# %%
dicts = [dict(**model.extract(x), **dict(zip(("mean", "sd", "max"), exporter.load(x)))) for x in exporter.list() if model.match(x)]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#       mutfunc  i         mean          sd          max
# 0  verysparse  3  1011.175303   12.905694  1044.803848
# 1      sparse  4  1782.083232  906.973332  2968.842953
# 2      sparse  2  1321.106547  675.850823  2232.137018
# 3        half  9   275.428516  823.285548  2860.808891
# 4      sparse  7  1278.343571   76.445750  1501.747636

# %%
new_df = df.groupby(["mutfunc"]).mean()
new_df
# Out:
#                    mean          sd          max
# mutfunc
# half        1100.721990  467.369174  1909.384307
# sparse      1156.104608  413.243817  1737.934860
# verysparse  1093.314054  160.746250  1393.172313

# %%
for i, row in new_df.iterrows():
    print(row.name, row["mean"], row["mean"] - row.sd / np.sqrt(10), row["mean"] + row.sd / np.sqrt(10))
# Out:
# half 1100.7219902834795 952.9268804941926 1248.5171000727664
# sparse 1156.1046082113996 1025.4254392920814 1286.783777130718
# verysparse 1093.3140537561603 1042.4816262004767 1144.146481311844

# %%
row.name
# Out:
# 'verysparse'
