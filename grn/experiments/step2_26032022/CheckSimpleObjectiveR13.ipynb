# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_n, ref_n = normalize_time(stats, ref_stats, "neuron_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_n = stats_n.set_index("time")
    
    prog = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron = stats_n.loc[last_time_stats]["neuron_pop_size"]
    
    ref_prog = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron = ref_n.loc[last_time_ref]["neuron_pop_size"]

    return 1 / max(1, 1000 - abs(prog - ref_prog) - abs(neuron - ref_neuron))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r13"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r13
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 975.2816234731171 for generation 0
# Step 3 passed !
# [out] ++ Best 978.0775418404642 for generation 7
# [out] ++ Best 994.2489887717807 for generation 38
# Saving ...
# [out] ++ Best 994.7451590138445 for generation 50
# [out] ++ Best 994.8816418330051 for generation 51
# [out] ++ Best 995.173730442416 for generation 59
# [out] ++ Best 995.7859753403751 for generation 61
# [out] ++ Best 995.9492406464975 for generation 78
# Saving ...
# [out] Step 100
# [out] ++ Best 996.5755193840257 for generation 120
# [out] ++ Best 996.7796010166788 for generation 128
# Saving ...
# Saving ...
# [out] Step 200
# [out] ++ Best 997.5614855444568 for generation 213
# Saving ...
# Saving ...
# [out] Step 300
# Saving ...
# Saving ...
# [out] Step 400
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# [out] ++ Best 997.6431181975179 for generation 675
# [out] ++ Best 998.7655671771099 for generation 676
# Saving ...
# [out] Step 700
# Saving ...
# [out] ++ Best 999.1533222791504 for generation 765
# [out] ++ Best 999.2349549322118 for generation 783
# Saving ...
# [out] Step 800
# [out] ++ Best 999.4122540779033 for generation 836
# Saving ...
# Saving ...
# [out] Step 900
# [out] ++ Best 999.5818937077221 for generation 935
# Saving ...
# Saving ...
# [out] Step 1000
# [out] ++ Best 999.6693785751579 for generation 1045
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# Saving ...
# [out] Step 1300
# Saving ...
# [out] ++ Best 999.8267916669057 for generation 1368
# [out] ++ Best 999.9428663228011 for generation 1386
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e0ef71e4cf71> in <module>
#       2 prun.cb_init = callback_init
#       3 prun.name = "check_simple_obj_r13"
# ----> 4 res = main(prun)
#
# <ipython-input-15-b9e59561fcb1> in main(prun)
#      20     for i in range(batch_gen * prun.batch_size,
#      21                    prun.n_gen * prun.batch_size):
# ---> 22         fit, stats = do_fitness(prun, sol)
#      23         sol.fit, sol.stats = fit, stats
#      24
#
# <ipython-input-12-803c9e3dddd9> in do_fitness(prun, sol)
#       3
#       4 def do_fitness(prun, sol):
# ----> 5     fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
#       6     return fitness, stats
#       7
#
# <ipython-input-11-424afec1b8a4> in fitness_multistep(prun, grn, steps)
#       6     # first step
#       7     for step in steps:
# ----> 8         if not bb.run_until(step.end_time):
#       9             stop = True
#      10
#
# ~/other/EmbryonicCortexModelling/grn/brain.py in run_until(self, time_point)
#     145                 and (self.range[self.current_step] < time_point):
#     146             T = self.range[self.current_step]
# --> 147             if not self._tick(T, self.time_step):
#     148                 self.info("Population exploded or extinguished")
#     149                 return False
#
# ~/other/EmbryonicCortexModelling/grn/brain.py in _tick(self, absolute_time, relative_time)
#     170         # take care of cells
#     171         if self.opti:
# --> 172             self.population.tick_cell_programs_batch(absolute_time, relative_time)
#     173         else:
#     174             self.population.tick_cell_programs(absolute_time, relative_time)
#
# ~/other/EmbryonicCortexModelling/grn/lib/population.py in tick_cell_programs_batch(self, absolute_time, relative_time)
#      65         cells = [self.base_population[C_id] for C_id in list(self.tissue_population.values())]
#      66         for C in cells:
# ---> 67             neighbours = self.brain.get_neighbours(C)
#      68             C.set_neighbourhood(neighbours)
#      69             # C.lazy_set_neighbourhood(neighbours)
#
# ~/other/EmbryonicCortexModelling/grn/brain.py in get_neighbours(self, cell)
#     218
#     219     def get_neighbours(self, cell):
# --> 220         ngbs = self.tissue.get_neighbours(cell.tissue_id)
#     221         return [self.population.cell_from_tissue_id(i) for i in ngbs]
#     222
#
# ~/other/EmbryonicCortexModelling/grn/cbmos/cbmodel/CBModelv3.py in get_neighbours(self, cell_id)
#     104         # compute all dists, then pick ones below a threshold
#     105         ref = self.ids_to_cells[cell_id]
# --> 106         dists = [(self.hpc_backend.linalg.norm(ref.position - cell.position), cell.ID)
#     107                   for cell in self.cells]
#     108         dists.sort()
#
# ~/other/EmbryonicCortexModelling/grn/cbmos/cbmodel/CBModelv3.py in <listcomp>(.0)
#     104         # compute all dists, then pick ones below a threshold
#     105         ref = self.ids_to_cells[cell_id]
# --> 106         dists = [(self.hpc_backend.linalg.norm(ref.position - cell.position), cell.ID)
#     107                   for cell in self.cells]
#     108         dists.sort()
#
# /opt/jupyterhub/lib/python3.8/site-packages/numpy/core/overrides.py in norm(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r13

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
for i in range(5):
    print(fitness_multistep(prun, res.grn, prun.steps))
# Out:
# (998.5614855444568,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              6.0                 62.0  56.25            68.0
# 56.50              7.0                 62.0  56.50            69.0
# 56.75              7.0                 64.0  56.75            71.0
# 57.00              7.0                 66.0  57.00            73.0
# ...                ...                  ...    ...             ...
# 85.00           1138.0                117.0  85.00          1255.0
# 85.25           1145.0                115.0  85.25          1260.0
# 85.50           1149.0                112.0  85.50          1261.0
# 85.75           1151.0                116.0  85.75          1267.0
# 86.00           1163.0                110.0  86.00          1273.0
#
# [121 rows x 4 columns])
# (998.7451590138446,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              5.0                 63.0  56.25            68.0
# 56.50              5.0                 65.0  56.50            70.0
# 56.75              5.0                 66.0  56.75            71.0
# 57.00              5.0                 68.0  57.00            73.0
# ...                ...                  ...    ...             ...
# 85.00           1137.0                113.0  85.00          1250.0
# 85.25           1142.0                110.0  85.25          1252.0
# 85.50           1145.0                108.0  85.50          1253.0
# 85.75           1152.0                104.0  85.75          1256.0
# 86.00           1160.0                 98.0  86.00          1258.0
#
# [121 rows x 4 columns])
# (997.7655671771098,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              5.0                 64.0  56.25            69.0
# 56.50              5.0                 65.0  56.50            70.0
# 56.75              5.0                 66.0  56.75            71.0
# 57.00              5.0                 67.0  57.00            72.0
# ...                ...                  ...    ...             ...
# 85.00           1098.0                116.0  85.00          1214.0
# 85.25           1103.0                116.0  85.25          1219.0
# 85.50           1107.0                116.0  85.50          1223.0
# 85.75           1119.0                106.0  85.75          1225.0
# 86.00           1122.0                108.0  86.00          1230.0
#
# [121 rows x 4 columns])
# (996.4448887792397,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              4.0                 65.0  56.25            69.0
# 56.50              4.0                 65.0  56.50            69.0
# 56.75              4.0                 67.0  56.75            71.0
# 57.00              5.0                 66.0  57.00            71.0
# ...                ...                  ...    ...             ...
# 85.00           1057.0                 82.0  85.00          1139.0
# 85.25           1063.0                 79.0  85.25          1142.0
# 85.50           1074.0                 68.0  85.50          1142.0
# 85.75           1079.0                 63.0  85.75          1142.0
# 86.00           1082.0                 61.0  86.00          1143.0
#
# [121 rows x 4 columns])
# (997.8938683710765,        neuron_pop_size  progenitor_pop_size   time  whole_pop_size
# 56.00              0.0                 49.0  56.00            49.0
# 56.25              4.0                 66.0  56.25            70.0
# 56.50              5.0                 65.0  56.50            70.0
# 56.75              5.0                 67.0  56.75            72.0
# 57.00              5.0                 68.0  57.00            73.0
# ...                ...                  ...    ...             ...
# 85.00           1119.0                 89.0  85.00          1208.0
# 85.25           1121.0                 90.0  85.25          1211.0
# 85.50           1127.0                 86.0  85.50          1213.0
# 85.75           1136.0                 77.0  85.75          1213.0
# 86.00           1139.0                 75.0  86.00          1214.0
#
# [121 rows x 4 columns])

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.42; m: 7.05; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.00; tree : -4
# >> G_1: init: 0.89; noise: 0.31; b: 1.81; m: 2.03; expr: 1.00; deg: 0.10; theta: 5.07; asym: 5.00; tree : -3
# >> G_2: init: 0.79; noise: 0.23; b: 2.28; m: 6.25; expr: 1.00; deg: 0.10; theta: 9.74; asym: 5.00; tree : ((2 OR 0) OR (4 OR -1))
# >> G_3: init: 0.30; noise: 0.20; b: 0.14; m: 9.34; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 0.76; noise: 0.07; b: 2.72; m: 5.84; expr: 1.00; deg: 0.10; theta: 7.95; asym: 5.00; tree : 3
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.42; m: 7.05; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.00; tree : -4
# >> G_1: init: 0.89; noise: 0.31; b: 1.81; m: 2.03; expr: 1.00; deg: 0.10; theta: 5.19; asym: 5.00; tree : -3
# >> G_2: init: 0.79; noise: 0.23; b: 2.68; m: 6.25; expr: 1.00; deg: 0.10; theta: 9.74; asym: 5.00; tree : ((3 OR 0) OR (4 OR -5))
# >> G_3: init: 0.30; noise: 0.20; b: 0.14; m: 9.34; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 0.76; noise: 0.07; b: 2.72; m: 5.84; expr: 1.00; deg: 0.10; theta: 7.95; asym: 5.00; tree : 3
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 2.23; noise: 0.37; b: 0.42; m: 7.05; expr: 1.00; deg: 0.10; theta: 2.91; asym: 5.00; tree : -4
# >> G_1: init: 0.89; noise: 0.31; b: 1.81; m: 2.03; expr: 1.00; deg: 0.10; theta: 5.07; asym: 5.00; tree : -3
# >> G_2: init: 0.79; noise: 0.23; b: 2.28; m: 6.25; expr: 1.11; deg: 0.09; theta: 9.74; asym: 5.62; tree : ((2 OR 0) OR (-3 OR -1))
# >> G_3: init: 0.30; noise: 0.20; b: 0.14; m: 9.34; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 0.76; noise: 0.08; b: 2.72; m: 5.84; expr: 1.00; deg: 0.10; theta: 7.95; asym: 5.00; tree : 3
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 2.63; noise: 0.37; b: 0.42; m: 7.05; expr: 1.00; deg: 0.10; theta: 2.91; asym: 5.00; tree : -4
# >> G_1: init: 0.89; noise: 0.31; b: 1.81; m: 2.03; expr: 1.08; deg: 0.10; theta: 5.07; asym: 5.35; tree : -3
# >> G_2: init: 0.79; noise: 0.23; b: 2.38; m: 6.25; expr: 1.11; deg: 0.09; theta: 9.74; asym: 5.62; tree : ((2 OR 0) OR (-3 OR -1))
# >> G_3: init: 0.30; noise: 0.20; b: 0.14; m: 9.34; expr: 1.00; deg: 0.10; theta: 5.69; asym: 5.00; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 0.76; noise: 0.08; b: 2.72; m: 5.84; expr: 1.00; deg: 0.10; theta: 7.95; asym: 5.00; tree : 3
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.42; m: 8.06; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.83; tree : -4
# >> G_1: init: 0.89; noise: 0.31; b: 1.81; m: 2.03; expr: 1.16; deg: 0.10; theta: 5.19; asym: 5.00; tree : -3
# >> G_2: init: 0.79; noise: 0.23; b: 2.28; m: 5.77; expr: 0.81; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (0 OR -5))
# >> G_3: init: 0.30; noise: 0.20; b: 0.16; m: 9.58; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.00; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 0.76; noise: 0.07; b: 2.72; m: 5.84; expr: 1.00; deg: 0.10; theta: 7.95; asym: 4.33; tree : 3
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.42; m: 8.06; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.00; tree : -4
# >> G_1: init: 0.89; noise: 0.31; b: 1.81; m: 2.03; expr: 1.00; deg: 0.10; theta: 5.19; asym: 5.00; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.28; m: 5.77; expr: 0.81; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.30; noise: 0.20; b: 0.16; m: 9.34; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.06; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 0.76; noise: 0.06; b: 2.72; m: 5.29; expr: 1.00; deg: 0.10; theta: 7.95; asym: 4.84; tree : 3
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.42; m: 8.06; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.00; tree : -4
# >> G_1: init: 0.89; noise: 0.31; b: 1.93; m: 2.03; expr: 1.00; deg: 0.10; theta: 5.19; asym: 5.00; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.28; m: 5.77; expr: 0.81; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.30; noise: 0.20; b: 0.16; m: 9.60; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.06; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 0.76; noise: 0.06; b: 2.72; m: 5.29; expr: 1.00; deg: 0.10; theta: 7.95; asym: 5.10; tree : 3
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.36; m: 8.06; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.00; tree : -4
# >> G_1: init: 0.89; noise: 0.31; b: 1.93; m: 2.03; expr: 1.00; deg: 0.10; theta: 5.19; asym: 5.39; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.28; m: 5.77; expr: 0.81; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.30; noise: 0.20; b: 0.16; m: 9.60; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.06; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.64; noise: 1.99; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.87; asym: 2.53; tree : -2
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.36; m: 8.06; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.00; tree : -4
# >> G_1: init: 0.89; noise: 0.36; b: 1.93; m: 2.03; expr: 1.00; deg: 0.10; theta: 5.73; asym: 5.39; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.28; m: 5.77; expr: 0.81; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.30; noise: 0.20; b: 0.15; m: 9.60; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.06; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.64; noise: 1.99; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.87; asym: 2.53; tree : -2
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.36; m: 8.06; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.00; tree : -4
# >> G_1: init: 0.89; noise: 0.36; b: 1.93; m: 2.03; expr: 1.00; deg: 0.10; theta: 5.19; asym: 5.39; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.28; m: 5.77; expr: 0.81; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.30; noise: 0.21; b: 0.13; m: 9.60; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.06; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.64; noise: 2.05; b: 8.11; m: 1.61; expr: 1.42; deg: 1.78; theta: 5.87; asym: 2.53; tree : -2
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.36; m: 6.58; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.29; tree : -4
# >> G_1: init: 0.77; noise: 0.36; b: 1.93; m: 2.03; expr: 1.00; deg: 0.10; theta: 4.29; asym: 5.39; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.28; m: 5.77; expr: 0.81; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.30; noise: 0.16; b: 0.15; m: 9.04; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.06; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.64; noise: 1.99; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.46; asym: 2.53; tree : -2
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 2.14; noise: 0.37; b: 0.36; m: 8.06; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.29; tree : -4
# >> G_1: init: 0.77; noise: 0.36; b: 1.93; m: 2.03; expr: 1.00; deg: 0.10; theta: 5.19; asym: 5.39; tree : -3
# >> G_2: init: 0.83; noise: 0.21; b: 2.28; m: 5.77; expr: 0.81; deg: 0.09; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.36; noise: 0.16; b: 0.15; m: 9.60; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.06; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.53; noise: 1.99; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.46; asym: 2.53; tree : -2
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.36; m: 5.79; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.29; tree : -4
# >> G_1: init: 0.77; noise: 0.36; b: 1.93; m: 2.03; expr: 1.00; deg: 0.09; theta: 4.29; asym: 4.67; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.27; m: 5.77; expr: 0.81; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.34; noise: 0.16; b: 0.15; m: 10.36; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.34; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.64; noise: 2.35; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.46; asym: 2.53; tree : -2
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.36; m: 5.79; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.29; tree : -5
# >> G_1: init: 0.77; noise: 0.36; b: 1.93; m: 2.03; expr: 1.00; deg: 0.09; theta: 4.29; asym: 4.67; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.27; m: 5.77; expr: 0.84; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.34; noise: 0.16; b: 0.15; m: 10.36; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.34; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.90; noise: 2.35; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.46; asym: 2.53; tree : 3
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 2.01; noise: 0.40; b: 0.36; m: 5.79; expr: 1.00; deg: 0.10; theta: 2.62; asym: 5.29; tree : -4
# >> G_1: init: 0.77; noise: 0.36; b: 1.93; m: 2.03; expr: 1.00; deg: 0.08; theta: 3.79; asym: 4.67; tree : -3
# >> G_2: init: 0.79; noise: 0.17; b: 2.27; m: 5.77; expr: 0.81; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.30; noise: 0.15; b: 0.15; m: 11.71; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.34; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.64; noise: 2.35; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.46; asym: 2.53; tree : -2
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.36; m: 4.72; expr: 1.00; deg: 0.10; theta: 2.62; asym: 4.27; tree : -5
# >> G_1: init: 0.77; noise: 0.36; b: 1.93; m: 2.03; expr: 1.01; deg: 0.09; theta: 4.65; asym: 4.67; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.27; m: 5.77; expr: 0.84; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.27; noise: 0.16; b: 0.15; m: 10.89; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.34; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.90; noise: 2.81; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.46; asym: 2.53; tree : 3
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.37; m: 4.72; expr: 0.99; deg: 0.10; theta: 2.62; asym: 4.27; tree : -5
# >> G_1: init: 0.77; noise: 0.36; b: 1.93; m: 2.03; expr: 1.01; deg: 0.09; theta: 4.65; asym: 4.67; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.27; m: 5.77; expr: 0.84; deg: 0.10; theta: 9.74; asym: 5.00; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.27; noise: 0.16; b: 0.15; m: 10.89; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.34; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.90; noise: 2.81; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.46; asym: 2.53; tree : 3
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 2.01; noise: 0.37; b: 0.37; m: 4.72; expr: 0.99; deg: 0.10; theta: 2.97; asym: 4.27; tree : -5
# >> G_1: init: 0.77; noise: 0.36; b: 1.93; m: 2.03; expr: 1.01; deg: 0.09; theta: 4.65; asym: 4.67; tree : -3
# >> G_2: init: 0.79; noise: 0.21; b: 2.27; m: 5.77; expr: 0.84; deg: 0.10; theta: 9.74; asym: 5.83; tree : (2 OR (1 OR -5))
# >> G_3: init: 0.27; noise: 0.16; b: 0.15; m: 10.89; expr: 1.00; deg: 0.09; theta: 5.69; asym: 5.34; tree : (-2 OR (-3 OR -5))
# >> G_4: init: 2.90; noise: 2.81; b: 8.11; m: 1.67; expr: 1.33; deg: 1.78; theta: 5.46; asym: 2.53; tree : 3
