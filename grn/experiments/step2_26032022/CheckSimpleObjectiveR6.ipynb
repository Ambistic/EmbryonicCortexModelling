# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve_2, show_curve_progenitor
from jf.models.stringmodel import read_model

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**1.2))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn5"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=66, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 100
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=5, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // 100
            exporter(pop[-prun.max_pop:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r6"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r6
# [definition]
#
#
# [reload] Found generation 49
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-81e2f4f6a6b3> in <module>
#       2 prun.cb_init = callback_init
#       3 prun.name = "check_simple_obj_r6"
# ----> 4 res = main(prun)
#
# <ipython-input-15-b9e59561fcb1> in main(prun)
#      20     for i in range(batch_gen * prun.batch_size,
#      21                    prun.n_gen * prun.batch_size):
# ---> 22         fit, stats = do_fitness(prun, sol)
#      23         sol.fit, sol.stats = fit, stats
#      24
#
# <ipython-input-12-803c9e3dddd9> in do_fitness(prun, sol)
#       3
#       4 def do_fitness(prun, sol):
# ----> 5     fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
#       6     return fitness, stats
#       7
#
# <ipython-input-11-424afec1b8a4> in fitness_multistep(prun, grn, steps)
#       6     # first step
#       7     for step in steps:
# ----> 8         if not bb.run_until(step.end_time):
#       9             stop = True
#      10
#
# ~/other/EmbryonicCortexModelling/grn/brain.py in run_until(self, time_point)
#     145                 and (self.range[self.current_step] < time_point):
#     146             T = self.range[self.current_step]
# --> 147             if not self._tick(T, self.time_step):
#     148                 self.info("Population exploded or extinguished")
#     149                 return False
#
# ~/other/EmbryonicCortexModelling/grn/brain.py in _tick(self, absolute_time, relative_time)
#     170         # take care of cells
#     171         if self.opti:
# --> 172             self.population.tick_cell_programs_batch(absolute_time, relative_time)
#     173         else:
#     174             self.population.tick_cell_programs(absolute_time, relative_time)
#
# ~/other/EmbryonicCortexModelling/grn/lib/population.py in tick_cell_programs_batch(self, absolute_time, relative_time)
#      70
#      71         # this batch function must be provided by the cell class
# ---> 72         self.cell_cls.batch_tick(cells, absolute_time, relative_time)
#      73
#      74         for C in cells:
#
# ~/other/EmbryonicCortexModelling/grn/submodels/grn_v5.py in batch_tick(cells, absolute_time, relative_time)
#     127         cell_programs = [c.cell_program for c in cells]
#     128         batch = CellBatch(cell_programs)
# --> 129         batch.run_step(relative_time)
#
# ~/other/EmbryonicCortexModelling/grn/lib/sde/cell/cell5.py in run_step(self, ts, base_size, mul)
#     183         for cell_batch in finebatch(self.cells, base_size, mul):
#     184             batch_size = max(base_size, len(cell_batch))
# --> 185             self.run_step_batch(cell_batch, batch_size, ts)
#     186
#     187     def run_step_batch(self, cell_batch, size, ts):
#
# ~/other/EmbryonicCortexModelling/grn/lib/sde/cell/cell5.py in run_step_batch(self, cell_batch, size, ts)
#     207         expressions = batch_compute_expression(self.grn.genes, full_activations)
#     208         derivatives = batch_compute_derivatives(expressions, quantities, self.grn.expr, self.grn.deg)
# --> 209         quantities = batch_compute_quantities(quantities, derivatives, self.grn.noise, ts, self.get_random_key())
#     210
#     211         """
#
# ~/other/EmbryonicCortexModelling/grn/lib/sde/grn/grn5.py in __getattr__(self, item)
#      47     def __getattr__(self, item):
#      48         if item in ParamGene:
# ---> 49             return self._params[ParamGene.get(item)]
#      50         else:
#      51             raise AttributeError(f"{item} is not found in ParamGene")
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    5786   arr = asarray(arr)
#    5787   treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> 5788   return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    5789                  unique_indices, mode, fill_value)
#    5790
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    5813   # We avoid generating a gather when indexer.gather_indices.size is empty.
#    5814   if not core.is_empty_shape(indexer.gather_indices.shape):
# -> 5815     y = lax.gather(
#    5816       y, indexer.gather_indices, indexer.dnums, indexer.gather_slice_shape,
#    5817       unique_indices=unique_indices or indexer.unique_indices,
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/lax/slicing.py in gather(operand, start_indices, dimension_numbers, slice_sizes, unique_indices, indices_are_sorted, mode, fill_value)
#     271   else:
#     272     fill_value = None
# --> 273   return gather_p.bind(
#     274       operand, start_indices, dimension_numbers=dimension_numbers,
#     275       slice_sizes=core.canonicalize_shape(slice_sizes),
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/core.py in bind(self, *args, **params)
#     277     assert (not config.jax_enable_checks or
#     278             all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 279     return self.bind_with_trace(find_top_trace(args), args, params)
#     280
#     281   def bind_with_trace(self, trace, args, params):
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/core.py in bind_with_trace(self, trace, args, params)
#     280
#     281   def bind_with_trace(self, trace, args, params):
# --> 282     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     283     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     284
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/core.py in process_primitive(self, primitive, tracers, params)
#     596
#     597   def process_primitive(self, primitive, tracers, params):
# --> 598     return primitive.impl(*tracers, **params)
#     599
#     600   def process_call(self, primitive, f, tracers, params):
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/dispatch.py in apply_primitive(prim, *args, **params)
#      92   compiled_fun = xla_primitive_callable(prim, *unsafe_map(arg_spec, args),
#      93                                         **params)
# ---> 94   return compiled_fun(*args)
#      95
#      96 # TODO(phawkins): update code referring to xla.apply_primitive to point here.
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/dispatch.py in <lambda>(*args, **kw)
#     112                                     prim.name, donated_invars, *arg_specs)
#     113   if not prim.multiple_results:
# --> 114     return lambda *args, **kw: compiled(*args, **kw)[0]
#     115   else:
#     116     return compiled
#
# /opt/jupyterhub/lib/python3.8/site-packages/jax/_src/dispatch.py in _execute_compiled(name, compiled, output_buffer_counts, result_handlers, kept_var_idx, *args)
#     442   input_bufs = util.flatten(
#     443       device_put(x, device) for i, x in enumerate(args) if i in kept_var_idx)
# --> 444   out_bufs = compiled.execute(input_bufs)
#     445   check_special(name, out_bufs)
#     446   if output_buffer_counts is None:
#
# KeyboardInterrupt:

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r6

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
show_curve_2(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g0 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.60; expr: 1.00; deg: 0.10; theta: 7.45; asym: 5.00; tree : 2
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 6.55; asym: 5.00; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 8.87; asym: 5.00; tree : 2
# >> G_3: init: 0.57; noise: 0.70; b: 0.41; m: 3.49; expr: 1.00; deg: 0.10; theta: 2.27; asym: 5.00; tree : -0
# >> G_4: init: 2.04; noise: 0.18; b: 0.56; m: 9.99; expr: 1.00; deg: 0.10; theta: 7.81; asym: 5.00; tree : -3
#
# ======= GENERATION generation_g1 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.60; expr: 1.00; deg: 0.10; theta: 8.66; asym: 5.00; tree : 2
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 8.43; asym: 5.00; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 8.87; asym: 5.00; tree : (2 OR 3)
# >> G_3: init: 0.57; noise: 0.70; b: 0.41; m: 3.49; expr: 1.00; deg: 0.10; theta: 2.27; asym: 4.13; tree : -0
# >> G_4: init: 0.76; noise: 0.18; b: 0.56; m: 9.99; expr: 1.00; deg: 0.10; theta: 7.81; asym: 5.00; tree : -3
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.60; expr: 1.00; deg: 0.10; theta: 8.66; asym: 5.00; tree : 2
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 8.43; asym: 5.00; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 8.87; asym: 5.00; tree : (2 OR 3)
# >> G_3: init: 0.34; noise: 0.70; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.27; asym: 4.13; tree : -0
# >> G_4: init: 0.76; noise: 0.18; b: 0.56; m: 9.99; expr: 1.00; deg: 0.10; theta: 7.81; asym: 5.00; tree : -3
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.60; expr: 1.00; deg: 0.10; theta: 8.61; asym: 5.00; tree : 2
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 9.14; asym: 5.00; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 8.87; asym: 5.00; tree : (2 OR 3)
# >> G_3: init: 0.34; noise: 0.70; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.39; asym: 4.13; tree : -0
# >> G_4: init: 0.76; noise: 0.18; b: 0.56; m: 9.99; expr: 1.00; deg: 0.10; theta: 9.34; asym: 5.00; tree : -3
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.60; expr: 1.00; deg: 0.10; theta: 11.50; asym: 4.37; tree : 2
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 8.34; asym: 5.00; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 8.87; asym: 5.00; tree : (2 OR 3)
# >> G_3: init: 0.34; noise: 0.70; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.13; asym: 4.13; tree : 4
# >> G_4: init: 0.76; noise: 0.18; b: 0.56; m: 9.99; expr: 1.00; deg: 0.10; theta: 7.81; asym: 5.00; tree : -3
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 9.77; asym: 3.77; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 12.81; asym: 4.03; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 10.05; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.95; asym: 3.34; tree : (-0 OR 3)
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 10.12; asym: 5.00; tree : -3
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 8.16; asym: 3.10; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 13.39; asym: 4.03; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 9.52; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 3.35; asym: 3.56; tree : (-0 OR 2)
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 10.12; asym: 5.00; tree : 1
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 11.24; asym: 3.77; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 12.81; asym: 4.03; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 9.45; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 3.33; asym: 4.13; tree : (2 OR 3)
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 10.21; asym: 4.15; tree : -3
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 7.45; asym: 3.10; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 13.39; asym: 4.03; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 10.44; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 3.35; asym: 2.96; tree : (-0 OR 3)
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 13.05; asym: 3.27; tree : (1 OR 5)
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 6.58; asym: 3.10; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 13.39; asym: 4.03; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 10.05; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 3.11; asym: 2.96; tree : (-0 OR 2)
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 15.16; asym: 3.27; tree : (1 OR 3)
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 6.90; asym: 3.10; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 13.39; asym: 4.03; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.18; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 3.11; asym: 2.96; tree : (NOT -0 OR 2)
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 11.78; asym: 3.27; tree : (1 OR 5)
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 6.58; asym: 2.58; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 12.96; asym: 4.03; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 10.05; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 3.41; asym: 2.96; tree : 2
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 13.75; asym: 3.27; tree : (1 OR 3)
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 6.90; asym: 3.10; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 12.41; asym: 4.03; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.18; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.65; asym: 2.96; tree : (NOT -0 OR 2)
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 11.78; asym: 2.81; tree : (1 OR 5)
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 6.54; asym: 3.10; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 14.18; asym: 4.03; tree : ((5 AND 1) AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.18; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.65; asym: 2.96; tree : (NOT 1 OR 2)
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 11.78; asym: 2.72; tree : (1 OR 5)
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 7.89; asym: 3.10; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 14.60; asym: 4.03; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.66; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.72; asym: 2.55; tree : NOT -0
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 13.73; asym: 3.27; tree : (1 OR 5)
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 8.08; asym: 3.10; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 14.60; asym: 4.03; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.66; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.72; asym: 2.55; tree : NOT -0
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 14.63; asym: 3.27; tree : (1 OR 5)
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 7.45; asym: 3.10; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 13.74; asym: 4.03; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.66; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.72; asym: 2.55; tree : NOT -0
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 14.63; asym: 3.27; tree : (1 OR 5)
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 7.45; asym: 2.18; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 13.34; asym: 4.03; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.66; asym: 5.00; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.72; asym: 2.55; tree : NOT -0
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 16.20; asym: 3.27; tree : (2 OR 5)
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 8.70; asym: 2.18; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 13.74; asym: 4.03; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.66; asym: 4.07; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.75; asym: 2.55; tree : NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 16.20; asym: 3.27; tree : (2 OR 5)
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 10.25; asym: 2.18; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 13.74; asym: 4.03; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.66; asym: 3.46; tree : 2
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.75; asym: 2.55; tree : NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 17.41; asym: 3.27; tree : (2 OR 5)
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 0.08; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 6.93; asym: 1.42; tree : (2 OR 1)
# >> G_1: init: 0.43; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 12.79; asym: 4.03; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 11.29; asym: 5.00; tree : (2 OR 5)
# >> G_3: init: 0.34; noise: 9.90; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.79; asym: 2.55; tree : NOT -0
# >> G_4: init: 0.76; noise: 0.18; b: 4.23; m: 9.99; expr: 1.00; deg: 1.61; theta: 14.51; asym: 3.27; tree : 3
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 12.82; asym: 0.93; tree : (2 OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 18.88; asym: 3.25; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.46; asym: 5.00; tree : (2 OR 4)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.16; asym: 2.55; tree : NOT 0
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.61; theta: 8.05; asym: 2.06; tree : 5
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 12.82; asym: 0.93; tree : (2 OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 18.88; asym: 3.25; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 14.34; asym: 5.00; tree : (2 OR 4)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.16; asym: 2.15; tree : NOT 0
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 8.05; asym: 2.06; tree : 5
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 15.30; asym: 0.93; tree : (2 OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 18.21; asym: 3.25; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.46; asym: 5.00; tree : (2 OR 4)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.23; asym: 2.12; tree : NOT 0
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.55; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 13.13; asym: 0.80; tree : (2 OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 18.88; asym: 3.25; tree : (-3 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.93; asym: 5.00; tree : (2 OR 5)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.23; asym: 2.12; tree : NOT 3
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.51; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 18.06; asym: 0.93; tree : (2 OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 18.21; asym: 3.25; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.70; asym: 5.00; tree : (2 OR 4)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.24; asym: 2.12; tree : NOT 0
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.80; asym: 1.79; tree : NOT 5
#
# ======= GENERATION generation_g26 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 18.06; asym: 0.93; tree : (2 OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 20.94; asym: 3.25; tree : (1 AND (-3 OR -2))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.70; asym: 5.00; tree : (2 OR 4)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.29; asym: 1.74; tree : NOT 0
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.80; asym: 1.79; tree : NOT 5
#
# ======= GENERATION generation_g27 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 14.12; asym: 0.69; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 21.99; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 14.52; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.18; asym: 1.71; tree : NOT 3
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.51; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g28 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 13.21; asym: 0.60; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 22.89; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.98; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.37; asym: 1.71; tree : NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.55; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g29 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 13.21; asym: 0.60; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 22.89; asym: 3.25; tree : (1 OR (-2 OR 0))
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 14.52; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.21; asym: 1.71; tree : NOT NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.55; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g30 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 14.39; asym: 0.60; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 25.18; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.98; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.09; asym: 1.71; tree : NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.55; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g31 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 14.39; asym: 0.60; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 25.18; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.98; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.09; asym: 1.71; tree : NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.98; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g32 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 15.06; asym: 0.53; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 27.50; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.99; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.09; asym: 1.71; tree : NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.98; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g33 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 14.39; asym: 0.51; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 25.39; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.98; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.05; asym: 1.15; tree : NOT (NOT 5 AND 4)
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.30; asym: 1.31; tree : 5
#
# ======= GENERATION generation_g34 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 15.06; asym: 0.53; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 27.50; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.16; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.55; deg: 1.21; theta: 2.32; asym: 1.71; tree : NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.98; asym: 1.79; tree : (5 OR 0)
#
# ======= GENERATION generation_g35 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 14.71; asym: 0.53; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 27.50; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.16; asym: 5.00; tree : (5 OR 2)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.32; asym: 1.71; tree : NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.98; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g36 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 16.08; asym: 0.53; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 29.42; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.16; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.32; asym: 1.71; tree : NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.98; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g37 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 15.49; asym: 0.38; tree : ((1 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 27.50; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.32; asym: 5.00; tree : (5 OR 2)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.16; asym: 1.71; tree : NOT NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 3.00; deg: 1.08; theta: 6.70; asym: 1.79; tree : (5 OR 0)
#
# ======= GENERATION generation_g38 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 14.98; asym: 0.44; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 38.79; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.16; asym: 5.00; tree : (5 OR 2)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.23; asym: 1.71; tree : NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.98; asym: 1.79; tree : 0
#
# ======= GENERATION generation_g39 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 15.74; asym: 0.44; tree : (4 OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 36.15; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.00; asym: 5.00; tree : (5 OR 2)
# >> G_3: init: 0.34; noise: 1.26; b: 0.41; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.69; asym: 1.71; tree : NOT NOT 5
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.29; deg: 1.08; theta: 5.98; asym: 1.79; tree : 3
#
# ======= GENERATION generation_g40 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 18.71; asym: 0.43; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 30.29; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.16; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.73; asym: 1.71; tree : NOT NOT 2
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.92; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g41 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 18.71; asym: 0.43; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 27.96; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.16; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.73; asym: 1.40; tree : NOT NOT (2 AND 4)
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.25; asym: 1.79; tree : NOT 5
#
# ======= GENERATION generation_g42 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 22.26; asym: 0.43; tree : ((2 AND 4) OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 27.96; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 13.16; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.73; asym: 1.40; tree : NOT NOT (2 AND 4)
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 5.81; asym: 1.52; tree : 5
#
# ======= GENERATION generation_g43 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 18.71; asym: 0.43; tree : (4 OR 5)
# >> G_1: init: 0.22; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 38.44; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.76; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.93; asym: 1.71; tree : NOT NOT NOT 2
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.19; asym: 1.52; tree : 5
#
# ======= GENERATION generation_g44 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 19.37; asym: 0.35; tree : (4 OR 5)
# >> G_1: init: 0.11; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 36.17; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.76; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.71; asym: 1.71; tree : NOT NOT NOT 2
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 1.00; deg: 1.08; theta: 6.19; asym: 1.79; tree : (5 AND 0)
#
# ======= GENERATION generation_g45 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 22.14; asym: 0.35; tree : (4 OR 1)
# >> G_1: init: 0.11; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 37.39; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.76; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.93; asym: 1.71; tree : NOT NOT NOT 2
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 2.70; deg: 1.08; theta: 6.19; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g46 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 21.66; asym: 0.30; tree : (NOT 4 OR 5)
# >> G_1: init: 0.11; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 44.91; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.76; asym: 5.00; tree : 5
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.93; asym: 1.71; tree : NOT NOT NOT 1
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 0.77; deg: 1.08; theta: 6.19; asym: 1.44; tree : 5
#
# ======= GENERATION generation_g47 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 22.84; asym: 0.35; tree : (4 OR 1)
# >> G_1: init: 0.11; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 36.23; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.71; asym: 5.00; tree : (5 AND 4)
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.65; asym: 1.71; tree : NOT NOT NOT 2
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 2.70; deg: 1.08; theta: 6.48; asym: 1.45; tree : 5
#
# ======= GENERATION generation_g48 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 22.53; asym: 0.35; tree : (4 OR 1)
# >> G_1: init: 0.11; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 36.23; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.76; asym: 5.00; tree : (5 AND 4)
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.98; asym: 1.71; tree : NOT NOT NOT NOT 2
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 2.70; deg: 1.08; theta: 5.46; asym: 1.79; tree : 5
#
# ======= GENERATION generation_g49 =======
# >> G_0: init: 2.72; noise: 0.75; b: 1.66; m: 3.69; expr: 1.00; deg: 0.10; theta: 25.16; asym: 0.35; tree : (4 OR 1)
# >> G_1: init: 0.11; noise: 0.12; b: 2.90; m: 1.44; expr: 1.00; deg: 0.10; theta: 36.23; asym: 3.25; tree : (1 OR -2)
# >> G_2: init: 0.86; noise: 0.03; b: 3.00; m: 1.47; expr: 1.00; deg: 0.10; theta: 12.95; asym: 5.00; tree : (5 AND 4)
# >> G_3: init: 0.34; noise: 1.26; b: 6.08; m: 3.49; expr: 1.00; deg: 1.21; theta: 2.65; asym: 1.71; tree : NOT NOT NOT 2
# >> G_4: init: 0.76; noise: 0.18; b: 9.61; m: 9.99; expr: 2.70; deg: 1.08; theta: 6.48; asym: 1.45; tree : (5 OR 0)
