# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")

# %%
def individual_generator(id_=-1, cb_init=None):
    return Solution(GRNMain(5, 0, 1, generate_funcs=cb_init), id_=id_)

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        mutate_grn(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    last_time = max(stats.time)
    stats = stats.set_index("time")
    prog = stats.loc[last_time]["progenitor_pop_size"]
    neuron = stats.loc[last_time]["neuron_pop_size"]
    # print(prog, neuron, neuron - prog**1.8)

    return 1 / max(1, 1000 + (neuron - prog**1.8))

# %%
def setup_tag(cp):
    indexes = list(cp.base_population.keys())
    shuffle(indexes)
    splits = np.array_split(indexes, 3)
    for i, ls in enumerate(splits):
        for idx in ls:
            cp.base_population[idx].tag["subbrain"] = i

# %%
def get_bb(prun, grn):
    ccls = factories["grn4"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
    )
    bb = BrainModel(time_step=0.5, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=56, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks, tag_func=setup_tag)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=0.05, id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    # ObjectiveStep(name="1", start_time=50, end_time=53, score_func=score_bb_size, min_fitness=0.2),
    # ObjectiveStep(name="2", start_time=53, end_time=56, score_func=score_bb_size, min_fitness=0.2),
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    print("debug", batch_gen, prun.n_gen)
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // prun.batch_size
            exporter(pop[-prun.batch_size:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r34"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r34
# [definition]
#
#
# [reload] Found generation 50
# debug 51 50

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r34

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load(pick_last(exp)))

# %%
res.fit
# Out:
# -1

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g1 =======
# >> G_0: init: 1.33; noise: 0.29; b: 0.15; m: 7.34; expr: 1.00; deg: 0.10; theta: 3.91; asym: 5.86; tree : (3 AND 2)
# >> G_1: init: 0.27; noise: 0.28; b: 0.42; m: 4.71; expr: 1.00; deg: 0.10; theta: 9.91; asym: 5.00; tree : 3
# >> G_2: init: 0.45; noise: 0.26; b: 2.50; m: 7.06; expr: 1.00; deg: 0.10; theta: 5.47; asym: 5.00; tree : 3
# >> G_3: init: 0.25; noise: 0.07; b: 0.39; m: 8.46; expr: 1.00; deg: 0.10; theta: 6.67; asym: 5.00; tree : ((-5 AND -1) AND -0)
# >> G_4: init: 0.76; noise: 0.51; b: 0.26; m: 4.71; expr: 1.00; deg: 0.10; theta: 9.96; asym: 5.00; tree : ((2 OR 5) AND (-1 OR 4))
#
# ======= GENERATION generation_g2 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.81; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ======= GENERATION generation_g3 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.45; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ======= GENERATION generation_g4 =======
# >> G_0: init: 0.54; noise: 0.36; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.66; b: 2.21; m: 6.45; expr: 1.00; deg: 0.12; theta: 4.51; asym: 5.47; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.99; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ======= GENERATION generation_g5 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : (3 OR 4)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.54; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (1 AND 3))
#
# ======= GENERATION generation_g6 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : (3 OR 4)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.54; b: 1.38; m: 2.12; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (1 AND 3))
#
# ======= GENERATION generation_g7 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.20; asym: 5.29; tree : (3 OR 4)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.54; b: 1.38; m: 2.12; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.97; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (1 AND 3))
#
# ======= GENERATION generation_g8 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.59; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (1 AND 3))
#
# ======= GENERATION generation_g9 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.10; theta: 3.20; asym: 5.29; tree : (3 OR 4)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.54; b: 1.38; m: 2.12; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.97; deg: 0.10; theta: 4.51; asym: 4.45; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.79; tree : ((-0 AND -5) AND (1 AND 3))
#
# ======= GENERATION generation_g10 =======
# >> G_0: init: 0.50; noise: 0.36; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 3.91; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.44; asym: 5.00; tree : 0
# >> G_3: init: 0.61; noise: 0.72; b: 2.21; m: 6.22; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.47; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.99; expr: 1.00; deg: 0.10; theta: 4.72; asym: 4.26; tree : ((-0 AND 1) AND (2 AND 3))
#
# ======= GENERATION generation_g11 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.18; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.63; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.73; asym: 4.39; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g12 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 1.79; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g13 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.11; theta: 3.48; asym: 5.29; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.43; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g14 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.11; theta: 3.48; asym: 5.29; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.63; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g15 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 4.44; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.57; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.09; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.63; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g16 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 4.71; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.57; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.09; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g17 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 4.44; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.67; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.09; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.63; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 4.21; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.25; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g18 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.20; m: 9.48; expr: 0.90; deg: 0.11; theta: 3.48; asym: 5.28; tree : ((1 OR 0) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.24; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.64; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.57; asym: 5.00; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g19 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.20; m: 9.48; expr: 0.90; deg: 0.11; theta: 3.48; asym: 5.29; tree : ((3 OR -2) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.54; b: 1.63; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 4.31; tree : 0
# >> G_3: init: 0.71; noise: 0.68; b: 2.21; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.64; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.98; asym: 5.00; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g20 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.00; m: 9.48; expr: 0.90; deg: 0.11; theta: 3.48; asym: 5.28; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.24; tree : 0
# >> G_3: init: 0.68; noise: 0.68; b: 2.21; m: 6.45; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.18; tree : -2
# >> G_4: init: 0.64; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.57; asym: 5.00; tree : (-0 AND (1 AND 3))
#
# ======= GENERATION generation_g21 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.92; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.78; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (2 OR -1))
#
# ======= GENERATION generation_g22 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.92; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.22; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.63; m: 2.02; expr: 1.01; deg: 0.11; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.78; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.19; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (2 OR -1))
#
# ======= GENERATION generation_g23 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.92; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 5.37; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.78; expr: 0.92; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 1.32; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (2 OR -1))
#
# ======= GENERATION generation_g24 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.78; expr: 0.92; deg: 0.10; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.98; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND -1)
#
# ======= GENERATION generation_g25 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.78; expr: 0.92; deg: 0.10; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.98; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND (4 AND -2))
#
# ======= GENERATION generation_g26 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.79; tree : (3 OR 4)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.98; deg: 0.10; theta: 4.73; asym: 5.04; tree : (-0 AND (4 AND -2))
#
# ======= GENERATION generation_g27 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.79; tree : (3 OR 4)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.40; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.98; deg: 0.10; theta: 4.73; asym: 5.04; tree : (-0 AND (4 AND -2))
#
# ======= GENERATION generation_g28 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 10.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.79; tree : (3 OR 4)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.40; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.98; deg: 0.10; theta: 4.73; asym: 5.04; tree : (-0 AND (4 AND -2))
#
# ======= GENERATION generation_g29 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 10.90; expr: 0.90; deg: 0.11; theta: 3.08; asym: 3.79; tree : (3 OR 4)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.40; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.98; deg: 0.10; theta: 4.73; asym: 5.04; tree : (-0 AND (4 AND -2))
#
# ======= GENERATION generation_g30 =======
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 10.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.79; tree : (3 OR 4)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.04; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.61; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.40; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.98; deg: 0.10; theta: 4.73; asym: 5.04; tree : (-0 AND (4 AND -2))
#
# ======= GENERATION generation_g31 =======
# >> G_0: init: 0.54; noise: 0.29; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.12; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.66; noise: 0.57; b: 2.21; m: 6.78; expr: 0.92; deg: 0.10; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.81; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g32 =======
# >> G_0: init: 0.54; noise: 0.32; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 2.85; asym: 3.79; tree : (3 OR (4 OR -0))
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.68; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.50; b: 2.21; m: 6.78; expr: 0.92; deg: 0.10; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g33 =======
# >> G_0: init: 0.54; noise: 0.29; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.12; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.63; m: 2.02; expr: 0.98; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.66; noise: 0.57; b: 2.21; m: 6.78; expr: 0.92; deg: 0.10; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.12; b: 1.73; m: 2.52; expr: 0.93; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g34 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 10.81; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.55; tree : (3 OR 4)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.18; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.24; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.36; m: 1.76; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.40; expr: 0.92; deg: 0.11; theta: 4.51; asym: 7.18; tree : -2
# >> G_4: init: 0.80; noise: 0.12; b: 1.73; m: 2.52; expr: 0.98; deg: 0.10; theta: 4.73; asym: 5.04; tree : (-0 AND (4 AND -2))
#
# ======= GENERATION generation_g35 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.18; m: 10.90; expr: 0.90; deg: 0.12; theta: 3.08; asym: 3.55; tree : (3 OR 4)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.49; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.24; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.46; b: 1.36; m: 1.76; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.40; expr: 0.92; deg: 0.11; theta: 4.51; asym: 7.18; tree : -2
# >> G_4: init: 0.80; noise: 0.12; b: 1.73; m: 2.52; expr: 0.98; deg: 0.09; theta: 4.73; asym: 5.04; tree : (-0 AND (4 AND -2))
#
# ======= GENERATION generation_g36 =======
# >> G_0: init: 0.54; noise: 0.29; b: 1.38; m: 9.90; expr: 0.90; deg: 0.11; theta: 3.08; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.40; m: 2.20; expr: 1.02; deg: 0.09; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.29; noise: 0.43; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.56; b: 2.27; m: 7.26; expr: 0.92; deg: 0.11; theta: 4.51; asym: 4.81; tree : -2
# >> G_4: init: 0.81; noise: 0.12; b: 1.73; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g37 =======
# >> G_0: init: 0.54; noise: 0.29; b: 1.38; m: 9.70; expr: 1.00; deg: 0.11; theta: 3.08; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.43; b: 1.63; m: 2.23; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.67; b: 2.36; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.10; b: 1.73; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g38 =======
# >> G_0: init: 0.54; noise: 0.29; b: 1.38; m: 9.70; expr: 1.00; deg: 0.11; theta: 3.08; asym: 3.79; tree : ((0 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.43; b: 1.63; m: 2.23; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.67; b: 2.36; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.10; b: 1.73; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g39 =======
# >> G_0: init: 0.54; noise: 0.29; b: 1.38; m: 12.55; expr: 1.01; deg: 0.11; theta: 3.08; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.31; noise: 0.43; b: 1.63; m: 2.02; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.71; noise: 0.56; b: 2.27; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 4.81; tree : -2
# >> G_4: init: 0.81; noise: 0.14; b: 1.73; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g40 =======
# >> G_0: init: 0.54; noise: 0.29; b: 1.38; m: 9.70; expr: 1.00; deg: 0.11; theta: 3.08; asym: 3.79; tree : (3 OR 4)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.43; b: 1.63; m: 2.23; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.62; noise: 0.63; b: 2.36; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.10; b: 1.73; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g41 =======
# >> G_0: init: 0.54; noise: 0.29; b: 1.54; m: 9.70; expr: 1.00; deg: 0.11; theta: 3.08; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.43; b: 1.63; m: 2.23; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.86; tree : 0
# >> G_3: init: 0.71; noise: 0.67; b: 2.36; m: 6.78; expr: 0.85; deg: 0.12; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.10; b: 1.73; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.81; tree : -0
#
# ======= GENERATION generation_g42 =======
# >> G_0: init: 0.54; noise: 0.26; b: 1.54; m: 9.70; expr: 1.00; deg: 0.11; theta: 3.08; asym: 3.79; tree : (3 AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.43; b: 1.63; m: 2.23; expr: 1.08; deg: 0.14; theta: 8.35; asym: 4.86; tree : 0
# >> G_3: init: 0.71; noise: 0.67; b: 2.36; m: 6.78; expr: 0.85; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.10; b: 1.73; m: 2.71; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g43 =======
# >> G_0: init: 0.54; noise: 0.31; b: 1.38; m: 8.10; expr: 1.00; deg: 0.11; theta: 3.08; asym: 3.79; tree : ((0 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.12; theta: 0.97; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.38; noise: 0.43; b: 1.63; m: 2.23; expr: 1.00; deg: 0.14; theta: 8.35; asym: 5.28; tree : 0
# >> G_3: init: 0.71; noise: 0.67; b: 2.36; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.10; b: 1.73; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g44 =======
# >> G_0: init: 0.54; noise: 0.31; b: 1.38; m: 8.10; expr: 1.00; deg: 0.11; theta: 3.08; asym: 3.79; tree : ((0 OR 4) AND 5)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.12; theta: 0.97; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.38; noise: 0.43; b: 1.52; m: 2.23; expr: 1.00; deg: 0.14; theta: 8.35; asym: 5.28; tree : 0
# >> G_3: init: 0.71; noise: 0.67; b: 2.36; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : -2
# >> G_4: init: 0.73; noise: 0.10; b: 1.73; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g45 =======
# >> G_0: init: 0.54; noise: 0.25; b: 1.38; m: 9.45; expr: 1.00; deg: 0.11; theta: 3.68; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.58; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.38; b: 1.82; m: 2.23; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.62; noise: 0.69; b: 2.36; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : (-2 AND 3)
# >> G_4: init: 0.73; noise: 0.10; b: 1.75; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g46 =======
# >> G_0: init: 0.54; noise: 0.29; b: 1.38; m: 8.49; expr: 1.00; deg: 0.11; theta: 3.08; asym: 3.79; tree : ((3 OR -2) OR 4)
# >> G_1: init: 0.49; noise: 0.04; b: 0.48; m: 2.43; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.43; b: 1.63; m: 2.18; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.62; noise: 0.74; b: 2.36; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : (-2 AND 3)
# >> G_4: init: 0.73; noise: 0.10; b: 1.73; m: 2.52; expr: 0.69; deg: 0.10; theta: 4.73; asym: 5.00; tree : -0
#
# ======= GENERATION generation_g47 =======
# >> G_0: init: 0.54; noise: 0.25; b: 1.38; m: 9.13; expr: 1.00; deg: 0.11; theta: 3.68; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.51; noise: 0.04; b: 0.48; m: 2.02; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.38; b: 1.82; m: 2.23; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.62; noise: 0.69; b: 2.36; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 5.97; tree : (-2 AND 3)
# >> G_4: init: 0.73; noise: 0.10; b: 1.75; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND -3)
#
# ======= GENERATION generation_g48 =======
# >> G_0: init: 0.54; noise: 0.25; b: 1.38; m: 9.45; expr: 1.00; deg: 0.11; theta: 3.68; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.51; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.38; b: 1.82; m: 2.15; expr: 1.00; deg: 0.12; theta: 8.35; asym: 5.52; tree : 0
# >> G_3: init: 0.62; noise: 0.69; b: 2.36; m: 6.78; expr: 0.88; deg: 0.11; theta: 4.51; asym: 6.00; tree : (-2 AND 3)
# >> G_4: init: 0.73; noise: 0.10; b: 1.75; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND -3)
#
# ======= GENERATION generation_g49 =======
# >> G_0: init: 0.65; noise: 0.25; b: 1.38; m: 9.45; expr: 0.99; deg: 0.11; theta: 3.68; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.51; noise: 0.04; b: 0.48; m: 2.20; expr: 1.02; deg: 0.10; theta: 1.04; asym: 4.59; tree : (-4 OR -3)
# >> G_2: init: 0.32; noise: 0.45; b: 1.93; m: 2.23; expr: 1.00; deg: 0.12; theta: 8.35; asym: 4.93; tree : 0
# >> G_3: init: 0.62; noise: 0.78; b: 2.36; m: 6.78; expr: 0.92; deg: 0.11; theta: 4.51; asym: 6.00; tree : (-2 AND 3)
# >> G_4: init: 0.73; noise: 0.10; b: 1.75; m: 2.52; expr: 0.64; deg: 0.10; theta: 4.73; asym: 5.00; tree : (-0 AND -3)
#
# ======= GENERATION generation_g50 =======
# >> G_0: init: 0.44; noise: 0.25; b: 1.38; m: 9.45; expr: 1.00; deg: 0.11; theta: 3.68; asym: 3.79; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.51; noise: 0.04; b: 0.48; m: 2.20; expr: 0.99; deg: 0.10; theta: 1.04; asym: 3.76; tree : (-4 OR -3)
# >> G_2: init: 0.34; noise: 0.38; b: 1.82; m: 2.15; expr: 1.00; deg: 0.12; theta: 8.35; asym: 5.52; tree : 0
# >> G_3: init: 0.62; noise: 0.71; b: 2.36; m: 6.78; expr: 0.88; deg: 0.11; theta: 4.51; asym: 6.00; tree : (-2 AND 3)
# >> G_4: init: 0.73; noise: 0.10; b: 1.82; m: 2.52; expr: 0.73; deg: 0.10; theta: 4.73; asym: 5.00; tree : ((-0 AND -2) AND -3)

# %%
def load_all(exp):
    ls = []
    for i in range(1, prun.n_gen + 1):
        ls.append(exp.load(f"generation_g{i}"))
        
    return sum(ls, [])

# %%
runs = load_all(exp)

# %%
druns = {r.id: r for r in runs}

# %%
res = runs[-2]
res.id, res.parent, res.fit
# Out:
# (2499, 2497, 2355.1196186860043)

# %%
lineage = [res]
cres = res
while cres.parent != -1:
    cres = druns[cres.parent]
    lineage.append(cres)
lineage = lineage[::-1]

# %%
plt.plot([r.fit for r in lineage])

# %%
for r in lineage[:20]:
    print(f"==== {r.id} {r.fit} ====")
    print(r.grn)
    print()
# Out:
# ==== 7 1064.0 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 1.00; deg: 0.10; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.16; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR (2 OR -3))
# >> G_2: init: 0.36; noise: 0.57; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 5))
#
# ==== 56 1066.0 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.10; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.16; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR (2 OR -3))
# >> G_2: init: 0.36; noise: 0.57; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 5))
#
# ==== 64 1050.8742674679168 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.10; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.16; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR (2 OR -3))
# >> G_2: init: 0.36; noise: 0.57; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ==== 70 1821.4403754494083 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.10; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.16; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.57; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ==== 76 1659.1680276135203 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.16; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.57; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ==== 78 1529.2878913387765 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.57; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ==== 82 1706.2878913387765 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.64; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ==== 88 2244.1680276135203 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.38; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ==== 97 2476.1680276135203 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.38; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : (0 AND 3)
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND 1) AND (2 AND 3))
#
# ==== 104 2067.1680276135203 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.38; m: 2.02; expr: 1.00; deg: 0.10; theta: 8.35; asym: 5.00; tree : (0 AND 3)
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (2 AND 3))
#
# ==== 114 2467.9435337779423 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.02; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : (0 AND 3)
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (2 AND 3))
#
# ==== 134 2261.1196186860043 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : (0 AND 3)
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (2 AND 3))
#
# ==== 167 2397.966610560379 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.64; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (2 AND 3))
#
# ==== 172 2269.1680276135203 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.93; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.54; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (2 AND 3))
#
# ==== 221 2678.2878913387767 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : 3
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.54; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (2 AND 3))
#
# ==== 237 3073.1196186860047 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : (3 OR 4)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.54; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (2 AND 3))
#
# ==== 238 3123.1196186860047 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : (3 OR 4)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.54; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (1 AND 3))
#
# ==== 256 2553.1680276135203 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.36; noise: 0.54; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (1 AND 3))
#
# ==== 283 2846.2432664377156 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (1 AND 3))
#
# ==== 328 2385.0 ====
# >> G_0: init: 0.54; noise: 0.30; b: 1.18; m: 9.90; expr: 0.90; deg: 0.12; theta: 3.48; asym: 5.29; tree : ((3 OR 4) AND 5)
# >> G_1: init: 0.48; noise: 0.03; b: 0.48; m: 2.17; expr: 1.00; deg: 0.10; theta: 1.04; asym: 5.00; tree : (-5 OR -3)
# >> G_2: init: 0.29; noise: 0.54; b: 1.38; m: 2.02; expr: 1.00; deg: 0.11; theta: 8.35; asym: 5.00; tree : 0
# >> G_3: init: 0.71; noise: 0.57; b: 2.21; m: 6.45; expr: 1.00; deg: 0.10; theta: 4.51; asym: 5.00; tree : -2
# >> G_4: init: 0.73; noise: 0.11; b: 1.73; m: 2.52; expr: 1.00; deg: 0.10; theta: 4.72; asym: 5.00; tree : ((-0 AND -5) AND (1 AND 3))
