# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn5 import GRNMain5 as GRNMain
from lib.sde.mutate import mutate_grn5 as mutate_grn, SparseMutator

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time

# %%
_count = -1
def provide_id():
    global _count
    _count += 1
    return _count

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")
_MUTATE_FUNC = SparseMutator()

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(7, 0, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late)**2 / ref_prog_late
                  + abs(neuron_infra_late - ref_neuron_infra_late)**2 / ref_neuron_infra_late
                  + abs(neuron_supra_late - ref_neuron_supra_late)**2 / ref_neuron_supra_late)
    delta_early = (abs(prog_early - ref_prog_early)**2 / ref_prog_early
                   + abs(neuron_infra_early - ref_neuron_infra_early)**2 / ref_neuron_infra_early
                  + abs(neuron_supra_early - ref_neuron_supra_early)**2 / max(1, ref_neuron_supra_early))

    return 1 / max(1, 10000 - 1 * delta_late - 0.5 * delta_early)

# %%
def get_bb(prun, grn):
    from submodels.grn_bi_v1 import GRNCell
    ccls = factories["grn_bi1"](grn=grn)
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=50, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks)
    return bb

# %%
def run_grn(prun, grn):
    get_bb(prun, grn)
    bb.run()
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_multistep(prun, sol.grn, prun.steps)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_steps = [
    ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2),
]

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.steps = example_steps
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if batch_gen == prun.n_gen:
        print("Already finished")
        return
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // prun.batch_size
            exporter(pop[-prun.batch_size:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "check_simple_obj_r36"
res = main(prun)
# Out:
# Exporting at output/check_simple_obj_r36
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 9872.452614486932 for generation 0
# [out] ++ Best 9872.872356217891 for generation 1
# [out] ++ Best 9873.471950450717 for generation 6
# [out] ++ Best 9896.292600512274 for generation 9
# Step 3 passed !
# Saving ...
# [out] ++ Best 9898.020391048136 for generation 57
# [out] ++ Best 9898.609228500734 for generation 60
# [out] ++ Best 9899.83744525719 for generation 69
# [out] ++ Best 9902.954025476465 for generation 85
# Saving ...
# [out] Step 100
# [out] ++ Best 9903.808547643685 for generation 116
# Saving ...
# [out] ++ Best 9903.855537943891 for generation 182
# [out] ++ Best 9904.113254462258 for generation 185
# [out] ++ Best 9909.561614979822 for generation 195
# Saving ...
# [out] Step 200
# [out] ++ Best 9910.039467202436 for generation 203
# Saving ...
# [out] ++ Best 9911.567396214983 for generation 286
# Saving ...
# [out] Step 300
# [out] ++ Best 9917.923659248176 for generation 343
# Saving ...
# [out] ++ Best 9918.285760018216 for generation 398
# Saving ...
# [out] Step 400
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# [out] ++ Best 9918.477238979309 for generation 553
# [out] ++ Best 9920.361629689547 for generation 590
# [out] ++ Best 9922.183622810584 for generation 597
# Saving ...
# [out] Step 600
# [out] ++ Best 9922.441203771523 for generation 605
# Saving ...
# [out] ++ Best 9922.448783609303 for generation 684
# Saving ...
# [out] Step 700
# Saving ...
# [out] ++ Best 9923.987949152977 for generation 753
# [out] ++ Best 9923.988906663026 for generation 760
# [out] ++ Best 9924.965098178562 for generation 795
# Saving ...
# [out] Step 800
# [out] ++ Best 9927.082094102367 for generation 801
# Saving ...
# Saving ...
# [out] Step 900
# [out] ++ Best 9927.87603617867 for generation 915
# [out] ++ Best 9928.95158501638 for generation 944
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# Saving ...
# [out] Step 1300
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# [out] ++ Best 9933.493248411607 for generation 1577
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# [out] ++ Best 9936.45031687222 for generation 2034
# Saving ...
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/check_simple_obj_r36

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load("generation_g10"))

# %%
res.fit
# Out:
# 9912.929319397601

# %%
# for i in range(5):
#     print(fitness_multistep(prun, res.grn, prun.steps))

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} {res.fit} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g1 9896.292600512274 =======
# >> G_0: init: 0.84; noise: 1.00; b: 1.92; m: 7.10; expr: 1.00; deg: 0.10; theta: 6.34; asym: 5.00; tree : (-1 OR 2)
# >> G_1: init: 0.84; noise: 1.00; b: 2.15; m: 3.34; expr: 1.00; deg: 0.10; theta: 2.96; asym: 5.00; tree : -5
# >> G_2: init: 1.57; noise: 1.00; b: 1.82; m: 4.19; expr: 1.00; deg: 0.10; theta: 7.18; asym: 5.00; tree : (-2 AND 5)
# >> G_3: init: 0.43; noise: 1.00; b: 1.58; m: 7.37; expr: 0.90; deg: 0.10; theta: 7.10; asym: 5.00; tree : -7
# >> G_4: init: 1.18; noise: 1.00; b: 1.16; m: 1.82; expr: 1.00; deg: 0.10; theta: 1.20; asym: 5.00; tree : -4
# >> G_5: init: 1.26; noise: 1.00; b: 0.96; m: 2.02; expr: 1.00; deg: 0.10; theta: 2.10; asym: 5.00; tree : -0
# >> G_6: init: 0.39; noise: 0.89; b: 0.60; m: 6.61; expr: 1.00; deg: 0.10; theta: 6.19; asym: 4.74; tree : 5
#
# ======= GENERATION generation_g2 9902.954025476465 =======
# >> G_0: init: 1.00; noise: 1.04; b: 0.17; m: 8.73; expr: 0.89; deg: 0.10; theta: 1.45; asym: 5.00; tree : 3
# >> G_1: init: 0.22; noise: 1.07; b: 0.88; m: 1.29; expr: 1.00; deg: 0.10; theta: 2.30; asym: 5.00; tree : -2
# >> G_2: init: 1.17; noise: 1.03; b: 0.77; m: 6.31; expr: 1.00; deg: 0.10; theta: 7.15; asym: 5.00; tree : -1
# >> G_3: init: 0.51; noise: 0.94; b: 0.92; m: 4.56; expr: 1.00; deg: 0.08; theta: 1.23; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 1.86; noise: 0.98; b: 0.94; m: 5.14; expr: 1.02; deg: 0.10; theta: 7.27; asym: 5.00; tree : ((6 AND -4) AND (2 OR 5))
# >> G_5: init: 1.27; noise: 1.14; b: 0.13; m: 3.95; expr: 1.00; deg: 0.10; theta: 9.87; asym: 5.00; tree : -5
# >> G_6: init: 0.55; noise: 1.09; b: 0.91; m: 4.59; expr: 1.12; deg: 0.10; theta: 5.78; asym: 4.53; tree : (5 AND 6)
#
# ======= GENERATION generation_g3 9903.808547643685 =======
# >> G_0: init: 1.00; noise: 1.04; b: 0.16; m: 8.64; expr: 0.81; deg: 0.11; theta: 1.45; asym: 5.00; tree : 3
# >> G_1: init: 0.22; noise: 0.97; b: 0.88; m: 1.11; expr: 1.00; deg: 0.10; theta: 2.79; asym: 5.00; tree : -2
# >> G_2: init: 1.17; noise: 1.03; b: 0.77; m: 6.31; expr: 1.00; deg: 0.10; theta: 7.67; asym: 4.58; tree : -1
# >> G_3: init: 0.51; noise: 0.94; b: 0.92; m: 4.56; expr: 1.18; deg: 0.08; theta: 1.23; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 1.86; noise: 0.98; b: 0.94; m: 5.14; expr: 1.02; deg: 0.10; theta: 7.27; asym: 3.18; tree : ((6 AND -4) AND (2 OR 5))
# >> G_5: init: 1.27; noise: 1.14; b: 0.15; m: 3.95; expr: 1.00; deg: 0.10; theta: 9.87; asym: 5.00; tree : -5
# >> G_6: init: 0.55; noise: 1.09; b: 0.91; m: 4.28; expr: 1.12; deg: 0.10; theta: 5.78; asym: 4.59; tree : (5 AND 6)
#
# ======= GENERATION generation_g4 9909.561614979822 =======
# >> G_0: init: 0.98; noise: 1.04; b: 0.15; m: 8.64; expr: 0.81; deg: 0.11; theta: 1.45; asym: 5.74; tree : 3
# >> G_1: init: 0.21; noise: 0.97; b: 0.82; m: 1.11; expr: 0.94; deg: 0.12; theta: 2.79; asym: 5.00; tree : -2
# >> G_2: init: 1.01; noise: 1.03; b: 0.77; m: 6.31; expr: 1.00; deg: 0.09; theta: 7.67; asym: 6.59; tree : -1
# >> G_3: init: 0.49; noise: 0.93; b: 0.92; m: 4.74; expr: 1.18; deg: 0.08; theta: 1.23; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 1.89; noise: 0.84; b: 0.94; m: 5.14; expr: 1.02; deg: 0.10; theta: 7.82; asym: 3.18; tree : ((6 AND -4) AND (2 OR 5))
# >> G_5: init: 1.32; noise: 1.14; b: 0.14; m: 4.18; expr: 1.14; deg: 0.10; theta: 10.50; asym: 5.00; tree : -5
# >> G_6: init: 0.55; noise: 1.09; b: 0.87; m: 4.28; expr: 1.12; deg: 0.11; theta: 6.08; asym: 4.59; tree : (5 AND 6)
#
# ======= GENERATION generation_g5 9910.039467202436 =======
# >> G_0: init: 0.98; noise: 1.04; b: 0.15; m: 8.64; expr: 0.81; deg: 0.11; theta: 1.45; asym: 5.74; tree : 3
# >> G_1: init: 0.21; noise: 1.06; b: 0.82; m: 1.11; expr: 0.94; deg: 0.11; theta: 2.69; asym: 5.00; tree : -2
# >> G_2: init: 1.01; noise: 1.03; b: 0.77; m: 6.31; expr: 1.00; deg: 0.09; theta: 7.67; asym: 6.59; tree : -1
# >> G_3: init: 0.49; noise: 0.93; b: 0.92; m: 4.74; expr: 1.19; deg: 0.07; theta: 1.23; asym: 4.70; tree : (6 AND (5 AND -2))
# >> G_4: init: 1.93; noise: 0.84; b: 0.94; m: 5.14; expr: 1.02; deg: 0.10; theta: 7.82; asym: 3.18; tree : ((6 AND -4) AND (2 OR 5))
# >> G_5: init: 1.32; noise: 1.14; b: 0.14; m: 4.12; expr: 1.14; deg: 0.10; theta: 10.50; asym: 4.63; tree : -5
# >> G_6: init: 0.60; noise: 1.01; b: 0.87; m: 4.07; expr: 1.12; deg: 0.11; theta: 6.08; asym: 4.59; tree : (5 AND 6)
#
# ======= GENERATION generation_g6 9911.567396214983 =======
# >> G_0: init: 0.98; noise: 0.95; b: 0.15; m: 8.11; expr: 0.81; deg: 0.11; theta: 1.45; asym: 5.74; tree : 3
# >> G_1: init: 0.20; noise: 1.13; b: 0.82; m: 1.11; expr: 0.94; deg: 0.11; theta: 2.61; asym: 3.98; tree : -2
# >> G_2: init: 1.01; noise: 1.03; b: 0.77; m: 6.31; expr: 1.00; deg: 0.10; theta: 7.67; asym: 6.59; tree : -1
# >> G_3: init: 0.49; noise: 0.93; b: 0.92; m: 4.74; expr: 1.19; deg: 0.08; theta: 1.23; asym: 4.70; tree : (6 AND (5 AND -2))
# >> G_4: init: 1.76; noise: 0.84; b: 0.94; m: 5.33; expr: 1.06; deg: 0.12; theta: 9.04; asym: 3.18; tree : ((6 AND -4) AND (2 OR 5))
# >> G_5: init: 1.35; noise: 1.14; b: 0.14; m: 4.82; expr: 1.14; deg: 0.10; theta: 10.11; asym: 5.30; tree : -5
# >> G_6: init: 0.51; noise: 1.01; b: 0.87; m: 4.07; expr: 1.30; deg: 0.11; theta: 5.57; asym: 4.59; tree : (5 AND 6)
#
# ======= GENERATION generation_g7 9917.923659248176 =======
# >> G_0: init: 1.07; noise: 1.12; b: 0.15; m: 8.64; expr: 0.81; deg: 0.09; theta: 1.02; asym: 5.74; tree : 3
# >> G_1: init: 0.23; noise: 0.78; b: 0.88; m: 1.26; expr: 0.94; deg: 0.12; theta: 2.79; asym: 5.00; tree : -2
# >> G_2: init: 1.01; noise: 1.03; b: 0.77; m: 5.79; expr: 1.00; deg: 0.07; theta: 8.23; asym: 7.28; tree : -1
# >> G_3: init: 0.49; noise: 0.93; b: 0.92; m: 4.33; expr: 1.18; deg: 0.09; theta: 1.29; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 1.97; noise: 0.90; b: 0.85; m: 5.53; expr: 1.02; deg: 0.10; theta: 8.28; asym: 3.18; tree : ((6 AND -4) AND 2)
# >> G_5: init: 1.20; noise: 1.03; b: 0.14; m: 4.18; expr: 1.28; deg: 0.10; theta: 9.92; asym: 5.00; tree : -5
# >> G_6: init: 0.55; noise: 0.98; b: 0.87; m: 4.29; expr: 1.13; deg: 0.11; theta: 6.08; asym: 5.36; tree : (5 AND 6)
#
# ======= GENERATION generation_g8 9918.285760018216 =======
# >> G_0: init: 1.07; noise: 1.14; b: 0.15; m: 8.64; expr: 0.81; deg: 0.09; theta: 1.02; asym: 5.91; tree : 3
# >> G_1: init: 0.26; noise: 0.71; b: 0.94; m: 1.26; expr: 0.94; deg: 0.11; theta: 2.99; asym: 5.00; tree : -2
# >> G_2: init: 1.01; noise: 1.03; b: 0.85; m: 5.79; expr: 1.00; deg: 0.07; theta: 8.23; asym: 7.79; tree : -1
# >> G_3: init: 0.47; noise: 0.85; b: 0.92; m: 3.89; expr: 1.18; deg: 0.08; theta: 1.29; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 1.92; noise: 0.90; b: 0.85; m: 5.53; expr: 1.02; deg: 0.10; theta: 8.28; asym: 3.18; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.20; noise: 1.03; b: 0.14; m: 3.78; expr: 1.37; deg: 0.08; theta: 9.92; asym: 5.00; tree : -5
# >> G_6: init: 0.55; noise: 1.09; b: 0.80; m: 4.29; expr: 1.13; deg: 0.11; theta: 6.51; asym: 4.93; tree : (5 AND 6)
#
# ======= GENERATION generation_g9 9917.985086235329 =======
# >> G_0: init: 1.14; noise: 1.12; b: 0.16; m: 10.29; expr: 0.81; deg: 0.07; theta: 1.02; asym: 6.19; tree : (3 AND 5)
# >> G_1: init: 0.25; noise: 0.78; b: 0.88; m: 1.26; expr: 0.94; deg: 0.14; theta: 2.76; asym: 5.46; tree : -2
# >> G_2: init: 1.01; noise: 1.03; b: 0.79; m: 5.79; expr: 1.00; deg: 0.07; theta: 8.23; asym: 7.78; tree : -1
# >> G_3: init: 0.43; noise: 0.93; b: 0.83; m: 2.98; expr: 1.18; deg: 0.08; theta: 1.29; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 2.11; noise: 0.90; b: 1.02; m: 5.16; expr: 1.17; deg: 0.10; theta: 8.28; asym: 3.46; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.20; noise: 1.03; b: 0.13; m: 3.93; expr: 1.28; deg: 0.08; theta: 11.57; asym: 5.00; tree : (-5 AND -3)
# >> G_6: init: 0.55; noise: 1.03; b: 1.00; m: 4.21; expr: 1.13; deg: 0.09; theta: 6.31; asym: 5.62; tree : (5 AND 6)
#
# ======= GENERATION generation_g10 9912.929319397601 =======
# >> G_0: init: 1.14; noise: 1.12; b: 0.16; m: 10.38; expr: 0.81; deg: 0.07; theta: 1.02; asym: 5.74; tree : (3 AND 5)
# >> G_1: init: 0.23; noise: 0.66; b: 0.92; m: 1.26; expr: 1.01; deg: 0.14; theta: 2.76; asym: 6.39; tree : -2
# >> G_2: init: 0.86; noise: 1.03; b: 0.79; m: 5.51; expr: 1.00; deg: 0.07; theta: 8.23; asym: 7.94; tree : -1
# >> G_3: init: 0.56; noise: 0.93; b: 0.83; m: 2.98; expr: 1.18; deg: 0.08; theta: 1.29; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 2.11; noise: 0.90; b: 1.02; m: 5.16; expr: 1.17; deg: 0.10; theta: 8.28; asym: 4.14; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.21; noise: 1.44; b: 0.13; m: 3.24; expr: 1.28; deg: 0.08; theta: 9.19; asym: 5.08; tree : (-5 AND -3)
# >> G_6: init: 0.58; noise: 1.03; b: 1.01; m: 3.75; expr: 1.06; deg: 0.09; theta: 6.18; asym: 5.62; tree : (5 AND 6)
#
# ======= GENERATION generation_g11 9916.720842658393 =======
# >> G_0: init: 1.14; noise: 1.14; b: 0.16; m: 10.38; expr: 0.90; deg: 0.07; theta: 1.02; asym: 5.74; tree : (3 AND 5)
# >> G_1: init: 0.23; noise: 0.66; b: 0.92; m: 1.26; expr: 1.01; deg: 0.14; theta: 2.76; asym: 6.39; tree : -2
# >> G_2: init: 0.86; noise: 1.03; b: 0.79; m: 5.51; expr: 1.00; deg: 0.07; theta: 8.23; asym: 7.94; tree : -1
# >> G_3: init: 0.57; noise: 1.04; b: 0.83; m: 2.98; expr: 1.18; deg: 0.08; theta: 1.29; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 2.11; noise: 0.90; b: 1.09; m: 5.16; expr: 1.06; deg: 0.10; theta: 8.28; asym: 4.14; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.17; noise: 1.38; b: 0.13; m: 3.15; expr: 1.28; deg: 0.08; theta: 9.19; asym: 5.08; tree : (-1 AND -3)
# >> G_6: init: 0.58; noise: 1.03; b: 1.01; m: 3.75; expr: 1.06; deg: 0.09; theta: 6.18; asym: 5.12; tree : (5 AND 6)
#
# ======= GENERATION generation_g12 9922.183622810584 =======
# >> G_0: init: 1.51; noise: 1.40; b: 0.18; m: 11.48; expr: 0.80; deg: 0.07; theta: 1.47; asym: 5.66; tree : (3 AND 5)
# >> G_1: init: 0.31; noise: 0.78; b: 0.86; m: 1.26; expr: 0.84; deg: 0.12; theta: 2.87; asym: 5.46; tree : -2
# >> G_2: init: 0.66; noise: 1.22; b: 0.83; m: 6.03; expr: 1.02; deg: 0.06; theta: 7.60; asym: 7.78; tree : -1
# >> G_3: init: 0.53; noise: 0.99; b: 0.69; m: 2.92; expr: 1.16; deg: 0.09; theta: 1.29; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 2.40; noise: 0.89; b: 0.91; m: 4.32; expr: 1.36; deg: 0.12; theta: 8.28; asym: 4.24; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.51; noise: 0.75; b: 0.13; m: 3.34; expr: 1.28; deg: 0.09; theta: 13.29; asym: 4.53; tree : (-5 AND -3)
# >> G_6: init: 0.55; noise: 1.03; b: 0.97; m: 3.92; expr: 1.03; deg: 0.08; theta: 5.55; asym: 4.58; tree : (5 AND 6)
#
# ======= GENERATION generation_g13 9922.441203771523 =======
# >> G_0: init: 1.51; noise: 1.40; b: 0.18; m: 11.48; expr: 0.79; deg: 0.08; theta: 1.47; asym: 5.66; tree : (3 AND 5)
# >> G_1: init: 0.31; noise: 0.78; b: 0.86; m: 1.23; expr: 0.84; deg: 0.12; theta: 2.87; asym: 5.46; tree : -2
# >> G_2: init: 0.66; noise: 1.22; b: 0.99; m: 6.03; expr: 1.03; deg: 0.07; theta: 7.60; asym: 7.78; tree : -1
# >> G_3: init: 0.53; noise: 1.17; b: 0.69; m: 2.92; expr: 1.16; deg: 0.09; theta: 1.29; asym: 5.00; tree : (6 AND (5 AND -2))
# >> G_4: init: 2.40; noise: 1.05; b: 0.91; m: 4.32; expr: 1.36; deg: 0.12; theta: 7.88; asym: 4.24; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.51; noise: 0.75; b: 0.13; m: 3.34; expr: 1.28; deg: 0.09; theta: 13.29; asym: 4.53; tree : (-5 AND -3)
# >> G_6: init: 0.55; noise: 1.03; b: 0.97; m: 3.92; expr: 1.03; deg: 0.08; theta: 5.55; asym: 4.58; tree : (5 AND 6)
#
# ======= GENERATION generation_g14 9922.448783609303 =======
# >> G_0: init: 1.51; noise: 1.42; b: 0.18; m: 12.38; expr: 0.79; deg: 0.09; theta: 1.47; asym: 5.48; tree : (3 AND 5)
# >> G_1: init: 0.32; noise: 0.81; b: 0.73; m: 1.23; expr: 0.84; deg: 0.12; theta: 2.50; asym: 5.72; tree : -2
# >> G_2: init: 0.65; noise: 1.23; b: 0.91; m: 6.42; expr: 1.06; deg: 0.07; theta: 7.60; asym: 7.93; tree : -1
# >> G_3: init: 0.45; noise: 1.17; b: 0.68; m: 3.12; expr: 1.16; deg: 0.09; theta: 1.29; asym: 5.02; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.49; noise: 1.07; b: 0.91; m: 4.31; expr: 1.36; deg: 0.12; theta: 7.94; asym: 3.83; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.51; noise: 0.82; b: 0.16; m: 3.34; expr: 1.24; deg: 0.08; theta: 9.48; asym: 4.53; tree : -5
# >> G_6: init: 0.55; noise: 0.96; b: 0.77; m: 4.02; expr: 1.03; deg: 0.07; theta: 5.55; asym: 4.10; tree : (5 AND 6)
#
# ======= GENERATION generation_g15 9922.31548339126 =======
# >> G_0: init: 1.51; noise: 1.42; b: 0.18; m: 12.45; expr: 0.79; deg: 0.09; theta: 1.47; asym: 5.48; tree : (3 AND 5)
# >> G_1: init: 0.32; noise: 0.81; b: 0.71; m: 1.23; expr: 0.84; deg: 0.12; theta: 2.29; asym: 5.72; tree : -2
# >> G_2: init: 0.54; noise: 1.23; b: 0.91; m: 6.75; expr: 1.01; deg: 0.07; theta: 7.60; asym: 7.93; tree : -1
# >> G_3: init: 0.45; noise: 1.17; b: 0.68; m: 3.12; expr: 1.16; deg: 0.10; theta: 1.29; asym: 5.02; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.49; noise: 1.07; b: 0.59; m: 5.01; expr: 1.36; deg: 0.12; theta: 8.13; asym: 3.83; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.51; noise: 0.82; b: 0.16; m: 3.34; expr: 1.24; deg: 0.08; theta: 9.48; asym: 4.53; tree : -5
# >> G_6: init: 0.55; noise: 0.96; b: 0.77; m: 4.02; expr: 0.92; deg: 0.07; theta: 5.21; asym: 3.75; tree : (5 AND 6)
#
# ======= GENERATION generation_g16 9924.965098178562 =======
# >> G_0: init: 1.51; noise: 1.42; b: 0.18; m: 12.45; expr: 0.79; deg: 0.10; theta: 1.47; asym: 5.48; tree : 3
# >> G_1: init: 0.30; noise: 0.81; b: 0.71; m: 1.23; expr: 0.84; deg: 0.12; theta: 2.29; asym: 5.72; tree : -2
# >> G_2: init: 0.54; noise: 1.29; b: 0.91; m: 7.87; expr: 1.01; deg: 0.07; theta: 8.20; asym: 8.57; tree : -1
# >> G_3: init: 0.51; noise: 0.98; b: 0.68; m: 3.12; expr: 1.16; deg: 0.10; theta: 1.29; asym: 5.02; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.49; noise: 1.07; b: 0.59; m: 5.01; expr: 1.36; deg: 0.12; theta: 8.13; asym: 3.97; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.51; noise: 0.89; b: 0.16; m: 3.34; expr: 1.24; deg: 0.08; theta: 9.48; asym: 4.53; tree : -5
# >> G_6: init: 0.55; noise: 0.96; b: 0.74; m: 3.91; expr: 0.92; deg: 0.07; theta: 5.21; asym: 3.75; tree : 6
#
# ======= GENERATION generation_g17 9927.082094102367 =======
# >> G_0: init: 1.51; noise: 1.42; b: 0.15; m: 12.45; expr: 0.79; deg: 0.09; theta: 1.47; asym: 5.48; tree : (3 AND 5)
# >> G_1: init: 0.32; noise: 0.79; b: 0.71; m: 1.23; expr: 0.84; deg: 0.12; theta: 2.29; asym: 5.72; tree : -2
# >> G_2: init: 0.54; noise: 1.26; b: 0.91; m: 6.75; expr: 1.01; deg: 0.07; theta: 7.60; asym: 7.93; tree : -1
# >> G_3: init: 0.45; noise: 1.26; b: 0.68; m: 2.95; expr: 1.16; deg: 0.10; theta: 1.29; asym: 5.02; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.49; noise: 1.07; b: 0.59; m: 5.59; expr: 1.58; deg: 0.11; theta: 8.13; asym: 3.81; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.51; noise: 0.82; b: 0.16; m: 2.78; expr: 1.24; deg: 0.08; theta: 10.46; asym: 4.65; tree : -5
# >> G_6: init: 0.55; noise: 0.96; b: 0.60; m: 4.02; expr: 0.92; deg: 0.07; theta: 5.21; asym: 3.26; tree : (5 AND 6)
#
# ======= GENERATION generation_g18 9925.295691251898 =======
# >> G_0: init: 1.75; noise: 1.42; b: 0.18; m: 12.45; expr: 0.79; deg: 0.10; theta: 1.42; asym: 5.48; tree : (3 AND 5)
# >> G_1: init: 0.36; noise: 0.85; b: 0.71; m: 1.27; expr: 0.84; deg: 0.12; theta: 2.21; asym: 6.34; tree : -2
# >> G_2: init: 0.54; noise: 1.23; b: 0.81; m: 6.20; expr: 1.01; deg: 0.07; theta: 7.60; asym: 7.93; tree : -1
# >> G_3: init: 0.45; noise: 1.26; b: 0.68; m: 3.12; expr: 1.16; deg: 0.10; theta: 1.29; asym: 5.72; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.49; noise: 1.09; b: 0.59; m: 5.01; expr: 1.33; deg: 0.12; theta: 8.13; asym: 3.83; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.51; noise: 0.82; b: 0.12; m: 3.37; expr: 1.24; deg: 0.08; theta: 9.51; asym: 4.65; tree : -5
# >> G_6: init: 0.55; noise: 0.96; b: 0.77; m: 4.02; expr: 0.92; deg: 0.06; theta: 5.21; asym: 4.02; tree : 6
#
# ======= GENERATION generation_g19 9928.95158501638 =======
# >> G_0: init: 1.30; noise: 1.42; b: 0.17; m: 10.47; expr: 0.84; deg: 0.10; theta: 1.53; asym: 5.04; tree : 3
# >> G_1: init: 0.30; noise: 0.81; b: 0.71; m: 1.23; expr: 0.84; deg: 0.12; theta: 2.18; asym: 5.72; tree : -2
# >> G_2: init: 0.60; noise: 1.22; b: 0.94; m: 7.91; expr: 1.01; deg: 0.07; theta: 9.19; asym: 8.57; tree : -1
# >> G_3: init: 0.42; noise: 0.98; b: 0.68; m: 3.43; expr: 0.93; deg: 0.10; theta: 1.17; asym: 4.34; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.49; noise: 0.91; b: 0.66; m: 4.30; expr: 1.50; deg: 0.12; theta: 8.06; asym: 3.66; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.51; noise: 0.94; b: 0.15; m: 3.17; expr: 1.19; deg: 0.11; theta: 10.68; asym: 4.53; tree : -5
# >> G_6: init: 0.55; noise: 0.96; b: 0.76; m: 3.57; expr: 0.92; deg: 0.08; theta: 5.67; asym: 4.02; tree : 6
#
# ======= GENERATION generation_g20 9925.044628899468 =======
# >> G_0: init: 1.28; noise: 1.32; b: 0.18; m: 11.64; expr: 0.84; deg: 0.10; theta: 1.47; asym: 6.12; tree : 3
# >> G_1: init: 0.30; noise: 0.76; b: 0.71; m: 1.23; expr: 0.73; deg: 0.10; theta: 2.18; asym: 5.72; tree : -2
# >> G_2: init: 0.70; noise: 1.29; b: 0.94; m: 8.72; expr: 1.01; deg: 0.07; theta: 8.20; asym: 8.57; tree : -1
# >> G_3: init: 0.37; noise: 1.02; b: 0.68; m: 3.43; expr: 0.79; deg: 0.10; theta: 1.17; asym: 4.34; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.49; noise: 0.91; b: 0.66; m: 4.30; expr: 1.50; deg: 0.12; theta: 7.48; asym: 3.66; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.51; noise: 0.94; b: 0.15; m: 2.93; expr: 1.19; deg: 0.11; theta: 10.68; asym: 4.53; tree : -5
# >> G_6: init: 0.56; noise: 0.96; b: 0.76; m: 4.31; expr: 0.92; deg: 0.08; theta: 5.05; asym: 4.02; tree : 6
#
# ======= GENERATION generation_g21 9925.560674705035 =======
# >> G_0: init: 1.01; noise: 1.28; b: 0.17; m: 11.40; expr: 0.90; deg: 0.13; theta: 1.53; asym: 5.04; tree : 3
# >> G_1: init: 0.30; noise: 0.81; b: 0.71; m: 1.21; expr: 0.79; deg: 0.12; theta: 2.18; asym: 5.72; tree : -2
# >> G_2: init: 0.61; noise: 1.22; b: 0.77; m: 9.39; expr: 0.97; deg: 0.07; theta: 9.19; asym: 8.57; tree : -1
# >> G_3: init: 0.37; noise: 1.20; b: 0.68; m: 2.99; expr: 0.93; deg: 0.10; theta: 1.17; asym: 2.91; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.33; noise: 0.91; b: 0.63; m: 4.88; expr: 1.50; deg: 0.11; theta: 8.06; asym: 4.79; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.70; noise: 0.95; b: 0.16; m: 2.83; expr: 1.39; deg: 0.10; theta: 8.82; asym: 4.32; tree : -5
# >> G_6: init: 0.64; noise: 0.92; b: 0.57; m: 3.33; expr: 0.92; deg: 0.09; theta: 5.34; asym: 4.25; tree : 6
#
# ======= GENERATION generation_g22 9923.815707091968 =======
# >> G_0: init: 1.36; noise: 1.34; b: 0.18; m: 12.45; expr: 0.79; deg: 0.10; theta: 1.51; asym: 5.21; tree : 3
# >> G_1: init: 0.26; noise: 0.81; b: 0.71; m: 1.24; expr: 0.83; deg: 0.12; theta: 2.50; asym: 5.63; tree : -2
# >> G_2: init: 0.61; noise: 1.29; b: 0.91; m: 6.31; expr: 1.10; deg: 0.07; theta: 7.64; asym: 8.57; tree : -1
# >> G_3: init: 0.51; noise: 0.78; b: 0.68; m: 3.12; expr: 1.42; deg: 0.10; theta: 1.30; asym: 5.15; tree : (-4 AND -2)
# >> G_4: init: 1.97; noise: 0.92; b: 0.72; m: 5.23; expr: 1.50; deg: 0.11; theta: 11.48; asym: 3.97; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.59; noise: 0.88; b: 0.15; m: 3.29; expr: 1.51; deg: 0.09; theta: 9.36; asym: 4.53; tree : -5
# >> G_6: init: 0.63; noise: 1.15; b: 0.72; m: 4.24; expr: 1.03; deg: 0.10; theta: 4.70; asym: 3.21; tree : 6
#
# ======= GENERATION generation_g23 9922.602170435663 =======
# >> G_0: init: 1.43; noise: 1.64; b: 0.18; m: 13.44; expr: 0.75; deg: 0.12; theta: 1.36; asym: 5.28; tree : 3
# >> G_1: init: 0.28; noise: 0.81; b: 0.71; m: 1.27; expr: 0.83; deg: 0.11; theta: 2.28; asym: 6.29; tree : -2
# >> G_2: init: 0.61; noise: 1.29; b: 0.91; m: 8.13; expr: 1.01; deg: 0.07; theta: 8.19; asym: 9.23; tree : -1
# >> G_3: init: 0.50; noise: 0.89; b: 0.65; m: 2.95; expr: 1.36; deg: 0.10; theta: 1.30; asym: 4.23; tree : (-0 AND (5 AND -2))
# >> G_4: init: 1.90; noise: 0.88; b: 0.57; m: 5.23; expr: 1.66; deg: 0.08; theta: 9.12; asym: 3.97; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.71; noise: 1.03; b: 0.17; m: 2.99; expr: 1.51; deg: 0.09; theta: 9.41; asym: 4.03; tree : -5
# >> G_6: init: 0.63; noise: 1.05; b: 0.74; m: 4.48; expr: 1.03; deg: 0.10; theta: 5.42; asym: 5.07; tree : 6
#
# ======= GENERATION generation_g24 9925.64240623729 =======
# >> G_0: init: 1.22; noise: 1.34; b: 0.14; m: 13.71; expr: 0.79; deg: 0.10; theta: 1.51; asym: 5.10; tree : 3
# >> G_1: init: 0.26; noise: 0.75; b: 0.71; m: 1.24; expr: 0.83; deg: 0.12; theta: 2.50; asym: 5.99; tree : -2
# >> G_2: init: 0.61; noise: 1.27; b: 0.91; m: 5.60; expr: 1.10; deg: 0.07; theta: 6.63; asym: 8.41; tree : -1
# >> G_3: init: 0.48; noise: 0.85; b: 0.68; m: 3.12; expr: 1.25; deg: 0.09; theta: 1.36; asym: 5.15; tree : (-4 AND -2)
# >> G_4: init: 1.97; noise: 0.96; b: 0.72; m: 6.04; expr: 1.50; deg: 0.12; theta: 12.90; asym: 3.97; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.59; noise: 0.88; b: 0.13; m: 3.29; expr: 1.44; deg: 0.09; theta: 9.36; asym: 4.49; tree : -5
# >> G_6: init: 0.65; noise: 1.15; b: 0.72; m: 4.24; expr: 1.03; deg: 0.10; theta: 4.70; asym: 3.21; tree : (6 OR 7)
#
# ======= GENERATION generation_g25 9927.1729431727 =======
# >> G_0: init: 1.36; noise: 1.06; b: 0.14; m: 13.71; expr: 0.79; deg: 0.10; theta: 1.51; asym: 5.19; tree : 3
# >> G_1: init: 0.26; noise: 0.70; b: 0.71; m: 1.24; expr: 0.87; deg: 0.12; theta: 2.50; asym: 5.63; tree : (-2 OR -4)
# >> G_2: init: 0.64; noise: 1.38; b: 0.91; m: 6.15; expr: 1.10; deg: 0.07; theta: 6.63; asym: 8.57; tree : -1
# >> G_3: init: 0.48; noise: 0.99; b: 0.68; m: 2.90; expr: 0.97; deg: 0.10; theta: 1.36; asym: 5.15; tree : (-4 AND -2)
# >> G_4: init: 1.97; noise: 0.96; b: 0.72; m: 5.56; expr: 1.39; deg: 0.12; theta: 13.23; asym: 4.23; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.59; noise: 0.88; b: 0.15; m: 3.29; expr: 1.65; deg: 0.09; theta: 9.34; asym: 4.54; tree : -5
# >> G_6: init: 0.63; noise: 1.15; b: 0.72; m: 3.85; expr: 1.03; deg: 0.09; theta: 4.28; asym: 3.21; tree : 6
#
# ======= GENERATION generation_g26 9925.59880579687 =======
# >> G_0: init: 1.00; noise: 1.32; b: 0.21; m: 10.62; expr: 0.78; deg: 0.13; theta: 1.68; asym: 5.19; tree : 3
# >> G_1: init: 0.30; noise: 0.93; b: 0.71; m: 1.24; expr: 0.81; deg: 0.12; theta: 2.21; asym: 5.99; tree : -2
# >> G_2: init: 0.63; noise: 1.40; b: 0.96; m: 9.10; expr: 0.97; deg: 0.06; theta: 10.13; asym: 8.57; tree : -1
# >> G_3: init: 0.28; noise: 1.05; b: 0.42; m: 3.43; expr: 1.02; deg: 0.08; theta: 1.17; asym: 2.91; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.44; noise: 0.69; b: 0.63; m: 4.93; expr: 1.71; deg: 0.11; theta: 8.06; asym: 4.66; tree : (6 AND -1)
# >> G_5: init: 1.70; noise: 0.90; b: 0.16; m: 2.78; expr: 1.23; deg: 0.11; theta: 9.55; asym: 4.57; tree : -5
# >> G_6: init: 0.54; noise: 0.97; b: 0.56; m: 3.53; expr: 0.99; deg: 0.06; theta: 4.79; asym: 4.70; tree : 6
#
# ======= GENERATION generation_g27 9926.824876981715 =======
# >> G_0: init: 1.00; noise: 1.32; b: 0.21; m: 10.62; expr: 0.78; deg: 0.13; theta: 1.68; asym: 5.19; tree : 3
# >> G_1: init: 0.30; noise: 0.93; b: 0.71; m: 1.24; expr: 0.81; deg: 0.12; theta: 2.21; asym: 5.99; tree : -2
# >> G_2: init: 0.63; noise: 1.40; b: 0.96; m: 9.10; expr: 0.97; deg: 0.06; theta: 10.13; asym: 8.57; tree : -1
# >> G_3: init: 0.28; noise: 1.05; b: 0.42; m: 3.43; expr: 1.02; deg: 0.08; theta: 1.17; asym: 2.91; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.44; noise: 0.69; b: 0.63; m: 4.93; expr: 1.71; deg: 0.11; theta: 8.06; asym: 4.66; tree : (6 AND -1)
# >> G_5: init: 1.70; noise: 0.90; b: 0.16; m: 2.78; expr: 1.23; deg: 0.11; theta: 9.55; asym: 4.57; tree : -5
# >> G_6: init: 0.54; noise: 0.97; b: 0.56; m: 3.53; expr: 0.99; deg: 0.06; theta: 4.79; asym: 4.70; tree : (6 OR 3)
#
# ======= GENERATION generation_g28 9926.172587010778 =======
# >> G_0: init: 1.22; noise: 1.43; b: 0.15; m: 14.92; expr: 0.78; deg: 0.09; theta: 1.37; asym: 5.11; tree : 3
# >> G_1: init: 0.26; noise: 0.76; b: 0.72; m: 1.24; expr: 0.70; deg: 0.10; theta: 2.50; asym: 5.44; tree : -2
# >> G_2: init: 0.67; noise: 1.27; b: 0.94; m: 5.31; expr: 1.10; deg: 0.07; theta: 7.16; asym: 9.57; tree : -1
# >> G_3: init: 0.49; noise: 0.90; b: 0.68; m: 3.77; expr: 1.19; deg: 0.08; theta: 1.40; asym: 5.50; tree : (-4 AND -2)
# >> G_4: init: 2.30; noise: 1.26; b: 0.68; m: 5.47; expr: 1.50; deg: 0.11; theta: 15.18; asym: 4.40; tree : ((6 AND -4) AND -1)
# >> G_5: init: 1.52; noise: 0.88; b: 0.14; m: 3.29; expr: 1.44; deg: 0.07; theta: 8.91; asym: 4.66; tree : -5
# >> G_6: init: 0.63; noise: 1.17; b: 0.75; m: 5.36; expr: 1.01; deg: 0.09; theta: 4.82; asym: 3.62; tree : 6
#
# ======= GENERATION generation_g29 9925.937539624927 =======
# >> G_0: init: 0.97; noise: 1.32; b: 0.21; m: 9.65; expr: 0.71; deg: 0.11; theta: 1.84; asym: 5.88; tree : (3 OR -2)
# >> G_1: init: 0.30; noise: 0.92; b: 0.71; m: 1.31; expr: 0.86; deg: 0.13; theta: 2.24; asym: 5.99; tree : -2
# >> G_2: init: 0.63; noise: 1.40; b: 0.96; m: 9.10; expr: 0.97; deg: 0.06; theta: 10.13; asym: 8.53; tree : -1
# >> G_3: init: 0.24; noise: 1.18; b: 0.42; m: 3.43; expr: 1.00; deg: 0.07; theta: 1.17; asym: 3.05; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.09; noise: 0.69; b: 0.63; m: 4.82; expr: 1.71; deg: 0.13; theta: 8.21; asym: 4.40; tree : (6 AND -1)
# >> G_5: init: 1.67; noise: 0.96; b: 0.14; m: 2.59; expr: 1.23; deg: 0.10; theta: 9.55; asym: 4.05; tree : -5
# >> G_6: init: 0.46; noise: 0.98; b: 0.50; m: 3.47; expr: 0.98; deg: 0.06; theta: 5.12; asym: 4.70; tree : (6 OR 3)
#
# ======= GENERATION generation_g30 9928.600387457227 =======
# >> G_0: init: 0.89; noise: 1.35; b: 0.20; m: 9.88; expr: 0.78; deg: 0.13; theta: 2.23; asym: 4.89; tree : 3
# >> G_1: init: 0.24; noise: 0.64; b: 0.71; m: 1.25; expr: 0.75; deg: 0.12; theta: 2.21; asym: 7.84; tree : -2
# >> G_2: init: 0.64; noise: 1.33; b: 0.94; m: 9.06; expr: 0.97; deg: 0.06; theta: 11.86; asym: 9.10; tree : -1
# >> G_3: init: 0.26; noise: 0.98; b: 0.51; m: 3.08; expr: 1.02; deg: 0.08; theta: 1.30; asym: 2.71; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.73; noise: 0.69; b: 0.64; m: 4.93; expr: 1.71; deg: 0.11; theta: 7.49; asym: 5.24; tree : (6 AND -1)
# >> G_5: init: 1.70; noise: 0.90; b: 0.15; m: 2.45; expr: 1.23; deg: 0.11; theta: 8.10; asym: 4.57; tree : -5
# >> G_6: init: 0.54; noise: 0.97; b: 0.56; m: 3.53; expr: 0.99; deg: 0.06; theta: 4.79; asym: 5.00; tree : (6 OR 3)
#
# ======= GENERATION generation_g31 9928.927561201876 =======
# >> G_0: init: 1.03; noise: 1.07; b: 0.26; m: 8.77; expr: 0.80; deg: 0.11; theta: 1.68; asym: 5.50; tree : (3 OR -2)
# >> G_1: init: 0.30; noise: 0.83; b: 0.71; m: 1.24; expr: 0.86; deg: 0.12; theta: 2.24; asym: 5.36; tree : -2
# >> G_2: init: 0.56; noise: 1.40; b: 1.01; m: 9.10; expr: 0.97; deg: 0.05; theta: 8.82; asym: 8.00; tree : -1
# >> G_3: init: 0.24; noise: 1.18; b: 0.42; m: 3.43; expr: 1.13; deg: 0.07; theta: 1.17; asym: 3.30; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.05; noise: 0.69; b: 0.64; m: 4.96; expr: 1.65; deg: 0.11; theta: 6.88; asym: 4.40; tree : (6 AND -1)
# >> G_5: init: 1.57; noise: 0.96; b: 0.16; m: 2.59; expr: 1.23; deg: 0.11; theta: 10.00; asym: 4.05; tree : -5
# >> G_6: init: 0.61; noise: 0.88; b: 0.52; m: 4.21; expr: 0.98; deg: 0.06; theta: 4.93; asym: 4.70; tree : 6
#
# ======= GENERATION generation_g32 9933.493248411607 =======
# >> G_0: init: 1.02; noise: 1.07; b: 0.21; m: 8.31; expr: 0.80; deg: 0.12; theta: 1.52; asym: 5.59; tree : (3 OR -2)
# >> G_1: init: 0.25; noise: 0.83; b: 0.69; m: 1.24; expr: 0.87; deg: 0.11; theta: 2.24; asym: 5.36; tree : -2
# >> G_2: init: 0.56; noise: 1.40; b: 0.78; m: 9.10; expr: 0.97; deg: 0.05; theta: 9.30; asym: 8.53; tree : -1
# >> G_3: init: 0.19; noise: 1.07; b: 0.43; m: 3.43; expr: 1.01; deg: 0.06; theta: 1.08; asym: 3.30; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.04; noise: 0.61; b: 0.64; m: 4.96; expr: 1.55; deg: 0.11; theta: 6.88; asym: 4.40; tree : (6 AND -1)
# >> G_5: init: 1.64; noise: 1.00; b: 0.16; m: 2.63; expr: 1.23; deg: 0.09; theta: 10.00; asym: 4.05; tree : -5
# >> G_6: init: 0.51; noise: 0.89; b: 0.52; m: 4.21; expr: 0.98; deg: 0.06; theta: 4.71; asym: 4.70; tree : 6
#
# ======= GENERATION generation_g33 9931.447141190343 =======
# >> G_0: init: 1.02; noise: 1.07; b: 0.21; m: 8.19; expr: 0.80; deg: 0.13; theta: 1.52; asym: 5.59; tree : (3 OR -2)
# >> G_1: init: 0.22; noise: 0.89; b: 0.69; m: 1.24; expr: 0.87; deg: 0.11; theta: 2.24; asym: 5.36; tree : -2
# >> G_2: init: 0.45; noise: 1.40; b: 0.78; m: 8.62; expr: 0.97; deg: 0.05; theta: 9.30; asym: 8.53; tree : -1
# >> G_3: init: 0.19; noise: 1.07; b: 0.43; m: 3.43; expr: 1.01; deg: 0.06; theta: 1.08; asym: 3.30; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.04; noise: 0.61; b: 0.64; m: 4.96; expr: 1.55; deg: 0.11; theta: 6.88; asym: 4.40; tree : (6 AND -1)
# >> G_5: init: 1.64; noise: 1.00; b: 0.18; m: 2.63; expr: 1.23; deg: 0.09; theta: 8.75; asym: 4.05; tree : -5
# >> G_6: init: 0.51; noise: 0.89; b: 0.52; m: 4.21; expr: 0.98; deg: 0.06; theta: 4.71; asym: 4.70; tree : 6
#
# ======= GENERATION generation_g34 9930.125583367457 =======
# >> G_0: init: 1.07; noise: 1.20; b: 0.18; m: 8.31; expr: 0.84; deg: 0.11; theta: 1.70; asym: 6.38; tree : (3 OR -2)
# >> G_1: init: 0.30; noise: 0.83; b: 0.69; m: 1.24; expr: 0.85; deg: 0.10; theta: 2.24; asym: 5.36; tree : -2
# >> G_2: init: 0.62; noise: 1.40; b: 1.04; m: 9.10; expr: 0.97; deg: 0.05; theta: 9.30; asym: 9.41; tree : -1
# >> G_3: init: 0.25; noise: 0.89; b: 0.46; m: 3.76; expr: 0.98; deg: 0.06; theta: 1.08; asym: 3.19; tree : (-0 AND (5 AND -2))
# >> G_4: init: 2.05; noise: 0.43; b: 0.63; m: 4.96; expr: 1.55; deg: 0.12; theta: 6.88; asym: 4.41; tree : (6 AND -1)
# >> G_5: init: 1.64; noise: 0.99; b: 0.13; m: 2.63; expr: 1.23; deg: 0.12; theta: 10.00; asym: 4.05; tree : -5
# >> G_6: init: 0.61; noise: 0.91; b: 0.52; m: 4.98; expr: 0.98; deg: 0.06; theta: 4.79; asym: 4.25; tree : 0
#
# ======= GENERATION generation_g35 9932.460166258377 =======
# >> G_0: init: 1.06; noise: 1.21; b: 0.20; m: 10.39; expr: 0.80; deg: 0.13; theta: 1.36; asym: 4.89; tree : 3
# >> G_1: init: 0.33; noise: 1.00; b: 0.73; m: 1.29; expr: 0.85; deg: 0.13; theta: 2.21; asym: 6.22; tree : -2
# >> G_2: init: 0.61; noise: 1.03; b: 0.91; m: 8.87; expr: 0.97; deg: 0.06; theta: 8.82; asym: 10.71; tree : -1
# >> G_3: init: 0.34; noise: 1.06; b: 0.36; m: 2.83; expr: 0.90; deg: 0.06; theta: 1.12; asym: 3.73; tree : (-3 AND (7 AND -2))
# >> G_4: init: 2.32; noise: 0.55; b: 0.59; m: 5.18; expr: 1.59; deg: 0.13; theta: 8.06; asym: 4.40; tree : -1
# >> G_5: init: 1.70; noise: 0.91; b: 0.13; m: 2.71; expr: 1.22; deg: 0.10; theta: 9.55; asym: 5.08; tree : (7 AND -2)
# >> G_6: init: 0.48; noise: 1.38; b: 0.70; m: 3.53; expr: 1.01; deg: 0.06; theta: 4.71; asym: 5.69; tree : (6 OR 3)
#
# ======= GENERATION generation_g36 9931.100107134907 =======
# >> G_0: init: 1.06; noise: 1.21; b: 0.20; m: 10.39; expr: 0.80; deg: 0.13; theta: 1.36; asym: 4.89; tree : 3
# >> G_1: init: 0.37; noise: 1.00; b: 0.73; m: 1.29; expr: 0.88; deg: 0.13; theta: 2.21; asym: 6.22; tree : -2
# >> G_2: init: 0.61; noise: 1.03; b: 0.91; m: 8.87; expr: 0.97; deg: 0.06; theta: 8.82; asym: 10.71; tree : -1
# >> G_3: init: 0.34; noise: 1.06; b: 0.36; m: 2.83; expr: 0.90; deg: 0.06; theta: 1.12; asym: 3.73; tree : (-3 AND (7 AND -2))
# >> G_4: init: 2.08; noise: 0.55; b: 0.68; m: 5.18; expr: 1.59; deg: 0.13; theta: 8.06; asym: 4.40; tree : -1
# >> G_5: init: 1.70; noise: 1.05; b: 0.14; m: 2.71; expr: 1.22; deg: 0.10; theta: 10.94; asym: 5.08; tree : (7 AND -2)
# >> G_6: init: 0.48; noise: 1.38; b: 0.70; m: 3.82; expr: 1.01; deg: 0.05; theta: 4.71; asym: 5.69; tree : (6 OR 3)
#
# ======= GENERATION generation_g37 9926.056146914276 =======
# >> G_0: init: 1.22; noise: 1.16; b: 0.20; m: 10.39; expr: 0.78; deg: 0.11; theta: 1.89; asym: 5.07; tree : 3
# >> G_1: init: 0.36; noise: 0.89; b: 0.73; m: 1.32; expr: 0.79; deg: 0.13; theta: 2.21; asym: 5.99; tree : -2
# >> G_2: init: 0.69; noise: 0.95; b: 0.95; m: 8.67; expr: 0.97; deg: 0.05; theta: 9.00; asym: 8.11; tree : -1
# >> G_3: init: 0.34; noise: 1.06; b: 0.39; m: 3.11; expr: 1.03; deg: 0.05; theta: 1.21; asym: 4.94; tree : (-0 AND (6 AND -2))
# >> G_4: init: 2.22; noise: 0.62; b: 0.61; m: 6.59; expr: 1.59; deg: 0.13; theta: 7.63; asym: 3.84; tree : ((0 AND -1) AND 4)
# >> G_5: init: 2.12; noise: 0.93; b: 0.12; m: 2.62; expr: 1.34; deg: 0.09; theta: 9.55; asym: 5.10; tree : -4
# >> G_6: init: 0.45; noise: 1.24; b: 0.64; m: 3.34; expr: 0.99; deg: 0.06; theta: 4.79; asym: 5.77; tree : (6 OR (3 OR -0))
#
# ======= GENERATION generation_g38 9929.230504675343 =======
# >> G_0: init: 0.94; noise: 1.21; b: 0.21; m: 8.90; expr: 0.80; deg: 0.13; theta: 1.36; asym: 4.89; tree : 3
# >> G_1: init: 0.32; noise: 1.00; b: 0.75; m: 1.29; expr: 0.85; deg: 0.14; theta: 2.21; asym: 6.22; tree : -2
# >> G_2: init: 0.61; noise: 1.03; b: 0.91; m: 8.87; expr: 0.93; deg: 0.06; theta: 8.82; asym: 9.12; tree : -1
# >> G_3: init: 0.34; noise: 0.99; b: 0.36; m: 2.83; expr: 0.90; deg: 0.06; theta: 1.11; asym: 3.73; tree : (7 AND -2)
# >> G_4: init: 2.42; noise: 0.48; b: 0.59; m: 4.77; expr: 1.59; deg: 0.13; theta: 8.06; asym: 4.60; tree : -1
# >> G_5: init: 1.70; noise: 0.91; b: 0.13; m: 2.71; expr: 1.22; deg: 0.10; theta: 6.89; asym: 5.08; tree : (7 AND -2)
# >> G_6: init: 0.48; noise: 1.30; b: 0.70; m: 3.53; expr: 0.91; deg: 0.06; theta: 5.37; asym: 5.69; tree : (6 OR 3)
#
# ======= GENERATION generation_g39 9927.86819993216 =======
# >> G_0: init: 1.06; noise: 1.21; b: 0.21; m: 10.39; expr: 0.80; deg: 0.13; theta: 1.36; asym: 4.89; tree : 3
# >> G_1: init: 0.37; noise: 1.00; b: 0.73; m: 1.29; expr: 0.88; deg: 0.13; theta: 2.21; asym: 6.22; tree : -2
# >> G_2: init: 0.61; noise: 1.03; b: 0.98; m: 8.87; expr: 0.97; deg: 0.06; theta: 8.82; asym: 12.91; tree : -1
# >> G_3: init: 0.34; noise: 1.06; b: 0.36; m: 2.83; expr: 0.90; deg: 0.05; theta: 1.12; asym: 4.12; tree : (-3 AND (7 AND -2))
# >> G_4: init: 2.08; noise: 0.55; b: 0.68; m: 5.18; expr: 1.59; deg: 0.13; theta: 8.06; asym: 3.80; tree : -1
# >> G_5: init: 1.70; noise: 1.05; b: 0.14; m: 2.48; expr: 1.22; deg: 0.10; theta: 10.94; asym: 5.08; tree : (7 AND -2)
# >> G_6: init: 0.48; noise: 1.38; b: 0.83; m: 3.82; expr: 1.14; deg: 0.05; theta: 4.71; asym: 5.69; tree : (6 OR -0)
#
# ======= GENERATION generation_g40 9931.28622131164 =======
# >> G_0: init: 1.06; noise: 1.32; b: 0.16; m: 9.72; expr: 0.76; deg: 0.13; theta: 1.42; asym: 6.05; tree : 3
# >> G_1: init: 0.33; noise: 1.00; b: 0.70; m: 1.29; expr: 0.81; deg: 0.13; theta: 2.21; asym: 5.66; tree : (-2 AND 4)
# >> G_2: init: 0.66; noise: 0.91; b: 0.85; m: 8.88; expr: 0.97; deg: 0.06; theta: 8.82; asym: 10.71; tree : -1
# >> G_3: init: 0.29; noise: 1.19; b: 0.34; m: 3.00; expr: 0.90; deg: 0.06; theta: 1.12; asym: 4.55; tree : (7 AND -2)
# >> G_4: init: 1.96; noise: 0.60; b: 0.59; m: 5.89; expr: 1.45; deg: 0.12; theta: 8.06; asym: 5.44; tree : -1
# >> G_5: init: 2.11; noise: 0.77; b: 0.14; m: 2.71; expr: 1.22; deg: 0.11; theta: 7.82; asym: 5.62; tree : (7 AND -2)
# >> G_6: init: 0.37; noise: 1.33; b: 0.61; m: 3.66; expr: 1.01; deg: 0.05; theta: 4.20; asym: 7.02; tree : (6 OR 3)
#
# ======= GENERATION generation_g41 9936.45031687222 =======
# >> G_0: init: 1.06; noise: 1.41; b: 0.15; m: 11.24; expr: 0.80; deg: 0.13; theta: 1.36; asym: 4.89; tree : 3
# >> G_1: init: 0.31; noise: 1.12; b: 0.73; m: 1.29; expr: 0.85; deg: 0.14; theta: 2.21; asym: 5.86; tree : (-2 AND 4)
# >> G_2: init: 0.61; noise: 1.04; b: 0.80; m: 8.88; expr: 0.97; deg: 0.06; theta: 8.82; asym: 10.71; tree : -1
# >> G_3: init: 0.37; noise: 1.14; b: 0.32; m: 2.98; expr: 0.90; deg: 0.06; theta: 0.98; asym: 3.99; tree : (7 AND -2)
# >> G_4: init: 1.96; noise: 0.60; b: 0.59; m: 5.67; expr: 1.31; deg: 0.13; theta: 7.21; asym: 4.33; tree : -1
# >> G_5: init: 2.11; noise: 0.80; b: 0.14; m: 2.71; expr: 1.32; deg: 0.11; theta: 9.73; asym: 5.08; tree : (7 AND -2)
# >> G_6: init: 0.48; noise: 1.27; b: 0.48; m: 3.54; expr: 1.01; deg: 0.05; theta: 3.73; asym: 5.47; tree : (6 OR 3)
#
# ======= GENERATION generation_g42 9930.75225043461 =======
# >> G_0: init: 1.06; noise: 1.26; b: 0.17; m: 10.61; expr: 0.76; deg: 0.12; theta: 1.42; asym: 6.27; tree : 3
# >> G_1: init: 0.28; noise: 0.98; b: 0.70; m: 1.29; expr: 0.90; deg: 0.12; theta: 2.21; asym: 5.66; tree : (-2 AND 4)
# >> G_2: init: 0.60; noise: 0.86; b: 0.95; m: 9.17; expr: 0.97; deg: 0.06; theta: 8.82; asym: 10.71; tree : -1
# >> G_3: init: 0.31; noise: 1.19; b: 0.34; m: 3.00; expr: 0.90; deg: 0.06; theta: 1.12; asym: 4.45; tree : (7 AND -2)
# >> G_4: init: 1.88; noise: 0.60; b: 0.59; m: 5.89; expr: 1.48; deg: 0.15; theta: 8.06; asym: 5.44; tree : -1
# >> G_5: init: 2.11; noise: 0.59; b: 0.14; m: 2.46; expr: 1.26; deg: 0.11; theta: 8.21; asym: 5.62; tree : -2
# >> G_6: init: 0.37; noise: 1.37; b: 0.61; m: 3.66; expr: 1.01; deg: 0.06; theta: 4.29; asym: 7.02; tree : (6 OR 3)
#
# ======= GENERATION generation_g43 9931.530418397339 =======
# >> G_0: init: 1.06; noise: 1.33; b: 0.14; m: 10.61; expr: 0.76; deg: 0.14; theta: 1.42; asym: 5.87; tree : 3
# >> G_1: init: 0.28; noise: 0.98; b: 0.70; m: 1.29; expr: 0.87; deg: 0.12; theta: 2.21; asym: 5.66; tree : (-2 AND 4)
# >> G_2: init: 0.60; noise: 0.86; b: 0.99; m: 8.71; expr: 0.97; deg: 0.06; theta: 8.82; asym: 10.33; tree : -1
# >> G_3: init: 0.31; noise: 1.19; b: 0.34; m: 3.04; expr: 0.95; deg: 0.06; theta: 1.18; asym: 4.45; tree : (7 AND -2)
# >> G_4: init: 1.88; noise: 0.60; b: 0.58; m: 5.98; expr: 1.48; deg: 0.15; theta: 7.99; asym: 5.44; tree : -1
# >> G_5: init: 2.11; noise: 0.59; b: 0.11; m: 2.46; expr: 1.19; deg: 0.11; theta: 7.60; asym: 5.20; tree : (7 AND -3)
# >> G_6: init: 0.34; noise: 1.50; b: 0.68; m: 3.66; expr: 0.92; deg: 0.06; theta: 4.40; asym: 7.80; tree : (6 OR 3)
#
# ======= GENERATION generation_g44 9933.91834826284 =======
# >> G_0: init: 1.06; noise: 1.26; b: 0.17; m: 10.61; expr: 0.76; deg: 0.12; theta: 1.37; asym: 6.27; tree : 3
# >> G_1: init: 0.28; noise: 0.98; b: 0.70; m: 1.29; expr: 0.88; deg: 0.12; theta: 2.21; asym: 5.26; tree : (-2 AND 4)
# >> G_2: init: 0.44; noise: 0.85; b: 0.95; m: 9.17; expr: 1.01; deg: 0.06; theta: 7.33; asym: 10.58; tree : -1
# >> G_3: init: 0.30; noise: 1.14; b: 0.30; m: 3.00; expr: 0.74; deg: 0.06; theta: 1.12; asym: 4.45; tree : (7 AND -2)
# >> G_4: init: 1.88; noise: 0.62; b: 0.50; m: 5.89; expr: 1.48; deg: 0.13; theta: 8.57; asym: 4.78; tree : -1
# >> G_5: init: 2.08; noise: 0.60; b: 0.12; m: 2.72; expr: 1.16; deg: 0.10; theta: 7.90; asym: 6.23; tree : -2
# >> G_6: init: 0.36; noise: 1.47; b: 0.61; m: 3.66; expr: 1.12; deg: 0.06; theta: 4.13; asym: 7.02; tree : (6 OR 3)
#
# ======= GENERATION generation_g45 9934.065484498806 =======
# >> G_0: init: 1.06; noise: 1.26; b: 0.17; m: 10.61; expr: 0.76; deg: 0.12; theta: 1.35; asym: 6.27; tree : 3
# >> G_1: init: 0.28; noise: 0.75; b: 0.69; m: 1.26; expr: 0.78; deg: 0.11; theta: 2.21; asym: 5.74; tree : (-2 AND 4)
# >> G_2: init: 0.48; noise: 0.75; b: 0.95; m: 8.53; expr: 0.96; deg: 0.06; theta: 7.06; asym: 10.96; tree : -1
# >> G_3: init: 0.31; noise: 1.22; b: 0.31; m: 3.00; expr: 0.90; deg: 0.05; theta: 0.96; asym: 4.45; tree : (7 AND (-2 AND 5))
# >> G_4: init: 1.88; noise: 0.72; b: 0.53; m: 5.89; expr: 1.56; deg: 0.13; theta: 7.16; asym: 5.21; tree : -1
# >> G_5: init: 2.39; noise: 0.63; b: 0.12; m: 2.46; expr: 1.22; deg: 0.11; theta: 8.34; asym: 5.77; tree : -2
# >> G_6: init: 0.36; noise: 1.37; b: 0.61; m: 3.63; expr: 1.06; deg: 0.06; theta: 5.05; asym: 7.02; tree : 6
#
# ======= GENERATION generation_g46 9931.8135632656 =======
# >> G_0: init: 1.06; noise: 1.26; b: 0.22; m: 9.78; expr: 0.76; deg: 0.12; theta: 1.35; asym: 6.83; tree : 3
# >> G_1: init: 0.30; noise: 0.75; b: 0.69; m: 1.26; expr: 0.78; deg: 0.11; theta: 2.21; asym: 5.74; tree : (-2 AND 4)
# >> G_2: init: 0.48; noise: 0.75; b: 0.95; m: 8.18; expr: 0.96; deg: 0.06; theta: 7.95; asym: 10.96; tree : -1
# >> G_3: init: 0.31; noise: 1.22; b: 0.31; m: 3.00; expr: 0.90; deg: 0.05; theta: 0.96; asym: 4.45; tree : (7 AND (-2 AND 5))
# >> G_4: init: 1.84; noise: 0.72; b: 0.45; m: 5.93; expr: 1.58; deg: 0.13; theta: 6.98; asym: 5.21; tree : (-1 AND -7)
# >> G_5: init: 2.39; noise: 0.63; b: 0.11; m: 2.46; expr: 1.22; deg: 0.12; theta: 8.34; asym: 5.77; tree : -2
# >> G_6: init: 0.36; noise: 1.37; b: 0.61; m: 3.63; expr: 1.23; deg: 0.06; theta: 5.05; asym: 7.02; tree : 6
#
# ======= GENERATION generation_g47 9932.825234884478 =======
# >> G_0: init: 1.00; noise: 1.26; b: 0.25; m: 9.78; expr: 0.76; deg: 0.12; theta: 1.35; asym: 6.82; tree : 3
# >> G_1: init: 0.30; noise: 0.75; b: 0.69; m: 1.26; expr: 0.65; deg: 0.11; theta: 2.21; asym: 5.74; tree : (-2 AND 4)
# >> G_2: init: 0.48; noise: 0.75; b: 0.95; m: 8.18; expr: 0.96; deg: 0.06; theta: 7.95; asym: 10.96; tree : -1
# >> G_3: init: 0.31; noise: 1.22; b: 0.36; m: 3.00; expr: 0.71; deg: 0.05; theta: 0.96; asym: 4.45; tree : (7 AND (-2 AND 5))
# >> G_4: init: 1.84; noise: 0.72; b: 0.45; m: 5.93; expr: 1.58; deg: 0.13; theta: 6.98; asym: 5.21; tree : (-1 AND -7)
# >> G_5: init: 2.39; noise: 0.63; b: 0.11; m: 2.46; expr: 1.22; deg: 0.12; theta: 9.06; asym: 5.90; tree : -2
# >> G_6: init: 0.36; noise: 1.37; b: 0.54; m: 3.63; expr: 1.23; deg: 0.06; theta: 5.69; asym: 7.02; tree : 6
#
# ======= GENERATION generation_g48 9933.628026347966 =======
# >> G_0: init: 1.01; noise: 1.27; b: 0.14; m: 10.61; expr: 0.77; deg: 0.13; theta: 1.52; asym: 5.87; tree : 3
# >> G_1: init: 0.32; noise: 0.76; b: 0.70; m: 1.29; expr: 0.80; deg: 0.13; theta: 2.21; asym: 6.52; tree : (-2 AND 4)
# >> G_2: init: 0.61; noise: 0.73; b: 0.81; m: 8.71; expr: 0.97; deg: 0.06; theta: 9.17; asym: 10.90; tree : -1
# >> G_3: init: 0.34; noise: 0.84; b: 0.34; m: 2.84; expr: 0.85; deg: 0.05; theta: 1.18; asym: 4.78; tree : (7 AND -2)
# >> G_4: init: 2.21; noise: 0.64; b: 0.60; m: 5.56; expr: 1.35; deg: 0.14; theta: 8.89; asym: 4.65; tree : -1
# >> G_5: init: 2.11; noise: 0.59; b: 0.12; m: 2.01; expr: 1.19; deg: 0.10; theta: 7.02; asym: 5.20; tree : -3
# >> G_6: init: 0.34; noise: 1.50; b: 0.68; m: 4.09; expr: 1.01; deg: 0.06; theta: 4.44; asym: 8.95; tree : (6 OR 3)
#
# ======= GENERATION generation_g49 9929.206365981168 =======
# >> G_0: init: 1.21; noise: 1.26; b: 0.15; m: 10.61; expr: 0.85; deg: 0.13; theta: 1.52; asym: 5.87; tree : 3
# >> G_1: init: 0.32; noise: 0.93; b: 0.70; m: 1.29; expr: 0.93; deg: 0.13; theta: 2.21; asym: 4.95; tree : (-2 AND 4)
# >> G_2: init: 0.61; noise: 0.73; b: 0.84; m: 9.32; expr: 1.06; deg: 0.06; theta: 10.14; asym: 10.31; tree : -1
# >> G_3: init: 0.31; noise: 0.65; b: 0.37; m: 2.84; expr: 0.85; deg: 0.05; theta: 1.18; asym: 4.45; tree : (7 AND -2)
# >> G_4: init: 2.01; noise: 0.62; b: 0.52; m: 5.23; expr: 1.66; deg: 0.15; theta: 8.89; asym: 4.83; tree : -1
# >> G_5: init: 2.11; noise: 0.59; b: 0.12; m: 2.13; expr: 1.04; deg: 0.09; theta: 8.30; asym: 5.20; tree : (7 AND -3)
# >> G_6: init: 0.34; noise: 1.55; b: 0.61; m: 4.09; expr: 1.01; deg: 0.05; theta: 4.72; asym: 8.95; tree : (6 OR -5)
#
# ======= GENERATION generation_g50 9930.822645046994 =======
# >> G_0: init: 1.06; noise: 1.25; b: 0.16; m: 11.73; expr: 0.77; deg: 0.17; theta: 1.44; asym: 5.34; tree : 3
# >> G_1: init: 0.39; noise: 0.87; b: 0.72; m: 1.32; expr: 0.89; deg: 0.13; theta: 2.30; asym: 5.15; tree : (-2 AND 4)
# >> G_2: init: 0.71; noise: 0.84; b: 1.11; m: 8.71; expr: 0.98; deg: 0.06; theta: 10.26; asym: 10.68; tree : -1
# >> G_3: init: 0.30; noise: 1.00; b: 0.34; m: 2.78; expr: 0.85; deg: 0.06; theta: 1.21; asym: 4.57; tree : ((7 AND -3) AND -2)
# >> G_4: init: 1.66; noise: 0.68; b: 0.57; m: 5.25; expr: 1.38; deg: 0.15; theta: 8.34; asym: 5.38; tree : -1
# >> G_5: init: 1.98; noise: 0.60; b: 0.09; m: 2.16; expr: 1.19; deg: 0.11; theta: 9.01; asym: 5.19; tree : (7 AND -3)
# >> G_6: init: 0.28; noise: 1.49; b: 0.81; m: 3.66; expr: 1.20; deg: 0.06; theta: 4.58; asym: 7.80; tree : (6 OR 3)
