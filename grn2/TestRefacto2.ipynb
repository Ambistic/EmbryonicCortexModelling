# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn import GRNMain
from lib.sde.mutate import SparseMutator

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time
from jf.utils.helper import provide_id

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")
_MUTATE_FUNC = SparseMutator()

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(7, 5, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 10000 - 1 * delta_late - 0.5 * delta_early)

# %%
def hook_event_handler(cell_program):
    # prob **2 and **4
    q = np.array(cell_program.quantities)
    if random() < (q[0] / 2)**4:  # missing a reset
        cell_program.quantities = cell_program.quantities.at[0].set(0)
        return Action.Divide, GRNCell.Progenitor
    
    if random() < (q[1] / 2)**2 * (1 - q[2] / 2)**2:
        return Action.DiffNeuron, GRNCell.PostMitoticInfra
    
    if random() < (q[2] / 2)**2 * (1 - q[1] / 2)**2:
        return Action.DiffNeuron, GRNCell.PostMitoticSupra
    
    return Action.NoOp, None

# %%
def get_bb(prun, grn):
    from submodels.grn_auto_v1 import GRNCell
    ccls = factories["grn_auto1"](grn=grn, hooks=dict(event_handler=hook_event_handler))
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=50, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks)
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def fitness_step(prun, grn, step):
    bb = get_bb(prun, grn)
    bb.run_until(step.end_time)
    score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
    fitness = 1.0 / score_step
        
    return fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_step(prun, sol.grn, prun.step)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_step = ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2)

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 20
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.step = example_step
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if batch_gen == prun.n_gen:
        print("Already finished")
        return
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // prun.batch_size
            exporter(pop[-prun.batch_size:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "test_refacto2"
res = main(prun)
# Out:
# Exporting at output/test_refacto2
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 9871.860301860303 for generation 0
# [out] ++ Best 9871.880710023566 for generation 2
# [out] ++ Best 9876.370505941934 for generation 3
# [out] ++ Best 9889.288547359976 for generation 4
# [out] ++ Best 9891.840971769543 for generation 43
# Saving ...
# [out] ++ Best 9893.890588176304 for generation 50
# [out] ++ Best 9896.319159604875 for generation 63
# [out] ++ Best 9902.135486135487 for generation 65
# Saving ...
# [out] Step 100
# [out] ++ Best 9903.553853482425 for generation 106
# [out] ++ Best 9907.218848718849 for generation 107
# [out] ++ Best 9908.400792257935 for generation 129
# [out] ++ Best 9912.208318708319 for generation 135
# Saving ...
# [out] ++ Best 9915.279747279748 for generation 171
# Saving ...
# [out] Step 200
# [out] ++ Best 9916.167502381788 for generation 210
# Saving ...
# [out] ++ Best 9918.83076768791 for generation 256
# Saving ...
# [out] Step 300
# Saving ...
# Saving ...
# [out] Step 400
# [out] ++ Best 9920.18650654365 for generation 442
# Saving ...
# Saving ...
# [out] Step 500
# [out] ++ Best 9923.513037155893 for generation 509
# Saving ...
# [out] ++ Best 9923.859975931404 for generation 551
# Saving ...
# [out] Step 600
# [out] ++ Best 9931.90219625934 for generation 617
# Saving ...
# Saving ...
# [out] Step 700
# Saving ...
# [out] ++ Best 9934.064057564057 for generation 773
# Saving ...
# [out] Step 800
# [out] ++ Best 9940.034849320564 for generation 843
# Saving ...
# [out] ++ Best 9941.533771248058 for generation 872
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/test_refacto2

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load("generation_g10"))
res = pick_best(exp.load(pick_last(exp)))

# %%
res.fit
# Out:
# 9938.137216065787

# %%
# for i in range(5):
#     print(fitness_multistep(prun, res.grn, prun.steps))

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} {res.fit} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g1 9891.840971769543 =======
# G> G_0: b=1.37; m=8.79; theta=4.87; init=1.02; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(-0.35x3 AND 0.35x4)
# G> G_1: b=0.23; m=7.47; theta=9.19; init=1.36; noise=0.98; expr=1.00; deg=0.10; asym=5.45; tree=(0.72x0z AND -0.16x3)
# G> G_2: b=2.34; m=0.81; theta=3.48; init=0.56; noise=1.00; expr=1.00; deg=0.10; asym=5.01; tree=(0.50x4 AND -0.76x1 AND 0.53x0z)
# G> G_3: b=4.94; m=2.94; theta=4.98; init=0.94; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(0.40x4 AND -0.93x1 AND 0.29x2)
# G> G_4: b=1.21; m=5.00; theta=6.37; init=0.18; noise=1.00; expr=1.00; deg=0.10; asym=4.83; tree=(0.17x0z AND 0.99x3 AND 0.81x4)
# G> G_5: b=1.13; m=7.37; theta=8.10; init=1.87; noise=1.00; expr=1.08; deg=0.10; asym=5.00; tree=(0.70x2 AND 0.58x1)
# G> G_6: b=1.02; m=0.55; theta=5.65; init=2.24; noise=0.98; expr=1.00; deg=0.10; asym=5.00; tree=(-0.36x3)
# R> tree=(-0.69x0)
# R> tree=(0.69x1z OR 0.61x1 OR -0.05x4)
# R> tree=(-0.75x2 OR 0.88x3)
# R> tree=()
# R> tree=(0.10x1 OR 0.95x1z OR -0.63x2)
#
# ======= GENERATION generation_g2 9902.135486135487 =======
# G> G_0: b=1.25; m=9.88; theta=5.45; init=0.89; noise=0.93; expr=1.00; deg=0.09; asym=6.26; tree=()
# G> G_1: b=0.29; m=3.95; theta=4.26; init=0.90; noise=1.13; expr=1.03; deg=0.10; asym=5.00; tree=(0.26x0z AND -0.71x2 AND -0.50x0)
# G> G_2: b=1.73; m=0.61; theta=4.54; init=1.87; noise=1.12; expr=1.04; deg=0.10; asym=4.89; tree=(0.33x3 AND -0.67x0)
# G> G_3: b=2.29; m=8.66; theta=1.99; init=1.37; noise=1.00; expr=1.12; deg=0.09; asym=4.88; tree=()
# G> G_4: b=1.98; m=4.56; theta=6.74; init=0.80; noise=1.00; expr=0.87; deg=0.10; asym=4.57; tree=()
# G> G_5: b=1.15; m=0.14; theta=5.80; init=1.44; noise=1.09; expr=1.00; deg=0.11; asym=5.00; tree=(0.69x1 AND 0.42x0z AND 0.77x4)
# G> G_6: b=1.24; m=3.37; theta=6.37; init=1.37; noise=0.97; expr=1.00; deg=0.10; asym=5.00; tree=(0.20x0z AND -0.39x2 AND 0.81x1 AND 0.03x4)
# R> tree=(-0.78x1 OR 0.29x1z OR -0.11x5 OR 0.02x0)
# R> tree=(0.91x1z OR 0.68x1 OR -0.94x0)
# R> tree=(0.39x0 OR 0.09x1z OR -0.85x4)
# R> tree=(0.64x1 OR 0.61x1z)
# R> tree=(-0.72x2 OR 0.56x7 OR -0.20x5)
#
# ======= GENERATION generation_g3 9912.208318708319 =======
# G> G_0: b=1.37; m=8.05; theta=4.87; init=1.02; noise=0.90; expr=1.04; deg=0.10; asym=4.61; tree=(-0.39x3 AND 0.45x4)
# G> G_1: b=0.21; m=7.47; theta=9.19; init=1.40; noise=0.96; expr=0.85; deg=0.10; asym=5.71; tree=(0.72x0z AND -0.08x3 AND -0.07x4)
# G> G_2: b=2.34; m=0.77; theta=3.48; init=0.57; noise=0.97; expr=1.11; deg=0.10; asym=4.37; tree=(0.50x4 AND -0.51x1 AND 0.53x0z)
# G> G_3: b=4.94; m=2.94; theta=5.10; init=0.92; noise=1.00; expr=0.84; deg=0.10; asym=4.82; tree=(0.55x4 AND -0.76x1 AND 0.15x2)
# G> G_4: b=1.09; m=5.00; theta=5.66; init=0.18; noise=1.09; expr=0.97; deg=0.10; asym=3.69; tree=(0.17x0z AND 1.00x3 AND 0.92x4)
# G> G_5: b=1.13; m=7.37; theta=8.88; init=1.67; noise=1.00; expr=1.20; deg=0.10; asym=5.00; tree=(0.77x2 AND 0.58x1 AND 0.16x0z)
# G> G_6: b=1.02; m=0.55; theta=5.65; init=2.40; noise=0.98; expr=1.31; deg=0.10; asym=5.41; tree=(-0.36x3)
# R> tree=(-0.69x0)
# R> tree=(0.72x1z OR 0.74x1 OR -0.05x4)
# R> tree=(-0.80x2 OR 0.85x3 OR 0.13x5)
# R> tree=()
# R> tree=(1.00x1z OR -0.70x2)
#
# ======= GENERATION generation_g4 9915.279747279748 =======
# G> G_0: b=1.44; m=7.55; theta=4.87; init=1.00; noise=0.91; expr=1.04; deg=0.09; asym=5.00; tree=(-0.39x3 AND 0.42x4)
# G> G_1: b=0.25; m=7.54; theta=7.78; init=1.40; noise=0.83; expr=0.78; deg=0.10; asym=5.50; tree=(0.72x0z AND -0.16x3)
# G> G_2: b=2.54; m=0.78; theta=3.27; init=0.56; noise=0.97; expr=1.11; deg=0.09; asym=4.37; tree=(0.43x4 AND -0.51x1 AND 0.53x0z)
# G> G_3: b=6.02; m=2.94; theta=5.04; init=1.16; noise=0.83; expr=0.80; deg=0.11; asym=4.82; tree=(0.49x4 AND -0.93x1 AND 0.14x2)
# G> G_4: b=0.97; m=5.00; theta=6.37; init=0.18; noise=1.12; expr=1.31; deg=0.10; asym=4.83; tree=(0.17x0z AND 0.99x3 AND 0.86x4)
# G> G_5: b=1.13; m=7.37; theta=8.74; init=1.66; noise=1.00; expr=1.20; deg=0.10; asym=4.80; tree=(0.78x2 AND 0.58x1)
# G> G_6: b=1.02; m=0.55; theta=5.65; init=2.10; noise=0.83; expr=0.99; deg=0.10; asym=6.37; tree=(-0.36x3)
# R> tree=(-0.69x0)
# R> tree=(0.96x1z OR 0.91x1 OR -0.05x4 OR -0.09x3)
# R> tree=(-0.75x2 OR 0.84x3)
# R> tree=()
# R> tree=(0.81x1z OR -0.66x2)
#
# ======= GENERATION generation_g5 9916.167502381788 =======
# G> G_0: b=1.37; m=8.05; theta=4.87; init=1.02; noise=1.03; expr=1.04; deg=0.10; asym=5.00; tree=(-0.36x3 AND 0.45x4 AND 0.10x2)
# G> G_1: b=0.22; m=7.68; theta=7.18; init=1.52; noise=0.96; expr=0.85; deg=0.10; asym=3.49; tree=(0.72x0z AND -0.15x3 AND -0.10x4)
# G> G_2: b=2.34; m=0.76; theta=4.02; init=0.58; noise=0.97; expr=1.11; deg=0.10; asym=4.37; tree=(0.50x4 AND -0.51x1 AND 0.53x0z)
# G> G_3: b=4.94; m=2.95; theta=4.94; init=0.93; noise=1.00; expr=0.84; deg=0.08; asym=4.34; tree=(0.40x4 AND -0.76x1 AND 0.36x2)
# G> G_4: b=1.24; m=5.38; theta=6.37; init=0.17; noise=1.12; expr=1.28; deg=0.12; asym=3.61; tree=(0.17x0z AND 0.98x3 AND 0.79x4)
# G> G_5: b=1.13; m=7.37; theta=10.00; init=1.97; noise=1.00; expr=1.20; deg=0.10; asym=5.00; tree=(0.77x2 AND 0.90x1 AND 0.16x0z AND -0.03x3)
# G> G_6: b=1.09; m=0.55; theta=5.65; init=2.24; noise=0.98; expr=1.22; deg=0.12; asym=6.57; tree=(-0.27x3)
# R> tree=(-0.69x0)
# R> tree=(0.77x1z OR 0.81x1 OR -0.11x4 OR 0.06x2 OR 0.02x3)
# R> tree=(-0.91x2 OR 0.68x3 OR -0.09x6)
# R> tree=()
# R> tree=(1.00x1z OR -0.70x2)
#
# ======= GENERATION generation_g6 9918.83076768791 =======
# G> G_0: b=1.37; m=8.05; theta=5.19; init=0.92; noise=1.03; expr=1.13; deg=0.09; asym=5.00; tree=(-0.39x3 AND 0.53x4)
# G> G_1: b=0.21; m=7.06; theta=9.46; init=1.40; noise=1.04; expr=0.85; deg=0.10; asym=6.29; tree=(0.72x0z AND -0.16x3 AND -0.03x4)
# G> G_2: b=2.34; m=0.70; theta=3.48; init=0.59; noise=0.97; expr=1.05; deg=0.11; asym=4.14; tree=(0.50x4 AND -0.51x1 AND 0.45x0z)
# G> G_3: b=4.94; m=2.95; theta=4.99; init=0.84; noise=1.06; expr=0.92; deg=0.11; asym=4.82; tree=(0.38x4 AND -0.87x1 AND 0.19x2 AND 0.01x0z)
# G> G_4: b=1.08; m=5.00; theta=6.18; init=0.19; noise=1.18; expr=1.00; deg=0.12; asym=3.61; tree=(0.17x0z AND 0.98x3 AND 0.86x4)
# G> G_5: b=1.13; m=7.79; theta=10.00; init=1.77; noise=1.00; expr=1.50; deg=0.10; asym=5.78; tree=(0.77x2 AND 0.38x1)
# G> G_6: b=1.05; m=0.55; theta=4.88; init=2.14; noise=1.00; expr=1.00; deg=0.11; asym=5.77; tree=(-0.27x3)
# R> tree=(-0.91x0)
# R> tree=(0.84x1z OR 0.90x1 OR -0.10x4)
# R> tree=(-0.91x2 OR 0.92x3)
# R> tree=()
# R> tree=(1.00x1z OR -0.76x2)
#
# ======= GENERATION generation_g7 9917.422604422603 =======
# G> G_0: b=1.18; m=8.54; theta=5.55; init=0.92; noise=1.03; expr=1.06; deg=0.09; asym=5.45; tree=(-0.39x3 AND 0.61x4 AND 0.19x0)
# G> G_1: b=0.21; m=7.06; theta=9.46; init=1.40; noise=1.04; expr=0.85; deg=0.10; asym=7.24; tree=(0.72x0z AND -0.20x3 AND -0.10x4)
# G> G_2: b=2.34; m=0.78; theta=3.48; init=0.63; noise=0.97; expr=1.05; deg=0.11; asym=4.14; tree=(0.50x4 AND -0.51x1 AND 0.39x0z AND 0.13x3)
# G> G_3: b=4.94; m=2.95; theta=4.99; init=0.84; noise=1.06; expr=0.92; deg=0.11; asym=4.82; tree=(0.38x4 AND -0.89x1 AND 0.19x2 AND 0.01x0z)
# G> G_4: b=0.95; m=5.00; theta=6.18; init=0.18; noise=1.30; expr=1.00; deg=0.12; asym=3.61; tree=(0.17x0z AND 0.79x3 AND 0.69x4 AND -0.03x0)
# G> G_5: b=1.13; m=7.79; theta=10.00; init=1.69; noise=1.00; expr=1.26; deg=0.10; asym=5.19; tree=(0.77x2 AND 0.38x1)
# G> G_6: b=1.05; m=0.55; theta=4.48; init=2.14; noise=1.00; expr=1.00; deg=0.11; asym=5.77; tree=(-0.27x3)
# R> tree=(-0.91x0)
# R> tree=(0.82x1z OR 0.90x1)
# R> tree=(-0.91x2 OR 0.92x3)
# R> tree=(0.02x7)
# R> tree=(1.00x1z OR -0.76x2)
#
# ======= GENERATION generation_g8 9915.157624229052 =======
# G> G_0: b=1.14; m=8.79; theta=4.87; init=0.86; noise=1.04; expr=1.04; deg=0.13; asym=5.00; tree=(-0.41x3 AND 0.45x4 AND -0.24x2)
# G> G_1: b=0.26; m=10.12; theta=8.58; init=1.20; noise=0.86; expr=0.85; deg=0.08; asym=4.68; tree=(0.69x0z AND -0.19x3 AND -0.29x4)
# G> G_2: b=1.94; m=0.89; theta=4.62; init=0.51; noise=1.00; expr=1.10; deg=0.10; asym=4.09; tree=(0.46x4 AND -0.50x1 AND 0.53x0z AND -0.07x3 AND -0.06x0)
# G> G_3: b=6.05; m=3.18; theta=5.09; init=0.89; noise=1.20; expr=0.72; deg=0.09; asym=5.67; tree=(0.77x4 AND -0.76x1 AND 0.10x2)
# G> G_4: b=0.94; m=5.00; theta=7.60; init=0.20; noise=1.33; expr=1.00; deg=0.14; asym=3.36; tree=(0.17x0z AND 0.98x3 AND 0.98x4 AND -0.13x0)
# G> G_5: b=1.20; m=7.37; theta=10.03; init=1.89; noise=0.94; expr=1.20; deg=0.10; asym=5.00; tree=(0.77x2 AND 0.58x1 AND 0.01x0z AND -0.17x3)
# G> G_6: b=1.11; m=0.53; theta=5.70; init=2.24; noise=0.76; expr=1.16; deg=0.09; asym=7.45; tree=(-0.23x3)
# R> tree=(-0.69x0 OR -0.08x3 OR 0.21x2 OR -0.04x5)
# R> tree=(0.81x1z OR 0.71x1 OR -0.07x4 OR 0.33x2)
# R> tree=(-1.00x2 OR 0.66x3 OR 0.15x6)
# R> tree=()
# R> tree=(1.00x1z OR -0.62x2 OR 0.11x5 OR 0.06x3)
#
# ======= GENERATION generation_g9 9920.18650654365 =======
# G> G_0: b=1.21; m=8.05; theta=4.87; init=0.94; noise=1.27; expr=1.04; deg=0.11; asym=4.58; tree=(-0.29x3 AND 0.43x4 AND -0.05x2 AND 0.01x0)
# G> G_1: b=0.26; m=8.46; theta=7.86; init=1.54; noise=0.85; expr=0.85; deg=0.08; asym=5.16; tree=(0.75x0z AND -0.18x3 AND -0.22x4)
# G> G_2: b=1.80; m=0.89; theta=4.82; init=0.49; noise=1.14; expr=1.21; deg=0.10; asym=3.98; tree=(0.32x4 AND -0.49x1 AND 0.53x0z AND 0.15x2)
# G> G_3: b=5.74; m=2.17; theta=5.06; init=0.89; noise=1.10; expr=0.60; deg=0.10; asym=5.67; tree=(0.53x4 AND -0.72x1 AND 0.17x2 AND 0.26x3)
# G> G_4: b=1.09; m=5.03; theta=7.67; init=0.20; noise=1.17; expr=0.85; deg=0.12; asym=3.28; tree=(0.21x0z AND 0.93x3 AND 0.95x4)
# G> G_5: b=1.33; m=7.64; theta=10.03; init=1.66; noise=1.00; expr=1.17; deg=0.10; asym=5.73; tree=(0.84x2 AND 0.58x1 AND 0.04x0z AND -0.06x3)
# G> G_6: b=1.33; m=0.55; theta=6.29; init=1.95; noise=0.76; expr=1.21; deg=0.09; asym=6.31; tree=(-0.31x3 AND 0.14x1)
# R> tree=(-0.56x0 OR -0.08x3 OR 0.14x2 OR -0.03x7)
# R> tree=(0.77x1z OR 0.98x1 OR -0.18x4 OR 0.14x2)
# R> tree=(-0.93x2 OR 0.66x3 OR 0.15x6 OR 0.04x0)
# R> tree=()
# R> tree=(1.00x1z OR -0.62x2 OR 0.01x5)
#
# ======= GENERATION generation_g10 9915.951812666097 =======
# G> G_0: b=1.21; m=8.05; theta=4.61; init=1.01; noise=1.27; expr=1.05; deg=0.11; asym=4.58; tree=(-0.29x3 AND 0.43x4 AND -0.05x2 AND 0.04x1 AND 0.10x0)
# G> G_1: b=0.30; m=7.72; theta=6.33; init=1.54; noise=0.83; expr=0.86; deg=0.06; asym=5.16; tree=(0.75x0z AND -0.11x3 AND -0.35x4 AND -0.24x1)
# G> G_2: b=2.30; m=1.04; theta=4.26; init=0.59; noise=0.80; expr=1.21; deg=0.09; asym=4.03; tree=(0.30x4 AND -0.50x1 AND 0.51x0z AND 0.15x2)
# G> G_3: b=5.74; m=2.53; theta=5.06; init=0.89; noise=1.13; expr=0.58; deg=0.10; asym=5.67; tree=(0.53x4 AND -0.72x1 AND 0.17x2 AND 0.26x3)
# G> G_4: b=1.09; m=5.15; theta=7.18; init=0.20; noise=1.27; expr=0.85; deg=0.14; asym=3.28; tree=(0.21x0z AND 0.86x3 AND 0.87x4)
# G> G_5: b=1.33; m=7.37; theta=10.03; init=1.66; noise=1.01; expr=1.17; deg=0.10; asym=5.73; tree=(0.70x2 AND 0.58x1 AND -0.14x3 AND -0.15x4)
# G> G_6: b=1.22; m=0.55; theta=6.29; init=2.30; noise=0.76; expr=1.21; deg=0.09; asym=6.31; tree=(-0.35x3 AND 0.14x1)
# R> tree=(-0.56x0 OR 0.21x2 OR -0.03x7 OR -0.12x3)
# R> tree=(0.77x1z OR 0.98x1 OR 0.09x2)
# R> tree=(-0.94x2 OR 0.64x3 OR 0.17x6 OR 0.10x0 OR 0.14x1z)
# R> tree=(-0.09x2)
# R> tree=(1.00x1z OR -0.62x2 OR 0.01x5)
#
# ======= GENERATION generation_g11 9923.513037155893 =======
# G> G_0: b=0.96; m=8.02; theta=4.81; init=0.94; noise=1.34; expr=1.05; deg=0.11; asym=4.58; tree=(-0.47x3 AND 0.38x4 AND -0.05x2 AND 0.04x1 AND 0.06x0 AND 0.04x0z)
# G> G_1: b=0.30; m=6.59; theta=6.99; init=1.77; noise=0.83; expr=0.86; deg=0.06; asym=4.69; tree=(0.75x0z AND -0.26x3 AND -0.35x4)
# G> G_2: b=2.33; m=0.89; theta=4.26; init=0.51; noise=1.12; expr=1.21; deg=0.10; asym=4.03; tree=(0.30x4 AND -0.50x1 AND 0.53x0z AND 0.15x2)
# G> G_3: b=6.78; m=2.72; theta=4.89; init=0.89; noise=1.13; expr=0.61; deg=0.10; asym=5.67; tree=(0.53x4 AND -0.72x1 AND 0.17x2 AND 0.25x3)
# G> G_4: b=0.86; m=5.32; theta=7.67; init=0.20; noise=1.27; expr=0.85; deg=0.13; asym=3.28; tree=(0.21x0z AND 0.86x3 AND 0.80x4)
# G> G_5: b=1.33; m=7.70; theta=10.03; init=1.66; noise=1.01; expr=1.17; deg=0.11; asym=5.73; tree=(0.73x2 AND 0.58x1 AND -0.14x3 AND -0.15x4)
# G> G_6: b=1.22; m=0.55; theta=6.65; init=2.24; noise=0.76; expr=1.39; deg=0.09; asym=5.64; tree=(-0.35x3 AND 0.14x1)
# R> tree=(-0.56x0 OR 0.21x2 OR -0.00x7 OR -0.12x3)
# R> tree=(0.77x1z OR 0.98x1 OR -0.27x4 OR 0.09x2)
# R> tree=(-0.94x2 OR 0.66x3 OR 0.17x6 OR 0.14x0)
# R> tree=(-0.09x2 OR -0.09x1)
# R> tree=(1.00x1z OR -0.62x2)
#
# ======= GENERATION generation_g12 9923.859975931404 =======
# G> G_0: b=1.17; m=8.05; theta=3.96; init=1.01; noise=1.38; expr=1.05; deg=0.11; asym=4.58; tree=(-0.29x3 AND 0.37x4 AND -0.05x2 AND 0.10x0 AND -0.00x1)
# G> G_1: b=0.28; m=7.27; theta=6.33; init=1.54; noise=0.93; expr=0.92; deg=0.06; asym=5.16; tree=(0.75x0z AND -0.11x3 AND -0.30x4 AND -0.24x1 AND 0.03x2)
# G> G_2: b=2.30; m=1.04; theta=4.26; init=0.59; noise=0.80; expr=1.24; deg=0.09; asym=3.93; tree=(0.29x4 AND -0.50x1 AND 0.51x0z AND 0.21x2)
# G> G_3: b=5.74; m=2.53; theta=5.06; init=0.89; noise=1.01; expr=0.58; deg=0.10; asym=5.00; tree=(0.53x4 AND -0.77x1 AND 0.19x2 AND 0.26x3)
# G> G_4: b=1.00; m=5.15; theta=7.96; init=0.22; noise=1.27; expr=0.85; deg=0.14; asym=3.28; tree=(0.21x0z AND 0.84x3 AND 0.82x4)
# G> G_5: b=1.26; m=7.44; theta=10.03; init=1.71; noise=1.01; expr=1.17; deg=0.10; asym=5.73; tree=(0.70x2 AND 0.58x1 AND -0.14x3)
# G> G_6: b=1.22; m=0.55; theta=6.29; init=2.30; noise=0.76; expr=1.29; deg=0.09; asym=6.31; tree=(-0.41x3 AND 0.17x1)
# R> tree=(-0.42x0 OR 0.25x2 OR -0.20x7 OR -0.12x3)
# R> tree=(0.77x1z OR 0.86x1 OR 0.09x2 OR 0.01x0)
# R> tree=(-0.94x2 OR 0.64x3 OR 0.17x6 OR 0.10x0 OR 0.14x1z)
# R> tree=(-0.09x2 OR 0.07x7)
# R> tree=(1.00x1z OR -0.62x2 OR 0.01x5 OR 0.12x1)
#
# ======= GENERATION generation_g13 9931.90219625934 =======
# G> G_0: b=1.21; m=8.05; theta=3.48; init=1.28; noise=1.22; expr=1.19; deg=0.10; asym=4.58; tree=(-0.29x3 AND 0.43x4 AND -0.05x2 AND 0.24x0)
# G> G_1: b=0.28; m=7.27; theta=6.33; init=1.54; noise=1.00; expr=0.89; deg=0.06; asym=7.50; tree=(0.65x0z AND -0.14x3 AND -0.37x4 AND -0.24x1)
# G> G_2: b=2.30; m=1.04; theta=4.26; init=0.66; noise=0.90; expr=1.21; deg=0.08; asym=4.15; tree=(0.30x4 AND -0.50x1 AND 0.51x0z AND 0.21x2)
# G> G_3: b=5.74; m=3.00; theta=5.93; init=0.92; noise=0.88; expr=0.58; deg=0.10; asym=6.05; tree=(0.53x4 AND -0.91x1 AND 0.29x2 AND 0.19x3 AND 0.00x0z)
# G> G_4: b=1.00; m=5.15; theta=7.23; init=0.22; noise=1.28; expr=0.78; deg=0.14; asym=3.22; tree=(0.21x0z AND 0.82x3 AND 0.82x4)
# G> G_5: b=1.08; m=7.24; theta=8.23; init=1.90; noise=0.76; expr=1.17; deg=0.09; asym=5.66; tree=(0.84x2 AND 0.58x1 AND -0.48x3)
# G> G_6: b=1.22; m=0.55; theta=6.62; init=2.30; noise=0.65; expr=1.30; deg=0.09; asym=7.72; tree=(-0.35x3 AND 0.14x1)
# R> tree=(-0.56x0 OR 0.40x2 OR -0.06x3)
# R> tree=(0.77x1z OR 0.90x1 OR 0.09x2 OR 0.01x0)
# R> tree=(-0.81x2 OR 0.64x3 OR 0.17x6 OR 0.10x0 OR 0.14x1z)
# R> tree=(-0.39x2 OR 0.07x7 OR 0.13x0)
# R> tree=(1.00x1z OR -0.67x2 OR 0.01x5 OR 0.10x3)
#
# ======= GENERATION generation_g14 9924.339893697035 =======
# G> G_0: b=1.30; m=8.05; theta=3.38; init=1.14; noise=0.98; expr=1.19; deg=0.10; asym=4.58; tree=(-0.29x3 AND 0.42x4 AND -0.05x2 AND 0.24x0 AND 0.00x0z)
# G> G_1: b=0.28; m=7.15; theta=6.33; init=1.54; noise=0.99; expr=0.83; deg=0.06; asym=7.61; tree=(0.62x0z AND -0.09x3 AND -0.36x4 AND -0.20x1 AND -0.17x0)
# G> G_2: b=2.27; m=1.12; theta=4.26; init=0.66; noise=0.72; expr=1.21; deg=0.08; asym=4.15; tree=(0.30x4 AND -0.50x1 AND 0.51x0z AND 0.21x2 AND 0.05x0)
# G> G_3: b=6.17; m=3.00; theta=5.93; init=0.92; noise=0.98; expr=0.59; deg=0.10; asym=6.05; tree=(0.42x4 AND -0.91x1 AND 0.29x2 AND 0.26x3 AND 0.01x0z)
# G> G_4: b=0.93; m=4.98; theta=7.92; init=0.19; noise=1.28; expr=0.78; deg=0.15; asym=3.22; tree=(0.21x0z AND 0.76x3 AND 0.82x4)
# G> G_5: b=0.97; m=6.26; theta=8.23; init=1.56; noise=0.76; expr=1.15; deg=0.09; asym=5.31; tree=(0.81x2 AND 0.80x1 AND -0.48x3)
# G> G_6: b=0.93; m=0.50; theta=6.62; init=2.26; noise=0.67; expr=1.30; deg=0.08; asym=7.72; tree=(-0.39x3 AND 0.21x1)
# R> tree=(-0.56x0 OR 0.27x2 OR -0.06x3)
# R> tree=(0.77x1z OR 0.90x1 OR 0.09x2)
# R> tree=(-0.81x2 OR 0.85x3 OR 0.17x6 OR 0.13x0 OR 0.14x1z)
# R> tree=(-0.32x2 OR 0.23x7 OR 0.13x0 OR 0.04x5)
# R> tree=(1.00x1z OR -0.65x2 OR 0.01x5 OR 0.10x3)
#
# ======= GENERATION generation_g15 9926.145690217118 =======
# G> G_0: b=1.30; m=8.05; theta=3.38; init=1.14; noise=1.03; expr=1.19; deg=0.10; asym=4.58; tree=(-0.29x3 AND 0.38x4 AND -0.09x2 AND 0.27x0 AND 0.00x0z)
# G> G_1: b=0.28; m=7.15; theta=5.41; init=1.54; noise=0.99; expr=0.84; deg=0.06; asym=7.61; tree=(0.62x0z AND -0.05x3 AND -0.36x4 AND -0.20x1 AND -0.24x0 AND -0.09x2)
# G> G_2: b=2.27; m=1.20; theta=4.26; init=0.66; noise=0.66; expr=1.21; deg=0.08; asym=4.15; tree=(0.27x4 AND -0.50x1 AND 0.51x0z AND 0.21x2 AND 0.05x0)
# G> G_3: b=5.46; m=3.00; theta=5.93; init=0.92; noise=1.02; expr=0.68; deg=0.10; asym=5.76; tree=(0.42x4 AND -0.89x1 AND 0.29x2 AND 0.20x3 AND 0.01x0z)
# G> G_4: b=0.93; m=4.98; theta=7.92; init=0.19; noise=1.28; expr=0.78; deg=0.15; asym=3.39; tree=(0.21x0z AND 0.76x3 AND 0.82x4)
# G> G_5: b=1.03; m=6.59; theta=8.23; init=1.56; noise=0.80; expr=1.15; deg=0.09; asym=5.31; tree=(0.81x2 AND 0.80x1 AND -0.48x3 AND 0.02x4)
# G> G_6: b=0.92; m=0.49; theta=6.62; init=2.28; noise=0.67; expr=1.50; deg=0.08; asym=7.72; tree=(-0.39x3 AND 0.21x1 AND -0.12x0)
# R> tree=(-0.56x0 OR 0.36x2 OR -0.06x3)
# R> tree=(0.82x1z OR 0.90x1 OR 0.09x2)
# R> tree=(-0.81x2 OR 0.75x3 OR 0.17x6 OR 0.31x0 OR 0.14x1z OR 0.01x4)
# R> tree=(-0.32x2 OR 0.13x7 OR 0.13x0 OR 0.04x5)
# R> tree=(0.91x1z OR -0.72x2 OR 0.03x5 OR 0.11x3)
#
# ======= GENERATION generation_g16 9934.064057564057 =======
# G> G_0: b=1.43; m=7.65; theta=3.09; init=1.13; noise=1.22; expr=1.19; deg=0.09; asym=5.50; tree=(-0.29x3 AND 0.29x4 AND 0.24x0)
# G> G_1: b=0.28; m=7.22; theta=7.10; init=1.47; noise=1.00; expr=0.94; deg=0.05; asym=7.50; tree=(0.65x0z AND -0.14x3 AND -0.37x4 AND -0.46x1)
# G> G_2: b=2.30; m=1.25; theta=3.67; init=0.66; noise=1.09; expr=1.21; deg=0.07; asym=4.08; tree=(0.16x4 AND -0.50x1 AND 0.51x0z AND 0.21x2)
# G> G_3: b=6.39; m=3.02; theta=5.47; init=1.00; noise=0.85; expr=0.52; deg=0.10; asym=6.05; tree=(0.53x4 AND -1.00x1 AND 0.40x2 AND 0.17x3 AND 0.03x0z)
# G> G_4: b=1.00; m=5.09; theta=6.56; init=0.22; noise=1.28; expr=0.66; deg=0.13; asym=3.22; tree=(0.34x0z AND 0.77x3 AND 0.82x4 AND -0.20x2)
# G> G_5: b=1.08; m=8.15; theta=9.17; init=1.91; noise=0.76; expr=1.17; deg=0.09; asym=5.66; tree=(0.83x2 AND 0.58x1 AND -0.29x3)
# G> G_6: b=1.22; m=0.51; theta=6.62; init=2.30; noise=0.36; expr=1.30; deg=0.09; asym=7.13; tree=(-0.35x3 AND 0.24x1 AND 0.08x0)
# R> tree=(-0.56x0 OR 0.40x2 OR -0.25x3)
# R> tree=(0.75x1z OR 0.90x1 OR 0.09x2 OR -0.09x3)
# R> tree=(-0.81x2 OR 0.75x3 OR 0.32x6 OR 0.48x0 OR 0.14x1z)
# R> tree=(-0.39x2 OR 0.07x7 OR 0.13x0)
# R> tree=(1.00x1z OR -0.79x2 OR 0.14x3 OR -0.08x0)
#
# ======= GENERATION generation_g17 9940.034849320564 =======
# G> G_0: b=1.26; m=8.05; theta=3.20; init=1.23; noise=1.07; expr=1.26; deg=0.10; asym=4.28; tree=(-0.09x3 AND 0.41x4 AND 0.24x0)
# G> G_1: b=0.28; m=7.94; theta=6.08; init=1.44; noise=0.99; expr=0.92; deg=0.07; asym=7.61; tree=(0.62x0z AND -0.25x4 AND -0.20x1 AND -0.34x0 AND 0.03x3)
# G> G_2: b=2.27; m=0.94; theta=3.98; init=0.71; noise=0.72; expr=1.25; deg=0.10; asym=4.59; tree=(0.35x4 AND -0.50x1 AND 0.45x0z AND 0.09x2 AND 0.06x0)
# G> G_3: b=6.17; m=3.20; theta=5.91; init=0.67; noise=0.98; expr=0.60; deg=0.10; asym=5.67; tree=(0.42x4 AND -0.84x1 AND 0.38x2 AND 0.29x3 AND 0.03x0z)
# G> G_4: b=0.93; m=4.98; theta=7.92; init=0.22; noise=1.28; expr=0.78; deg=0.19; asym=2.62; tree=(0.22x0z AND 0.72x3 AND 0.82x4)
# G> G_5: b=0.97; m=6.93; theta=7.58; init=1.56; noise=0.76; expr=1.15; deg=0.10; asym=4.79; tree=(0.89x2 AND 0.95x1 AND -0.35x3 AND 0.07x0)
# G> G_6: b=0.65; m=0.51; theta=6.70; init=2.44; noise=0.60; expr=1.30; deg=0.08; asym=8.75; tree=(-0.33x3 AND 0.21x1 AND 0.09x0z AND 0.13x2)
# R> tree=(-0.62x0 OR 0.44x2 OR -0.06x3)
# R> tree=(0.77x1z OR 0.90x1 OR 0.09x2)
# R> tree=(-0.74x2 OR 0.85x3 OR 0.17x6 OR -0.17x4 OR -0.09x7)
# R> tree=(-0.32x2 OR 0.22x7 OR 0.21x0 OR 0.25x5)
# R> tree=(0.99x1z OR -0.63x2 OR 0.01x5 OR 0.19x3)
#
# ======= GENERATION generation_g18 9941.533771248058 =======
# G> G_0: b=1.34; m=8.05; theta=3.15; init=1.21; noise=1.07; expr=1.26; deg=0.10; asym=4.28; tree=(-0.21x3 AND 0.41x4 AND 0.24x0)
# G> G_1: b=0.28; m=7.94; theta=6.03; init=1.44; noise=0.99; expr=0.98; deg=0.07; asym=10.72; tree=(0.65x0z AND -0.26x4 AND -0.20x1 AND -0.34x0 AND 0.03x3)
# G> G_2: b=2.03; m=0.94; theta=4.07; init=0.71; noise=0.72; expr=1.25; deg=0.10; asym=4.59; tree=(0.35x4 AND -0.50x1 AND 0.45x0z AND 0.09x2 AND 0.06x0)
# G> G_3: b=6.10; m=3.20; theta=5.91; init=0.67; noise=0.98; expr=0.60; deg=0.10; asym=5.67; tree=(0.34x4 AND -0.74x1 AND 0.36x2 AND 0.29x3 AND 0.03x0z)
# G> G_4: b=0.93; m=4.52; theta=7.92; init=0.22; noise=1.17; expr=0.78; deg=0.19; asym=2.47; tree=(0.22x0z AND 0.72x3 AND 0.82x4 AND -0.17x2)
# G> G_5: b=0.78; m=6.93; theta=7.58; init=1.56; noise=0.75; expr=1.15; deg=0.10; asym=4.79; tree=(0.89x2 AND 1.00x1 AND -0.35x3 AND 0.07x0 AND 0.16x4)
# G> G_6: b=0.65; m=0.51; theta=6.70; init=2.43; noise=0.66; expr=1.54; deg=0.08; asym=8.75; tree=(-0.33x3 AND 0.21x1 AND 0.09x0z AND 0.22x2)
# R> tree=(-0.62x0 OR 0.50x2 OR -0.03x3)
# R> tree=(0.77x1z OR 0.99x1 OR 0.23x2)
# R> tree=(-0.70x2 OR 0.82x3 OR 0.17x6 OR -0.09x7 OR 0.04x5)
# R> tree=(-0.32x2 OR 0.22x7 OR 0.21x0 OR 0.25x5)
# R> tree=(0.97x1z OR -0.68x2 OR 0.11x5 OR 0.19x3)
#
# ======= GENERATION generation_g19 9939.900792257937 =======
# G> G_0: b=1.52; m=7.65; theta=3.09; init=1.13; noise=1.11; expr=1.19; deg=0.08; asym=4.46; tree=(-0.29x3 AND 0.42x4 AND 0.24x0)
# G> G_1: b=0.28; m=6.97; theta=8.05; init=1.21; noise=1.00; expr=0.94; deg=0.05; asym=7.51; tree=(0.65x0z AND -0.02x3 AND -0.26x4 AND -0.50x1 AND 0.40x0)
# G> G_2: b=2.30; m=1.39; theta=3.21; init=0.72; noise=1.09; expr=1.21; deg=0.06; asym=4.08; tree=(0.16x4 AND -0.50x1 AND 0.51x0z AND 0.21x2)
# G> G_3: b=7.65; m=3.17; theta=5.47; init=1.05; noise=0.88; expr=0.52; deg=0.10; asym=6.05; tree=(0.53x4 AND -1.00x1 AND 0.37x2 AND 0.08x3 AND 0.26x0z AND -0.03x0)
# G> G_4: b=1.09; m=5.60; theta=6.56; init=0.24; noise=1.51; expr=0.72; deg=0.13; asym=2.88; tree=(0.46x0z AND 0.58x3 AND 0.82x4 AND -0.07x2)
# G> G_5: b=0.86; m=8.12; theta=9.17; init=1.84; noise=0.69; expr=1.17; deg=0.09; asym=5.66; tree=(0.80x2 AND 0.71x1 AND -0.41x3 AND -0.08x4 AND 0.11x0z)
# G> G_6: b=0.86; m=0.51; theta=5.76; init=1.91; noise=0.30; expr=1.30; deg=0.09; asym=6.90; tree=(-0.24x3 AND 0.23x1 AND 0.20x0)
# R> tree=(-0.60x0 OR 0.37x2 OR -0.28x3 OR -0.05x4)
# R> tree=(0.72x1z OR 0.84x1 OR 0.08x2 OR -0.30x3)
# R> tree=(-0.81x2 OR 0.84x3 OR 0.12x6 OR 0.53x0 OR 0.12x1z)
# R> tree=(-0.63x2 OR 0.07x7)
# R> tree=(1.00x1z OR -0.65x2 OR 0.22x3 OR -0.08x0 OR 0.06x7)
#
# ======= GENERATION generation_g20 9938.137216065787 =======
# G> G_0: b=1.42; m=8.05; theta=2.96; init=1.36; noise=1.08; expr=1.32; deg=0.10; asym=3.81; tree=(-0.09x3 AND 0.41x4 AND 0.24x0)
# G> G_1: b=0.28; m=8.15; theta=6.66; init=1.40; noise=0.96; expr=1.06; deg=0.08; asym=7.94; tree=(0.61x0z AND -0.26x4 AND -0.23x1 AND -0.42x0 AND 0.03x3)
# G> G_2: b=1.77; m=0.86; theta=2.49; init=0.78; noise=0.72; expr=1.25; deg=0.11; asym=4.59; tree=(0.18x4 AND -0.48x1 AND 0.45x0z AND 0.06x0)
# G> G_3: b=4.94; m=3.20; theta=6.33; init=0.68; noise=1.00; expr=0.53; deg=0.09; asym=5.67; tree=(0.42x4 AND -0.74x1 AND 0.40x2 AND 0.41x3 AND 0.03x0z)
# G> G_4: b=0.80; m=4.98; theta=7.92; init=0.22; noise=1.28; expr=0.78; deg=0.19; asym=2.62; tree=(0.22x0z AND 0.72x3 AND 0.82x4)
# G> G_5: b=0.97; m=6.93; theta=7.58; init=1.56; noise=0.76; expr=1.11; deg=0.10; asym=4.79; tree=(0.83x2 AND 0.95x1 AND -0.38x3 AND 0.07x0 AND -0.02x4)
# G> G_6: b=0.65; m=0.51; theta=6.70; init=2.32; noise=0.59; expr=1.30; deg=0.08; asym=10.15; tree=(-0.33x3 AND 0.02x1 AND 0.20x2 AND 0.09x4)
# R> tree=(-0.62x0 OR 0.44x2)
# R> tree=(0.78x1z OR 0.90x1 OR 0.09x2)
# R> tree=(-0.74x2 OR 0.85x3 OR 0.12x6 OR -0.16x4 OR -0.11x7)
# R> tree=(-0.42x2 OR 0.23x7 OR 0.21x0 OR 0.10x5 OR 0.07x1z)
# R> tree=(1.00x1z OR -0.58x2 OR 0.08x5 OR 0.19x3)

# %%
GRNMain(7, 5, 1).copy()
# Out:
# G> G_0: b=0.55; m=8.79; theta=6.80; init=9.61; noise=1.08; expr=2.45; deg=3.28; asym=7.72; tree=(-0.51x4)
# G> G_1: b=0.26; m=7.13; theta=6.00; init=3.75; noise=0.18; expr=2.10; deg=3.27; asym=3.23; tree=(0.85x0z)
# G> G_2: b=1.22; m=4.95; theta=3.48; init=2.68; noise=1.06; expr=0.79; deg=1.46; asym=3.70; tree=(-0.75x0)
# G> G_3: b=0.68; m=0.04; theta=6.78; init=3.46; noise=4.03; expr=2.03; deg=4.35; asym=6.45; tree=()
# G> G_4: b=0.08; m=6.52; theta=3.14; init=7.74; noise=2.80; expr=1.02; deg=8.24; asym=9.77; tree=(0.53x2)
# G> G_5: b=0.32; m=9.03; theta=7.65; init=6.56; noise=1.51; expr=1.49; deg=1.14; asym=6.96; tree=(-0.99x1 AND -0.03x0 AND 0.14x0z)
# G> G_6: b=1.77; m=7.74; theta=5.20; init=9.27; noise=4.80; expr=0.41; deg=1.38; asym=2.06; tree=()
# R> tree=()
# R> tree=(0.88x2 OR -0.43x3 OR -0.84x0)
# R> tree=(-0.53x2 OR 0.73x1z OR 0.20x7)
# R> tree=()
# R> tree=(-0.39x4 OR -0.57x6 OR -0.57x5)
