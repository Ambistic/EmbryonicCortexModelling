# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn import GRNMain
from lib.sde.mutate import SparseMutator

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time
from jf.utils.helper import provide_id

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")
_MUTATE_FUNC = SparseMutator()

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(7, 5, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 10000 - 1 * delta_late - 0.5 * delta_early)

# %%
def hook_event_handler(cell_program):
    # prob **2 and **4
    q = np.array(cell_program.quantities)
    if random() < (q[0] / 2)**4:  # missing a reset
        cell_program.quantities = cell_program.quantities.at[0].set(0)
        return Action.Divide, GRNCell.Progenitor
    
    if random() < (q[1] / 2)**1.5 * (1 - q[2] / 2)**1.5:
        return Action.DiffNeuron, GRNCell.PostMitoticInfra
    
    if random() < (q[2] / 2)**1.5 * (1 - q[1] / 2)**1.5:
        return Action.DiffNeuron, GRNCell.PostMitoticSupra
    
    return Action.NoOp, None

# %%
def get_bb(prun, grn):
    from submodels.grn_auto_v1 import GRNCell
    ccls = factories["grn_auto1"](grn=grn, hooks=dict(event_handler=hook_event_handler))
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=50, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks)
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def fitness_step(prun, grn, step):
    bb = get_bb(prun, grn)
    bb.run_until(step.end_time)
    score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
    fitness = 1.0 / score_step
        
    return fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_step(prun, sol.grn, prun.step)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_step = ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2)

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 20
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.step = example_step
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if batch_gen == prun.n_gen:
        print("Already finished")
        return
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // prun.batch_size
            exporter(pop[-prun.batch_size:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "test_refacto3"
res = main(prun)
# Out:
# Exporting at output/test_refacto3
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 9871.00315900316 for generation 0
# [out] ++ Best 9871.462342676628 for generation 2
# [out] ++ Best 9881.553853482426 for generation 13
# [out] ++ Best 9887.217118788549 for generation 28
# [out] ++ Best 9907.533771248058 for generation 29
# Saving ...
# [out] ++ Best 9917.064057564057 for generation 84
# [out] ++ Best 9921.15622022765 for generation 87
# Saving ...
# [out] Step 100
# [out] ++ Best 9925.023567166423 for generation 130
# Saving ...
# [out] ++ Best 9936.341297698442 for generation 163
# Saving ...
# [out] Step 200
# Saving ...
# [out] ++ Best 9939.086195657623 for generation 286
# Saving ...
# [out] Step 300
# [out] ++ Best 9951.24913503485 for generation 315
# Saving ...
# [out] ++ Best 9953.584465727323 for generation 359
# Saving ...
# [out] Step 400
# Saving ...
# Saving ...
# [out] Step 500
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# [out] ++ Best 9959.361379932809 for generation 706
# [out] ++ Best 9961.43173043173 for generation 710
# Saving ...
# [out] ++ Best 9962.237526951812 for generation 780
# Saving ...
# [out] Step 800
# [out] ++ Best 9969.574587574587 for generation 801
# [out] ++ Best 9971.023241237528 for generation 845
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/test_refacto3

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load("generation_g10"))
res = pick_best(exp.load(pick_last(exp)))

# %%
res.fit
# Out:
# 9970.166098380383

# %%
# for i in range(5):
#     print(fitness_multistep(prun, res.grn, prun.steps))

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} {res.fit} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g1 9907.533771248058 =======
# G> G_0: b=3.78; m=8.55; theta=3.92; init=1.00; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=()
# G> G_1: b=1.71; m=0.85; theta=7.77; init=0.45; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(-0.98x4 AND 0.72x1 AND 0.53x3)
# G> G_2: b=0.61; m=3.00; theta=1.96; init=0.85; noise=0.85; expr=0.95; deg=0.10; asym=5.00; tree=(0.25x0z AND -0.77x4 AND -0.18x0)
# G> G_3: b=1.25; m=9.36; theta=9.51; init=1.07; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(0.43x3 AND -0.30x4 AND -0.95x2)
# G> G_4: b=1.58; m=9.34; theta=4.42; init=1.52; noise=0.88; expr=1.00; deg=0.10; asym=5.00; tree=(-0.63x4)
# G> G_5: b=1.48; m=3.39; theta=5.49; init=2.46; noise=1.00; expr=1.00; deg=0.10; asym=5.66; tree=(0.49x2 AND 0.57x0z AND 0.09x0)
# G> G_6: b=1.99; m=6.65; theta=1.19; init=1.80; noise=1.04; expr=1.00; deg=0.11; asym=5.00; tree=(-0.51x3)
# R> tree=(0.12x1 OR -0.84x0 OR -0.37x4)
# R> tree=(0.86x2 OR -0.62x4 OR 0.60x3)
# R> tree=(-0.71x0 OR 0.68x5)
# R> tree=(0.28x2)
# R> tree=(-0.09x1 OR 0.86x1z)
#
# ======= GENERATION generation_g2 9921.15622022765 =======
# G> G_0: b=3.78; m=8.55; theta=3.49; init=1.00; noise=1.11; expr=1.00; deg=0.10; asym=5.03; tree=()
# G> G_1: b=1.71; m=0.85; theta=7.77; init=0.45; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(-0.98x4 AND 0.72x1 AND 0.53x3)
# G> G_2: b=0.61; m=3.00; theta=1.96; init=0.72; noise=1.04; expr=0.95; deg=0.10; asym=5.00; tree=(0.25x0z AND -0.77x4 AND -0.18x0 AND -0.01x3)
# G> G_3: b=1.25; m=9.36; theta=9.51; init=1.07; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(0.50x3 AND -0.30x4 AND -0.95x2)
# G> G_4: b=1.58; m=9.34; theta=4.48; init=1.52; noise=0.88; expr=1.00; deg=0.10; asym=5.00; tree=(-0.63x4)
# G> G_5: b=1.48; m=3.39; theta=5.50; init=2.46; noise=0.96; expr=1.00; deg=0.10; asym=5.66; tree=(0.45x2 AND 0.53x0z AND 0.09x0)
# G> G_6: b=1.99; m=6.65; theta=1.05; init=1.62; noise=1.04; expr=1.00; deg=0.11; asym=5.00; tree=(-0.42x3)
# R> tree=(0.12x1 OR -0.84x0 OR -0.15x4)
# R> tree=(0.86x2 OR -0.51x4 OR 0.60x3)
# R> tree=(-0.71x0 OR 0.79x5)
# R> tree=(0.28x2)
# R> tree=(-0.09x1 OR 0.86x1z)
#
# ======= GENERATION generation_g3 9925.023567166423 =======
# G> G_0: b=3.78; m=8.55; theta=3.49; init=1.00; noise=1.11; expr=1.00; deg=0.10; asym=5.03; tree=(-0.02x3)
# G> G_1: b=1.71; m=0.85; theta=6.93; init=0.45; noise=1.06; expr=1.00; deg=0.10; asym=5.00; tree=(-0.98x4 AND 0.72x1 AND 0.53x3 AND -0.17x0)
# G> G_2: b=0.61; m=3.00; theta=1.96; init=0.72; noise=1.04; expr=0.99; deg=0.11; asym=5.00; tree=(0.16x0z AND -0.85x4 AND -0.18x0 AND -0.01x3)
# G> G_3: b=1.25; m=9.36; theta=7.33; init=0.94; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(0.42x3 AND -0.30x4 AND -0.80x2)
# G> G_4: b=1.58; m=9.45; theta=4.48; init=1.52; noise=0.83; expr=1.00; deg=0.10; asym=5.00; tree=(-0.63x4)
# G> G_5: b=1.48; m=3.39; theta=5.50; init=2.46; noise=0.96; expr=1.00; deg=0.10; asym=5.66; tree=(0.45x2 AND 0.53x0z AND 0.09x0)
# G> G_6: b=1.99; m=6.65; theta=1.05; init=1.55; noise=1.04; expr=1.00; deg=0.11; asym=5.33; tree=(-0.42x3 AND 0.06x1)
# R> tree=(0.12x1 OR -0.84x0 OR -0.15x4 OR 0.08x6)
# R> tree=(0.88x2 OR -0.51x4 OR 0.60x3)
# R> tree=(-0.71x0 OR 0.69x5)
# R> tree=(0.28x2)
# R> tree=(-0.09x1 OR 0.86x1z)
#
# ======= GENERATION generation_g4 9936.341297698442 =======
# G> G_0: b=3.78; m=8.55; theta=3.73; init=1.00; noise=1.11; expr=0.92; deg=0.10; asym=5.03; tree=(-0.00x0)
# G> G_1: b=1.90; m=0.81; theta=7.77; init=0.42; noise=0.99; expr=1.14; deg=0.09; asym=3.74; tree=(-0.98x4 AND 0.72x1 AND 0.53x3)
# G> G_2: b=0.61; m=3.00; theta=1.96; init=0.68; noise=0.85; expr=0.97; deg=0.09; asym=5.00; tree=(0.25x0z AND -0.78x4 AND -0.03x0)
# G> G_3: b=1.38; m=9.36; theta=9.51; init=1.12; noise=1.00; expr=0.91; deg=0.10; asym=5.00; tree=(0.50x3 AND -0.30x4 AND -0.84x2)
# G> G_4: b=1.58; m=9.34; theta=4.45; init=1.50; noise=0.88; expr=1.00; deg=0.12; asym=6.43; tree=(-0.63x4 AND -0.11x3 AND -0.02x1)
# G> G_5: b=1.48; m=3.39; theta=5.73; init=3.09; noise=0.96; expr=1.04; deg=0.10; asym=5.66; tree=(0.45x2 AND 0.47x0z AND 0.14x0)
# G> G_6: b=2.21; m=6.65; theta=0.99; init=1.91; noise=0.93; expr=1.00; deg=0.11; asym=6.43; tree=(-0.42x3 AND 0.10x0)
# R> tree=(0.12x1 OR -0.84x0 OR -0.08x4)
# R> tree=(0.92x2 OR -0.36x4 OR 0.63x3 OR 0.11x6)
# R> tree=(-1.00x0 OR 0.79x5)
# R> tree=(0.28x2)
# R> tree=(-0.09x1 OR 0.75x1z OR 0.09x4)
#
# ======= GENERATION generation_g5 9936.034849320564 =======
# G> G_0: b=3.78; m=8.55; theta=3.37; init=1.00; noise=1.33; expr=1.00; deg=0.10; asym=4.93; tree=()
# G> G_1: b=1.74; m=0.72; theta=7.34; init=0.45; noise=1.00; expr=0.86; deg=0.10; asym=5.08; tree=(-0.97x4 AND 0.72x1 AND 0.54x3)
# G> G_2: b=0.61; m=3.00; theta=2.09; init=0.77; noise=1.01; expr=0.90; deg=0.10; asym=5.52; tree=(0.31x0z AND -0.77x4 AND -0.18x0)
# G> G_3: b=1.13; m=7.27; theta=9.90; init=1.05; noise=0.95; expr=1.00; deg=0.11; asym=5.48; tree=(0.50x3 AND -0.32x4 AND -0.89x2)
# G> G_4: b=1.56; m=8.31; theta=4.48; init=1.25; noise=0.88; expr=0.95; deg=0.09; asym=4.75; tree=(-0.63x4)
# G> G_5: b=1.38; m=3.39; theta=5.89; init=2.39; noise=0.96; expr=0.94; deg=0.10; asym=5.87; tree=(0.45x2 AND 0.51x0z AND 0.05x0)
# G> G_6: b=1.80; m=8.07; theta=1.16; init=1.94; noise=1.19; expr=0.76; deg=0.09; asym=5.00; tree=(-0.55x3 AND 0.25x2)
# R> tree=(0.09x1 OR -0.91x0 OR -0.26x4 OR 0.01x1z)
# R> tree=(0.81x2 OR -0.34x4 OR 0.60x3)
# R> tree=(-0.71x0 OR 0.89x5)
# R> tree=(0.25x2)
# R> tree=(-0.09x1 OR 1.00x1z OR -0.01x5)
#
# ======= GENERATION generation_g6 9939.086195657623 =======
# G> G_0: b=3.40; m=9.20; theta=3.37; init=1.00; noise=1.33; expr=1.00; deg=0.10; asym=4.93; tree=()
# G> G_1: b=1.43; m=0.72; theta=8.44; init=0.45; noise=1.00; expr=0.86; deg=0.10; asym=5.08; tree=(-0.97x4 AND 0.79x1 AND 0.45x3 AND 0.03x0z)
# G> G_2: b=0.61; m=2.81; theta=2.28; init=0.71; noise=1.06; expr=0.90; deg=0.10; asym=5.52; tree=(0.31x0z AND -0.77x4 AND -0.18x0)
# G> G_3: b=1.13; m=6.32; theta=9.90; init=1.05; noise=0.95; expr=1.09; deg=0.11; asym=5.48; tree=(0.57x3 AND -0.17x4 AND -0.89x2)
# G> G_4: b=1.37; m=8.31; theta=4.48; init=1.25; noise=0.88; expr=1.05; deg=0.09; asym=5.52; tree=(-0.63x4)
# G> G_5: b=1.38; m=3.39; theta=4.89; init=2.71; noise=0.96; expr=0.92; deg=0.11; asym=5.87; tree=(0.54x2 AND 0.51x0z AND 0.05x0)
# G> G_6: b=1.79; m=6.95; theta=1.20; init=1.73; noise=1.05; expr=0.76; deg=0.10; asym=5.29; tree=(-0.55x3 AND 0.25x2)
# R> tree=(0.13x1 OR -0.91x0 OR -0.26x4 OR 0.01x1z)
# R> tree=(0.75x2 OR -0.36x4 OR 0.60x3)
# R> tree=(-0.71x0 OR 0.89x5)
# R> tree=(0.20x2)
# R> tree=(-0.09x1 OR 1.00x1z OR 0.04x7)
#
# ======= GENERATION generation_g7 9951.24913503485 =======
# G> G_0: b=3.40; m=9.02; theta=3.27; init=1.00; noise=1.33; expr=1.00; deg=0.10; asym=4.93; tree=()
# G> G_1: b=1.74; m=0.72; theta=8.44; init=0.45; noise=1.09; expr=0.79; deg=0.10; asym=5.08; tree=(-0.97x4 AND 0.60x1 AND 0.43x3 AND 0.09x0z)
# G> G_2: b=0.56; m=2.55; theta=2.53; init=0.77; noise=1.01; expr=0.90; deg=0.10; asym=5.52; tree=(0.31x0z AND -0.77x4 AND -0.18x0)
# G> G_3: b=1.21; m=7.91; theta=10.28; init=1.05; noise=1.03; expr=1.07; deg=0.11; asym=6.56; tree=(0.56x3 AND -0.32x4 AND -0.89x2 AND 0.03x1)
# G> G_4: b=1.56; m=8.31; theta=4.48; init=1.25; noise=0.88; expr=0.95; deg=0.09; asym=4.75; tree=(-0.63x4)
# G> G_5: b=1.32; m=3.10; theta=5.63; init=2.73; noise=0.96; expr=0.94; deg=0.11; asym=5.87; tree=(0.44x2 AND 0.51x0z AND 0.05x0)
# G> G_6: b=1.80; m=8.07; theta=1.20; init=1.73; noise=1.05; expr=0.87; deg=0.10; asym=5.98; tree=(-0.55x3 AND 0.27x2)
# R> tree=(0.12x1 OR -0.91x0 OR -0.26x4)
# R> tree=(0.81x2 OR -0.34x4 OR 0.63x3 OR -0.04x5)
# R> tree=(-0.67x0 OR 0.98x5)
# R> tree=(0.20x2 OR -0.11x4)
# R> tree=(-0.09x1 OR 1.00x1z OR -0.01x7)
#
# ======= GENERATION generation_g8 9953.584465727323 =======
# G> G_0: b=3.79; m=9.20; theta=3.37; init=1.01; noise=1.12; expr=1.04; deg=0.10; asym=5.23; tree=()
# G> G_1: b=1.43; m=0.76; theta=8.44; init=0.48; noise=1.00; expr=0.84; deg=0.11; asym=5.08; tree=(-0.96x4 AND 1.00x1 AND 0.45x3 AND 0.03x0z)
# G> G_2: b=0.61; m=2.81; theta=2.45; init=0.76; noise=0.96; expr=0.90; deg=0.10; asym=5.44; tree=(0.13x0z AND -0.72x4 AND -0.18x0 AND -0.07x3)
# G> G_3: b=1.13; m=6.32; theta=9.90; init=0.98; noise=0.95; expr=1.00; deg=0.11; asym=5.48; tree=(0.55x3 AND -0.26x4 AND -0.89x2)
# G> G_4: b=1.36; m=8.31; theta=5.17; init=1.25; noise=0.88; expr=1.10; deg=0.09; asym=5.52; tree=(-0.63x4 AND 0.15x3)
# G> G_5: b=1.38; m=3.49; theta=3.75; init=2.71; noise=0.96; expr=0.92; deg=0.11; asym=5.87; tree=(0.54x2 AND 0.62x0z AND 0.03x3)
# G> G_6: b=1.79; m=6.95; theta=1.17; init=1.71; noise=1.05; expr=0.71; deg=0.10; asym=5.29; tree=(-0.55x3 AND 0.31x2)
# R> tree=(0.34x1 OR -0.91x0 OR -0.26x4 OR 0.01x1z)
# R> tree=(0.98x2 OR -0.41x4 OR 0.60x3)
# R> tree=(-0.71x0 OR 0.89x5 OR 0.22x1)
# R> tree=(0.20x2)
# R> tree=(-0.28x1 OR 1.00x1z OR 0.04x7 OR -0.29x2)
#
# ======= GENERATION generation_g9 9938.229052800481 =======
# G> G_0: b=2.87; m=7.96; theta=3.36; init=1.03; noise=1.33; expr=1.00; deg=0.10; asym=3.49; tree=()
# G> G_1: b=2.00; m=0.61; theta=8.44; init=0.37; noise=0.89; expr=0.86; deg=0.11; asym=5.08; tree=(-1.00x4 AND 0.76x1 AND 0.48x3)
# G> G_2: b=0.60; m=3.14; theta=2.52; init=0.77; noise=1.12; expr=0.84; deg=0.11; asym=6.75; tree=(0.30x0z AND -0.77x4)
# G> G_3: b=1.20; m=7.27; theta=10.66; init=0.92; noise=1.06; expr=1.09; deg=0.11; asym=5.26; tree=(0.67x3 AND -0.35x4 AND -0.89x2 AND 0.01x1)
# G> G_4: b=1.56; m=8.31; theta=4.48; init=1.25; noise=0.88; expr=0.95; deg=0.08; asym=5.00; tree=(-0.63x4)
# G> G_5: b=1.39; m=3.39; theta=5.15; init=2.56; noise=0.93; expr=0.92; deg=0.11; asym=5.98; tree=(0.64x2 AND 0.51x0z AND -0.20x4 AND -0.05x1)
# G> G_6: b=1.57; m=7.55; theta=1.22; init=1.73; noise=0.80; expr=0.76; deg=0.10; asym=5.43; tree=(-0.38x3 AND 0.33x2)
# R> tree=(0.13x1 OR -0.80x0 OR -0.18x4)
# R> tree=(0.75x2 OR -0.38x4 OR 0.94x3)
# R> tree=(-0.78x0 OR 0.78x5)
# R> tree=(0.20x2)
# R> tree=(-0.09x1 OR 0.90x1z OR -0.01x5)
#
# ======= GENERATION generation_g10 9950.482750839894 =======
# G> G_0: b=3.92; m=7.95; theta=3.37; init=1.01; noise=1.23; expr=1.04; deg=0.10; asym=5.23; tree=()
# G> G_1: b=1.43; m=0.76; theta=7.91; init=0.48; noise=1.04; expr=0.84; deg=0.13; asym=5.08; tree=(-0.96x4 AND 1.00x1 AND 0.45x3 AND 0.03x0z)
# G> G_2: b=0.64; m=3.40; theta=2.25; init=0.91; noise=0.96; expr=0.90; deg=0.12; asym=5.57; tree=(-0.72x4 AND -0.44x0 AND -0.07x3)
# G> G_3: b=1.22; m=6.96; theta=10.38; init=0.99; noise=0.95; expr=0.86; deg=0.11; asym=5.48; tree=(0.55x3 AND -0.15x4 AND -0.89x2)
# G> G_4: b=1.26; m=9.58; theta=5.17; init=1.25; noise=0.58; expr=1.10; deg=0.09; asym=5.52; tree=(-0.59x4 AND 0.34x3)
# G> G_5: b=1.55; m=3.49; theta=3.05; init=2.45; noise=0.80; expr=0.81; deg=0.11; asym=5.65; tree=(0.44x2 AND 0.66x0z AND 0.07x3 AND 0.10x4)
# G> G_6: b=1.63; m=6.48; theta=1.30; init=1.67; noise=1.05; expr=0.71; deg=0.11; asym=5.29; tree=(-0.61x3 AND 0.29x2)
# R> tree=(0.34x1 OR -1.00x0 OR -0.28x4 OR 0.01x1z OR -0.21x2)
# R> tree=(0.74x2 OR -0.41x4 OR 0.60x3)
# R> tree=(-0.71x0 OR 0.89x5 OR 0.29x1)
# R> tree=(0.20x2)
# R> tree=(-0.39x1 OR 0.89x1z OR 0.04x7 OR -0.29x2 OR 0.08x6 OR 0.22x4)
#
# ======= GENERATION generation_g11 9941.910996339568 =======
# G> G_0: b=3.92; m=7.95; theta=3.37; init=0.84; noise=1.37; expr=1.04; deg=0.10; asym=5.23; tree=()
# G> G_1: b=1.43; m=0.76; theta=7.10; init=0.47; noise=1.04; expr=0.79; deg=0.14; asym=5.08; tree=(-0.96x4 AND 1.00x1 AND 0.65x3)
# G> G_2: b=0.67; m=3.40; theta=2.39; init=0.94; noise=1.04; expr=0.90; deg=0.12; asym=5.63; tree=(-0.72x4 AND -0.55x0 AND -0.07x3)
# G> G_3: b=1.18; m=6.96; theta=11.81; init=0.88; noise=0.98; expr=1.05; deg=0.11; asym=4.92; tree=(0.55x3 AND -0.18x4 AND -0.89x2)
# G> G_4: b=1.26; m=9.58; theta=5.17; init=1.28; noise=0.56; expr=1.10; deg=0.09; asym=5.52; tree=(-0.59x4 AND 0.34x3)
# G> G_5: b=1.69; m=3.26; theta=3.05; init=2.18; noise=0.81; expr=0.81; deg=0.09; asym=5.65; tree=(0.52x2 AND 0.66x0z AND 0.07x3 AND 0.01x4)
# G> G_6: b=1.63; m=6.90; theta=1.42; init=1.67; noise=1.12; expr=0.70; deg=0.08; asym=5.29; tree=(-0.57x3 AND 0.29x2 AND 0.06x4)
# R> tree=(0.34x1 OR -0.99x0 OR -0.28x4 OR -0.16x2)
# R> tree=(0.74x2 OR -0.48x4 OR 0.60x3)
# R> tree=(-0.77x0 OR 1.00x5 OR 0.21x1 OR -0.19x4)
# R> tree=(0.39x2)
# R> tree=(-0.39x1 OR 0.85x1z OR 0.04x7 OR -0.26x2 OR 0.12x6 OR 0.22x4)
#
# ======= GENERATION generation_g12 9949.931404502833 =======
# G> G_0: b=3.17; m=8.95; theta=3.39; init=1.11; noise=1.31; expr=1.15; deg=0.10; asym=4.67; tree=(-0.00x1)
# G> G_1: b=2.06; m=0.69; theta=7.71; init=0.51; noise=0.92; expr=0.86; deg=0.12; asym=6.14; tree=(-1.00x4 AND 0.61x1 AND 0.78x3 AND 0.14x0z)
# G> G_2: b=0.58; m=2.82; theta=2.02; init=0.65; noise=1.06; expr=0.90; deg=0.09; asym=5.67; tree=(0.31x0z AND -0.77x4 AND -0.12x0)
# G> G_3: b=1.29; m=7.66; theta=9.90; init=1.26; noise=0.65; expr=1.11; deg=0.12; asym=5.25; tree=(0.57x3 AND -0.52x4 AND -1.00x2 AND 0.02x0)
# G> G_4: b=1.56; m=9.23; theta=4.30; init=1.49; noise=0.73; expr=0.95; deg=0.07; asym=4.17; tree=(-0.63x4)
# G> G_5: b=1.47; m=3.79; theta=6.58; init=2.71; noise=0.99; expr=0.93; deg=0.10; asym=5.78; tree=(0.68x2 AND 0.44x0z AND 0.02x0 AND -0.04x4)
# G> G_6: b=2.01; m=8.79; theta=1.28; init=2.00; noise=1.05; expr=0.73; deg=0.09; asym=4.68; tree=(-0.32x3 AND 0.44x2 AND -0.09x0 AND 0.05x4)
# R> tree=(-0.94x0 OR -0.32x4 OR 0.20x1z OR 0.35x6 OR 0.05x2)
# R> tree=(0.84x2 OR -0.52x4 OR 0.60x3)
# R> tree=(-0.38x0 OR 1.00x5 OR -0.01x7)
# R> tree=(0.20x2)
# R> tree=(-0.05x1 OR 1.00x1z OR -0.22x5)
#
# ======= GENERATION generation_g13 9945.298751441609 =======
# G> G_0: b=3.92; m=7.29; theta=3.37; init=0.92; noise=1.20; expr=1.27; deg=0.10; asym=5.23; tree=(-0.10x1)
# G> G_1: b=1.34; m=0.78; theta=7.91; init=0.47; noise=1.04; expr=0.82; deg=0.13; asym=4.76; tree=(-1.00x4 AND 1.00x1 AND 0.45x3 AND 0.10x0z)
# G> G_2: b=0.64; m=3.63; theta=2.25; init=0.94; noise=0.90; expr=1.03; deg=0.12; asym=5.75; tree=(-0.72x4 AND -0.32x0)
# G> G_3: b=1.41; m=6.96; theta=9.13; init=0.99; noise=1.10; expr=0.77; deg=0.11; asym=4.88; tree=(0.53x3 AND -0.39x4 AND -0.89x2)
# G> G_4: b=1.41; m=9.18; theta=5.33; init=1.17; noise=0.48; expr=0.99; deg=0.09; asym=5.52; tree=(-0.59x4 AND 0.34x3)
# G> G_5: b=1.55; m=3.49; theta=3.08; init=2.36; noise=0.80; expr=0.75; deg=0.10; asym=5.02; tree=(0.51x2 AND 0.66x0z AND 0.24x3 AND -0.05x0 AND 0.06x4 AND 0.06x1)
# G> G_6: b=1.84; m=6.71; theta=1.47; init=1.36; noise=1.20; expr=0.71; deg=0.11; asym=5.82; tree=(-0.56x3 AND 0.29x2)
# R> tree=(0.34x1 OR -1.00x0 OR -0.28x4 OR -0.21x2)
# R> tree=(0.72x2 OR -0.50x4 OR 0.60x3)
# R> tree=(-0.67x0 OR 0.90x5 OR 0.28x1 OR 0.05x1z)
# R> tree=(0.20x2 OR 0.06x7 OR 0.03x3 OR 0.00x1z)
# R> tree=(-0.58x1 OR 1.00x1z OR 0.02x7 OR -0.29x2 OR 0.08x6 OR 0.22x4)
#
# ======= GENERATION generation_g14 9939.870180013037 =======
# G> G_0: b=3.92; m=7.95; theta=3.24; init=0.80; noise=1.27; expr=1.04; deg=0.11; asym=5.64; tree=()
# G> G_1: b=1.43; m=0.76; theta=8.47; init=0.58; noise=1.04; expr=0.56; deg=0.15; asym=5.22; tree=(-0.84x4 AND 0.90x1 AND 0.65x3)
# G> G_2: b=0.67; m=4.01; theta=2.39; init=0.94; noise=1.24; expr=0.90; deg=0.13; asym=5.63; tree=(-0.65x4 AND -0.56x0 AND 0.01x1)
# G> G_3: b=1.25; m=6.64; theta=9.79; init=0.86; noise=0.98; expr=1.05; deg=0.09; asym=4.92; tree=(0.54x3 AND -0.18x4 AND -0.89x2)
# G> G_4: b=1.14; m=9.58; theta=5.20; init=1.10; noise=0.55; expr=1.07; deg=0.07; asym=5.52; tree=(-0.69x4 AND 0.33x3)
# G> G_5: b=1.69; m=2.82; theta=3.05; init=2.11; noise=0.63; expr=0.88; deg=0.10; asym=6.15; tree=(0.56x2 AND 0.60x0z AND 0.09x3 AND 0.01x4)
# G> G_6: b=1.63; m=5.67; theta=1.30; init=1.67; noise=1.10; expr=0.70; deg=0.08; asym=5.22; tree=(-0.63x3 AND 0.35x2 AND 0.08x4)
# R> tree=(0.50x1 OR -0.86x0 OR -0.19x4 OR -0.33x2 OR -0.10x7)
# R> tree=(0.72x2 OR -0.48x4 OR 0.59x3 OR -0.01x7 OR -0.16x6)
# R> tree=(-1.00x0 OR 0.92x5 OR 0.31x1 OR -0.19x4 OR 0.07x1z)
# R> tree=(0.57x2)
# R> tree=(-0.39x1 OR 0.85x1z OR -0.26x2 OR 0.30x6 OR 0.22x4 OR -0.08x0 OR 0.22x7)
#
# ======= GENERATION generation_g15 9961.43173043173 =======
# G> G_0: b=4.15; m=6.39; theta=3.28; init=1.02; noise=1.17; expr=1.33; deg=0.09; asym=5.23; tree=(0.02x1)
# G> G_1: b=1.52; m=0.94; theta=8.53; init=0.46; noise=1.27; expr=0.67; deg=0.12; asym=5.27; tree=(-0.56x4 AND 0.84x1 AND 0.41x3 AND 0.22x0z)
# G> G_2: b=0.60; m=3.33; theta=2.18; init=0.91; noise=0.96; expr=1.10; deg=0.11; asym=4.63; tree=(-0.72x4 AND -0.49x0 AND 0.06x3)
# G> G_3: b=1.16; m=6.95; theta=9.56; init=1.11; noise=0.78; expr=0.87; deg=0.14; asym=4.68; tree=(0.53x3 AND -0.17x4 AND -0.87x2)
# G> G_4: b=1.24; m=8.62; theta=5.35; init=1.35; noise=0.64; expr=1.10; deg=0.08; asym=5.18; tree=(-0.49x4 AND 0.30x3 AND -0.14x1 AND 0.22x0z AND -0.04x2)
# G> G_5: b=1.85; m=3.76; theta=3.64; init=2.57; noise=0.78; expr=0.72; deg=0.12; asym=6.43; tree=(0.28x2 AND 0.59x0z AND 0.11x3 AND 0.10x4 AND -0.03x1)
# G> G_6: b=1.63; m=5.93; theta=1.50; init=1.67; noise=1.16; expr=0.71; deg=0.09; asym=4.47; tree=(-0.42x3 AND 0.20x2)
# R> tree=(0.56x1 OR -1.00x0 OR 0.08x1z OR -0.29x2)
# R> tree=(0.84x2 OR -0.22x4 OR 0.68x3)
# R> tree=(-0.68x0 OR 0.93x5 OR 0.40x1 OR 0.00x3 OR 0.27x7)
# R> tree=(0.02x2)
# R> tree=(-0.51x1 OR 1.00x1z OR -0.29x2 OR 0.22x4)
#
# ======= GENERATION generation_g16 9962.237526951812 =======
# G> G_0: b=4.15; m=7.35; theta=3.28; init=1.02; noise=1.17; expr=1.33; deg=0.09; asym=5.28; tree=(0.08x2)
# G> G_1: b=1.52; m=0.90; theta=10.24; init=0.47; noise=1.34; expr=0.67; deg=0.11; asym=6.53; tree=(-0.56x4 AND 0.77x1 AND 0.55x3 AND 0.43x0z)
# G> G_2: b=0.60; m=3.33; theta=2.26; init=0.87; noise=0.96; expr=1.17; deg=0.11; asym=4.63; tree=(-0.72x4 AND -0.51x0 AND 0.08x3)
# G> G_3: b=1.16; m=7.48; theta=9.56; init=1.18; noise=0.78; expr=0.87; deg=0.13; asym=4.38; tree=(0.53x3 AND -0.17x4 AND -0.88x2)
# G> G_4: b=1.24; m=8.75; theta=5.35; init=1.26; noise=0.65; expr=1.10; deg=0.08; asym=4.86; tree=(-0.49x4 AND 0.24x3 AND -0.14x1 AND 0.22x0z AND -0.04x2)
# G> G_5: b=2.15; m=3.78; theta=3.82; init=2.44; noise=0.71; expr=0.68; deg=0.13; asym=6.43; tree=(0.28x2 AND 0.69x0z AND 0.11x3 AND 0.10x4 AND 0.03x0)
# G> G_6: b=1.63; m=6.32; theta=1.37; init=1.67; noise=1.02; expr=0.71; deg=0.09; asym=4.47; tree=(-0.42x3 AND 0.30x2)
# R> tree=(0.56x1 OR -1.00x0 OR 0.04x1z OR -0.29x2)
# R> tree=(0.72x2 OR -0.10x4 OR 0.91x3)
# R> tree=(-0.75x0 OR 0.97x5 OR 0.43x1 OR 0.00x3 OR 0.36x7)
# R> tree=()
# R> tree=(-0.51x1 OR 1.00x1z OR -0.36x2 OR 0.22x4 OR -0.20x0)
#
# ======= GENERATION generation_g17 9971.023241237528 =======
# G> G_0: b=3.96; m=6.39; theta=3.28; init=1.03; noise=1.21; expr=1.33; deg=0.09; asym=4.52; tree=(0.18x2 AND -0.08x0)
# G> G_1: b=1.41; m=0.64; theta=7.13; init=0.60; noise=1.77; expr=0.65; deg=0.12; asym=6.23; tree=(-0.56x4 AND 0.67x1 AND 0.38x3 AND 0.29x0z AND -0.04x0)
# G> G_2: b=0.56; m=2.79; theta=2.18; init=1.00; noise=0.99; expr=1.31; deg=0.10; asym=3.99; tree=(-0.74x4 AND -0.58x0 AND 0.14x0z)
# G> G_3: b=1.31; m=7.35; theta=11.15; init=1.20; noise=0.86; expr=1.00; deg=0.14; asym=4.19; tree=(0.53x3 AND -0.32x4 AND -0.81x2 AND -0.06x0)
# G> G_4: b=1.41; m=8.62; theta=5.35; init=1.18; noise=0.70; expr=1.01; deg=0.07; asym=4.69; tree=(-0.55x4 AND 0.12x3 AND -0.07x1 AND 0.07x0z AND 0.03x0)
# G> G_5: b=1.86; m=2.99; theta=3.82; init=3.12; noise=0.63; expr=0.61; deg=0.09; asym=6.43; tree=(0.40x2 AND 0.35x0z AND 0.11x3 AND 0.15x4 AND -0.07x1 AND 0.33x0)
# G> G_6: b=1.63; m=6.06; theta=1.10; init=1.76; noise=1.16; expr=0.54; deg=0.09; asym=5.11; tree=(-0.32x3 AND 0.36x2 AND 0.05x0)
# R> tree=(0.73x1 OR -0.93x0 OR 0.17x1z OR -0.50x2)
# R> tree=(0.88x2 OR -0.15x4 OR 0.70x3 OR 0.06x6)
# R> tree=(-0.78x0 OR 1.00x5 OR 0.14x1 OR 0.11x3 OR 0.20x7 OR 0.33x2)
# R> tree=(0.01x2)
# R> tree=(-0.37x1 OR 1.00x1z OR -0.42x2 OR -0.01x7)
#
# ======= GENERATION generation_g18 9967.584465727323 =======
# G> G_0: b=4.23; m=5.70; theta=3.28; init=1.03; noise=1.08; expr=1.33; deg=0.09; asym=4.52; tree=(0.05x2)
# G> G_1: b=1.52; m=0.64; theta=7.13; init=0.54; noise=1.77; expr=0.69; deg=0.12; asym=6.23; tree=(-0.56x4 AND 0.67x1 AND 0.60x3 AND 0.29x0z AND -0.04x0)
# G> G_2: b=0.56; m=2.73; theta=2.18; init=0.96; noise=0.96; expr=1.32; deg=0.10; asym=4.52; tree=(-0.72x4 AND -0.48x0 AND 0.30x3 AND 0.14x0z)
# G> G_3: b=1.31; m=7.08; theta=11.15; init=1.20; noise=0.86; expr=1.00; deg=0.13; asym=4.19; tree=(0.53x3 AND -0.32x4 AND -0.87x2)
# G> G_4: b=1.30; m=8.62; theta=5.35; init=1.22; noise=0.73; expr=1.10; deg=0.07; asym=4.86; tree=(-0.65x4 AND 0.24x3 AND -0.07x1 AND 0.07x0z AND 0.03x0)
# G> G_5: b=1.86; m=3.76; theta=3.17; init=3.12; noise=0.65; expr=0.67; deg=0.10; asym=6.44; tree=(0.40x2 AND 0.49x0z AND 0.11x3 AND 0.15x4 AND -0.07x1 AND 0.31x0)
# G> G_6: b=1.63; m=6.06; theta=1.50; init=1.55; noise=1.16; expr=0.71; deg=0.09; asym=5.11; tree=(-0.32x3 AND 0.36x2 AND 0.05x0)
# R> tree=(0.68x1 OR -0.87x0 OR 0.08x1z OR -0.50x2)
# R> tree=(0.88x2 OR -0.15x4 OR 0.76x3 OR 0.06x6)
# R> tree=(-0.78x0 OR 1.00x5 OR 0.14x1 OR 0.04x3 OR 0.42x7 OR 0.26x2)
# R> tree=(0.01x2)
# R> tree=(-0.37x1 OR 1.00x1z OR -0.42x2 OR -0.01x7 OR -0.08x6)
#
# ======= GENERATION generation_g19 9949.115403901118 =======
# G> G_0: b=4.22; m=6.39; theta=3.28; init=1.17; noise=0.97; expr=1.16; deg=0.09; asym=4.77; tree=(0.18x2)
# G> G_1: b=1.37; m=0.80; theta=7.86; init=0.43; noise=1.55; expr=0.67; deg=0.13; asym=5.95; tree=(-0.52x4 AND 0.80x1 AND 0.47x3 AND 0.32x0z)
# G> G_2: b=0.58; m=3.08; theta=2.11; init=0.99; noise=0.86; expr=1.06; deg=0.10; asym=4.58; tree=(-0.72x4 AND -0.48x0 AND 0.18x3 AND 0.20x0z)
# G> G_3: b=1.16; m=6.91; theta=10.22; init=1.25; noise=0.75; expr=0.92; deg=0.13; asym=4.68; tree=(0.52x3 AND -0.14x4 AND -0.94x2 AND 0.02x1)
# G> G_4: b=1.17; m=7.41; theta=5.35; init=1.18; noise=0.65; expr=1.10; deg=0.08; asym=4.81; tree=(-0.28x4 AND 0.29x3 AND -0.14x1 AND 0.36x0z AND -0.00x2)
# G> G_5: b=1.47; m=3.85; theta=3.80; init=2.94; noise=0.88; expr=0.68; deg=0.12; asym=6.56; tree=(0.41x2 AND 0.59x0z AND 0.41x3 AND 0.29x4 AND -0.03x1 AND 0.20x0)
# G> G_6: b=1.44; m=7.17; theta=1.50; init=1.61; noise=1.11; expr=0.75; deg=0.09; asym=4.47; tree=(-0.52x3 AND 0.36x2 AND 0.08x0z)
# R> tree=(0.56x1 OR -0.88x0 OR -0.52x2)
# R> tree=(0.74x2 OR -0.34x4 OR 0.52x3 OR 0.10x7)
# R> tree=(-0.64x0 OR 0.97x5 OR 0.11x1 OR 0.12x3 OR 0.40x7)
# R> tree=(0.01x2 OR 0.04x0)
# R> tree=(-0.44x1 OR 1.00x1z OR -0.39x2 OR 0.19x4 OR -0.00x6)
#
# ======= GENERATION generation_g20 9970.166098380383 =======
# G> G_0: b=4.15; m=6.51; theta=3.17; init=1.11; noise=1.08; expr=1.31; deg=0.11; asym=4.38; tree=(0.10x2)
# G> G_1: b=1.51; m=0.60; theta=6.69; init=0.54; noise=2.02; expr=0.69; deg=0.16; asym=6.23; tree=(-0.56x4 AND 0.49x1 AND 0.60x3 AND 0.13x0z AND -0.05x0)
# G> G_2: b=0.64; m=3.02; theta=1.98; init=1.05; noise=0.96; expr=1.32; deg=0.11; asym=3.99; tree=(-0.72x4 AND -0.48x0 AND 0.04x3 AND 0.14x0z)
# G> G_3: b=1.31; m=7.08; theta=12.22; init=1.20; noise=0.85; expr=0.82; deg=0.13; asym=4.19; tree=(0.43x3 AND -0.32x4 AND -0.81x2)
# G> G_4: b=1.00; m=8.62; theta=5.35; init=1.05; noise=0.63; expr=1.12; deg=0.07; asym=3.87; tree=(-0.65x4 AND 0.24x3 AND 0.07x0z AND 0.03x0 AND 0.07x1)
# G> G_5: b=1.79; m=4.12; theta=4.09; init=3.12; noise=0.61; expr=0.60; deg=0.11; asym=4.70; tree=(0.41x2 AND 0.41x0z AND 0.11x3 AND 0.02x4 AND -0.05x1 AND 0.31x0)
# G> G_6: b=1.60; m=9.30; theta=1.14; init=1.76; noise=1.16; expr=0.74; deg=0.09; asym=5.11; tree=(-0.33x3 AND 0.36x2)
# R> tree=(0.68x1 OR -0.92x0 OR 0.08x1z OR -0.50x2)
# R> tree=(0.88x2 OR -0.08x4 OR 0.72x3)
# R> tree=(-0.78x0 OR 1.00x5 OR 0.16x1 OR 0.14x3 OR 0.42x7 OR 0.33x2)
# R> tree=(0.01x2)
# R> tree=(-0.37x1 OR 1.00x1z OR -0.61x2 OR -0.01x7)
