# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".13"

# %%
import pandas as pd
from brain import BrainModel
from submodels import factories
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from random import shuffle

from lib.score import (
    fate_corr, score_both_size_norm, shrink_and_align_stats, score_stats_norm
)
from lib.preprocess import *
from lib.callback import (
    cell_number_callback, progenitor_number_callback, neuron_number_callback,
    TargetPopulation, TagNumberCallback, TypeNumberCallback,
)
from lib.sde.grn.grn import GRNMain
from lib.sde.mutate import SparseMutator

from lib.ga.utils import weighted_selection_one, normalize_fitness_values
from lib.utils import pick_best, pick_last
from jf.utils.export import Exporter
from jf.autocompute.jf import O, L
from itertools import product
import jf.models.stringmodel as sm
from lib.analyser import show_curve, show_curve_progenitor
from jf.models.stringmodel import read_model
from lib.utils import normalize_time, align_time
from jf.utils.helper import provide_id

# %%
REF = O(
    stats=pd.read_csv("reference/ref_tristate2.csv"),  # ref is a mean
)
SM_GEN = read_model("generation")
_MUTATE_FUNC = SparseMutator()

# %%
def individual_generator(id_=-1, cb_init=None):
    sol = Solution(GRNMain(7, 5, 1, generate_funcs=cb_init), id_=id_)
    sol.grn.set_mutable()
    sol.grn.genes[0].init = 1
    for gene in sol.grn.genes:
        gene.noise = max(1, gene.noise)
    sol.grn.compile()
    return sol

# %%
class Solution:
    def __init__(self, grn, id_=0, parent=-1):
        self.id = id_
        self.grn = grn
        self.parent = parent
        self.fit = -1
        self.stats = None
        
    def copy(self, id_=0):
        return Solution(self.grn.copy(), id_=id_, parent=self.id)
        
    def mutate(self):
        _MUTATE_FUNC(self.grn)

# %%
def score_bb_size(bb, ref, *args, **kwargs):
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 70.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    ref_neuron_supra_early = 0.0
    
    ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    ref_neuron_infra_late = ref_neuron_infra_early
    ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - ref_neuron_infra_late
    
    delta_late = (abs(prog_late - ref_prog_late) + abs(neuron_infra_late - ref_neuron_infra_late)
                  + abs(neuron_supra_late - ref_neuron_supra_late))
    delta_early = (abs(prog_early - ref_prog_early) + abs(neuron_infra_early - ref_neuron_infra_early)
                  + abs(neuron_supra_early - ref_neuron_supra_early))

    return 1 / max(1, 100 - 1 * delta_late - 0.5 * delta_early)

# %%
def hook_event_handler(cell_program):
    # prob **2 and **4
    q = np.array(cell_program.quantities)
    if random() < (q[0] / 2)**4:  # missing a reset
        cell_program.quantities = cell_program.quantities.at[0].set(0)
        return Action.Divide, GRNCell.Progenitor
    
    if random() < (q[1] / 2)**1.5 * (1 - q[2] / 2)**1.5:
        return Action.DiffNeuron, GRNCell.PostMitoticInfra
    
    if random() < (q[2] / 2)**1.5 * (1 - q[1] / 2)**1.5:
        return Action.DiffNeuron, GRNCell.PostMitoticSupra
    
    return Action.NoOp, None

# %%
def get_bb(prun, grn):
    from submodels.grn_auto_v1 import GRNCell
    ccls = factories["grn_auto1"](grn=grn, hooks=dict(event_handler=hook_event_handler))
    callbacks = dict(
        progenitor_pop_size=progenitor_number_callback,
        whole_pop_size=cell_number_callback,
        neuron_pop_size=neuron_number_callback,
        infra_pop_size=TypeNumberCallback(GRNCell.PostMitoticInfra, TargetPopulation.whole),
        supra_pop_size=TypeNumberCallback(GRNCell.PostMitoticSupra, TargetPopulation.whole),
    )
    bb = BrainModel(time_step=0.25, verbose=False, start_population=prun.size, max_pop_size=5e2,
            cell_cls=ccls, end_time=prun.end_time, start_time=prun.start_time, silent=True, opti=True,
              run_tissue=True, monitor_callbacks=callbacks)
    return bb

# %%
def fitness_multistep(prun, grn, steps):
    total_fitness = 0
    stop = False
    previous_time = None
    bb = get_bb(prun, grn)
    # first step
    for step in steps:
        if not bb.run_until(step.end_time):
            stop = True
        
        score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
        fitness_step = 1.0 / score_step
        fitness_step = min(fitness_step, step.max_fitness)
        total_fitness += fitness_step
        if fitness_step < step.min_fitness or stop:
            return total_fitness, bb.stats
        else:
            previous_time = step.end_time
            step.passed()
        
    return total_fitness, bb.stats

# %%
def fitness_step(prun, grn, step):
    bb = get_bb(prun, grn)
    bb.run_until(step.end_time)
    score_step = step.score_func(bb, prun.ref, max_step=step.end_time, min_step=step.start_time)
    fitness = 1.0 / score_step
        
    return fitness, bb.stats

# %%
def do_init(prun):
    return individual_generator(provide_id(), prun.cb_init)

def do_fitness(prun, sol):
    fitness, stats = fitness_step(prun, sol.grn, prun.step)
    return fitness, stats

def do_selection(prun, pop_fit, pop):
    if len(pop) < prun.min_pop:
        return individual_generator(provide_id(), prun.cb_init)
    
    pop_fit = normalize_fitness_values(pop_fit)
    
    return weighted_selection_one(pop, pop_fit, lambda x: individual_generator(x, prun.cb_init), new_fitness=10., id_=provide_id())[0]

def do_mutation(prun, sol):
    sol.mutate()
    return sol

# %%
class ObjectiveStep(O):
    start_time = 0
    end_time = 0
    max_fitness = 1e9
    min_fitness = 1
    name = ""
    _passed = False
    
    def reset(self):
        self._passed = False
    
    def passed(self):
        if self._passed:
            return
        print(f"Step {self.name} passed !")
        self._passed = True
    
example_step = ObjectiveStep(name="3", start_time=56, end_time=86, score_func=score_bb_size, min_fitness=0.2)

class ParamRun(O):
    pop_size = 50
    batch_size = 50
    n_gen = 50
    current_gen = 0
    end_time = 86
    ref = REF
    min_pop = 50
    max_pop = 50
    start_time = 56

def get_prun(size=7, exponent=1):
    prun = ParamRun()
    prun.cb_init = dict()
    prun.size = size
    prun.exponent = exponent
    prun.step = example_step
    return prun

# %%
def pick_last_exported(exporter):
    generations = list(filter(SM_GEN.match, exporter.list()))
    if len(generations) == 0:
        return None, 0
    
    last = max(generations, key=lambda x: int(SM_GEN.extract(x).get("generation")))
    b_gen = int(SM_GEN.extract(last).get("generation")) + 1
    exporter.print(f"Found generation {b_gen - 1}", "reload")
    pop = exporter.load(last)
    return pop, b_gen

# %%
def main(prun):
    prun.history = dict()
    exporter = Exporter(name=prun.name, copy_stdout=True)
    definition = """
    
    """
    exporter.print(definition, slot="definition")
    best = 0
    
    # setup
    pop, batch_gen = pick_last_exported(exporter)
    
    if batch_gen == prun.n_gen:
        print("Already finished")
        return
    
    if pop is None:
        sol = do_init(prun)
        pop = [sol]
        batch_gen = 0
    else:
        sol = pop[-1]
        
    for i in range(batch_gen * prun.batch_size,
                   prun.n_gen * prun.batch_size):
        fit, stats = do_fitness(prun, sol)
        sol.fit, sol.stats = fit, stats
        
        if i % 100 == 0:
            exporter.print(f"Step {i}")
        if fit > best:
            exporter.print(f"++ Best {fit} for generation {i}")
            best = fit
            
        monitor = sol
        prun.history[i] = monitor
        # exporter(monitor, f"generation_g{generation}")
        
        sub_pop = pop[-prun.max_pop:]
        sol = do_selection(prun, [s.fit for s in sub_pop], sub_pop)
            
        sol = do_mutation(prun, sol)
        pop.append(sol)
        
        if (i + 1) % prun.batch_size == 0:
            print("Saving ...")
            batch_gen = (i + 1) // prun.batch_size
            exporter(pop[-prun.batch_size:], SM_GEN.fill(generation=batch_gen))
        
    return best

# %%
callback_init = dict(
    init=lambda: np.random.beta(1.5, 3) * 3,
    b=lambda: np.random.beta(1.5, 3) * 5,
    expr=lambda: 1,
    deg=lambda: 0.1,
    noise=lambda: np.random.beta(1.5, 3) * 1,
    asym=lambda: 5,
)

# %%
prun = get_prun()
prun.cb_init = callback_init
prun.name = "test_refacto7"
res = main(prun)
# Out:
# Exporting at output/test_refacto7
# [definition]
#
#
# [out] Step 0
# [out] ++ Best 69.55678942929435 for generation 0
# [out] ++ Best 69.58740167419231 for generation 2
# [out] ++ Best 71.94454453133517 for generation 3
# Saving ...
# [out] ++ Best 72.02617718439639 for generation 53
# [out] ++ Best 75.57719759255966 for generation 65
# Saving ...
# [out] Step 100
# [out] ++ Best 75.78127922521271 for generation 115
# [out] ++ Best 76.28127922521273 for generation 118
# [out] ++ Best 76.98536085786577 for generation 125
# [out] ++ Best 78.77596633255494 for generation 133
# Saving ...
# Saving ...
# [out] Step 200
# [out] ++ Best 79.28127922521271 for generation 208
# [out] ++ Best 79.29637449582026 for generation 214
# Saving ...
# [out] ++ Best 79.31678265908556 for generation 293
# Saving ...
# [out] Step 300
# [out] ++ Best 79.4188234754121 for generation 323
# [out] ++ Best 81.55678942929435 for generation 343
# Saving ...
# Saving ...
# [out] Step 400
# [out] ++ Best 82.91287085539867 for generation 400
# [out] ++ Best 83.12715656968439 for generation 408
# [out] ++ Best 84.20878922274561 for generation 414
# Saving ...
# [out] ++ Best 84.78127922521271 for generation 479
# [out] ++ Best 87.62715656968439 for generation 497
# Saving ...
# [out] Step 500
# [out] ++ Best 89.14756473294968 for generation 514
# [out] ++ Best 90.98429942682723 for generation 527
# Saving ...
# Saving ...
# [out] Step 600
# Saving ...
# Saving ...
# [out] Step 700
# [out] ++ Best 92.21474184275904 for generation 701
# [out] ++ Best 92.39049474161327 for generation 702
# [out] ++ Best 92.71223457052206 for generation 726
# Saving ...
# Saving ...
# [out] Step 800
# [out] ++ Best 93.56937742766492 for generation 820
# Saving ...
# Saving ...
# [out] Step 900
# Saving ...
# Saving ...
# [out] Step 1000
# Saving ...
# Saving ...
# [out] Step 1100
# Saving ...
# Saving ...
# [out] Step 1200
# Saving ...
# Saving ...
# [out] Step 1300
# Saving ...
# Saving ...
# [out] Step 1400
# Saving ...
# Saving ...
# [out] Step 1500
# Saving ...
# Saving ...
# [out] Step 1600
# Saving ...
# Saving ...
# [out] Step 1700
# Saving ...
# Saving ...
# [out] Step 1800
# Saving ...
# Saving ...
# [out] Step 1900
# Saving ...
# Saving ...
# [out] Step 2000
# Saving ...
# Saving ...
# [out] Step 2100
# Saving ...
# Saving ...
# [out] Step 2200
# Saving ...
# Saving ...
# [out] Step 2300
# Saving ...
# Saving ...
# [out] Step 2400
# Saving ...
# Saving ...

# %%
exp = Exporter(name=prun.name)
# Out:
# Exporting at output/test_refacto7

# %%
sm = read_model("generation")

# %%
res = pick_best(exp.load("generation_g26"))
# res = pick_best(exp.load(pick_last(exp)))

# %%
res.fit
# Out:
# 90.25198946601412

# %%
# for i in range(5):
#     print(fitness_multistep(prun, res.grn, prun.steps))

# %%
def quick_show(stats):
    plt.plot(stats.time, stats.progenitor_pop_size, label="Progenitor")
    plt.plot(stats.time, stats.whole_pop_size, label="Whole")
    plt.plot(stats.time, stats.neuron_pop_size, label="Neurons")
    plt.plot(stats.time, stats.infra_pop_size, label="Infra")
    plt.plot(stats.time, stats.supra_pop_size, label="Supra")
    plt.legend()
    
quick_show(res.stats)

# %%
show_curve(res.stats, REF.stats)

# %%
for g in sorted(filter(sm.match, exp.list()), key=lambda x: int(sm.extract(x)["generation"])):
    gen = exp.load(g)
    res = pick_best(gen)
    print()
    print(f"======= GENERATION {g} {res.fit} =======")
    print(res.grn)
# Out:
# ======= GENERATION generation_g1 71.94454453133517 =======
# G> G_0: b=0.90; m=7.61; theta=4.51; init=0.99; noise=1.00; expr=1.00; deg=0.10; asym=5.20; tree=(0.32x3 AND 0.55x0 AND -0.80x2)
# G> G_1: b=1.02; m=5.00; theta=8.25; init=1.43; noise=1.27; expr=1.00; deg=0.10; asym=5.00; tree=(0.82x0 AND -0.82x3 AND 0.13x0z)
# G> G_2: b=1.28; m=0.43; theta=8.24; init=0.70; noise=1.06; expr=1.00; deg=0.10; asym=5.00; tree=(-0.80x0 AND 0.77x4 AND -0.81x2)
# G> G_3: b=1.98; m=6.88; theta=5.55; init=0.35; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(0.46x3 AND -0.82x2 AND -0.11x4)
# G> G_4: b=2.68; m=0.90; theta=8.18; init=1.64; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(0.40x0z AND 0.06x2 AND -0.36x1)
# G> G_5: b=0.82; m=2.82; theta=4.85; init=0.30; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(0.62x1 AND -0.37x3 AND 0.57x0z)
# G> G_6: b=0.30; m=9.96; theta=1.11; init=0.48; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(0.96x0z AND 0.41x4)
# R> tree=()
# R> tree=(0.87x0)
# R> tree=()
# R> tree=(-0.43x6 OR -0.64x3 OR -0.59x7)
# R> tree=(0.56x3 OR 0.31x0 OR -0.84x5 OR 0.11x2)
#
# ======= GENERATION generation_g2 75.57719759255966 =======
# G> G_0: b=1.04; m=4.21; theta=3.87; init=1.00; noise=1.04; expr=1.00; deg=0.10; asym=4.97; tree=()
# G> G_1: b=0.37; m=5.51; theta=4.47; init=0.83; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(0.79x1 AND 0.65x0 AND 0.58x0z AND -0.05x3)
# G> G_2: b=1.30; m=7.19; theta=9.17; init=2.17; noise=1.00; expr=1.00; deg=0.11; asym=5.00; tree=(-0.75x1 AND 0.35x0z AND 0.57x3 AND 0.05x2 AND 0.10x0)
# G> G_3: b=3.06; m=2.74; theta=1.35; init=1.24; noise=0.93; expr=1.05; deg=0.10; asym=4.27; tree=(-0.53x1 AND 0.69x0 AND 0.93x0z)
# G> G_4: b=2.79; m=8.20; theta=6.86; init=1.68; noise=1.00; expr=1.00; deg=0.11; asym=5.43; tree=(0.03x1)
# G> G_5: b=1.56; m=7.66; theta=7.71; init=0.23; noise=0.96; expr=1.00; deg=0.10; asym=4.93; tree=(0.19x0 AND -0.54x4 AND 0.01x0z)
# G> G_6: b=2.08; m=6.35; theta=5.46; init=0.49; noise=1.00; expr=1.00; deg=0.09; asym=5.00; tree=(-0.85x0 AND 0.95x0z AND -0.37x2 AND 0.10x1 AND -0.07x3)
# R> tree=()
# R> tree=(-0.46x5 OR -0.62x1 OR -0.71x7)
# R> tree=(-0.56x1 OR 0.47x3 OR 0.53x4)
# R> tree=(0.11x6)
# R> tree=(-0.28x6 OR 0.20x4)
#
# ======= GENERATION generation_g3 78.77596633255494 =======
# G> G_0: b=1.26; m=4.55; theta=4.21; init=1.16; noise=1.04; expr=1.00; deg=0.10; asym=4.97; tree=(0.24x1)
# G> G_1: b=0.39; m=5.87; theta=4.47; init=0.92; noise=0.89; expr=0.91; deg=0.10; asym=5.00; tree=(0.79x1 AND 0.65x0 AND 0.58x0z AND -0.05x3 AND 0.10x2)
# G> G_2: b=1.48; m=7.19; theta=6.85; init=2.17; noise=0.92; expr=1.02; deg=0.11; asym=5.00; tree=(-0.75x1 AND 0.35x0z AND 0.50x3 AND 0.10x0 AND -0.25x4)
# G> G_3: b=3.04; m=2.74; theta=1.35; init=1.24; noise=0.92; expr=1.08; deg=0.10; asym=4.27; tree=(-0.53x1 AND 0.74x0 AND 1.00x0z)
# G> G_4: b=2.79; m=8.20; theta=6.86; init=1.68; noise=1.00; expr=1.03; deg=0.12; asym=5.43; tree=(0.03x1)
# G> G_5: b=1.31; m=6.86; theta=7.71; init=0.23; noise=0.96; expr=1.03; deg=0.11; asym=4.93; tree=(0.09x0 AND -0.54x4 AND 0.01x0z AND -0.05x1)
# G> G_6: b=1.83; m=6.85; theta=4.63; init=0.49; noise=0.86; expr=1.00; deg=0.11; asym=5.00; tree=(-0.85x0 AND 0.93x0z AND -0.37x2 AND 0.10x1 AND -0.07x3)
# R> tree=()
# R> tree=(-0.47x5 OR -0.56x1 OR -0.87x7)
# R> tree=(-0.56x1 OR 0.47x3 OR 0.34x4 OR -0.03x2)
# R> tree=()
# R> tree=(-0.21x6 OR 0.20x4)
#
# ======= GENERATION generation_g4 78.84739490398353 =======
# G> G_0: b=1.30; m=4.44; theta=3.87; init=1.02; noise=1.16; expr=1.00; deg=0.10; asym=4.97; tree=(0.24x1)
# G> G_1: b=0.39; m=5.79; theta=4.47; init=0.77; noise=1.00; expr=0.91; deg=0.09; asym=5.00; tree=(0.97x1 AND 0.65x0 AND 0.58x0z AND -0.05x3 AND 0.09x2)
# G> G_2: b=1.40; m=5.71; theta=8.46; init=2.49; noise=1.00; expr=1.00; deg=0.11; asym=4.96; tree=(-0.96x1 AND 0.35x0z AND 0.57x3 AND 0.34x0)
# G> G_3: b=2.86; m=2.74; theta=1.31; init=1.24; noise=0.88; expr=1.05; deg=0.11; asym=4.40; tree=(-0.54x1 AND 0.81x0 AND 1.00x0z AND 0.15x3)
# G> G_4: b=2.71; m=7.36; theta=6.18; init=1.45; noise=0.99; expr=1.03; deg=0.12; asym=5.43; tree=(0.15x1)
# G> G_5: b=1.31; m=7.65; theta=6.62; init=0.25; noise=0.82; expr=1.03; deg=0.12; asym=4.93; tree=(0.17x0 AND -0.52x4 AND -0.05x1 AND -0.03x2)
# G> G_6: b=2.01; m=6.85; theta=4.63; init=0.49; noise=0.86; expr=0.98; deg=0.10; asym=5.64; tree=(-0.85x0 AND 0.93x0z AND -0.28x2 AND -0.23x3)
# R> tree=()
# R> tree=(-0.47x5 OR -0.61x1 OR -0.87x7)
# R> tree=(-0.56x1 OR 0.32x3 OR 0.49x4 OR 0.09x7 OR 0.04x6)
# R> tree=()
# R> tree=(-0.25x6 OR 0.20x4 OR -0.10x5)
#
# ======= GENERATION generation_g5 79.29637449582026 =======
# G> G_0: b=1.04; m=5.64; theta=3.87; init=1.00; noise=0.92; expr=1.00; deg=0.10; asym=5.10; tree=(0.05x1)
# G> G_1: b=0.34; m=5.51; theta=4.47; init=0.88; noise=0.91; expr=0.94; deg=0.10; asym=4.76; tree=(0.79x1 AND 0.65x0 AND 0.58x0z AND -0.05x3)
# G> G_2: b=1.43; m=7.51; theta=9.17; init=1.85; noise=1.01; expr=0.88; deg=0.11; asym=4.90; tree=(-0.92x1 AND 0.35x0z AND 0.56x3 AND 0.17x0)
# G> G_3: b=3.35; m=2.86; theta=1.42; init=1.24; noise=0.99; expr=1.05; deg=0.10; asym=4.11; tree=(-0.61x1 AND 0.72x0 AND 1.00x0z AND -0.05x3 AND 0.00x4)
# G> G_4: b=2.79; m=8.20; theta=6.86; init=1.68; noise=0.91; expr=1.06; deg=0.11; asym=5.87; tree=(0.06x1)
# G> G_5: b=1.46; m=7.17; theta=7.71; init=0.22; noise=0.96; expr=1.00; deg=0.10; asym=4.47; tree=(0.20x0 AND -0.54x4)
# G> G_6: b=2.07; m=6.35; theta=5.46; init=0.49; noise=1.26; expr=0.99; deg=0.09; asym=5.23; tree=(-1.00x0 AND 0.95x0z AND -0.37x2 AND 0.13x1 AND -0.07x3)
# R> tree=()
# R> tree=(-0.46x5 OR -0.51x1 OR -0.71x7)
# R> tree=(-0.56x1 OR 0.47x3 OR 0.53x4)
# R> tree=(0.11x6 OR 0.02x4)
# R> tree=(-0.23x6 OR 0.11x4)
#
# ======= GENERATION generation_g6 79.31678265908556 =======
# G> G_0: b=0.89; m=4.91; theta=3.87; init=1.00; noise=0.84; expr=1.00; deg=0.09; asym=4.46; tree=(0.06x2)
# G> G_1: b=0.35; m=5.79; theta=4.25; init=0.62; noise=0.91; expr=0.98; deg=0.12; asym=5.83; tree=(0.85x1 AND 0.65x0 AND 0.57x0z AND -0.08x3 AND -0.08x4)
# G> G_2: b=1.45; m=6.16; theta=9.17; init=2.19; noise=0.91; expr=0.97; deg=0.12; asym=5.11; tree=(-0.68x1 AND 0.28x0z AND 0.57x3 AND 0.39x0)
# G> G_3: b=3.35; m=2.74; theta=1.45; init=1.39; noise=1.15; expr=1.05; deg=0.09; asym=4.64; tree=(-0.60x1 AND 0.84x0 AND 0.82x0z AND -0.05x3 AND 0.14x2)
# G> G_4: b=2.75; m=8.25; theta=7.31; init=1.74; noise=0.91; expr=1.00; deg=0.11; asym=4.93; tree=(0.06x1 AND 0.06x2 AND 0.01x0z)
# G> G_5: b=1.42; m=7.17; theta=9.27; init=0.25; noise=0.84; expr=0.95; deg=0.11; asym=5.78; tree=(0.20x0 AND -0.54x4)
# G> G_6: b=2.08; m=5.57; theta=5.04; init=0.49; noise=1.18; expr=0.96; deg=0.09; asym=5.08; tree=(-1.00x0 AND 0.95x0z AND -0.37x2 AND 0.10x1 AND -0.07x3)
# R> tree=()
# R> tree=(-0.59x5 OR -0.41x1 OR -0.69x7)
# R> tree=(-0.56x1 OR 0.31x3 OR 0.53x4)
# R> tree=(0.16x6 OR 0.18x1z)
# R> tree=(-0.16x6 OR 0.03x4 OR 0.14x7)
#
# ======= GENERATION generation_g7 81.55678942929435 =======
# G> G_0: b=2.22; m=0.20; theta=10.01; init=1.00; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=()
# G> G_1: b=2.51; m=6.62; theta=2.80; init=0.91; noise=1.29; expr=1.04; deg=0.10; asym=5.00; tree=(0.86x0z AND -0.61x1 AND -0.13x3)
# G> G_2: b=0.22; m=0.13; theta=7.04; init=0.71; noise=1.00; expr=1.02; deg=0.10; asym=5.00; tree=(0.14x0z AND -0.55x2 AND 0.95x0)
# G> G_3: b=1.70; m=0.84; theta=7.15; init=0.97; noise=1.03; expr=1.00; deg=0.10; asym=4.56; tree=(-0.96x3 AND -0.64x0 AND -0.10x1)
# G> G_4: b=1.04; m=8.83; theta=8.43; init=0.84; noise=0.98; expr=1.00; deg=0.10; asym=4.60; tree=(-0.58x0 AND -0.12x3)
# G> G_5: b=3.61; m=1.56; theta=7.67; init=2.08; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(-0.61x4 AND -0.51x0)
# G> G_6: b=1.53; m=4.23; theta=7.29; init=0.47; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(-0.95x4)
# R> tree=(0.48x5 OR -0.90x4 OR 0.15x6)
# R> tree=(-0.95x5)
# R> tree=()
# R> tree=()
# R> tree=(1.00x2 OR -0.92x0 OR -0.52x4)
#
# ======= GENERATION generation_g8 79.91287085539867 =======
# G> G_0: b=2.22; m=0.20; theta=10.01; init=1.00; noise=1.00; expr=1.05; deg=0.10; asym=5.00; tree=()
# G> G_1: b=2.51; m=6.62; theta=2.80; init=0.91; noise=1.29; expr=1.04; deg=0.10; asym=5.00; tree=(0.97x0z AND -0.61x1 AND -0.13x3)
# G> G_2: b=0.22; m=0.13; theta=7.04; init=0.71; noise=1.00; expr=1.02; deg=0.10; asym=5.00; tree=(0.11x0z AND -0.55x2 AND 0.95x0)
# G> G_3: b=1.70; m=0.84; theta=7.15; init=0.97; noise=1.03; expr=1.00; deg=0.10; asym=4.56; tree=(-0.96x3 AND -0.64x0 AND -0.10x1)
# G> G_4: b=1.08; m=8.83; theta=8.01; init=0.84; noise=0.98; expr=1.00; deg=0.10; asym=4.60; tree=(-0.58x0 AND -0.12x3 AND 0.01x1)
# G> G_5: b=3.61; m=1.56; theta=7.67; init=2.04; noise=1.00; expr=1.00; deg=0.10; asym=5.00; tree=(-0.61x4 AND -0.51x0)
# G> G_6: b=1.53; m=3.73; theta=7.29; init=0.49; noise=0.90; expr=1.00; deg=0.10; asym=5.00; tree=(-0.95x4)
# R> tree=(0.43x5 OR -0.90x4 OR 0.15x6)
# R> tree=(-0.95x5)
# R> tree=()
# R> tree=()
# R> tree=(0.92x2 OR -0.74x0 OR -0.52x4)
#
# ======= GENERATION generation_g9 84.20878922274561 =======
# G> G_0: b=2.22; m=0.20; theta=10.01; init=1.00; noise=1.00; expr=1.05; deg=0.10; asym=5.00; tree=()
# G> G_1: b=2.72; m=6.62; theta=2.88; init=0.91; noise=1.29; expr=0.99; deg=0.10; asym=5.00; tree=(0.83x0z AND -0.61x1 AND -0.13x3 AND 0.02x0)
# G> G_2: b=0.22; m=0.13; theta=7.04; init=0.71; noise=0.86; expr=1.02; deg=0.10; asym=4.69; tree=(0.11x0z AND -0.55x2 AND 0.98x0)
# G> G_3: b=1.70; m=0.84; theta=6.95; init=0.93; noise=1.19; expr=0.96; deg=0.10; asym=4.56; tree=(-0.96x3 AND -0.64x0 AND -0.19x1)
# G> G_4: b=1.11; m=8.83; theta=8.01; init=0.74; noise=0.99; expr=1.00; deg=0.11; asym=4.60; tree=(-0.39x0 AND -0.12x3 AND 0.01x1 AND 0.01x0z)
# G> G_5: b=3.61; m=1.71; theta=7.67; init=1.76; noise=0.96; expr=0.97; deg=0.08; asym=5.00; tree=(-0.48x4 AND -0.51x0)
# G> G_6: b=1.53; m=3.73; theta=7.29; init=0.49; noise=0.90; expr=1.04; deg=0.10; asym=3.84; tree=(-0.95x4 AND 0.06x1)
# R> tree=(0.43x5 OR -0.90x4 OR 0.06x6)
# R> tree=(-0.95x5 OR -0.01x0)
# R> tree=()
# R> tree=()
# R> tree=(0.92x2 OR -0.74x0 OR -0.52x4)
#
# ======= GENERATION generation_g10 87.62715656968439 =======
# G> G_0: b=2.22; m=0.20; theta=10.01; init=1.00; noise=1.06; expr=1.05; deg=0.10; asym=4.77; tree=()
# G> G_1: b=2.78; m=6.62; theta=2.81; init=0.91; noise=1.29; expr=0.99; deg=0.08; asym=5.64; tree=(0.79x0z AND -0.61x1 AND -0.13x3 AND 0.02x0)
# G> G_2: b=0.22; m=0.13; theta=6.27; init=0.71; noise=0.74; expr=1.02; deg=0.11; asym=4.69; tree=(0.11x0z AND -0.55x2 AND 0.98x0 AND -0.07x1)
# G> G_3: b=1.68; m=0.84; theta=6.95; init=0.93; noise=1.19; expr=0.99; deg=0.10; asym=4.56; tree=(-0.96x3 AND -0.71x0 AND -0.19x1)
# G> G_4: b=1.11; m=8.83; theta=8.01; init=0.74; noise=0.99; expr=1.00; deg=0.12; asym=4.60; tree=(-0.39x0 AND -0.24x3 AND 0.01x1 AND 0.01x0z)
# G> G_5: b=3.78; m=1.65; theta=7.67; init=2.03; noise=0.96; expr=0.87; deg=0.08; asym=5.00; tree=(-0.42x4 AND -0.55x0)
# G> G_6: b=1.64; m=3.73; theta=6.70; init=0.53; noise=0.90; expr=1.23; deg=0.10; asym=3.84; tree=(-0.87x4 AND 0.06x1 AND 0.03x0 AND 0.02x0z)
# R> tree=(0.55x5 OR -0.97x4 OR 0.03x6 OR 0.12x1z)
# R> tree=(-0.88x5 OR -0.01x0)
# R> tree=(0.10x3)
# R> tree=(0.01x1)
# R> tree=(0.87x2 OR -0.74x0 OR -0.52x4)
#
# ======= GENERATION generation_g11 90.98429942682723 =======
# G> G_0: b=2.22; m=0.17; theta=10.73; init=0.97; noise=1.13; expr=1.08; deg=0.10; asym=4.77; tree=()
# G> G_1: b=2.78; m=6.62; theta=2.74; init=0.91; noise=1.53; expr=0.99; deg=0.08; asym=5.64; tree=(0.79x0z AND -0.61x1 AND -0.07x3 AND 0.04x0)
# G> G_2: b=0.17; m=0.12; theta=6.35; init=0.86; noise=0.74; expr=0.96; deg=0.10; asym=4.69; tree=(0.11x0z AND -0.54x2 AND 0.97x0 AND -0.11x1)
# G> G_3: b=1.58; m=0.84; theta=6.36; init=0.93; noise=1.19; expr=0.99; deg=0.11; asym=4.56; tree=(-0.96x3 AND -0.78x0 AND -0.19x1)
# G> G_4: b=1.05; m=9.39; theta=8.27; init=0.74; noise=1.05; expr=1.16; deg=0.12; asym=4.60; tree=(-0.39x0 AND -0.24x3 AND 0.01x1)
# G> G_5: b=3.78; m=1.65; theta=6.98; init=1.92; noise=0.96; expr=0.87; deg=0.08; asym=5.00; tree=(-0.26x4 AND -0.55x0)
# G> G_6: b=1.75; m=3.73; theta=6.70; init=0.53; noise=0.90; expr=1.34; deg=0.08; asym=4.82; tree=(-0.78x4 AND 0.00x1 AND 0.13x0 AND 0.09x0z)
# R> tree=(0.55x5 OR -1.00x4 OR 0.03x6 OR 0.12x1z)
# R> tree=(-0.61x5 OR -0.01x0)
# R> tree=(0.10x3)
# R> tree=(0.01x1)
# R> tree=(0.87x2 OR -0.74x0 OR -0.52x4)
#
# ======= GENERATION generation_g12 89.25066698031476 =======
# G> G_0: b=2.22; m=0.20; theta=8.82; init=1.00; noise=0.92; expr=1.05; deg=0.10; asym=4.77; tree=(-0.06x1)
# G> G_1: b=2.71; m=6.11; theta=2.75; init=0.84; noise=1.41; expr=1.08; deg=0.10; asym=5.43; tree=(0.79x0z AND -0.49x1 AND -0.09x3)
# G> G_2: b=0.17; m=0.13; theta=5.23; init=0.49; noise=0.74; expr=0.96; deg=0.11; asym=4.97; tree=(0.11x0z AND -0.55x2 AND 0.81x0 AND -0.26x1 AND 0.08x4)
# G> G_3: b=1.58; m=0.84; theta=6.63; init=0.69; noise=1.30; expr=1.01; deg=0.11; asym=4.65; tree=(-0.96x3 AND -0.73x0 AND -0.28x1)
# G> G_4: b=1.05; m=7.93; theta=6.07; init=0.64; noise=0.82; expr=1.16; deg=0.11; asym=4.60; tree=(-0.42x0 AND -0.15x3 AND 0.01x1 AND 0.01x0z)
# G> G_5: b=4.35; m=1.65; theta=6.98; init=2.14; noise=0.96; expr=0.87; deg=0.08; asym=4.92; tree=(-0.26x4 AND -0.45x0)
# G> G_6: b=1.60; m=3.73; theta=7.06; init=0.53; noise=1.00; expr=1.34; deg=0.10; asym=2.77; tree=(-0.78x4 AND 0.18x1 AND 0.05x0z)
# R> tree=(0.55x5 OR -1.00x4 OR 0.03x6 OR 0.14x1z)
# R> tree=(-0.88x5 OR -0.01x0)
# R> tree=(0.10x3)
# R> tree=()
# R> tree=(0.72x2 OR -0.91x0 OR -0.61x4)
#
# ======= GENERATION generation_g13 90.7200547354168 =======
# G> G_0: b=2.59; m=0.22; theta=8.97; init=1.21; noise=1.18; expr=1.05; deg=0.09; asym=4.87; tree=(0.12x0)
# G> G_1: b=2.67; m=6.47; theta=1.65; init=0.92; noise=1.17; expr=0.96; deg=0.08; asym=5.19; tree=(0.79x0z AND -0.61x1 AND -0.13x3 AND 0.02x0)
# G> G_2: b=0.22; m=0.13; theta=6.27; init=0.66; noise=0.56; expr=1.07; deg=0.10; asym=4.69; tree=(0.17x0z AND -0.52x2 AND 0.87x0 AND -0.07x1 AND -0.17x4)
# G> G_3: b=1.62; m=0.75; theta=7.98; init=0.93; noise=1.08; expr=0.87; deg=0.10; asym=4.45; tree=(-0.98x3 AND -0.74x0 AND -0.19x1)
# G> G_4: b=1.02; m=8.83; theta=8.01; init=0.74; noise=0.76; expr=1.00; deg=0.13; asym=4.30; tree=(-0.49x0 AND -0.26x3 AND 0.01x1 AND 0.21x0z AND 0.15x2 AND 0.02x4)
# G> G_5: b=3.91; m=1.80; theta=8.84; init=1.94; noise=0.89; expr=0.92; deg=0.09; asym=5.00; tree=(-0.45x4 AND -0.59x0)
# G> G_6: b=1.90; m=3.73; theta=8.55; init=0.41; noise=1.10; expr=1.26; deg=0.10; asym=3.48; tree=(-0.85x4 AND 0.06x1 AND 0.06x0)
# R> tree=(0.46x5 OR -1.00x4 OR 0.25x1z)
# R> tree=(-0.97x5)
# R> tree=(0.10x3 OR -0.06x4)
# R> tree=(-0.03x3 OR -0.16x1)
# R> tree=(0.99x2 OR -0.66x0 OR -0.41x4 OR -0.36x3 OR -0.20x6 OR 0.18x1z)
#
# ======= GENERATION generation_g14 89.45474861296782 =======
# G> G_0: b=2.55; m=0.22; theta=8.97; init=1.21; noise=1.27; expr=1.05; deg=0.09; asym=4.87; tree=(0.12x0)
# G> G_1: b=3.20; m=7.54; theta=1.72; init=0.92; noise=1.17; expr=0.96; deg=0.08; asym=5.19; tree=(0.79x0z AND -0.61x1 AND -0.06x3)
# G> G_2: b=0.20; m=0.12; theta=6.27; init=0.51; noise=0.56; expr=1.09; deg=0.12; asym=4.70; tree=(0.12x0z AND -0.52x2 AND 0.87x0 AND -0.07x1 AND -0.17x4)
# G> G_3: b=1.68; m=0.77; theta=7.57; init=1.07; noise=1.20; expr=0.84; deg=0.10; asym=4.45; tree=(-0.74x3 AND -0.72x0 AND -0.27x1 AND 0.00x0z)
# G> G_4: b=1.02; m=8.83; theta=7.05; init=0.73; noise=0.87; expr=1.08; deg=0.13; asym=4.30; tree=(-0.51x0 AND -0.26x3 AND 0.06x1 AND 0.10x0z AND 0.15x2 AND 0.02x4)
# G> G_5: b=3.78; m=1.74; theta=9.57; init=1.94; noise=0.93; expr=0.92; deg=0.10; asym=4.57; tree=(-0.60x4 AND -0.54x0)
# G> G_6: b=1.69; m=4.33; theta=8.55; init=0.41; noise=1.04; expr=1.17; deg=0.09; asym=3.54; tree=(-0.85x4 AND 0.06x1 AND 0.06x0)
# R> tree=(0.46x5 OR -1.00x4 OR 0.16x1z)
# R> tree=(-0.97x5)
# R> tree=(0.10x3 OR -0.09x4)
# R> tree=(-0.11x1 OR -0.05x4)
# R> tree=(0.88x2 OR -0.76x0 OR -0.41x4 OR -0.36x3 OR -0.26x6)
#
# ======= GENERATION generation_g15 92.71223457052206 =======
# G> G_0: b=2.43; m=0.14; theta=8.02; init=1.21; noise=1.21; expr=1.09; deg=0.09; asym=4.82; tree=(0.27x0 AND 0.08x3)
# G> G_1: b=2.78; m=6.86; theta=1.78; init=0.76; noise=1.11; expr=1.04; deg=0.08; asym=5.19; tree=(0.79x0z AND -0.69x1 AND -0.13x3 AND 0.04x0)
# G> G_2: b=0.22; m=0.12; theta=6.27; init=0.60; noise=0.56; expr=1.07; deg=0.09; asym=4.35; tree=(0.24x0z AND -0.51x2 AND 0.87x0 AND -0.07x1 AND -0.19x4 AND 0.07x3)
# G> G_3: b=1.41; m=0.75; theta=7.79; init=1.15; noise=1.08; expr=0.87; deg=0.12; asym=5.22; tree=(-0.98x3 AND -0.72x0 AND -0.23x1)
# G> G_4: b=0.95; m=10.45; theta=8.01; init=0.82; noise=0.93; expr=1.00; deg=0.15; asym=4.04; tree=(-0.47x0 AND -0.06x3 AND 0.34x1 AND 0.23x0z AND 0.11x2 AND 0.23x4)
# G> G_5: b=3.91; m=1.59; theta=9.13; init=1.94; noise=0.89; expr=1.04; deg=0.09; asym=5.00; tree=(-0.45x4 AND -0.64x0 AND -0.03x1)
# G> G_6: b=1.67; m=3.73; theta=8.59; init=0.41; noise=1.17; expr=1.44; deg=0.10; asym=3.13; tree=(-0.82x4 AND 0.23x1 AND 0.06x0)
# R> tree=(0.68x5 OR -0.91x4 OR 0.00x1z OR 0.01x1)
# R> tree=(-0.92x5)
# R> tree=(0.10x3 OR -0.00x4)
# R> tree=(-0.03x3 OR -0.15x1)
# R> tree=(1.00x2 OR -0.64x0 OR -0.41x4 OR -0.36x3 OR -0.13x6 OR 0.16x1z)
#
# ======= GENERATION generation_g16 92.25836378971043 =======
# G> G_0: b=2.59; m=0.22; theta=8.97; init=1.21; noise=1.04; expr=0.95; deg=0.10; asym=4.87; tree=(0.11x0)
# G> G_1: b=2.45; m=5.00; theta=1.53; init=0.72; noise=1.15; expr=1.05; deg=0.08; asym=5.19; tree=(0.79x0z AND -0.66x1 AND -0.11x3 AND 0.17x0)
# G> G_2: b=0.22; m=0.13; theta=6.27; init=0.66; noise=0.49; expr=1.07; deg=0.12; asym=3.78; tree=(0.17x0z AND -0.65x2 AND 0.96x0 AND 0.20x4)
# G> G_3: b=1.58; m=0.79; theta=7.20; init=0.93; noise=1.19; expr=1.10; deg=0.10; asym=5.03; tree=(-0.98x3 AND -0.50x0 AND -0.20x1)
# G> G_4: b=1.08; m=8.83; theta=7.42; init=0.68; noise=0.73; expr=1.00; deg=0.13; asym=4.59; tree=(-0.16x0 AND -0.18x3 AND 0.11x1 AND 0.48x0z AND 0.39x2 AND 0.28x4)
# G> G_5: b=3.86; m=1.95; theta=11.07; init=1.91; noise=0.86; expr=0.92; deg=0.07; asym=4.29; tree=(-0.39x4 AND -0.76x0)
# G> G_6: b=1.94; m=4.14; theta=9.02; init=0.37; noise=1.24; expr=1.25; deg=0.09; asym=4.05; tree=(-0.69x4 AND 0.21x0 AND 0.03x2)
# R> tree=(0.46x5 OR -1.00x4 OR 0.30x1z)
# R> tree=(-0.79x5)
# R> tree=()
# R> tree=(-0.09x3)
# R> tree=(0.99x2 OR -0.69x0 OR -0.67x4 OR -0.33x3 OR -0.29x6 OR 0.09x1z)
#
# ======= GENERATION generation_g17 93.56937742766492 =======
# G> G_0: b=2.43; m=0.18; theta=9.16; init=1.00; noise=1.18; expr=1.02; deg=0.10; asym=4.87; tree=(0.10x0 AND -0.01x4 AND 0.07x0z)
# G> G_1: b=2.78; m=6.86; theta=1.57; init=0.80; noise=1.17; expr=1.04; deg=0.08; asym=6.09; tree=(0.79x0z AND -0.61x1 AND 0.04x0 AND -0.15x4)
# G> G_2: b=0.21; m=0.10; theta=6.51; init=0.59; noise=0.57; expr=1.19; deg=0.09; asym=4.35; tree=(0.30x0z AND -0.55x2 AND 0.87x0 AND -0.19x1 AND -0.20x4 AND -0.04x3)
# G> G_3: b=1.48; m=0.72; theta=7.79; init=1.16; noise=1.06; expr=0.97; deg=0.09; asym=5.91; tree=(-0.79x3 AND -0.66x0 AND -0.26x1 AND -0.28x4)
# G> G_4: b=1.12; m=11.58; theta=8.06; init=0.73; noise=1.03; expr=1.00; deg=0.15; asym=4.25; tree=(-0.37x0 AND 0.12x0z AND 0.15x2 AND 0.40x4 AND 0.04x3)
# G> G_5: b=4.07; m=1.59; theta=8.84; init=1.79; noise=0.89; expr=1.15; deg=0.09; asym=5.00; tree=(-0.61x4 AND -0.59x0)
# G> G_6: b=2.08; m=3.73; theta=8.55; init=0.62; noise=1.33; expr=1.44; deg=0.11; asym=3.72; tree=(-0.84x4 AND 0.17x1 AND 0.03x0 AND -0.12x2)
# R> tree=(0.49x5 OR -1.00x4 OR 0.00x1z)
# R> tree=(-0.97x5 OR -0.03x1)
# R> tree=(0.17x3 OR -0.02x4)
# R> tree=()
# R> tree=(0.92x2 OR -0.62x0 OR -0.43x4 OR -0.38x3 OR -0.14x6 OR 0.03x1z OR 0.56x5)
#
# ======= GENERATION generation_g18 91.97515677623312 =======
# G> G_0: b=2.67; m=0.26; theta=11.14; init=1.21; noise=1.30; expr=1.04; deg=0.09; asym=4.31; tree=(0.11x0)
# G> G_1: b=2.55; m=5.88; theta=1.75; init=0.88; noise=1.17; expr=1.13; deg=0.07; asym=4.54; tree=(0.79x0z AND -0.95x1 AND -0.01x3 AND 0.22x0 AND 0.24x2)
# G> G_2: b=0.23; m=0.13; theta=6.82; init=0.36; noise=0.53; expr=1.07; deg=0.11; asym=4.73; tree=(0.17x0z AND -0.66x2 AND 1.00x0 AND -0.16x1 AND 0.09x4)
# G> G_3: b=1.62; m=0.68; theta=7.98; init=1.11; noise=1.29; expr=0.87; deg=0.10; asym=3.09; tree=(-1.00x3 AND -0.49x0 AND -0.33x1)
# G> G_4: b=1.16; m=8.37; theta=8.47; init=0.79; noise=0.84; expr=1.41; deg=0.18; asym=4.02; tree=(-0.41x0 AND -0.31x3 AND 0.08x1 AND 0.22x0z AND 0.23x2 AND 0.26x4)
# G> G_5: b=4.47; m=1.64; theta=10.68; init=2.02; noise=0.80; expr=0.92; deg=0.07; asym=4.29; tree=(-0.52x4 AND -0.54x0 AND 0.12x2)
# G> G_6: b=1.94; m=3.66; theta=8.55; init=0.37; noise=1.10; expr=1.26; deg=0.09; asym=3.46; tree=(-0.85x4 AND 0.05x1 AND 0.06x0 AND 0.07x2)
# R> tree=(0.46x5 OR -1.00x4 OR 0.25x1z)
# R> tree=(-1.00x5)
# R> tree=(0.17x3 OR -0.18x4 OR -0.02x1 OR 0.10x2)
# R> tree=(-0.11x3 OR -0.31x1 OR 0.02x1z)
# R> tree=(1.00x2 OR -0.67x0 OR -0.48x4 OR -0.21x3 OR -0.20x6 OR 0.12x1z OR 0.05x7)
#
# ======= GENERATION generation_g19 93.18056089458555 =======
# G> G_0: b=2.11; m=0.18; theta=9.16; init=1.00; noise=1.18; expr=1.02; deg=0.10; asym=4.92; tree=(0.10x0 AND 0.07x0z)
# G> G_1: b=2.78; m=6.86; theta=1.57; init=0.84; noise=1.17; expr=1.04; deg=0.08; asym=6.13; tree=(0.79x0z AND -0.61x1 AND -0.15x4)
# G> G_2: b=0.21; m=0.10; theta=6.51; init=0.51; noise=0.57; expr=1.19; deg=0.09; asym=4.35; tree=(0.30x0z AND -0.55x2 AND 0.87x0 AND -0.16x1 AND -0.22x4 AND -0.04x3)
# G> G_3: b=1.45; m=0.72; theta=6.62; init=1.02; noise=1.06; expr=0.97; deg=0.06; asym=5.91; tree=(-0.88x3 AND -0.66x0 AND -0.26x1 AND -0.32x4)
# G> G_4: b=1.03; m=12.59; theta=6.56; init=0.73; noise=1.11; expr=1.00; deg=0.17; asym=3.41; tree=(-0.31x0 AND 0.12x0z AND 0.05x2 AND 0.39x4 AND 0.08x1)
# G> G_5: b=4.07; m=1.67; theta=9.30; init=1.79; noise=0.89; expr=1.12; deg=0.09; asym=4.60; tree=(-0.61x4 AND -0.59x0 AND -0.06x1)
# G> G_6: b=2.17; m=3.73; theta=7.73; init=0.62; noise=1.70; expr=1.44; deg=0.08; asym=4.31; tree=(-0.80x4 AND 0.17x1 AND 0.03x0 AND -0.19x2)
# R> tree=(0.49x5 OR -1.00x4 OR 0.00x1z OR -0.22x6)
# R> tree=(-0.84x5 OR -0.03x1)
# R> tree=(0.04x3 OR -0.15x4)
# R> tree=(0.09x4)
# R> tree=(0.92x2 OR -0.70x0 OR -0.46x4 OR -0.31x3 OR -0.14x6 OR 0.11x1z OR 0.57x5 OR -0.05x1)
#
# ======= GENERATION generation_g20 91.99025204684067 =======
# G> G_0: b=3.05; m=0.22; theta=12.60; init=1.15; noise=1.33; expr=1.04; deg=0.09; asym=4.87; tree=(0.11x0)
# G> G_1: b=2.26; m=7.36; theta=1.75; init=0.75; noise=1.18; expr=1.09; deg=0.07; asym=5.18; tree=(0.79x0z AND -1.00x1 AND -0.01x3 AND 0.17x0 AND 0.18x2)
# G> G_2: b=0.20; m=0.14; theta=6.40; init=0.55; noise=0.45; expr=1.07; deg=0.10; asym=4.80; tree=(0.17x0z AND -0.67x2 AND 1.00x0 AND -0.07x1 AND 0.14x4 AND -0.04x3)
# G> G_3: b=1.86; m=0.84; theta=7.38; init=0.98; noise=1.29; expr=0.94; deg=0.07; asym=3.13; tree=(-0.98x3 AND -0.49x0 AND -0.12x1 AND 0.04x0z)
# G> G_4: b=1.00; m=7.48; theta=7.70; init=0.91; noise=0.93; expr=0.98; deg=0.23; asym=4.69; tree=(-0.57x0 AND -0.06x3 AND 0.20x1 AND 0.17x0z AND 0.29x2 AND 0.26x4)
# G> G_5: b=4.47; m=1.64; theta=9.53; init=1.94; noise=0.80; expr=0.92; deg=0.05; asym=3.83; tree=(-0.49x4 AND -0.59x0 AND 0.14x2)
# G> G_6: b=1.66; m=3.66; theta=8.55; init=0.37; noise=1.21; expr=1.26; deg=0.09; asym=3.38; tree=(-0.85x4 AND 0.05x1 AND 0.06x0 AND 0.27x2 AND 0.04x0z)
# R> tree=(0.19x5 OR -1.00x4 OR 0.25x1z)
# R> tree=(-0.99x5)
# R> tree=(0.04x3 OR -0.30x4 OR -0.15x1 OR 0.10x2)
# R> tree=(-0.17x3 OR -0.16x1)
# R> tree=(0.81x2 OR -0.68x0 OR -0.40x4 OR -0.14x3 OR -0.11x6 OR 0.02x1z OR 0.05x7)
#
# ======= GENERATION generation_g21 90.65101008072614 =======
# G> G_0: b=2.00; m=0.19; theta=12.44; init=1.21; noise=1.33; expr=0.91; deg=0.12; asym=5.24; tree=()
# G> G_1: b=2.30; m=7.13; theta=1.85; init=0.87; noise=1.31; expr=1.10; deg=0.08; asym=5.62; tree=(0.77x0z AND -0.97x1 AND 0.17x0 AND 0.42x2)
# G> G_2: b=0.24; m=0.14; theta=7.77; init=0.50; noise=0.47; expr=1.22; deg=0.10; asym=3.96; tree=(0.08x0z AND -0.91x2 AND 1.00x0 AND -0.04x1 AND 0.15x4 AND -0.11x3)
# G> G_3: b=1.62; m=0.93; theta=7.72; init=1.09; noise=1.13; expr=0.66; deg=0.10; asym=3.69; tree=(-1.00x3 AND -0.49x0 AND -0.09x1 AND 0.17x0z AND 0.08x2 AND 0.07x4)
# G> G_4: b=1.11; m=6.55; theta=7.76; init=0.81; noise=0.97; expr=1.10; deg=0.25; asym=3.80; tree=(-0.62x0 AND -0.28x3 AND 0.22x1 AND 0.06x0z AND 0.57x2 AND 0.26x4)
# G> G_5: b=4.27; m=1.64; theta=10.04; init=2.02; noise=0.77; expr=0.93; deg=0.06; asym=3.66; tree=(-0.49x4 AND -0.44x0 AND 0.06x2 AND 0.08x1)
# G> G_6: b=1.46; m=4.73; theta=7.58; init=0.38; noise=1.27; expr=1.30; deg=0.10; asym=3.76; tree=(-0.67x4 AND 0.15x1 AND 0.05x0)
# R> tree=(0.28x5 OR -1.00x4 OR 0.35x1z)
# R> tree=(-0.94x5 OR -0.12x7 OR 0.11x4)
# R> tree=(-0.21x4)
# R> tree=(-0.10x3 OR -0.30x1)
# R> tree=(0.96x2 OR -0.62x0 OR -0.60x4 OR -0.25x3 OR -0.14x6 OR 0.17x1z OR 0.05x7)
#
# ======= GENERATION generation_g22 92.75555816928964 =======
# G> G_0: b=2.29; m=0.19; theta=9.87; init=1.20; noise=1.21; expr=1.03; deg=0.10; asym=4.73; tree=(0.08x0)
# G> G_1: b=2.09; m=5.76; theta=1.28; init=0.83; noise=1.17; expr=1.04; deg=0.08; asym=4.59; tree=(0.76x0z AND -1.00x1 AND -0.01x3 AND 0.17x0 AND 0.27x2)
# G> G_2: b=0.21; m=0.14; theta=6.68; init=0.50; noise=0.57; expr=1.07; deg=0.11; asym=4.32; tree=(0.17x0z AND -0.64x2 AND 1.00x0 AND -0.22x1 AND 0.02x3)
# G> G_3: b=1.79; m=0.81; theta=9.00; init=1.02; noise=1.27; expr=0.94; deg=0.08; asym=3.00; tree=(-0.91x3 AND -0.49x0 AND 0.06x0z)
# G> G_4: b=0.87; m=9.66; theta=7.87; init=0.83; noise=1.11; expr=1.34; deg=0.16; asym=4.32; tree=(-0.49x0 AND -0.57x3 AND 0.16x1 AND 0.37x0z AND 0.29x2 AND 0.22x4)
# G> G_5: b=3.66; m=1.99; theta=8.61; init=2.84; noise=0.92; expr=0.77; deg=0.08; asym=4.09; tree=(-0.39x4 AND -0.42x0 AND 0.09x0z)
# G> G_6: b=1.83; m=2.58; theta=9.74; init=0.36; noise=1.24; expr=1.40; deg=0.12; asym=2.26; tree=(-0.85x4)
# R> tree=(0.40x5 OR -0.94x4 OR 0.33x1z OR -0.04x6)
# R> tree=(-1.00x5 OR 0.04x4)
# R> tree=(0.04x3 OR -0.22x4 OR 0.28x5 OR -0.02x1)
# R> tree=(-0.26x3 OR -0.05x4 OR 0.16x1z)
# R> tree=(0.99x2 OR -0.80x0 OR -0.51x4 OR -0.22x3 OR -0.36x6 OR 0.32x1z OR 0.15x7 OR 0.11x5)
#
# ======= GENERATION generation_g23 91.89246269213336 =======
# G> G_0: b=2.34; m=0.22; theta=12.64; init=1.25; noise=1.33; expr=1.04; deg=0.10; asym=4.87; tree=(0.01x0)
# G> G_1: b=2.41; m=6.82; theta=1.89; init=0.66; noise=1.19; expr=1.07; deg=0.07; asym=5.79; tree=(0.79x0z AND -0.87x1 AND -0.01x3 AND 0.09x2 AND -0.09x4)
# G> G_2: b=0.20; m=0.15; theta=6.40; init=0.47; noise=0.52; expr=1.07; deg=0.10; asym=4.68; tree=(0.17x0z AND -0.64x2 AND 0.99x0 AND -0.18x1 AND 0.14x4 AND -0.04x3)
# G> G_3: b=1.62; m=0.75; theta=7.82; init=0.97; noise=1.29; expr=0.65; deg=0.09; asym=3.01; tree=(-0.98x3 AND -0.49x0 AND -0.25x1 AND 0.17x0z)
# G> G_4: b=0.83; m=6.70; theta=7.29; init=0.91; noise=0.93; expr=1.05; deg=0.18; asym=4.69; tree=(-0.57x0 AND -0.02x3 AND 0.28x1 AND 0.17x0z AND 0.27x2 AND 0.17x4)
# G> G_5: b=4.57; m=1.56; theta=10.04; init=1.94; noise=0.94; expr=0.92; deg=0.04; asym=4.22; tree=(-0.49x4 AND -0.69x0 AND 0.20x2)
# G> G_6: b=1.66; m=3.58; theta=8.55; init=0.37; noise=1.21; expr=1.29; deg=0.09; asym=3.33; tree=(-0.71x4 AND 0.20x0 AND 0.04x0z)
# R> tree=(0.19x5 OR -1.00x4 OR 0.33x1z)
# R> tree=(-0.99x5 OR 0.18x0)
# R> tree=(-0.25x4 OR -0.14x1 OR 0.16x2)
# R> tree=(-0.22x3 OR 0.10x6)
# R> tree=(0.66x2 OR -0.77x0 OR -0.41x4 OR -0.31x3 OR -0.22x6 OR 0.02x1z OR 0.05x7)
#
# ======= GENERATION generation_g24 89.8915561726518 =======
# G> G_0: b=2.51; m=0.28; theta=12.99; init=1.30; noise=1.10; expr=1.08; deg=0.09; asym=4.68; tree=(0.19x0)
# G> G_1: b=2.41; m=7.85; theta=1.73; init=0.83; noise=1.19; expr=1.21; deg=0.08; asym=6.12; tree=(0.79x0z AND -0.80x1 AND 0.03x0 AND 0.09x2 AND -0.09x4)
# G> G_2: b=0.18; m=0.17; theta=6.55; init=0.58; noise=0.52; expr=1.14; deg=0.09; asym=5.06; tree=(0.17x0z AND -0.65x2 AND 1.00x0 AND 0.14x4 AND -0.23x3)
# G> G_3: b=1.76; m=0.82; theta=8.26; init=0.81; noise=1.56; expr=0.67; deg=0.08; asym=3.32; tree=(-0.98x3 AND -0.49x0 AND -0.24x1 AND 0.22x0z)
# G> G_4: b=0.93; m=7.17; theta=7.02; init=0.91; noise=1.01; expr=1.22; deg=0.19; asym=4.60; tree=(-0.57x0 AND -0.13x3 AND 0.28x1 AND 0.35x0z AND 0.29x2 AND 0.26x4)
# G> G_5: b=4.90; m=1.76; theta=11.56; init=1.76; noise=1.03; expr=0.90; deg=0.04; asym=4.02; tree=(-0.49x4 AND -0.65x0 AND 0.20x2)
# G> G_6: b=1.56; m=3.67; theta=8.18; init=0.37; noise=1.12; expr=1.01; deg=0.07; asym=3.51; tree=(-0.74x4 AND 0.01x1 AND 0.17x0 AND 0.11x2)
# R> tree=(0.27x5 OR -1.00x4 OR 0.32x1z OR 0.08x6)
# R> tree=(-1.00x5 OR 0.38x0 OR 0.02x1z)
# R> tree=(-0.46x4 OR -0.14x1 OR 0.14x2 OR 0.01x6)
# R> tree=(-0.17x3 OR 0.03x6)
# R> tree=(0.66x2 OR -0.77x0 OR -0.35x4 OR -0.25x3 OR -0.11x6 OR 0.08x1z OR 0.04x7 OR -0.34x5)
#
# ======= GENERATION generation_g25 92.21474184275904 =======
# G> G_0: b=2.51; m=0.24; theta=14.51; init=1.09; noise=1.10; expr=1.08; deg=0.09; asym=5.02; tree=(0.19x0 AND -0.01x4 AND 0.02x0z)
# G> G_1: b=2.41; m=7.56; theta=1.73; init=0.83; noise=1.19; expr=1.21; deg=0.08; asym=6.12; tree=(0.79x0z AND -0.80x1 AND 0.16x0 AND 0.15x2 AND -0.09x4)
# G> G_2: b=0.18; m=0.14; theta=7.27; init=0.53; noise=0.58; expr=1.10; deg=0.09; asym=4.92; tree=(0.17x0z AND -0.65x2 AND 1.00x0 AND -0.03x1 AND 0.14x4 AND -0.23x3)
# G> G_3: b=1.76; m=0.82; theta=8.62; init=0.97; noise=1.75; expr=0.63; deg=0.08; asym=3.32; tree=(-1.00x3 AND -0.49x0 AND -0.15x1 AND 0.22x0z)
# G> G_4: b=0.93; m=7.17; theta=7.02; init=0.86; noise=0.92; expr=1.22; deg=0.22; asym=4.60; tree=(-0.57x0 AND -0.13x3 AND 0.28x1 AND 0.51x0z AND 0.29x2 AND 0.26x4)
# G> G_5: b=4.35; m=1.88; theta=11.88; init=1.76; noise=1.03; expr=0.84; deg=0.04; asym=4.24; tree=(-0.50x4 AND -0.61x0 AND 0.20x2)
# G> G_6: b=1.16; m=3.67; theta=6.39; init=0.34; noise=1.12; expr=0.98; deg=0.07; asym=3.94; tree=(-0.74x4 AND 0.09x1 AND 0.18x0 AND 0.07x2 AND 0.01x0z)
# R> tree=(0.22x5 OR -1.00x4 OR 0.32x1z)
# R> tree=(-1.00x5 OR 0.31x0 OR 0.03x1z)
# R> tree=(-0.46x4 OR -0.17x1 OR 0.14x2 OR 0.01x6)
# R> tree=(-0.22x3 OR 0.03x6)
# R> tree=(0.66x2 OR -0.77x0 OR -0.43x4 OR -0.28x3 OR -0.11x6 OR 0.08x1z OR 0.04x7 OR -0.36x5 OR -0.22x1)
#
# ======= GENERATION generation_g26 90.25198946601412 =======
# G> G_0: b=2.66; m=0.24; theta=15.50; init=1.30; noise=1.10; expr=0.99; deg=0.10; asym=4.34; tree=(0.11x0 AND -0.02x4 AND 0.01x2)
# G> G_1: b=2.23; m=8.17; theta=1.58; init=0.83; noise=1.19; expr=1.19; deg=0.08; asym=6.12; tree=(0.79x0z AND -1.00x1 AND 0.05x0 AND 0.09x2 AND -0.09x4 AND -0.20x3)
# G> G_2: b=0.20; m=0.13; theta=7.40; init=0.58; noise=0.52; expr=1.14; deg=0.10; asym=5.06; tree=(0.17x0z AND -0.65x2 AND 0.97x0 AND 0.10x4 AND -0.26x3)
# G> G_3: b=1.48; m=0.85; theta=9.57; init=1.07; noise=1.66; expr=0.67; deg=0.08; asym=3.68; tree=(-0.88x3 AND -0.49x0 AND -0.25x1 AND 0.22x0z)
# G> G_4: b=0.93; m=7.00; theta=6.09; init=1.05; noise=1.01; expr=1.22; deg=0.21; asym=5.01; tree=(-0.62x0 AND 0.16x1 AND 0.35x0z AND 0.17x2 AND 0.26x4)
# G> G_5: b=4.03; m=1.47; theta=9.30; init=2.08; noise=1.03; expr=0.90; deg=0.04; asym=4.14; tree=(-0.43x4 AND -0.65x0 AND 0.20x2)
# G> G_6: b=1.82; m=3.48; theta=10.16; init=0.38; noise=1.09; expr=1.18; deg=0.07; asym=3.51; tree=(-0.81x4 AND 0.18x0 AND 0.02x2 AND 0.01x0z)
# R> tree=(0.22x5 OR -0.91x4 OR 0.32x1z OR -0.22x6)
# R> tree=(-1.00x5 OR 0.38x0 OR 0.02x1z)
# R> tree=(-0.51x4 OR -0.14x1 OR 0.09x2 OR 0.01x0)
# R> tree=(-0.55x3 OR 0.14x6)
# R> tree=(0.66x2 OR -0.77x0 OR -0.60x4 OR -0.32x3 OR -0.31x5)
#
# ======= GENERATION generation_g27 91.03638126602904 =======
# G> G_0: b=2.43; m=0.28; theta=14.21; init=1.30; noise=1.21; expr=1.10; deg=0.11; asym=4.68; tree=(0.15x0 AND -0.01x4)
# G> G_1: b=2.51; m=7.97; theta=1.73; init=0.83; noise=1.30; expr=1.24; deg=0.08; asym=5.30; tree=(0.79x0z AND -0.97x1 AND 0.19x0 AND 0.09x2 AND -0.12x4)
# G> G_2: b=0.19; m=0.13; theta=5.86; init=0.64; noise=0.59; expr=1.04; deg=0.09; asym=5.06; tree=(0.17x0z AND -0.61x2 AND 0.95x0 AND -0.03x1 AND -0.16x3)
# G> G_3: b=1.76; m=0.82; theta=10.06; init=0.93; noise=1.55; expr=0.67; deg=0.08; asym=3.87; tree=(-0.98x3 AND -0.33x0 AND -0.24x1 AND 0.22x0z AND -0.12x2)
# G> G_4: b=0.93; m=6.89; theta=7.54; init=0.93; noise=1.01; expr=1.02; deg=0.21; asym=5.35; tree=(-0.41x0 AND -0.13x3 AND 0.27x1 AND 0.35x0z AND 0.29x2 AND 0.26x4)
# G> G_5: b=4.95; m=1.76; theta=9.94; init=1.79; noise=1.02; expr=0.90; deg=0.04; asym=4.02; tree=(-0.35x4 AND -0.82x0 AND 0.49x2)
# G> G_6: b=1.56; m=3.67; theta=8.18; init=0.28; noise=1.09; expr=1.00; deg=0.07; asym=3.51; tree=(-0.81x4 AND 0.10x1 AND 0.10x0 AND 0.19x2 AND 0.02x0z AND 0.05x3)
# R> tree=(0.22x5 OR -1.00x4 OR 0.35x1z OR -0.12x6 OR 0.14x0 OR -0.05x7)
# R> tree=(-1.00x5 OR 0.38x0 OR 0.02x1z OR 0.01x7)
# R> tree=(-0.46x4 OR -0.49x1 OR 0.15x2 OR 0.01x6)
# R> tree=(-0.49x3 OR 0.03x6)
# R> tree=(0.66x2 OR -0.67x0 OR -0.38x4 OR -0.25x3 OR -0.07x6 OR 0.04x7 OR -0.31x5)
#
# ======= GENERATION generation_g28 91.10780983745761 =======
# G> G_0: b=2.38; m=0.28; theta=14.21; init=1.28; noise=1.21; expr=1.10; deg=0.12; asym=4.29; tree=(-0.01x4)
# G> G_1: b=2.63; m=7.97; theta=2.22; init=0.86; noise=1.24; expr=1.24; deg=0.08; asym=5.20; tree=(0.79x0z AND -0.84x1 AND 0.05x0 AND 0.08x2 AND -0.12x4 AND 0.01x3)
# G> G_2: b=0.18; m=0.13; theta=5.86; init=0.64; noise=0.61; expr=1.00; deg=0.09; asym=4.81; tree=(0.17x0z AND -0.61x2 AND 0.95x0 AND -0.11x3 AND 0.06x4)
# G> G_3: b=1.78; m=0.82; theta=10.17; init=0.84; noise=1.55; expr=0.67; deg=0.09; asym=3.87; tree=(-0.92x3 AND -0.32x0 AND -0.14x1 AND 0.34x0z AND -0.01x2)
# G> G_4: b=0.93; m=6.26; theta=9.44; init=0.93; noise=1.17; expr=1.02; deg=0.21; asym=4.83; tree=(-0.41x0 AND -0.10x3 AND 0.27x1 AND 0.35x0z AND 0.30x2 AND 0.38x4)
# G> G_5: b=4.95; m=1.86; theta=9.94; init=1.79; noise=1.04; expr=0.86; deg=0.04; asym=4.02; tree=(-0.31x4 AND -0.82x0 AND 0.42x2)
# G> G_6: b=1.56; m=3.67; theta=7.36; init=0.28; noise=1.09; expr=1.05; deg=0.07; asym=3.51; tree=(-0.81x4 AND 0.10x1 AND 0.10x0 AND 0.23x2 AND 0.02x0z AND 0.05x3)
# R> tree=(0.22x5 OR -1.00x4 OR 0.27x1z OR -0.21x6 OR 0.16x0 OR -0.13x7 OR 0.09x1)
# R> tree=(-1.00x5 OR 0.43x0 OR 0.02x1z OR 0.01x7)
# R> tree=(-0.55x4 OR -0.49x1 OR 0.20x2 OR 0.05x6)
# R> tree=(-0.49x3 OR 0.03x6)
# R> tree=(0.66x2 OR -0.75x0 OR -0.59x4 OR -0.25x3 OR -0.10x6 OR 0.04x7 OR -0.36x5)
#
# ======= GENERATION generation_g29 91.53000694233273 =======
# G> G_0: b=2.38; m=0.28; theta=14.21; init=1.30; noise=1.15; expr=1.10; deg=0.11; asym=4.29; tree=(-0.01x4)
# G> G_1: b=2.55; m=7.97; theta=1.86; init=0.86; noise=1.34; expr=1.24; deg=0.08; asym=5.20; tree=(0.79x0z AND -0.82x1 AND 0.10x0 AND 0.26x2 AND -0.10x4 AND 0.01x3)
# G> G_2: b=0.19; m=0.13; theta=5.86; init=0.64; noise=0.61; expr=1.00; deg=0.09; asym=4.33; tree=(0.17x0z AND -0.61x2 AND 0.95x0 AND -0.11x3 AND 0.08x4)
# G> G_3: b=1.78; m=1.04; theta=10.17; init=0.99; noise=1.55; expr=0.65; deg=0.07; asym=3.87; tree=(-0.92x3 AND -0.26x0 AND -0.05x1 AND 0.51x0z AND -0.01x2)
# G> G_4: b=0.93; m=6.26; theta=8.97; init=0.93; noise=1.17; expr=0.97; deg=0.21; asym=5.35; tree=(-0.41x0 AND -0.02x3 AND 0.32x1 AND 0.35x0z AND 0.29x2 AND 0.19x4)
# G> G_5: b=5.26; m=1.76; theta=9.54; init=2.21; noise=1.04; expr=0.86; deg=0.04; asym=4.02; tree=(-0.35x4 AND -0.82x0 AND 0.34x2 AND 0.07x0z)
# G> G_6: b=1.56; m=3.67; theta=7.36; init=0.33; noise=1.26; expr=1.05; deg=0.07; asym=3.05; tree=(-0.79x4 AND 0.23x1 AND 0.23x2 AND 0.02x0z AND 0.15x3)
# R> tree=(0.04x5 OR -1.00x4 OR 0.27x1z OR -0.11x6 OR 0.10x0 OR 0.09x2)
# R> tree=(-0.94x5 OR 0.37x0 OR 0.01x7)
# R> tree=(-0.45x4 OR -0.62x1 OR 0.27x2 OR 0.05x6)
# R> tree=(-0.49x3 OR 0.03x6)
# R> tree=(0.66x2 OR -0.75x0 OR -0.38x4 OR -0.25x3 OR -0.01x6 OR 0.15x7 OR -0.36x5)
#
# ======= GENERATION generation_g30 90.36423436397331 =======
# G> G_0: b=2.43; m=0.24; theta=9.95; init=1.59; noise=1.32; expr=1.10; deg=0.10; asym=4.56; tree=(0.15x0 AND -0.13x4)
# G> G_1: b=2.40; m=8.10; theta=1.73; init=0.82; noise=1.27; expr=1.33; deg=0.08; asym=4.38; tree=(0.79x0z AND -0.77x1 AND 0.20x0 AND 0.41x2 AND -0.12x4)
# G> G_2: b=0.25; m=0.13; theta=6.27; init=0.57; noise=0.59; expr=1.12; deg=0.10; asym=5.06; tree=(0.25x0z AND -0.69x2 AND 1.00x0)
# G> G_3: b=1.70; m=0.82; theta=8.82; init=0.93; noise=1.48; expr=0.70; deg=0.08; asym=3.59; tree=(-0.96x3 AND -0.39x0 AND -0.42x1 AND 0.07x0z AND -0.12x2 AND 0.08x4)
# G> G_4: b=0.93; m=7.75; theta=7.58; init=0.97; noise=0.90; expr=0.95; deg=0.21; asym=5.72; tree=(-0.45x0 AND -0.12x3 AND 0.25x1 AND 0.46x0z AND 0.29x2 AND 0.26x4)
# G> G_5: b=4.95; m=1.63; theta=8.98; init=1.54; noise=0.93; expr=1.00; deg=0.04; asym=4.23; tree=(-0.34x4 AND -0.93x0 AND 0.15x2)
# G> G_6: b=1.70; m=3.67; theta=8.32; init=0.29; noise=0.98; expr=0.96; deg=0.08; asym=3.51; tree=(-0.88x4 AND 0.02x0 AND 0.30x2 AND 0.05x0z AND 0.04x3 AND 0.11x1)
# R> tree=(0.22x5 OR -0.93x4 OR 0.35x1z OR 0.14x0 OR -0.08x7)
# R> tree=(-0.90x5 OR 0.39x0 OR 0.02x1z OR 0.21x7 OR 0.11x3 OR 0.08x4)
# R> tree=(-0.46x4 OR -0.80x1 OR 0.02x6 OR 0.28x1z OR -0.10x5)
# R> tree=(-0.30x3 OR 0.00x0 OR -0.17x5)
# R> tree=(0.65x2 OR -0.59x0 OR -0.48x4 OR -0.01x6 OR 0.06x7 OR -0.48x5)
#
# ======= GENERATION generation_g31 91.15526154234536 =======
# G> G_0: b=2.43; m=0.24; theta=14.08; init=1.54; noise=1.32; expr=1.10; deg=0.09; asym=4.56; tree=(0.15x0 AND -0.13x4)
# G> G_1: b=2.40; m=8.92; theta=1.73; init=0.83; noise=1.27; expr=1.26; deg=0.08; asym=4.38; tree=(0.79x0z AND -0.77x1 AND 0.20x0 AND 0.41x2 AND -0.12x4)
# G> G_2: b=0.24; m=0.12; theta=6.27; init=0.59; noise=0.59; expr=1.07; deg=0.09; asym=5.06; tree=(0.25x0z AND -0.65x2 AND 1.00x0 AND -0.11x3)
# G> G_3: b=1.70; m=0.82; theta=8.82; init=0.93; noise=1.65; expr=0.70; deg=0.08; asym=3.57; tree=(-1.00x3 AND -0.48x0 AND -0.32x1 AND 0.07x0z AND -0.12x2 AND 0.08x4)
# G> G_4: b=0.93; m=7.75; theta=7.58; init=0.97; noise=0.90; expr=0.95; deg=0.21; asym=5.72; tree=(-0.45x0 AND -0.12x3 AND 0.42x1 AND 0.50x0z AND 0.29x2 AND 0.26x4)
# G> G_5: b=4.95; m=1.71; theta=8.98; init=1.66; noise=0.79; expr=1.00; deg=0.04; asym=4.36; tree=(-0.34x4 AND -0.93x0 AND 0.30x2)
# G> G_6: b=1.52; m=3.48; theta=8.32; init=0.31; noise=1.10; expr=0.95; deg=0.08; asym=3.51; tree=(-0.88x4 AND 0.02x0 AND 0.30x2 AND 0.05x0z AND 0.04x3)
# R> tree=(0.22x5 OR -0.93x4 OR 0.35x1z OR 0.14x0 OR -0.12x7)
# R> tree=(-0.90x5 OR 0.39x0 OR 0.02x1z OR 0.21x7 OR 0.28x3 OR 0.09x4)
# R> tree=(-0.72x4 OR -0.80x1 OR 0.03x6 OR 0.28x1z)
# R> tree=(-0.30x3 OR 0.00x0 OR -0.17x5)
# R> tree=(0.65x2 OR -0.59x0 OR -0.50x4 OR -0.14x3 OR -0.01x6 OR 0.06x7 OR -0.48x5)
#
# ======= GENERATION generation_g32 91.238494948162 =======
# G> G_0: b=2.57; m=0.28; theta=14.54; init=1.30; noise=1.15; expr=1.04; deg=0.11; asym=3.84; tree=(-0.01x4 AND 0.12x2)
# G> G_1: b=2.55; m=7.36; theta=1.96; init=0.82; noise=1.43; expr=1.24; deg=0.08; asym=5.63; tree=(0.79x0z AND -0.85x1 AND 0.10x0 AND 0.13x2 AND -0.10x4)
# G> G_2: b=0.21; m=0.15; theta=5.32; init=0.56; noise=0.61; expr=1.04; deg=0.09; asym=4.33; tree=(0.17x0z AND -0.61x2 AND 0.95x0 AND -0.25x3 AND 0.12x4 AND -0.16x1)
# G> G_3: b=1.78; m=1.04; theta=11.68; init=0.97; noise=1.26; expr=0.58; deg=0.07; asym=3.87; tree=(-0.92x3 AND -0.34x0 AND -0.05x1 AND 0.62x0z)
# G> G_4: b=0.93; m=6.91; theta=8.57; init=0.93; noise=1.15; expr=0.97; deg=0.21; asym=6.10; tree=(-0.39x0 AND -0.22x3 AND 0.32x1 AND 0.30x0z AND 0.46x2 AND 0.24x4)
# G> G_5: b=5.26; m=1.76; theta=9.96; init=2.21; noise=1.04; expr=0.77; deg=0.04; asym=4.02; tree=(-0.55x4 AND -0.72x0 AND 0.54x2 AND 0.07x0z AND -0.10x3)
# G> G_6: b=1.34; m=3.67; theta=6.45; init=0.33; noise=1.26; expr=1.03; deg=0.06; asym=3.05; tree=(-0.79x4 AND 0.16x1 AND 0.23x2 AND 0.15x3)
# R> tree=(-1.00x4 OR 0.25x1z OR -0.11x6 OR 0.09x0 OR -0.08x5)
# R> tree=(-0.96x5 OR 0.16x0 OR -0.16x4)
# R> tree=(-0.34x4 OR -0.51x1 OR 0.27x2)
# R> tree=(-0.49x3 OR 0.03x6 OR -0.01x2)
# R> tree=(0.65x2 OR -0.84x0 OR -0.55x4 OR -0.25x3 OR 0.05x7 OR -0.22x5)
#
# ======= GENERATION generation_g33 89.57948110365878 =======
# G> G_0: b=2.57; m=0.28; theta=14.54; init=1.30; noise=1.15; expr=1.04; deg=0.13; asym=3.80; tree=(-0.01x4)
# G> G_1: b=3.00; m=7.36; theta=1.82; init=1.03; noise=1.47; expr=1.24; deg=0.08; asym=5.63; tree=(0.79x0z AND -0.85x1 AND 0.10x0 AND 0.26x2 AND -0.20x4 AND 0.01x3)
# G> G_2: b=0.14; m=0.15; theta=5.86; init=0.60; noise=0.61; expr=1.04; deg=0.09; asym=4.33; tree=(0.17x0z AND -0.61x2 AND 0.95x0 AND -0.11x3 AND 0.09x4)
# G> G_3: b=1.87; m=1.04; theta=11.68; init=1.00; noise=1.23; expr=0.67; deg=0.07; asym=3.87; tree=(-0.90x3 AND -0.26x0 AND -0.05x1 AND 0.53x0z)
# G> G_4: b=0.98; m=6.91; theta=8.21; init=0.99; noise=1.33; expr=0.99; deg=0.21; asym=6.09; tree=(-0.43x0 AND -0.22x3 AND 0.31x1 AND 0.35x0z AND 0.46x2 AND 0.19x4)
# G> G_5: b=5.26; m=2.24; theta=9.96; init=2.21; noise=1.04; expr=0.77; deg=0.04; asym=3.87; tree=(-0.73x4 AND -0.85x0 AND 0.34x2 AND -0.10x3 AND 0.03x1)
# G> G_6: b=1.56; m=3.25; theta=7.05; init=0.33; noise=1.36; expr=1.17; deg=0.07; asym=3.05; tree=(-0.79x4 AND 0.09x1 AND 0.23x2 AND 0.15x3)
# R> tree=(-0.97x4 OR 0.29x1z OR -0.11x6 OR 0.04x2 OR -0.14x5 OR -0.08x3)
# R> tree=(-0.96x5 OR 0.37x0 OR -0.16x4 OR 0.03x2)
# R> tree=(-0.51x4 OR -0.40x1 OR 0.31x2 OR 0.09x0)
# R> tree=(-0.49x3 OR 0.03x6 OR -0.01x2)
# R> tree=(0.63x2 OR -0.79x0 OR -0.55x4 OR 0.05x7 OR -0.45x5)
#
# ======= GENERATION generation_g34 90.83229963337598 =======
# G> G_0: b=2.57; m=0.27; theta=14.54; init=1.35; noise=1.11; expr=1.04; deg=0.11; asym=3.84; tree=(-0.01x4)
# G> G_1: b=2.72; m=7.36; theta=2.27; init=0.82; noise=1.45; expr=1.24; deg=0.08; asym=5.64; tree=(0.77x0z AND -0.85x1 AND 0.19x0 AND 0.13x2 AND -0.21x4 AND 0.11x3)
# G> G_2: b=0.19; m=0.15; theta=5.86; init=0.60; noise=0.65; expr=1.07; deg=0.07; asym=4.15; tree=(0.18x0z AND -0.73x2 AND 0.95x0 AND -0.11x3 AND 0.31x4 AND -0.10x1)
# G> G_3: b=1.78; m=1.21; theta=11.68; init=1.01; noise=1.16; expr=0.58; deg=0.08; asym=3.87; tree=(-0.90x3 AND -0.08x0 AND 0.49x0z)
# G> G_4: b=0.84; m=6.91; theta=8.21; init=1.05; noise=0.98; expr=0.99; deg=0.21; asym=6.32; tree=(-0.43x0 AND -0.19x3 AND 0.32x1 AND 0.35x0z AND 0.40x2 AND 0.24x4)
# G> G_5: b=5.26; m=2.00; theta=9.96; init=2.21; noise=0.84; expr=0.77; deg=0.04; asym=3.55; tree=(-0.56x4 AND -0.77x0 AND 0.34x2 AND -0.24x3 AND 0.12x0z)
# G> G_6: b=1.56; m=3.67; theta=6.91; init=0.33; noise=1.36; expr=1.07; deg=0.07; asym=3.87; tree=(-0.75x4 AND 0.23x2 AND 0.31x3)
# R> tree=(-0.97x4 OR 0.46x1z OR -0.11x6 OR 0.11x2 OR -0.14x5 OR -0.08x3)
# R> tree=(-0.97x5 OR 0.51x0 OR -0.16x4 OR -0.04x6)
# R> tree=(-0.41x4 OR -0.57x1 OR 0.41x2 OR 0.09x0)
# R> tree=(-0.49x3 OR 0.04x6 OR -0.09x2 OR -0.09x5)
# R> tree=(0.65x2 OR -0.84x0 OR -0.55x4 OR -0.25x3 OR 0.03x7 OR -0.45x5)
#
# ======= GENERATION generation_g35 88.87549987664451 =======
# G> G_0: b=2.57; m=0.27; theta=14.54; init=1.42; noise=1.03; expr=0.86; deg=0.11; asym=3.84; tree=(-0.14x4)
# G> G_1: b=2.72; m=7.32; theta=2.09; init=0.82; noise=1.51; expr=1.24; deg=0.08; asym=5.64; tree=(0.77x0z AND -0.89x1 AND 0.36x0 AND 0.13x2 AND -0.20x4 AND 0.13x3)
# G> G_2: b=0.19; m=0.15; theta=5.89; init=0.63; noise=0.65; expr=0.85; deg=0.09; asym=4.15; tree=(0.18x0z AND -0.76x2 AND 1.00x0 AND 0.26x4 AND -0.10x1)
# G> G_3: b=1.78; m=0.98; theta=11.68; init=1.02; noise=1.16; expr=0.50; deg=0.08; asym=3.81; tree=(-0.90x3 AND -0.26x0 AND 0.31x0z AND 0.05x2)
# G> G_4: b=0.83; m=6.91; theta=8.21; init=1.05; noise=0.98; expr=1.09; deg=0.22; asym=6.82; tree=(-0.44x0 AND -0.22x3 AND 0.32x1 AND 0.35x0z AND 0.36x2 AND 0.18x4)
# G> G_5: b=6.12; m=1.97; theta=9.96; init=2.24; noise=1.07; expr=0.77; deg=0.04; asym=3.45; tree=(-0.56x4 AND -0.76x0 AND 0.34x2 AND -0.24x3 AND 0.04x0z)
# G> G_6: b=1.56; m=3.67; theta=6.91; init=0.32; noise=1.68; expr=1.02; deg=0.07; asym=3.51; tree=(-0.75x4 AND 0.23x2 AND 0.20x3 AND 0.10x0z AND -0.04x0 AND -0.04x1)
# R> tree=(-0.97x4 OR 0.46x1z OR -0.11x6 OR -0.14x5 OR -0.01x3)
# R> tree=(-0.97x5 OR 0.51x0 OR -0.06x4 OR -0.02x3)
# R> tree=(-0.31x4 OR -0.51x1 OR 0.54x2 OR 0.09x0)
# R> tree=(-0.49x3 OR 0.04x6 OR -0.06x2 OR -0.09x5)
# R> tree=(0.69x2 OR -0.91x0 OR -0.55x4 OR -0.25x3 OR -0.38x5 OR -0.16x1)
#
# ======= GENERATION generation_g36 90.95278066244772 =======
# G> G_0: b=2.57; m=0.28; theta=14.54; init=1.06; noise=1.11; expr=1.04; deg=0.09; asym=3.84; tree=()
# G> G_1: b=2.72; m=6.76; theta=2.21; init=0.82; noise=1.40; expr=1.24; deg=0.08; asym=7.43; tree=(0.77x0z AND -0.85x1 AND 0.35x0 AND 0.07x2 AND -0.07x4 AND 0.11x3)
# G> G_2: b=0.18; m=0.17; theta=5.86; init=0.60; noise=0.65; expr=1.07; deg=0.07; asym=3.87; tree=(0.19x0z AND -0.69x2 AND 1.00x0 AND -0.11x3 AND 0.43x4 AND -0.11x1)
# G> G_3: b=2.19; m=1.21; theta=11.41; init=1.01; noise=1.03; expr=0.58; deg=0.08; asym=4.36; tree=(-0.84x3 AND -0.14x0 AND 0.54x0z)
# G> G_4: b=0.86; m=7.08; theta=7.11; init=1.22; noise=1.05; expr=0.93; deg=0.21; asym=6.32; tree=(-0.43x0 AND -0.24x3 AND 0.32x1 AND 0.35x0z AND 0.24x2 AND 0.24x4)
# G> G_5: b=5.26; m=1.78; theta=9.96; init=2.02; noise=0.86; expr=0.64; deg=0.04; asym=3.55; tree=(-0.65x4 AND -0.79x0 AND 0.28x2 AND -0.24x3 AND 0.18x0z)
# G> G_6: b=1.49; m=3.67; theta=5.70; init=0.33; noise=1.36; expr=1.01; deg=0.07; asym=3.87; tree=(-0.75x4 AND 0.23x2 AND 0.31x3)
# R> tree=(-0.97x4 OR 0.37x1z OR -0.11x6 OR 0.11x2 OR -0.28x5 OR -0.08x3)
# R> tree=(-0.99x5 OR 0.52x0 OR -0.16x4 OR -0.04x6 OR 0.09x2 OR 0.06x3)
# R> tree=(-0.54x4 OR -0.56x1 OR 0.41x2 OR 0.09x0)
# R> tree=(-0.49x3 OR 0.04x6 OR -0.00x7)
# R> tree=(0.65x2 OR -0.81x0 OR -0.47x4 OR 0.03x7 OR -0.45x5)
#
# ======= GENERATION generation_g37 90.98536085786579 =======
# G> G_0: b=2.36; m=0.27; theta=13.93; init=1.25; noise=1.11; expr=1.04; deg=0.11; asym=3.84; tree=()
# G> G_1: b=2.86; m=6.76; theta=2.21; init=0.82; noise=1.40; expr=1.05; deg=0.07; asym=6.87; tree=(0.75x0z AND -0.85x1 AND 0.38x0 AND 0.13x2 AND -0.01x4 AND 0.11x3)
# G> G_2: b=0.16; m=0.17; theta=5.86; init=0.60; noise=0.66; expr=1.07; deg=0.07; asym=4.14; tree=(0.21x0z AND -0.69x2 AND 1.00x0 AND -0.11x3 AND 0.43x4 AND -0.11x1)
# G> G_3: b=2.09; m=1.21; theta=11.68; init=1.01; noise=1.16; expr=0.58; deg=0.07; asym=4.36; tree=(-0.78x3 AND -0.14x0 AND 0.66x0z)
# G> G_4: b=0.64; m=6.91; theta=7.11; init=1.22; noise=1.17; expr=0.89; deg=0.23; asym=6.32; tree=(-0.32x0 AND -0.24x3 AND 0.32x1 AND 0.35x0z AND 0.24x2 AND 0.24x4)
# G> G_5: b=5.26; m=1.78; theta=11.05; init=2.21; noise=0.84; expr=0.64; deg=0.04; asym=3.55; tree=(-0.65x4 AND -0.94x0 AND 0.25x2 AND -0.24x3 AND 0.12x0z)
# G> G_6: b=1.48; m=3.61; theta=6.53; init=0.33; noise=1.36; expr=1.01; deg=0.08; asym=3.87; tree=(-0.75x4 AND 0.13x2)
# R> tree=(-0.93x4 OR 0.37x1z OR -0.11x6 OR 0.07x2 OR -0.15x5 OR -0.07x1)
# R> tree=(-0.99x5 OR 0.52x0 OR -0.21x4 OR -0.04x6 OR 0.09x2)
# R> tree=(-0.62x4 OR -0.56x1 OR 0.41x2 OR 0.09x0)
# R> tree=(-0.49x3 OR 0.04x6 OR -0.04x5)
# R> tree=(0.65x2 OR -0.81x0 OR -0.46x4 OR -0.29x3 OR 0.03x7 OR -0.45x5)
#
# ======= GENERATION generation_g38 92.29971943795793 =======
# G> G_0: b=2.74; m=0.25; theta=15.52; init=0.88; noise=1.04; expr=1.04; deg=0.09; asym=3.84; tree=(0.08x2)
# G> G_1: b=2.23; m=7.02; theta=1.94; init=0.73; noise=1.40; expr=1.24; deg=0.10; asym=7.43; tree=(0.77x0z AND -0.85x1 AND 0.31x0 AND -0.07x4 AND 0.14x3)
# G> G_2: b=0.18; m=0.15; theta=5.98; init=0.52; noise=0.60; expr=1.07; deg=0.06; asym=3.87; tree=(0.19x0z AND -0.69x2 AND 1.00x0 AND -0.19x3 AND 0.43x4 AND -0.19x1)
# G> G_3: b=2.39; m=1.20; theta=9.99; init=1.01; noise=0.92; expr=0.50; deg=0.08; asym=4.36; tree=(-0.84x3 AND -0.10x0 AND 0.63x0z)
# G> G_4: b=0.77; m=7.08; theta=7.11; init=1.22; noise=1.03; expr=0.93; deg=0.22; asym=4.84; tree=(-0.29x0 AND -0.24x3 AND 0.32x1 AND 0.52x0z AND 0.24x2 AND 0.28x4)
# G> G_5: b=5.09; m=1.78; theta=10.95; init=1.72; noise=0.86; expr=0.70; deg=0.04; asym=3.55; tree=(-0.50x4 AND -0.79x0 AND 0.15x2 AND -0.36x3 AND 0.18x0z)
# G> G_6: b=1.41; m=3.67; theta=5.70; init=0.33; noise=1.36; expr=1.01; deg=0.07; asym=3.87; tree=(-0.76x4 AND 0.23x2 AND 0.55x3)
# R> tree=(-1.00x4 OR 0.47x1z OR -0.11x6 OR 0.11x2 OR -0.37x5 OR -0.14x3 OR -0.11x0)
# R> tree=(-0.99x5 OR 0.52x0 OR -0.16x4 OR -0.04x6 OR 0.31x2)
# R> tree=(-0.59x4 OR -0.54x1 OR 0.36x2 OR 0.21x0)
# R> tree=(-0.29x3 OR 0.27x6 OR -0.00x7)
# R> tree=(0.65x2 OR -0.66x0 OR -0.45x4 OR 0.03x7 OR -0.45x5)
#
# ======= GENERATION generation_g39 91.95809355510548 =======
# G> G_0: b=2.74; m=0.25; theta=15.52; init=0.88; noise=1.15; expr=1.04; deg=0.09; asym=3.84; tree=(0.11x2)
# G> G_1: b=1.99; m=6.73; theta=1.94; init=0.78; noise=1.31; expr=1.24; deg=0.10; asym=7.43; tree=(0.77x0z AND -0.85x1 AND 0.27x0 AND -0.07x4 AND 0.14x3)
# G> G_2: b=0.18; m=0.15; theta=5.98; init=0.47; noise=0.59; expr=1.07; deg=0.06; asym=3.87; tree=(0.19x0z AND -0.68x2 AND 1.00x0 AND -0.19x3 AND 0.43x4 AND -0.18x1)
# G> G_3: b=2.39; m=1.13; theta=9.99; init=1.01; noise=0.92; expr=0.50; deg=0.08; asym=4.36; tree=(-0.83x3 AND -0.17x0 AND 0.51x0z AND 0.09x4)
# G> G_4: b=0.82; m=7.46; theta=8.31; init=1.22; noise=1.04; expr=0.93; deg=0.22; asym=4.81; tree=(-0.37x0 AND -0.16x3 AND 0.32x1 AND 0.52x0z AND 0.35x2 AND 0.28x4)
# G> G_5: b=5.09; m=1.67; theta=10.68; init=1.72; noise=0.86; expr=0.70; deg=0.04; asym=3.74; tree=(-0.32x4 AND -0.74x0 AND 0.15x2 AND -0.36x3 AND 0.34x0z)
# ...
# R> tree=(-0.59x4 OR -0.54x1 OR 0.28x2 OR 0.13x0)
# R> tree=(-0.41x3 OR 0.27x6 OR -0.02x7)
# R> tree=(0.62x2 OR -0.72x0 OR -0.45x4 OR 0.03x7 OR -0.45x5)
#
# ======= GENERATION generation_g40 92.53876518276695 =======
# G> G_0: b=2.74; m=0.26; theta=15.52; init=0.71; noise=1.04; expr=1.05; deg=0.09; asym=3.84; tree=(0.23x2)
# G> G_1: b=2.23; m=7.02; theta=1.94; init=0.79; noise=1.40; expr=1.20; deg=0.10; asym=7.43; tree=(0.77x0z AND -0.85x1 AND 0.31x0 AND -0.10x4 AND 0.14x3)
# G> G_2: b=0.18; m=0.15; theta=5.43; init=0.50; noise=0.60; expr=1.07; deg=0.06; asym=4.17; tree=(0.19x0z AND -0.69x2 AND 1.00x0 AND -0.30x3 AND 0.53x4 AND -0.19x1)
# G> G_3: b=2.61; m=1.20; theta=10.92; init=1.01; noise=0.95; expr=0.50; deg=0.08; asym=4.36; tree=(-0.86x3 AND -0.25x0 AND 0.78x0z AND 0.07x4)
# G> G_4: b=0.77; m=7.08; theta=7.11; init=1.22; noise=1.03; expr=0.93; deg=0.22; asym=4.84; tree=(-0.21x0 AND -0.10x3 AND 0.32x1 AND 0.46x0z AND 0.24x2 AND 0.43x4)
# G> G_5: b=5.09; m=1.78; theta=10.95; init=1.72; noise=0.86; expr=0.70; deg=0.04; asym=3.55; tree=(-0.50x4 AND -0.78x0 AND -0.36x3 AND 0.20x0z)
# G> G_6: b=1.42; m=3.67; theta=5.95; init=0.33; noise=1.36; expr=1.16; deg=0.08; asym=3.53; tree=(-0.76x4 AND 0.23x2 AND 0.55x3)
# R> tree=(-1.00x4 OR 0.47x1z OR -0.11x6 OR 0.11x2 OR -0.37x5 OR -0.14x3 OR -0.11x0)
# R> tree=(-0.83x5 OR 0.52x0 OR -0.16x4 OR 0.31x2)
# R> tree=(-0.59x4 OR -0.54x1 OR 0.36x2 OR 0.21x0)
# R> tree=(-0.28x3 OR 0.27x6 OR -0.00x7)
# R> tree=(0.65x2 OR -0.66x0 OR -0.45x4 OR 0.03x7 OR -0.43x5)
#
# ======= GENERATION generation_g41 91.38332004153925 =======
# G> G_0: b=2.54; m=0.24; theta=14.33; init=1.17; noise=1.70; expr=1.04; deg=0.16; asym=4.26; tree=(0.06x2)
# G> G_1: b=2.86; m=6.02; theta=3.42; init=0.86; noise=1.32; expr=0.92; deg=0.08; asym=7.40; tree=(0.62x0z AND -0.80x1 AND 0.37x0 AND 0.34x2 AND -0.03x4 AND 0.07x3)
# G> G_2: b=0.19; m=0.19; theta=4.02; init=0.77; noise=0.66; expr=1.04; deg=0.06; asym=3.82; tree=(0.21x0z AND -0.46x2 AND 1.00x0 AND -0.29x3 AND 0.52x4 AND -0.23x1)
# G> G_3: b=2.11; m=1.08; theta=11.17; init=0.73; noise=1.13; expr=0.63; deg=0.08; asym=6.37; tree=(-0.72x3 AND -0.10x0 AND 0.78x0z)
# G> G_4: b=0.70; m=6.90; theta=5.15; init=1.41; noise=0.86; expr=0.69; deg=0.26; asym=5.66; tree=(-0.64x0 AND -0.21x3 AND 0.26x1 AND 0.33x0z AND 0.47x2 AND 0.29x4)
# G> G_5: b=3.66; m=2.70; theta=8.71; init=1.28; noise=0.83; expr=0.79; deg=0.04; asym=4.30; tree=(-0.78x4 AND -0.72x0 AND 0.13x2 AND 0.15x0z AND 0.09x1)
# G> G_6: b=1.48; m=2.41; theta=7.18; init=0.37; noise=1.28; expr=0.99; deg=0.05; asym=4.65; tree=(-0.56x4 AND 0.13x2 AND 0.05x3)
# R> tree=(-0.63x4 OR 0.41x1z OR -0.11x6 OR 0.10x2 OR -0.28x3 OR -0.41x1)
# R> tree=(-1.00x5 OR 0.45x0 OR -0.16x4 OR 0.08x2)
# R> tree=(-0.56x4 OR -0.43x1 OR 0.20x2 OR 0.19x0)
# R> tree=(-0.45x3 OR 0.08x6 OR -0.38x5)
# R> tree=(0.50x2 OR -0.55x0 OR -0.43x4 OR -0.43x3 OR 0.08x7 OR -0.77x5 OR 0.17x1z OR 0.08x6)
#
# ======= GENERATION generation_g42 89.57362888928412 =======
# G> G_0: b=2.59; m=0.27; theta=14.33; init=1.17; noise=1.70; expr=1.04; deg=0.16; asym=4.06; tree=()
# G> G_1: b=2.86; m=6.02; theta=3.42; init=0.86; noise=1.32; expr=0.96; deg=0.08; asym=7.40; tree=(0.62x0z AND -0.87x1 AND 0.37x0 AND 0.34x2 AND -0.08x4)
# G> G_2: b=0.19; m=0.19; theta=4.02; init=0.77; noise=0.68; expr=1.08; deg=0.06; asym=3.82; tree=(0.21x0z AND -0.46x2 AND 1.00x0 AND -0.29x3 AND 0.39x4 AND -0.23x1)
# G> G_3: b=2.13; m=1.21; theta=11.17; init=0.83; noise=1.13; expr=0.63; deg=0.09; asym=6.24; tree=(-0.83x3 AND -0.10x0 AND 0.77x0z)
# G> G_4: b=0.70; m=6.90; theta=5.15; init=1.52; noise=0.86; expr=0.68; deg=0.21; asym=5.66; tree=(-0.64x0 AND -0.21x3 AND 0.26x1 AND 0.33x0z AND 0.47x2 AND 0.19x4)
# G> G_5: b=3.66; m=2.52; theta=8.71; init=1.28; noise=0.85; expr=0.79; deg=0.03; asym=4.30; tree=(-0.78x4 AND -0.74x0 AND 0.13x2 AND 0.20x0z)
# G> G_6: b=1.48; m=2.44; theta=7.81; init=0.37; noise=1.28; expr=0.99; deg=0.06; asym=4.65; tree=(-0.52x4 AND 0.13x2 AND 0.05x3)
# R> tree=(-0.63x4 OR 0.17x1z OR -0.09x6 OR 0.27x2 OR -0.08x5 OR -0.36x3 OR -0.41x1)
# R> tree=(-1.00x5 OR 0.45x0 OR -0.09x4)
# R> tree=(-0.46x4 OR -0.43x1 OR 0.28x2 OR 0.19x0)
# R> tree=(-0.45x3 OR 0.10x6 OR -0.56x5)
# R> tree=(0.47x2 OR -0.26x0 OR -0.43x4 OR -0.52x3 OR 0.08x7 OR -0.77x5 OR 0.16x1z OR 0.08x6)
#
# ======= GENERATION generation_g43 92.91142501420023 =======
# G> G_0: b=2.37; m=0.24; theta=14.35; init=1.17; noise=1.92; expr=1.04; deg=0.13; asym=4.26; tree=(0.06x2 AND 0.03x0z)
# G> G_1: b=2.65; m=5.88; theta=3.22; init=0.86; noise=1.32; expr=0.92; deg=0.08; asym=6.80; tree=(0.62x0z AND -0.80x1 AND 0.37x0 AND 0.34x2 AND -0.03x4 AND 0.07x3)
# G> G_2: b=0.24; m=0.18; theta=3.95; init=0.77; noise=0.66; expr=1.04; deg=0.06; asym=3.82; tree=(0.37x0z AND -0.47x2 AND 1.00x0 AND -0.09x3 AND 0.52x4 AND -0.23x1)
# G> G_3: b=2.11; m=1.08; theta=11.17; init=0.67; noise=1.13; expr=0.65; deg=0.08; asym=5.83; tree=(-0.72x3 AND -0.10x0 AND 0.74x0z)
# G> G_4: b=0.76; m=8.47; theta=5.15; init=1.61; noise=0.86; expr=0.68; deg=0.26; asym=5.80; tree=(-0.70x0 AND -0.21x3 AND 0.22x1 AND 0.33x0z AND 0.47x2 AND 0.39x4)
# G> G_5: b=3.66; m=2.58; theta=7.63; init=1.17; noise=0.83; expr=0.79; deg=0.04; asym=4.30; tree=(-0.85x4 AND -0.87x0 AND 0.13x2 AND 0.15x0z AND 0.09x1)
# G> G_6: b=1.17; m=2.41; theta=7.18; init=0.36; noise=1.31; expr=1.05; deg=0.05; asym=5.05; tree=(-0.56x4 AND 0.14x2 AND 0.04x3)
# R> tree=(-0.63x4 OR 0.31x1z OR -0.05x6 OR 0.10x2 OR -0.28x3 OR -0.59x1 OR -0.06x0)
# R> tree=(-0.82x5 OR 0.56x0 OR -0.18x4 OR 0.08x2 OR -0.12x3)
# R> tree=(-0.61x4 OR -0.68x1 OR 0.21x2 OR 0.16x0)
# R> tree=(-0.42x3 OR 0.08x6 OR -0.38x5 OR 0.06x0)
# R> tree=(0.51x2 OR -0.55x0 OR -0.30x4 OR -0.43x3 OR 0.08x7 OR -0.77x5 OR 0.04x1z OR 0.08x6)
#
# ======= GENERATION generation_g44 92.69713929991451 =======
# G> G_0: b=2.47; m=0.24; theta=15.13; init=1.27; noise=1.75; expr=1.04; deg=0.13; asym=3.72; tree=(0.03x0z)
# G> G_1: b=2.65; m=4.89; theta=3.42; init=0.94; noise=1.32; expr=0.92; deg=0.07; asym=7.72; tree=(0.62x0z AND -0.75x1 AND 0.37x0 AND 0.34x2 AND -0.03x4 AND 0.07x3)
# G> G_2: b=0.19; m=0.17; theta=4.02; init=0.82; noise=0.66; expr=1.04; deg=0.06; asym=2.90; tree=(0.21x0z AND -0.52x2 AND 1.00x0 AND -0.29x3 AND 0.35x4 AND -0.04x1)
# G> G_3: b=2.05; m=1.08; theta=11.24; init=0.54; noise=1.13; expr=0.57; deg=0.07; asym=5.70; tree=(-0.77x3 AND -0.10x0 AND 0.80x0z)
# G> G_4: b=0.72; m=7.78; theta=5.15; init=1.61; noise=0.84; expr=0.68; deg=0.26; asym=5.91; tree=(-0.70x0 AND -0.21x3 AND 0.22x1 AND 0.22x0z AND 0.47x2 AND 0.40x4)
# G> G_5: b=3.66; m=2.58; theta=7.72; init=1.28; noise=0.90; expr=0.79; deg=0.04; asym=3.99; tree=(-0.85x4 AND -0.72x0 AND 0.11x2 AND 0.15x0z AND 0.01x1 AND 0.11x3)
# G> G_6: b=1.48; m=2.41; theta=7.18; init=0.39; noise=1.28; expr=0.99; deg=0.05; asym=5.05; tree=(-0.56x4 AND 0.21x2)
# R> tree=(-0.64x4 OR 0.31x1z OR -0.16x6 OR 0.10x2 OR -0.28x3 OR -0.65x1 OR -0.06x0)
# R> tree=(-0.97x5 OR 0.45x0 OR -0.16x4 OR 0.21x2)
# R> tree=(-0.56x4 OR -0.68x1 OR 0.21x2 OR 0.14x0)
# R> tree=(-0.42x3 OR 0.20x6 OR -0.52x5)
# R> tree=(0.51x2 OR -0.55x0 OR -0.43x4 OR -0.43x3 OR 0.08x7 OR -0.77x5 OR 0.17x1z OR 0.08x6)
#
# ======= GENERATION generation_g45 90.92413636806987 =======
# G> G_0: b=2.28; m=0.26; theta=13.78; init=1.25; noise=1.01; expr=1.07; deg=0.09; asym=4.16; tree=(0.14x3 AND -0.04x0)
# G> G_1: b=2.85; m=7.83; theta=2.38; init=0.57; noise=1.19; expr=1.26; deg=0.07; asym=5.07; tree=(0.75x0z AND -0.64x1 AND 0.50x0 AND 0.33x2 AND 0.16x3 AND 0.02x4)
# G> G_2: b=0.16; m=0.16; theta=5.62; init=0.66; noise=0.62; expr=1.03; deg=0.05; asym=3.38; tree=(0.21x0z AND -0.58x2 AND 0.86x0 AND -0.25x3 AND 0.54x4 AND -0.21x1)
# G> G_3: b=2.01; m=1.43; theta=11.41; init=0.97; noise=0.72; expr=0.51; deg=0.05; asym=6.14; tree=(-0.98x3 AND 0.49x0z AND 0.13x2 AND -0.01x4 AND 0.11x1 AND 0.10x0)
# G> G_4: b=0.63; m=4.14; theta=6.28; init=0.95; noise=1.28; expr=0.96; deg=0.22; asym=5.36; tree=(-0.27x0 AND -0.17x3 AND 0.17x1 AND 0.42x0z AND 0.46x2 AND 0.15x4)
# G> G_5: b=5.04; m=1.73; theta=10.28; init=1.75; noise=1.25; expr=0.62; deg=0.05; asym=3.37; tree=(-0.69x4 AND -0.70x0 AND -0.47x3 AND 0.11x0z AND -0.00x1)
# G> G_6: b=1.54; m=3.91; theta=6.67; init=0.35; noise=1.09; expr=1.07; deg=0.10; asym=4.05; tree=(-0.97x4 AND -0.02x3 AND -0.30x0)
# R> tree=(-0.90x4 OR 0.71x1z OR -0.43x5 OR -0.03x1 OR -0.12x0 OR 0.36x6 OR -0.30x2)
# R> tree=(-0.83x5 OR 0.13x0 OR -0.22x4 OR -0.04x6 OR 0.14x2 OR 0.08x1z OR -0.08x3)
# R> tree=(-0.78x4 OR -0.54x1 OR 0.46x2 OR 0.48x0 OR 0.05x3 OR -0.02x6)
# R> tree=(-0.83x3 OR 0.03x2 OR 0.26x1z)
# R> tree=(0.30x2 OR -0.56x0 OR -0.40x4 OR -0.04x3 OR -0.37x5 OR 0.00x1z OR 0.16x1)
#
# ======= GENERATION generation_g46 90.33559006959545 =======
# G> G_0: b=2.28; m=0.23; theta=15.14; init=1.36; noise=1.01; expr=1.08; deg=0.08; asym=4.07; tree=(0.35x3 AND -0.03x0)
# G> G_1: b=3.09; m=9.27; theta=2.28; init=0.57; noise=1.39; expr=1.04; deg=0.07; asym=5.83; tree=(0.75x0z AND -0.59x1 AND 0.52x0 AND 0.18x2 AND 0.21x3 AND 0.09x4)
# G> G_2: b=0.16; m=0.15; theta=5.32; init=0.72; noise=0.56; expr=0.95; deg=0.07; asym=3.14; tree=(0.21x0z AND -0.58x2 AND 0.73x0 AND -0.21x3 AND 0.53x4 AND -0.21x1)
# G> G_3: b=1.76; m=1.31; theta=10.38; init=0.67; noise=0.93; expr=0.46; deg=0.05; asym=8.04; tree=(-0.80x3 AND 0.54x0z AND 0.30x2 AND -0.10x4 AND 0.17x1 AND -0.13x0)
# G> G_4: b=0.61; m=4.14; theta=5.50; init=0.84; noise=1.28; expr=1.06; deg=0.22; asym=4.85; tree=(-0.33x0 AND -0.23x3 AND 0.14x1 AND 0.35x0z AND 0.37x2 AND 0.15x4)
# G> G_5: b=5.99; m=1.50; theta=10.51; init=1.93; noise=1.47; expr=0.62; deg=0.05; asym=3.40; tree=(-0.72x4 AND -1.00x0 AND -0.41x3 AND 0.10x0z AND -0.13x1)
# G> G_6: b=1.18; m=3.69; theta=6.10; init=0.35; noise=1.14; expr=1.35; deg=0.07; asym=5.71; tree=(-0.97x4 AND -0.06x3 AND -0.36x0)
# R> tree=(-1.00x4 OR 0.60x1z OR -0.44x5 OR -0.11x1 OR -0.11x0 OR 0.54x6 OR -0.02x2 OR -0.08x3)
# R> tree=(-0.76x5 OR 0.17x0 OR -0.28x4 OR 0.14x2 OR 0.13x1z OR -0.06x3)
# R> tree=(-0.88x4 OR -0.47x1 OR 0.46x2 OR 0.64x0 OR 0.05x3 OR -0.02x6)
# R> tree=(-0.83x3 OR 0.09x2 OR 0.49x1z)
# R> tree=(0.29x2 OR -0.77x0 OR -0.40x4 OR -0.07x3 OR -0.13x5 OR 0.06x1z OR 0.24x1 OR 0.03x7)
#
# ======= GENERATION generation_g47 92.50045612847333 =======
# G> G_0: b=2.28; m=0.23; theta=13.02; init=1.36; noise=1.01; expr=1.08; deg=0.09; asym=4.07; tree=(0.42x3 AND -0.03x0)
# G> G_1: b=3.09; m=9.27; theta=2.28; init=0.66; noise=1.39; expr=1.15; deg=0.07; asym=5.22; tree=(0.75x0z AND -0.59x1 AND 0.55x0 AND 0.23x2 AND 0.21x3 AND 0.09x4)
# G> G_2: b=0.17; m=0.16; theta=5.32; init=0.74; noise=0.59; expr=0.95; deg=0.07; asym=3.38; tree=(0.21x0z AND -0.58x2 AND 0.79x0 AND -0.21x3 AND 0.53x4 AND -0.21x1)
# G> G_3: b=1.76; m=1.28; theta=10.38; init=0.67; noise=0.86; expr=0.46; deg=0.06; asym=7.67; tree=(-0.80x3 AND 0.52x0z AND 0.21x2 AND -0.14x4 AND 0.20x1 AND -0.13x0)
# G> G_4: b=0.59; m=4.14; theta=5.50; init=0.84; noise=1.28; expr=1.06; deg=0.22; asym=4.94; tree=(-0.33x0 AND -0.23x3 AND 0.23x1 AND 0.35x0z AND 0.53x2 AND 0.15x4)
# G> G_5: b=5.99; m=1.71; theta=10.51; init=1.93; noise=1.47; expr=0.62; deg=0.05; asym=3.40; tree=(-0.72x4 AND -0.81x0 AND -0.41x3 AND 0.24x0z AND -0.12x1 AND -0.12x2)
# G> G_6: b=1.18; m=3.70; theta=6.30; init=0.32; noise=1.16; expr=1.21; deg=0.07; asym=5.15; tree=(-0.97x4 AND -0.06x3 AND -0.35x0 AND 0.05x2)
# R> tree=(-1.00x4 OR 0.45x1z OR -0.44x5 OR -0.23x1 OR -0.11x0 OR 0.54x6 OR -0.16x2)
# R> tree=(-0.76x5 OR 0.17x0 OR -0.12x4 OR 0.14x2 OR 0.18x1z OR -0.06x3)
# R> tree=(-0.91x4 OR -0.51x1 OR 0.46x2 OR 0.64x0 OR -0.02x6)
# R> tree=(-0.70x3 OR 0.09x2 OR 0.49x1z)
# R> tree=(0.29x2 OR -0.70x0 OR -0.40x4 OR -0.07x3 OR -0.13x5 OR 0.00x1z OR 0.22x1 OR 0.03x7 OR -0.09x6)
#
# ======= GENERATION generation_g48 92.59760575582496 =======
# G> G_0: b=2.28; m=0.23; theta=14.90; init=1.36; noise=1.01; expr=1.03; deg=0.10; asym=4.48; tree=(0.42x3 AND -0.03x0)
# G> G_1: b=3.09; m=9.37; theta=2.29; init=0.66; noise=1.42; expr=1.15; deg=0.07; asym=4.16; tree=(0.75x0z AND -0.37x1 AND 0.55x0 AND 0.26x2 AND 0.17x3 AND 0.09x4)
# G> G_2: b=0.19; m=0.16; theta=5.32; init=0.74; noise=0.52; expr=0.94; deg=0.07; asym=3.64; tree=(0.25x0z AND -0.58x2 AND 0.71x0 AND -0.21x3 AND 0.53x4 AND -0.21x1)
# G> G_3: b=1.76; m=1.28; theta=10.38; init=0.67; noise=0.86; expr=0.53; deg=0.07; asym=8.09; tree=(-0.80x3 AND 0.44x0z AND 0.21x2 AND -0.14x4 AND 0.20x1 AND -0.13x0)
# G> G_4: b=0.59; m=4.14; theta=5.50; init=0.84; noise=1.35; expr=1.06; deg=0.19; asym=4.94; tree=(-0.33x0 AND -0.23x3 AND 0.23x1 AND 0.35x0z AND 0.42x2 AND 0.15x4)
# G> G_5: b=6.87; m=1.80; theta=10.51; init=1.93; noise=1.47; expr=0.62; deg=0.05; asym=3.55; tree=(-0.72x4 AND -0.79x0 AND -0.57x3 AND 0.24x0z AND -0.12x1 AND -0.25x2)
# G> G_6: b=1.16; m=3.70; theta=6.30; init=0.32; noise=1.04; expr=1.06; deg=0.07; asym=5.15; tree=(-0.94x4 AND -0.06x3 AND -0.35x0 AND 0.33x2)
# R> tree=(-1.00x4 OR 0.45x1z OR -0.44x5 OR -0.23x1 OR -0.11x0 OR 0.54x6 OR -0.30x2 OR -0.03x3)
# R> tree=(-0.76x5 OR 0.05x0 OR -0.12x4 OR 0.14x2 OR 0.18x1z OR -0.06x3)
# R> tree=(-0.87x4 OR -0.59x1 OR 0.31x2 OR 0.64x0 OR -0.01x6)
# R> tree=(-0.63x3 OR 0.09x2 OR 0.15x1z OR -0.22x7)
# R> tree=(0.16x2 OR -0.70x0 OR -0.40x4 OR -0.07x3 OR -0.26x5 OR 0.00x1z OR 0.24x1 OR 0.03x7 OR -0.09x6)
#
# ======= GENERATION generation_g49 91.85073984612119 =======
# G> G_0: b=2.36; m=0.23; theta=14.90; init=1.36; noise=1.01; expr=1.03; deg=0.10; asym=4.48; tree=(0.40x3 AND -0.03x0)
# G> G_1: b=3.09; m=9.37; theta=2.29; init=0.68; noise=1.42; expr=1.15; deg=0.07; asym=4.16; tree=(0.75x0z AND -0.37x1 AND 0.55x0 AND 0.26x2 AND 0.17x3 AND 0.09x4)
# G> G_2: b=0.19; m=0.16; theta=5.32; init=0.74; noise=0.50; expr=0.94; deg=0.07; asym=3.64; tree=(0.25x0z AND -0.58x2 AND 0.71x0 AND -0.27x3 AND 0.53x4 AND -0.38x1)
# G> G_3: b=1.76; m=1.28; theta=10.38; init=0.67; noise=0.86; expr=0.53; deg=0.06; asym=8.03; tree=(-0.80x3 AND 0.40x0z AND 0.21x2 AND -0.14x4 AND 0.12x1 AND -0.13x0)
# G> G_4: b=0.53; m=4.31; theta=5.50; init=0.84; noise=1.35; expr=0.89; deg=0.19; asym=4.88; tree=(-0.33x0 AND -0.23x3 AND 0.23x1 AND 0.35x0z AND 0.29x2 AND 0.15x4)
# G> G_5: b=6.87; m=1.66; theta=13.08; init=1.93; noise=1.47; expr=0.62; deg=0.05; asym=3.55; tree=(-0.72x4 AND -0.79x0 AND -0.27x3 AND 0.24x0z AND -0.12x1 AND -0.24x2)
# G> G_6: b=1.17; m=3.70; theta=6.30; init=0.32; noise=1.04; expr=1.06; deg=0.07; asym=5.15; tree=(-0.94x4 AND -0.35x0 AND 0.50x2)
# R> tree=(-1.00x4 OR 0.45x1z OR -0.44x5 OR -0.23x1 OR -0.11x0 OR 0.54x6 OR -0.30x2)
# R> tree=(-0.76x5 OR 0.05x0 OR -0.12x4 OR 0.14x2 OR 0.17x1z OR -0.06x3)
# R> tree=(-0.87x4 OR -0.69x1 OR 0.28x2 OR 0.64x0 OR -0.01x6 OR -0.12x5)
# R> tree=(-0.63x3 OR 0.09x2 OR 0.15x1z OR -0.20x7)
# R> tree=(0.16x2 OR -0.70x0 OR -0.40x4 OR -0.11x3 OR -0.26x5 OR 0.24x1 OR 0.03x7 OR -0.09x6)
#
# ======= GENERATION generation_g50 91.27596633255496 =======
# G> G_0: b=2.00; m=0.21; theta=13.78; init=1.16; noise=1.13; expr=1.13; deg=0.09; asym=4.07; tree=(0.46x3 AND -0.03x0)
# G> G_1: b=3.09; m=9.53; theta=2.28; init=0.67; noise=1.46; expr=1.15; deg=0.07; asym=4.70; tree=(0.75x0z AND -0.83x1 AND 0.55x0 AND 0.13x2 AND 0.21x3)
# G> G_2: b=0.16; m=0.16; theta=5.32; init=0.84; noise=0.60; expr=1.01; deg=0.06; asym=3.73; tree=(0.23x0z AND -0.56x2 AND 0.85x0 AND -0.22x3 AND 0.53x4 AND -0.36x1)
# G> G_3: b=1.76; m=1.53; theta=10.91; init=0.69; noise=0.86; expr=0.54; deg=0.05; asym=9.11; tree=(-0.80x3 AND 0.52x0z AND 0.19x2 AND -0.14x4 AND 0.05x1 AND -0.20x0)
# G> G_4: b=0.46; m=3.61; theta=5.30; init=0.58; noise=1.11; expr=0.89; deg=0.20; asym=4.99; tree=(-0.33x0 AND -0.50x3 AND 0.23x1 AND 0.58x0z AND 0.63x2 AND 0.16x4)
# G> G_5: b=5.99; m=1.67; theta=10.31; init=1.93; noise=1.68; expr=0.62; deg=0.04; asym=3.19; tree=(-0.72x4 AND -0.81x0 AND -0.41x3 AND 0.02x0z AND -0.02x2)
# G> G_6: b=0.94; m=3.70; theta=6.06; init=0.40; noise=1.01; expr=1.21; deg=0.07; asym=5.11; tree=(-0.72x4 AND -0.06x3 AND -0.41x0 AND 0.09x2 AND 0.10x0z)
# R> tree=(-1.00x4 OR 0.04x1z OR -0.42x5 OR -0.23x1 OR -0.09x0 OR 0.59x6 OR -0.28x2)
# R> tree=(-0.95x5 OR 0.17x0 OR -0.05x4 OR 0.14x2 OR 0.11x1z OR -0.06x3 OR 0.16x7 OR -0.08x1 OR -0.12x6)
# R> tree=(-0.88x4 OR -0.41x1 OR 0.46x2 OR 0.64x0 OR -0.02x6)
# R> tree=(-0.47x3 OR 0.49x1z OR -0.05x5)
# R> tree=(0.26x2 OR -0.89x0 OR -0.24x4 OR -0.24x3 OR -0.07x5 OR 0.00x1z OR 0.27x1 OR 0.03x7 OR -0.35x6)

# %%
def metrics_bb_size(bb, ref, *args, **kwargs):
    d = O()
    stats = bb.stats.copy()
    stats, ref_stats = align_time(stats, ref.stats)
    stats_p, ref_p = normalize_time(stats, ref_stats, "progenitor_pop_size", "progenitor_pop_size")
    stats_infra, ref_n = normalize_time(stats, ref_stats, "infra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    stats_supra, _ = normalize_time(stats, ref_stats, "supra_pop_size", "neuron_pop_size",
                                    "progenitor_pop_size", "progenitor_pop_size")
    last_time_stats, last_time_ref = max(stats.time), max(ref_stats.time)
    time_switch = 64.0
    
    ref_p = ref_p.set_index("time")
    ref_n = ref_n.set_index("time")
    stats_p = stats_p.set_index("time")
    stats_infra = stats_infra.set_index("time")
    stats_supra = stats_supra.set_index("time")
    
    d.prog_early = stats_p.loc[min(last_time_stats, time_switch)]["progenitor_pop_size"]
    d.neuron_infra_early = stats_infra.loc[min(last_time_stats, time_switch)]["infra_pop_size"]
    d.neuron_supra_early = stats_supra.loc[min(last_time_stats, time_switch)]["supra_pop_size"]
    
    d.prog_late = stats_p.loc[last_time_stats]["progenitor_pop_size"]
    d.neuron_infra_late = stats_infra.loc[last_time_stats]["infra_pop_size"]
    d.neuron_supra_late = stats_supra.loc[last_time_stats]["supra_pop_size"]
    
    d.ref_prog_early = ref_p.loc[time_switch]["progenitor_pop_size"]
    d.ref_neuron_infra_early = ref_n.loc[time_switch]["neuron_pop_size"]
    d.ref_neuron_supra_early = 0.0
    
    d.ref_prog_late = ref_p.loc[last_time_ref]["progenitor_pop_size"]
    d.ref_neuron_infra_late = d.ref_neuron_infra_early
    d.ref_neuron_supra_late = ref_n.loc[last_time_ref]["neuron_pop_size"] - d.ref_neuron_infra_late
    
    metrics = pd.DataFrame({
        "value": [d.prog_early, d.neuron_infra_early, d.neuron_supra_early,
                  d.prog_late, d.neuron_infra_late, d.neuron_supra_late],
        "ref": [d.ref_prog_early, d.ref_neuron_infra_early, d.ref_neuron_supra_early,
                d.ref_prog_late, d.ref_neuron_infra_late, d.ref_neuron_supra_late],
        "coeff": [0.5, 0.5, 0.5, 1, 1, 1],
    }, index=["prog_early", "neuron_infra_early", "neuron_supra_early",
                "prog_late", "neuron_infra_late", "neuron_supra_late"])
    
    metrics["metrics"] = (metrics["value"] - metrics["ref"]).apply(abs) * metrics["coeff"]
    
    return metrics

def score_metrics_bb_size(metrics):
    return 1 / max(1, 10000 - metrics["metrics"].sum())

# %%
metrics_bb_size(res, REF)
# Out:
#                         value        ref  coeff   metrics
# prog_early           3.142857   2.383750    0.5  0.379553
# neuron_infra_early   1.000000   3.481867    0.5  1.240933
# neuron_supra_early   2.673469   0.000000    0.5  1.336735
# prog_late            1.408163   1.976666    1.0  0.568502
# neuron_infra_late    8.428571   3.481867    1.0  4.946705
# neuron_supra_late   15.285714  21.423109    1.0  6.137395
