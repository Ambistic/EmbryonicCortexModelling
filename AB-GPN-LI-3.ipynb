# %%
# imports
import numpy as np
import seaborn as sns
import tqdm
import random
import matplotlib.pyplot as plt
import os
import pandas as pd
from numpy.random import choice
from scipy import stats
from collections import Counter
from model import AbstractCell, Action, Brain, Submodels
from modelrgpn import BrainLI
from experiment import Experiment
from utils import nop, highest_lower, Profiler, plot_function
from submodels.cellbasic1 import CellBasic
from submodels.bistate1 import BiStateModelFactory
from submodels.bistate_LI import BiStateLIModelFactory
from submodels.tristate_LI import TriStateLIModelFactory
from submodels import factories
from biodata import *
from tree import tree_from_cell

# %%
def var_metric(gpn, cells):
    ls_ratio = list()
    for cell in cells:
        ngbs = gpn.ngb(cell.gpn_id)
        # now dependent of the data format
        ratio = np.mean([ngb == IP])

# %% [markdown]
# ## Model

# %%
# Definition of the var of the model
# We start with 100 cells for homogeneity
START_POPULATION_SQRT = 10
START_TIME = 49
END_TIME = 94
# We arbitrarily set variance of Tc at 12.5^2
# 95 % seems to be into 50, so sigma = 50 / 4 = 12.5
SIG_TC = 12.5

# %%
# attempt to show side collapse

# %%
smooth = 0.2
start_val = 0.35
bias_ratio = [0.2, 0.2, -0.1, -0.1, -0.1]
size = 6
NAME = "none"
DESC = f"bias {bias_ratio} size {size} startval {start_val} smooth {smooth}"

# %%
root = "/home/nathan/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/output/evonet13/"
count = 0
from viz import embedded_viz, quick_export
import gc
def my_callback(gpn):
    global count, root
    gc.collect()
    count += 1
    if count % 100 == 0:
        print(count)
        
    name = os.path.join(root, f"image_{count}.png")
    
    if os.path.exists(name):
        return
    # here
    gpn.update_dist()
    pos = embedded_viz(gpn, finetune=False)
    quick_export(gpn, pos, name)

# %%
def go(seed=0):
    random.seed(0+seed)
    np.random.seed(0+seed)
    ccls = TriStateLIModelFactory(tc_coeff_RG=[1., 1., 1., 1., 1.], smooth=smooth, start_val=start_val,
                                bias_ratio=bias_ratio)
    bb = BrainLI(time_step=0.5, verbose=True, start_population=size, cell_cls=ccls.generate, check=False,
                end_time=94, callback_gpn=None)

    # bb.run()
    return bb

# %%
bb = go(1)
bb.run()
# Out:
# Ticking abs : 49.0, step : 0.5
# Ticking abs : 49.5, step : 0.5
# Duplicating 0 1
# Duplicated with ids : 1 and 36
# Duplicating 2 2
# Duplicated with ids : 2 and 37
# Duplicating 7 7
# Duplicated with ids : 7 and 38
# Duplicating 12 12
# Duplicated with ids : 12 and 39
# Duplicating 14 14
# Duplicated with ids : 14 and 40
# Duplicating 15 15
# Duplicated with ids : 15 and 41
# Duplicating 20 20
# Duplicated with ids : 20 and 42
# Ticking abs : 50.0, step : 0.5
# Duplicating 1 0
# Duplicated with ids : 0 and 43
# Duplicating 4 4
# Duplicated with ids : 4 and 44
# Problem here, actualized is  True True False
# Duplicating 5 5
# Counter at 10 1628089296.1089826
# Duplicated with ids : 5 and 45
# Duplicating 9 9
# Duplicated with ids : 9 and 46
# Problem here, actualized is  True True False
# Removing 43 12
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 13 13
# Duplicated with ids : 13 and 47
# Problem here, actualized is  True True False
# Duplicating 16 16
# Duplicated with ids : 16 and 48
# Duplicating 17 17
# Duplicated with ids : 17 and 49
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 49 20
# Problem here, actualized is  True True False
# Duplicating 21 21
# Duplicated with ids : 21 and 50
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 23 23
# Duplicated with ids : 23 and 51
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 27 27
# Duplicated with ids : 27 and 52
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 28 28
# Counter at 20 1628089296.8906355
# Duplicated with ids : 28 and 53
# Duplicating 29 29
# Duplicated with ids : 29 and 54
# Problem here, actualized is  True True False
# Removing 48 42
# Problem here, actualized is  True True False
# Ticking abs : 50.5, step : 0.5
# Duplicating 37 1
# Duplicated with ids : 1 and 55
# Duplicating 55 5
# Duplicated with ids : 5 and 56
# Problem here, actualized is  True True False
# Duplicating 8 8
# Duplicated with ids : 8 and 57
# Problem here, actualized is  True True False
# Removing 57 9
# Duplicating 10 10
# Duplicated with ids : 10 and 58
# Problem here, actualized is  True True False
# Duplicating 11 11
# Duplicated with ids : 11 and 59
# Duplicating 18 18
# Duplicated with ids : 18 and 60
# Duplicating 19 19
# Counter at 30 1628089297.6815598
# Duplicated with ids : 19 and 61
# Problem here, actualized is  True True False
# Removing 65 21
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 22 22
# Duplicated with ids : 22 and 62
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 67 23
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 25 25
# Duplicated with ids : 25 and 63
# Problem here, actualized is  True True False
# Duplicating 26 26
# Duplicated with ids : 26 and 64
# Removing 71 28
# Problem here, actualized is  True True False
# Removing 73 29
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 32 32
# Duplicated with ids : 32 and 65
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 34 34
# Duplicated with ids : 34 and 66
# Duplicating 35 35
# Counter at 40 1628089298.5843697
# Duplicated with ids : 35 and 67
# Duplicating 40 38
# Duplicated with ids : 38 and 68
# Duplicating 44 40
# Duplicated with ids : 40 and 69
# Removing 56 46
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 62 49
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 64 50
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 66 51
# Removing 72 54
# Ticking abs : 51.0, step : 0.5
# Removing 75 1
# Problem here, actualized is  True True False
# Removing 77 5
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 6 6
# Counter at 50 1628089299.2756646
# Duplicated with ids : 6 and 70
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 41 7
# Duplicated with ids : 7 and 71
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 45 14
# Duplicated with ids : 14 and 72
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 87 19
# Problem here, actualized is  True True False
# Removing 89 22
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 24 24
# Duplicated with ids : 24 and 73
# Duplicating 30 30
# Duplicated with ids : 30 and 74
# Duplicating 31 31
# Duplicated with ids : 31 and 75
# Problem here, actualized is  True True False
# Duplicating 33 33
# Duplicated with ids : 33 and 76
# Removing 97 34
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 38 37
# Counter at 60 1628089300.2470078
# Duplicated with ids : 37 and 77
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 101 38
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 50 43
# Duplicated with ids : 43 and 78
# Duplicating 54 45
# Duplicated with ids : 45 and 79
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 60 48
# Duplicated with ids : 48 and 80
# Removing 74 55
# Removing 76 56
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 86 61
# Removing 88 62
# Removing 90 63
# Removing 100 68
# Counter at 70 1628089301.0535052
# Ticking abs : 51.5, step : 0.5
# Duplicating 3 3
# Duplicated with ids : 3 and 81
# Removing 105 6
# Duplicating 83 11
# Duplicated with ids : 11 and 82
# Duplicating 47 15
# Duplicated with ids : 15 and 83
# Duplicating 61 16
# Duplicated with ids : 16 and 84
# Removing 113 30
# Problem here, actualized is  True True False
# Removing 115 31
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 117 33
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 36 36
# Duplicated with ids : 36 and 85
# Duplicating 42 39
# Counter at 80 1628089301.8307366
# Duplicated with ids : 39 and 86
# Duplicating 46 41
# Duplicated with ids : 41 and 87
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 123 45
# Duplicating 78 57
# Duplicated with ids : 57 and 88
# Duplicating 82 59
# Duplicated with ids : 59 and 89
# Removing 104 70
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 112 74
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 114 75
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 116 76
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Ticking abs : 52.0, step : 0.5
# Duplicating 51 0
# Duplicated with ids : 0 and 90
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 39 2
# Counter at 90 1628089302.5889115
# Duplicated with ids : 2 and 91
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 53 4
# Duplicated with ids : 4 and 92
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 81 10
# Duplicated with ids : 10 and 93
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 129 11
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 63 17
# Duplicated with ids : 17 and 94
# Problem here, actualized is  True True False
# Duplicating 93 26
# Duplicated with ids : 26 and 95
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 69 27
# Duplicated with ids : 27 and 96
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 95 32
# Duplicated with ids : 32 and 97
# Problem here, actualized is  True True False
# Duplicating 121 43
# Duplicated with ids : 43 and 98
# Duplicating 52 44
# Duplicated with ids : 44 and 99
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 68 52
# Counter at 100 1628089303.3268752
# Duplicated with ids : 52 and 100
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 70 53
# Duplicated with ids : 53 and 101
# Problem here, actualized is  True True False
# Duplicating 80 58
# Duplicated with ids : 58 and 102
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 98 67
# Duplicated with ids : 67 and 103
# Duplicating 126 81
# Duplicated with ids : 81 and 104
# Removing 128 82
# Removing 136 86
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 138 87
# Problem here, actualized is  True True False
# Removing 140 88
# Problem here, actualized is  True True False
# Ticking abs : 52.5, step : 0.5
# Removing 147 2
# Duplicating 79 8
# Counter at 110 1628089304.1319306
# Duplicated with ids : 8 and 105
# Removing 151 10
# Problem here, actualized is  True True False
# Duplicating 59 13
# Duplicated with ids : 13 and 106
# Duplicating 109 14
# Duplicated with ids : 14 and 107
# Removing 153 17
# Duplicating 85 18
# Duplicated with ids : 18 and 108
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 111 24
# Duplicated with ids : 24 and 109
# Removing 157 27
# Duplicating 99 35
# Duplicated with ids : 35 and 110
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 58 47
# Duplicated with ids : 47 and 111
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 167 53
# Counter at 120 1628089304.9027972
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 169 58
# Duplicating 84 60
# Duplicated with ids : 60 and 112
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 94 65
# Duplicated with ids : 65 and 113
# Duplicating 102 69
# Duplicated with ids : 69 and 114
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 110 73
# Duplicated with ids : 73 and 115
# Problem here, actualized is  True True False
# Duplicating 118 77
# Duplicated with ids : 77 and 116
# Removing 173 81
# Removing 146 91
# Problem here, actualized is  True True False
# Removing 150 93
# Removing 152 94
# Counter at 130 1628089305.7444813
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 156 96
# Problem here, actualized is  True True False
# Removing 166 101
# Removing 172 104
# Ticking abs : 53.0, step : 0.5
# Duplicating 127 3
# Duplicated with ids : 3 and 117
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 107 7
# Duplicated with ids : 7 and 118
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 175 8
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 131 15
# Duplicated with ids : 15 and 119
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 133 16
# Duplicated with ids : 16 and 120
# Problem here, actualized is  True True False
# Removing 181 18
# Problem here, actualized is  True True False
# Duplicating 91 25
# Counter at 140 1628089306.7041414
# Duplicated with ids : 25 and 121
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 185 35
# Problem here, actualized is  True True False
# Duplicating 119 37
# Duplicated with ids : 37 and 122
# Duplicating 125 48
# Duplicated with ids : 48 and 123
# Problem here, actualized is  True True False
# Removing 189 60
# Problem here, actualized is  True True False
# Duplicating 92 64
# Duplicated with ids : 64 and 124
# Removing 191 65
# Problem here, actualized is  True True False
# Duplicating 96 66
# Duplicated with ids : 66 and 125
# Duplicating 122 79
# Duplicated with ids : 79 and 126
# Duplicating 124 80
# Duplicated with ids : 80 and 127
# Removing 174 105
# Counter at 150 1628089307.4378858
# Removing 176 106
# Problem here, actualized is  True True False
# Removing 180 108
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 184 110
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 190 113
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Ticking abs : 53.5, step : 0.5
# Removing 199 3
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 149 4
# Duplicated with ids : 4 and 128
# Removing 207 25
# Duplicating 135 36
# Duplicated with ids : 36 and 129
# Removing 209 37
# Duplicating 103 40
# Counter at 160 1628089308.1061175
# Duplicated with ids : 40 and 130
# Duplicating 165 52
# Duplicated with ids : 52 and 131
# Duplicating 143 59
# Duplicated with ids : 59 and 132
# Removing 215 66
# Duplicating 193 69
# Duplicated with ids : 69 and 133
# Duplicating 106 71
# Duplicated with ids : 71 and 134
# Duplicating 120 78
# Duplicated with ids : 78 and 135
# Removing 217 79
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 130 83
# Duplicated with ids : 83 and 136
# Problem here, actualized is  True True False
# Duplicating 132 84
# Duplicated with ids : 84 and 137
# Duplicating 134 85
# Counter at 170 1628089308.8560684
# Duplicated with ids : 85 and 138
# Problem here, actualized is  True True False
# Duplicating 142 89
# Duplicated with ids : 89 and 139
# Duplicating 148 92
# Duplicated with ids : 92 and 140
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 160 98
# Duplicated with ids : 98 and 141
# Duplicating 164 100
# Duplicated with ids : 100 and 142
# Duplicating 168 102
# Duplicated with ids : 102 and 143
# Removing 198 117
# Removing 204 120
# Removing 208 122
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 214 125
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Ticking abs : 54.0, step : 0.5
# Duplicating 179 14
# Counter at 180 1628089309.7371159
# Duplicated with ids : 14 and 144
# Duplicating 155 26
# Duplicated with ids : 26 and 145
# Duplicating 159 32
# Duplicated with ids : 32 and 146
# Duplicating 137 39
# Duplicated with ids : 39 and 147
# Duplicating 161 43
# Duplicated with ids : 43 and 148
# Duplicating 163 44
# Duplicated with ids : 44 and 149
# Duplicating 187 47
# Duplicated with ids : 47 and 150
# Problem here, actualized is  True True False
# Removing 229 59
# Duplicating 171 67
# Duplicated with ids : 67 and 151
# Problem here, actualized is  True True False
# Removing 233 71
# Problem here, actualized is  True True False
# Duplicating 108 72
# Counter at 190 1628089310.675578
# Duplicated with ids : 72 and 152
# Removing 235 78
# Problem here, actualized is  True True False
# Duplicating 219 80
# Duplicated with ids : 80 and 153
# Removing 237 83
# Removing 245 92
# Duplicating 158 97
# Duplicated with ids : 97 and 154
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 247 98
# Duplicated with ids : 98 and 155
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 162 99
# Duplicated with ids : 99 and 156
# Problem here, actualized is  True True False
# Removing 251 102
# Duplicating 192 114
# Duplicated with ids : 114 and 157
# Duplicating 194 115
# Counter at 200 1628089311.8002298
# Duplicated with ids : 115 and 158
# Duplicating 210 123
# Duplicated with ids : 123 and 159
# Duplicating 216 126
# Duplicated with ids : 126 and 160
# Removing 226 131
# Removing 228 132
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 232 134
# Removing 236 136
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 244 140
# Removing 246 141
# Problem here, actualized is  True True False
# Removing 250 143
# Ticking abs : 54.5, step : 0.5
# Duplicating 145 0
# Counter at 210 1628089312.9253626
# Duplicated with ids : 0 and 161
# Problem here, actualized is  True True False
# Duplicating 201 7
# Duplicated with ids : 7 and 162
# Problem here, actualized is  True True False
# Duplicating 177 13
# Duplicated with ids : 13 and 163
# Removing 253 14
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 183 24
# Duplicated with ids : 24 and 164
# Removing 255 26
# Duplicating 225 40
# Duplicated with ids : 40 and 165
# Duplicating 139 41
# Duplicated with ids : 41 and 166
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 261 43
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 141 57
# Duplicated with ids : 57 and 167
# Duplicating 195 73
# Counter at 220 1628089314.1028426
# Duplicated with ids : 73 and 168
# Duplicating 197 77
# Duplicated with ids : 77 and 169
# Removing 271 80
# Duplicating 154 95
# Duplicated with ids : 95 and 170
# Duplicating 170 103
# Duplicated with ids : 103 and 171
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 182 109
# Duplicated with ids : 109 and 172
# Duplicating 188 112
# Duplicated with ids : 112 and 173
# Removing 281 115
# Problem here, actualized is  True True False
# Duplicating 196 116
# Duplicated with ids : 116 and 174
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 200 118
# Duplicated with ids : 118 and 175
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 283 123
# Counter at 230 1628089315.1483867
# Removing 285 126
# Duplicating 222 129
# Duplicated with ids : 129 and 176
# Removing 252 144
# Removing 258 147
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 260 148
# Problem here, actualized is  True True False
# Removing 274 155
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 280 158
# Problem here, actualized is  True True False
# Removing 282 159
# Problem here, actualized is  True True False
# Removing 284 160
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Ticking abs : 55.0, step : 0.5
# Removing 287 0
# Counter at 240 1628089316.2857242
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 221 4
# Duplicated with ids : 4 and 177
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 297 41
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 211 48
# Duplicated with ids : 48 and 178
# Duplicating 213 64
# Duplicated with ids : 64 and 179
# Removing 303 77
# Duplicating 144 90
# Duplicated with ids : 90 and 180
# Duplicating 178 107
# Duplicated with ids : 107 and 181
# Duplicating 186 111
# Duplicated with ids : 111 and 182
# Removing 311 112
# Duplicating 206 121
# Counter at 250 1628089317.4256387
# Duplicated with ids : 121 and 183
# Duplicating 212 124
# Duplicated with ids : 124 and 184
# Duplicating 218 127
# Duplicated with ids : 127 and 185
# Removing 317 129
# Duplicating 230 133
# Duplicated with ids : 133 and 186
# Duplicating 240 138
# Duplicated with ids : 138 and 187
# Duplicating 248 142
# Duplicated with ids : 142 and 188
# Duplicating 256 146
# Duplicated with ids : 146 and 189
# Removing 290 163
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 298 167
# Removing 304 170
# Counter at 260 1628089318.5511506
# Removing 306 171
# Removing 308 172
# Removing 310 173
# Removing 316 176
# Ticking abs : 55.5, step : 0.5
# Removing 319 4
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 205 16
# Duplicated with ids : 16 and 190
# Duplicating 223 36
# Duplicated with ids : 36 and 191
# Duplicating 265 47
# Duplicated with ids : 47 and 192
# Removing 321 48
# Duplicating 231 69
# Counter at 270 1628089319.741622
# Duplicated with ids : 69 and 193
# Duplicating 239 84
# Duplicated with ids : 84 and 194
# Duplicating 241 85
# Duplicated with ids : 85 and 195
# Problem here, actualized is  True True False
# Duplicating 243 89
# Duplicated with ids : 89 and 196
# Removing 325 90
# Removing 327 107
# Removing 331 121
# Removing 335 127
# Problem here, actualized is  True True False
# Duplicating 224 130
# Duplicated with ids : 130 and 197
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 312 174
# Duplicated with ids : 174 and 198
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 318 177
# Counter at 280 1628089320.8022196
# Removing 320 178
# Removing 324 180
# Removing 326 181
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 334 185
# Ticking abs : 56.0, step : 0.5
# Duplicating 291 13
# Duplicated with ids : 13 and 199
# Duplicating 203 15
# Duplicated with ids : 15 and 200
# Removing 345 16
# Duplicating 257 32
# Duplicated with ids : 32 and 201
# Removing 347 36
# Problem here, actualized is  True True False
# Duplicating 259 39
# Counter at 290 1628089322.0040894
# Duplicated with ids : 39 and 202
# Duplicating 263 44
# Duplicated with ids : 44 and 203
# Problem here, actualized is  True True False
# Removing 351 69
# Duplicating 269 72
# Duplicated with ids : 72 and 204
# Duplicating 305 95
# Duplicated with ids : 95 and 205
# Duplicating 273 97
# Duplicated with ids : 97 and 206
# Duplicating 275 98
# Duplicated with ids : 98 and 207
# Duplicating 249 100
# Duplicated with ids : 100 and 208
# Duplicating 202 119
# Duplicated with ids : 119 and 209
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 220 128
# Duplicated with ids : 128 and 210
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 359 130
# Counter at 300 1628089323.0979433
# Problem here, actualized is  True True False
# Duplicating 234 135
# Duplicated with ids : 135 and 211
# Duplicating 238 137
# Duplicated with ids : 137 and 212
# Duplicating 339 138
# Duplicated with ids : 138 and 213
# Duplicating 242 139
# Duplicated with ids : 139 and 214
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 266 151
# Duplicated with ids : 151 and 215
# Duplicating 270 153
# Duplicated with ids : 153 and 216
# Problem here, actualized is  True True False
# Duplicating 288 162
# Duplicated with ids : 162 and 217
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 344 190
# Problem here, actualized is  True True False
# Removing 346 191
# Problem here, actualized is  True True False
# Removing 354 195
# Counter at 310 1628089324.167716
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 358 197
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Ticking abs : 56.5, step : 0.5
# Removing 363 13
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 365 15
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 369 39
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 371 44
# Duplicating 227 52
# Duplicated with ids : 52 and 218
# Duplicating 299 57
# Duplicated with ids : 57 and 219
# Duplicating 267 67
# Duplicated with ids : 67 and 220
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 375 95
# Problem here, actualized is  True True False
# Removing 377 97
# Counter at 320 1628089325.3912833
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 379 98
# Duplicating 277 99
# Duplicated with ids : 99 and 221
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 381 100
# Duplicating 307 103
# Duplicated with ids : 103 and 222
# Duplicating 279 114
# Duplicated with ids : 114 and 223
# Duplicating 313 116
# Duplicated with ids : 116 and 224
# Removing 383 119
# Duplicating 337 133
# Duplicated with ids : 133 and 225
# Removing 387 135
# Removing 393 139
# Counter at 330 1628089326.5898101
# Duplicating 254 145
# Duplicated with ids : 145 and 226
# Duplicating 262 149
# Duplicated with ids : 149 and 227
# Duplicating 264 150
# Duplicated with ids : 150 and 228
# Duplicating 272 154
# Duplicated with ids : 154 and 229
# Duplicating 276 156
# Duplicated with ids : 156 and 230
# Duplicating 278 157
# Duplicated with ids : 157 and 231
# Duplicating 286 161
# Duplicated with ids : 161 and 232
# Duplicating 296 166
# Duplicated with ids : 166 and 233
# Duplicating 300 168
# Duplicated with ids : 168 and 234
# Problem here, actualized is  True True False
# Duplicating 302 169
# Counter at 340 1628089327.8113062
# Duplicated with ids : 169 and 235
# Duplicating 338 187
# Duplicated with ids : 187 and 236
# Removing 362 199
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 364 200
# Problem here, actualized is  True True False
# Removing 368 202
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 370 203
# Removing 376 206
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 378 207
# Removing 380 208
# Removing 382 209
# Problem here, actualized is  True True False
# Removing 386 211
# Counter at 350 1628089329.0121906
# Removing 392 214
# Removing 396 216
# Ticking abs : 57.0, step : 0.5
# Duplicating 289 7
# Duplicated with ids : 7 and 237
# Problem here, actualized is  True True False
# Duplicating 295 40
# Duplicated with ids : 40 and 238
# Removing 401 52
# Removing 403 57
# Duplicating 357 89
# Duplicated with ids : 89 and 239
# Removing 409 103
# Duplicating 309 109
# Duplicated with ids : 109 and 240
# Duplicating 315 118
# Counter at 360 1628089330.1013455
# Duplicated with ids : 118 and 241
# Duplicating 333 124
# Duplicated with ids : 124 and 242
# Removing 415 133
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 341 142
# Duplicated with ids : 142 and 243
# Removing 417 145
# Removing 421 150
# Duplicating 268 152
# Duplicated with ids : 152 and 244
# Removing 427 157
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 429 161
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 292 164
# Duplicated with ids : 164 and 245
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 294 165
# Counter at 370 1628089331.2704082
# Duplicated with ids : 165 and 246
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 435 169
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 314 175
# Duplicated with ids : 175 and 247
# Duplicating 322 179
# Duplicated with ids : 179 and 248
# Duplicating 330 183
# Duplicated with ids : 183 and 249
# Duplicating 332 184
# Duplicated with ids : 184 and 250
# Duplicating 336 186
# Duplicated with ids : 186 and 251
# Duplicating 340 188
# Duplicated with ids : 188 and 252
# Removing 402 219
# Problem here, actualized is  True True False
# Removing 408 222
# Removing 414 225
# Counter at 380 1628089332.376132
# Removing 416 226
# Removing 418 227
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 420 228
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 426 231
# Problem here, actualized is  True True False
# Removing 432 234
# Removing 434 235
# Ticking abs : 57.5, step : 0.5
# Duplicating 293 24
# Duplicated with ids : 24 and 253
# Duplicating 349 47
# Duplicated with ids : 47 and 254
# Duplicating 353 84
# Duplicated with ids : 84 and 255
# Removing 443 89
# Counter at 390 1628089333.4013834
# Removing 445 109
# Duplicating 329 111
# Duplicated with ids : 111 and 256
# Removing 451 142
# Duplicating 343 146
# Duplicated with ids : 146 and 257
# Removing 453 152
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 397 153
# Duplicated with ids : 153 and 258
# Removing 461 179
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 328 182
# Duplicated with ids : 182 and 259
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 463 183
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 348 192
# Counter at 400 1628089334.4874988
# Duplicated with ids : 192 and 260
# Problem here, actualized is  True True False
# Duplicating 360 198
# Duplicated with ids : 198 and 261
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 442 239
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 444 240
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Ticking abs : 58.0, step : 0.5
# Removing 471 24
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 323 64
# Duplicated with ids : 64 and 262
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 373 72
# Duplicated with ids : 72 and 263
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 355 85
# Duplicated with ids : 85 and 264
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 407 99
# Duplicated with ids : 99 and 265
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 413 116
# Duplicated with ids : 116 and 266
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 481 153
# Counter at 410 1628089335.636685
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 431 166
# Duplicated with ids : 166 and 267
# Removing 483 182
# Duplicating 342 189
# Duplicated with ids : 189 and 268
# Removing 485 192
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 350 193
# Duplicated with ids : 193 and 269
# Duplicating 352 194
# Duplicated with ids : 194 and 270
# Problem here, actualized is  True True False
# Duplicating 356 196
# Duplicated with ids : 196 and 271
# Problem here, actualized is  True True False
# Duplicating 366 201
# Duplicated with ids : 201 and 272
# Problem here, actualized is  True True False
# Duplicating 374 205
# Duplicated with ids : 205 and 273
# Problem here, actualized is  True True False
# Duplicating 384 210
# Counter at 420 1628089336.7629845
# Duplicated with ids : 210 and 274
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 388 212
# Duplicated with ids : 212 and 275
# Problem here, actualized is  True True False
# Duplicating 398 217
# Duplicated with ids : 217 and 276
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 480 258
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 482 259
# Removing 484 260
# Ticking abs : 58.5, step : 0.5
# Duplicating 441 40
# Duplicated with ids : 40 and 277
# Duplicating 301 73
# Duplicated with ids : 73 and 278
# Problem here, actualized is  True True False
# Removing 493 85
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 495 99
# Problem here, actualized is  True True False
# Duplicating 411 114
# Counter at 430 1628089337.9251492
# Duplicated with ids : 114 and 279
# Duplicating 391 138
# Duplicated with ids : 138 and 280
# Duplicating 395 151
# Duplicated with ids : 151 and 281
# Duplicating 423 154
# Duplicated with ids : 154 and 282
# Removing 499 166
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 433 168
# Duplicated with ids : 168 and 283
# Duplicating 361 174
# Duplicated with ids : 174 and 284
# Duplicating 459 175
# Duplicated with ids : 175 and 285
# Problem here, actualized is  True True False
# Duplicating 437 187
# Duplicated with ids : 187 and 286
# Removing 505 194
# Duplicating 372 204
# Counter at 440 1628089338.9595468
# Duplicated with ids : 204 and 287
# Removing 511 205
# Removing 515 212
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 394 215
# Duplicated with ids : 215 and 288
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 517 217
# Problem here, actualized is  True True False
# Duplicating 400 218
# Duplicated with ids : 218 and 289
# Duplicating 406 221
# Duplicated with ids : 221 and 290
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 410 223
# Duplicated with ids : 223 and 291
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 430 233
# Duplicated with ids : 233 and 292
# Problem here, actualized is  True True False
# Duplicating 446 241
# Duplicated with ids : 241 and 293
# Problem here, actualized is  True True False
# Duplicating 464 250
# Counter at 450 1628089340.1233783
# Duplicated with ids : 250 and 294
# Removing 492 264
# Problem here, actualized is  True True False
# Removing 494 265
# Removing 498 267
# Removing 502 269
# Removing 504 270
# Removing 510 273
# Removing 512 274
# Removing 514 275
# Removing 516 276
# Ticking abs : 59.0, step : 0.5
# Duplicating 439 7
# Counter at 460 1628089341.405665
# Duplicated with ids : 7 and 295
# Duplicating 367 32
# Duplicated with ids : 32 and 296
# Duplicating 447 118
# Duplicated with ids : 118 and 297
# Duplicating 385 128
# Duplicated with ids : 128 and 298
# Removing 525 138
# Duplicating 419 149
# Duplicated with ids : 149 and 299
# Removing 527 151
# Duplicating 425 156
# Duplicated with ids : 156 and 300
# Duplicating 399 162
# Duplicated with ids : 162 and 301
# Duplicating 457 165
# Duplicated with ids : 165 and 302
# Removing 531 168
# Counter at 470 1628089342.4316301
# Removing 535 175
# Duplicating 469 188
# Duplicated with ids : 188 and 303
# Problem here, actualized is  True True False
# Duplicating 390 213
# Duplicated with ids : 213 and 304
# Removing 541 215
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 543 218
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 422 229
# Duplicated with ids : 229 and 305
# Duplicating 428 232
# Duplicated with ids : 232 and 306
# Removing 549 233
# Problem here, actualized is  True True False
# Duplicating 436 236
# Duplicated with ids : 236 and 307
# Removing 551 241
# Counter at 480 1628089343.7533104
# Duplicating 450 243
# Duplicated with ids : 243 and 308
# Duplicating 456 246
# Duplicated with ids : 246 and 309
# Duplicating 460 248
# Duplicated with ids : 248 and 310
# Duplicating 462 249
# Duplicated with ids : 249 and 311
# Duplicating 468 252
# Duplicated with ids : 252 and 312
# Duplicating 478 257
# Duplicated with ids : 257 and 313
# Removing 524 280
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 526 281
# Problem here, actualized is  True True False
# Removing 530 283
# Removing 532 284
# Counter at 490 1628089344.9630187
# Removing 534 285
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 540 288
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 542 289
# Removing 548 292
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 550 293
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Ticking abs : 59.5, step : 0.5
# Removing 557 32
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 489 64
# Duplicated with ids : 64 and 314
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 405 67
# Duplicated with ids : 67 and 315
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 475 84
# Duplicated with ids : 84 and 316
# Duplicating 449 124
# Counter at 500 1628089346.2108576
# Duplicated with ids : 124 and 317
# Removing 561 128
# Duplicating 479 146
# Duplicated with ids : 146 and 318
# Removing 569 165
# Duplicating 404 220
# Duplicated with ids : 220 and 319
# Removing 577 232
# Duplicating 440 238
# Duplicated with ids : 238 and 320
# Duplicating 448 242
# Duplicated with ids : 242 and 321
# Removing 581 243
# Duplicating 452 244
# Duplicated with ids : 244 and 322
# Duplicating 454 245
# Counter at 510 1628089347.4947948
# Duplicated with ids : 245 and 323
# Removing 585 248
# Removing 587 249
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 466 251
# Duplicated with ids : 251 and 324
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 470 253
# Duplicated with ids : 253 and 325
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 472 254
# Duplicated with ids : 254 and 326
# Duplicating 486 261
# Duplicated with ids : 261 and 327
# Duplicating 500 268
# Duplicated with ids : 268 and 328
# Removing 556 296
# Removing 568 302
# Problem here, actualized is  True True False
# Removing 580 308
# Counter at 520 1628089348.7967072
# Removing 586 311
# Ticking abs : 60.0, step : 0.5
# Duplicating 473 47
# Duplicated with ids : 47 and 329
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 595 67
# Duplicating 477 111
# Duplicated with ids : 111 and 330
# Duplicating 389 137
# Duplicated with ids : 137 and 331
# Duplicating 465 184
# Duplicated with ids : 184 and 332
# Duplicating 467 186
# Duplicated with ids : 186 and 333
# Duplicating 501 189
# Duplicated with ids : 189 and 334
# Duplicating 507 196
# Duplicated with ids : 196 and 335
# Duplicating 487 198
# Counter at 530 1628089350.1739738
# Duplicated with ids : 198 and 336
# Duplicating 412 224
# Duplicated with ids : 224 and 337
# Duplicating 424 230
# Duplicated with ids : 230 and 338
# Duplicating 438 237
# Duplicated with ids : 237 and 339
# Removing 609 244
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 611 245
# Problem here, actualized is  True True False
# Duplicating 553 250
# Duplicated with ids : 250 and 340
# Removing 615 253
# Duplicating 474 255
# Duplicated with ids : 255 and 341
# Duplicating 476 256
# Duplicated with ids : 256 and 342
# Duplicating 488 262
# Counter at 540 1628089351.5495887
# Duplicated with ids : 262 and 343
# Duplicating 490 263
# Duplicated with ids : 263 and 344
# Problem here, actualized is  True True False
# Duplicating 508 272
# Duplicated with ids : 272 and 345
# Problem here, actualized is  True True False
# Duplicating 572 304
# Duplicated with ids : 304 and 346
# Removing 594 315
# Problem here, actualized is  True True False
# Removing 598 317
# Removing 600 318
# Removing 610 323
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 614 325
# Problem here, actualized is  True True False
# Ticking abs : 60.5, step : 0.5
# Duplicating 521 73
# Duplicated with ids : 73 and 347
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 523 114
# Counter at 550 1628089352.9170523
# Duplicated with ids : 114 and 348
# Problem here, actualized is  True True False
# Duplicating 497 116
# Duplicated with ids : 116 and 349
# Removing 627 137
# Duplicating 513 210
# Duplicated with ids : 210 and 350
# Duplicating 545 221
# Duplicated with ids : 221 and 351
# Duplicating 579 236
# Duplicated with ids : 236 and 352
# Duplicating 458 247
# Duplicated with ids : 247 and 353
# Removing 649 256
# Removing 653 263
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 566 301
# Duplicated with ids : 301 and 354
# Problem here, actualized is  True True False
# Duplicating 582 309
# Counter at 560 1628089354.2252936
# Duplicated with ids : 309 and 355
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 590 313
# Duplicated with ids : 313 and 356
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 626 331
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 638 337
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 652 344
# Ticking abs : 61.0, step : 0.5
# Duplicating 519 40
# Duplicated with ids : 40 and 357
# Duplicating 491 72
# Duplicated with ids : 72 and 358
# Duplicating 563 149
# Duplicated with ids : 149 and 359
# Duplicating 455 164
# Duplicated with ids : 164 and 360
# Duplicating 537 187
# Duplicated with ids : 187 and 361
# Duplicating 503 193
# Counter at 570 1628089355.5964718
# ...
# Problem here, actualized is  True True False
# Duplicating 1176 606
# Duplicated with ids : 606 and 758
# Duplicating 1180 608
# Counter at 1270 1628089492.4849877
# Duplicated with ids : 608 and 759
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1192 614
# Duplicated with ids : 614 and 760
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 1427 616
# Duplicating 1198 617
# Duplicated with ids : 617 and 761
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1204 620
# Duplicated with ids : 620 and 762
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1226 631
# Duplicated with ids : 631 and 763
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1228 632
# Duplicated with ids : 632 and 764
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1244 640
# Duplicated with ids : 640 and 765
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1264 650
# Duplicated with ids : 650 and 766
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1320 678
# Duplicated with ids : 678 and 767
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1370 703
# Counter at 1280 1628089494.6928356
# Duplicated with ids : 703 and 768
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 1388 712
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 1392 714
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 1394 715
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 1398 717
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 1408 722
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 1410 723
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 1418 727
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Removing 1424 730
# Removing 1426 731
# Removing 1428 732
# Counter at 1290 1628089497.018413
# Ticking abs : 69.0, step : 0.5
# Removing 1431 111
# Duplicating 1279 118
# Duplicated with ids : 118 and 769
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1209 156
# Duplicated with ids : 156 and 770
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1283 164
# Duplicated with ids : 164 and 771
# Duplicating 1213 187
# Duplicated with ids : 187 and 772
# Duplicating 1287 229
# Duplicated with ids : 229 and 773
# Problem here, actualized is  True True False
# Duplicating 1051 242
# Duplicated with ids : 242 and 774
# Duplicating 1217 250
# Duplicated with ids : 250 and 775
# Problem here, actualized is  True True False
# Duplicating 1157 251
# Duplicated with ids : 251 and 776
# Problem here, actualized is  True True False
# Duplicating 1053 255
# Counter at 1300 1628089499.3459117
# Duplicated with ids : 255 and 777
# Duplicating 1093 282
# Duplicated with ids : 282 and 778
# Removing 1441 312
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1057 338
# Duplicated with ids : 338 and 779
# Problem here, actualized is  True True False
# Problem here, actualized is  True True True
# Problem here, actualized is  True True True
# Duplicating 1239 368
# Duplicated with ids : 368 and 780
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1243 381
# Duplicated with ids : 381 and 781
# Problem here, actualized is  True True True
# Duplicating 1347 383
# Duplicated with ids : 383 and 782
# Problem here, actualized is  True True True
# Problem here, actualized is  True True True
# Duplicating 1305 394
# Duplicated with ids : 394 and 783
# Problem here, actualized is  True True False
# Duplicating 1307 400
# Duplicated with ids : 400 and 784
# Problem here, actualized is  True True True
# Problem here, actualized is  True True True
# Duplicating 1245 401
# Duplicated with ids : 401 and 785
# Problem here, actualized is  True True True
# Problem here, actualized is  True True True
# Problem here, actualized is  True True True
# Duplicating 1117 430
# Counter at 1310 1628089501.6443121
# Duplicated with ids : 430 and 786
# Problem here, actualized is  True True True
# Problem here, actualized is  True True True
# Removing 1453 448
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Problem here, actualized is  True True False
# Duplicating 1249 449
# Duplicated with ids : 449 and 787
# Problem here, actualized is  True True True
# Problem here, actualized is  True True True
# Removing 1455 450
# Problem here, actualized is  True True True
# Problem here, actualized is  True True False
# Problem here, actualized is  True True True
# Problem here, actualized is  True True True
# Removing 1457 452
# Duplicating 1129 453
# Duplicated with ids : 453 and 788
# Duplicating 1137 473
# Duplicated with ids : 473 and 789
# Problem here, actualized is  True True True
# Problem here, actualized is  True True False
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# DEBUG --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# {'ngb_1': [(2959, 2945, 0), (-1, 2959, 0), (2944, 2959, 0)], 'ngb_0': [(2940, -1, 0), (-1, 2527, 0), (2768, -1, 0), (-1, 2950, 0), (-1, 1329, 0), (2886, -1, 0), (1534, -1, 0), (-1, 2312, 1), (2312, -1, 3), (-1, 2307, 2), (-1, 2738, 0), (-1, 2897, 0), (2479, -1, 0), (2740, -1, 0), (2208, -1, 0), (2896, -1, 0), (1687, -1, 0), (-1, 2502, 1), (2706, -1, 0), (2859, -1, 0), (2510, -1, 0), (2746, -1, 0), (-1, 2875, 0), (-1, 2877, 0), (2958, -1, 0), (2949, -1, 1), (-1, 2908, 0), (2915, -1, 0), (2883, -1, 0), (-1, 2925, 0), (2921, -1, 0), (2958, -1, 0), (2842, -1, 0), (2865, -1, 0), (2804, -1, 1), (2818, -1, 0), (-1, 2266, 0), (-1, 2502, 0), (2876, -1, 0), (1773, -1, 0), (2703, -1, 0), (-1, 2858, 0), (-1, 2926, 0), (2668, -1, 0), (2707, -1, 0), (2665, -1, 0), (-1, 2275, 0), (2312, -1, 0), (-1, 2312, 2), (2263, -1, 0), (-1, 1322, 0), (2683, -1, 0), (2682, -1, 0), (2417, -1, 0), (2688, -1, 0), (-1, 2588, 0), (1500, -1, 0), (1821, -1, 0), (2324, -1, 0), (-1, 2324, 1), (-1, 2959, 0), (-1, -1, 0)], '_': 0, 'dual_1': 2959, 'dual_0': -1, 'dual_edge': (-1, 2959, 0), 'edge': (534, 478), 'self': <relaxablegpn2.RelaxableGPN object at 0x7f87d4424a90>}
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-9cc0aff5ecf5>", line 2, in <module>
#     bb.run()
#   File "/home/nathan/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/model.py", line 143, in run
#     self._tick(T, self.time_step)
#   File "/home/nathan/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/model.py", line 164, in _tick
#     self.run_action(action, C, absolute_time)
#   File "/home/nathan/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/model.py", line 185, in run_action
#     self.mapping[action](cell, T)
#   File "/home/nathan/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/modelrgpn.py", line 69, in divide
#     self.gpn.relax()
#   File "/home/nathan/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/relaxablegpn2.py", line 495, in relax
#     self.try_action(action)
#   File "/home/nathan/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/relaxablegpn2.py", line 606, in try_action
#     try:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/usr/lib/python3.6/posixpath.py", line 396, in realpath
#     return abspath(path)
#   File "/usr/lib/python3.6/posixpath.py", line 385, in abspath
#     return normpath(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-8-9cc0aff5ecf5> in <module>
#       1 bb = go(1)
# ----> 2 bb.run()
#
# ~/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/model.py in run(self)
#     142         for T in np.arange(self.start_time, self.end_time, self.time_step):
# --> 143             self._tick(T, self.time_step)
#     144
#
# ~/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/model.py in _tick(self, absolute_time, relative_time)
#     163             action = C.tick(absolute_time, relative_time, neighbours)
# --> 164             self.run_action(action, C, absolute_time)
#     165
#
# ~/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/model.py in run_action(self, action, cell, T)
#     184     def run_action(self, action, cell, T):
# --> 185         self.mapping[action](cell, T)
#     186
#
# ~/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/modelrgpn.py in divide(self, cell, T)
#      68         for i in range(2):
# ---> 69             self.gpn.relax()
#      70
#
# ~/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/relaxablegpn2.py in relax(self)
#     494         for action in action_candidates[:3]:
# --> 495             self.try_action(action)
#     496
#
# ~/Bureau/ENS/Thèse/dev/EmbryonicCortexModelling/relaxablegpn2.py in try_action(self, action)
#     605     def try_action(self, action):
# --> 606         try:
#     607             gpn = self.copy()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
bb.gpn.check_not_double_border()

# %%
for x in [615] + list(bb.gpn.ngb(615)):
    print(x)
    bb.gpn.summary(x)

# %%
bb.gpn.summary(1831)

# %%
# faulty node is 1846, now 615

# %%
bb.gpn.summary(1039)

# %%
bb.gpn.summary(1914)

# %%
for n in bb.gpn.G:
    if len(bb.gpn.G.nodes[n]["ngb"]) <= 2:
        print(n, bb.gpn.is_border_node(n))

# %%
for n in bb.gpn.ngb(1914):
    print(n, bb.gpn.is_border_node(n))

# %%
bb.gpn.get_cycle_pairs(1914)

# %%
bb.gpn.dual((7302, -1, 1)), bb.gpn.dual((7302, -1, 0))

# %%
bb.gpn.ngb(1844), bb.gpn.ngb(1896)

# %%
bb.gpn.is_border_node(1708)

# %%
bb.gpn.show_all()

# %%
len(bb.gpn.G)

# %%
raise

# %%
bb.gpn.update_all_dist()

# %%
for n in bb.gpn.G.nodes:
    node = bb.gpn.G.nodes[n]
    if node["dist_E"] + node["dist_W"] == 0:
        print(n)

# %%
mg = bb.gpn.copy()

# %%
sel = 629

# %%
mg.G.nodes[341]

# %%
mg.ngb(341)

# %%
mg.G.nodes[341]["side"] = {'W', 'S'}

# %%
import viz
mg.update_all_dist()
pos = viz.embedded_viz(mg, finetune=False)
fig = mg.show_dist(pos=pos, hl_nodes=[1914, 1896, 1844, 1708])

# %%
from relaxablegpn2 import EnergyPoint
def relax(self):
    # prepare
    self.last_action = None
    self.quick_update_all_dist()
    mean_NS = self.mean_NS()
    mean_EW = self.mean_EW()

    nodes = list(self.G.nodes)
    random.shuffle(nodes)

    # list all pain points
    candidates = list()
    for n in nodes:
        node = self.G.nodes[n]
        dist_NS = node["dist_N"] + node["dist_S"]
        dist_EW = node["dist_E"] + node["dist_W"]
        val_NS = dist_NS / mean_NS
        val_EW = dist_EW / mean_EW
        if dist_NS < 4:
            candidates.append(EnergyPoint(n, "NS", self.low_width_penalty(dist_NS)))
        elif val_NS >= 1.1 or val_NS <= 0.9:
            candidates.append(EnergyPoint(n, "NS", val_NS))

        if dist_EW < 4:
            candidates.append(EnergyPoint(n, "EW", self.low_width_penalty(dist_EW)))
        elif val_EW >= 1.1 or val_EW <= 0.9:
            candidates.append(EnergyPoint(n, "EW", val_EW))

    # lower is worse, so to be tested

    candidates.sort(reverse=False)

    # list all possible actions
    action_candidates = list()
    for pt in candidates[:5]:
        for action in self.enumerate_actions(pt):
            self.estimate_action(action, mean_NS, mean_EW)
            action_candidates.append(action)

    # higher score is better to do !!

    action_candidates.sort(reverse=True)
    return candidates, action_candidates

# %%
cand, act = relax(mg)

# %%
mg.low_width_penalty(2)

# %%
cand[:10]

# %%
mg.G.nodes[805]

# %%
cand[0].to_shorten()

# %%
list(mg.enumerate_actions(cand[0]))

# %%
mg.summary(275), mg.summary(1394)

# %%
act

# %%
mg.ngb(2382), mg.ngb(2506)

# %%
def act_from_one_c(self, pt):
    action_candidates = []
    for action in self.enumerate_actions(pt):
        self.estimate_action(action, 5, 5)
        action_candidates.append(action)
    action_candidates.sort(reverse=True)
    return action_candidates

# %%
act_from_one_c(mg, cand[0])

# %%
raise

# %%
name = os.path.join(root, f"image_{count}.png")seed = 0
while True:
    print("Doing", seed)
    try:
        bb = go(seed)
    except:
        seed += 1
        if seed > 15:
            raise
    else:
        break

# %%
def plot_size(stats, name=None):
    ref = stats.whole_pop_size.iloc[0]
    plot_number_cells()
    p1 = plt.plot(stats.time, stats.progenitor_pop_size / ref, label="Progenitor population")
    # p2 = plt.plot(stats.time, stats.whole_pop_size / ref, label="Whole Population")
    plt.legend()
    if name:
        plt.savefig(f"output/results/prog_size_{name}.png")
    
def plot_ratio(stats, name=None):
    non_IP = (stats.size_type_RG + stats.size_type_GP) if "size_type_GP" in stats.columns else \
                stats.size_type_RG
    
    plt.plot(stats.time, stats.size_type_IP / (non_IP + stats.size_type_IP),
             label="IP ratio")
    plt.plot(ratio_eomes.index, ratio_eomes.val / 100, label="Reference IP ratio")
    plt.legend()
    if name:
        plt.savefig(f"output/results/IP_ratio_{name}.png")
        
def plot_size_ratio(stats, name=None):
    plt.figure(figsize=(12, 12))
    plt.subplot(2, 1, 1)
    plot_size(stats)
    plt.subplot(2, 1, 2)
    plot_ratio(stats)
    if name:
        plt.savefig(f"output/results/prog_size_ratio_{name}.png")
        
def save_stats(stats, name):
    stats.to_csv(f"output/results/stats_{name}.csv")
    
def save_txt(txt, name):
    fn = f"output/results/txt_{name}.txt"
    with open(fn, "w") as f:
        f.write(txt)

# %%
plot_size_ratio(bb.stats, NAME)

# %%
save_stats(bb.stats, NAME)
save_txt(DESC, NAME)
