# %%
import networkx as nx
import igraph as ig

# %%
# %%time
G = nx.Graph()
for i in range(10000):
    G.add_node(i)
    
for i in range(10000):
    G.remove_node(i)
# Out:
# CPU times: user 12.8 ms, sys: 6.77 ms, total: 19.6 ms
# Wall time: 18.9 ms

# %%
# %%time
g = ig.Graph()
for i in range(10000):
    g.add_vertex(i)
    
for i in range(10000):
    g.delete_vertices(0)
# Out:
# CPU times: user 680 ms, sys: 3.9 ms, total: 684 ms
# Wall time: 683 ms

# %%
[x for x in g.vs]
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 0, {'name': 3}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 1, {'name': 5}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 2, {'name': 7}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 3, {'name': 9}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 4, {'name': 11}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 5, {'name': 13}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 6, {'name': 15}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 7, {'name': 17}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 8, {'name': 19}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 9, {'name': 21}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 10, {'name': 23}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 11, {'name': 25}),
#  igraph.Vertex(<igraph.Graph object at 0x7fe6328ed408>, 12, {'name': 27}),
# ...

# %%
g.delete_vertices(0)

# %%
# igraph is shit for dynamic mutable networks
