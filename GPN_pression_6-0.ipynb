# %% [markdown]
# Our problematic is that density is really respected in our network as long as it evolves.
# We must, therefore, find rules such that it can work properly, having nice and realistic 2D representation.

# %%
from gpn6 import GrowingPlanarNetwork, gpn_action
from helper import *
import networkx as nx
import random
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from heapq import heappush, heappop

# %%
class RGPN(GrowingPlanarNetwork):
    def init_tissue(self, size=3):
        super().init_tissue(size=size)
        total_size = size**2 - 1
        # set north
        for i in range(size):
            self.G.nodes[i]["side"] = self.G.nodes[i].get("side", set()) | {"N"}
        
        # set south
        for i in range(size):
            self.G.nodes[total_size - i]["side"] = self.G.nodes[total_size - i].get("side", set()) | {"S"}
        
        # set west
        for i in range(size):
            self.G.nodes[i * size]["side"] = self.G.nodes[i * size].get("side", set()) | {"W"}
        
        # set east
        for i in range(size):
            self.G.nodes[total_size - i * size]["side"] = \
                self.G.nodes[total_size - i * size].get("side", set()) | {"E"}
            
    def diffuse_border(self, node):
        # if the border is a corner, we can just return
        # ideally, we shall never have a length of 3 ...
        
        if self.is_border_node(node):
            if len(self.G.nodes[node].get("side", set())) >= 2:
                return
            ngb1, ngb2 = self.get_border_neighbours(node)
            side1 = self.G.nodes[ngb1].get("side", set())
            side2 = self.G.nodes[ngb2].get("side", set())
            side = self.G.nodes[node].get("side", set())
            assert len(side1 & side2) == 1, f"side is not of the right size, " \
                f"should be one : {side1}, {side2}, {ngb1}, {ngb2}" \
                f" with node {node}, {side}"
            self.G.nodes[node]["side"] = side1 & side2
            
        else:
            if "side" in self.G.nodes[node]:
                del self.G.nodes[node]["side"]
    
    def update_corner(self, node):
        if self.is_border_node(node):
            ngb1, ngb2 = self.get_border_neighbours(node)
            side1 = self.G.nodes[ngb1].get("side", set())
            side2 = self.G.nodes[ngb2].get("side", set())
            side_ref = self.G.nodes[node].get("side", set())
            
            if len(side1 & side2) == 0:
                self.G.nodes[ngb1]["side"] = side1 | side2
            
    # TODO override duplicate to set the border (NSEW)
    def duplicate(self, node):
        new_node = super().duplicate(node)
        self.diffuse_border(new_node)
            
    
    # TODO override remove to check for corners
    def destroy(self, node):
        self.update_corner(node)
                
        super().destroy(node)
    
    def edge_swapper(self):
        pass
    
    def update_all_dist(self):
        self.update_dist(direction="N")
        self.update_dist(direction="S")
        self.update_dist(direction="E")
        self.update_dist(direction="W")
        
    def mean_NS(self):
        return np.mean([self.G.nodes[n]["dist_N"] + self.G.nodes[n]["dist_S"] for n in self.G.nodes])
    
    def mean_EW(self):
        return np.mean([self.G.nodes[n]["dist_E"] + self.G.nodes[n]["dist_W"] for n in self.G.nodes])
    
    def update_dist(self, direction="N"):
        """
        Update for each node its distance to each sides
        Direction is one of NSEW
        """
        key = "dist_" + direction
        queue = []
        nodes = set(self.G.nodes)
        # NORTH
        for i in self.G.nodes:
            n = self.G.nodes[i]
            if direction in n.get("side", set()):
                value = 0
            else:
                value = np.inf
                
            n[key] = value
            heappush(queue, (value, i))
            
        while queue and nodes:
            _, inode = heappop(queue)
            if inode not in nodes:
                continue
                
            nodes.remove(inode)
            node = self.G.nodes[inode]
            value = node[key] + 1
            for ngb in node["ngb"]:
                if value < self.G.nodes[ngb][key]:
                    self.G.nodes[ngb][key] = value
                    heappush(queue, (value, ngb))

    
    def show_dist(self, k=5, iterations=1000, figsize=(10, 10), pos=None):
        # green for NS, red for EW
        plt.figure(figsize=figsize)
        if not pos:
            pos = nx.spring_layout(self.G, k=k, iterations=iterations)
        green = lambda x: format(max(0, 255 - (x["dist_N"] + x["dist_S"]) * 20), '02x')
        red = lambda x: format(max(0, 255 - (x["dist_E"] + x["dist_W"]) * 20), '02x')
        corner = lambda x: len(x.get("side", set())) >= 2
        def col_border(node):
            side = tuple(node.get("side", set()))
            return {
                ("N",): "#888822",  # yellow
                ("S",): "#228888",  # cyan
                ("E",): "#882288",  # purple
                ("W",): "#666666",  # grey
            }.get(side, "")
        colors = ["#000000" if corner(self.G.nodes[n]) else 
                  col_border(self.G.nodes[n])
                  or "#" + red(self.G.nodes[n]) + green(self.G.nodes[n]) + "ff" 
                  for n in self.G.nodes]
        nx.draw_networkx(self.G, pos, node_color=colors)
        
    def _reduce_on_axis(self, n, axis):
        """
        Warning, non node-cycle reducing, taking one step further
        Rationale is that empirically, we did not find much into cycle opportunity
        But we will have to do it later
        """
        assert axis in ["NS", "EW"], "Wrong axis argument"
        
        if self._quick_reduce(n, axis):
            print("Quick reducing", n, "on", axis)
            return True
        
        distA, distB = ("dist_N", "dist_S") if axis == "NS" else ("dist_E", "dist_W")
        node = self.G.nodes[n]
        N, S = node[distA], node[distB]
        ingbs = set(self.get_intermediate_neighbours(n)) - {-1}
        
        candidate_list = list()
        
        for ingb in ingbs:
            dngbs = self.ngb(ingb, net="dual")
            
            for edge_dngb in dngbs:
                node_dngb = self.get_other_node(edge_dngb, ingb)
                if node_dngb in (set(ingbs) | {-1}):
                    continue
                    
                # if #ngb == 2
                p_edge = self.dual(edge_dngb)
                if len(self.ngb(p_edge[0])) == 2 or len(self.ngb(p_edge[1])) == 2:
                    continue
                    
                pngbs = self.get_intermediate_neighbours(node_dngb, net="dual")
                
                # the best thing would be to make a list of possible
                # candidates then pick the very best, the same way as 
                # _augment
                for pngb in pngbs:
                    # no edge
                    if (n, pngb) in self.G.edges:
                        continue

                    pnode = self.G.nodes[pngb]
                    pN, pS = pnode[distA], pnode[distB]

                    # nothing to win (here for NS but works also for EW)
                    if pN >= N - 1 and pS >= S - 1:
                        continue
                        
                    candidate_list.append((self.dual(edge_dngb), pngb))
                    
        if len(candidate_list) == 0:
            print(f"No candidates for node {n} in _reduce")
            return False

        candidate_list.sort(key=lambda x: len(self.ngb(x[1])))

        p_edge, pngb = candidate_list[0]
        print(f"Reducing node {n}")
        self.replace_edge(p_edge, (n, pngb))
        return True
                
    def _get_border_candidates(self, node):
        assert self.is_border_node(node)
        return [n for ngb in gpn.get_border_neighbours(node)
                for n in gpn.get_border_neighbours(ngb)
                if n != node]
    
    def _get_quick_candidates(self, node, dual_node):
        assert dual_node != -1, "Operation not allowed for dual -1"
        return [ngb for ngb in 
                self.get_intermediate_neighbours(dual_node, net="dual")
                if ngb != node]
    
    def _get_common_border_ngb(self, n_a, n_b):
        s_a = set(gpn.get_border_neighbours(n_a))
        s_b = set(gpn.get_border_neighbours(n_b))
        return list(s_a & s_b)[0]
                
    def _quick_reduce(self, n, axis):
        """
        The idea is the same as "_reduce_on_axis" but here
        we just create a direct edge without removing anything
        directly (maybe something will be removed through
        stabilize_ngb later)
        """
        assert axis in ["NS", "EW"], "Wrong axis argument"
        
        A, B = axis
        node = self.G.nodes[n]
        N, S = self._dist(n, A), self._dist(n, B)
        dist = self._dist(n, axis)
        # get dual nodes
        ingbs = self.get_intermediate_neighbours(n)
        
        # gather all candidates without any filter
        candidates = []
        for ingb in ingbs:
            if ingb == -1:
                ls_c = self._get_border_candidates(n)
            else:
                ls_c = self._get_quick_candidates(n, ingb)
            candidates += [(c, ingb) for c in ls_c]
                
        # filter candidates
        filtered_candidates = [(c, d) for c, d in candidates
                               if self._dist(c, A) < N - 1
                               or self._dist(c, B) < S - 1]
        
        # pick best
        random.shuffle(filtered_candidates)
        
        # TODO number of ngb does not correct for already ngb with the next removed edge
        # neither border sides
        filtered_candidates.sort(key=lambda x: len(self.ngb(x[0])))

        # if empty
        if len(filtered_candidates) == 0:
            return False
            
        # select the best one (the first)
        candidate, dual = filtered_candidates[0]
        self.build_new_edge(n, candidate, dual)
        return True
        
    def build_new_edge(self, n, candidate, dual):
        if dual == -1:
            ref_node = self._get_common_border_ngb(n, candidate)
            if self.is_corner(ref_node):
                self.update_corner(ref_node)
            self._make_border_edge(ref_node, (n, candidate))
            self.diffuse_border(ref_node)
        else:
            self._make_edge(dual, (n, candidate))
            
        return True
                
    @gpn_action
    def replace_edge(self, edge1, edge2):
        dual_node = self._remove_edge(edge1)
        # print("Dual node", dual_node)
        self._make_edge(dual_node, edge2)
        
    def shorten_dist(self):
        """
        For now, one max action per round, otherwise tricky mechanisms could occur
        """
        self.update_all_dist()
        mean_NS = self.mean_NS()
        mean_EW = self.mean_EW()
        # find nodes with most pressure
        # for threshold, let's say *1.5 compared to mean
        nodes = list(self.G.nodes)
        random.shuffle(nodes)
        # TODO we must sort from the most "out" to the less
        # list candidates
        candidates = list()
        for n in nodes:
            node = self.G.nodes[n]
            val_NS = (node["dist_N"] + node["dist_S"]) / mean_NS
            val_EW = (node["dist_E"] + node["dist_W"]) / mean_EW
            if val_NS >= 1.1:
                candidates.append((n, "NS", val_NS))
                
            if val_EW >= 1.1:
                candidates.append((n, "EW", val_EW))
            
        # pick best candidate
        candidates.sort(key=lambda x: x[2], reverse=True)
        for n, axis, _ in candidates:
            if self._reduce_on_axis(n, axis=axis):
                self.check_all()
                self.stabilize_around(n)
                return True
            
            else:
                print(f"Impossible shorten for node {n} on axis {axis}")
        
        # success is implicit
        return False
                
    def maxen_dist(self):
        self.update_all_dist()
        mean_NS = self.mean_NS()
        mean_EW = self.mean_EW()
        # find nodes with most pressure
        # for threshold, let's say *1.5 compared to mean
        nodes = list(self.G.nodes)
        random.shuffle(nodes)
        candidates = list()
        for n in nodes:
            node = self.G.nodes[n]
            val_NS = (node["dist_N"] + node["dist_S"]) / mean_NS
            val_EW = (node["dist_E"] + node["dist_W"]) / mean_EW
            if val_NS <= 0.9:
                candidates.append((n, "NS", val_NS))
                
            if val_EW <= 0.9:
                candidates.append((n, "EW", val_EW))
            
        # pick best candidate
        candidates.sort(key=lambda x: x[2], reverse=False)
        for n, axis, _ in candidates:
            if self._augment(n, axis=axis):
                self.stabilize_around(n)
                return True
        
        # success is implicit
        return False
    
    def get_all_dists(self):
        l_NS, l_EW, l_both = list(), list(), list()
        nodes = list(self.G.nodes)
        candidates = list()
        for n in nodes:
            node = self.G.nodes[n]
            val_NS = (node["dist_N"] + node["dist_S"])
            val_EW = (node["dist_E"] + node["dist_W"])
            l_NS.append(val_NS)
            l_EW.append(val_EW)
            l_both.append(val_NS + val_EW)
            
        return l_NS, l_EW, l_both
    
    def print_dist_metrics(self):
        lA, lB, lC = self.get_all_dists()
        xA, xB, xC = np.std(lA) / np.mean(lA), np.std(lB) / np.mean(lB), np.std(lC) / np.mean(lC)
        print(f"Score are for NS : {xA}, EW : {xB}, both : {xC}")

    @gpn_action
    def setup_edge(self, edge, dual_node, candidate):
        # setup the edge and delete the one chosen
        node1, node2 = edge
        if (node1, candidate) not in self.G.edges:
            other_dual = self._make_edge(dual_node, (node1, candidate))
            # update dual_node
            ingb = set(self.get_intermediate_neighbours(dual_node, net="dual"))
            if not ingb.issuperset({node2, candidate}):
                dual_node, other_dual = other_dual, dual_node
            
        if (node2, candidate) not in self.G.edges:
            self._make_edge(dual_node, (node2, candidate))
        
        self._remove_edge(edge)
        self.diffuse_border(candidate)
    
    # TODO, find a better way
    def _dist(self, n, axis):
        node = self.G.nodes[n]
        return sum([node["dist_" + str(x)] for x in axis])
                
    def _augment(self, n, axis="NS"):
        A, B = axis
        node = self.G.nodes[n]
        N, S = self._dist(n, A), self._dist(n, B)
        dist = self._dist(n, axis)
        target_node = None
        # first step, find ngb that has the same dist
        for ngb in self.ngb(n):
            if self._dist(ngb, axis) <= dist:
                target_node = ngb
                break
                
        # stop here if #ngb == 2
        if len(self.ngb(n)) == 2 or len(self.ngb(target_node)) == 2:
            return False
                
        if target_node == None:
            raise RuntimeError(f"Should not have no ngb with same dist, dist is {dist}")
            
        dual_nodes = set(self.dual((n, target_node))[:2]) - {-1}
        
        # build list of candidate link node
        candidate_list = []
        for dual_node in dual_nodes:
            pngbs = set(self.get_intermediate_neighbours(dual_node, net="dual")) - {n, target_node}
            candidate_list += [(dual_node, pngb) for pngb in pngbs 
                               if self._dist(pngb, A) >= N and self._dist(pngb, B) >= S]
            
        random.shuffle(candidate_list)
        # TODO number of ngb does not correct for already ngb with the next removed edge
        candidate_list.sort(key=lambda x: len(self.ngb(x[1])))

        # if empty
        if len(candidate_list) == 0:
            return False
            
        # select the best one (the first)
        dual, candidate = candidate_list[0]
        
        self.setup_edge((n, target_node), dual, candidate)
        return True

# %%
seed = 1
random.seed(seed)
np.random.seed(seed)
gpn = RGPN()
gpn.init_tissue(6)
gpn.update_all_dist()

def p_dupl():
    return np.random.random() > 0.46

# %% [raw]
# # seed = 1
# random.seed(seed)
# np.random.seed(seed)
# gpn = RGPN()
# gpn.init_square(6)
# gpn.update_all_dist()
#
# pos = nx.spring_layout(gpn.G, k=0.1, iterations=50)
# # plt.figure(figsize=(8, 8))
# # nx.draw_networkx(gpn.G, pos=pos)
# ratio = 0
# for i in range(100):
#     # print(gpn.G.number_of_nodes(), ratio)
#     # gpn.check_all()
#     print(i)
#     if p_dupl():
#         ratio += 1
#         gpn.duplicate_random_node()
#     else:
#         ratio -= 1
#         gpn.remove_random_node()
#
#     gpn.shorten_dist()
#     gpn.maxen_dist()
#
#     if i % 100 == 0:
#         print()
#         print("Iteration", i, "ratio", ratio, "density", gpn.density())

# %% [raw]
# gpn.update_all_dist()
# gpn.show_dist()

# %%
np.min(np.array(list(pos.values()))), np.max(np.array(list(pos.values())))
# Out:
# (-0.7854771389845343, 0.9999999999999999)

# %%
def node_pos(node):
    x = node["dist_N"] / (node["dist_N"] + node["dist_S"])
    y = node["dist_E"] / (node["dist_E"] + node["dist_W"])
    x, y = (x - 0.5) * 1.5, (y - 0.5) * 1.5
    return np.array([x, y])

def embedded_viz(gpn):
    gpn.update_all_dist()
    # pos is a dict of np array with coordinates
    pos = {n: node_pos(gpn.G.nodes[n]) for n in gpn.G.nodes}
    return pos

# %%
seed = 1
random.seed(seed)
np.random.seed(seed)
gpn = RGPN()
gpn.debug = True
gpn.init_tissue(8)
gpn.update_all_dist()
ignore_export = True

def quick_export(gpn, pos, name):
    global ignore_export
    if ignore_export:
        return
    gpn.update_all_dist()
    gpn.show_dist(pos=pos, figsize=(8, 8))
    plt.savefig(name)
    plt.close()

pos = nx.spring_layout(gpn.G, k=0.1, iterations=50)
root = "output/evonet8/"
ratio = 0
for i in range(300):
    # print(gpn.G.number_of_nodes(), ratio)
    # gpn.check_all()
    print()
    print("-" * 50)
    print()
    print(f"Run {i}")
    if p_dupl():
        ratio += 1
        gpn.duplicate_random()
    else:
        ratio -= 1
        gpn.destroy_random()
        
    pos = nx.spring_layout(gpn.G, pos=pos, k=0.1, iterations=10)
    quick_export(gpn, pos, root + str(i).zfill(4) + "_a.png")
    
    print("Action")
    gpn.update_all_dist()
    gpn.print_dist_metrics()

    if gpn.shorten_dist():
        pos = nx.spring_layout(gpn.G, pos=pos, k=0.1, iterations=10)
        quick_export(gpn, pos, root + str(i).zfill(4) + "_b.png")
        print("Shorten")
        gpn.update_all_dist()
        gpn.print_dist_metrics()

    if gpn.maxen_dist():
        pos = nx.spring_layout(gpn.G, pos=pos, k=0.1, iterations=10)
        quick_export(gpn, pos, root + str(i).zfill(4) + "_c.png")
        print("Maxen")
        gpn.update_all_dist()
        gpn.print_dist_metrics()
        
    if i % 100 == 0:
        print()
        print("Iteration", i, "ratio", ratio, "density", gpn.density())
# Out:
# Calling _init_square  with  () {'size': 8}
#
# --------------------------------------------------
#
# Run 0
# Calling _destroy_node  with  (17,) {}
# Action
# Score are for NS : 0.0, EW : 0.0, both : 0.0
#
# Iteration 0 ratio -1 density 0.08035714285714286
#
# --------------------------------------------------
#
# Run 1
# Calling _duplicate_node  with  (28,) {}
# Action
# Score are for NS : 0.04868401632666737, EW : 0.04390106451744655, both : 0.03508771929824561
# Quick reducing 31 on EW
# Shorten
# Score are for NS : 0.04868401632666737, EW : 0.04108977556426791, both : 0.03455560096311129
#
# --------------------------------------------------
#
# Run 2
# Calling _destroy_node  with  (45,) {}
# Action
# Score are for NS : 0.04137190606019447, EW : 0.04137190606019447, both : 0.03287905695010977
# Quick reducing 29 on EW
# Shorten
# Score are for NS : 0.04137190606019447, EW : 0.01781449745251541, both : 0.02560136485206084
#
# --------------------------------------------------
#
# Run 3
# Calling _destroy_node  with  (42,) {}
# Action
# Score are for NS : 0.041659779045053094, EW : 0.01795459695610725, both : 0.025784032394693655
# Quick reducing 64 on EW
# Shorten
# Score are for NS : 0.041659779045053094, EW : 0.0, both : 0.02097288647577043
#
# --------------------------------------------------
#
# Run 4
# Calling _destroy_node  with  (1,) {}
# Action
# Score are for NS : 0.04195358458333707, EW : 0.07232502970803363, both : 0.039325195831226914
# Quick reducing 36 on NS
# Shorten
# Score are for NS : 0.04195358458333707, EW : 0.07232502970803363, both : 0.039325195831226914
#
# --------------------------------------------------
#
# Run 5
# Calling _destroy_node  with  (39,) {}
# Action
# Score are for NS : 0.06661234241982274, EW : 0.07172475198623653, both : 0.0482226966340245
# Quick reducing 4 on NS
# Shorten
# Score are for NS : 0.06401477588640982, EW : 0.07172475198623653, both : 0.04851388294395695
# Calling setup_edge  with  ((23, 15), 13, 22) {}
# Maxen
# Score are for NS : 0.04510857209428155, EW : 0.10695719802366262, both : 0.053785979296743766
#
# --------------------------------------------------
#
# Run 6
# Calling _duplicate_node  with  (34,) {}
# Action
# Score are for NS : 0.051677756478884285, EW : 0.10963529763452978, both : 0.05995205274626983
# Quick reducing 34 on EW
# Shorten
# Score are for NS : 0.051677756478884285, EW : 0.10639149663447295, both : 0.057303612207906585
# Calling setup_edge  with  ((22, 21), 60, 15) {}
# Maxen
# Score are for NS : 0.051677756478884285, EW : 0.1019899245582747, both : 0.05502392344497607
#
# --------------------------------------------------
#
# Run 7
# Calling _destroy_node  with  (30,) {}
# Removing crossing border edge 22 31 (27, 20, 0)
# Action
# Score are for NS : 0.058472707559675215, EW : 0.10259783520851541, both : 0.05608212388458637
# Reducing node 64
# Calling replace_edge  with  ((29, 28), (64, 21)) {}
# Shorten
# Score are for NS : 0.04994005894085909, EW : 0.10296611677655133, both : 0.05493480360811603
# Calling setup_edge  with  ((20, 19), 17, 28) {}
# Maxen
# Score are for NS : 0.04994005894085909, EW : 0.07714757498502972, both : 0.04259415579266907
#
# --------------------------------------------------
#
# Run 8
# Calling _duplicate_node  with  (52,) {}
# Action
# Score are for NS : 0.05523624443272046, EW : 0.09038244094776356, both : 0.05461949558261629
# Quick reducing 66 on EW
# Shorten
# Score are for NS : 0.05816669087700979, EW : 0.08190542798094372, both : 0.0513322605948407
#
# --------------------------------------------------
#
# Run 9
# Calling _destroy_node  with  (63,) {}
# Action
# Score are for NS : 0.08481889296799709, EW : 0.0820611295604749, both : 0.07109949767689529
# Quick reducing 52 on EW
# Shorten
# Score are for NS : 0.08481889296799709, EW : 0.07714757498502972, both : 0.06843581873708979
# Calling setup_edge  with  ((21, 13), 11, 20) {}
# Maxen
# Score are for NS : 0.08054671613692699, EW : 0.07714757498502972, both : 0.06569871693586897
#
# --------------------------------------------------
#
# Run 10
# Calling _destroy_node  with  (51,) {}
# Action
# Score are for NS : 0.07406956373836858, EW : 0.07714928323726546, both : 0.0623103989883329
# Reducing node 52
# Calling replace_edge  with  ((59, 66), (52, 44)) {}
# Shorten
# Score are for NS : 0.07783351013849717, EW : 0.08220062025187216, both : 0.06764882965008105
# Calling setup_edge  with  ((55, 47), 41, 54) {}
# Removing crossing border edge 54 62 (48, 47, 0)
# Maxen
# Score are for NS : 0.07018538058791002, EW : 0.07467508044796224, both : 0.058366645448548735
#
# --------------------------------------------------
#
# Run 11
# Calling _duplicate_node  with  (12,) {}
# Action
# Score are for NS : 0.07545005545221735, EW : 0.07616685193636982, both : 0.06133947545594825
# Calling outside_with_anchor
# debug_anchor {'next_': 47, 'prev': 55, 'current': 54, 'ngb2': 54, 'ngb1': 62, 'node': 55, 'self': <__main__.RGPN object at 0x7f6227d42400>}
# Quick reducing 62 on NS
# Shorten
# Score are for NS : 0.0868728674312729, EW : 0.08164137953714766, both : 0.07154020220902602
# Calling setup_edge  with  ((11, 3), 2, 10) {}
# Maxen
# Score are for NS : 0.08550227342164776, EW : 0.08164137953714766, both : 0.07039885666760973
#
# --------------------------------------------------
#
# Run 12
# Calling _destroy_node  with  (54,) {}
# Action
# Score are for NS : 0.09001666078023352, EW : 0.08188247375948235, both : 0.07138212478753575
# Quick reducing 66 on EW
# Shorten
# Score are for NS : 0.09001666078023352, EW : 0.07632623114025547, both : 0.06832262868961142
# Calling setup_edge  with  ((43, 35), 30, 65) {}
# Maxen
# Score are for NS : 0.0768310281133224, EW : 0.07632623114025547, both : 0.061414658755821125
#
# --------------------------------------------------
#
# Run 13
# Calling _destroy_node  with  (25,) {}
# Action
# Score are for NS : 0.0774931102541986, EW : 0.07606079610524481, both : 0.06167957885273351
# Reducing node 53
# Calling replace_edge  with  ((46, 55), (53, 47)) {}
# Shorten
# Score are for NS : 0.0774931102541986, EW : 0.07606079610524481, both : 0.06167957885273351
# Calling setup_edge  with  ((23, 22), 27, 29) {}
# Removing crossing border edge 31 29 (63, 73, 0)
# Maxen
# Score are for NS : 0.07205555864836014, EW : 0.10693816480553471, both : 0.07188827670608945
#
# --------------------------------------------------
#
# Run 14
# Calling _duplicate_node  with  (55,) {}
# Action
# Score are for NS : 0.08171734878962648, EW : 0.11292973468498343, both : 0.08130988610362203
# Quick reducing 68 on EW
# Shorten
# Score are for NS : 0.07726073735314183, EW : 0.10751112489090905, both : 0.07537783614444091
# Calling setup_edge  with  ((40, 41), 28, 32) {}
# Maxen
# Score are for NS : 0.07726073735314183, EW : 0.10751112489090905, both : 0.07537783614444091
#
# --------------------------------------------------
#
# Run 15
# Calling _destroy_node  with  (12,) {}
# Action
# Score are for NS : 0.06651975757165023, EW : 0.11656940497536872, both : 0.07273309805318078
# Quick reducing 55 on NS
# Shorten
# Score are for NS : 0.0577249958112068, EW : 0.13347015765889814, both : 0.07670198862437796
# Calling setup_edge  with  ((15, 21), 60, 22) {}
# Maxen
# Score are for NS : 0.08689089159195072, EW : 0.13347015765889814, both : 0.09188323937504006
#
# --------------------------------------------------
#
# Run 16
# Calling _destroy_node  with  (3,) {}
# Action
# Score are for NS : 0.08724653469147013, EW : 0.14452117827721161, both : 0.09644233684778854
# Quick reducing 66 on EW
# Shorten
# Score are for NS : 0.08724653469147013, EW : 0.13898422180668027, both : 0.0931765410865414
# Calling setup_edge  with  ((6, 5), 5, 14) {}
# Removing crossing border edge 14 15 (13, 6, 0)
# Maxen
# Score are for NS : 0.08724653469147013, EW : 0.13095081267898007, both : 0.09041840858204472
#
# --------------------------------------------------
#
# Run 17
# Calling _duplicate_node  with  (28,) {}
# Action
# Score are for NS : 0.09378263512354251, EW : 0.12050305403166153, both : 0.08822253298872747
# Quick reducing 53 on EW
# Shorten
# Score are for NS : 0.09378263512354251, EW : 0.11499778169998918, both : 0.08507127705430849
# Calling setup_edge  with  ((41, 32), 35, 49) {}
# Maxen
# Score are for NS : 0.12449218518069854, EW : 0.1058862273467867, both : 0.09674510217599791
#
# --------------------------------------------------
#
# Run 18
# Calling _duplicate_node  with  (43,) {}
# Action
# Score are for NS : 0.12461539180923052, EW : 0.11991678531077281, both : 0.10255785063627476
# Quick reducing 44 on EW
# Shorten
# Score are for NS : 0.12461539180923052, EW : 0.1110166146455769, both : 0.09849922756306445
# Calling setup_edge  with  ((29, 21), 60, 22) {}
# Maxen
# Score are for NS : 0.12461539180923052, EW : 0.10853650078320207, both : 0.09708533506872012
#
# --------------------------------------------------
#
# Run 19
# Calling _duplicate_node  with  (59,) {}
# Action
# Score are for NS : 0.12385339716096863, EW : 0.13616326202412055, both : 0.1064650977478327
# Quick reducing 46 on EW
# Shorten
# Score are for NS : 0.11318090543626119, EW : 0.13323467750529824, both : 0.09623482191670293
# Calling setup_edge  with  ((20, 11), 66, 28) {}
# Maxen
# Score are for NS : 0.10698972158776239, EW : 0.1099802443630115, both : 0.08478490500798731
#
# --------------------------------------------------
#
# Run 20
# Calling _destroy_node  with  (38,) {}
# Action
# Score are for NS : 0.10593145553066642, EW : 0.10724614730194791, both : 0.0776329284276064
# Quick reducing 37 on NS
# Shorten
# Score are for NS : 0.09594153337585577, EW : 0.10724614730194791, both : 0.06900072317407256
# Calling setup_edge  with  ((10, 2), 49, 9) {}
# Maxen
# Score are for NS : 0.09214323267878476, EW : 0.10724614730194791, both : 0.06548706312851935
#
# --------------------------------------------------
#
# Run 21
# Calling _duplicate_node  with  (0,) {}
# Action
# Score are for NS : 0.09392407122542887, EW : 0.1028617562334609, both : 0.06410751716645871
# Reducing node 53
# Calling replace_edge  with  ((52, 60), (53, 59)) {}
# Shorten
# Score are for NS : 0.09392407122542887, EW : 0.08951874156623552, both : 0.06004361401096384
# Calling setup_edge  with  ((57, 49), 42, 56) {}
# Maxen
# Score are for NS : 0.09392407122542887, EW : 0.08999867269123356, both : 0.061856097079632744
#
# --------------------------------------------------
#
# Run 22
# Calling _destroy_node  with  (34,) {}
# Action
# Score are for NS : 0.08972799488666527, EW : 0.11890055584256208, both : 0.07276052761750727
# Quick reducing 66 on EW
# Shorten
# Score are for NS : 0.08972799488666527, EW : 0.11151199624062036, both : 0.0702114043232033
# Calling setup_edge  with  ((33, 24), 15, 26) {}
# Maxen
# Score are for NS : 0.09109776442420943, EW : 0.12162247959478557, both : 0.0701842775311353
#
# --------------------------------------------------
#
# Run 23
# Calling _destroy_node  with  (29,) {}
# Action
# Score are for NS : 0.11174991437463298, EW : 0.13524926079120528, both : 0.07634678540135358
# Quick reducing 66 on EW
# Shorten
# Score are for NS : 0.11174991437463298, EW : 0.13524926079120528, both : 0.07634678540135358
# Calling setup_edge  with  ((33, 32), 85, 41) {}
# Maxen
# Score are for NS : 0.11174991437463298, EW : 0.13524926079120528, both : 0.07767505347086193
#
# --------------------------------------------------
#
# Run 24
# Calling _duplicate_node  with  (10,) {}
# Action
# Score are for NS : 0.11087335919219338, EW : 0.1382467172166705, both : 0.08319127217029613
# Quick reducing 52 on EW
# Shorten
# Score are for NS : 0.11087335919219338, EW : 0.13185912305815992, both : 0.08110515542009192
# Calling setup_edge  with  ((65, 41), 29, 33) {}
# Maxen
# Score are for NS : 0.11087335919219338, EW : 0.12232410604970256, both : 0.07785647360067827
#
# --------------------------------------------------
#
# Run 25
# Calling _duplicate_node  with  (37,) {}
# Action
# Score are for NS : 0.11001663874376111, EW : 0.12162377817933161, both : 0.07798117510526505
# Quick reducing 13 on EW
# Shorten
# Score are for NS : 0.11001663874376111, EW : 0.11831731920966622, both : 0.07507583861104165
# Calling setup_edge  with  ((21, 69), 64, 20) {}
# Maxen
# Score are for NS : 0.11001663874376111, EW : 0.10720133399482283, both : 0.0712801788066268
#
# --------------------------------------------------
#
# Run 26
# Calling _destroy_node  with  (55,) {}
# Action
# Score are for NS : 0.11087335919219338, EW : 0.10406418688503417, both : 0.0697306662807664
# Quick reducing 13 on NS
# Shorten
# Score are for NS : 0.09977702917202638, EW : 0.10023437403201586, both : 0.060783207697111034
# Calling setup_edge  with  ((26, 24), 15, 33) {}
# Maxen
# Score are for NS : 0.09655471991673195, EW : 0.10098130644469948, both : 0.06405611286651623
#
# --------------------------------------------------
#
# Run 27
# Calling _duplicate_node  with  (20,) {}
# Action
# Score are for NS : 0.11180339887498947, EW : 0.10215546534356695, both : 0.07765040890801855
# Quick reducing 75 on NS
# Shorten
# Score are for NS : 0.10570975793966486, EW : 0.10215546534356695, both : 0.07446143114632514
# Calling setup_edge  with  ((33, 65), 22, 26) {}
# Maxen
# Score are for NS : 0.10570975793966486, EW : 0.07713080907803255, both : 0.06640197633943963
#
# --------------------------------------------------
#
# Run 28
# Calling _duplicate_node  with  (44,) {}
# Action
# Score are for NS : 0.1026328859799319, EW : 0.0906801007556675, both : 0.0721184284094676
# Quick reducing 20 on NS
# Shorten
# Score are for NS : 0.09652960790694584, EW : 0.12381143155801574, both : 0.08640173300219231
# Calling setup_edge  with  ((15, 13), 103, 7) {}
# Maxen
# Score are for NS : 0.10372420557286903, EW : 0.12381143155801574, both : 0.08742854225022857
#
# --------------------------------------------------
#
# Run 29
# Calling _destroy_node  with  (20,) {}
# Action
# Score are for NS : 0.11697150056860292, EW : 0.14420107784153913, both : 0.09229472015946653
# Quick reducing 28 on NS
# Shorten
# Score are for NS : 0.11201673534430619, EW : 0.14420107784153913, both : 0.09074043622688456
# Calling setup_edge  with  ((67, 4), 13, 13) {}
# Maxen
# Score are for NS : 0.1176029281943422, EW : 0.2337180377004858, both : 0.137215089554511
#
# --------------------------------------------------
#
# Run 30
# Calling _destroy_node  with  (48,) {}
# Action
# Score are for NS : 0.11972502167915977, EW : 0.2357971460967015, both : 0.13934018911739748
# Quick reducing 43 on EW
# Shorten
# Score are for NS : 0.11972502167915977, EW : 0.2256842766738603, both : 0.13504929456726172
# Calling setup_edge  with  ((18, 10), 9, 11) {}
# Maxen
# Score are for NS : 0.11924741108663568, EW : 0.21518457450849918, both : 0.1248373668095243
#
# --------------------------------------------------
#
# Run 31
# Calling _destroy_node  with  (23,) {}
# Action
# Score are for NS : 0.14637007598218987, EW : 0.21453175782336797, both : 0.12877502890093506
# Reducing node 75
# Calling replace_edge  with  ((11, 67), (75, 10)) {}
# Shorten
# Score are for NS : 0.14103269769747714, EW : 0.21089690771029887, both : 0.12511885440561618
# Calling setup_edge  with  ((7, 10), 111, 4) {}
# Removing crossing border edge 4 7 (111, 121, 0)
# Maxen
# Score are for NS : 0.14158505128207197, EW : 0.11891017128380182, both : 0.08607275656112333
#
# --------------------------------------------------
#
# Run 32
# Calling _destroy_node  with  (8,) {}
# Action
# Score are for NS : 0.1622905261309471, EW : 0.11698270750796472, both : 0.0953454005451356
# Quick reducing 28 on NS
# Shorten
# Score are for NS : 0.1622905261309471, EW : 0.11698270750796472, both : 0.0953454005451356
# Calling setup_edge  with  ((15, 7), 111, 67) {}
# Removing crossing border edge 67 4 (111, 119, 0)
# Maxen
# Score are for NS : 0.14870567426997683, EW : 0.10426341139899575, both : 0.09543809417845622
#
# --------------------------------------------------
#
# Run 33
# Calling _destroy_node  with  (31,) {}
# Action
# Score are for NS : 0.1612662931955879, EW : 0.10656184734623955, both : 0.09765695130302612
# Reducing node 27
# Calling replace_edge  with  ((18, 19), (27, 11)) {}
# Shorten
# Score are for NS : 0.1612662931955879, EW : 0.10656184734623955, both : 0.09765695130302612
# Calling setup_edge  with  ((24, 16), 56, 11) {}
# Maxen
# Score are for NS : 0.12635454857644057, EW : 0.1674713341907409, both : 0.11073551480154922
#
# --------------------------------------------------
#
# Run 34
# Calling _destroy_node  with  (76,) {}
# Action
# Score are for NS : 0.12134210506579404, EW : 0.1746001348813675, both : 0.10712347331498033
# Quick reducing 26 on NS
# Shorten
# Score are for NS : 0.11745602737768265, EW : 0.1746001348813675, both : 0.10590261333725341
# Calling setup_edge  with  ((75, 10), 111, 4) {}
# Maxen
# Score are for NS : 0.103563426977855, EW : 0.13673633145906916, both : 0.08504701504239175
#
# --------------------------------------------------
#
# Run 35
# Calling _duplicate_node  with  (70,) {}
# Action
# Score are for NS : 0.10350609578722443, EW : 0.15491933384829668, both : 0.09511456147029379
# Quick reducing 49 on EW
# Shorten
# Score are for NS : 0.10350609578722443, EW : 0.15491933384829668, both : 0.09511456147029379
# Calling setup_edge  with  ((22, 15), 130, 74) {}
# Maxen
# Score are for NS : 0.07530655685082076, EW : 0.1287794693236731, both : 0.06916849028473984
#
# --------------------------------------------------
#
# Run 36
# Calling _destroy_node  with  (26,) {}
# Action
# Score are for NS : 0.0755577933351017, EW : 0.12789602659611182, both : 0.06814100309352909
# Reducing node 46
# Calling replace_edge  with  ((66, 53), (46, 59)) {}
# Shorten
# Score are for NS : 0.0755577933351017, EW : 0.12789602659611182, both : 0.06814100309352909
# Calling setup_edge  with  ((7, 13), 110, 6) {}
# Maxen
# Score are for NS : 0.0755577933351017, EW : 0.12598755386610405, both : 0.06641998065263477
#
# --------------------------------------------------
#
# Run 37
# Calling _duplicate_node  with  (50,) {}
# Action
# Score are for NS : 0.07998024153590083, EW : 0.13842319630212116, both : 0.07696673871735356
# Quick reducing 49 on EW
# Shorten
# Score are for NS : 0.08496702117393432, EW : 0.1328961779330681, both : 0.07855844048495726
# Calling setup_edge  with  ((69, 64), 113, 35) {}
# Maxen
# Score are for NS : 0.08496702117393432, EW : 0.1328961779330681, both : 0.07855844048495726
#
# --------------------------------------------------
#
# Run 38
# Calling _duplicate_node  with  (69,) {}
# Action
# Score are for NS : 0.09549847530793593, EW : 0.12970597761410044, both : 0.08011942324320821
# Quick reducing 50 on EW
# Shorten
# Score are for NS : 0.09032106474595009, EW : 0.1238494762890754, both : 0.0743781959607999
# Calling setup_edge  with  ((5, 4), 111, 75) {}
# Maxen
# Score are for NS : 0.08237720140507343, EW : 0.11493180042550026, both : 0.07507712084299767
#
# --------------------------------------------------
#
# Run 39
# Calling _duplicate_node  with  (72,) {}
# Action
# Score are for NS : 0.08232515678257032, EW : 0.12378650001330431, both : 0.08042743797254752
# Calling outside_with_anchor
# debug_anchor {'next_': 16, 'prev': 72, 'current': 0, 'ngb2': 0, 'ngb1': 79, 'node': 72, 'self': <__main__.RGPN object at 0x7f6227d42400>}
# Quick reducing 79 on EW
# Shorten
# Score are for NS : 0.08718817452944969, EW : 0.11949947152422709, both : 0.0817478747635398
# Calling setup_edge  with  ((24, 18), 125, 11) {}
# Maxen
# Score are for NS : 0.08718817452944969, EW : 0.11475409836065573, both : 0.0796678658199484
#
# --------------------------------------------------
#
# Run 40
# Calling _duplicate_node  with  (9,) {}
# Action
# Score are for NS : 0.09539926606257397, EW : 0.12208558018410233, both : 0.08990103878383125
# Reducing node 72
# Calling replace_edge  with  ((9, 80), (72, 2)) {}
# Shorten
# Score are for NS : 0.10311393891573614, EW : 0.11837403005977891, both : 0.09103312079117101
# Calling setup_edge  with  ((11, 18), 143, 24) {}
# Maxen
# Score are for NS : 0.10311393891573614, EW : 0.11837403005977891, both : 0.09103312079117101
#
# --------------------------------------------------
#
# Run 41
# Calling _duplicate_node  with  (74,) {}
# Action
# Score are for NS : 0.10602802223601424, EW : 0.11793512828693424, both : 0.09360481309520526
# Reducing node 80
# Calling replace_edge  with  ((72, 2), (80, 9)) {}
# Shorten
# Score are for NS : 0.10056355184433319, EW : 0.12155169388737067, both : 0.09257728676678464
# Calling setup_edge  with  ((15, 64), 134, 74) {}
# Maxen
# Score are for NS : 0.10056355184433319, EW : 0.11824534594490078, both : 0.09172668395419083
#
# --------------------------------------------------
#
# Run 42
# Calling _destroy_node  with  (77,) {}
# Action
# Score are for NS : 0.13295986964099835, EW : 0.11859923177566446, both : 0.10748018421381621
# Quick reducing 80 on EW
# Shorten
# Score are for NS : 0.13038857556375202, EW : 0.11859923177566446, both : 0.10511502735132239
# Calling setup_edge  with  ((75, 28), 102, 78) {}
# Maxen
# Score are for NS : 0.1268636740590186, EW : 0.11837403005977891, both : 0.10511502735132239
#
# --------------------------------------------------
#
# Run 43
# Calling _destroy_node  with  (64,) {}
# Action
# Score are for NS : 0.12276192816309087, EW : 0.12522076583042674, both : 0.10765224954370124
# Quick reducing 80 on EW
# Shorten
# Score are for NS : 0.12276192816309087, EW : 0.12522076583042674, both : 0.10765224954370124
# Calling setup_edge  with  ((65, 27), 22, 33) {}
# Maxen
# Score are for NS : 0.09568176860464343, EW : 0.13074209465413517, both : 0.09787082584436006
#
# --------------------------------------------------
#
# Run 44
# Calling _destroy_node  with  (52,) {}
# Action
# Score are for NS : 0.0994489919088011, EW : 0.14427727137975357, both : 0.10785811388228816
# Reducing node 72
# Calling replace_edge  with  ((9, 80), (72, 2)) {}
# Shorten
# Score are for NS : 0.10688500583586463, EW : 0.13985319515147615, both : 0.10887558158987998
# Calling setup_edge  with  ((43, 37), 70, 71) {}
# Maxen
# Score are for NS : 0.10815311400398317, EW : 0.13985319515147615, both : 0.11260136519970042
#
# --------------------------------------------------
#
# Run 45
# Calling _duplicate_node  with  (78,) {}
# Action
# Score are for NS : 0.10752593350741572, EW : 0.14076213313093308, both : 0.11215007561728906
# Reducing node 80
# Calling replace_edge  with  ((72, 2), (80, 9)) {}
# Shorten
# Score are for NS : 0.099989797479951, EW : 0.14492378913424472, both : 0.11117804527101975
# Calling setup_edge  with  ((67, 21), 112, 15) {}
# Maxen
# Score are for NS : 0.099989797479951, EW : 0.14334102047385475, both : 0.1096594077168272
#
# --------------------------------------------------
#
# Run 46
# Calling _destroy_node  with  (35,) {}
# Action
# Score are for NS : 0.1458579278749254, EW : 0.17719879675766903, both : 0.14310624505014216
# Reducing node 72
# Calling replace_edge  with  ((80, 9), (72, 2)) {}
# Shorten
# Score are for NS : 0.1458579278749254, EW : 0.17313142347915464, both : 0.14041028692713164
# Calling setup_edge  with  ((24, 33), 145, 18) {}
# Maxen
# Score are for NS : 0.1458579278749254, EW : 0.1476266927250398, both : 0.13075329280962683
#
# --------------------------------------------------
#
# Run 47
# Calling _duplicate_node  with  (2,) {}
# Action
# Score are for NS : 0.15184055965240498, EW : 0.16226632851693693, both : 0.14171051360269013
# Quick reducing 80 on EW
# Shorten
# Score are for NS : 0.14530140786345377, EW : 0.16296276951249666, both : 0.13762618249905487
# Calling setup_edge  with  ((65, 36), 31, 44) {}
# Maxen
# Score are for NS : 0.14530140786345377, EW : 0.1488640111886029, both : 0.13224502536319682
#
# --------------------------------------------------
#
# Run 48
# Calling _destroy_node  with  (22,) {}
# Action
# Score are for NS : 0.13823488269082315, EW : 0.1473969065008578, both : 0.12902266850944624
# Reducing node 80
# Calling replace_edge  with  ((9, 73), (80, 16)) {}
# Shorten
# Score are for NS : 0.13823488269082315, EW : 0.1473969065008578, both : 0.12902266850944624
# Calling setup_edge  with  ((18, 27), 22, 33) {}
# Maxen
# Score are for NS : 0.13517922403999527, EW : 0.12683138434529276, both : 0.11892533523918022
#
# --------------------------------------------------
#
# Run 49
# Calling _destroy_node  with  (0,) {}
# Action
# Score are for NS : 0.14005073653286512, EW : 0.11532831323968433, both : 0.11663310853940943
# Quick reducing 9 on NS
# Shorten
# Score are for NS : 0.13470289021083068, EW : 0.11532831323968433, both : 0.11339602005652233
# Calling setup_edge  with  ((37, 71), 152, 59) {}
# Maxen
# Score are for NS : 0.13668816949684132, EW : 0.11532831323968433, both : 0.11325015308502308
#
# --------------------------------------------------
#
# Run 50
# Calling _duplicate_node  with  (66,) {}
# Action
# Score are for NS : 0.1304105684702714, EW : 0.11921813185486076, both : 0.11393245072062438
# Quick reducing 66 on NS
# Shorten
# Score are for NS : 0.1304105684702714, EW : 0.11505223636804114, both : 0.11091073930396946
# Calling setup_edge  with  ((37, 71), 165, 59) {}
# Maxen
# Score are for NS : 0.12790974651972417, EW : 0.0919813699104452, both : 0.10005304295291798
#
# --------------------------------------------------
#
# Run 51
# Calling _duplicate_node  with  (43,) {}
# Action
# Score are for NS : 0.12684766672656153, EW : 0.09146387081998232, both : 0.09900992328543919
# Reducing node 72
# Calling replace_edge  with  ((73, 83), (72, 4)) {}
# Shorten
# Score are for NS : 0.12125316753139512, EW : 0.08180049005656884, both : 0.08717044070553115
# Calling setup_edge  with  ((15, 67), 139, 21) {}
# Maxen
# Score are for NS : 0.1307420946541352, EW : 0.11256982398401849, both : 0.09696399417714961
#
# --------------------------------------------------
#
# Run 52
# Calling _destroy_node  with  (79,) {}
# Action
# Score are for NS : 0.14093855884666598, EW : 0.11213300552359493, both : 0.10195394939483807
# Quick reducing 72 on NS
# Shorten
# Score are for NS : 0.14093855884666598, EW : 0.11213300552359493, both : 0.10195394939483807
# Calling setup_edge  with  ((75, 82), 138, 5) {}
# Maxen
# Score are for NS : 0.13510902789315324, EW : 0.07574505280918745, both : 0.09278686812394707
#
# --------------------------------------------------
#
# Run 53
# Calling _destroy_node  with  (47,) {}
# Action
# Score are for NS : 0.13503929083659053, EW : 0.07537307789325134, both : 0.08977974158904635
# Reducing node 80
# Calling replace_edge  with  ((72, 2), (80, 16)) {}
# Shorten
# Score are for NS : 0.12828876983250329, EW : 0.08191552122131385, both : 0.09106928326400958
# Calling setup_edge  with  ((65, 44), 31, 76) {}
# Maxen
# Score are for NS : 0.12828876983250329, EW : 0.0822081034171237, both : 0.08980078646042008
#
# --------------------------------------------------
#
# Run 54
# Calling _destroy_node  with  (76,) {}
# Action
# Score are for NS : 0.1316988479661901, EW : 0.08178176691969984, both : 0.09295866767634463
# Quick reducing 72 on NS
# Shorten
# Score are for NS : 0.1259404298591682, EW : 0.07559289460184546, both : 0.08607859547612093
# Calling setup_edge  with  ((75, 28), 175, 4) {}
# Maxen
# Score are for NS : 0.12611631711950275, EW : 0.07559289460184546, both : 0.08714335508060883
#
# --------------------------------------------------
#
# Run 55
# Calling _duplicate_node  with  (66,) {}
# Action
# Score are for NS : 0.13798465415332828, EW : 0.0922958206990897, both : 0.10306371609364649
# Reducing node 66
# Calling replace_edge  with  ((46, 86), (66, 62)) {}
# Shorten
# Score are for NS : 0.14157593314415434, EW : 0.08733379056596591, both : 0.10194373714966848
# Calling setup_edge  with  ((36, 44), 155, 69) {}
# Maxen
# Score are for NS : 0.14361137779241254, EW : 0.08733379056596591, both : 0.10307834971171681
#
# --------------------------------------------------
#
# Run 56
# Calling _duplicate_node  with  (83,) {}
# Action
# Score are for NS : 0.13612321014168977, EW : 0.1291286156518581, both : 0.11490901458394402
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.12289185910675893, EW : 0.12464183962522711, both : 0.10503876739008967
# Calling setup_edge  with  ((36, 74), 160, 37) {}
# Maxen
# Score are for NS : 0.14935597697049274, EW : 0.12263377236211537, both : 0.11990086873574664
#
# --------------------------------------------------
#
# Run 57
# Calling _duplicate_node  with  (32,) {}
# Action
# Score are for NS : 0.17739475870151677, EW : 0.12170502660141214, both : 0.13076613395419898
# Reducing node 72
# Calling replace_edge  with  ((16, 9), (72, 11)) {}
# Shorten
# Score are for NS : 0.1739809982587238, EW : 0.09179687721631204, both : 0.113380652731377
# Calling setup_edge  with  ((36, 78), 154, 21) {}
# Maxen
# Score are for NS : 0.1780504501817318, EW : 0.09184793602843673, both : 0.11514360630306537
#
# --------------------------------------------------
#
# Run 58
# Calling _duplicate_node  with  (5,) {}
# Action
# Score are for NS : 0.17657520256177775, EW : 0.0995050686174104, both : 0.11546334226740643
# Reducing node 80
# Calling replace_edge  with  ((72, 16), (80, 11)) {}
# Shorten
# Score are for NS : 0.16992445047556737, EW : 0.0995050686174104, both : 0.11452346185079616
# Calling setup_edge  with  ((5, 82), 139, 89) {}
# Maxen
# Score are for NS : 0.17172819613303877, EW : 0.09917861346512613, both : 0.11164180423730916
#
# --------------------------------------------------
#
# Run 59
# Calling _duplicate_node  with  (74,) {}
# Action
# Score are for NS : 0.17123557536828618, EW : 0.09866877349904957, both : 0.11155722027446864
# Quick reducing 83 on NS
# Shorten
# Score are for NS : 0.17123557536828618, EW : 0.10290741452036169, both : 0.11266469426281392
# Calling setup_edge  with  ((59, 37), 70, 85) {}
# Maxen
# Score are for NS : 0.13894843168120563, EW : 0.10290741452036169, both : 0.10447127427541804
#
# --------------------------------------------------
#
# Run 60
# Calling _destroy_node  with  (11,) {}
# Action
# Score are for NS : 0.11949988239608707, EW : 0.10603764614306559, both : 0.09904372810183085
# Quick reducing 68 on NS
# Shorten
# Score are for NS : 0.12192435064163319, EW : 0.10371814133702979, both : 0.10008044431448226
# Calling setup_edge  with  ((43, 58), 37, 70) {}
# Maxen
# Score are for NS : 0.11698542788475937, EW : 0.10371814133702979, both : 0.0975401403486783
#
# --------------------------------------------------
#
# Run 61
# Calling _destroy_node  with  (85,) {}
# Action
# Score are for NS : 0.17018561563274037, EW : 0.11398109383004063, both : 0.12135257470326251
# Quick reducing 86 on NS
# Shorten
# Score are for NS : 0.16790100838532526, EW : 0.11398109383004063, both : 0.12025487408946813
# Calling setup_edge  with  ((59, 37), 196, 71) {}
# Maxen
# Score are for NS : 0.16790100838532526, EW : 0.11398109383004063, both : 0.12025487408946813
#
# --------------------------------------------------
#
# Run 62
# Calling _duplicate_node  with  (53,) {}
# Action
# Score are for NS : 0.17594223317362837, EW : 0.11612247758833823, both : 0.12712725082241833
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.17594223317362837, EW : 0.12769127792808957, both : 0.13321596102234082
# Calling setup_edge  with  ((82, 89), 139, 67) {}
# Removing crossing border edge 67 89 (202, 201, 0)
# Maxen
# Score are for NS : 0.17670118612414726, EW : 0.12832888405499934, both : 0.13652354483045584
#
# --------------------------------------------------
#
# Run 63
# Calling _duplicate_node  with  (59,) {}
# Action
# Score are for NS : 0.1813622053444714, EW : 0.15715215128203816, both : 0.15241009342440853
# Quick reducing 46 on EW
# Shorten
# Score are for NS : 0.1813622053444714, EW : 0.1447132667860998, both : 0.14642404174178503
# Calling setup_edge  with  ((69, 44), 182, 65) {}
# Maxen
# Score are for NS : 0.16010230458642466, EW : 0.1447132667860998, both : 0.13658823254183983
#
# --------------------------------------------------
#
# Run 64
# Calling _destroy_node  with  (66,) {}
# Action
# Score are for NS : 0.15519009087254815, EW : 0.13060589167785389, both : 0.12608180828675464
# Reducing node 68
# Calling replace_edge  with  ((46, 62), (68, 86)) {}
# Shorten
# Score are for NS : 0.15684346966340498, EW : 0.14000925530938496, both : 0.1329678589663007
# Calling setup_edge  with  ((82, 5), 202, 67) {}
# Removing crossing border edge 67 5 (170, 205, 0)
# Maxen
# Score are for NS : 0.1564312044622911, EW : 0.13906472283972052, both : 0.13939434653010047
#
# --------------------------------------------------
#
# Run 65
# Calling _duplicate_node  with  (15,) {}
# Action
# Score are for NS : 0.15899685531481433, EW : 0.13790483442756551, both : 0.1388471317888432
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.15322512066197225, EW : 0.14216305353565217, both : 0.1381331988799874
# Calling setup_edge  with  ((44, 65), 131, 43) {}
# Maxen
# Score are for NS : 0.15322512066197225, EW : 0.14216305353565217, both : 0.1381331988799874
#
# --------------------------------------------------
#
# Run 66
# Calling _destroy_node  with  (50,) {}
# Action
# Score are for NS : 0.1564312044622911, EW : 0.14235059469837522, both : 0.13982651597159818
# Quick reducing 53 on EW
# Shorten
# Score are for NS : 0.178223991965677, EW : 0.12626906806902632, both : 0.13939434653010047
# Calling setup_edge  with  ((92, 37), 196, 44) {}
# Maxen
# Score are for NS : 0.18757261025146219, EW : 0.16762406516378459, both : 0.1646401866466015
#
# --------------------------------------------------
#
# Run 67
# Calling _duplicate_node  with  (19,) {}
# Action
# Score are for NS : 0.18528841240909813, EW : 0.16575190918364463, both : 0.16231419033851874
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.1797014835823959, EW : 0.16575190918364463, both : 0.15922945443191058
# Calling setup_edge  with  ((65, 69), 160, 37) {}
# Maxen
# Score are for NS : 0.1457239493308314, EW : 0.17682966155067162, both : 0.14710786587358396
#
# --------------------------------------------------
#
# Run 68
# Calling _destroy_node  with  (56,) {}
# Action
# Score are for NS : 0.16301577135135373, EW : 0.1780087388616388, both : 0.15492747467412132
# Quick reducing 91 on NS
# Shorten
# Score are for NS : 0.16301577135135373, EW : 0.1780087388616388, both : 0.15492747467412132
# Calling setup_edge  with  ((41, 33), 145, 18) {}
# Maxen
# Score are for NS : 0.182275745392567, EW : 0.17573985802304795, both : 0.1631527551961012
#
# --------------------------------------------------
#
# Run 69
# Calling _duplicate_node  with  (60,) {}
# Action
# Score are for NS : 0.18422117432027652, EW : 0.189361159810194, both : 0.17079355700002471
# Quick reducing 91 on NS
# Shorten
# Score are for NS : 0.18422117432027652, EW : 0.189361159810194, both : 0.17079355700002471
# Calling setup_edge  with  ((33, 65), 214, 70) {}
# Maxen
# Score are for NS : 0.18422117432027652, EW : 0.19179117332835383, both : 0.1716573907864036
#
# --------------------------------------------------
#
# Run 70
# Calling _destroy_node  with  (65,) {}
# Action
# Score are for NS : 0.1952073454564861, EW : 0.19332485048582068, both : 0.17929241091623946
# Quick reducing 53 on NS
# Shorten
# Score are for NS : 0.1952073454564861, EW : 0.1918064859300637, both : 0.1787757172883175
# Calling setup_edge  with  ((88, 41), 36, 32) {}
# Maxen
# Score are for NS : 0.19117742780052316, EW : 0.19380631797980397, both : 0.17807992038966566
#
# --------------------------------------------------
#
# Run 71
# Calling _duplicate_node  with  (41,) {}
# Action
# Score are for NS : 0.18125783103362322, EW : 0.19249781153080217, both : 0.1708972272450357
# Quick reducing 53 on NS
# Shorten
# Score are for NS : 0.18125783103362322, EW : 0.19249781153080217, both : 0.1708972272450357
# Calling setup_edge  with  ((37, 90), 209, 44) {}
# Maxen
# Score are for NS : 0.24067773425375688, EW : 0.211642532934086, both : 0.20740181140153768
#
# --------------------------------------------------
#
# Run 72
# Calling _destroy_node  with  (84,) {}
# Removing crossing border edge 81 92 (164, 198, 0)
# Action
# Score are for NS : 0.23138554244609863, EW : 0.20865916437968404, both : 0.20022389133275323
# Reducing node 53
# Calling replace_edge  with  ((46, 60), (53, 61)) {}
# Shorten
# Score are for NS : 0.23717072451824667, EW : 0.20397288611873132, both : 0.20022389133275323
# Calling setup_edge  with  ((58, 41), 227, 71) {}
# Maxen
# Score are for NS : 0.21143870007205193, EW : 0.21996372978035833, both : 0.19239325417526032
#
# --------------------------------------------------
#
# Run 73
# Calling _duplicate_node  with  (67,) {}
# Action
# Score are for NS : 0.2250388393453623, EW : 0.21850089365954192, both : 0.1976908332387047
# Quick reducing 95 on EW
# Removing crossing border edge 61 95 (205, 233, 0)
# Shorten
# Score are for NS : 0.22146555605980564, EW : 0.222917173352756, both : 0.1976908332387047
# Calling setup_edge  with  ((4, 73), 161, 9) {}
# Maxen
# Score are for NS : 0.21790221293578668, EW : 0.222917173352756, both : 0.20067427236523433
#
# --------------------------------------------------
#
# Run 74
# Calling _duplicate_node  with  (10,) {}
# Action
# Score are for NS : 0.214800623910435, EW : 0.2213855439178552, both : 0.19882980810783618
# Quick reducing 13 on NS
# Shorten
# Score are for NS : 0.21029409294811327, EW : 0.21805176047675814, both : 0.19328597675950357
# Calling setup_edge  with  ((18, 33), 215, 94) {}
# Maxen
# Score are for NS : 0.21029409294811327, EW : 0.21291397179709332, both : 0.19068121747158487
#
# --------------------------------------------------
#
# Run 75
# Calling _destroy_node  with  (71,) {}
# Action
# Score are for NS : 0.18393970494245712, EW : 0.23707346324882664, both : 0.18045952610305716
# Quick reducing 53 on EW
# Shorten
# Score are for NS : 0.18840579710144928, EW : 0.23363416594555778, both : 0.18045952610305716
# Calling setup_edge  with  ((90, 44), 164, 81) {}
# Maxen
# Score are for NS : 0.18840579710144928, EW : 0.24094194008026362, both : 0.18178637711614815
#
# --------------------------------------------------
#
# Run 76
# Calling _destroy_node  with  (7,) {}
# Action
# Score are for NS : 0.18127463187417703, EW : 0.2417204224745707, both : 0.1786638151458429
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.18127463187417703, EW : 0.2417204224745707, both : 0.1786638151458429
# Calling setup_edge  with  ((41, 88), 237, 96) {}
# Maxen
# Score are for NS : 0.18127463187417703, EW : 0.19504925810716578, both : 0.16618295345548634
#
# --------------------------------------------------
#
# Run 77
# Calling _destroy_node  with  (91,) {}
# Action
# Score are for NS : 0.1787171417156836, EW : 0.194343187110887, both : 0.16419288788443884
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.17325360157994826, EW : 0.19559826110002365, both : 0.16218101256203782
# Calling setup_edge  with  ((18, 24), 221, 73) {}
# Maxen
# Score are for NS : 0.17325360157994826, EW : 0.1941874447505555, both : 0.15919893135171326
#
# --------------------------------------------------
#
# Run 78
# Calling _duplicate_node  with  (49,) {}
# Action
# Score are for NS : 0.1707574546054719, EW : 0.19247610880519594, both : 0.15754447156391227
# Quick reducing 14 on EW
# Shorten
# Score are for NS : 0.1707574546054719, EW : 0.18862770984981708, both : 0.15507439206083584
# Calling setup_edge  with  ((32, 96), 217, 49) {}
# Maxen
# Score are for NS : 0.1707574546054719, EW : 0.18595007252597054, both : 0.15298722186218422
#
# --------------------------------------------------
#
# Run 79
# Calling _destroy_node  with  (95,) {}
# Action
# Score are for NS : 0.16751264585703668, EW : 0.17753253988471368, both : 0.14593899383284298
# Quick reducing 72 on EW
# Shorten
# Score are for NS : 0.16751264585703668, EW : 0.17753253988471368, both : 0.14593899383284298
# Calling setup_edge  with  ((96, 88), 222, 49) {}
# Maxen
# Score are for NS : 0.1628962069155753, EW : 0.17326294759321137, both : 0.14112845701455942
#
# --------------------------------------------------
#
# Run 80
# Calling _duplicate_node  with  (24,) {}
# Action
# Score are for NS : 0.13243621089438473, EW : 0.1717483925436519, both : 0.12877542898826277
# Quick reducing 72 on EW
# Shorten
# Score are for NS : 0.13243621089438473, EW : 0.1717483925436519, both : 0.12877542898826277
# Calling setup_edge  with  ((18, 88), 208, 96) {}
# Maxen
# Score are for NS : 0.16494360173681274, EW : 0.19507966088782838, both : 0.15056047847867451
#
# --------------------------------------------------
#
# Run 81
# Calling _destroy_node  with  (87,) {}
# Action
# Score are for NS : 0.16235067781467652, EW : 0.18236508419487188, both : 0.1447204160363827
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.15838338936146723, EW : 0.1790495300145379, both : 0.14012856712915642
# Calling setup_edge  with  ((58, 96), 231, 70) {}
# Maxen
# Score are for NS : 0.1350553083695861, EW : 0.18236508419487188, both : 0.13680403926330906
#
# --------------------------------------------------
#
# Run 82
# Calling _duplicate_node  with  (62,) {}
# Action
# Score are for NS : 0.13874597710563796, EW : 0.20380594683858103, both : 0.1508266096015072
# Quick reducing 61 on EW
# Shorten
# Score are for NS : 0.14468193428047207, EW : 0.18715315743857247, both : 0.14581818673161384
# Calling setup_edge  with  ((96, 41), 240, 70) {}
# Maxen
# Score are for NS : 0.14468193428047207, EW : 0.18027756377319945, both : 0.14254682275362263
#
# --------------------------------------------------
#
# Run 83
# Calling _duplicate_node  with  (33,) {}
# Action
# Score are for NS : 0.14346090287621963, EW : 0.18081913334633248, both : 0.1417429850111989
# Quick reducing 68 on NS
# Shorten
# Score are for NS : 0.13757131423753924, EW : 0.17819072190490803, both : 0.13658996032096854
# Calling setup_edge  with  ((24, 18), 249, 96) {}
# Maxen
# Score are for NS : 0.13757131423753924, EW : 0.16843672118210415, both : 0.13003927736518847
#
# --------------------------------------------------
#
# Run 84
# Calling _destroy_node  with  (59,) {}
# Action
# Score are for NS : 0.14371629134298766, EW : 0.16326301485382713, both : 0.13028936968848467
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.14371629134298766, EW : 0.16326301485382713, both : 0.13028936968848467
# Calling setup_edge  with  ((81, 44), 239, 90) {}
# Maxen
# Score are for NS : 0.14371629134298766, EW : 0.16326301485382713, both : 0.13028936968848467
#
# --------------------------------------------------
#
# Run 85
# Calling _duplicate_node  with  (83,) {}
# Action
# Score are for NS : 0.14249932390163625, EW : 0.16925351641479877, both : 0.13254076075692153
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.14249932390163625, EW : 0.16925351641479877, both : 0.13254076075692153
# Calling setup_edge  with  ((40, 57), 42, 99) {}
# Maxen
# Score are for NS : 0.14527942452995526, EW : 0.15039958406871906, both : 0.1351994875532093
#
# --------------------------------------------------
#
# Run 86
# Calling _duplicate_node  with  (18,) {}
# Action
# Score are for NS : 0.1413127564051438, EW : 0.15041176123118385, both : 0.13015660222905848
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.1413127564051438, EW : 0.15041176123118385, both : 0.13015660222905848
# Calling setup_edge  with  ((18, 96), 247, 104) {}
# Quasi lonely node 18 with #ngbs = 2
# Maxen
# Score are for NS : 0.14270816333604322, EW : 0.14780110899175894, both : 0.13015660222905848
#
# --------------------------------------------------
#
# Run 87
# Calling _duplicate_node  with  (4,) {}
# Action
# Score are for NS : 0.14153603771816686, EW : 0.1557096095516528, both : 0.1327106326917217
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.14153603771816686, EW : 0.1557096095516528, both : 0.1327106326917217
# Calling setup_edge  with  ((96, 70), 208, 49) {}
# Maxen
# Score are for NS : 0.13873448207196015, EW : 0.1489758590252227, both : 0.12563504085243477
#
# --------------------------------------------------
#
# Run 88
# Calling _destroy_node  with  (97,) {}
# Action
# Score are for NS : 0.12269599030180221, EW : 0.15015594938715943, both : 0.1190065610643156
# Reducing node 89
# Calling replace_edge  with  ((13, 5), (89, 75)) {}
# Shorten
# Score are for NS : 0.12201434341912429, EW : 0.1521516881145997, both : 0.12188932372705048
# Calling setup_edge  with  ((41, 70), 247, 18) {}
# Maxen
# Score are for NS : 0.12247410248491844, EW : 0.14797583377569434, both : 0.11930456376352787
#
# --------------------------------------------------
#
# Run 89
# Calling _duplicate_node  with  (27,) {}
# Action
# Score are for NS : 0.12166590182491102, EW : 0.15270901192789427, both : 0.12209051383171285
# Quick reducing 53 on NS
# Shorten
# Score are for NS : 0.1157337446445231, EW : 0.15270901192789427, both : 0.11963861252029338
# Calling setup_edge  with  ((90, 44), 256, 81) {}
# Maxen
# Score are for NS : 0.1157337446445231, EW : 0.15448865972793283, both : 0.12055175697340784
#
# --------------------------------------------------
#
# Run 90
# Calling _duplicate_node  with  (6,) {}
# Action
# Score are for NS : 0.1177761405037802, EW : 0.16109343227385395, both : 0.12739250675227026
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.1177761405037802, EW : 0.16475089420958278, both : 0.13026178177244216
# Calling setup_edge  with  ((57, 58), 133, 70) {}
# Maxen
# Score are for NS : 0.1433262381603182, EW : 0.15570566241205774, both : 0.1353271075501208
#
# --------------------------------------------------
#
# Run 91
# Calling _duplicate_node  with  (27,) {}
# Quasi lonely node 27 with #ngbs = 2
# Action
# Score are for NS : 0.14805351248336932, EW : 0.1647187251827419, both : 0.14285714285714285
# Quick reducing 27 on EW
# Shorten
# Score are for NS : 0.14805351248336932, EW : 0.15930231976004863, both : 0.1402136819482013
# Calling setup_edge  with  ((81, 44), 267, 90) {}
# Maxen
# Score are for NS : 0.14805351248336932, EW : 0.15802831743719556, both : 0.13947017024999506
#
# --------------------------------------------------
#
# Run 92
# Calling _destroy_node  with  (103,) {}
# Action
# Score are for NS : 0.14891769203824057, EW : 0.15852544117801998, both : 0.1400721888576099
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.14891769203824057, EW : 0.16130940906347402, both : 0.14149615840192942
# Calling setup_edge  with  ((49, 70), 136, 57) {}
# Maxen
# Score are for NS : 0.14891769203824057, EW : 0.15734437208246266, both : 0.1421953265604245
#
# --------------------------------------------------
#
# Run 93
# Calling _duplicate_node  with  (92,) {}
# Action
# Score are for NS : 0.16389560824818716, EW : 0.18052930792885394, both : 0.15781076794419452
# Quick reducing 46 on EW
# Shorten
# Score are for NS : 0.16389560824818716, EW : 0.18052930792885394, both : 0.15781076794419452
# Calling setup_edge  with  ((4, 83), 272, 2) {}
# Removing crossing border edge 2 16 (141, 190, 0)
# Maxen
# Score are for NS : 0.16389560824818716, EW : 0.16623850387253286, both : 0.15436215019494803
#
# --------------------------------------------------
#
# Run 94
# Calling _destroy_node  with  (13,) {}
# Removing crossing border edge 107 75 (5, 263, 0)
# Removing crossing border edge 107 14 (5, 101, 0)
# Action
# Score are for NS : 0.16304600161020064, EW : 0.16791940943888325, both : 0.15560705079735312
# Quick reducing 46 on EW
# Shorten
# Score are for NS : 0.16304600161020064, EW : 0.16791940943888325, both : 0.15560705079735312
# Calling setup_edge  with  ((4, 9), 243, 98) {}
# Maxen
# Score are for NS : 0.15770301904064132, EW : 0.16791940943888325, both : 0.15350626564370076
#
# --------------------------------------------------
#
# Run 95
# Calling _destroy_node  with  (102,) {}
# Action
# Score are for NS : 0.17168446509674531, EW : 0.17218911082159638, both : 0.16270138515749477
# Quick reducing 46 on EW
# Shorten
# Score are for NS : 0.17168446509674531, EW : 0.17218911082159638, both : 0.16270138515749477
# Calling setup_edge  with  ((10, 94), 132, 19) {}
# Maxen
# Score are for NS : 0.14582895151961203, EW : 0.17092050872198827, both : 0.15270327670864867
#
# --------------------------------------------------
#
# Run 96
# Calling _duplicate_node  with  (19,) {}
# Action
# Score are for NS : 0.13720280512329422, EW : 0.17365358525432867, both : 0.1500746938586541
# Quick reducing 46 on EW
# Shorten
# Score are for NS : 0.13720280512329422, EW : 0.17365358525432867, both : 0.1500746938586541
# Calling setup_edge  with  ((18, 104), 145, 94) {}
# Maxen
# Score are for NS : 0.13309615094780683, EW : 0.16260765989533107, both : 0.13617092046366464
#
# --------------------------------------------------
#
# Run 97
# Calling _duplicate_node  with  (100,) {}
# Action
# Score are for NS : 0.13369601779676618, EW : 0.16145503202572742, both : 0.1340193074907993
# Quick reducing 46 on EW
# Shorten
# Score are for NS : 0.13369601779676618, EW : 0.16145503202572742, both : 0.1340193074907993
# Calling setup_edge  with  ((75, 78), 5, 6) {}
# Removing crossing border edge 6 75 (284, 283, 0)
# Maxen
# Score are for NS : 0.13683440555529955, EW : 0.15694560111724729, both : 0.136035524008804
#
# --------------------------------------------------
#
# Run 98
# Calling _duplicate_node  with  (86,) {}
# Action
# Score are for NS : 0.14459078573204473, EW : 0.16038681909302865, both : 0.14197763722927753
# Quick reducing 46 on EW
# Shorten
# Score are for NS : 0.14459078573204473, EW : 0.15551619079064877, both : 0.13891110933361772
# Calling setup_edge  with  ((36, 21), 54, 15) {}
# Maxen
# Score are for NS : 0.14193075922278786, EW : 0.15551619079064877, both : 0.13775089343439959
#
# --------------------------------------------------
#
# Run 99
# Calling _destroy_node  with  (80,) {}
# Action
# Score are for NS : 0.14268717594049496, EW : 0.15743692432937137, both : 0.13783789492452728
# Quick reducing 53 on NS
# Shorten
# Score are for NS : 0.14268717594049496, EW : 0.15743692432937137, both : 0.13783789492452728
# Calling setup_edge  with  ((43, 37), 218, 108) {}
# Maxen
# Score are for NS : 0.1235299693995946, EW : 0.15743692432937137, both : 0.13166828608761355
#
# ...
# Calling setup_edge  with  ((205, 154), 502, 193) {}
# Maxen
# Score are for NS : 0.2288278258406949, EW : 0.34193631195530755, both : 0.2703318145184329
#
# --------------------------------------------------
#
# Run 268
# Calling _destroy_node  with  (166,) {}
# Action
# Score are for NS : 0.2301819076558256, EW : 0.3425479560841296, both : 0.27165916716513905
# Reducing node 175
# Calling replace_edge  with  ((119, 196), (175, 207)) {}
# Shorten
# Score are for NS : 0.23176816388107, EW : 0.3448533681590637, both : 0.27416503335268655
# Calling setup_edge  with  ((193, 154), 676, 72) {}
# Maxen
# Score are for NS : 0.2331635356890095, EW : 0.34485336815906376, both : 0.27584609938285265
#
# --------------------------------------------------
#
# Run 269
# Calling _duplicate_node  with  (5,) {}
# Action
# Score are for NS : 0.2330959626648452, EW : 0.3430429374967181, both : 0.27508511276109143
# Quick reducing 175 on EW
# Shorten
# Score are for NS : 0.2330959626648452, EW : 0.3430429374967181, both : 0.27508511276109143
# Calling setup_edge  with  ((169, 14), 656, 200) {}
# Maxen
# Score are for NS : 0.26418905729516484, EW : 0.3413545122506928, both : 0.2909661275181567
#
# --------------------------------------------------
#
# Run 270
# Calling _duplicate_node  with  (145,) {}
# Action
# Score are for NS : 0.26729305518675334, EW : 0.34311168238800777, both : 0.2937507830461191
# Quick reducing 175 on EW
# Shorten
# Score are for NS : 0.26729305518675334, EW : 0.34311168238800777, both : 0.2937507830461191
# Calling setup_edge  with  ((133, 14), 657, 75) {}
# Maxen
# Score are for NS : 0.3036376917072508, EW : 0.3265245636642009, both : 0.3046818219280217
#
# --------------------------------------------------
#
# Run 271
# Calling _duplicate_node  with  (18,) {}
# Action
# Score are for NS : 0.31227196683537073, EW : 0.33224950381479706, both : 0.3120127535968529
# Reducing node 18
# Calling replace_edge  with  ((27, 125), (18, 126)) {}
# Shorten
# Score are for NS : 0.3102835533557768, EW : 0.3305491792825776, both : 0.31008193678642987
# Calling setup_edge  with  ((75, 14), 690, 78) {}
# Maxen
# Score are for NS : 0.29547646937528393, EW : 0.3305491792825776, both : 0.3025902291557946
#
# --------------------------------------------------
#
# Run 272
# Calling _duplicate_node  with  (159,) {}
# Action
# Score are for NS : 0.29318587841795807, EW : 0.3280333045357683, both : 0.3001601629175539
# Quick reducing 125 on EW
# Shorten
# Score are for NS : 0.29064106580579274, EW : 0.32573521068300315, both : 0.29762932683348003
# Calling setup_edge  with  ((201, 28), 661, 96) {}
# Maxen
# Score are for NS : 0.29064106580579274, EW : 0.32573521068300315, both : 0.2974739580739253
#
# --------------------------------------------------
#
# Run 273
# Calling _destroy_node  with  (158,) {}
# Quasi lonely node 198 with #ngbs = 2
# Action
# Score are for NS : 0.29221467683928093, EW : 0.3544247379578056, both : 0.3137206603950559
# Quick reducing 198 on EW
# Shorten
# Score are for NS : 0.29984615407225007, EW : 0.35733396783137716, both : 0.3190109340852594
# Calling setup_edge  with  ((96, 28), 625, 201) {}
# Maxen
# Score are for NS : 0.29984615407225007, EW : 0.35733396783137716, both : 0.3191542267871925
#
# --------------------------------------------------
#
# Run 274
# Calling _destroy_node  with  (140,) {}
# Action
# Score are for NS : 0.3249292417266562, EW : 0.35596063570151226, both : 0.33232854902932124
# Quick reducing 211 on EW
# Shorten
# Score are for NS : 0.3203968841032905, EW : 0.34951280537845403, both : 0.32659701955028475
# Calling setup_edge  with  ((14, 148), 614, 133) {}
# Maxen
# Score are for NS : 0.2962820387955824, EW : 0.3670390224389091, both : 0.32214501464989814
#
# --------------------------------------------------
#
# Run 275
# Calling _destroy_node  with  (73,) {}
# Action
# Score are for NS : 0.3009236311825672, EW : 0.3671391440750785, both : 0.3262684818186266
# Reducing node 125
# Calling replace_edge  with  ((18, 126), (125, 192)) {}
# Shorten
# Score are for NS : 0.30422305078147965, EW : 0.3676238236944254, both : 0.3279982776674626
# Calling setup_edge  with  ((14, 133), 707, 148) {}
# Maxen
# Score are for NS : 0.31722908520210236, EW : 0.3473276405500629, both : 0.3249240804809128
#
# --------------------------------------------------
#
# Run 276
# Calling _duplicate_node  with  (36,) {}
# Action
# Score are for NS : 0.30925726324483394, EW : 0.3600083071073339, both : 0.3277707400090738
# Quick reducing 18 on EW
# Shorten
# Score are for NS : 0.30386965629100393, EW : 0.35271310460414057, both : 0.32123217786088304
# Calling setup_edge  with  ((14, 148), 707, 182) {}
# Maxen
# Score are for NS : 0.2922101875131213, EW : 0.3578509553174443, both : 0.3179204093017164
#
# --------------------------------------------------
#
# Run 277
# Calling _destroy_node  with  (96,) {}
# Action
# Score are for NS : 0.29089217000907513, EW : 0.3505102230338102, both : 0.31383865621284257
# Reducing node 18
# Calling replace_edge  with  ((125, 192), (18, 126)) {}
# Shorten
# Score are for NS : 0.29089217000907513, EW : 0.34775065926227555, both : 0.3123393703244428
# Calling setup_edge  with  ((28, 201), 501, 190) {}
# Maxen
# Score are for NS : 0.2652713335188342, EW : 0.34775065926227555, both : 0.299554512765557
#
# --------------------------------------------------
#
# Run 278
# Calling _duplicate_node  with  (197,) {}
# Action
# Score are for NS : 0.26771680418792226, EW : 0.3489567786035017, both : 0.30157134893375737
# Reducing node 18
# Calling replace_edge  with  ((126, 192), (18, 159)) {}
# Shorten
# Score are for NS : 0.26771680418792226, EW : 0.3489567786035017, both : 0.30157134893375737
# Calling setup_edge  with  ((179, 182), 678, 200) {}
# Maxen
# Score are for NS : 0.26771680418792226, EW : 0.34563205624054893, both : 0.3001103528296884
#
# --------------------------------------------------
#
# Run 279
# Calling _destroy_node  with  (182,) {}
# Action
# Score are for NS : 0.2779598289082874, EW : 0.34543262276398873, both : 0.30588928239622715
# Quick reducing 198 on EW
# Shorten
# Score are for NS : 0.2861766759442547, EW : 0.3508367423077099, both : 0.3129971775838463
# Calling setup_edge  with  ((75, 78), 655, 69) {}
# Maxen
# Score are for NS : 0.2861766759442547, EW : 0.3472561858383346, both : 0.3115409376947935
#
# --------------------------------------------------
#
# Run 280
# Calling _destroy_node  with  (104,) {}
# Action
# Score are for NS : 0.2871398555909346, EW : 0.3463446613216771, both : 0.3105731040637199
# Quick reducing 192 on EW
# Shorten
# Score are for NS : 0.28465663915856865, EW : 0.34273926173762304, both : 0.30730458595051807
# Calling setup_edge  with  ((75, 14), 711, 78) {}
# Maxen
# Score are for NS : 0.28267609910563696, EW : 0.34273926173762304, both : 0.3062884991279968
#
# --------------------------------------------------
#
# Run 281
# Calling _duplicate_node  with  (28,) {}
# Action
# Score are for NS : 0.2791239940987386, EW : 0.3524447774338529, both : 0.31056110731379294
# Reducing node 211
# Calling replace_edge  with  ((210, 145), (211, 86)) {}
# Shorten
# Score are for NS : 0.2791239940987386, EW : 0.3524447774338529, both : 0.31056110731379294
# Calling setup_edge  with  ((19, 154), 657, 133) {}
# Maxen
# Score are for NS : 0.30280272123200613, EW : 0.3524447774338529, both : 0.32059892930168643
#
# --------------------------------------------------
#
# Run 282
# Calling _destroy_node  with  (171,) {}
# Action
# Score are for NS : 0.29830692719985774, EW : 0.37522398216397723, both : 0.3282605063137958
# Reducing node 18
# Calling replace_edge  with  ((192, 126), (18, 159)) {}
# Shorten
# Score are for NS : 0.29830692719985774, EW : 0.37522398216397723, both : 0.3282605063137958
# Calling setup_edge  with  ((154, 72), 723, 19) {}
# Maxen
# Score are for NS : 0.30462042707947184, EW : 0.3678502283851399, both : 0.32693861936771834
#
# --------------------------------------------------
#
# Run 283
# Calling _duplicate_node  with  (213,) {}
# Action
# Score are for NS : 0.3021827285047487, EW : 0.36614920221636305, both : 0.3250189400411298
# Quick reducing 198 on EW
# Shorten
# Score are for NS : 0.3021827285047487, EW : 0.36614920221636305, both : 0.3250189400411298
# Calling setup_edge  with  ((19, 190), 651, 215) {}
# Maxen
# Score are for NS : 0.2647737484522783, EW : 0.36614920221636305, both : 0.3063735094173895
#
# --------------------------------------------------
#
# Run 284
# Calling _duplicate_node  with  (192,) {}
# Action
# Score are for NS : 0.2692019197154246, EW : 0.3689320988615191, both : 0.3102684465634516
# Reducing node 27
# Calling replace_edge  with  ((192, 18), (27, 159)) {}
# Shorten
# Score are for NS : 0.2692019197154246, EW : 0.3689320988615191, both : 0.3102684465634516
# Calling setup_edge  with  ((14, 133), 707, 148) {}
# Maxen
# Score are for NS : 0.2692019197154246, EW : 0.3808651778912831, both : 0.31470595421394215
#
# --------------------------------------------------
#
# Run 285
# Calling _duplicate_node  with  (187,) {}
# Quasi lonely node 187 with #ngbs = 2
# Action
# Score are for NS : 0.26920374183721835, EW : 0.37795713795245195, both : 0.3128954813747404
# Reducing node 211
# Calling replace_edge  with  ((145, 210), (211, 86)) {}
# Shorten
# Score are for NS : 0.26920374183721835, EW : 0.37795713795245195, both : 0.3128954813747404
# Calling setup_edge  with  ((19, 75), 727, 215) {}
# Maxen
# Score are for NS : 0.26920374183721835, EW : 0.38018967888277655, both : 0.31554125951425627
#
# --------------------------------------------------
#
# Run 286
# Calling _duplicate_node  with  (175,) {}
# Action
# Score are for NS : 0.2707907516722029, EW : 0.38111202865384614, both : 0.3170754252829902
# Quick reducing 217 on EW
# Shorten
# Score are for NS : 0.2568671135191932, EW : 0.36315659989787147, both : 0.30011071622736457
# Calling setup_edge  with  ((14, 98), 707, 148) {}
# Maxen
# Score are for NS : 0.2568671135191932, EW : 0.3380494322882365, both : 0.2896196569265695
#
# --------------------------------------------------
#
# Run 287
# Calling _duplicate_node  with  (214,) {}
# Action
# Score are for NS : 0.2612942816836984, EW : 0.3432263698898032, both : 0.29469339678922446
# Reducing node 211
# Calling replace_edge  with  ((18, 125), (211, 126)) {}
# Shorten
# Score are for NS : 0.2612942816836984, EW : 0.3432263698898032, both : 0.29469339678922446
# Calling setup_edge  with  ((201, 190), 659, 153) {}
# Maxen
# Score are for NS : 0.2612942816836984, EW : 0.3190431940174257, both : 0.28302349767737817
#
# --------------------------------------------------
#
# Run 288
# Calling _duplicate_node  with  (72,) {}
# Action
# Score are for NS : 0.25627151124266484, EW : 0.31880824155886484, both : 0.2794502844414113
# Quick reducing 211 on EW
# Shorten
# Score are for NS : 0.25627151124266484, EW : 0.31880824155886484, both : 0.2794502844414113
# Calling setup_edge  with  ((190, 153), 734, 28) {}
# Maxen
# Score are for NS : 0.267132925713024, EW : 0.33565777098884914, both : 0.2933739659601454
#
# --------------------------------------------------
#
# Run 289
# Calling _duplicate_node  with  (206,) {}
# Action
# Score are for NS : 0.26642721080458937, EW : 0.34904686155593473, both : 0.2986103315533497
# Quick reducing 214 on EW
# Shorten
# Score are for NS : 0.26642721080458937, EW : 0.34670956561483085, both : 0.2974539622529336
# Calling setup_edge  with  ((19, 215), 723, 72) {}
# Maxen
# Score are for NS : 0.2649413252348046, EW : 0.360521296429501, both : 0.3022698389486434
#
# --------------------------------------------------
#
# Run 290
# Calling _duplicate_node  with  (18,) {}
# Action
# Score are for NS : 0.26902551910446343, EW : 0.36258321917594055, both : 0.30563327698745196
# Quick reducing 175 on EW
# Shorten
# Score are for NS : 0.2662962296573982, EW : 0.3611565779366733, both : 0.30289183461007185
# Calling setup_edge  with  ((137, 78), 656, 169) {}
# Maxen
# Score are for NS : 0.26557879211514135, EW : 0.3611565779366733, both : 0.30222086390046077
#
# --------------------------------------------------
#
# Run 291
# Calling _destroy_node  with  (215,) {}
# Action
# Score are for NS : 0.2889603414036525, EW : 0.3627970173803643, both : 0.3107690976274805
# Quick reducing 220 on EW
# Shorten
# Score are for NS : 0.28672557534261844, EW : 0.36037514094972317, both : 0.30830200242696176
# Calling setup_edge  with  ((78, 75), 707, 14) {}
# Maxen
# Score are for NS : 0.30194866871269904, EW : 0.3646862261669584, both : 0.3182398399708636
#
# --------------------------------------------------
#
# Run 292
# Calling _destroy_node  with  (100,) {}
# Action
# Score are for NS : 0.3264840966381728, EW : 0.34699182389598404, both : 0.32636125043872516
# Quick reducing 223 on NS
# Shorten
# Score are for NS : 0.32871718345800327, EW : 0.34699182389598404, both : 0.32747802206346865
# Calling setup_edge  with  ((188, 134), 552, 160) {}
# Removing crossing border edge 160 201 (659, 575, 0)
# Maxen
# Score are for NS : 0.3197001332374291, EW : 0.3486552178285326, both : 0.3231906710875703
#
# --------------------------------------------------
#
# Run 293
# Calling _duplicate_node  with  (222,) {}
# Action
# Score are for NS : 0.31790400911508243, EW : 0.34688314049123953, both : 0.3213219446655178
# Quick reducing 223 on NS
# Shorten
# Score are for NS : 0.31845990984580197, EW : 0.34510308355893066, both : 0.3204841056087314
# Calling setup_edge  with  ((28, 75), 655, 69) {}
# Maxen
# Score are for NS : 0.30134334480050434, EW : 0.34510308355893066, both : 0.31151352112471864
#
# --------------------------------------------------
#
# Run 294
# Calling _duplicate_node  with  (83,) {}
# Action
# Score are for NS : 0.3003677581668648, EW : 0.34177342861200605, both : 0.3092807354962155
# Quick reducing 192 on NS
# Shorten
# Score are for NS : 0.29925007398577536, EW : 0.34355989262802167, both : 0.30984047778706597
# Calling setup_edge  with  ((98, 133), 430, 154) {}
# Maxen
# Score are for NS : 0.27150592954410646, EW : 0.34355989262802167, both : 0.29719079464386616
#
# --------------------------------------------------
#
# Run 295
# Calling _duplicate_node  with  (194,) {}
# Action
# Score are for NS : 0.270016512447604, EW : 0.3418648290636839, both : 0.29567365583217964
# Quick reducing 219 on EW
# Shorten
# Score are for NS : 0.2738845035796571, EW : 0.3445567200790135, both : 0.2993581226913363
# Calling setup_edge  with  ((14, 148), 687, 208) {}
# Maxen
# Score are for NS : 0.2563447217419335, EW : 0.3445567200790135, both : 0.2919759512331477
#
# --------------------------------------------------
#
# Run 296
# Calling _destroy_node  with  (201,) {}
# Action
# Score are for NS : 0.25532747764978303, EW : 0.35279203820696153, both : 0.29597554570970436
# Quick reducing 175 on EW
# Shorten
# Score are for NS : 0.25377217399521107, EW : 0.3451684062076371, both : 0.2912815808449916
# Calling setup_edge  with  ((154, 133), 753, 208) {}
# Maxen
# Score are for NS : 0.2530062796367935, EW : 0.3445295262163416, both : 0.28948922603381894
#
# --------------------------------------------------
#
# Run 297
# Calling _destroy_node  with  (150,) {}
# Quasi lonely node 187 with #ngbs = 2
# Action
# Score are for NS : 0.2542153174381417, EW : 0.34798295581146815, both : 0.29184511323058643
# Quick reducing 27 on EW
# Shorten
# Score are for NS : 0.2542153174381417, EW : 0.3448148051392691, both : 0.2901521379084102
# Calling setup_edge  with  ((153, 28), 659, 181) {}
# Maxen
# Score are for NS : 0.25278647054722886, EW : 0.3448148051392691, both : 0.28945004513371964
#
# --------------------------------------------------
#
# Run 298
# Calling _duplicate_node  with  (125,) {}
# Quasi lonely node 125 with #ngbs = 2
# Action
# Score are for NS : 0.2627677206203227, EW : 0.354514637533962, both : 0.2999930092884884
# Quick reducing 220 on EW
# Shorten
# Score are for NS : 0.2593288684051664, EW : 0.35104599687115895, both : 0.29654481996558935
# Calling setup_edge  with  ((181, 28), 659, 134) {}
# Maxen
# Score are for NS : 0.25732968727562505, EW : 0.34270780438465953, both : 0.2889601139435203
#
# --------------------------------------------------
#
# Run 299
# Calling _duplicate_node  with  (69,) {}
# Action
# Score are for NS : 0.2542010984346034, EW : 0.3372914109012689, both : 0.28423081785270893
# Quick reducing 227 on EW
# Quasi lonely node 125 with #ngbs = 2
# Shorten
# Score are for NS : 0.2626005789122696, EW : 0.3517410301685063, both : 0.29639342268595165
# Calling setup_edge  with  ((169, 78), 656, 137) {}
# Maxen
# Score are for NS : 0.26290919481444963, EW : 0.3455168257326904, both : 0.2942203417429763

# %%
seed = 2
random.seed(seed)
np.random.seed(seed)
gpn = RGPN()
gpn.debug = True
gpn.init_tissue(8)
gpn.update_all_dist()
ignore_export = False

def quick_export(gpn, pos, name):
    global ignore_export
    if ignore_export:
        return
    gpn.update_all_dist()
    gpn.show_dist(pos=pos, figsize=(8, 8))
    plt.savefig(name)
    plt.close()

pos = nx.spring_layout(gpn.G, k=0.1, iterations=50)
root = "output/evonet8/"
ratio = 0
for i in range(300):
    # print(gpn.G.number_of_nodes(), ratio)
    # gpn.check_all()
    print()
    print("-" * 50)
    print()
    print(f"Run {i}")
    if i < 100:
        if p_dupl():
            ratio += 1
            gpn.duplicate_random()
        else:
            ratio -= 1
            gpn.destroy_random()
        
    pos = embedded_viz(gpn)
    quick_export(gpn, pos, root + str(i).zfill(4) + "_a.png")
    
    print("Action")
    gpn.update_all_dist()
    gpn.print_dist_metrics()

    if gpn.shorten_dist():
        pos = embedded_viz(gpn)
        quick_export(gpn, pos, root + str(i).zfill(4) + "_b.png")
        print("Shorten")
        gpn.update_all_dist()
        gpn.print_dist_metrics()

    if gpn.maxen_dist():
        pos = embedded_viz(gpn)
        quick_export(gpn, pos, root + str(i).zfill(4) + "_c.png")
        print("Maxen")
        gpn.update_all_dist()
        gpn.print_dist_metrics()
        
    if i % 100 == 0:
        print()
        print("Iteration", i, "ratio", ratio, "density", gpn.density())
# Out:
# Calling _init_square  with  () {'size': 8}
#
# --------------------------------------------------
#
# Run 0
# Calling _destroy_node  with  (7,) {}
# Action
# Score are for NS : 0.0, EW : 0.04561979233461597, both : 0.022627416997969524
# Calling setup_edge  with  ((5, 4), 4, 13) {}
# Maxen
# Score are for NS : 0.06133864568481871, EW : 0.038182480641090595, both : 0.03826642173766337
#
# Iteration 0 ratio -1 density 0.08035714285714286
#
# --------------------------------------------------
#
# Run 1
# Calling _destroy_node  with  (16,) {}
# Action
# Score are for NS : 0.07104794552601071, EW : 0.034775219661479034, both : 0.041728039728706694
# Quick reducing 10 on EW
# Shorten
# Score are for NS : 0.07104794552601071, EW : 0.025124887958952576, both : 0.03843856035825846
#
# --------------------------------------------------
#
# Run 2
# Calling _destroy_node  with  (39,) {}
# Action
# Score are for NS : 0.07618388046902588, EW : 0.025321166646154344, both : 0.04102726510015224
# Quick reducing 11 on EW
# Shorten
# Score are for NS : 0.07618388046902588, EW : 0.025321166646154344, both : 0.04102726510015224
#
# --------------------------------------------------
#
# Run 3
# Calling _destroy_node  with  (8,) {}
# Action
# Score are for NS : 0.10296611677655133, EW : 0.02552210809068485, both : 0.052996071808102646
# Reducing node 12
# Calling replace_edge  with  ((4, 20), (12, 21)) {}
# Shorten
# Score are for NS : 0.10360696516619473, EW : 0.0, both : 0.04975185951049945
# Calling setup_edge  with  ((48, 40), 35, 49) {}
# Removing crossing border edge 49 57 (43, 42, 0)
# Maxen
# Score are for NS : 0.10371386170743915, EW : 0.04950504382128918, both : 0.06206296004113861
#
# --------------------------------------------------
#
# Run 4
# Calling _destroy_node  with  (1,) {}
# Action
# Score are for NS : 0.10413873124952305, EW : 0.06747671321155246, both : 0.06831112515824006
# Calling setup_edge  with  ((0, 24), 7, 17) {}
# Maxen
# Score are for NS : 0.07956703105677204, EW : 0.07450579303953439, both : 0.058366645448548735
#
# --------------------------------------------------
#
# Run 5
# Calling _destroy_node  with  (0,) {}
# Action
# Score are for NS : 0.07240186942735768, EW : 0.11224890839387841, both : 0.07084813499787627
# Calling setup_edge  with  ((3, 2), 51, 9) {}
# Maxen
# Score are for NS : 0.07590634264134714, EW : 0.0747793552727, both : 0.05732369991559463
#
# --------------------------------------------------
#
# Run 6
# Calling _duplicate_node  with  (50,) {}
# Action
# Score are for NS : 0.07625101304718421, EW : 0.07008203859789625, both : 0.05513517695918211
# Quick reducing 10 on NS
# Shorten
# Score are for NS : 0.07206350455013028, EW : 0.07008203859789625, both : 0.05328497513885871
# Calling setup_edge  with  ((20, 19), 17, 28) {}
# Maxen
# Score are for NS : 0.07206350455013028, EW : 0.07008203859789625, both : 0.05328497513885871
#
# --------------------------------------------------
#
# Run 7
# Calling _duplicate_node  with  (31,) {}
# Action
# Score are for NS : 0.06250530808103212, EW : 0.06961912187590956, both : 0.04773973041333154
# Quick reducing 48 on EW
# Removing crossing border edge 48 57 (43, 60, 0)
# Shorten
# Score are for NS : 0.06250530808103212, EW : 0.06961912187590956, both : 0.04773973041333154
# Calling setup_edge  with  ((58, 64), 43, 48) {}
# Removing crossing border edge 48 58 (61, 60, 0)
# Maxen
# Score are for NS : 0.06401477588640982, EW : 0.06567573842287922, both : 0.048600935171382434
#
# --------------------------------------------------
#
# Run 8
# Calling _duplicate_node  with  (10,) {}
# Action
# Score are for NS : 0.06843859108291549, EW : 0.06916411091638353, both : 0.053727903073109165
# Quick reducing 10 on EW
# Shorten
# Score are for NS : 0.06348582382697432, EW : 0.055767644131493675, both : 0.04375873296829238
# Calling setup_edge  with  ((53, 45), 39, 44) {}
# Maxen
# Score are for NS : 0.04195358458333707, EW : 0.055767644131493675, both : 0.03421920126082923
#
# --------------------------------------------------
#
# Run 9
# Calling _duplicate_node  with  (60,) {}
# Action
# Score are for NS : 0.044493008776300635, EW : 0.07886766344095836, both : 0.04837812808314404
# Quick reducing 20 on EW
# Shorten
# Score are for NS : 0.044493008776300635, EW : 0.07697370086861781, both : 0.04779548266588911
# Calling setup_edge  with  ((3, 9), 57, 66) {}
# Maxen
# Score are for NS : 0.06552545477649473, EW : 0.04930096990483421, both : 0.04307753941578358
#
# --------------------------------------------------
#
# Run 10
# Calling _destroy_node  with  (30,) {}
# Action
# Score are for NS : 0.07063652550388305, EW : 0.09467157386320277, both : 0.061896110929484854
# Quick reducing 61 on EW
# Shorten
# Score are for NS : 0.0763196482756312, EW : 0.07194088392074452, both : 0.05742067285445725
# Calling setup_edge  with  ((51, 43), 37, 50) {}
# Maxen
# Score are for NS : 0.05523624443272046, EW : 0.07194088392074452, both : 0.04918872324575054
#
# --------------------------------------------------
#
# Run 11
# Calling _destroy_node  with  (24,) {}
# Action
# Score are for NS : 0.07773089794718827, EW : 0.07105297076439271, both : 0.056836293434893465
# Quick reducing 62 on EW
# Shorten
# Score are for NS : 0.07773089794718827, EW : 0.06708935898062418, both : 0.05413990650697526
# Calling setup_edge  with  ((49, 40), 36, 64) {}
# Removing crossing border edge 48 64 (43, 61, 0)
# Maxen
# Score are for NS : 0.05555555555555556, EW : 0.0820611295604749, both : 0.050793323902540904
#
# --------------------------------------------------
#
# Run 12
# Calling _duplicate_node  with  (11,) {}
# Action
# Score are for NS : 0.05942952731476786, EW : 0.09038244094776356, both : 0.05790660241435862
# Quick reducing 11 on EW
# Shorten
# Score are for NS : 0.05942952731476786, EW : 0.0819054279809437, both : 0.05418764935438058
#
# --------------------------------------------------
#
# Run 13
# Calling _destroy_node  with  (35,) {}
# Action
# Score are for NS : 0.08361578810320282, EW : 0.10103977164318785, both : 0.07202430145443968
# Quick reducing 11 on NS
# Shorten
# Score are for NS : 0.08195078893739613, EW : 0.10103977164318785, both : 0.07056648490117873
# Calling setup_edge  with  ((36, 43), 71, 27) {}
# Maxen
# Score are for NS : 0.057086406902116735, EW : 0.08189086883421186, both : 0.05170819643001996
#
# --------------------------------------------------
#
# Run 14
# Calling _duplicate_node  with  (38,) {}
# Action
# Score are for NS : 0.059429527314767853, EW : 0.0816991170792285, both : 0.05372790307310915
# Quick reducing 48 on EW
# Removing crossing border edge 48 58 (43, 75, 0)
# Shorten
# Score are for NS : 0.059429527314767853, EW : 0.0816991170792285, both : 0.05372790307310915
#
# --------------------------------------------------
#
# Run 15
# Calling _destroy_node  with  (17,) {}
# Action
# Score are for NS : 0.08428121139767301, EW : 0.08189086883421186, both : 0.05963404335064733
# Quick reducing 48 on EW
# Removing crossing border edge 48 57 (43, 75, 0)
# Shorten
# Score are for NS : 0.08428121139767301, EW : 0.08189086883421186, both : 0.05963404335064733
# Calling setup_edge  with  ((51, 50), 43, 48) {}
# Maxen
# Score are for NS : 0.08115401195323234, EW : 0.11101892776484865, both : 0.07302657786633317
#
# --------------------------------------------------
#
# Run 16
# Calling _duplicate_node  with  (59,) {}
# Action
# Score are for NS : 0.08203724604939515, EW : 0.11979166666666664, both : 0.07795119555779044
# Calling outside_with_anchor
# debug_anchor {'next_': 51, 'prev': 56, 'current': 48, 'ngb2': 56, 'ngb1': 58, 'node': 57, 'self': <__main__.RGPN object at 0x7f625b8abcf8>}
# Quick reducing 58 on EW
# Quasi lonely node 57 with #ngbs = 2
# Shorten
# Score are for NS : 0.08203724604939515, EW : 0.11582805750819235, both : 0.07670429255503206
# Calling setup_edge  with  ((48, 51), 75, 57) {}
# Maxen
# Score are for NS : 0.08346102078333788, EW : 0.0770954575447487, both : 0.06353337415691004
#
# --------------------------------------------------
#
# Run 17
# Calling _duplicate_node  with  (15,) {}
# Action
# Score are for NS : 0.09174757204474823, EW : 0.08199143253253666, both : 0.06855906957333396
# Quick reducing 15 on EW
# Shorten
# Score are for NS : 0.08901500259233483, EW : 0.08199143253253666, both : 0.07046902367866735
# Calling setup_edge  with  ((64, 40), 54, 41) {}
# Maxen
# Score are for NS : 0.06695905287797148, EW : 0.08194377305399407, both : 0.06161093644614961
#
# --------------------------------------------------
#
# Run 18
# Calling _duplicate_node  with  (44,) {}
# Action
# Score are for NS : 0.06665384985088607, EW : 0.08574700820781556, both : 0.06301954097412779
# Quick reducing 6 on NS
# Shorten
# Score are for NS : 0.061057342594364905, EW : 0.08574700820781556, both : 0.05941694197203951
#
# --------------------------------------------------
#
# Run 19
# Calling _destroy_node  with  (72,) {}
# Action
# Score are for NS : 0.07734818608815328, EW : 0.08180311857336536, both : 0.06204617525734186
# Quick reducing 6 on EW
# Shorten
# Score are for NS : 0.07886068896771578, EW : 0.07660909987781132, both : 0.060603043502854954
# Calling setup_edge  with  ((53, 61), 69, 62) {}
# Maxen
# Score are for NS : 0.060287377627780164, EW : 0.07660909987781132, both : 0.05569056158238845
#
# --------------------------------------------------
#
# Run 20
# Calling _destroy_node  with  (66,) {}
# Action
# Score are for NS : 0.059429527314767853, EW : 0.06591026911238415, both : 0.04770561760673847
# Quick reducing 69 on EW
# Shorten
# Score are for NS : 0.07349141800515326, EW : 0.060061647822533065, both : 0.047624798229001404
#
# --------------------------------------------------
#
# Run 21
# Calling _duplicate_node  with  (50,) {}
# Action
# Score are for NS : 0.07404343245377955, EW : 0.0655554777357089, both : 0.04867910102593633
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.06948675227085464, EW : 0.0655554777357089, both : 0.04703933518395359
#
# --------------------------------------------------
#
# Run 22
# Calling _destroy_node  with  (57,) {}
# Action
# Score are for NS : 0.06923242151460188, EW : 0.09543305571897803, both : 0.052352028876320685
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.06923242151460188, EW : 0.09543305571897803, both : 0.052352028876320685
# Calling setup_edge  with  ((55, 54), 48, 63) {}
# Maxen
# Score are for NS : 0.06406183920929016, EW : 0.09272315818623192, both : 0.050562937659107327
#
# --------------------------------------------------
#
# Run 23
# Calling _destroy_node  with  (68,) {}
# Action
# Score are for NS : 0.0642824346533225, EW : 0.09128709291752768, both : 0.05062114182829146
# Quick reducing 64 on EW
# Shorten
# Score are for NS : 0.0642824346533225, EW : 0.08636661918290675, both : 0.04814379125889359
# Calling setup_edge  with  ((51, 52), 45, 59) {}
# Maxen
# Score are for NS : 0.06357761155787182, EW : 0.05806039372799064, both : 0.04171361273849682
#
# --------------------------------------------------
#
# Run 24
# Calling _destroy_node  with  (70,) {}
# Action
# Score are for NS : 0.06303052300327669, EW : 0.04953487361146392, both : 0.03664064916862057
# Quick reducing 72 on EW
# Shorten
# Score are for NS : 0.0873123808176778, EW : 0.07207470450526221, both : 0.05987445738996795
# Calling setup_edge  with  ((64, 72), 43, 49) {}
# Maxen
# Score are for NS : 0.061141617942209806, EW : 0.07207470450526221, both : 0.04633156666562219
#
# --------------------------------------------------
#
# Run 25
# Calling _duplicate_node  with  (54,) {}
# Action
# Score are for NS : 0.06757373783994859, EW : 0.07774532443984881, both : 0.05513569019503094
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.06757373783994859, EW : 0.07474350927519359, both : 0.0512464272722893
# Calling setup_edge  with  ((72, 49), 54, 50) {}
# Maxen
# Score are for NS : 0.06757373783994859, EW : 0.07150695071305535, both : 0.04973129531394332
#
# --------------------------------------------------
#
# Run 26
# Calling _destroy_node  with  (58,) {}
# Action
# Score are for NS : 0.0670800237295626, EW : 0.07843817605661654, both : 0.052668281181057965
# Quick reducing 73 on NS
# Shorten
# Score are for NS : 0.0670800237295626, EW : 0.07843817605661654, both : 0.052668281181057965
# Calling setup_edge  with  ((56, 48), 75, 51) {}
# Removing crossing border edge 59 51 (45, 76, 2)
# Maxen
# Score are for NS : 0.06920703955552747, EW : 0.07843817605661654, both : 0.05005463487333822
#
# --------------------------------------------------
#
# Run 27
# Calling _destroy_node  with  (43,) {}
# Action
# Score are for NS : 0.06947722341290488, EW : 0.10666375417399938, both : 0.060602969012179646
# Quick reducing 62 on EW
# Shorten
# Score are for NS : 0.06947722341290488, EW : 0.10257192557338483, both : 0.05808480140406119
# Calling setup_edge  with  ((37, 36), 92, 38) {}
# Maxen
# Score are for NS : 0.06998385385238377, EW : 0.10148364010422706, both : 0.057930934380474274
#
# --------------------------------------------------
#
# Run 28
# Calling _destroy_node  with  (69,) {}
# Action
# Score are for NS : 0.06974529449261316, EW : 0.10098765591517082, both : 0.05843526519859515
# Quick reducing 12 on EW
# Shorten
# Score are for NS : 0.06974529449261316, EW : 0.09662328687021146, both : 0.05763604994348886
# Calling setup_edge  with  ((48, 72), 45, 56) {}
# Removing crossing border edge 48 56 (45, 109, 0)
# Maxen
# Score are for NS : 0.06917144638660747, EW : 0.0954243653710368, both : 0.05940988044009484
#
# --------------------------------------------------
#
# Run 29
# Calling _destroy_node  with  (52,) {}
# Action
# Score are for NS : 0.11681179883769897, EW : 0.09928953673961718, both : 0.07373988428607306
# Quick reducing 73 on NS
# Shorten
# Score are for NS : 0.11681179883769897, EW : 0.09928953673961718, both : 0.07373988428607306
# Calling setup_edge  with  ((38, 31), 66, 37) {}
# Maxen
# Score are for NS : 0.11846307154957493, EW : 0.0983102385219176, both : 0.07700020604586413
#
# --------------------------------------------------
#
# Run 30
# Calling _duplicate_node  with  (53,) {}
# Action
# Score are for NS : 0.13441660778956024, EW : 0.10626007617170598, both : 0.09156012936983102
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.13441660778956024, EW : 0.10626007617170598, both : 0.09156012936983102
# Calling setup_edge  with  ((32, 33), 28, 40) {}
# Maxen
# Score are for NS : 0.1332252369414442, EW : 0.10626007617170596, both : 0.0902335579878787
#
# --------------------------------------------------
#
# Run 31
# Calling _destroy_node  with  (72,) {}
# Action
# Score are for NS : 0.17490401299559202, EW : 0.1015690989838075, both : 0.11233551293741842
# Quick reducing 74 on NS
# Shorten
# Score are for NS : 0.17490401299559202, EW : 0.1015690989838075, both : 0.11233551293741842
# Calling setup_edge  with  ((10, 9), 108, 11) {}
# Maxen
# Score are for NS : 0.17200522903844537, EW : 0.09336221073251054, both : 0.11110992017513426
#
# --------------------------------------------------
#
# Run 32
# Calling _duplicate_node  with  (21,) {}
# Action
# Score are for NS : 0.1755625399263181, EW : 0.0927170410665807, both : 0.1150007563664736
# Quick reducing 74 on NS
# Shorten
# Score are for NS : 0.1755625399263181, EW : 0.0927170410665807, both : 0.1150007563664736
# Calling setup_edge  with  ((32, 2), 14, 25) {}
# Maxen
# Score are for NS : 0.1755625399263181, EW : 0.09412315235788216, both : 0.11698270750796472
#
# --------------------------------------------------
#
# Run 33
# Calling _destroy_node  with  (49,) {}
# Action
# Score are for NS : 0.1739280107286725, EW : 0.09475798222213436, both : 0.11578230203985024
# Quick reducing 74 on NS
# Shorten
# Score are for NS : 0.1739280107286725, EW : 0.09475798222213436, both : 0.11578230203985024
# Calling setup_edge  with  ((42, 34), 105, 44) {}
# Maxen
# Score are for NS : 0.16562688009835733, EW : 0.09475798222213436, both : 0.11246094963541974
#
# --------------------------------------------------
#
# Run 34
# Calling _duplicate_node  with  (4,) {}
# Action
# Score are for NS : 0.16430670062859754, EW : 0.12085784727553542, both : 0.12178937991969781
# Quick reducing 73 on NS
# Shorten
# Score are for NS : 0.16430670062859754, EW : 0.12085784727553542, both : 0.12178937991969781
# Calling setup_edge  with  ((25, 33), 28, 32) {}
# Maxen
# Score are for NS : 0.15114134240302327, EW : 0.12085784727553542, both : 0.1126056117820095
#
# --------------------------------------------------
#
# Run 35
# Calling _destroy_node  with  (74,) {}
# Action
# Score are for NS : 0.14561195265051152, EW : 0.11646890286489635, both : 0.10642074497831049
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.14046573894913136, EW : 0.11475726891674778, both : 0.10420628701229906
# Calling setup_edge  with  ((18, 9), 108, 10) {}
# Maxen
# Score are for NS : 0.1439507241620958, EW : 0.11475726891674778, both : 0.10532293155080114
#
# --------------------------------------------------
#
# Run 36
# Calling _duplicate_node  with  (73,) {}
# Action
# Score are for NS : 0.1498830085489933, EW : 0.11906443003963368, both : 0.11170093017333332
# Quick reducing 73 on NS
# Shorten
# Score are for NS : 0.14272480642961255, EW : 0.15108231343279926, both : 0.10566567000003535
# Calling setup_edge  with  ((67, 59), 116, 44) {}
# Maxen
# Score are for NS : 0.20513673924145967, EW : 0.15904529424864594, both : 0.15310500210234249
#
# --------------------------------------------------
#
# Run 37
# Calling _duplicate_node  with  (55,) {}
# Action
# Score are for NS : 0.22455764597010802, EW : 0.1594971548449317, both : 0.16302412666058086
# Quick reducing 77 on NS
# Shorten
# Score are for NS : 0.2200382121327593, EW : 0.1594971548449317, both : 0.1604931390072018
# Calling setup_edge  with  ((10, 9), 108, 18) {}
# Maxen
# Score are for NS : 0.21605856070263119, EW : 0.1594971548449317, both : 0.15922167369336224
#
# --------------------------------------------------
#
# Run 38
# Calling _destroy_node  with  (65,) {}
# Action
# Score are for NS : 0.20731478690753197, EW : 0.12487810821089253, both : 0.14027746021075294
# Reducing node 62
# Calling replace_edge  with  ((53, 60), (62, 67)) {}
# Shorten
# Score are for NS : 0.20731478690753197, EW : 0.11960551582721705, both : 0.13566603093243326
# Calling setup_edge  with  ((18, 2), 118, 25) {}
# Maxen
# Score are for NS : 0.20356336355359445, EW : 0.11960551582721705, both : 0.13438228420739817
#
# --------------------------------------------------
#
# Run 39
# Calling _destroy_node  with  (73,) {}
# Action
# Score are for NS : 0.1993419714939699, EW : 0.10698915444862031, both : 0.12167332811307553
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.1993419714939699, EW : 0.10698915444862031, both : 0.12167332811307553
# Calling setup_edge  with  ((9, 18), 108, 2) {}
# Maxen
# Score are for NS : 0.1993419714939699, EW : 0.10698915444862031, both : 0.12167332811307553
#
# --------------------------------------------------
#
# Run 40
# Calling _destroy_node  with  (5,) {}
# Action
# Score are for NS : 0.20119311134855067, EW : 0.09146565768710055, both : 0.1223734143747825
# Quick reducing 53 on NS
# Shorten
# Score are for NS : 0.1964270667377802, EW : 0.08730821768516117, both : 0.11666811269335602
# Calling setup_edge  with  ((26, 18), 28, 32) {}
# Maxen
# Score are for NS : 0.16574314321144484, EW : 0.09090680040175461, both : 0.10474629747086911
#
# --------------------------------------------------
#
# Run 41
# Calling _destroy_node  with  (34,) {}
# Action
# Score are for NS : 0.16556536579985137, EW : 0.09319935126238524, both : 0.10436091355310592
# Quick reducing 48 on NS
# Removing crossing border edge 48 56 (45, 139, 0)
# Shorten
# Score are for NS : 0.16556536579985137, EW : 0.09319935126238524, both : 0.10436091355310592
# Calling setup_edge  with  ((12, 4), 53, 75) {}
# Maxen
# Score are for NS : 0.16556536579985137, EW : 0.09319935126238524, both : 0.10436091355310592
#
# --------------------------------------------------
#
# Run 42
# Calling _duplicate_node  with  (14,) {}
# Action
# Score are for NS : 0.1654114468395768, EW : 0.11443758452502877, both : 0.11086579220731616
# Quick reducing 79 on EW
# Shorten
# Score are for NS : 0.1654114468395768, EW : 0.09681238528239307, both : 0.10666280103672507
# Calling setup_edge  with  ((13, 15), 5, 6) {}
# Removing crossing border edge 6 71 (6, 81, 0)
# Maxen
# Score are for NS : 0.16401642290847435, EW : 0.10783917106592607, both : 0.10339206713567657
#
# --------------------------------------------------
#
# Run 43
# Calling _duplicate_node  with  (13,) {}
# Action
# Score are for NS : 0.1625101536702051, EW : 0.13077811335077572, both : 0.10819131751098897
# Quick reducing 80 on EW
# Shorten
# Score are for NS : 0.1651964963952059, EW : 0.11752910466667495, both : 0.11055643452567303
# Calling setup_edge  with  ((80, 14), 86, 13) {}
# Maxen
# Score are for NS : 0.16519649639520587, EW : 0.11752910466667495, both : 0.11055643452567303
#
# --------------------------------------------------
#
# Run 44
# Calling _destroy_node  with  (40,) {}
# Action
# Score are for NS : 0.16251402321239586, EW : 0.11672893454950277, both : 0.11301338657013642
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.16251402321239586, EW : 0.11672893454950277, both : 0.11301338657013642
# Calling setup_edge  with  ((56, 59), 99, 50) {}
# Removing crossing border edge 50 64 (143, 104, 0)
# Maxen
# Score are for NS : 0.16251402321239586, EW : 0.11732071406499327, both : 0.11370372974713859
#
# --------------------------------------------------
#
# Run 45
# Calling _destroy_node  with  (26,) {}
# Action
# Score are for NS : 0.1878472417704608, EW : 0.11630969816922596, both : 0.12643356900241134
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.1878472417704608, EW : 0.11630969816922596, both : 0.12643356900241134
# Calling setup_edge  with  ((44, 36), 46, 42) {}
# Maxen
# Score are for NS : 0.159111456835146, EW : 0.15813988396010886, both : 0.12890155064471173
#
# --------------------------------------------------
#
# Run 46
# Calling _destroy_node  with  (32,) {}
# Action
# Score are for NS : 0.18889660530358446, EW : 0.1596068059729477, both : 0.1493690433493872
# Quick reducing 62 on NS
# Shorten
# Score are for NS : 0.18889660530358446, EW : 0.1596068059729477, both : 0.1493690433493872
# Calling setup_edge  with  ((64, 42), 143, 50) {}
# Removing crossing border edge 64 50 (114, 143, 0)
# Removing crossing border edge 48 50 (114, 45, 0)
# Maxen
# Score are for NS : 0.1920093658114692, EW : 0.15338547905771951, both : 0.1482040400212323
#
# --------------------------------------------------
#
# Run 47
# Calling _duplicate_node  with  (48,) {}
# Quasi lonely node 81 with #ngbs = 2
# Action
# Score are for NS : 0.19566908017297877, EW : 0.15430013862066316, both : 0.15103251636994217
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.19566908017297877, EW : 0.15430013862066316, both : 0.15103251636994217
# Calling setup_edge  with  ((42, 41), 114, 50) {}
# Removing crossing border edge 50 41 (114, 149, 0)
# Maxen
# Score are for NS : 0.15860721925561902, EW : 0.13789786918385055, both : 0.1322580437871785
#
# --------------------------------------------------
#
# Run 48
# Calling _duplicate_node  with  (81,) {}
# Quasi lonely node 82 with #ngbs = 2
# Action
# Score are for NS : 0.1786020130165493, EW : 0.14166581857402705, both : 0.142779616860845
# Quick reducing 51 on NS
# Removing crossing border edge 81 51 (114, 149, 0)
# Shorten
# Score are for NS : 0.1786020130165493, EW : 0.14166581857402705, both : 0.142779616860845
# Calling setup_edge  with  ((41, 33), 114, 51) {}
# Removing crossing border edge 41 51 (114, 149, 0)
# Maxen
# Score are for NS : 0.19960899278339142, EW : 0.1460818245239391, both : 0.15919185562160387
#
# --------------------------------------------------
#
# Run 49
# Calling _duplicate_node  with  (29,) {}
# Action
# Score are for NS : 0.18466040652825477, EW : 0.14201720748158284, both : 0.1491068906956241
# Quick reducing 48 on EW
# Removing crossing border edge 48 82 (114, 151, 0)
# Shorten
# Score are for NS : 0.18466040652825477, EW : 0.14201720748158284, both : 0.1491068906956241
# Calling setup_edge  with  ((2, 18), 134, 25) {}
# Maxen
# Score are for NS : 0.14957757504279034, EW : 0.14201720748158284, both : 0.132574046487325
#
# --------------------------------------------------
#
# Run 50
# Calling _duplicate_node  with  (11,) {}
# Action
# Score are for NS : 0.14836714035659873, EW : 0.13933173842787341, both : 0.13032370438032917
# Quick reducing 48 on EW
# Removing crossing border edge 48 82 (114, 151, 0)
# Shorten
# Score are for NS : 0.14836714035659873, EW : 0.13933173842787341, both : 0.13032370438032917
# Calling setup_edge  with  ((42, 50), 148, 59) {}
# Maxen
# Score are for NS : 0.14836714035659873, EW : 0.13576860657553425, both : 0.12910811587628407
#
# --------------------------------------------------
#
# Run 51
# Calling _duplicate_node  with  (56,) {}
# Quasi lonely node 85 with #ngbs = 2
# Action
# Score are for NS : 0.1478073358136643, EW : 0.13087508893498412, both : 0.1280851949856627
# Quick reducing 62 on EW
# Shorten
# Score are for NS : 0.1543135262892985, EW : 0.12679026253253028, both : 0.1280851949856627
# Calling setup_edge  with  ((15, 71), 6, 79) {}
# Maxen
# Score are for NS : 0.1686385348947208, EW : 0.1310392443256814, both : 0.13995214395708847
#
# --------------------------------------------------
#
# Run 52
# Calling _destroy_node  with  (76,) {}
# Action
# Score are for NS : 0.16951672878860305, EW : 0.1332252369414442, both : 0.1413455117952679
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.16951672878860305, EW : 0.1332252369414442, both : 0.1413455117952679
# Calling setup_edge  with  ((25, 18), 114, 64) {}
# Removing crossing border edge 64 25 (114, 151, 0)
# Maxen
# Score are for NS : 0.1478072692512367, EW : 0.12177359137382902, both : 0.12611006299185135
#
# --------------------------------------------------
#
# Run 53
# Calling _duplicate_node  with  (80,) {}
# Action
# Score are for NS : 0.14652956298200515, EW : 0.1202731495718451, both : 0.12458281068443652
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.14652956298200515, EW : 0.1202731495718451, both : 0.12458281068443652
# Calling setup_edge  with  ((13, 4), 139, 75) {}
# Maxen
# Score are for NS : 0.1545078607873814, EW : 0.12095166428083863, both : 0.1255501232867897
#
# --------------------------------------------------
#
# Run 54
# Calling _duplicate_node  with  (4,) {}
# Quasi lonely node 87 with #ngbs = 2
# Action
# Score are for NS : 0.156998387703288, EW : 0.11505461377750786, both : 0.11936027396081159
# Quick reducing 77 on NS
# Shorten
# Score are for NS : 0.15199504292835425, EW : 0.11876156107942785, both : 0.11936027396081159
# Calling setup_edge  with  ((37, 29), 145, 42) {}
# Maxen
# Score are for NS : 0.16342053635142947, EW : 0.14301933946391626, both : 0.13066068198816028
#
# --------------------------------------------------
#
# Run 55
# Calling _duplicate_node  with  (53,) {}
# Action
# Score are for NS : 0.1699560308912001, EW : 0.1467593830857376, both : 0.13548023518331215
# Quick reducing 53 on NS
# Shorten
# Score are for NS : 0.1659025273557561, EW : 0.14309796547476994, both : 0.13223914288559216
# Calling setup_edge  with  ((51, 33), 150, 56) {}
# Maxen
# Score are for NS : 0.188154380241709, EW : 0.1430621912515491, both : 0.14428215104906483
#
# --------------------------------------------------
#
# Run 56
# Calling _destroy_node  with  (61,) {}
# Action
# Score are for NS : 0.18747596500854788, EW : 0.14180381769705447, both : 0.14267731327583616
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.1732683289170228, EW : 0.14180381769705447, both : 0.13540643417647444
# Calling setup_edge  with  ((37, 42), 160, 29) {}
# Maxen
# Score are for NS : 0.1718296238583724, EW : 0.13779569726796861, both : 0.1427955966456727
#
# --------------------------------------------------
#
# Run 57
# Calling _duplicate_node  with  (80,) {}
# Quasi lonely node 89 with #ngbs = 2
# Action
# Score are for NS : 0.1708775834026465, EW : 0.14432402401168135, both : 0.14488687324277105
# Quick reducing 45 on EW
# Shorten
# Score are for NS : 0.1761932215932682, EW : 0.13977554282906593, both : 0.14488687324277105
# Calling setup_edge  with  ((21, 83), 19, 22) {}
# Maxen
# Score are for NS : 0.15764539639937844, EW : 0.13977554282906593, both : 0.1357904580510876
#
# --------------------------------------------------
#
# Run 58
# Calling _destroy_node  with  (18,) {}
# Action
# Score are for NS : 0.1965740167131695, EW : 0.1492472976000476, both : 0.15665140147709264
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.19572733503163933, EW : 0.13747934708306406, both : 0.14967787959523818
# Calling setup_edge  with  ((84, 9), 114, 25) {}
# Removing crossing border edge 25 9 (114, 174, 0)
# Maxen
# Score are for NS : 0.15945476610378823, EW : 0.1428892268405814, both : 0.14021904487008385
#
# --------------------------------------------------
#
# Run 59
# Calling _duplicate_node  with  (81,) {}
# Quasi lonely node 90 with #ngbs = 2
# Action
# Score are for NS : 0.17181227132943472, EW : 0.14487696766356534, both : 0.14684356463027073
# Quick reducing 90 on NS
# Removing crossing border edge 90 82 (152, 174, 0)
# Shorten
# Score are for NS : 0.17181227132943472, EW : 0.14487696766356534, both : 0.14684356463027073
# Calling setup_edge  with  ((84, 25), 173, 41) {}
# Maxen
# Score are for NS : 0.17181227132943472, EW : 0.14487696766356534, both : 0.14684356463027073
#
# --------------------------------------------------
#
# Run 60
# Calling _destroy_node  with  (21,) {}
# Action
# Score are for NS : 0.21518457450849918, EW : 0.13921569457279095, both : 0.15521208316528165
# Quick reducing 81 on NS
# Removing crossing border edge 81 51 (152, 179, 0)
# Shorten
# Score are for NS : 0.21518457450849918, EW : 0.13921569457279095, both : 0.15521208316528165
# Calling setup_edge  with  ((29, 42), 145, 36) {}
# Maxen
# Score are for NS : 0.20661483816784207, EW : 0.14601110225769573, both : 0.1476047335864555
#
# --------------------------------------------------
#
# Run 61
# Calling _destroy_node  with  (23,) {}
# Action
# Score are for NS : 0.20436018545560442, EW : 0.13822386159627315, both : 0.13929299177772403
# Calling outside_with_anchor
# debug_anchor {'next_': 85, 'prev': 51, 'current': 56, 'ngb2': 82, 'ngb1': 90, 'node': 81, 'self': <__main__.RGPN object at 0x7f625b8abcf8>}
# Quick reducing 90 on NS
# Quasi lonely node 81 with #ngbs = 2
# Shorten
# Score are for NS : 0.1902009019571003, EW : 0.14322285276138355, both : 0.1384712158769784
# Calling setup_edge  with  ((37, 44), 179, 42) {}
# Maxen
# Score are for NS : 0.18630508110300248, EW : 0.14322285276138355, both : 0.13764044943820225
#
# --------------------------------------------------
#
# Run 62
# Calling _duplicate_node  with  (20,) {}
# Action
# Score are for NS : 0.15845286265360062, EW : 0.15459332317605137, both : 0.13199326582148888
# Quick reducing 81 on NS
# Shorten
# Score are for NS : 0.1514330147122886, EW : 0.1504072947188972, both : 0.1252981231428875
# Calling setup_edge  with  ((33, 56), 164, 50) {}
# Removing crossing border edge 50 56 (187, 164, 0)
# Maxen
# Score are for NS : 0.15548710677638258, EW : 0.15240898040612302, both : 0.1309048911322473
#
# --------------------------------------------------
#
# Run 63
# Calling _destroy_node  with  (53,) {}
# Action
# Score are for NS : 0.15581176073722092, EW : 0.15073783032511864, both : 0.12917731304230656
# Quick reducing 81 on EW
# Shorten
# Score are for NS : 0.14719991687748862, EW : 0.14652956298200515, both : 0.12173791730762021
# Calling setup_edge  with  ((71, 22), 65, 31) {}
# Maxen
# Score are for NS : 0.14719991687748862, EW : 0.14652956298200515, both : 0.12173791730762021
#
# --------------------------------------------------
#
# Run 64
# Calling _duplicate_node  with  (15,) {}
# Action
# Score are for NS : 0.14937905393604867, EW : 0.14691855487574496, both : 0.12269651487331842
# Quick reducing 86 on EW
# Removing crossing border edge 80 86 (86, 191, 0)
# Shorten
# Score are for NS : 0.14937905393604867, EW : 0.14691855487574496, both : 0.12269651487331842
# Calling setup_edge  with  ((29, 36), 179, 42) {}
# Maxen
# Score are for NS : 0.15536894278529279, EW : 0.13394954845252774, both : 0.12841485732014227
#
# --------------------------------------------------
#
# Run 65
# Calling _destroy_node  with  (11,) {}
# Action
# Score are for NS : 0.19032045527516514, EW : 0.1386601990590429, both : 0.14729059123020388
# Quick reducing 90 on NS
# Shorten
# Score are for NS : 0.18611102117269523, EW : 0.1442106229950116, both : 0.14870278226774616
# Calling setup_edge  with  ((84, 10), 174, 41) {}
# Maxen
# Score are for NS : 0.15043669321196762, EW : 0.13624939241422043, both : 0.12884363942873422
#
# --------------------------------------------------
#
# Run 66
# Calling _destroy_node  with  (33,) {}
# Removing crossing border edge 64 50 (138, 187, 0)
# Action
# Score are for NS : 0.1529438225803745, EW : 0.1365216192439029, both : 0.1270854478878797
# Reducing node 82
# Calling replace_edge  with  ((81, 51), (82, 56)) {}
# Shorten
# Score are for NS : 0.148492538430172, EW : 0.13034547975433394, both : 0.12081366485722354
# Calling setup_edge  with  ((42, 59), 188, 36) {}
# Maxen
# Score are for NS : 0.148492538430172, EW : 0.13034547975433394, both : 0.12081366485722354
#
# --------------------------------------------------
#
# Run 67
# Calling _destroy_node  with  (25,) {}
# Action
# Score are for NS : 0.141902251610066, EW : 0.13149069895419918, both : 0.11798200323108499
# Quick reducing 82 on EW
# Shorten
# Score are for NS : 0.141902251610066, EW : 0.12770900856315118, both : 0.11662177806815871
# Calling setup_edge  with  ((84, 41), 174, 10) {}
# Maxen
# Score are for NS : 0.141902251610066, EW : 0.12770900856315118, both : 0.11662177806815871
#
# --------------------------------------------------
#
# Run 68
# Calling _duplicate_node  with  (77,) {}
# Action
# Score are for NS : 0.15308515110397714, EW : 0.13730853927798434, both : 0.1289329392451521
# Quick reducing 77 on EW
# Shorten
# Score are for NS : 0.15308515110397714, EW : 0.13125279560470568, both : 0.12534552434063498
# Calling setup_edge  with  ((3, 84), 194, 9) {}
# Maxen
# Score are for NS : 0.15476464650682736, EW : 0.13125279560470568, both : 0.1258683215002007
#
# --------------------------------------------------
#
# Run 69
# Calling _duplicate_node  with  (46,) {}
# Action
# Score are for NS : 0.1640184627292735, EW : 0.1343497585623214, both : 0.13246674789584906
# Quick reducing 46 on NS
# Shorten
# Score are for NS : 0.15961805922755767, EW : 0.13098264958143954, both : 0.12807445880675009
# Calling setup_edge  with  ((22, 14), 190, 71) {}
# Maxen
# Score are for NS : 0.1574049157378025, EW : 0.13098264958143954, both : 0.12718680547747999
#
# --------------------------------------------------
#
# Run 70
# Calling _duplicate_node  with  (15,) {}
# Quasi lonely node 95 with #ngbs = 2
# Action
# Score are for NS : 0.16134879168156535, EW : 0.140041833472529, both : 0.13467714140090928
# Quick reducing 77 on NS
# Shorten
# Score are for NS : 0.15294661574324273, EW : 0.140041833472529, both : 0.1307071201494084
# Calling setup_edge  with  ((36, 28), 145, 42) {}
# Maxen
# Score are for NS : 0.15294661574324273, EW : 0.140041833472529, both : 0.1307071201494084
#
# --------------------------------------------------
#
# Run 71
# Calling _duplicate_node  with  (84,) {}
# Action
# Score are for NS : 0.14979986232169745, EW : 0.14658650451451907, both : 0.13471032230954072
# Quick reducing 95 on EW
# Shorten
# Score are for NS : 0.15406191430668337, EW : 0.13766952905645055, both : 0.1326134899814635
# Calling setup_edge  with  ((91, 19), 176, 28) {}
# Maxen
# Score are for NS : 0.15406191430668337, EW : 0.13329889362377437, both : 0.12969855629432275
#
# --------------------------------------------------
#
# Run 72
# Calling _duplicate_node  with  (45,) {}
# Action
# Score are for NS : 0.16154199943154185, EW : 0.1370230223063822, both : 0.1359553914372405
# Quick reducing 86 on EW
# Shorten
# Score are for NS : 0.16154199943154185, EW : 0.13254945226161702, both : 0.13334192246165308
# Calling setup_edge  with  ((29, 28), 181, 91) {}
# Maxen
# Score are for NS : 0.16154199943154185, EW : 0.11756151337500745, both : 0.12740461183850127
#
# --------------------------------------------------
#
# Run 73
# Calling _duplicate_node  with  (20,) {}
# Action
# Score are for NS : 0.16493718995658765, EW : 0.11663029414165697, both : 0.12849757938177958
# Quick reducing 45 on NS
# Shorten
# Score are for NS : 0.15911806797716818, EW : 0.11663029414165697, both : 0.12558198786751013
# Calling setup_edge  with  ((3, 12), 59, 9) {}
# Maxen
# Score are for NS : 0.15911806797716818, EW : 0.12356834466184753, both : 0.12101088703122623
#
# --------------------------------------------------
#
# Run 74
# Calling _destroy_node  with  (59,) {}
# Action
# Score are for NS : 0.15816728134759378, EW : 0.12672364644935535, both : 0.12228354433860811
# Quick reducing 97 on NS
# Shorten
# Score are for NS : 0.15816728134759378, EW : 0.12672364644935535, both : 0.12228354433860811
# Calling setup_edge  with  ((9, 2), 204, 84) {}
# Maxen
# Score are for NS : 0.16033865615577486, EW : 0.13029760274391294, both : 0.12382494131109431
#
# --------------------------------------------------
#
# Run 75
# Calling _destroy_node  with  (92,) {}
# Action
# Score are for NS : 0.1559897754569054, EW : 0.13041013273932528, both : 0.12250211432186704
# Reducing node 86
# Calling replace_edge  with  ((15, 6), (86, 79)) {}
# Shorten
# Score are for NS : 0.1559897754569054, EW : 0.13041013273932528, both : 0.12250211432186704
# Calling setup_edge  with  ((84, 12), 212, 9) {}
# Maxen
# Score are for NS : 0.1559897754569054, EW : 0.12833834012763728, both : 0.12342164601457202
#
# --------------------------------------------------
#
# Run 76
# Calling _destroy_node  with  (56,) {}
# Action
# Score are for NS : 0.16524820115491148, EW : 0.12904608696889447, both : 0.12784460997934025
# Reducing node 93
# Calling replace_edge  with  ((77, 94), (93, 46)) {}
# Shorten
# Score are for NS : 0.17852611057846715, EW : 0.12439109741663826, both : 0.1311596295089265
# Calling setup_edge  with  ((51, 85), 138, 82) {}
# Removing crossing border edge 82 90 (196, 183, 0)
# Maxen
# Score are for NS : 0.1822950950688838, EW : 0.11629011915406012, both : 0.13367033521940966
#
# --------------------------------------------------
#
# Run 77
# Calling _duplicate_node  with  (97,) {}
# Action
# Score are for NS : 0.19001776336033613, EW : 0.12432615303635791, both : 0.14308968362892718
# Quick reducing 99 on NS
# Shorten
# Score are for NS : 0.18461411490651797, EW : 0.12432615303635791, both : 0.1404015145248888
# Calling setup_edge  with  ((4, 12), 59, 3) {}
# Maxen
# Score are for NS : 0.18461411490651797, EW : 0.12297466765574597, both : 0.1407725829830692
#
# --------------------------------------------------
#
# Run 78
# Calling _duplicate_node  with  (54,) {}
# Action
# Score are for NS : 0.19915748074370132, EW : 0.12997903563941302, both : 0.15215462948746128
# Quick reducing 99 on NS
# Shorten
# Score are for NS : 0.19440232697354745, EW : 0.12997903563941302, both : 0.1497864685449575
# Calling setup_edge  with  ((28, 91), 210, 29) {}
# Maxen
# Score are for NS : 0.20107851891413614, EW : 0.17099130376971183, both : 0.15929074760968534
#
# --------------------------------------------------
#
# Run 79
# Calling _duplicate_node  with  (47,) {}
# Action
# Score are for NS : 0.21216241220650228, EW : 0.1701952563375059, both : 0.16256685086149794
# Quick reducing 97 on NS
# Shorten
# Score are for NS : 0.2071643320928904, EW : 0.1701952563375059, both : 0.16004846872538694
# Calling setup_edge  with  ((84, 91), 216, 9) {}
# Maxen
# Score are for NS : 0.2071643320928904, EW : 0.15414867740205074, both : 0.16031443001009776
#
# --------------------------------------------------
#
# Run 80
# Calling _duplicate_node  with  (22,) {}
# Action
# Score are for NS : 0.2201406688063339, EW : 0.1532209320770734, both : 0.1641510217212219
# Quick reducing 86 on NS
# Shorten
# Score are for NS : 0.2201406688063339, EW : 0.1532209320770734, both : 0.1641510217212219
# Calling setup_edge  with  ((91, 9), 198, 19) {}
# Maxen
# Score are for NS : 0.23874375509186627, EW : 0.14904035920939265, both : 0.17026051365323838
#
# --------------------------------------------------
#
# Run 81
# Calling _duplicate_node  with  (86,) {}
# Action
# Score are for NS : 0.24166091947189144, EW : 0.15634719199411432, both : 0.17674747359294166
# Quick reducing 103 on NS
# Shorten
# Score are for NS : 0.23849063593988046, EW : 0.15305718474546118, both : 0.17310574206800303
# Calling setup_edge  with  ((44, 42), 184, 67) {}
# Maxen
# Score are for NS : 0.2438928579323159, EW : 0.15333457909463344, both : 0.17664658900178745
#
# --------------------------------------------------
#
# Run 82
# Calling _duplicate_node  with  (67,) {}
# Action
# Score are for NS : 0.24205952155349278, EW : 0.1534604386298729, both : 0.16793721899433728
# Quick reducing 45 on NS
# Shorten
# Score are for NS : 0.24205952155349278, EW : 0.1534604386298729, both : 0.16793721899433728
# Calling setup_edge  with  ((19, 27), 202, 10) {}
# Maxen
# Score are for NS : 0.2261818038246927, EW : 0.1534604386298729, both : 0.16314550221031016
#
# --------------------------------------------------
#
# Run 83
# Calling _duplicate_node  with  (100,) {}
# Action
# Score are for NS : 0.22912661998959075, EW : 0.15856914995416257, both : 0.1683159045170983
# Quick reducing 86 on NS
# Shorten
# Score are for NS : 0.22601267833736843, EW : 0.15600005918353882, both : 0.16500924116937485
# Calling setup_edge  with  ((104, 42), 188, 44) {}
# Maxen
# Score are for NS : 0.22601267833736843, EW : 0.15600005918353882, both : 0.16500924116937488
#
# --------------------------------------------------
#
# Run 84
# Calling _destroy_node  with  (84,) {}
# Action
# Score are for NS : 0.20441447310432695, EW : 0.1712404557319543, both : 0.15366612150726866
# Quick reducing 100 on NS
# Shorten
# Score are for NS : 0.201033985837068, EW : 0.16878397221735342, both : 0.1499244010398743
# Calling setup_edge  with  ((2, 96), 114, 41) {}
# Maxen
# Score are for NS : 0.201033985837068, EW : 0.16878397221735342, both : 0.1499244010398743
#
# --------------------------------------------------
#
# Run 85
# Calling _destroy_node  with  (71,) {}
# Action
# Score are for NS : 0.15092707126072852, EW : 0.165600330276709, both : 0.1335339855662401
# Reducing node 100
# Calling replace_edge  with  ((88, 62), (100, 60)) {}
# Shorten
# Score are for NS : 0.15092707126072852, EW : 0.16617445750664372, both : 0.13442773109810754
# Calling setup_edge  with  ((91, 96), 198, 12) {}
# Maxen
# Score are for NS : 0.15092707126072852, EW : 0.16191321726088717, both : 0.14025562455970586
#
# --------------------------------------------------
#
# Run 86
# Calling _destroy_node  with  (9,) {}
# Action
# Score are for NS : 0.15033026329235816, EW : 0.16342863293337465, both : 0.1407387302969124
# Quick reducing 99 on EW
# Shorten
# Score are for NS : 0.15033026329235816, EW : 0.16342863293337465, both : 0.1407387302969124
# Calling setup_edge  with  ((28, 19), 219, 91) {}
# Maxen
# Score are for NS : 0.14847846772912465, EW : 0.16342863293337465, both : 0.13935067213889102
#
# --------------------------------------------------
#
# Run 87
# Calling _duplicate_node  with  (82,) {}
# Action
# Score are for NS : 0.1473139127471974, EW : 0.16879738280810813, both : 0.1386723740037182
# Quick reducing 45 on NS
# Shorten
# Score are for NS : 0.14317524669300466, EW : 0.16879738280810813, both : 0.1363760405676178
# Calling setup_edge  with  ((64, 10), 201, 85) {}
# Removing crossing border edge 64 85 (201, 231, 0)
# Maxen
# Score are for NS : 0.2246159936319509, EW : 0.16789887081679206, both : 0.16512964288510942
#
# --------------------------------------------------
#
# Run 88
# Calling _duplicate_node  with  (20,) {}
# Quasi lonely node 20 with #ngbs = 2
# Action
# Score are for NS : 0.22517699813377764, EW : 0.16660048031140826, both : 0.1637581024039711
# Reducing node 62
# Calling replace_edge  with  ((54, 100), (62, 99)) {}
# Shorten
# Score are for NS : 0.2218629769233717, EW : 0.16929177754700464, both : 0.1637581024039711
# Calling setup_edge  with  ((41, 2), 204, 96) {}
# Maxen
# Score are for NS : 0.16012815380508713, EW : 0.19676394329936583, both : 0.14701296470510083
#
# --------------------------------------------------
#
# Run 89
# Calling _destroy_node  with  (82,) {}
# Action
# Score are for NS : 0.1613743060919757, EW : 0.18665692635588763, both : 0.14449769120487826
# Reducing node 54
# Calling replace_edge  with  ((62, 99), (54, 100)) {}
# Shorten
# Score are for NS : 0.16490949796727247, EW : 0.18407900701773808, both : 0.14449769120487826
# Calling setup_edge  with  ((41, 10), 201, 64) {}
# Maxen
# Score are for NS : 0.16227011581753015, EW : 0.18148726882502506, both : 0.14301359580388404
#
# --------------------------------------------------
#
# Run 90
# Calling _duplicate_node  with  (106,) {}
# Action
# Score are for NS : 0.16102379783833448, EW : 0.18868377105333334, both : 0.1442565878629793
# Reducing node 62
# Calling replace_edge  with  ((100, 60), (62, 88)) {}
# Shorten
# Score are for NS : 0.1644567496049612, EW : 0.18795176617139697, both : 0.14554029831823093
# Calling setup_edge  with  ((96, 19), 201, 41) {}
# Maxen
# Score are for NS : 0.13667767623494714, EW : 0.19068814520941652, both : 0.13969896391954978
#
# --------------------------------------------------
#
# Run 91
# Calling _duplicate_node  with  (75,) {}
# Action
# Score are for NS : 0.13571265267813623, EW : 0.1780646227511098, both : 0.13643199394550656
# Reducing node 100
# Calling replace_edge  with  ((62, 88), (100, 60)) {}
# Shorten
# Score are for NS : 0.13191002568786364, EW : 0.1785024072486953, both : 0.13514173547110764
# Calling setup_edge  with  ((22, 98), 190, 20) {}
# Maxen
# Score are for NS : 0.13191002568786364, EW : 0.1737149937785324, both : 0.13325343680308457
#
# --------------------------------------------------
#
# Run 92
# Calling _duplicate_node  with  (47,) {}
# Action
# Score are for NS : 0.14557886715174184, EW : 0.17243211821504917, both : 0.13505240756156642
# Quick reducing 55 on NS
# Shorten
# Score are for NS : 0.1354882110383773, EW : 0.17322717878069485, both : 0.1350351354983073
# Calling setup_edge  with  ((83, 29), 175, 102) {}
# Maxen
# Score are for NS : 0.1354882110383773, EW : 0.1472366387713178, both : 0.12125429569205175
#
# --------------------------------------------------
#
# Run 93
# Calling _destroy_node  with  (31,) {}
# Action
# Score are for NS : 0.12806248474865697, EW : 0.1444880643628346, both : 0.116230724900157
# Quick reducing 81 on EW
# Shorten
# Score are for NS : 0.12806248474865697, EW : 0.14080153722988034, both : 0.11491476562288178
# Calling setup_edge  with  ((14, 13), 192, 80) {}
# Maxen
# Score are for NS : 0.12912312684288896, EW : 0.13450760877394657, both : 0.11175369742826806
#
# --------------------------------------------------
#
# Run 94
# Calling _duplicate_node  with  (10,) {}
# Action
# Score are for NS : 0.12602902090374943, EW : 0.1341955971158327, both : 0.1084849194293976
# Reducing node 62
# Calling replace_edge  with  ((54, 100), (62, 99)) {}
# Shorten
# Score are for NS : 0.12171465431450454, EW : 0.13560951967961182, both : 0.1084849194293976
# Calling setup_edge  with  ((29, 102), 238, 98) {}
# Maxen
# Score are for NS : 0.11803583185709274, EW : 0.13397311518044216, both : 0.10774956879196722
#
# --------------------------------------------------
#
# Run 95
# Calling _duplicate_node  with  (37,) {}
# Action
# Score are for NS : 0.12385950294825276, EW : 0.1340543561322562, both : 0.09901388758325716
# Quick reducing 102 on NS
# Shorten
# Score are for NS : 0.12025989418850905, EW : 0.13636363636363635, both : 0.10175530284296079
# Calling setup_edge  with  ((98, 91), 11, 109) {}
# Maxen
# Score are for NS : 0.13036891647430318, EW : 0.136652562736651, both : 0.11089470041744856
#
# --------------------------------------------------
#
# Run 96
# Calling _destroy_node  with  (97,) {}
# Action
# Score are for NS : 0.1302860212358443, EW : 0.14236061053734844, both : 0.11381659588861391
# Reducing node 54
# Calling replace_edge  with  ((62, 99), (54, 45)) {}
# Shorten
# Score are for NS : 0.14189357582930961, EW : 0.13585284241319914, both : 0.11482245980057874
# Calling setup_edge  with  ((47, 22), 241, 14) {}
# Maxen
# Score are for NS : 0.1402429797821163, EW : 0.10129755194401663, both : 0.09533398131774144
#
# --------------------------------------------------
#
# Run 97
# Calling _destroy_node  with  (22,) {}
# Action
# Score are for NS : 0.12392814083154204, EW : 0.12488934976679249, both : 0.10252293443570341
# Quick reducing 99 on NS
# Shorten
# Score are for NS : 0.11867117911120391, EW : 0.12176959746050395, both : 0.09755417476614618
# Calling setup_edge  with  ((20, 98), 11, 107) {}
# Maxen
# Score are for NS : 0.11682857179378991, EW : 0.09868997058023411, both : 0.08509492333652956
#
# --------------------------------------------------
#
# Run 98
# Calling _destroy_node  with  (47,) {}
# Action
# Score are for NS : 0.09725062657150055, EW : 0.0777197567625065, both : 0.07391726848675319
# Quick reducing 54 on NS
# Shorten
# Score are for NS : 0.092920519369713, EW : 0.07842843292648662, both : 0.07281863128851587
# Calling setup_edge  with  ((75, 12), 59, 87) {}
# Maxen
# Score are for NS : 0.09366391184573002, EW : 0.062448822265282235, both : 0.06095574738373794
#
# --------------------------------------------------
#
# Run 99
# Calling _destroy_node  with  (96,) {}
# Action
# Score are for NS : 0.12084075401643331, EW : 0.06251318946899416, both : 0.06783286321136217
# Quick reducing 62 on NS
# Shorten
# ...
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 252
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 253
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 254
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 255
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 256
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 257
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 258
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 259
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 260
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 261
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 262
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 263
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 264
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 265
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 266
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 267
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 268
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 269
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 270
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 271
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 272
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 273
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 274
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 275
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 276
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 277
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 278
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 279
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 280
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 281
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 282
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 283
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 284
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 285
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 286
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 287
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 288
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 289
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 290
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 291
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 292
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 293
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 294
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 295
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 296
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 297
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
#
# --------------------------------------------------
#
# Run 298
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891
# Reducing node 105
# Calling replace_edge  with  ((88, 37), (105, 67)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
#
# --------------------------------------------------
#
# Run 299
# Action
# Score are for NS : 0.09655082710109865, EW : 0.08295522479100842, both : 0.0793564942518123
# Reducing node 88
# Calling replace_edge  with  ((105, 67), (88, 37)) {}
# Shorten
# Score are for NS : 0.09655082710109865, EW : 0.08107501920564492, both : 0.0780475206509891

# %%
lA, lB, lC = gpn.get_all_dists()
plt.subplot(3, 1, 1)
plt.hist(lA)
plt.subplot(3, 1, 2)
plt.hist(lB)
plt.subplot(3, 1, 3)
plt.hist(lC)
# Out:
# (array([ 9., 21., 16., 12.,  9.,  8., 12.,  3.,  5.,  1.]),
#  array([ 9. , 10.9, 12.8, 14.7, 16.6, 18.5, 20.4, 22.3, 24.2, 26.1, 28. ]),
#  <BarContainer object of 10 artists>)

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-9c9a2cba73bf> in <module>
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
for x in [(-1, 117, 1), (117, 118, 0), (118, 47, 0), (-1, 120, 0), (120, 47, 0)]:
    print(gpn.dual(x))

# %%
gpn.G.nodes[9], gpn.G.nodes[8], gpn.G.nodes[0]

# %%
gpn.show_all()

# %%
pos = nx.spring_layout(gpn.G, pos=pos, k=0.1, iterations=10)
gpn.update_all_dist()
gpn.show_dist(pos=pos, figsize=(8, 8))

# %%
gpn.dual((125, 15)), gpn.ngb(15), gpn.ngb(7), gpn.dual((125, 7))

# %%
raise

# %%
list_inner = [gpn.G.degree(n) for n in gpn.G.nodes if not gpn.is_border_node(n)]
list_outer = [gpn.G.degree(n) for n in gpn.G.nodes if gpn.is_border_node(n)]

# %%
plt.hist(list_inner)

# %%
plt.hist(list_outer)

# %%
gpn.show_all()

# %%
raise

# %%
# test 1
def test_func():
    gpn = GrowingPlanarNetwork()
    gpn.init_square(8)
    for i in range(500):
        if p_dupl():
            gpn.duplicate_random_node()
        else:
            gpn.remove_random_node()
    dist = np.array(list(nx.betweenness_centrality(gpn.G).values()))
    return (skew(dist), kurtosis(dist), gpn.G, gpn.D)

for i in range(10):
    S, K, G, D = test_func()
    print(G.size(), D.degree(-1))

# %%
G = gpn.G

# %%
pos = nx.spring_layout(G, k=0.1, iterations=50)
pos = nx.planar_layout(gpn.G)
plt.figure(figsize=(12, 12))
nx.draw_networkx(gpn.G, pos=pos)

# %%
pos = nx.planar_layout(Gstart)
plt.figure(figsize=(12, 12))
nx.draw_networkx(Gstart, pos=pos)

# %%
raise

# %%
gpn.show_all()

# %%
ls_ngb = [len(gpn.ngb(x)) for x in gpn.G.nodes]

# %%
plt.hist(ls_ngb)

# %%
raise

# %%
couple_ngb = [(len(gpn.ngb(x)), x) for x in gpn.G.nodes if len(gpn.ngb(x)) > 4]
couple_ngb

# %%
gpn.stabilize_ngb(10)

# %%
couple_ngb = [(len(gpn.ngb(x)), x) for x in gpn.G.nodes if len(gpn.ngb(x)) > 4]
couple_ngb
